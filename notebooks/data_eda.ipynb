# %% [markdown]
# ## Imports

# %%
import os
import glob
import numpy as np
import pandas as pd
import json
os.chdir("/Users/huongn/Desktop/open_whisper")

# %%
metadata_files = glob.glob("data/metadata/*.parquet")
metadata_files
# Out:
# ['data/metadata/captions-0001.parquet',
#  'data/metadata/captions-0008.parquet',
#  'data/metadata/captions-0009.parquet',
#  'data/metadata/captions-0010.parquet',
#  'data/metadata/captions-0000.parquet',
#  'data/metadata/captions-0002.parquet',
#  'data/metadata/captions-0003.parquet',
#  'data/metadata/captions-0006.parquet',
#  'data/metadata/captions-0007.parquet',
#  'data/metadata/captions-0005.parquet',
#  'data/metadata/captions-0004.parquet']

# %% [markdown]
# ## UDFs

# %%
def standardize_dialects(s):
    words = s.split(",")
    transformed_words = [word.split("-")[0] if "-" in word else word for word in words]
    return ",".join(transformed_words)

# %%
def standardize_dialects_list(s):
    words = s.split(",")
    transformed_words = [word.split("-")[0] if "-" in word else word for word in words]
    return transformed_words

# %%
def get_percent_empty(df):
    return df.apply(lambda col: (col == "").mean() * 100)

# %%
def clean_df(df):
    df = df.copy()
    # fill in missing values with empty string
    df["automatic_caption_orig_language"] = df[
        "automatic_caption_orig_language"
    ].fillna("")
    df["language"] = df["language"].fillna("")

    # maybe don't need code above because this takes care of en case as well
    df["manual_caption_languages"] = df["manual_caption_languages"].apply(
        standardize_dialects
    )
    df["automatic_caption_orig_language"] = df["automatic_caption_orig_language"].apply(
        standardize_dialects
    )
    df["language"] = df["language"].apply(standardize_dialects)

    # check if all "en" types have been changed to strictly "en"
    if "-" in df["manual_caption_languages"].unique():
        print("dialects still exists in manual_caption_languages")
    else:
        print(
            "all dialects have been changed to strictly family language in manual_caption_languages"
        )

    if "-" in df["automatic_caption_orig_language"].unique():
        print("dialects still exists in automatic_caption_orig_language")
    else:
        print(
            "all dialects have been changed to strictly family language in automatic_caption_orig_language"
        )

    if "-" in df["language"].unique():
        print("dialects still exists in language")
    else:
        print("all dialects have been changed to strictly family language in language")

    return df

# %%
def check_in_col(row, ref_col, tgt_col):
    words = [word.strip() for word in row[tgt_col].split(",")]
    # Check if the second column's value is in the list of words
    return row[ref_col] in words

# %%
def get_duration_ml_t(df):
    condition = (
        df["manual_caption_languages"]
        .str.split(",")
        .apply(lambda lst: set(lst) == {"en"})
    )
    not_strictly_en_df = df[~condition]
    condition_4 = not_strictly_en_df["manual_caption_languages"].str.contains("en")
    no_en_df = not_strictly_en_df[~condition_4]
    condition_5 = (
        no_en_df["manual_caption_languages"]
        .str.split(",")
        .apply(lambda lst: len(lst) == 1)
    )
    one_man_lang_df = no_en_df[condition_5]
    condition_6 = (
        (
            one_man_lang_df["manual_caption_languages"]
            == one_man_lang_df["automatic_caption_orig_language"]
        )
        | (one_man_lang_df["automatic_caption_orig_language"] == "")
        | (one_man_lang_df["automatic_caption_orig_language"] == "en")
    )
    condition_7 = (
        no_en_df["manual_caption_languages"]
        .str.split(",")
        .apply(lambda lst: len(lst) > 1)
    )
    many_man_lang_df = no_en_df[condition_7]
    condition_8 = many_man_lang_df.apply(
        check_in_col,
        axis=1,
        args=("automatic_caption_orig_language", "manual_caption_languages"),
    )

    temp_2 = many_man_lang_df[condition_8]
    # getting data complement of condition 8
    temp_3 = many_man_lang_df[~condition_8]
    # getting data where automatic_caption_orig_language == ""
    condition_9 = temp_3["automatic_caption_orig_language"] == ""
    temp_4 = temp_3[condition_9][
        temp_3[condition_9].apply(
            check_in_col, axis=1, args=("language", "manual_caption_languages")
        )
    ]
    condition_10 = temp_3["automatic_caption_orig_language"] != ""
    temp_5 = temp_3[condition_10][
        temp_3[condition_10].apply(
            check_in_col, axis=1, args=("language", "manual_caption_languages")
        )
    ]
    condition_11 = (
        condition_4
        & (not_strictly_en_df["automatic_caption_orig_language"] != "en")
        & (not_strictly_en_df["automatic_caption_orig_language"] != "")
    )
    condition_12 = not_strictly_en_df[condition_11].apply(
        check_in_col,
        axis=1,
        args=("automatic_caption_orig_language", "manual_caption_languages"),
    )
    temp_6 = not_strictly_en_df[condition_11][condition_12]
    condition_13 = (
        (not_strictly_en_df["manual_caption_languages"].str.contains("en"))
        & ("" == not_strictly_en_df["automatic_caption_orig_language"])
        & (not_strictly_en_df["language"] != "en")
    )
    condition_14 = (
        (not_strictly_en_df["manual_caption_languages"].str.contains("en"))
        & (not_strictly_en_df["automatic_caption_orig_language"] == "en")
        & (not_strictly_en_df["language"] != "en")
        & (not_strictly_en_df["language"] != "")
    )
    condition_15 = (
        (not_strictly_en_df["manual_caption_languages"].str.contains("en"))
        & ("" == not_strictly_en_df["automatic_caption_orig_language"])
        & (not_strictly_en_df["language"] != "en")
        & (not_strictly_en_df["language"] != "")
    )
    condition_16 = not_strictly_en_df[condition_15].apply(
        check_in_col,
        axis=1,
        args=("language", "manual_caption_languages"),
    )
    temp_7 = not_strictly_en_df[condition_15][condition_16]
    condition_17 = not_strictly_en_df[condition_14].apply(
        check_in_col,
        axis=1,
        args=("language", "manual_caption_languages"),
    )
    temp_8 = not_strictly_en_df[condition_14][condition_17]

    ml_dur = (
        one_man_lang_df[condition_6]["duration"].sum() / (60 * 60)
        + temp_2["duration"].sum() / (60 * 60)
        + temp_4["duration"].sum() / (60 * 60)
        + temp_5["duration"].sum() / (60 * 60)
        + temp_6["duration"].sum() / (60 * 60)
        + temp_7["duration"].sum() / (60 * 60)
        + temp_8["duration"].sum() / (60 * 60)
    )
    t_dur = (
        (not_strictly_en_df[condition_11]["duration"].sum() / (60 * 60))
        + (not_strictly_en_df[condition_13]["duration"].sum() / (60 * 60))
        + (not_strictly_en_df[condition_14]["duration"].sum() / (60 * 60))
    )

    return ml_dur, t_dur

# %%
def get_duration_en_only(df):
    # getting data that's strictly en in manual_caption_languages
    condition = (
        df["manual_caption_languages"]
        .str.split(",")
        .apply(lambda lst: set(lst) == {"en"})
    )
    manual_en_df = df[condition]

    temp = df[~condition]

    # getting data where en in manual_caption_languages (not exactly "en") (temp) and en == automatic_caption_orig_language
    condition_2 = (
        (temp["manual_caption_languages"].str.contains("en"))
        & (temp["automatic_caption_orig_language"] == "en")
        & ((temp["language"] == "en") | (temp["language"] == ""))
    )

    # getting data where en in manual_caption_languages (not exactly "en") (temp) and "" == automatic_caption_orig_language but en == language
    condition_3 = (
        (temp["manual_caption_languages"].str.contains("en"))
        & ("" == temp["automatic_caption_orig_language"])
        & (temp["language"] == "en")
    )

    # returning total duration
    return (
        (manual_en_df["duration"].sum() / (60 * 60))
        + (temp[condition_2]["duration"].sum() / (60 * 60))
        + (temp[condition_3]["duration"].sum() / (60 * 60))
    )

# %%
def view_lang_cols(df, num_rows=5):
    return df[["id", "title"] + [col for col in df.columns if "lang" in col]].head(num_rows)

# %%
def get_num_rows(df):
    return df.shape[0]

# %%
def subsample_data(df, per_iter_sample: int, hours_to_subsample: int):
    subsampled_ids = []
    ids_list = df["id"].tolist()
    dur = 0
    rng = np.random.default_rng(42)
    while True:
        # Randomly subsample a specified amount of values from 'category' column
        subsampled_values = rng.choice(ids_list, per_iter_sample, replace=False)
        subsampled_ids.extend(subsampled_values)
        
        dur += df[df['id'].isin(subsampled_values)]["duration"].sum() / (60 * 60)
        print(f"{dur=}")
        print(f"{len(subsampled_values)=}")
        
        if dur >= hours_to_subsample:
            break
        else:
            ids_list = list(set(ids_list) - set(subsampled_values))

    return subsampled_ids

# %%
def get_subsampled_batches(subsampled_ids_langs, batch_size):
    subsampled_batches = [{f"videoIds": subsampled_ids_langs[i:i + batch_size], "batchIdx": i // batch_size} for i in range(0, len(subsampled_ids_langs), batch_size)]
    return subsampled_batches

# %% [markdown]
# ## Getting Video IDs

# %% [markdown]
# ### Loading in data from parquet files

# %%
df_list = []
for path in metadata_files:
    df = pd.read_parquet(path)
    df_list.append(df)
main_df = pd.concat(df_list)
main_df.reset_index(drop=True, inplace=True)

# %%
len(main_df)
# Out:
# 60102381

# %%
main_df_dedup = main_df.drop_duplicates(subset=["id"], keep="first")
len(main_df_dedup)
# Out:
# 60098151

# %%
main_df_dedup["duration"].sum() / (60 * 60)
# Out:
# 11933139.694166666

# %%
main_df.columns
# Out:
# Index(['id', 'title', 'duration', 'view_count', 'categories', 'comment_count',
#        'like_count', 'channel', 'channel_id', 'channel_follower_count',
#        'age_limit', 'upload_date', 'is_live', 'was_live', 'format',
#        'format_id', 'language', 'filesize', 'stretched_ratio', 'width',
#        'height', 'fps', 'dynamic_range', 'aspect_ratio', 'abr', 'vbr',
#        'vcodec', 'asr', 'audio_channels', 'chapters',
#        'manual_caption_languages', 'automatic_caption_orig_language',
#        'location', 'license'],
#       dtype='object')

# %% [markdown]
# ### Duplicates in df from joining parquet files (exploration - don't run)

# %%
len(main_df)
# Out:
# 60102381

# %%
len(set(main_df["id"]))
# Out:
# 60098151

# %%
len(main_df["id"]) - len(set(main_df["id"]))
# Out:
# 4230

# %%
unique_count_main_df = len(set(main_df["id"]))
unique_count_downloaded = len(set(id_downloaded))
print(unique_count_main_df, unique_count_downloaded)
print(unique_count_main_df - unique_count_downloaded)
# Out:
# 60098151 2448500
# 57649651

# %%
main_df_dedup = main_df.drop_duplicates(subset=["id"], keep="first")
len(main_df_dedup)
# Out:
# 60098151

# %% [markdown]
# #### Confirmation that there are duplicates when joining all parquet files

# %%
from collections import defaultdict
d = defaultdict(int)
for id in main_df["id"].tolist():
    d[id] += 1

# %%
for id, count in d.items():
    if count > 1:
        print(id)
# Out:
# fyvEDS-PQO8
# QIySuiQ3_Yw
# -t-J098gF10
# QAgrHKTqkIE
# 5F5oJyZv0Dc
# LLIwgjSQnj0
# X3-I_5gdZ00
# 2We5HvMPLFY
# EcqahSwiJRo
# xqS5zApPnKw
# V7gZj9C9OUk
# liPcdDFouP0
# lqNAbx1nXkc
# xFAckAQoIFs
# OdJyNoOeYHo
# XdC3qMWmap8
# xUC88-IuEkM
# kNgP0TF-ENQ
# Rz8zo1iPr0k
# Gm-zwbxzzOQ
# LK4r2ePVb1U
# wseZE-FzyQw
# WG7XUDDBnpM
# L6Hi4HSVBDQ
# Woa4MU04aVk
# slUYJZ1Fm3E
# _MjflJq6f7w
# I2ADZMmP0Uc
# CpxeV9XMvdg
# gfv9EjSMQ60
# FKvAfEpijPE
# ScRAOOK-Vlc
# ppAk683jX_0
# BnQ_T-rjeJA
# EaYAwNY5OHw
# 8mGu6xP74Hk
# dtrfTUw6vKc
# XfdnPE7bQ_A
# bzWAKI7lFp4
# D3Fn3914hOI
# s6vH0tYrh9o
# L7joInxvxkw
# YKXT1oMhCWk
# ML_d9o0eQ7g
# 6lhiTVDJzio
# tSuKLGf1jXE
# e_MzXz3D8qQ
# X80Epyyy450
# r3jSMTmdhP8
# ew0w8-StOb4
# nkesANaBEBc
# sD4tmb_VYUU
# XKIC5ZAcumE
# C42IcopodNE
# yHwFqC8k4bE
# KH8HYrX-JvY
# GvIyZ1kVoTw
# 3-4RV5d9w4U
# 7Nt_W_TM1yw
# YELcmcSY1eA
# SlNh4aRMRT8
# _0j9JoWm9Uo
# 877UTIzw_Oo
# I51gsm0FHTg
# mdXmMblgj9Y
# ojnM5FfSHNY
# gmpdNWFCLwk
# LIk59pRMU58
# F_LESLVzU_M
# MlZvjMePLaM
# cVnZuq1XBa0
# O9npRJ6OVvM
# PCyiFADtKHY
# xLdrfWIs84Y
# KlkqaZuqkoo
# 5wy9JRzJ7aM
# ohc5qPk3y6w
# wE6-OYTH7ks
# C5SaOTC0tIM
# Qd1HedDfZRU
# ucg0U4qZ1UU
# XKhHI3wMcdc
# LRjt2rDtQok
# t7liAk1JPrc
# 7Ik3qUjzgFQ
# ogoLrcU-w5w
# EmRqwvk1KgI
# DXdTAK8lTcY
# A427cYw9QQs
# S254Z2CgEGw
# JiXNATXxjnw
# EM_u1CR82rY
# BT3Jsgimp20
# uF_Mu-7aaIs
# 6O-inTztoXo
# XPzxni16Iuo
# YDzHynGv_d4
# 8V6Q3SumXJM
# NhbGVsYM2Eo
# WFYlv2ItG44
# hcniaZE55D4
# Oy_CW5iaP18
# Hi-TEFvUn7w
# H1CG0w62E_c
# o5PNEjn2szo
# 6pJ3_dvwELI
# srQ_knBrxtI
# HfCfr9AzuRU
# pmJq3tfQ698
# 6UlEhexCim4
# WjPkLKadT9Q
# TTWvpShMbEQ
# BiYP9eYVZxk
# QrsKF6d6tug
# WpEWFm7C0xY
# 2wQb2f4pMCQ
# 7efZKfDDDgU
# NQqvhKAHdlM
# ifAa8wlraXk
# vFMKZbfM-A8
# ZRsIi8_2kVY
# EgUnnFJSJ7M
# 9sMICIUmKOU
# bQGDMrwxZtQ
# iJSRfXGJMNo
# daUnuvs_8V0
# T4NWKWknWw8
# MoKTpfq1t88
# OBCD5Lzz5T4
# NEIGWQdKf9M
# zIlf4tXqvqw
# QBi7p_jqdQw
# RKrVrl2tMBw
# jDwJawAsDbg
# RalP4zAYDDI
# wO2gGpX9h4E
# D437KwiHuts
# r1M_pSse70M
# YEGGwAASmMY
# 48g3oIlxngM
# yOrzMYlBPvs
# _rChf46fIjU
# 17qV9hXin8Y
# A5AIfuw9QDY
# O7bVeraRGL4
# Q0Z31JqwzEQ
# DOrbRovUVl4
# tOoOB263dGQ
# xDLvGzI0seA
# ML-FiO1syrw
# 6iWEBhlgUTU
# dCRk_KRwGuM
# 3U--g4iDHgo
# SHK9bt4Ofi4
# L-aqfGKaFto
# iuvL6uPsM_w
# qMLjSncsQaM
# ycJ0MnvxWQU
# lNK5rrD14GI
# khxkKuR5BAA
# zaa7FhfTNq0
# F1EFSUeSAvI
# ckC5SMCIAe0
# 9EZRJGOV4cE
# Zbgy1yZl8Dk
# h6nBFoEQ21k
# hZDUpXaSkIA
# dD7nflI7KPc
# MG0sT9gvHX4
# HWT1c-J672M
# yrf3dNp9yBc
# v_HYZkuMQw0
# Ecmf6betSZ8
# NJDCNpdUR-w
# E9doqPpeGcA
# OGyD2KkrRxQ
# mZ_QggQou8U
# a8MdoxOLO40
# WgkTDouZYl0
# a7Q0Y7zFyHc
# GY1CgLWpbcI
# 6za4kBb32Mc
# 6TpKc0KT02w
# snK8vWdpCGs
# _FZ03xExT0E
# pTLotb4cZh4
# zWlZCVADCOc
# ONCxzJYLemk
# DOveJ-XFHcE
# D1UBOzYkxaQ
# 3BsLDw98vyI
# -wUij-4lmJc
# XvredyBYnOA
# BINSjbNN74Q
# gcpXJSndz20
# 02_0FqpyJnQ
# _m56_mCdQFU
# 9v9zCExtCSI
# EqcQARkXw0U
# QYc4UKC6f3s
# x8dAPxu927Q
# lIiJkpyxPiE
# 0bSF19lBzao
# RlRshcwdY7E
# XiFw2iW83as
# FcuUv35bhG8
# npxNKvLcUTA
# YT40s5-zhEs
# DZnK2xU0od4
# 4q54M2VxPaQ
# wdEHzIWB-Ak
# haJpsec2fRM
# bWf5a5W51sk
# TCdfdDzAueY
# Ttfs7juBFUg
# vm2MVeKVrAg
# ufdF0XUTbMI
# 1csSrd0TG6Q
# 9UPQ6B34HDk
# nwCsjXgKZfQ
# 8ALMd3lQxJ0
# YQzgAqQFR2k
# yZS-9V4HdL4
# wyBJFb2LV4k
# 2DOP3jhEo-U
# dMAtxWuGaQk
# Z4x9nXzV12I
# E2Vo9YaOqKk
# LieJoFurgZc
# gBkwXHDnNQA
# GHo4KW6gDg4
# XCnIRWZVE4U
# x8oEZN2buY4
# yw8dIf4SNQM
# zE1sv71_u9s
# WNoSIa8--ZE
# a_xKOuq9XOE
# gnlNVlWdGuM
# XoQX0zr2UNg
# GvnMX6npaBk
# bseRddB38BE
# oSHz6FEYsWM
# q2GUwRBq5pY
# qLhL9p_uuvM
# NrPEG9zLXWw
# qzPgCpUIEV0
# yi6aYKxYEvU
# q9FeJtac65s
# wpg_NaXs6bA
# KinzfviHC9Y
# 7e-y1tX8EP4
# wI09n224avQ
# yS_8oL3alWo
# P8yVSDWXFeM
# 23TDL-Ksu7s
# qENpOVAiB4g
# 6qhKZRP6Lhs
# Gh4hQpL9gc4
# cbMkDDOMzFM
# LUQPJU5kt54
# tVR7XwdqVE0
# cwI8pf_-9lE
# 9SEiUujbjtI
# gSEo20CXe0Q
# no1Cxm8b4M0
# _go0sYYgU8o
# vhVc2KorDUc
# y6JYeSekeFI
# YGdTXtWA1Tg
# HuVk6nKNpQM
# cK613OrNI7Q
# nNVKhXNV7_U
# ah6WMZ1jFoI
# 0ZtOGQFVKM8
# Nf2wKRulFz8
# fJ0YywdMx_E
# JL2RpBSOSyI
# 0f8nJdIrRuE
# uEN2KNAxHrY
# rdQqbxkIqfw
# CkmfdQZ2-7s
# kx97vuBTexU
# YnmpLhhWRlY
# iyIo19C4JFI
# A7SWcc0ENow
# x9PgxTSbo0o
# sdZxSxRGVlk
# f9PIosD__fA
# KUQhiDWFT_Y
# eCNHFRJrUpI
# lxEMXt99tQw
# MviQ-YdayaU
# esuyHyBkDXY
# CU2yQxzkvFg
# S_73G8Qca9c
# j-b9TgMD-eE
# exQrNh99I0Q
# aDfKUHPIFKg
# 2DOTHkqbd_8
# bNu0hPMb9jQ
# FS1cK6vzY7o
# Qoym7QNilcs
# qp_Zf_i12Vk
# G6uT8IEtVXk
# 2nJlBh40DKY
# DtCZh9CVRGU
# 7JXQBQ6wre4
# 47UvD9YI9IU
# UBoIy2CKW08
# wyjVL9_tWew
# iZ6mMFRq6fc
# AY1jEKMxewQ
# 1xMiC2wWBaU
# 9yRClH6eZE8
# UHkOgU8mMCo
# NfvbMkzjPMk
# _VT2CA6uREY
# 0PGyNieM93w
# Y2D2XhBQJHo
# JeAbM_wJ-iM
# wWmNyU5nJmQ
# Bjfe3wT1b-0
# lCnH_SJBYZE
# ofOYAMhINeA
# TX07Ewvm7eY
# iWtsjUKlHec
# w9JJinOPJI0
# _WjaMRqXDp8
# KSto2hHxBEI
# NPCr6hXMde8
# SkIFj3PNMXQ
# VDl5Sp2mUqM
# Yn8pWy5fDSQ
# 9xX3SNvOwVw
# WauHn0zA4K8
# Y6Qwm0C19xM
# ruu2HO_ue_0
# Ovknk7B9XzU
# DoYMqYk1RRo
# 2O_1HDwIm6s
# nfFW8zs8nVo
# KlTZTjM4uew
# daJ1AJ708bw
# cw2n49-yTpw
# Qswx7IAAESU
# 0zGqaAEmmVU
# PPZXmYHynzc
# l1a0SUd3rKE
# ZMJEMUTWHBE
# _LExdLKXmRY
# KZz49YN9JU0
# BnZ-xIWzXJ4
# MpCjMqoQctI
# gMTe6YrDKLo
# eh77AUKedyM
# zfaOQmXTwQY
# zU14wZPV128
# BomaHfDnJjc
# IFwuwo5aW4I
# v2b2E1v4BkY
# 8lojzxNznmI
# yA-TrgTDil0
# 63x3Jr14Ih4
# afNoaGO212I
# XrWKbCmpjjU
# DS9T0sUn75I
# T1Qo_nCkgac
# seWUQgYsuGg
# k82ZYEGjh_M
# svJfG2WuxdM
# Pd1QYpvnhaw
# trNWGDcL5Do
# sVWxqmFwTgo
# UN5fzu7O7UQ
# R10G9ABqwWA
# 2CCDJr0GLPc
# Dn5u5A41fiM
# ym_WnZ5cu2E
# 5erxDoYYCOM
# TF-7J3LhpNE
# LXmwlbt0hlo
# tR1R-NOTxZ4
# cendNj0K5u4
# z74yKLL1O_I
# 91mbHKlhQvU
# EMgELLmFdrs
# nebg8dip8xM
# 1MwMsz2O0cc
# r9l48abLlL0
# TnnoF_2NlPs
# 2HF9kCfxo38
# TaR7hMgsntc
# ps29ajwb_O0
# VViqBUth0mg
# 05-BZ8RByf0
# jCrP6qRODEk
# pdWlmeQZLEg
# rue0DygTr2U
# O5nCl8M19GE
# VWI0niUrOXA
# FUafRTTAw04
# yhcnYReSIZc
# X8pMEWa0rEk
# jVgoDgy0I-s
# sLZOE7MlIl8
# 6_2lRdufhRY
# Fb7AvBIzwzw
# jlYSN40AQqY
# 7BGT79c6CtI
# 0KG5NxohISE
# 9GPrWUvGtoE
# uZts2wmT394
# IyMWH7LoFMc
# HH_OZcmyNRQ
# ZgEP7mIVmbQ
# bBFsHh2PK10
# H2F9oGSnxsg
# rmdxUNB4FgI
# B9DEyawblQ8
# mur6P3kyyFo
# GRWcb41ZTC8
# zmxQeg4Rbx4
# S5rd0MceP0A
# syWmPMrPMDI
# zgEA-qD8lVo
# qyB0Vtgt05M
# 8xUM9LjERO8
# TP9zUkdZgNQ
# MQ2XTE2Oyqg
# kTJbdb-5ej8
# CkJA-rPMup4
# YzVqrcgBjhE
# A54rEIU34YI
# w6Gt-3_TEK4
# cBK80Uzmx7Y
# ZaSMmaCnFpw
# ZkCDVsy4sDk
# RuzHsHQIYlw
# UYt24IT79HI
# JIoJ0MwTPog
# P9xJj7KiAQQ
# FnBc3nugk50
# uwgPfcYfiSc
# UGAw9AhTisE
# ClwjgkhK1yg
# X6lzd1V5q08
# KFjFQFqoC88
# JVZAswVQ41o
# UebzsoAIX9Q
# rpWvj3O-01M
# 5U6cAK9lBO0
# 4X2WQZHPqsc
# wQMcKHOAYQk
# kwB_kuwJdLM
# CBk27qKXcEQ
# ufSmYg7HycY
# b1I2FuoZwvA
# qCnWmz0Cb2g
# Fk4ZGRrz07o
# iIenBzu8-Bk
# OO03qGnCozc
# jhnjLhHd8ak
# h_ZnNDUigFg
# Cdsp3vDapuA
# -wk5h5V4orU
# auLsRn0KDX8
# RiT3tSF3SBY
# Swl5JBGeGtg
# 80jGlFd7y28
# SZBbqHxhaTo
# li4s14JJ84g
# X8uNMu4geTA
# SAPfL-Ss0kA
# V7gJQIWzXzQ
# 44qIcwaa6Vg
# 6zy_ZuqktKg
# o31YAUBiqN0
# 7T8_0KWKVpI
# bUooL3JhKFg
# t8gh08eoDY8
# SeQDIDyAxHc
# 3c5T0Q7eHHg
# G-ui9g82-I0
# kfiCjM8ZF5Y
# G0xkimqgRLE
# k-k17fHZhw0
# eP3qod07v_0
# l794-4bm4w0
# FE9DhDzyTxk
# alXsD72eEuU
# HuZKW4imQTU
# bZPZrLqbU0o
# jRenlzLUQLY
# r1yLQigTvvg
# icoRPDNHbCA
# wcrkbNfmvfE
# jdzREV9t-58
# we96wX2Tlm0
# SI18uD8inLI
# x8staFCa0mY
# HfFCw4eF28M
# 1_aBJ7Lh1Co
# n7-o-BA_2NU
# MmbcCnmyVjI
# m8aeybfblSU
# 6gdMG09l4aY
# Y-CNXOvlVf0
# 9AvpCX5i0j8
# domA3wnbcQc
# FDVEJ5tSJ2Q
# JioXzRNXV6k
# jRi-h4iseLg
# RLEE4zxJ4Oo
# HO0MJxetN-4
# bvtCbp7Bo-0
# FlkeRVyVGv4
# aEwzb3BWvD8
# bygcIdYyqqE
# 4bZsyRWPD_Q
# STDhuDcME9M
# 6kvY2zXBvGc
# -_LKCgoQhpQ
# UT0lmiOBjmE
# Bo9QHtTeoMs
# qyhuKnVzvqY
# CmkOsXDUNrk
# je_TUH3oVnc
# 9OTvrxD1PeY
# 8nYI4Do_Kbs
# NHnOCqDf6Z8
# so24gof2ZPA
# aaUCmMf8oAM
# 6ImvPs4kY38
# iunzKylTE28
# cL88TI31Umo
# rmpazHi33MI
# NuOHmv_LiFc
# QU4Tg5kBmrs
# dAWS28jbKBs
# 1BN3hEGhsk0
# gqHk9WuBGPk
# AXvHNyGELok
# AwWGQX8adIk
# YJDrSRyXfX4
# rCPz-N0ht_s
# FVWQzpyf3qw
# 2nR5PH_3QsM
# nTXx0OLg5C8
# 1TIV7O7BPe4
# hi6nFNkvxhY
# UTYYyD8Caio
# ydXc9EQczWU
# heeTHeJmRmI
# fLJ4DZ1jIZc
# moa4gLa2c9g
# tBgVJikg-K4
# XCprLBu5ytg
# xVy7MlQ0eqA
# -64qs9BEHns
# cWWKNtKh_YY
# JLAfYeqXbAk
# enmKIzu02eM
# rTPbsRK-7Qk
# QkNvy_PsHGI
# wOfOCnopkxU
# MoMRfBheqBM
# CgWLHYi--CI
# XxLM6w7GxWQ
# PkTBqrA6PCc
# yI1jChwqcfU
# Y4Dw6iUKWh0
# gC28B8HEWSI
# 37iKlUuDSu0
# yUhxWO-5EvA
# jiZUUvf3oNc
# WtBltvLVua8
# t1aU98NUBR4
# ejM-FEzvg9w
# WLXrPnoBVnE
# Wt5H38bkQ0A
# LUc5LRIArnw
# oeLB7THRw44
# gvL2fWIFPAE
# -xBm-DEUaRo
# Lt5miwgwTcY
# ad098WzSK5s
# Q1g_UQMIzrA
# XK3VXMwAQT8
# j5e1_d4GVSI
# Jzl1RaeRgFY
# 18GbNoJ6slA
# 3xJBjO7FQE4
# VfVlsoC09Zs
# qvLjMfo6bpU
# ptdrZd58pCg
# kdgDFFLce3c
# AzYNNOZa_8c
# LT4cABTPdxI
# PPMokAwFRao
# 59IzbMeUvtY
# 8q8ZM7hAosQ
# Y-h6AL2_uH0
# XGR8o8r2IFQ
# wWukmjbEuwI
# cM5iGFby6xg
# tcw20ffg02I
# OozOKOCvN0s
# eME8Hcfvotk
# jG0gL0YYIfY
# a1Iw5xmSFoE
# wT8c3cGEUNc
# PQN1xKeUmH4
# ZBrJK9G-FEw
# 7fV9sfH74Bc
# yp-YZXqOTgo
# YwE25R436DI
# IzwlEneS_to
# yo6xRG9NuVs
# aCou0tbP59k
# io32Em77zQk
# _bAilu-cieI
# vw20JYjO4H8
# GtSGylfSb-I
# f_JqG9Vp02o
# XmSA_eCwbD8
# J3rojBHV_3s
# g2Izp-QsC1Q
# KtZUVICCk_E
# fSC850gIRJU
# mdzYZVzTJS8
# hrzCLbx8gjI
# 3iiXTXXJUQI
# rSeC0zciuy8
# VTCDelqNxCo
# UKOVrw7GOVw
# Cnh-aNk4ed8
# ADpbdo751bY
# WJwod1hjdNk
# bLPdN6C9v5k
# 3B8AIlI2MWE
# Z60SqMwnBJc
# wj1IpPTkXSo
# 0kPaUQ1SqeI
# yPENHDYIvKM
# jqfo4Tp8IFA
# tm8J2i6sRjk
# _L6IwdfB63c
# hQnj6FZlZW4
# gaZIqfughEU
# s4OVNbT_D60
# M-R9Tu7mOdI
# U8Xci3exoJk
# r0g56THDCOE
# _0nbB6YYHk0
# SyI-0Vpyq_o
# hZ5RoHNoTyI
# ywKcV9nDBIg
# z1DEdJ0K48M
# E2VLdRT-Uds
# 0Z1Uyu5ZbOY
# 3xmMipSfM9s
# IedsVStS7N8
# 6BKSLnaurVE
# WZhqY4tOtUs
# _dyeSne49E0
# _bEQnRL4kL8
# v_HQUxposO4
# KSLX1FxWNFk
# Yr30XFhvwLA
# LAJFag8rLtA
# D_-ULaR5h_k
# ScGxHy9-nM4
# fkrt240uAFM
# jlsvP4PRZqI
# B2OWnpaUIUE
# ZPdTa88iWt8
# YBrimPqj8kg
# bike6HAPP28
# EJ51spNW24A
# 9XbAmo728Yk
# 7ziM8j21nnU
# WFUo3XTxG0w
# NYEdzCl_jzk
# XLMtOJVQqUQ
# bNh8a6EMHJ0
# Rd7hcPE-ys0
# 0gfDzACgbj4
# StYBHG1weeU
# gxwSZ9VCx4E
# 0ouQpcpKPZc
# m2ttJpjftbY
# qnzIWeW7x6Q
# lMzbSf4oWCM
# TF9fpaBh-1E
# NJu372K6RUU
# uH10Mqd42HQ
# tXOQ-fz1ywA
# 3QvDAR9Z5l0
# ppYIoHHzyB0
# ItrpsYLFdHY
# Px0N3WxZn3A
# wwwjWZlVLzU
# NN2utb-QXZg
# WMP170wfiJw
# CIL_g5OOPeU
# JVXu_cb0_6w
# H5BcTP4OUVk
# YOuQUKFbptw
# BbNABus0qfY
# JJGPjIUes0I
# q814B_St5Os
# -o7RBOkuZpY
# yp_ig_Vg00k
# yLIeRJWVtso
# aAT1BRiTFLg
# OyxXcG9dMX8
# nr6lUM-7MR0
# 0ODXCKtyMCk
# -wWARmk_p-k
# MyzOkjLTb4Q
# c-hs8RAk10o
# uThFbWBdYks
# xj-NH8kM5cQ
# eRZuNFjItaE
# VYreM31EGC0
# 5CYDhPXYT_g
# 8qd47V-ciQo
# QszQxxD8Piw
# 1R1C4iX0010
# AqUTuJF0VqI
# U-_3E5Ymre8
# z6wGSzfnznU
# O_xr4NseL2Q
# bCKZDyqsufY
# JIfTetq0fT4
# awUg2GI3skU
# Iu3MjRcekRA
# t-99DvrMFpE
# POBx7y89zc4
# yYxVMYf04n4
# 9G8ftwqFwes
# SenwO5aTsZ4
# LUUPFu5-Ur0
# zX5ULewm38c
# 151HZav7ODk
# xogVkeyMfVM
# r1ufw0iG3Ns
# PYo2v2WGTjw
# GbCH2AEjVhc
# z7J6HplqrBQ
# QxVoG2lCx5M
# Eux1Xdcvwig
# IzF3EzdcTok
# P9_-x9OwXBY
# yEUYomA3rPY
# ZFOSSZDF4e4
# SpPsiNJEC2A
# x0Mqg15hCUU
# wlVC0R8pc64
# k7NE3hlrG8o
# Zxpc7fz8WVQ
# tT1BKpgK6A4
# S58Z2flRNkw
# G-DWwBQFgSI
# 1UBXFdbDgy8
# Xz1pxDO-qIE
# IM76yBJfb7g
# CKOdzEofppo
# L-4wOWB733w
# XPCOfL1YJPE
# fJy5s66IMKI
# nCudx9z7CIg
# D66uCe8S9zU
# 80zxw9ZtAfI
# 4hK_9xSlK00
# 2bXDUbRxGUw
# _2khPdWX6eI
# AgrJ1_vqIHg
# gY_THHkVW40
# BvJbJvi7Gmo
# 2CWmrpsN41E
# KPE5W8MuRF8
# GkXOtldEFWk
# UGVo48CwetI
# lJTrOxYDj4E
# veHrtVLz0uE
# RbuHUYofCjQ
# tEVmKL_Z25s
# 1Ntv9l4xAWQ
# UbHuyaun3Tc
# k6GhQFaNQuc
# VXBUXsDxMpQ
# _YtI_GuLhdg
# pgHWk1cX0vc
# LY5nXTI3N54
# ySlBwdiyM68
# JCsrFWd6wn0
# L6lE3AkdTaQ
# UgirAoeCgU0
# n7EAQWCBUtU
# gDhsiJxa5w4
# 81DZzgzs2KU
# 7LO6M1UgdGg
# KdbvTuXWiPY
# 6MIHqRgYtWE
# HUfL8h28SvQ
# wNc6T2ZY2qM
# AWC7D2qLm5I
# KoZ-Vn2jKmw
# uxzqFkgkuTA
# VfeB-GcQt70
# OfgOtCdUeX0
# 7FL2cfCSRpQ
# _PkXq8y70yA
# UgjNymiVlLk
# Gzv11LWSaFo
# muBSMdrvjRA
# _RRnenJD8W8
# o_Aj04LiQTQ
# xSwOH8wsf78
# wEcI8bKpkX0
# P0_qlR7fr14
# E6-Z6Xjocrg
# G1NiTlCtxPQ
# aIZSSN2NZ6E
# jf4KTjefzZc
# MGcqnK70iPA
# 5-e6qZPqUtw
# wdeLFQneSNs
# zj5CGCVVkJ8
# 3Em6i804kvY
# osiB4oWMSHM
# W5bZ1bEXuFU
# T7VQ6OwJAyc
# Nka19f_VUts
# TjW6Z7EmxtY
# 1VhH3GNAM1k
# C-NLNLaatEI
# W0RyJ7L_bgw
# FeBPlcQc0EE
# AcA6EeGDpNo
# LPSf0stqkvY
# MFMTfPaHyww
# mui70_KJmho
# NrJD-25sa18
# _96VHrdT1oM
# B9z1q5_Kt_Q
# etBUx4ZAReQ
# 24pcuXiZJ1U
# F_pEIgdiKRk
# 59-116339I8
# Ll4V5pMVOE8
# TJCF42W3-oM
# mk3WarBPHQ4
# JJM3JUeamVg
# 4UTUGFNczk4
# vAFtLikKBY8
# Qtkj9EFcYYk
# 3FjMyfc-gNY
# fqvbeZjRCS8
# itChKmP2zb0
# 8xF0a73Q-Rc
# yLv0Aqi1ef4
# dYXl8pWX69U
# 3D5B6MQ2Nr4
# UeMk__KvSGQ
# cSl4POL0-VU
# smte1VPq7J4
# SKSuFTDn_DQ
# m4ObF9K5TJU
# MBxkXI2NRJk
# z1MDwV32qD0
# oJ5-Aqeottg
# rp3FcVJDaMA
# NsYiIncDvQM
# p5DXou9Exx4
# 15t8j_X-C-0
# lCei05KynXc
# kyS5zOoygUY
# I22O9cNiRIA
# HPweLiMKVwA
# gMnow7b-r34
# tFtwcKxsS4M
# g1sb3UGThyo
# TuHlyjWI7Ws
# OnlP6mEi2Do
# 6KQjmfx7Ipk
# CE9nNQ-EK7w
# M_cCXADIClQ
# yH2yvFceZIA
# UCall9dEsUM
# ppvCzIfvSAU
# p0KcF4aJndE
# E5RV8ZR2RXM
# Qma6j1b3HKo
# RdiL4ekbxOY
# M6xowDMqOGw
# psimLbWf8Yc
# zWNHd5mhjtI
# kAFF1sRLIJA
# 1PyH_4eZoz4
# scZ-goRaYFE
# HrcxooUZqm0
# p-JWFySCzeg
# SwSakR-1SNM
# OV8Au6MPJew
# oUg-TdxP-MI
# 7-MWM_Tnn2Q
# 36FctF5Lf5o
# -LUm213hQCI
# bDC1kaR3Guk
# JV3lSWnxEps
# iNNSQtRI4Ys
# WfIJwXbLMCc
# W-Um-v_34Vs
# JZUqRzRWzFs
# 6kty59qaPYs
# FQleDy2qFh0
# KtoVd4FDirg
# 3CEpZSsSZXw
# PUFsCrX4q6E
# aAtwO0pit3A
# lYyCyJQBGGE
# Nr2F6Tlrxfg
# kxlcW2qRXc4
# qq8YWazlBig
# vuwOyih_5Q0
# WNfTWYvgKWg
# ErN3pWN4yN4
# SNexLVRwEAo
# qqb0JgSuFDA
# p67b3EGLbAM
# sql9XkaaW1E
# OBqvUyKOwq4
# 38WEWEezMU0
# atL3u3mq7Kg
# Zz2EPdtbSr0
# BDAspF5NBNE
# hWzwZPVZfU0
# ZQGEnkfpexU
# RWS0hRN714M
# QQtGhPrxGGE
# LqMb_fluxls
# WXGCgaZjTKM
# nZtmfgQOuTk
# k9aUccXtNPc
# AIKNes235RA
# dyOdQxaTBrw
# KAHlifC6q-Q
# LwDDEIx63cA
# oiX3Hjt8Ekw
# KZaEhGtR8-o
# 4EKwPWJz7pA
# 2Xs8om4xDYA
# JLhaF1QNEnw
# YRzYwyV1EaM
# xqehxMwcAFg
# AuwrD0zjQj4
# GHVjzs-X19M
# PSixaklYywA
# IQtnt4RnxXU
# NHxO2Va95RI
# oyeVw5IpknA
# ldMqUGYFHkg
# 3-eAqbC4QGM
# GWOFF5tMv_A
# ShXswHycXbs
# gxr7lUtlRHM
# 001bZCFyoUw
# VJndvuIvcbQ
# qGAqJCKAy5Q
# XK23IQHJay4
# qFIunKHoEYQ
# q7augf0AMAE
# I0ml8iE0tt4
# nR4bKRcIRXQ
# e5joOUPINiU
# Qt8Ijd68Mfo
# Znf6m1kVlGE
# 5_u35V7jRdc
# 5dBI0LLMzQk
# ifbE_xAlJUc
# na9xE6s0b60
# DRsTqtxHysk
# UCJk14oMfXI
# Pa8k3miH-5U
# G8V0yjTxZ-g
# cA4Q8icc1Yk
# QfDYz_c6cao
# ISTyD_TmX2A
# GQzGddSSo1I
# lw5MkyXPPnI
# 8vAa4GdUACQ
# t47rPl3EIU0
# pek08EhZTIc
# AM7NwZWmssY
# d79aX_xxaTM
# YKq2ajPA-ms
# nnULRhMZhn0
# XGGtpA0SW1k
# pIC-ahUfEo0
# JanDJpiSvL0
# i4Ui9TFw4WY
# OxvHLi_cvAQ
# crXh39yPIvY
# 4KeMLsYLAyA
# PkLxOeNUIQo
# 1hvU6jIuAB8
# p1t_14tKZ2c
# qO_h5qpS-9g
# ulnjcVZZWno
# b08guVrXAm0
# O5rdhcwhQAE
# CubLUR6OwUg
# uBXDNx4TPSQ
# eLtqJm6VAvg
# SBV4_tPJ8zg
# bgzBOPuDEVk
# h72NHbcpS_8
# vjZ_sfNOU7o
# zAVGR6gLBDE
# qVgey1e-HbU
# ZBYrBA90atM
# Uw63CkFU-po
# gUKBFznvGe8
# 1aJ6xXuH5k4
# FY1ZVo73Jfw
# xgsX0CDnLHc
# xRdd2yr2Vuw
# pbfUjpGNHWY
# 4NQ_T1lFofI
# Kps2ZnHLXYc
# -fNp0OvCckE
# -y4WLGyRyOQ
# 9GksCPkzk9E
# Nzu8ED3dR24
# ugmUMmaTul4
# HFeqe41sILU
# cneYNtd00mM
# qG-8QA_KJVI
# hGOea_saUTg
# gHehSgF0S6I
# RFG_XSqzkBc
# MyGbfe3P5j0
# WaqbhvLZtH4
# fhViWB-EfwY
# bzlpBj5UzMA
# rfDuZyNCSx0
# BCoSnksLMfw
# BGRGEa6KDJA
# 1X79viZeXzE
# j-ESFjGxivw
# MsGMnqeYJRw
# t0HXDuG2bro
# L7OiS-k6NFc
# TO4ycvBHNqM
# Z-HM2Ew_I74
# _6v9aunoSQk
# RxTuVwloo_8
# RsCnKV_au5A
# hGIWH3g4NHo
# Hjlece9rovo
# 4oczbdAaQdI
# O-JgvMocRvs
# wACq5cTi7v4
# 1ge1tgBZN_w
# WT9U18LszdE
# 7t_FAt85Gto
# hlSw355TOmk
# UFOQmPHVdFY
# eRannHDo_LU
# esZgaDZelJg
# PDVmRPfC0bQ
# DqzA2WFcw7s
# L2EbD8MCbAc
# v9Z_QR-XREg
# PwtDHFCPnt4
# oIcQlr9sQqU
# UsT3gqunXWU
# TGBj6Ri6jcE
# JMO5nquRJv8
# Nv3qI2S4isw
# _KjyOnoWtpA
# vF9Sqsbi7aY
# 30jFr78QZKY
# fDS3uxH8d5A
# s_xs_oPfZ98
# ZgX3O2xM5dA
# wPUcxeAtZsk
# nZ-NjNZpKnE
# mUBZl8Hg3Kw
# b-KZO-JIx2g
# LgpKv2ehKI8
# _V7bu0oXJE4
# GgwWGq3Rme8
# WKVx0e6hhDU
# r5b325Y2K4Q
# MH85B8GFwPY
# zk0ir6bZ2DY
# RZ5PG9-CEY0
# CyUcKc6ZDRM
# D_KkMRpZxiw
# inAl_Wa4cds
# 8GNrf17SkVo
# fw2n1WxBiYU
# HDh3qINW1hk
# 2B4Zsq4hf-c
# xMvg_WBN9G4
# 5qKNKnZGUCA
# oSszi1gVK1Q
# VkjMthOEoLg
# T3wCN3qviM8
# w5Ba-0yvIz0
# sb4rIZB4Vt0
# MLnJW7-yxrA
# qNMj3_DdQKI
# 1BBPhKKzDjc
# exIJVSKz7Vo
# o0EeH3DKlCA
# 1L-RFOO5-QQ
# MV7J5OrpLg0
# 8T9NwWOmHgQ
# x6PPeLnPRTY
# WPDvu9vYX98
# LVc5-NDM8pk
# zGfTID9-ZLY
# YNARQGbWQxE
# uyFBJPQocPs
# g-Kd95CWGDM
# TbzA_REDtMQ
# mDRpN4ywXzw
# oOqkAIOnOHU
# gyBQ1lsseds
# qvitrN2cEik
# UCjvWq0pCrY
# dRVy1vG3Kos
# ytrbBBpM0pU
# Pc5ZfcNLehs
# uooOTRzA0k0
# 0H1E1vkw3ik
# pC1tThK9hek
# IFym45dgP_g
# 9B7qeApWtGE
# vs9KqFqUtLs
# 8T1mKEirzNs
# -1gfOcdkjQU
# GG68CJEndpM
# QTZXZXbDHBQ
# hx3thRb3Eko
# 7hG-gy04GNo
# f0dfVveiDD4
# sW9feENESOE
# UvzRIj3A8Z8
# 5Kal8Z5-ZGQ
# Lb7f6Or2iBU
# xJfjOAc1R0I
# ZxSDUXViTHo
# 6RgYaPFkBdE
# KgWOd0jBxDw
# B-zygAV5AAU
# kHb9-O0Rmwk
# 3XW0cmCo6RI
# tzg6pQoaxq4
# OorAXYg5ucY
# 4E_iu5i6v3g
# hVyvWQlm2hg
# -FanvfvN1g8
# jzOd2QW2Dik
# jzYjq-Uhtzs
# GKs28fD0N8s
# QHySbLw5_4I
# nzLRzsiKTA4
# FkM-7jHKa98
# PK23Nvl0DRI
# 1Kd55aRVEcI
# FegZdNkhBr8
# FUXjKgccJzU
# fpR56_364zI
# oUPWEx9iN78
# StpCebRyefU
# now0TSUi90Q
# GmXw6o24P78
# M70NMEWN-GM
# Iy0z7Jv85fc
# hr3ldOx9-aQ
# s6lgGWcoWLk
# a_tU6ecW6TA
# 3PF8jjmkP1Y
# U34yk9uzki0
# IB-gD15u_yM
# pPDtjFnthKA
# Oxd6MW-jFaE
# J4yclxGr998
# SEfzLYYKRmo
# ct9xeYKfaPA
# KxzwYd93fT0
# SDRDe1EMong
# cWNHB_AUbZY
# RNcb9RmHjPE
# Lx2q7whZVjA
# 3yf1A5PI0Iw
# zE9nGJlRHP4
# MQ5kJISWhWg
# lUMI-sA7654
# 0d-17afSJUI
# O59CwHwp6k4
# w7ra0eZD72Y
# Fqx-JBBJO90
# Wp-X5eg4ywk
# Y8MCmtxYhjM
# pF8LxH_1N7s
# LgqEhBu4tP4
# l5GjFGowaRY
# HJ8eN7NvoRY
# KsVyVIugrCI
# ZHZE7jssKU8
# wHzSXKnseKM
# 59cDVtf-I3o
# RXx7BfoYjd0
# azLP9Xg37LU
# Tp9mJ3OlsDU
# UGdsMev3Vro
# cD9Ilvl8PIE
# 2frrpsG9Rls
# x0aY2a5HNb8
# BXVeqUH7kyc
# ifX8zauiWLY
# KD8e2286CW4
# DU1f6D7D3po
# xxL7v_PC3vU
# xnQyvUdl5PU
# nyV51j06Bis
# 5yC0twey3cQ
# 2NoixLFLTg0
# ARorXiLttZc
# qy2qlUaBA_U
# CkyRkI_JNwI
# IdkYjECqLXM
# dBlzF4QpjUc
# 98MA1j3CWR8
# psYSUjok5r4
# 5YNQ1lxMoa0
# oIXPx51Qq1k
# N3n6RyZW4v0
# UkTQr8fyWFU
# aC7PXRiN4-I
# E76VibL6qzI
# fzxtZEqgf4g
# AXQuP3VAdSU
# nwfInS-HfJc
# BTt_ZvDNFsg
# EMEEdOAG6Kg
# c5wZwk4msAo
# Fakfzpgcxbo
# CzvL6JqIv6M
# qkOhmk0Jp_A
# cbygPmvNkP0
# 5OcxHkaJjw0
# N4ZWqeXuPG4
# Xc3LENxxD2Y
# v8Z5N5UpFfk
# klDxhjrbO8w
# XyKTMOyWHjo
# Ymk7ppILwS4
# jt2oi2sz1-Y
# KfsgPzEDtiw
# kJX2Ph9y20k
# qoB0BjzOTUw
# iKBXqfxh4qk
# w3ck1OoA9tA
# 9v8CLrPRKFA
# NJ3Ws9BQ-tI
# w6NSxA5ZWpw
# RWcFmtvhjW8
# At31UkWxdsQ
# kA3AsXLn-aI
# cG6fUXKZsKo
# -UnSdAXWwY4
# gRR_YRbXVr0
# P6gJczr980s
# lCIXbhFW5SU
# ytFKorKcr4I
# _5C6OuIhI2Y
# _mLIw86yqPM
# epHrd39z3t4
# 347EqcC_ciI
# VOO0uUsqfE8
# AxPVUJxwcM8
# IFqMcoj42VU
# PPnZ22WrH88
# EfVID0ebKJc
# 7AtHw0F-XNo
# kVp2XN4mI84
# K1K0RWgM8L0
# WLwLjf9dsgk
# FsgcLKQBcIY
# iP_xi3nhScM
# 6celcTghn-I
# xY-u1PPE-io
# vdz_9qW4z_A
# uqIXNL9NikE
# y96sWYKl_y0
# YZH1myCaeVo
# HL7mC2WryLA
# 7RsbkTnbrZM
# MAUWVD0Oa6c
# Bnm4zm4PGrM
# IS8gnL_PkU8
# abVRjzaVo4U
# -Ndk8lbFn4g
# p10rZAKB0-M
# UpJ-iU9vwqo
# viSDpK7-52g
# gKwlp_nAlyA
# -W8JEuPtPR0
# 4nvwjd9Jy-g
# k5JAUmm53uU
# SiGB9MbcMok
# FRgo9RyMEcY
# FSLsEjfiXQ4
# 28ecrJ3rzwY
# 0nRZRTbHQXA
# 6hDhfQe5skg
# Q3bTcO__qPw
# pf54EflZxN4
# KJrSFzRcbtU
# rCNOnhvGvQQ
# fT5MI2zvpYY
# 7ch83blSdE4
# RwbGuHpggCE
# tsLVYv84XJc
# T_sgSX-EjPQ
# lO4_QNXTFJg
# 2tLZEvLj02g
# RjN8zT9D46U
# cZ-Ew21nsvI
# YGKJxm_u_Yg
# FRiPpCPoNs0
# ND4Xgydof7I
# Wzb8DQtUUDU
# 2o8BDSPZ6WM
# ij2dL9R3r60
# 1kCVt7bZXIU
# 5GGI4YaFHl4
# jg_2x_Loc2U
# N7oD7qh5Gt0
# jjGVv5vrRpY
# 3sNqzIMF_lw
# I7c8RdIMLWE
# vCTeclcsgVs
# YgdOLQyq6HE
# Zys39GL42-E
# DK73wQEghZc
# ZonACAW3aws
# OXQKRi6_Fk0
# aBX5G6v3DAg
# l-mcI9XIkQs
# Y5z2JQeYPz0
# F-rmTlxdVKQ
# PuIcKGgvdU0
# jWgYhZlWs0U
# 08lYdKNRxyU
# vbz0Q-meed8
# Ra6hbKkA4CU
# _aWM4LXIY7s
# k5mZJvayfVs
# rGbsK0NSM6g
# BuApn8ZN-kE
# Uq-Y7n8EM9Y
# ZUEhpZnGCNA
# wzZZ7pEJMJ8
# 4qB_haktUb0
# dz10Xi3dFEY
# 5rKaYcsITBQ
# 7cZBPJj3ivs
# HU2odSwriY0
# aX_JgOhWqHQ
# l8q3CvKt8os
# 657CTzZpp0o
# 3JsPBEXAeO4
# aT7sRxAA1tw
# bFLOeH7rkxw
# hOIrvBKlUKc
# 9ThPR2d27PY
# WuQVwnwih9w
# i2X4E3tl_kU
# cbFmvgWvIhg
# ouehRn4oz60
# CKrd34nIkbQ
# lmc3lJmqAXk
# _FSvyTVytT4
# 685q94f61iA
# qDbg8ccPSrY
# dBpJgIXss2k
# x_sNLoQezxw
# 70sCVCHNGIM
# TI6HV0XmbBA
# kLmGmB-xLio
# gaa0pSlaF_I
# UWhW-2A3EK4
# won51T1wS34
# MPAZ3siVTzI
# SbpM-oTUQCY
# X1q3ru-ej6I
# uWBXdplpqOw
# YksNHSYKxYQ
# P3OlqDXODO0
# nOw1uUoMviQ
# wSNsAkIQe1E
# VM2BDBz5Vss
# bTBmI49ZHSY
# 4seV3pMINwE
# gsDX_SW4XBs
# wv0i-Ud2sYk
# MweaZW8CRfs
# oKNBvUSpmgs
# lMkSF6fzgeI
# 4VxQfSpg8Uc
# 0u_22xgfnRU
# o_tX8uw8IrE
# MTHY8gX3EZs
# zn0jmURafvQ
# owgBWNTBjoI
# aimUpaNieK4
# He2jbyjeUuk
# bLE9awPsFbA
# 0T20jkTYm1k
# mr8c7_oRf0A
# 5h738CZAjm8
# KqpoFjoUpdA
# ZvTYDmHXV7A
# MndJXhLLpgk
# 0pHn0TcUSNc
# a82aH5ZKYBU
# 4j-FXCJTCXs
# EY4CIY9bCRs
# wK3sSSMoguU
# hJTpnMifCe4
# DRu9bzCAX_Q
# Da6Sq9h6_JM
# FL-gVf_osy4
# oKwysvAfaO0
# FArPausB02U
# Tv0Oxd7rZ10
# 4xmApwb622I
# IAGK58643Vw
# IpAYumhCtkw
# h7-GOZDx-iQ
# Ttadpjp6Ufs
# h73a-dvu6Ig
# MO6Gyhvj0kU
# utanlrzR1Ng
# VPrFX43DxBw
# CH_y-VDH_Z8
# bHeUW4z8KAo
# GpOQnzIYcmY
# esnd2KVjXPs
# iM3ssaSktbk
# VqKUmbacOGM
# h1lpVIDiFs0
# D_hpdO6X7Ks
# vfQd0xG4rlc
# GP6r2WOkU2s
# qcN_c5rPsc0
# AX6FW0chhnY
# TM9TNONoxiQ
# hZ-aTDhRM-Y
# AeNjF4w22mc
# EiP3NQsOfGE
# QGM134U35Dw
# Uy2rSAssKpU
# 9W5E1VCzCEc
# tepp2G2u7y0
# Qcju6QNOCDQ
# PIQ09WwKk3M
# g8mdIXhWH0s
# IZVxVf9H9ag
# VSd7wJtdHoE
# tPufy6AcAlQ
# 5LrHMeT9oto
# wagON4Gvh-c
# _c9S2SVuOTA
# NxATocnQDEI
# Lp9N8TfPF0k
# 49jo3WSTSM0
# hB2JDYWUQto
# U8_Zabxa6tM
# KLOb1R_4BBI
# Gao5v2fE6zs
# jJc6PF8SwNw
# HCSPaRBAFfY
# 3fVCWKJXo5o
# s6U_T8fO-RU
# K096r-6pUgQ
# 3Se55NBBfBg
# HNzks1qZ83A
# -bCxl1oRWKg
# y0C7rEpGcoQ
# qJJHNatmrPs
# x9N3ZH2YSSM
# sKF5sEqzPjg
# vm1m5JP1Uuk
# kYV2fshuksY
# 0UJhEpX2Vhc
# QL__QdI7hCg
# _PKeYzJE-8w
# dNSWVibmwrM
# ho24yTXlRB0
# jlUtNJXhyAs
# YzXQP6sQ6v8
# oOeQ6E8gxJM
# U1tZvQl3MUQ
# 8nDpFYeZEO0
# gjYa8cCQCFs
# PeQjwBiTukI
# 6NoQrUP3EVY
# 95tSAuR_mIU
# GLT-81aZSlc
# TmxG7R6_oGo
# uX4r0Xa3zmA
# Fqyul1UPDzc
# 9wu3gyQ5iKc
# LqpXU9eiNFE
# lbjWdF6vElo
# HsVabyKEyhg
# TgpKMEcKuk4
# IcVUs90Ee0w
# IVjl4r9ZCHI
# 00BWaji2tW8
# cr6pP94wqB0
# o71hTmuezm4
# ITC5Bcj_reg
# Oa7SXDEcGkQ
# vYmpJEQynEE
# 66sAqxLAr44
# 8ybs0GyTuFI
# WU_ZYzzwhH0
# NZaYB29bjZk
# yKJwYbB_OYU
# safQr3sV-rE
# ZvPsBLp28yo
# _qHWQDvqSE0
# uD3RFznjEnQ
# mqHXFP90ssE
# IeKcjavaC7k
# ZyfrNm7lW64
# DdyQwJ80UbM
# U6h2aol191o
# W5b8R4r7rU8
# DkQXa-EKz1M
# JpVcQ2blnKM
# rJdKOvxHwZo
# WPqAaB8DbnY
# mWtu-9vJaXs
# W048Pr_TFRA
# tWoQFFIMRNU
# HC_QCY24LJk
# Vw_eK01EkS8
# qhlb1hgrWws
# Onp00jfJUbY
# M32ke3JgTw0
# 47eLk1d5t6A
# _Ti_zR6M0Aw
# HReF2Hur39g
# Jw0gbbsW2SE
# JUPFQl2mzgI
# KmXl7ReFNb4
# AX2XMUlVUAw
# SwVc5HJDXoA
# XA534EUz0sk
# UhmAKZpYBqI
# q4QmG1CXRXs
# DfAKxP8K8Jo
# DP1APoZW23U
# 5sylNfmVF_0
# AitfDr3AUNA
# P9w8usDXaA0
# HwigyT9IYLA
# Hy8Q7hd10Xw
# _kzGdqomvec
# 2QUvHI9l2rc
# g51cIqAlzyg
# AZoYBaM021Y
# I74KhbQPQjk
# mvuA_8rRB0k
# KcKmLL3xSPk
# yOa8saI88ik
# iLIXBkzNwU0
# uQ3JlsWWs0w
# gMMhIo-uIMI
# wEYiGMM9QSg
# 60cuDzcWqTA
# wNG0ucj87LQ
# Jlo1WooLvu8
# bsRDtP6ta38
# 9pJU-H2O-Ik
# cJKMLhylEuE
# oXNYYaBm82U
# 1K1u6d3aYTw
# dRW7VhST7OE
# 846U97ZOAJ0
# JgbP5vH3Uls
# 9YFtISOCELU
# 4RpRSXSC3bA
# pmwSsRZgEGQ
# PNJgCqCxEKw
# GApnkmOkBLI
# 0d4rGkNhYO8
# lMkhOBHDm5g
# qkzVQ9e8m3g
# kRQBiq5l3WE
# qW0UDomvLq8
# sG_2ayK79B4
# EPlG6UQUT4E
# G34W6xi50IQ
# 7ZXV7tS7jO4
# Jz3rhbS5Jp0
# qx-LwsSuH8k
# JoN37lmc_SA
# GC24ep_sgJQ
# H2EaqTk4wbI
# bN03pwSC5W8
# abp2IzWY1lI
# T3K6qacyM9I
# OJ7vPqaRrnU
# -wTVDeBOnU4
# VXyl1TeGZOI
# S1zlVjuL9vE
# wn_RHKBqAcs
# d72gIFjmUEE
# p5nMWRgUcio
# 16OXiK0-GP8
# -SxGLKuhgUA
# OG1VJdjWIg4
# lkRva8muMAc
# A3VqZ1V7j5Y
# U0ewMr-d-Zg
# _d77_s4EcNc
# lY-c_T9ZCHk
# WdNDtkd3xNs
# d70TikRVxbw
# ZtOI1MZNIdI
# ceq3Tw0krA8
# UfH0h869vqM
# pvZCBiwEIr0
# 8vkZRtKAmD8
# -bhFf2txEcY
# nNsWq4FEAvU
# 0XEavg-W3lM
# MI5uZR3Vixk
# yoQs_sAqmW8
# ujPUO9sLijo
# siIAkA67fC0
# 6ipMp8WxNnU
# jrQySaDmuQc
# 7UF8Zl0BFKE
# _1J5SLVExrA
# F4ob5EG8ixw
# qilEFziSe3Q
# Yi4-8lt1Bvw
# g3XOp5xhbXo
# 7zOS9sANITY
# vN1jRuLwFLc
# OMsBe8Tt7D0
# akt6as0dYAQ
# NgFxd0IOR28
# FxKo3t1D7a4
# EuGuxZ7zij0
# K3nf115_0gA
# SYeW3c8yUfU
# w9FWGKeyubk
# Y0aY88t18SU
# rh9Vizi9r_o
# KbeG5x2AhUI
# Jr97ZWgEZV8
# ulfY-wdWjkU
# 7ooOcXYHRq8
# tBXkOQ10Qq8
# r-iesGeo5IU
# v7pusxn_mcU
# tXMqsWAwKww
# qmIlC2ndgjM
# ePDGHlJYht4
# Q4VSIQ3ObFw
# MuIoqsqG84g
# fpZYyAqQSrY
# cChgbcv7HN4
# MjM6VmskWGw
# h_bGDD-s6ys
# dEGlVa9ThvU
# jndiEYCpuS4
# eOaU80s-gR8
# LL0JT_6xoJc
# v3Kfl63HRzw
# MFR9xsjVsZY
# 6MCTLpazzjI
# jIrG8MFwGsg
# _MwaEBX19sw
# qVset7msGaU
# Zz_jfbQkMTQ
# seTATdw-qdI
# tiZrQgKptyg
# BxbnjFDkEYw
# bU4kVzGyzLQ
# wKPqbdC2uls
# LUViWPhalfE
# h3NPXlZUbJ4
# IsBnSSyT_jE
# -wrBNJ3nm1c
# hca6C5JuPQ4
# auCULXWOeao
# 7tcFSdOna0A
# 6bdsvjSsHm8
# XT23a91pBo0
# Ji4EhAVZQGA
# mdKbHm3-F-E
# BrI7xJJZSog
# hFAj1wqy62U
# gS8XmWBcJgA
# RbCjigXrqrE
# _Uv7fTS71ZA
# wH7D2z-6H0k
# AEEyJaB97GU
# 4PHHh2I3adE
# SgOwbhz6GGY
# h2wIjL9UUdU
# -hQebZNLJiE
# GB2mBkHdkXA
# p6RQofzSgc4
# 9PUxwOaFGbU
# t6wBJkL5MBw
# PJkxcSZRH28
# k9wiEA03HKo
# GEvyCVeE7Fk
# osSnONXFi4U
# 1FwmYh-FoM0
# u0JGDY2YC-k
# y5fGvAal6wk
# TCKMvHPr3Ew
# OQAuBNLadws
# cllorceYICY
# A3AthwH2bfI
# 6Xag3Z5usPM
# mO1V_OFOjTE
# 76IwpdJNJBc
# k_wpZo6PmPY
# N-mI3Yn-BM0
# Nh3GLUZpR2s
# nMk2E1aoy9Y
# sYnDfoSMlS8
# VBB9jrq_bhs
# UWeta-4iQm0
# V9sd4YCUsL8
# cBF1rDFlnKE
# 0pjqEI0uLGY
# Te0dmkMmyE4
# 6aqv0I37s5g
# LAnsnzsKG7w
# gS-a6_ceIWY
# izzs6l0qpxI
# zc9_mGhCNoA
# cxWma6niubQ
# W7vj1yhZTEg
# DzkLJRNSnG4
# wPCFLNmW5dg
# i_Rt3LkGRBw
# JJPvKNz1DxA
# 8DrB3LnBCO4
# qlseQShxbso
# SPB2FR52-gY
# -hpoo0uonRA
# AMIG-kycW_k
# 182wSRAqgbc
# rbQKrdV5dro
# p1PYierF_N4
# k9DJAZICG3Q
# krsaZHIEmU8
# vifSWEOqwuU
# qRudqqBA_5c
# K6kUSl3zh-c
# 0zdovDHoaOw
# 8DgDKePn7Bo
# FNL0qzJkB0Y
# gFOlneD7OTg
# SlOo8oZ3URo
# axNTYcYRY2Y
# HohTV1hv2CM
# h-8ADSD8yvk
# akLi3t877GY
# 2hz1M1xG0kQ
# 5a1rrEYTZcI
# Kj_WV21T6Cg
# 2dCdnj6TX40
# esWbHMDSceE
# jwC9z647qZM
# CMnyXVPm0P4
# 7TgCA1JzfHo
# QqOhYjGSfzo
# Ry5a3Xgczyo
# xx329zblJ8o
# nCl3XUK2aMk
# 3oNnHGpkLx4
# 8Wm5tZYHL2g
# RdSkqs5n_kQ
# hrwdHUyvkjw
# h6xVux4plV0
# VWBawpGeCLQ
# s2IyE0AoBRY
# WWDRsvgPRYE
# wBybvvXgESI
# V5hPE2SOj6o
# 37ySuT43T-c
# 0ACK4BIKd8Q
# w_o5urFbwB8
# BGG6MSq4MlY
# M3wxYjop_Ew
# xee7uZ7IDik
# zY2lSR5of8I
# s5yWqonxxPI
# XHwe9fEkCgU
# 3GLGcw9wyPU
# G-UCinmbkVE
# v_XwMClcMr4
# kL-S_6mfqR8
# aLxdMS5OJ4k
# GkoO6kpG5k8
# osk1bS-Q4p4
# Bp9ZYD8URF4
# Ez6OSdilGZ0
# cel9XLaF_DI
# ASD-FTRc36w
# q1nM7oFJcTM
# a5S1gQNkhFc
# Eskxli32JXo
# ULNta1ORkUM
# 0uRFSRti4L4
# 2GJmcr8hlPE
# DRcx3EPckVc
# HqUM7OWNGiU
# GTY9X15-8MU
# uaTT7JvbRk8
# 7-TWbID7z70
# PaAuqoM11z4
# WUJ5sm3yEt0
# Gs9oJczh9Uk
# ioNu_4FAc8o
# HCV7PM5T7LY
# 33BSzd8Weag
# 5bKlTlxjm-s
# rIG5rLqaTa8
# OyCj8h0nOyk
# 1TfRWgJnSUY
# S_t1dh_hCz4
# ty8u6WHK7U4
# dtoCoz3A9RA
# efT9fjk-psg
# TyCfCnrc2vM
# bMwJkWuoBeY
# CyBHQbSp3qo
# Eu9qipblFTQ
# -sZlEQLN96U
# nILbFBRSaTY
# yQulO5J0buc
# qHNMRxITikg
# oqNokwVxxCM
# 3nCkEO26GoE
# _YQU_tUz7pM
# uUDDYbF5s7A
# T5XrvtooEeM
# vKcmq2spE0Q
# OxzzYeyEiMo
# SBlLUzKgRpE
# 5Ox5ERQRU40
# xJ68alrgDjU
# nF1cQO4Vi28
# 4e6B92UAK7k
# REQelEdHlus
# xWbAvZZqxFY
# K4AbkNml6tw
# KZZIFHDbLwo
# dPCZRvBI3XE
# THQcPLztFVA
# vU-ShrWXLKA
# 7X88sO7I0Sw
# Myb1mBboixw
# S4SgSsR_JMo
# wBbUnaoUSsE
# 8RZtv20pExk
# 6EbyA7WY_X0
# 1AC6NTmFkDY
# geyAR667c2A
# OGA-OTC6k2c
# 5cpBYn7Fu2Q
# 58cRL2C3Q1w
# mzVOqEWd8ts
# kD-Wi5yj_kM
# BDCCaLtmUZI
# oqPs500w0x4
# gzvRKTBpK9o
# JiZ0m8mb0rs
# YsDJAJ4hzqU
# 0K9hKOBV-Ag
# 8h8fql1_g4o
# D2nXVa82Opc
# vajBDQU_0ao
# _yThYx_oG8g
# bVyp8dHEM8I
# CdAH14nwaZ4
# 9uSDVY_uZp0
# dfyROUdgXCg
# jlGDuVr1IJs
# 5qy7vGJw_2w
# J2wJWG1Ihdw
# IJJBPQoIxw4
# F8xvs52wWTY
# 1zgD3flNJrk
# fsMBHgjFAlg
# xxMzm95ahfA
# XF4MmoP4qOE
# zVOX44eNDK8
# yxt0k_9MSI4
# dKb5EPKa1gM
# nSdBwpubr28
# 7pSxI6As7jE
# h4xB_bIjoCE
# plzlIrdG-rk
# GAT_jt0pTk0
# KZx5p9Y9-fM
# _L9c-xiBVU8
# 89FeAkdCL-U
# 9LVAwe4Kq6M
# xvDkSo-vu3w
# Ze6czo_P7qg
# M3lH3Z3FKbM
# O7APD4fnJ-A
# DKaXGUSgNL4
# lAv9Kmttk1Y
# 4umLBidNLvM
# -F8cl7jlAtQ
# cog782YWZaI
# yH3z4Qx9n_o
# waj59B9NABU
# P660XGdQHCc
# LxJPOeT2bIo
# Vsgvbw05QOE
# 5I4kE-ofAbs
# iOs2m3f-g7I
# ZTZoMRWhTOk
# gStIENaGt3c
# YAf0sM9is_w
# YHvfrDhWIq0
# L6647BJMfPE
# N8l5ZofsviY
# xmNLjUhqjJA
# 70R0WlNkGLY
# jtv8zNCwEIk
# oVBYjdlCnmM
# H_7jbEljwss
# _6NtaIYoLHY
# GXbm8DkvNuI
# VFA2iwcU3PE
# VPeRceZ6hSA
# fOrTxaMsZ3I
# xCpv5fD9KPI
# P2PCMwgujNg
# pM49cXTZFsk
# q451Iqu-gew
# BeSmNT0MikM
# z0UhsTEPK_s
# JX-pug0p_Lw
# _EYt4X-RMXM
# qxlCAdTl3o0
# P_YdI-AGLL0
# 4Hth52kKdII
# LPGJl8k9WF0
# 9Jp7TxDjbL8
# 7tu5fB3X-WQ
# 7nMNuNpym7g
# ASuO4QB38VE
# yN2JCFdXpT4
# BuyXWhWoDg4
# zXO0ciiRlw4
# Rin4aOYCQ8I
# KTa-4F7Q9ig
# ZSausEfok3E
# NE1oGBrzUTw
# HtRnUOC-VPo
# blax31jp7mU
# GowtwK5ttyg
# pUDKkuaqXe0
# umZwzOvNxzo
# Ro3MBuFlre4
# kyKUy6qoK44
# Qf2Ujsv5d78
# g8LqKwgUcb0
# UhG8MRcZCGo
# lUSOO5Vog2M
# rL4IabCb-b4
# SNss9Zk1nTE
# xsnDw3oeH5o
# d_h6J9_QCbM
# uNkumQ0v-H8
# SdJrCB92p7U
# KKb4jzDlsw4
# bIsjQI-BRak
# 1XhT5bxzwFs
# 08pszQi2Ch8
# 1aqu3NlR0SU
# AkJZ16OuwLg
# 4THav6m345k
# keCylioh3eo
# WGHMeMLeOVw
# BDq29_hMvlk
# KWvZWHY2yYs
# wrAesS8c9rk
# 6IMZ-_45TBI
# eQBeoGK0Kgg
# 0wROK-7Oz_g
# j3r4i4pn5OY
# B1AjhlhR8_k
# ovLyDbhW5wU
# SvU3Ynmcrvg
# 5ICkMYqb9R4
# QCU1pia10WQ
# rvGrUkK5gXw
# vEsbKUxYxj8
# CCAKZkAz-28
# hX7OLiZVC6k
# 3FStu3IF4vU
# tSdgutzVjRY
# 8r1AEjpD2Jg
# uB41u8chlvk
# LmMaB1urlLI
# 3OdMNeljUeY
# Cql6xL1U8vk
# YFIB9odsB1I
# 2R0zobExFjE
# LFNdurs06GQ
# cBI055j5a-E
# lbS4BrMEJOU
# Ma8zmrkGJN8
# sjtEYHnqP_A
# SuqjflJKxgk
# Am4bGwZkzUQ
# WUbFApNoWcc
# 7cH4xK6Xl2s
# Kl2O-C1sXY0
# Q_4E8PU-xsY
# iVbHjaKNmNU
# 0Z8P1xfM14Y
# Sl7Wxq_AOmo
# iEeqzNQjkEo
# xolWfyAsy4M
# wSzJzA-bhh8
# QWpYj-xI-hE
# Jc-i7x13zUo
# yw4zErr8tQY
# k7koNG2f7DI
# uGOMj8s5GOA
# N0v4NhV6bwE
# Zo9ce43El3Y
# DphPRo087NM
# apQC3R1O8Ok
# Gj4iFWcLcA0
# XICImoDCXhE
# qoGGAsy0yL4
# 9IZ766ogMfQ
# wEGKDAo469U
# ES9gUrse5NI
# WwdeHaIG608
# BTat7sWpxcg
# Fqr_ai4pXYg
# PBo_dN_KRDo
# aY0Y0fSEcWQ
# e_GDmUhb9NU
# cz0p41YYSw8
# KFInlNoabS0
# xAyu2gbh8Iw
# DZ9NbLzkyz4
# uhweVy6FAQU
# YsmxT5o-9i8
# a6cyk5FvP6U
# C_6Waf1LVXA
# 2LylRFxMBB4
# HLGjQ6BRbJk
# HQHKzrxEp9I
# Dc0P8AdmBko
# iFD240Up2p8
# M9n4kzJwpr4
# O7NdbFnxAfY
# BCQ_L2BLBZs
# M3i7vtZhb38
# LODLkrw_zR4
# cR-aGYFSM4g
# a01UFb-Cls0
# Uc5B1k-kPjU
# 5Xr9fyhIfCM
# ZmJc_rwQSu4
# 6OoUD7lbGDA
# 4M0K2FOH_DI
# JfVbkz3DHIc
# ck9y2eZxHCo
# SxOGjEeB4yw
# wXb9N4lQ0Ic
# 4NX-AG9Ss0E
# JuNqtmdSHAM
# rXC-pMCulzg
# 52g3PBacZVk
# 00vscq_n5J8
# 2cGZdfpxvdU
# QmBUW2YNAnk
# 5_06GW8ZcFM
# 95W1rCrXB0Q
# haQ-RebcnIw
# TQv09m9fJXY
# 8F5AlvcYBY8
# 3pndACAToh8
# PMEelyMgoJE
# sY5bO2kDI-M
# EEo0q9z9Sdk
# HwHgkLnHMPg
# 9fR3dCqgEhg
# kqtjnHfU1qc
# jf2Z1ZJM1R8
# 8lZ1tnEv00w
# H6OzLPfKShE
# Zi9u6rlWtpk
# xIYNCCLd1bA
# 5f64Ui8jes8
# u4yEFD4JFMI
# ZJiFG2hoUGs
# 4TgwnZLW3nI
# yHdZkXHNiqg
# 6m8NSEgQqcw
# 6zGdXmBklBs
# ng8ZgZ7ADxA
# pSUUnmQHA8Q
# Yt9WgdBS16M
# 4bW6Itl8AGc
# fj_txM9ywFU
# J428R3ZF5bA
# vwX86jQ2lDk
# 0ZivqkRXapo
# sNZsfWjedCQ
# nLuExoAC0hQ
# N2ZG5baRCZA
# iuZIUsNrdfQ
# E96j9tPofGU
# COg6npzOhEA
# lz_52SOlm-A
# aPXDra11XIw
# mzNTiuMzAQE
# uUX0UCXr9uA
# qIDrq6iM3Ck
# gw5jXzw7xK4
# 3CS7dAnwpoQ
# 7qO8Y9m3O50
# h-EQNyN1c2A
# YzqaEgOgXw4
# es4SCX2bgNw
# Pq3H484BrKI
# M-enbyKnGoY
# kC4VUKlfAqE
# 7gRxQ_9gkdY
# B9hm2A9-fTc
# ZUr-QmRrBM0
# iga578pSs7k
# bTvLO3_rVWo
# 1gKUnmCArDY
# gAFRhSbkKcA
# MuPAOJ_Ds4c
# Ap00kfjaLTg
# IF9nnATZ86I
# BK_6duGJREQ
# NebzmaKI6aE
# 8-gaQAuf42s
# TEiiGxsVmoI
# ts8-h0yW4e0
# AxKwE5OIXsM
# 2e5tIBtg0P0
# eD2zZzXyBeo
# Nn695I1DqkQ
# aaYskG4mXQc
# UnCvSKGeLnI
# F0m-aC8Yh0E
# WsW7yo8fGNI
# sOmJnCammTY
# ZC9MVHcsyGg
# K0Hp-qar6vs
# Vj-wihg7K8w
# Mf4cpXWRzoM
# Tuat2Pfm234
# OrhnP9EzLdA
# PQ-bDRT2-u0
# QQPQa2wfGLE
# JHMuIEHZz4M
# esob5PeuNrM
# 8HTN2JR56nY
# FCZqMhwZMGk
# PTP_iIR7q0Y
# P4nNJk76xFo
# sI8K4tiAQd0
# yiFNfhRtxvs
# WMPqT3QcHlg
# jqPSOcb0klA
# Y3otj3eeUu8
# oi55auCGA4I
# Y0swbFoTM8Y
# 2znKTxw4SF8
# NySrvB3Q32I
# jP3DXkfGXuk
# w9jfgD52m6s
# 6xPUjn-AP4U
# u8z5DgQ62FY
# 8mCmM9IJfT8
# vrZ1M-swA8Y
# 2LVST6OE3X4
# _9NcWjjQ8-Y
# oqXXbsmiFEg
# wGGzNGZRYAI
# z-Q5kQJ-25E
# ld_CifXlMcc
# GEysj2yBPeQ
# EheP26NEzHg
# caFWaPEWlHI
# NV0Zb8B_LBg
# 3b0CGOAqWgA
# 1ELjRuGdhM8
# YZbhJb6_q9I
# EeKsgAbn-5k
# t-tjiPliVYQ
# YcoStSkIzqY
# GEu4Fv-GPfQ
# bLlLU9YaCKk
# 1l2HsLvjW_w
# ArF7feyqfIA
# ALuzzJzrY2o
# F0_8ymTFk9M
# d5L-d3bE6gU
# -l3BLcyW2pE
# D7_fty_Z0eo
# oqA7EAtMdfA
# ZkToCvmRgYU
# snYJ6wwzEqo
# I-cSIZRnkJI
# tFc8ax55a74
# JZYtcrmWQYA
# vD4LLxt4_cs
# jfTTxYCmOrQ
# J2ZuhUJNIaQ
# Jx8O9oKRZgE
# 4w-TeoxkT3A
# ajiEGc9mCNY
# tMTXKVfTC9M
# g1YZQeMjxuo
# FjyUM_8uI6w
# sCwN2hnSTAw
# XCm4hvMOYgA
# 82x7UlS22vY
# aMb8RgGhlxM
# 2OUoDe1kkK8
# fRwsj6vwLao
# 3kmR3Gw_5CI
# hh-2YxP4pSk
# qNmr4UfKEuc
# XeiLUFIRclc
# eaPNXzx7g5Y
# 2dSmuPSFKxM
# izUBP1BbBV8
# saDX-1pakAQ
# blLcCZHafRM
# qYs1bCqkgSo
# C9w7xDPbCuk
# kr9go1cBanw
# 5oMbMNZCbx4
# YMNU1dwj40k
# _DntTuGEVAg
# K9VhjH5mlyo
# CkuNU42zPnU
# GoV_ikO4oL8
# 80y2NaUbDhg
# nDY-YzHkfpI
# tmClMOtBWdM
# K8WjPoXCmHU
# Ub5jlww4i9c
# -_nJUtGhkuw
# km05o7DUcX0
# SVSQPEFyk0M
# FEYjybo5Oos
# 12pwH4q2R5A
# nQjLDCKeErE
# 77K4i0DrIqU
# 3f9x6IGMrBg
# Dua-GjYbjwo
# yVUfzPH1XWc
# _3K8XyBGsJY
# NDbUYyDXVzs
# il1Hq0KUq8I
# DsmKZplDTpE
# ZjdJuCDcDTE
# uiLz97gFlPI
# uMYO8ZNw-Bg
# HIeJP5VDfu0
# qRaKGPz_15o
# baMh2-HmoI0
# j2_-dH7C4Mc
# d28DY0TJF1s
# GMVurPnEGnQ
# 4XQB3TbXAos
# cqeBi-mYh6A
# LiPRmPKKYao
# C5scBUJXoaQ
# u7N3tdORUpw
# FdlWNnDyj7g
# EKDlu90bTgA
# 9eA-IEOcafQ
# MJqWjOF5YVA
# yIbWB_sQ7No
# 6mM9-QTx-_k
# yYdG2KfUwPk
# pfxmh4q5oOI
# sJ5OA578npg
# 9XKcm5Wt_Fo
# Sy5qD4LibSI
# _e8-RcSii0A
# YGd1z7RdfUw
# FEhrsZSQxSI
# nwcRf54-U4Y
# oidFodUsdF0
# E1RGJnKuGIw
# 9HQJZVSVukU
# xZCJOnCuKW0
# rIFC26-xQE4
# pY6ULY60GD4
# du5xDFMTFaY
# wGBePeL5naw
# Z8vU8VitN_k
# 6PCkds9Ucog
# 59ji3bD_Yxk
# 6krtMs8mUFE
# 7UIPlhb4f-A
# ew9RVRoQ_fE
# aoZrVEXd7r8
# WUwSvvBDlU0
# 109ilBiYmrs
# vg7xq-vAab0
# 3WpJ_vxt2b0
# eQs-KLNf9a0
# FEn5zLHzbZM
# GjX2wV7R6RE
# KAdjeGZtWd4
# 5YImqAkoAQE
# pG96UVXsCVA
# HWGrhxYaPN0
# i_XxKMy5_uM
# jRMzjp3TaLw
# IlUUZtDS_G0
# b-JQRiEG4kk
# 2utJqqalkFg
# hfhsChrHlhc
# rEN63bFqtT0
# ji0XuygWByo
# iSWrOLEM1Eo
# X71HmXHdpx0
# eE16oisoMZk
# 98Hdzehd0Zs
# LFkxRJGDmR8
# iZx2k7cUgtk
# 4q_T8rT0leU
# k8BFidCMMDE
# XLvZ93bpr-Q
# abm30dIPPoE
# _MXFxAho5Rs
# AArPGeYdoNU
# s8cmhyxcQ1U
# sFsgSO19SUw
# qyr2G17U14g
# hxEj5MI806s
# blsZ8MAD6Z0
# gzTwMI2ryKQ
# Up_8OdWKTrs
# TAXinhFue98
# CO02s5DHqKo
# _eMhC5u9LQA
# 7KZKH8FmK34
# 7s6kL7XuNlU
# I0kKsgYXZeg
# -Miy-y0MFMw
# rc2-pUcO3UI
# bL0Mng6isu0
# RLH_VVUj4UY
# TMvgGwjR-d4
# DZKfpHORbhk
# FIDsnB_K3Ko
# 1pfm02kdgiM
# u5mCk8lVQdo
# YToldh0MOJU
# LXurKQdY9Us
# Am9pGYNr5Oo
# o0fHU_w9T04
# zkf7ficMSbk
# 3JH8fiqGjEc
# 8WkBfXVCBwI
# MfvMtRmvmtY
# ju90i-ZCA0k
# bO615GBSSyI
# 1Y330bu9CF8
# GvIGcXVUF18
# R4K7eFSaTZE
# e12usFH64GM
# zUN7y0tvqqU
# 4cc83hOeJX4
# x7DaPBEIBp8
# CBLj7Ph3mdc
# IddD4QXVdiI
# 1oL56XFzMro
# a0R4wZCpQTQ
# oc1bX3cbcb0
# bV-TIun35Oo
# vRpnnVJzPCo
# dLL1Y3wVL6E
# 8zbXypcOWWU
# as4aDRhs5Fw
# PPWcliuU1EQ
# M6S9l-qjH2Y
# xt-Y7OI83y0
# ghqmai_TSM8
# 1UTmxJrijAM
# zbzMtH67ZiE
# Ghx8I8BgFAU
# c9cTkXRSoDA
# l0mmHqbnhF8
# sOBcF5NKtxA
# qmiVa_ns4gw
# MELDkDSgBdY
# scrlgBKDGBI
# JaM99Bm9MpA
# Xg8q2EbCP8Y
# tO5MAwYOSW8
# V5o-pHzRAOE
# 4VGLb3Q1440
# kuMsnDN5al8
# _p8Ob80L_ZY
# MmLpevXDu9E
# PrEkPeJvQgY
# O3QNNIggdkI
# 3PjEw4koY_Y
# GMei4IRI2I8
# Jg6fpgCuanc
# H0_x7518_II
# jSe3odU-r_c
# KcnKMuMrYP0
# -Xi0VJ_gXU4
# sIedqZILqsc
# LE9Ho9AAoNw
# 16OveF8mRTM
# XdU81V3z1U0
# vCs2DqKTVTI
# NLjib2jmEfs
# RC06uIFb6nw
# _Z08BV3VcoU
# _HcU_Zcc1yo
# XPVYlIRVhkk
# -jcOE0jKZo0
# b4tESqWJn6k
# EHCely4lqoU
# 8q79DLUMd2I
# jrA6djHImWg
# sU0OI9lgeyo
# 1Zhrt6E7bkk
# WBjih_CDLbU
# kOPlmk66KzQ
# hATiFx_Wz1Q
# EaBH-FcUAec
# aCqV_x6YT-4
# NJtqYDBcyA4
# LiKNQS5gcdg
# eCfH0cLj26Q
# FDW3lz5aNQg
# doNidSEXCrE
# D90VC21nx2Y
# wjtfxUkv0AY
# XhD87j5c8QQ
# jUn0cLYoub4
# dMeKcomSEu0
# 9QC0JNKYVxQ
# ct4JdFOiUVQ
# qa4WK9_4_V4
# TxxtXHKjtf0
# qBU-VuWAPsc
# vmxbW-ZOF_A
# DdyqChGWiTI
# vVtdfxlP1m4
# 2u3w7XsndZI
# TZ_nndd-gH4
# ovIGjn4Z5rg
# D4-F5I8_wtg
# ZLzy3PRNk8I
# RhoKhNaikXI
# S_JgwifNR6g
# v9Ml_1khJLY
# dUcVf_qHlfs
# nWQXDExja9g
# Da2m0wiFYPo
# aTvgtF88vtQ
# oXsoSuoUBiY
# H_PJcZ7ZCrY
# 2n8gzdtkpuc
# xjCVUAM8u-c
# HfWNMmd_qCw
# 5H9v2aDchNc
# INDImg2iOh4
# 44K6rvEDv3k
# -aNvHlFnnIc
# 3A8pWgE7rrA
# G_HAelnOmAc
# ErCtwCkIU2M
# 96pRe1Un3nM
# vL5hQDSqH_0
# fLj0wdI9DtU
# hjoBrY1yDUc
# PYML31hX8Ro
# EgOTyR5ynb8
# Y7Kwv8Z8qRI
# BhsivGwQPEs
# F61p6rn5JCE
# NrYo5yqTsUA
# 5Q-iIHukVvU
# iW9KY7tTypQ
# sW2Mn5Ny48g
# 8O8QgPz2d60
# 6_2QC70zP5U
# To33gI5saoI
# q3cobe5qMP8
# Jp0IZYlzFF0
# 1DbUIb1SHrg
# 4OW-idDro2E
# w_QC6SbUZiE
# SV4KkGfl_o4
# dqvh5ZHK-hY
# OQCJIJaaDb0
# GLp_EF9WxVc
# 2U694sdSTmE
# Szfh3dpLqfw
# cDmQvW_l79E
# Bx7yFtVo2CA
# -_L4NIgbPVA
# 3lKwLPR6rm8
# 5CqSrvy5cxk
# yRP3d1-oUzI
# 72hz-apUiRI
# prk2l_M6b7g
# MfJQxA08sRY
# ts9Mrs4fC-o
# Bv44YB7qRq8
# hsdlTyYQOVg
# -P5v5j90h_I
# 6OnUaFUweSM
# SvUp73i28UM
# UjHEGuaKbdc
# nIYXEtLzIk4
# wkepmjK6uzA
# UaPVPdnvg0c
# VLtrO-1ucec
# Wv-IcSEiNeY
# jwKHwzUpzxE
# egivCSi9Vas
# 4mXjRbo1cu0
# Qa7pzU6kBmQ
# oE4FiowI7wA
# uuVEIuWJq8Y
# -a-TaRl6onk
# hZB6Qk7BwyA
# ddoriE0UdRE
# eiB9XM0cPgg
# qsu43tztGM0
# ECmjo6v_bIA
# m1YaAGN95-U
# M3M-MYA5weA
# SXy3GqUAmO4
# BBTxakmQCAw
# tEzlOAIMPvs
# Q58KczBUxUo
# xNfzr0awdfQ
# CrQLomhenNU
# P-X3pUdB0VA
# 3y1t5FE2sR0
# wPuhA1r_9mo
# 0YTAK_IIg24
# yl6Os2VG86c
# bmlRwStsOx8
# TF8M4dYyMZk
# PYXCA004SXU
# 4eaGxGK8NR8
# hgOfFXrdRcw
# D3ZBrDKQ7zY
# 1WIcz4yBruY
# _PAv3bduYK0
# KGrlFXXWNjk
# mq1N917cqk0
# NbWmKt2sznY
# Eh9_ncpzAqE
# bF_wETnoYbI
# UStp3q_BoUw
# tcGhyLHVVdM
# BWfk_ysYJnk
# HksiHUTimqQ
# N6Z59PVqTM0
# Gaa7TzM-ouo
# ocJV3ktleNE
# mj0B43bXUTM
# smB_saXJM-w
# vW66AfVBRZg
# IlQOeJZ9w9k
# wSEUdwLbzHo
# pbEopqxpM10
# 6Lmxh21RDUo
# se7p3u1ssh4
# xX6MioBi8lY
# tysbBg1nhk0
# FoL-CDxBHy4
# 3iE1kbyTdFk
# Gw_boRf-OSw
# sdxl_vwje7k
# o0Wt6Oxw9p0
# LQ1L80We2C0
# UI8VdfSRuBg
# YPf1pHKRRPk
# lW1I2x8D9MU
# mBUZA1W4YWo
# kX_Mf2qxVRU
# _38TO9yiRCk
# 9otQseL9YVA
# KgQQZZWVYH0
# QkC8lLpV0mE
# saZs43Ft7h8
# iDqQ4MVLHu4
# uSXHz4t0CBc
# v2c46Mqi_v4
# omYKsldXoZk
# _Y16Vm9p_xc
# cuHScB5zGRA
# YHul1eMhCzA
# M6d-dsfOW8Y
# 9qKek4_lLLY
# 33Tc3O6QA9I
# 5Jem9jcH2VE
# 62ps5BwU5GU
# VSZyd0YYPug
# whNXHxpcoKs
# dWiLbl1lImU
# RjyLPMvzVaI
# kIb3C59eUZM
# cqe3vDeUoKU
# _rK4huLRLQM
# AMmFfcfZV1I
# C_-cD6xSrPw
# cAU1L5ntipI
# -KyQlNVKMfM
# F1risUxfy_E
# sYUhFgIaXRw
# fB95HC8vFr0
# BO51UDBh-sc
# cK9hyMLtv8M
# Hecw3cFzYUg
# gyb-Rt20CfY
# 1lPgcJ113fo
# 63XODvtmC7I
# 8xt09aQ9Fv4
# SXMajFVImNs
# xXPJA3SDsvU
# DsDQIl7PJZg
# 8SMcmwta6KM
# -xTZYWT587Q
# XwwRTcPSETQ
# ixmRy5Y0xd0
# JfVwH8Akj6k
# NtK4vxzQihg
# 9xs-KwvTsPQ
# j4CYPphHQUE
# EpmM-du0Qag
# XRucrWss-pk
# wyqo2eHoyyE
# pfbLsnVbyJE
# Oh_C7Muq9dA
# qoAEy99yy14
# _NeYUxlAZnE
# yUC7IPJJFQI
# -NaU7gbzJ6k
# zCIGeR0RTyI
# VSmCsPY6rcw
# W5v0yGL7fPc
# zE8OuC5om5Y
# pqXVvbEdJbk
# eTXkjuu-l7s
# AAfz92vBX6M
# k2uzXgKmCRg
# j_MbMyJ0MVc
# mEzzZWaMqkY
# XOA-__R3pNc
# mGx9WHNX0zw
# aECqxTNQ2vI
# _eQmi9QNPJg
# pOnJHwktbu0
# xxwzdNC9oI4
# gWWu7eGeOG8
# voLJsG3embM
# umH3SeIvrjU
# 9LMjwLuEFmM
# 22UKjC9NG9g
# rpLmhETfFBU
# IyNyt3nBbNA
# EK5N2VLhwQM
# iaNrfkaaZVs
# kJnlANMKZGw
# -u5mNzEoUdM
# mDkSOYP0-gc
# 1V58DzlqPhk
# rfySWp9_kq8
# JkQkT_PrvcE
# v_ALA8-CscQ
# OsHOPbcKA7g
# Ifwk5fBMFb0
# cTLvHAwiAuw
# PrlijjAt-uA
# 4sm1YJtqBmc
# NAXEZ6v7vPw
# Qf9enRgh34U
# uK5yWa3DMuk
# vEw6bADXcQk
# xKgpBoR9ZuE
# H6RrZjYCnQ8
# G0PIk2nQLus
# GN0Z8mWmU7U
# QyN8hhnRGug
# ExrPSrbbaGM
# rFdxeqEhZKs
# WhUbx_NCbbo
# -x-Xy2OqTYA
# fI_SWZTMz50
# 0UG1lVP46Wk
# JrTY3j6O7dQ
# VvomlhtS050
# lX8fMYogFV4
# hvX5XtKzYz0
# fYNHZZNMpqs
# URB5R9aajFc
# XYtJA6d94DY
# 7yv1vMBDviw
# aflypWVIbkw
# _9YvihTMZXs
# Pwr1F3NmWmQ
# Ls0e7MuGHi0
# o0LWfOwQbdQ
# c2t_Hllwei4
# H8vty9y_y40
# NRMAjgkOTj0
# jFhgmYlACE8
# oiFt57TDqOA
# xPoL41zZIE0
# bDvdNzPsYs8
# L6m2U8ZvfLk
# coo0X3oUQCM
# CFQrvzloAMQ
# rLTKoqycjcw
# Dn941lIy84k
# NyIdbZZIPjc
# 3aHbCgyfUIU
# CTNYDJ5BLZ4
# qrcQr4njA-0
# N5HqPPGEiBY
# xO_Y-WIJX_A
# h8xq6mg161o
# 9CRZGxKHtDo
# TX-Ot_7Ma80
# sJY8iKqFS8I
# KUh8tp5gz5k
# 0ZR9NytRTIk
# SR8tSwlqDn8
# 09BALTsXmk0
# QaR66QXA3q0
# dquP8JmxU-4
# qaJXXmp1hnE
# Os_Zoh7DthM
# 5rSF9IrSRuA
# YB2ZHsELPuI
# 3epeWBX_3P0
# Oa_uyOfID2w
# z0IdO4PcAuI
# _Z2C-zhqu14
# sUp6vYt-TMw
# FdY5M0tL25Q
# ARqXbH8OUQM
# xksweTlNV90
# GzQmqP04VFk
# q05CDbqroWg
# rcQLNFKyh_Y
# DQxsoKmJnOE
# frtUncKb3Rs
# 5pxIzlyLwls
# n73rtwpTfxo
# pnrq_49xSoY
# ZcgFq7aFoLM
# cKjg22CFGT4
# DGPfs_0mXoY
# HbcXK44sN6s
# YNeNri4Mtxo
# OQTd72DezEY
# cRreQ-14Sc4
# 4j5fhFq4Ces
# C4sNmgAjoqo
# Z9AiJTDZBqY
# OeD1Bfz8fLQ
# H2TJv58E1ps
# 0SURTMDPkUQ
# xBNx_qRPdU8
# UcmWtweNnS0
# 7gZCNBZ8hzw
# VWEVXiUPhwQ
# TKy7I_0vuE8
# F_7acZOdcAs
# 6x-0Gww2qro
# 8R8OTUu4fxQ
# VcuBJ3DmqTY
# 6asJKGaXTgk
# wkeW1uF9JVc
# T-RBdyXe7Es
# i3c-E0_yF3g
# ctAWaIz965U
# 3wytOO7V-bM
# U417eBBXpqY
# uvJAuZndaIs
# qRTYhj2AXUY
# QXPs_hnGDmo
# Zzxgmv6jv_I
# LiuAgokqDFc
# ay3P4oC0eWw
# 5N2cy8nogvI
# 6pZijj2eBTA
# LJ9o3IcivgY
# 3f36-D1Iw7Q
# G74Mefmn2JE
# YAFEU2W9lak
# 7cokG_NWh3k
# eq7FZbOYGig
# K7aoM46Fu0k
# 126rYi8ZuKc
# K2AqNC42vOI
# nd9uyXUvMf0
# 4AKaAlM-nbE
# b3J3a2YFeuo
# 1KEY6GRXYeo
# 9M5MIIkDqlI
# XbhDEbEKdLo
# KEusRFn8LHM
# uK5Jx0U2gT4
# yAlmV8CbERk
# d0h3khHH-Vc
# qZpmmZewA1U
# Pd8r4XhsRXM
# TX8vbPYdUUU
# F2EHRsSxYvE
# 0umoT5uXpdQ
# MWDwpWtwXb0
# DbiaNyhrly0
# fKLXnSOwqM0
# Ss8_RmyTPIY
# WH5EONfc11I
# 4P_yIVzvj4c
# bCaiM4tFMgU
# G1ELDkzXSL0
# MzvRV62cTqM
# Bh3Qlq63Btk
# dwJ6RUqF7Ko
# a1mknpYpERE
# v64Dp_EskdE
# bLaAFq8qn74
# VGTDX7L6RKU
# D0A6ldOcAvY
# CoWByZ8S5mc
# qHSklDRIuCc
# ucli7Iltglk
# fe4HpcNyqHE
# s1h6bZ-WWzE
# 7HBkdYIAGBE
# w2mORNsLwH0
# NVAFE7i3h18
# b13NlXxflrA
# jMGNWb9M2Cs
# H5R_kVno_4k
# JJw_SEFSRks
# SFhRQVXt9Jk
# iUGwfLNKjoc
# 21J-RTWrzho
# bh9LVgPACn4
# YiE464OqKO4
# qc8akIksqAk
# RbHm6y757n8
# sGU3xNyoa3Q
# VX-m4t-MQqg
# 6kMIuPAQB-0
# w4y9VOU6F_Q
# 9ahXhoCGmg0
# oN65Thp3nmM
# PIhnqo1CFH0
# WqZVWA7j8_g
# GdIARjOu6AA
# AEs_O3dUa3k
# dqjMoK36XJE
# 38rsJSOF4so
# xSJv5aUOmuY
# urXpt5L3vmU
# lhuV7MvLgew
# e7jCdciai-g
# MS7GDU-fvK0
# _O-b9Dl6YPY
# xLlfCwO6jrM
# foPU37VgG3I
# jCGnLtIAE5g
# XvFcitdTpUA
# HMnK0tSsHdE
# JJ4FTjBjZD0
# Fb5RIAWFXZw
# 2m-sq2vXSyo
# YpioD8LltSY
# RDoYj9gfmYI
# J9HI1uRFcW8
# LkcjJa8inxs
# 4tqm8s77xjo
# QuTPytysnrA
# vKqVlUabxMM
# 1np47QVtgB0
# A7nW75d2kJY
# XZNF7BkWesY
# VfGNssjzchI
# sz9UL3WR_qI
# O2zVUp2Iauk
# zsS7HyFParo
# KEB1l1gUzdA
# kt6RqIbTjJU
# hsG2vF1b0Z8
# 9fbhCPlKN90
# 19dWAYE-9Iw
# 4enJ8BvqzOI
# aMxTHESe2Ss
# HhS4v1mqa6Y
# 2sM971Hsf-g
# sa9BnbirmbI
# -9ZR0wvc57I
# A9yRKjgl6Cg
# XxEBLHydUEU
# RTGSwlp9nAE
# mHfRBT8BkSk
# QT_LtVbZAzU
# rCkgYskPndM
# U-OpJetFszk
# VzwmTZPZBaY
# Z242u6bOaPU
# e08QiCvPny0
# fv7l_9xcDHU
# XsYDRLcQBFg
# ZLWeHM8P7rU
# RR2qIrZHP10
# EOttef29t9Y
# himTcqgJKHI
# yudC-1O0hRo
# XYOfcPgr4DA
# MetuwUUvT2w
# NS4JCJAQMSU
# 0w9wvW-tBY8
# 2nROGmULPWY
# zHhi9N7LYcc
# VRIrcsxw27g
# BFilmeLftyk
# sj_QLkcMLac
# ietcaHKvJXA
# btDmskZ5_Kk
# WHBjlubDIVk
# hzGNz7hSKeA
# hHmjc7cnvUc
# xxODzezlveo
# PKND9z0Ot0o
# avr1JVcf-wM
# Ntd4GnBBVPY
# 39VmPkzJApA
# DqSJCL8zHnM
# KjBfH7L7rO0
# tHmnRjIKsGk
# CxB8CCsYQc0
# awVV1qSSUew
# 3-J34Eb3fmU
# ICHiFg1c3fo
# khvDPP-lfb8
# Zgf8-Uy9iGI
# GUZklhLQErc
# GnTdoB1V9hc
# eq3Z5y-1COE
# K3Su56Nysrg
# Zis1-D7zkOw
# 3JXN1Qceevk
# 0y5UM7tG1VA
# 9rgF7vfMK3A
# jpqqQ1Odds0
# PUV9_OdMcCA
# -7OmGcjkO_Y
# qW1hpmDjG_M
# 8Vu38kVVQxQ
# Pr67zLsIELU
# IeIq3JeSvjs
# JOU52X6Gcy8
# hP4gTcrwn5M
# LNOkOsOEEJw
# 5t33swWOH4M
# szGq6J5hbi4
# VSWmlR8__FY
# oVDXKYkbTnU
# TylrgNS_xe8
# RqIfnYbuePQ
# mpLkEiEKoJQ
# HrD595c2pzo
# qv1Xa_EY7sE
# gsPK93fi6EE
# fkIcrhWazpQ
# eDpC_LxzqQ4
# bI91lV0DbhY
# PV0dq1Secp0
# cNiGmAaYHpw
# KO7vUgfeWrw
# imdpGhH5QsU
# -KPES4rsnaQ
# KvT-C4C1VNM
# xONmK4-9nLk
# cbUg_H3d9XE
# N96xdWV39kQ
# fl3Dfazaxos
# tJ_sSmSOUqo
# vab670m3ZqA
# QYyh3ooSLNU
# pVn3hCNazQw
# 4Ddnqrpfpsw
# 31tMXVS9fyk
# RRAjL2BRScY
# -s75DlPohl8
# ACXQwCgHe_8
# jHRvigZvAEY
# JK9aBtpggn0
# rFoNl3AsoGM
# utqQHWae6Ro
# lnrs1OT2NFE
# B2FeDiLGFL4
# 1bESq9UEOG0
# bfBuMtO9QG4
# -T7u6M2mRW0
# 0OBVPdy5QWY
# cjIKzaXNxTc
# GICEYWJx61k
# g-06sDLT8is
# b06sQ3VNH4o
# 7-MS_8kjR8Y
# IwiYh-1gTL8
# izlCIRDaYYw
# U2J4Qpcwqhk
# y9ism2zYq-U
# nCq7_vBPJmI
# OqhdNSdqn54
# mjvmEjfIfgo
# aLmEiO_d4Bs
# tkiKQrxQbJI
# nnvs2dr-EyM
# uQYKtZWGydM
# 95np0iMCCsM
# R310Dxh_uj8
# CdwFSgovnV0
# 01RRQbZ7Pyg
# RMF1ZnZoTUE
# gmN9IaSU4j8
# PqGEP-GVI5M
# 4O5pw3AfSJI
# 5CBu0pACqeI
# hi32FdiN8Yg
# LuOv5d_Bnbo
# VbS1bAbzVnM
# qAXFfyVZ5Ks
# yYTZUfJh9dQ
# -UOLneIAg9o
# 0oMbtyV1L9Y
# KreQq8mcHEg
# eLu4TmxJPE0
# bGjDHtY-Gr8
# v2JeVe-p_ng
# 8gHdsgVa-QA
# SdXQAEsP2Mk
# 1LPezNcRsUU
# hDz8gLilFFA
# oZU_b0ncZK0
# XqFx5xOPTZo
# ehfRBvBL18E
# haQJ-7Vzp9E
# pwaCLU11vI4
# ZfN4ECGKQsk
# o-rsJ91nrRQ
# RBdY2lxtg2Q
# QISuLbP1AhE
# DF-NK8e3W3o
# Djcr3pYQGMk
# WyTxRQIAiU8
# npMA4AxuK4I
# chRRscr_m94
# rYY4wCtcsq8
# LegG4gZcXys
# Ah-pdcB-Xa4
# oDuSjyc5kZk
# 8lI0P6ZpRrI
# MyhlKblrTOk
# D3KSSoN4E-0
# 8pi-j6WSOY4
# ZAUCjBxbsGk
# zMGDWYm2dnM
# _WQUxTEpTlM
# CfN64rw1TzE
# 433MQ7mtKt4
# CAS0-uH_YLc
# 3wkVQQafONM
# mj737Fn3Wp4
# 4f9kFadnwU0
# 7aETrYob98c
# E5WLEtthlqk
# 5Purfu_ji_0
# t2ftv8tOlXE
# 3jxEqWlXiWY
# IqU28B0lHPM
# EJAyImVeyDs
# WeKX7SKwT2g
# eV3YOSsdXQI
# gcKapP7NOxo
# FzoCxiPejtw
# 2NVlgI2XNj4
# Fg4ObEAxIro
# i0hYrZ-lMWU
# mb9VSENQjxY
# UB05Q5FGzO4
# BUsIjFD0pBs
# iLW0hsJfJ7Y
# uLvY0zzb9Eo
# h5BhdJHbovA
# SE7224zvyVg
# Ro2M0452oiI
# g1iMCvysRCs
# 1wInrEzWAsk
# 04slcZfmFe4
# zdMp31ns8bI
# U3grtR_nxKQ
# TKhnW4pbvo0
# 4Ha5X8tuHwM
# 2ADDJ6nL6RA
# HJGvkFShwws
# 7DFA26doN_I
# nC6jHaM5c8o
# yz-NHNcFrQY
# gCcDNUxL0gE
# XLY_qhBYm_I
# i42IfJ3Da2w
# KIOW1eLItfY
# 5nkWQZvomVA
# -2M-owk-10s
# jMVS7JTKH8I
# ozkCTE_al3A
# _acA-ThYCXM
# 4B-gd3y_XyM
# B9YCoU9h93E
# 3MIcxh5MLAI
# OGCaXsmVvS8
# Rf0WcbCD5YI
# jurApsYzvxI
# CInn1mpc67M
# POnzdG9EQiY
# EMRSHAWHtzU
# Cio22GgTM5M
# 8Yt34YCTAPM
# px9Khrji5ng
# OzDeQwE-hGI
# 9xbY3Sj1Skk
# -oJM3qzX6J0
# Ji3bo7fWSlg
# beaYRRFbY40
# pkrJLTRsGxA
# esLOm_Z-Rys
# nPUnapR2uxo
# 5lbgmjQ3RRQ
# iSXarpm-WSA
# abNXvRv-DQ0
# CDVzTf0Gkb4
# Y-ePQKBtasg
# t2BG3P_owpY
# gel33fyC-lk
# f0KxMgG9kIE
# YHJV2YL41Z0
# l61Krp_ER0A
# ryYGDm-mt9M
# sn96atV2xQ4
# T2O6dxlQhp0
# HVtywSELn3A
# UZQL75WCv_4
# 3vSkRj2RvYg
# hws2DfBa6lc
# xaa5CStvTE8
# 38G4V-imPQI
# HlR9blhbHgE
# VyFeHiQuvSQ
# 9IRYNOgXQ0Q
# L0amDVBDZlw
# TjSvWXte3u4
# OMPiv_cpy5U
# 9F-um4BYpf4
# rRD0tjIi5u8
# zISHPHz8QEQ
# uWeyNmY2U40
# Ec5L3MjjM7w
# rM6BP1i6TOk
# ijXPipS8qWk
# f72HafZzWFs
# nfGboX7T4WI
# 0yqeVeLflMs
# w3ZDdCsyaNk
# yxPKPF7Kfzg
# qsFw3uFhzcw
# STxoUQ1hRj0
# s6za2rDjQDc
# n-Phcz-Wwu0
# glqE5CCxdLs
# Em1u-0UBzKE
# K2t15Dzf_E8
# 5YAlsWi1JL8
# qMyE5kWRCCg
# FxyZXf_e8n0
# tfcotZry2DI
# _kaX2b1J-J8
# IDtM0jaCQJU
# YCde1ic-1vE
# U3rl6z53R5Y
# yPsuAvBgsK8
# OD6fwn6hYqU
# -vOwwmbbfIE
# t40fSSl7jeM
# J-DUdrx6Opk
# SFWWBNIcpZ0
# mEH48eu_ga8
# MRGFx3cR7Sc
# aeT2AcQRUQs
# XKR50eqJ4Rk
# B8GLN9zqqQU
# aYZacc9uu-8
# OhEu0ydh2eY
# IFtq8dY2eoE
# nIMYr3A7u6I
# ka27AdvuHuM
# YhOsjV4HjmQ
# -GXDL51qmyU
# U6K2_2BqHGw
# SUPDaCGkyaM
# BmLfwtKySqo
# Y3s0EdDme8U
# OIdTMeYYHaw
# bEEacxeseTE
# BJciHaS7i8o
# usNUCVRZXMk
# 6nSNLRW2rAM
# l0tIfHBtwuQ
# piuYSM09ixk
# Go8MITMsSn4
# idRut93qI1E
# H-cN7rpNUMQ
# mX-wrqqwc8k
# epN0TnYspZ8
# 1TJrhiMA1JU
# QSsnKEZck5w
# NlnGCbQutPE
# FMDC0KpnduQ
# mWOa2WHzZWc
# gOAn12ojVYo
# Nr2pzjH-28k
# dtTFUI0HvIU
# CjYU3i2IcE0
# EgB51Ah_ABQ
# HV5s3sPTorM
# rwep_-a2G-I
# Z9IAR2-uPeQ
# KAwriJBhSZg
# r07t9FwHy1Y
# YX4H4ESDn9I
# QbpMvSZAN8I
# A_0VHx4ZcbE
# Pit3xJj3GWE
# -qr7uZiwC44
# BavTxBE1k1c
# xSeyzbpVBp4
# 05EpD6rd0X0
# -jb5TbofDvI
# kXO4FxYXZkY
# FcruFi5HsyI
# Zm4MoOU_P3w
# sRwBM_2RQQY
# MU6hGgsPrXI
# fcNxgHrxsV4
# SrGbc5fs20g
# M7w_QDoxEpc
# 9O5viqjz9co
# n5EG6Aak11w
# TxEahv_TulQ
# QgSJOcvIvj4
# TXCFoV3NNfo
# tgEAaNYYQJ4
# mOnwDsiTGNw
# r_gumncraOg
# TmzzHrdjOIs
# 3BB7O2YRCEo
# ogsHFW-MKy0
# -GzmpgFA6pY
# 0koRcmPDR5Y
# szNpoZgjiDU
# sXkWuX5nm1M
# sRQPU6Sqjj8
# cqV78ora704
# s3ab22g64vQ
# RVHqRrcmQCA
# am7IH38rN8M
# eFEwJcjQvDU
# Czrk_QDecdI
# 7w9sjEsq7PY
# ylvVfG4Zvm8
# 01kaWABuCk0
# xPJZjEdBQxY
# 0M5uRvRtZ_s
# AOVVGOKwLnk
# 718Ob2Ajk_E
# qDYpPy6zf4E
# yGcCLwqs1ds
# XXAQG4p6ed0
# e9qvnf2oXzo
# NBAt-jBE-xE
# Pxj-kU-KERA
# R5zAmTVxZfE
# jcUOh28mcnU
# F0ewu021R_0
# nU6Md4Rjs50
# BD77De5rim4
# MxbJxo5GaUw
# Gvi6EZj8mA4
# jVGSTIf_PDY
# ZXZQweUoXrc
# ffnKz9jqTjM
# PkE0mx1hX-M
# Pe5rJkYL8r0
# DCDpzt58XmE
# FgH-Bdx9Psc
# WgueU0cPljA
# 8STX53w9-JE
# 7Wa00TGR1fk
# 8DWrgSIRzLs
# CDR7LLKyxxc
# D6-YlbqBgI0
# bYxhUp1DTc4
# 2lICE16oBc4
# fln7068S1VA
# ulSwxU2mDG0
# A638pkuTG7w
# fwDD461HtGs
# DAK1HKIuksU
# mtAQ3niETj0
# layQ22XBPGQ
# da6qPDHKg0g
# hJ-XFQVSKJw
# TI4_1WOq_ec
# ywMmVW_5ojs
# WLzpt01KAHk
# fTy_x_3SkFQ
# L0AgtvJIjCo
# z2KAOSdrqds
# 1yjf0E2LO7Y
# jA_fgng7_NI
# 95N9R4fhBDw
# AAGpSClNkhk
# KDwrCJOqMtM
# rN6oaBLGl9g
# SrlauL7WLLI
# h7xwI9VNt6A
# 76JOGWVYHwo
# OMAff4DpqGM
# BW-NXu3bWjE
# xPa-CwRP024
# pHU6zxLxr68
# QTgKm4uaJE8
# c_SSLELG5f8
# k2gmHJ_7kA8
# -yLujnry1Wc
# j42Rem7kWvI
# EYZ1w2cVg3Q
# g7BIs9Hm6qM
# wbOunXS03yM
# BTDdNHs5Ryw
# qBKFw3wvvjE
# tcYsaOTiVf0
# thDxpyxwsGk
# 4XKoaBGnScc
# kFuhe4w14Cs
# OQl7bJs4LOU
# 10wMCwcJWZk
# BHxqYWaBV0w
# GDQWFirSIb4
# emTiCc0vr0I
# Squ3gHHXaWs
# AhrkccdAc7M
# 5ScwrIPL5jU
# PspGfxUF1mw
# JGNySbo2SqE
# WESGvh29rjM
# EyuT1x-lgUA
# JzO3_qAZwtw
# MNJ0v8jWTWY
# TR-fR57kONY
# wJMQ3ARnW_g
# Fm5Ir11VEb8
# 6ppqBZCjugA
# 0Dzm-dYguzw
# 71VvLekZ7cg
# gk0Su2Y2UF8
# -3Wcvffy9LA
# i35mA0Q-mbg
# pdGVV9VYQOA
# f4UubOwU2Fo
# ieZe2M-uZA4
# 9E-FuQ5hTVg
# IDTZHjH2ej4
# ftp6LRl608g
# 4c2an8LWGwQ
# EsOR5P0TUI4
# o1ErbfvycZs
# aLHbTwhPQ64
# NEPD621SH7M
# M2n2PyyXvyM
# AHx5N-uoZFA
# MRxychIrboM
# 5-pLy7MeZcw
# 4j0dqV_Xn_E
# 745D77Vvhtk
# a_S2nPIIAJs
# OkMqT3P2cSE
# xcp5cvjoR3A
# P2LsLrEj2Ms
# ZGVgF0jgSkc
# HHEbjXbJNeQ
# mjtpEacFfDU
# Xkpr2XIPfrY
# ZQQ5H4scfdA
# Lx0prfa2h3c
# uhKRXH-7Rdk
# l6dfiYI4Ah8
# qLwDyl7PbXw
# EVvWYXcTXDM
# Baavf-VyCzM
# YiVAJbzmzCY
# ZMlxVVF4hkI
# wmChE9nxwk4
# k7E_CeUfoJw
# FHYXoFuhywk
# P8rOLfwY6SQ
# CHzqIl5LDCY
# u83Uqi0zjiw
# U8kcPCAtqLg
# tobl_yyL7NY
# trBurFq8Mjw
# 9kJ_7xVnI4U
# 4Zytp8SqpVY
# HXh_V5z-VzI
# Ih7hqdhZUw8
# MxB4fRQ4He8
# n0xmrZnpc1I
# PP6I8JqNfGM
# DOWT-MbA4Gs
# qq6R1P69HjA
# c2bflmXnAAE
# KZhGjelNS2g
# 3CnXoIiQE6M
# 1FhwRZbp6Mg
# lTnacz8zvTI
# GwS1iXBuiYI
# yH0rV5dbM5g
# hhZdGkSfyCA
# U0GCHVrjaIQ
# j0BttAhc--8
# SR36Qw0qJcM
# 0p9dZbNFCa0
# aUZR-4Bkkzk
# pBmkVlTjqUs
# TP0hly8A2TY
# S4My9lTwCfE
# 5jqFFQqV-hU
# RM69Sl6_Eo8
# xoOmK52t8lM
# 3Y2A_tcJyEU
# 1K3n0zYG4V8
# Z958g5D8IME
# FZWdTfFDwGE
# HaGujyUuRK0
# TowxFsENnJk
# yzgA91ZCuAI
# CHJhTXU_7gE
# cdBjcUTKZ2k
# 7xdZZ703hOg
# BT9Mx5jh9sg
# 90tLpfsq78s
# -XFOPID2kp8
# 7HrTipdq8z8
# DKLRsMim6tE
# OfZ4zPaXfr4
# sbgYT6JDeAM
# 3-k8sapQFE4
# yPuxSK8qvxc
# 7_1sGi4dLPM
# nm8-qB4O7Jo
# bdPlgDdIU-8
# hY80557MXZQ
# BGoHVjKrTcc
# QSYu2_gilfw
# uW3ViIIs8Z0
# ITJsM91NUVQ
# IEY-PhbVdus
# iwaG6RzMJuw
# u35aCxjNOQw
# g7mU9ITXhzc
# iKAzt377pLY
# 2sIvSPbwTgs
# KnPxB4vOsyg
# q3Mvbxn2s1M
# 6dMKnhM4UVQ
# D9sqbSn9C3U
# RQTW9kXk2q4
# UaOkALLIp6c
# CthUO4uQjcs
# sozz8z_gs5A
# vJuy--Umkh4
# kp9U_0v6rp0
# H4RSO0pQ28A
# cESxIgTw-CM
# aizSV4PqCWk
# aB8ZASQzekk
# 7vi2VAolr4s
# 2amOGfzu1t4
# sOLdkEG8CKM
# UhL44ERrEHw
# IXj1-Rl58Ik
# vxecFHk6020
# 0sZT1lc5rf4
# DL5kmdhV3ok
# Pf_lV7dUefo
# -IgLOSd9iZA
# BI4fZZ0TLT0
# ZFr_A73gadM
# PuLaHAmynlk
# AbkTNb5LSR4
# 113_giijpBw
# cbcxaLw_gco
# hG1rDS4b9Rk
# 12AuC4ay070
# qL9GoFXl4nA
# sGGgqNOq6NE
# w69PYfwgmQY
# wl7BKkpcqRI
# AjP9HWiQOZA
# wPOdJ22bwVs
# cF71Dic8E1w
# uS5dFhFYUt4
# C9TePsEYEic
# EmaRX8Ylads
# xJcQxRVY8rM
# gl17D-6kIZ4
# f4KhsRLRemU
# Im2E368ITnw
# suInbkXpfpo
# vt2SQVABqeI
# TbJjdh21zPg
# Lfve_hdETR0
# DXdQeI2mEhQ
# HgM3BpVetoc
# b3teRO-R2RE
# q81aEx1t-f0
# q5PyxtuYFUM
# MwX6jZbTOA0
# dLZsaZP8Zos
# jcbyTPOSM30
# bH04qdF97kk
# oQLL5o98tks
# pJIfF0EMKRw
# -PkLYnAce7Q
# l_GScSyUBxc
# rDMcxlbweZE
# WPcmzL-PLu8
# KHxJoGtPx1E
# JyBshEY2OX8
# 0hyfNYJsjBc
# PwN98c0cpyk
# nxzasruSHsE
# qmVSePowHPw
# WxvVHqKsTkE
# POp_m-r0TpY
# wCSI0IUa-Ds
# ikdwTq9zBbQ
# riKZdUVRo2w
# xqC6a_358HE
# FgsKQdjWfOU
# PpkoNfsUu-U
# ztU9IhbpyZs
# r7vNLd5oTEw
# YRKEmCBvtRY
# CjCx7VbyvK0
# ky3sME_qGLg
# HUCDEX02A00
# BhlEqps_g34
# 3lHFUhmhTsA
# zMopIMop4qI
# cu__WAmPd2U
# o5SHKoZzfPU
# qm0XAAUyZpQ
# aFah_SZLw4g
# mdOZ6qqbgC4
# Ececv8l_47U
# xCgrc6rg0WU
# QyLctnxJ2os
# oAknQ3GQoLo
# i6FYEkudCHw
# 5yyi87dPbMo
# Z6hf6duAi1g
# AnjL0XEnYms
# -IWxxJ5sYMA
# KufeBVL48tE
# Pvr-GhQbFVA
# Tlm2yPSxq2s
# fg70lCRsdMA
# C2achKP9px4
# k1MQhe5RuEg
# m54QHXnzXUw
# vsGNxl3uHZ0
# E9WeIDs2QAQ
# m_Wi_QncGxo
# fqGslb-3SeQ
# N6fMSthsJww
# zs7soucwxRk
# WOqW5N1WdVg
# GivR5fSMhuM
# dNoD847GM-g
# 6LHRWhpTJ-o
# DG44zosL6Y8
# tdig1IWZb8Y
# H7MkN9pb1W8
# refxowQopoQ
# ZM_vSsUhVGM
# ioWb64i7S_0
# Dt142RhPkrs
# Zr2Tmqidki4
# cdV48c_RWwQ
# MPLMSSba_uA
# iXJWyFZYDSU
# od_kmhpSvOI
# e9s_jUDFWNI
# SnJw9Lx2eX4
# jNdFIPxVVeU
# aUVxa2y-ARA
# kipzH-naP5U
# jAJur6XGXIc
# C5aQsDbTUpQ
# 3RSF_efqK6U
# 5F_wLx9_ymk
# 4UdlYblUlvI
# _6AjDVSqGfI
# Dkie3rRMPGQ
# NdybquSkB3M
# C0rCySPm-mM
# AAhs3YaZWh4
# cGyqFdezJ_8
# zqccS-NMQfo
# xzNdTC1ZBmY
# R154EEpNfEY
# B1rDh2nsaS4
# 6qSKZ7IQSf4
# 7ME-_oYuAWE
# 6T69CpjrxHg
# WJFXu8E1zmI
# Sn12CPJ1BKc
# rbg6rbwWzck
# dFRX-9JZzKw
# z3_F5NR4ARA
# h2w0ZfBdubY
# tiQl1kp8KF4
# BBzux3C4hbg
# NY-mMlMmCtM
# 8xPYbpEIjcw
# 0up__7_mabs
# 2btVJD68-AU
# zyvTTYsPfDk
# J7tcWjlTSWM
# QgRYOQyeQSE
# bLc9wi1Naqs
# CXvkVXCXZmM
# nuvLV5P5yM0
# NRkrRDc_eH0
# tecuI29MZI0
# yb4_PrUb_GI
# cmyHdxbEgjw
# WdX4_3bUVuM
# dY9fJsCTdSY
# Iw9JLdvy2h4
# uur9F9xfl1g
# ogjNegD_2ok
# rx_3OgjYsZQ
# LovoxX9AeBw
# zJTuvzMY6pE
# XLgkJaKiMlw
# iyMTa9uBzVQ
# qDbDzC1ICtI
# d0WWfdi9n04
# C8eqYgC9urI
# BjAe6PcbjDU
# 5VnB4mljzcE
# cXBmfOAnVis
# RdVqSK3Q8E8
# mfnyftoQ3-c
# 9DrljRevBF8
# SoSpNgH0B3U
# xpDB6rllstw
# aLIF51VNqBw
# Q1UhOVdICLM
# cH8zGJ1s2nU
# UHfxLaokLJ0
# zi_1HLyOFT4
# VDEcroRIraM
# obZnlirdSp8
# 0jP1eJfDCpQ
# GS65Y3GmLa4
# 8Doca9OeAms
# dZMbA-csLYI
# WdVsc67u9ms
# 2HBV_Ra2Fu4
# VJvg8E-lhEk
# gEIj3b9MfwU
# QNGFxEqFZG4
# T3XMqz412_4
# L3jGksVnCts
# 7EzZwvS-mz8
# hjJZ0iyTqDI
# wsk7w0TuezE
# aUG-zqhX_UE
# AK4Ep7ZfBP8
# wlx5BP11SEQ
# Ot2ncfG4Gyw
# GqOWC8dOEEg
# r8ZuxImkV0g
# _SOd_DisgWM
# Wu5WJ7wrb-U
# sV2XGpQJZMI
# Z1mgBOWePys
# IJR1Hj40sl0
# 89WcuaQukEk
# A94UiWyH0GE
# QfXEvIdVpb4
# MHUx64D8QhY
# B42qhjNduFE
# ZF1tyg4axBs
# hMg5s2LnqmA
# BNkW-qeGnPg
# rUcc5PePhRY
# Rk2L0H7MUx8
# Hlzxr8Gaxv0
# vCkEjIO8jCc
# yVekOx5xVPc
# huWQ_fFyYac
# yZKdrXuJrbM
# KhglC1ISRlM
# jyY-Est-Wbo
# HyiZxD_sz_c
# kDs6K4xNQkI
# 7aQkzZcDslQ
# loF1S1XLiUE
# 2ADkE9zFTlI
# fA531PanwRo
# jFTmN1QXchw
# N43nJP7QErM
# ea-X1HWnWds
# 0_5kkaNmCVw
# QCrcpLjN2lM
# kX9e-hg5oUA
# FeNOSoo7WlY
# 7VtGYtvvlxI
# kBsROmnh3T8
# y_AYYE_ORpA
# JnjYVKPUPMQ
# jYriPSzpkPI
# Ze7xWTWBpys
# vm_zhSNT5lw
# p3H8X8PNwFg
# JAk3os4vq7I
# po9ICRzjYVU
# j-fwpkjMaLM
# T5naLs65RmM
# ycWJlmdSnwA
# hcj7Ix9LetI
# SQnrQCcQvps
# dcMmxHibYw8
# 2bV8gXmv5wk
# kmV9-ce14OE
# L--KKX4nkM0
# jT74YrnjfYs
# yRSCsop1JJQ
# u2do_d6RLGc
# ShzRKbhrKOA
# NmUFm94eCgg
# QmecSdTp0zo
# PO0x5n-fEk0
# C8erHyNXwqY
# fPsDPbVbOTg
# bGigncv7kuc
# uj6avHWXTGQ
# NJXjHvyxvMs
# 6FKLeeBljdE
# LWNVQJguEsI
# Gog-IcYLUpQ
# FTNOTzm1Q8Y
# qcABcwb_spg
# OItQmT6bRNs
# 7HpV7aU3yVc
# VQ3X9_-EEDU
# 756BAcmRgYQ
# hNrDJkqxm2s
# 2KLcA3xDKBk
# gis5Y9oCOq0
# 6oNqSePeqIk
# H8XBb9vbb0I
# c_Yc1Pcq19Y
# VjUT1YDQZss
# 9l-EcX7uarw
# ewH3gU4yV-s
# jNnVxBvs-ug
# vlHDP9P8P5k
# nx0KARU5B_I
# kGdilCDEvZI
# NxgyDU8FwRQ
# HieEvbozlO0
# 6p_Mdo378So
# ivrJcdjFpjk
# RNqTDkRRWv8
# dvu3fHz8gQ8
# v-f3pzaCJMc
# cpkXKfqfHS0
# xdoJENrmLNM
# bBsMH_3fcrA
# idRo2HQCTKs
# 33IWV92pMws
# rcRwAaaF-_E
# d0ASIQ7VMTc
# sc6rjp_NVDg
# 4ue2AqXl5Fk
# iD-1mMr7y10
# fEQHqSnRlUg
# 1CKXawKbRF0
# APN3olj2ibo
# nBUwGYrVuB0
# P_kDXPUn7jU
# fdjiq4ID0-g
# SYP-BM4opnQ
# Lt9lw-DLQKw
# VB404TRlntc
# Yc15rpmiWS0
# wWZ7wRNAg7A
# uchjs64JND8
# dcdvfejRjVM
# w-P6AekhgnI
# t1fGDukQgYU
# hGMaKAzaTvU
# BDI-w40QU7Y
# IIZdbRnyPaQ
# Vl89obZ6v24
# 0WffllyCTBU
# wZ2QTbRdB2o
# u0yKLmEezlg
# XVQblN7pioo
# UiNR15P6lsc
# 8snwHvJGgYY
# Vm6pNG1JD-E
# UHom-Xi5pzA
# azMSr816yys
# gJZs7q54SXY
# trsEr45BTLs
# Dad7lgZNzas
# ArHHgtIdu4A
# 3M8YGF16jl8
# lyYGC8GAZmI
# rIs4SIN9-zE
# Irs8qS_NUY8
# C_4n04jTIvg
# zHOD_3NsL-Y
# jrploPfc5Tg
# fz5daHHYo2Y
# 8fBUGQqZ-XU
# 2Db7g8irGM0
# rf6K1ys8GB8
# OlZIVMAN4Xs
# c7ZIbg3uAEA
# fGejjfVvDS8
# 0-aJnKvnzzY
# GwcXL3nr4Do
# 8ZpjYVQs68g
# 093pbP9BTlA
# lGTO_cAO7jA
# CcM70PKcd-Y
# X5F6wNG-dIg
# NEBfy72FKiE
# J_bi029Fx5U
# l2Au3DFkOC4
# lhQHgBpvyYU
# fy1t-vtceW0
# zxneJ2tZYbc
# pQ_tExxaS6A
# vcrTdfm_KRI
# j8O8-LytqrA
# Z31SD2tz6TA
# kRhGQ_5rSDk
# CQzGrUDJDZg
# FLz1-rPqcqs
# yDxwtevkMYA
# JoVVN9Bubr8
# 2ny9u-qlxCs
# LvsO3y4cy50
# J3uTZSPSt44
# Z_P0TPE2kgg
# Y5geUXpIp3U
# H4zHK4By8hM
# tUGZHCyIM8g
# MhvRcRAhZzc
# 82Xn74NImjs
# g3UHcpMex7k
# sbRWkH5evZ8
# GcZkqpAA5QE
# XeS4PYyfXpY
# _GV3cNjAJpA
# mAwcpEcc38s
# N8ELFQl0L3g
# 46F-qD73tJE
# CX7ztDHdYbc
# SMRyasoZ3kk
# nCMOyOd2uAo
# BqiFKbo-NRg
# aE3ykYykR7E
# u_qdKsZw2EY
# z2yhoBWkR5s
# WR3DnVIB10M
# g-2gMeiKFsg
# WY9oZsuWqzE
# buQGz9FphT0
# LP1swyTWCcc
# nP0NpeU73FQ
# AwE05UsXIHI
# mMoR2atwOiU
# UpahDMF9Tek
# DoloyE_pGfY
# 3oyjA4GQx1g
# RPtEr5et4qc
# GotY7f0LVg0
# BeRsyOSomkk
# b7YD2dm9rWk
# MvExL0fMFdk
# KWpEQWQlU24
# B61EoBKTRv8
# 1hVaCS6DVEg
# 5ZjgVre5_WY
# v8JV_uO-hBU
# WuTeeiEHoYk
# vYgMWafQAL4
# z8YolcNGfdE
# jwOxNXREifo
# HzqVD4HzWk0
# e7Rm3wVb92Q
# M2N-U1tx3kw
# _Cie4GFu0f8
# Vx-XdwjNbl4
# 1cnUYychq6k
# JQ--1rrZRQE
# uQW_0v-9TIY
# ETw88C-SvXo
# Euw2EPkGVhA
# Cwr-4hCAM7k
# Sfj44L-tFTk
# crR_4jzUjCw
# lnhTvwNGVfk
# 4T_ERDsHkzc
# 50Vx8hkqcMY
# K-K24uIFYmY
# Wx9y2aN5wag
# nsWD2uq_q_Y
# _iWhAvqhFZ8
# ycqdsoeKyHo
# hRyXCZPnYhc
# UK3n3RN6tSQ
# 8i_IGwnC1q4
# 3ES7ulm8eAE
# 4XZBXq3MQjQ
# izGIlNVPrPc
# Dy_WhJ78SyA
# nEPknO1XN_k
# 9k5cQ4bcFQ8
# 8Yh6WfDH77w
# 0QxS_cbrQeE
# tNEjpV1dSyQ
# 3zpRwmPwJO8
# djGMI0Q2_ok
# Rd3Dnp9uLMc
# 8e2jeV-Wb6k
# zm8swEKvl_0
# mUv0wXgKoC0
# TiXGr8fmUe8
# rpGdHgDC-Js
# 90h2FZO-bIc
# OL9X_pJHw4g
# zPCqvTAKAUk
# Drazzv4m0n0
# zJabngpDVGs
# 3LRNH2d1FOg
# 5L88DK2tO8o
# C11HxVCipRA
# iIKqe26rgbo
# F7l5P0zszTs
# 2RZxJkZ_c80
# cfY3Z_asQ0o
# Be2OHvGu2ag
# IZSLCUL2bAI
# VEkUmC-qmpE
# b_OvRQzjKGQ
# fQp8qpDavhM
# GoRpzUj6lvc
# HPoExrxpTSo
# xGqgxN8Dfn4
# 2JC2PUgsv_Q
# Q8LZwK2CWIM
# QLB-h_sBVEQ
# DbnmI12T_Qg
# eulxVOO-nR8
# kbHwkuzeUPY
# mYBzJBtLoCM
# PyVIjI4mf78
# dsUhfAhx4I4
# xIDRdyrsYW0
# Wv-L5TTq0Vg
# pbIGkjUME9g
# lEKl2j3vQWI
# 5WkoogZT-GM
# A8xBR_hE5Os
# z2s-PgLAvVk
# DPNdwwPvpc4
# xmHoO-RaLxQ
# Vn9Q7yU6if8
# XHyX8d8khpY
# 1Ei5VA3vq2U
# sFE4Z8yYr5g
# RBmQ7Y0Kegs
# iEU7FK8ljM8
# M4FLyWEThTo
# Q8FVQahpeOA
# kqwct-TsqMA
# DR4tBRiTCvc
# UbNowFcJJIU
# 1D0WOic1Wm4
# FtRM5pfWxH8
# GVVgpacQrSI
# Dkg62MYTpsU
# zYdFO2vBu_U
# jSHvsDuslsc
# kOBdtSybOJY
# Zu1Dycwg66M
# oks9P2ORdIc
# qk4Et4Pz0yE
# sh9fNco7i_A
# omQ_wLd8dPg
# lWZHQ3HXoSI
# XMjZemTwE3E
# i88t25Q8wgQ
# 0z46ZJsDD8E
# cVU_-2UpYYc
# XC-BIboVmoY
# pd0dj2ryvu4
# XxuAyJeM-Bg
# Urt8yEu2ELA
# KcLT6UxXSJU
# 8xsQ_v2iK_w
# N6hDOMBl_60
# 5l4mlIFiaY0
# pjClbm90yAc
# EnYpCZRaTZs
# 0T8PflP4i2g
# tWQc4AC1BEg
# BcGsO-SpCWQ
# g9M_iYWDKfA
# CASDCt3PUJg
# SDla7erhAnA
# pEg3HIm01e4
# 8ZbxGNzBRCg
# AKAjEzI5n5U
# TPgTqTmYPoA
# xzHsgf3bnjc
# tYcWu4d8QWU
# 3Bf9tIPFlYQ
# AYXJHiEGbWo
# p3awf8ue5X0
# f4Pvjr0GEds
# gGkpIxEPK4k
# LYfw0YCxHZY
# 7SVEmoYB5-4
# JQn9WFWE2kw
# aChDSQNOS9Q
# XqlYdXG19Ws
# aT2FCTqn_Mk
# 4KcYLMiuWfM
# BPsNOeU-jWI
# -Gj-PHyrdbA
# 0mbv436NqEQ
# rH0O8OQtyTo
# v9Cks5rdpcA
# FWMD63nN1RY
# XjoheN_Pe3Q
# 2U3_fpTbfHw
# c7tBLItjQLc
# QrnbFPcAlRE
# ghyVOJvTqQw
# CH5HVZKDOjw
# OYf_mxfe5x4
# D6FaxKPoD4E
# hM1CMrbEF0Y
# bgvj5KH8O-g
# -P7bwMHmwUo
# nCKIDsmfx-o
# Xwl2eRl9edQ
# JpiaXnyvWZI
# tK8jGR3m5G0
# eFFtwf7x9Z8
# DxuBz_p6fRc
# iZoLUEr5K9s
# GLkoEdOPbSg
# 1nQsYetqsJQ
# 2mJwW1-kniQ
# 4VYGW1sgImE
# DBozlPMDlYQ
# 96HHDaINJ0c
# FZiT09VXTFM
# YNgxGQaVAa8
# x4_BiTCFunk
# nlM1NXM_3P0
# wiMH3tBK7Ek
# OrjpKhOU_hI
# j3Kn9L8QpYM
# hf5BY_vrTTo
# zTGxuCJenRM
# vzhJY4Zh7b0
# 1JTCGS6-VzY
# QAQRv1D9KyQ
# rf0qsFjb7fg
# 8EDoQlTOyEE
# tyTjVgmuQt4
# qhFi0QRbp8M
# fsbtwEppBc8
# 92GiQzCoGCc
# 3IqFK5vQPXc
# J0EfiOvOEgw
# kfUb60GKL8Q
# VvdssiRzUWc
# lS0x5ReHJpY
# uEv0iqnlpXE
# WOoX7Mo1DWE
# cpNAliO92dI
# JlGQ42zmt-M
# CtwbMInrRV8
# PyVL-0mXmfs
# 1KcNzXeLiik
# ossx9sW9S3k
# EtWd0VPkRXw
# 4rAe6rraRmE
# x7c6e1vEIrE
# h17TkOuBdNI
# tSk2k6DSwPY
# fhPFpoMwQc4
# x5I9MK_-O4U
# diXn5H-43Vw
# DNIzuUgGucw
# D0l7G65WaRI
# bADutdlO35Q
# C8ZnAenuyH8
# i_eyU1ebgas
# 8-Kd4dTqdkk
# 9dbxc9a6o8U
# u1tO1zdiRXc
# kTU2878_xv8
# DNaN30vkXE4
# 0hH7AKx4X3s
# wssOe_cU6Go
# Au2bbW7dzW8
# ACkm1q4TqN0
# W9luF3xcHfs
# hOTTfE_CaM4
# NZq4AadVWiw
# DQ3uPEzeT0g
# bK_kfh8vIbI
# DpXmX3eI9tc
# mY2D9TQEvxo
# WhHJUoCrGKs
# giYT6Q64TlI
# piCeN0_pjDs
# syIZW4LzbFY
# J58E8W3EoXI
# wSLuS6YOwrs
# Q6sZlIc2v2Q
# hbxR81fJoec
# h4uIy_YSwao
# V8yyWzhtkQ4
# A8gHGgD3H1M
# pqML9AHtDFg
# 6N35c-f7uws
# 05-LLQiEtjs
# JQ8xWuvBuq0
# Siol7hEg7zI
# vwUbG--8Shc
# ZW6Y0fE1nq8
# heinnAVAhTA
# lOYTzLozgKI
# fL2asXnTiL4

# %%
main_df[main_df["id"] == "fyvEDS-PQO8"]
# Out:
#                    id                 title  duration  view_count  \
# 16753897  fyvEDS-PQO8  404 (FILE NOT FOUND)       368        19.0
# 18029445  fyvEDS-PQO8  404 (FILE NOT FOUND)       368        19.0
#
#               categories  comment_count  like_count channel  \
# 16753897  People & Blogs            1.0         2.0    Nubz
# 18029445  People & Blogs            1.0         2.0    Nubz
#
#                         channel_id  channel_follower_count  ...     abr  \
# 16753897  UCVlYKhbTiO8TT6fRD-aY6vw                    53.0  ...  125.77
# 18029445  UCVlYKhbTiO8TT6fRD-aY6vw                    53.0  ...  125.77
#
#              vbr         vcodec      asr audio_channels chapters  \
# 16753897  125.77  vp09.00.50.08  48000.0            2.0     None
# 18029445  125.77  vp09.00.50.08  48000.0            2.0     None
#
#          manual_caption_languages  automatic_caption_orig_language  location  \
# 16753897                    en-GB                               en      None
# 18029445                    en-GB                               en      None
#
#           license
# 16753897     None
# 18029445     None
#
# [2 rows x 34 columns]

# %% [markdown]
# ### Getting information on remaining to download

# %% [markdown]
# #### Getting approximately English data to download (2nd round)
# - Conditions used to get approximately English data (union):
#     1. manual_caption_languages must only contain `en` or variants of `en`
#     2. in the complement set of 1., manual_caption_languages must contain at least `en` or variants of `en`
#
#         3. in this set, language == `en`
# - UPDATE: 11/5/2024
#     - These are conditions that lead to bad eval performance. That could mean there could be more filtering to get higher quality data. For now, we use a subset from this and do more data filtering to train.

# %%
with open("logs/data/download/2M_en/2M_download_ids.txt", "r") as f:
    id_downloaded = [line.strip().split("\t")[0] for line in f]
print(id_downloaded[:5])
print(len(id_downloaded))
# Out:
# ['05xOF5ubabQ', 'GjTPw_aQmgg', 'T9_3s_yybq8', 'nKZSV-h0SGA', '3993tVeKd-w']
# 2448500

# %%
all_ids = set(main_df_dedup['id'])
downloaded_ids = set(id_downloaded)

not_downloaded_ids = all_ids - downloaded_ids

not_downloaded_df = main_df_dedup[main_df_dedup['id'].isin(not_downloaded_ids)]

# %%
not_downloaded_df.reset_index(drop=True, inplace=True)

# %%
view_lang_cols(not_downloaded_df)
# Out:
#             id                           title language  \
# 0  LwJv3vSd8no             Free Art Wednesday!       en
# 1  XXjYyBCNJEY              FREE Art Wednesday     None
# 2  OREjUtUT2Sc  New Intro | I keep losing them     None
# 3  cNPxiPUdyvA      (Примьера дораммы 2021!!!)     None
# 4  2XitiLKk6rM              Анонимки в тик ток       ru
#
#   manual_caption_languages automatic_caption_orig_language
# 0                       en                              en
# 1                       en                              en
# 2                       en                              en
# 3                       sv                              sv
# 4                       sv                              ru

# %%
print(not_downloaded_df.shape[0])
# Out:
# 57649651

# %%
clean_not_downloaded_df = clean_df(not_downloaded_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language

# %%
clean_not_downloaded_df.head()
# Out:
#             id                           title  duration  view_count  \
# 0  LwJv3vSd8no             Free Art Wednesday!       372       378.0
# 1  XXjYyBCNJEY              FREE Art Wednesday       293       194.0
# 2  OREjUtUT2Sc  New Intro | I keep losing them        11        39.0
# 3  cNPxiPUdyvA      (Примьера дораммы 2021!!!)        20        29.0
# 4  2XitiLKk6rM              Анонимки в тик ток       102       578.0
#
#        categories  comment_count  like_count       channel  \
# 0  People & Blogs          175.0        70.0         Wajas
# 1  People & Blogs           69.0        48.0         Wajas
# 2  People & Blogs            3.0         9.0  Sade Royalty
# 3  People & Blogs            NaN         5.0         Overk
# 4  People & Blogs            3.0        17.0         Overk
#
#                  channel_id  channel_follower_count  ...      abr      vbr  \
# 0  UCrfdGNBnkDd0rOh1M9mdmaQ                  1680.0  ...  120.177  120.177
# 1  UCrfdGNBnkDd0rOh1M9mdmaQ                  1680.0  ...  129.700  129.700
# 2  UCE_3_c7b769PCiS1iqc1APw                   363.0  ...  158.206  158.206
# 3  UCOxiCFiOYLUgPCtdcDZiK5A                    12.0  ...  129.293  129.293
# 4  UCOxiCFiOYLUgPCtdcDZiK5A                    12.0  ...  121.210  121.210
#
#                          vcodec      asr audio_channels chapters  \
# 0                           vp9  48000.0            2.0     None
# 1                           vp9  48000.0            2.0     None
# 2                           vp9  48000.0            2.0     None
# 3                           vp9  48000.0            2.0     None
# 4  vp09.00.21.08.01.05.01.06.00  48000.0            2.0     None
#
#   manual_caption_languages  automatic_caption_orig_language  location  license
# 0                       en                               en      None     None
# 1                       en                               en      None     None
# 2                       en                               en      None     None
# 3                       sv                               sv      None     None
# 4                       sv                               ru      None     None
#
# [5 rows x 34 columns]

# %%
view_lang_cols(clean_not_downloaded_df)
# Out:
#             id                           title manual_caption_languages  \
# 0  LwJv3vSd8no             Free Art Wednesday!                       en
# 1  XXjYyBCNJEY              FREE Art Wednesday                       en
# 2  OREjUtUT2Sc  New Intro | I keep losing them                       en
# 3  cNPxiPUdyvA      (Примьера дораммы 2021!!!)                       sv
# 4  2XitiLKk6rM              Анонимки в тик ток                       sv
#
#   automatic_caption_orig_language language
# 0                              en       en
# 1                              en
# 2                              en
# 3                              sv
# 4                              ru       ru

# %% [markdown]
# ##### First condition

# %%
condition = (
        clean_not_downloaded_df["manual_caption_languages"]
        .str.split(",")
        .apply(lambda lst: set(lst) == {"en"})
    )
only_en_1 = clean_not_downloaded_df[condition]

# %%
only_en_1.shape[0]
# Out:
# 25507801

# %%
not_only_en_1_id = set(clean_not_downloaded_df["id"]) - set(only_en_1["id"])
len(not_only_en_1_id)
# Out:
# 32141850

# %% [markdown]
# ##### Second condition

# %%
not_only_en_1 = clean_not_downloaded_df[clean_not_downloaded_df["id"].isin(not_only_en_1_id)]

# %%
view_lang_cols(not_only_en_1)
# Out:
#             id                                  title  \
# 3  cNPxiPUdyvA             (Примьера дораммы 2021!!!)
# 4  2XitiLKk6rM                     Анонимки в тик ток
# 5  IPxXLQpOJRU                          Marisa Marisa
# 6  ug5TkquQEHo                          Marisa marisa
# 7  Ar-XwEnnFPY  Formation des Classe D | Serveur UPRP
#
#   manual_caption_languages automatic_caption_orig_language language
# 3                       sv                              sv
# 4                       sv                              ru       ru
# 5                       it                              it
# 6                       it                              it
# 7                       fr                              fr       fr

# %%
get_num_rows(not_only_en_1)
# Out:
# 32141850

# %%
view_lang_cols(not_only_en_1[not_only_en_1["language"] == "en"], 20)
# Out:
#               id                                              title  \
# 75   qVlXu1zanWE                               【游玩克拉普】 平常小方块怎么测试声音的
# 99   1f14oKd9jx8  Meet Don - Direct Express cardholder & PayPerk...
# 100  SK6ngqjyp8E  Meet Helen (Part 2) - Financial Capability wit...
# 101  Wssea1xQJBE  Meet Helen (Part 1) - Convenience, Safety & Se...
# 102  OjjMLrhBkSk  Meet Ray: Direct Express Cardholder & PayPerks...
# 103  zicChYIBtIw  Direct Express Cardholder & PayPerks User Prof...
# 104  6KsSZFDkwJ4  Meet Dawn - Direct Express Cardholder & PayPer...
# 181  AxmibPoLlvo                              [𝐏𝐋𝐀𝐘𝐋𝐈𝐒𝐓] 일렁이는 여름 햇살
# 280  wboahvmJHyU  Resident Evil Revelations 2 - Trailer Oficial ...
# 281  p_GO0YcfN4M  Resident Evil Revelations 2 - Trailer Oficial ...
# 283  GszPk3jAqck                  แกงฟักทองหอมใบเตยแบบ โบร๊าณ โบราณ
# 284  BadVeuJ6h1E                              Short history of Rome
# 327  3jsjeyAOmEs  Capt  Steve Neal (Ret.)  WRIC Naked Man Shot o...
# 328  59UHgUKNfTk  Capt  Steve Neal Ret  WRIC Graduation Safety S...
# 368  G3neEq6-ZWk       Talking To The Moon cover by (Arthur Miguel)
# 439  O1ebCIhPopw  Unboxing and Album Tour "IM NAYEON" NAYEON 1st...
# 532  w_MhP2dmxf8  explaining my three year toxic relationship. s...
# 547  4khB0ZyEhVM                             DFAT-CSIRO partnership
# 571  uWWBF5S-UHE                      送給被生活壓垮的你⋯ 《Burnt out》(audio)
# 665  stIDKDUA-Xs                         Panty Bleaching Gone Viral
#
#     manual_caption_languages automatic_caption_orig_language language
# 75                        zh                              en       en
# 99                     en,es                              en       en
# 100                    en,es                              en       en
# 101                    en,es                              en       en
# 102                    en,es                              en       en
# 103                    en,es                              en       en
# 104                    en,es                              en       en
# 181                       ko                              en       en
# 280                       pt                              en       en
# 281                       pt                              en       en
# 283                       th                              en       en
# 284                       sr                              en       en
# 327                      und                              en       en
# 328                      und                              en       en
# 368                      fil                              en       en
# 439                      fil                              en       en
# 532                       fr                              en       en
# 547                    en,vi                              en       en
# 571             live_chat,zh                              en       en
# 665             en,live_chat                              en       en

# %%
get_num_rows(not_only_en_1[not_only_en_1["language"] == "en"])
# Out:
# 4070589

# %%
view_lang_cols(not_only_en_1[not_only_en_1["manual_caption_languages"].str.contains("en")], 20)
# Out:
#               id                                              title  \
# 11   hWQZq0wHIwQ                           rimne - First Color / MV
# 19   4w-OpSyV5dw            Sangat Sedap | Semua Pasti Menyukainya!
# 21   JiHuFJ9RoHM  DEI UMA PASSADA NO CANADÁ ANTES DE IR PARA O B...
# 22   YhPHqdGcCQ4  MINHA COLEÇÃO INTEIRA DA SUPERESTRELA DA NBA, ...
# 23   zwPpeXqHsZs  JOGUEI O NBA 2K23 (PS4) CURRENT GEN PELA PRIME...
# 24   VdlUZgEL1Qs  JOGUEI BASQUETE COM OS GRINGOS EM UMA QUADRA A...
# 56   9wY84F2-aUQ  DOĞADA HAYAT 44.BÖLÜM |  LİFE İN NATURE EPİSOD...
# 90   so8TfVlMuVs  COMING SEPT 2021 - NEW MUSIC FROM "CUSTOM"! - ...
# 92   OFZyHn-GP48                                Control Z - bad guy
# 99   1f14oKd9jx8  Meet Don - Direct Express cardholder & PayPerk...
# 100  SK6ngqjyp8E  Meet Helen (Part 2) - Financial Capability wit...
# 101  Wssea1xQJBE  Meet Helen (Part 1) - Convenience, Safety & Se...
# 102  OjjMLrhBkSk  Meet Ray: Direct Express Cardholder & PayPerks...
# 103  zicChYIBtIw  Direct Express Cardholder & PayPerks User Prof...
# 104  6KsSZFDkwJ4  Meet Dawn - Direct Express Cardholder & PayPer...
# 106  SI7nWeZJsaE  अब रोबोट पुलिस करेगी अपराधियों का एनकाउंटर/Now...
# 107  -ruaKTKQuvM  Ayam Penyet Cheese & Kambing Bakar Madu - Menu...
# 108  AbEu5_Rn7P4  Kopi 434 - Jenama Kopi PADU Dari Muar! (ENG SUBS)
# 109  bYbhnr-aQ6o  "Pernah Jual Keropok Lekor Tepi Jalan, Payung ...
# 110  TTPbel0c3Qk  Roti John Western Cheese Tarik Paling Dahsyat ...
#
#     manual_caption_languages automatic_caption_orig_language language
# 11                     en,ja                         unknown
# 19           en,live_chat,ms                         unknown
# 21                     en,pt                              pt       pt
# 22                     en,pt                              pt       pt
# 23                     en,pt                         unknown
# 24                     en,pt                              pt       pt
# 56                  en,ko,ur                              tr       tr
# 90              en,live_chat                              en
# 92                  en,es,pt                         unknown
# 99                     en,es                              en       en
# 100                    en,es                              en       en
# 101                    en,es                              en       en
# 102                    en,es                              en       en
# 103                    en,es                              en       en
# 104                    en,es                              en       en
# 106                    en,hi                              hi       hi
# 107                    en,ms                         unknown
# 108                    en,ms                         unknown
# 109                    en,ms                         unknown
# 110                    en,ms                         unknown

# %%
# second condition set here
only_en_2 = not_only_en_1[not_only_en_1["manual_caption_languages"].str.contains("en")]

# %%
only_en_2.shape[0]
# Out:
# 9991767

# %% [markdown]
# ##### Third condition

# %%
view_lang_cols(only_en_2[only_en_2["language"] == "en"], 20)
# Out:
#                id                                              title  \
# 99    1f14oKd9jx8  Meet Don - Direct Express cardholder & PayPerk...
# 100   SK6ngqjyp8E  Meet Helen (Part 2) - Financial Capability wit...
# 101   Wssea1xQJBE  Meet Helen (Part 1) - Convenience, Safety & Se...
# 102   OjjMLrhBkSk  Meet Ray: Direct Express Cardholder & PayPerks...
# 103   zicChYIBtIw  Direct Express Cardholder & PayPerks User Prof...
# 104   6KsSZFDkwJ4  Meet Dawn - Direct Express Cardholder & PayPer...
# 547   4khB0ZyEhVM                             DFAT-CSIRO partnership
# 665   stIDKDUA-Xs                         Panty Bleaching Gone Viral
# 696   1G1Fv0oGcpM             Adding subtitles using Chromebook only
# 750   LeXguFYox0o  ENTREVISTA | Neil Newbon, dublador de Nicholai...
# 767   VSa8tQ4umrA                                           Among us
# 854   PiOkO0yKL6s                      Katolik bukan menyembah Maria
# 903   _UsoeCHeBRM                             Who is the antichrist?
# 925   KO6P3mzJ8Q8  Sandwich Ikan Hanyir + Jus Jeruk Kobis Masam G...
# 1023  e9aHLwWbTXk  ENTREVISTA | Jolene Andersen, dubladora de Ada...
# 1083  MZIobSwlDNc  [cafe vlog] 취미부터 창업까지, 베이킹 클래스 오픈 브이로그 | Bakin...
# 1143  1LyApwguwcA  【Kitchen Construction 廚房工程全記錄】Clarence Hong Ko...
# 1176  nlD3u_MZ_oM  ENTREVISTA | Nicole Tompkins, dubladora de Jil...
# 1178  rlCTN-n4q7w  ENTREVISTA | Jeff Schine, dublador de Carlos O...
# 1180  ask0_XubD2k  VINHETA | Nicole Tompkins, dubladora de Jill V...
#
#                     manual_caption_languages automatic_caption_orig_language  \
# 99                                     en,es                              en
# 100                                    en,es                              en
# 101                                    en,es                              en
# 102                                    en,es                              en
# 103                                    en,es                              en
# 104                                    en,es                              en
# 547                                    en,vi                              en
# 665                             en,live_chat                              en
# 696                                    de,en                              en
# 750                                    en,pt                              en
# 767                                    ba,en                              en
# 854                                    en,ms                              en
# 903                             en,live_chat                              en
# 925                                    en,ms                              en
# 1023                                   en,pt                              en
# 1083  de,en,es,fr,id,it,ja,pt,ru,th,vi,zh,zh                              en
# 1143                                   en,zh                              en
# 1176                                   en,pt                              en
# 1178                                   en,pt                              en
# 1180                                   en,pt                              en
#
#      language
# 99         en
# 100        en
# 101        en
# 102        en
# 103        en
# 104        en
# 547        en
# 665        en
# 696        en
# 750        en
# 767        en
# 854        en
# 903        en
# 925        en
# 1023       en
# 1083       en
# 1143       en
# 1176       en
# 1178       en
# 1180       en

# %%
get_num_rows(only_en_2[only_en_2["language"] == "en"])
# Out:
# 1933919

# %%
(only_en_2[only_en_2["language"] == "en"]["automatic_caption_orig_language"] == "").sum() / len(only_en_2[only_en_2["language"] == "en"])
# Out:
# 0.0011768848643609168

# %%
view_lang_cols(only_en_2[only_en_2["automatic_caption_orig_language"] == "en"], 20)
# Out:
#                id                                              title  \
# 90    so8TfVlMuVs  COMING SEPT 2021 - NEW MUSIC FROM "CUSTOM"! - ...
# 99    1f14oKd9jx8  Meet Don - Direct Express cardholder & PayPerk...
# 100   SK6ngqjyp8E  Meet Helen (Part 2) - Financial Capability wit...
# 101   Wssea1xQJBE  Meet Helen (Part 1) - Convenience, Safety & Se...
# 102   OjjMLrhBkSk  Meet Ray: Direct Express Cardholder & PayPerks...
# 103   zicChYIBtIw  Direct Express Cardholder & PayPerks User Prof...
# 104   6KsSZFDkwJ4  Meet Dawn - Direct Express Cardholder & PayPer...
# 433   tFtImC8E0wY  My Heart And Seoul 😍 | 15 Days Around Seoul - ...
# 547   4khB0ZyEhVM                             DFAT-CSIRO partnership
# 665   stIDKDUA-Xs                         Panty Bleaching Gone Viral
# 696   1G1Fv0oGcpM             Adding subtitles using Chromebook only
# 750   LeXguFYox0o  ENTREVISTA | Neil Newbon, dublador de Nicholai...
# 767   VSa8tQ4umrA                                           Among us
# 854   PiOkO0yKL6s                      Katolik bukan menyembah Maria
# 865   -2auYFne_l0  Adventures of Zalke West : Tenerife Part II - ...
# 866   dM2FwfPBC2A  Adventures of Zalke West: Tenerife Part I - Teide
# 903   _UsoeCHeBRM                             Who is the antichrist?
# 925   KO6P3mzJ8Q8  Sandwich Ikan Hanyir + Jus Jeruk Kobis Masam G...
# 1023  e9aHLwWbTXk  ENTREVISTA | Jolene Andersen, dubladora de Ada...
# 1083  MZIobSwlDNc  [cafe vlog] 취미부터 창업까지, 베이킹 클래스 오픈 브이로그 | Bakin...
#
#                     manual_caption_languages automatic_caption_orig_language  \
# 90                              en,live_chat                              en
# 99                                     en,es                              en
# 100                                    en,es                              en
# 101                                    en,es                              en
# 102                                    en,es                              en
# 103                                    en,es                              en
# 104                                    en,es                              en
# 433                             en,live_chat                              en
# 547                                    en,vi                              en
# 665                             en,live_chat                              en
# 696                                    de,en                              en
# 750                                    en,pt                              en
# 767                                    ba,en                              en
# 854                                    en,ms                              en
# 865                             en,live_chat                              en
# 866                             en,live_chat                              en
# 903                             en,live_chat                              en
# 925                                    en,ms                              en
# 1023                                   en,pt                              en
# 1083  de,en,es,fr,id,it,ja,pt,ru,th,vi,zh,zh                              en
#
#      language
# 90
# 99         en
# 100        en
# 101        en
# 102        en
# 103        en
# 104        en
# 433
# 547        en
# 665        en
# 696        en
# 750        en
# 767        en
# 854        en
# 865
# 866
# 903        en
# 925        en
# 1023       en
# 1083       en

# %%
get_num_rows(only_en_2[only_en_2["automatic_caption_orig_language"] == "en"])
# Out:
# 1980299

# %%
view_lang_cols(only_en_2[(only_en_2["automatic_caption_orig_language"] == "en") & (only_en_2["language"] == "en")], 20)
# Out:
#                id                                              title  \
# 99    1f14oKd9jx8  Meet Don - Direct Express cardholder & PayPerk...
# 100   SK6ngqjyp8E  Meet Helen (Part 2) - Financial Capability wit...
# 101   Wssea1xQJBE  Meet Helen (Part 1) - Convenience, Safety & Se...
# 102   OjjMLrhBkSk  Meet Ray: Direct Express Cardholder & PayPerks...
# 103   zicChYIBtIw  Direct Express Cardholder & PayPerks User Prof...
# 104   6KsSZFDkwJ4  Meet Dawn - Direct Express Cardholder & PayPer...
# 547   4khB0ZyEhVM                             DFAT-CSIRO partnership
# 665   stIDKDUA-Xs                         Panty Bleaching Gone Viral
# 696   1G1Fv0oGcpM             Adding subtitles using Chromebook only
# 750   LeXguFYox0o  ENTREVISTA | Neil Newbon, dublador de Nicholai...
# 767   VSa8tQ4umrA                                           Among us
# 854   PiOkO0yKL6s                      Katolik bukan menyembah Maria
# 903   _UsoeCHeBRM                             Who is the antichrist?
# 925   KO6P3mzJ8Q8  Sandwich Ikan Hanyir + Jus Jeruk Kobis Masam G...
# 1023  e9aHLwWbTXk  ENTREVISTA | Jolene Andersen, dubladora de Ada...
# 1083  MZIobSwlDNc  [cafe vlog] 취미부터 창업까지, 베이킹 클래스 오픈 브이로그 | Bakin...
# 1143  1LyApwguwcA  【Kitchen Construction 廚房工程全記錄】Clarence Hong Ko...
# 1176  nlD3u_MZ_oM  ENTREVISTA | Nicole Tompkins, dubladora de Jil...
# 1178  rlCTN-n4q7w  ENTREVISTA | Jeff Schine, dublador de Carlos O...
# 1180  ask0_XubD2k  VINHETA | Nicole Tompkins, dubladora de Jill V...
#
#                     manual_caption_languages automatic_caption_orig_language  \
# 99                                     en,es                              en
# 100                                    en,es                              en
# 101                                    en,es                              en
# 102                                    en,es                              en
# 103                                    en,es                              en
# 104                                    en,es                              en
# 547                                    en,vi                              en
# 665                             en,live_chat                              en
# 696                                    de,en                              en
# 750                                    en,pt                              en
# 767                                    ba,en                              en
# 854                                    en,ms                              en
# 903                             en,live_chat                              en
# 925                                    en,ms                              en
# 1023                                   en,pt                              en
# 1083  de,en,es,fr,id,it,ja,pt,ru,th,vi,zh,zh                              en
# 1143                                   en,zh                              en
# 1176                                   en,pt                              en
# 1178                                   en,pt                              en
# 1180                                   en,pt                              en
#
#      language
# 99         en
# 100        en
# 101        en
# 102        en
# 103        en
# 104        en
# 547        en
# 665        en
# 696        en
# 750        en
# 767        en
# 854        en
# 903        en
# 925        en
# 1023       en
# 1083       en
# 1143       en
# 1176       en
# 1178       en
# 1180       en

# %%
get_num_rows(only_en_2[(only_en_2["automatic_caption_orig_language"] == "en") & (only_en_2["language"] == "en")])
# Out:
# 1930688

# %%
lang_en = only_en_2[only_en_2["language"] == "en"]
auto_lang_en = only_en_2[only_en_2["automatic_caption_orig_language"] == "en"]
lang_en_auto_lang_en = only_en_2[(only_en_2["automatic_caption_orig_language"] == "en") & (only_en_2["language"] == "en")]

# %%
lang_en.shape[0], auto_lang_en.shape[0], lang_en_auto_lang_en.shape[0]
# Out:
# (1933919, 1980299, 1930688)

# %%
temp = set(lang_en["id"]) - set(lang_en_auto_lang_en["id"])
temp_df_2 = lang_en[lang_en["id"].isin(temp)]
view_lang_cols(temp_df_2, 20)
# Out:
#                  id                                              title  \
# 30378   VHOvLOPVxX8                  noc18-me62-Lec 02B-Instrument -II
# 38783   M56GMKXRE7c  🥥❤️ Sadece 3 Malzemeyle Yapabileceğiniz En Güz...
# 59528   34iDTeCNTz4  Simulating color vision deficiencies in the Bl...
# 123890  Wn_1Egqrq9o  Crazy Speed Eating Challenge w/ Rosanna | Copy...
# 123891  RZsb2O2ndCk  Transforming 3 YouTubers into Contortionists |...
# 219529  Np8GMBsUiv8    L'Italien | Policier | Film complet en français
# 219532  J-t9WP_Gl_I  N'embrasse pas la mariée | Comédie, Action | F...
# 219533  CWKZetMHzO8    Ultime Combat (Action) Film complet en français
# 220580  V9JSRHVuLBE  Petite Princesse | Classique | Film complet en...
# 220584  dZPEVh0PWAU  Last Apocalypse | Action | Film complet en fra...
# 220767  Hg9SlI_akI8  Action Movie | Black Belt Angels (1994) | Shaw...
# 220770  ebmWoXYGyPg  La revanche d'un pistolero | Western, Jack Nic...
# 220771  z_Kw9uVyy-g  La Nuit de tous les Mystères | Thriller | Film...
# 220773  d15Fhz3LtSg  Le bistouri de la mafia blanche | Policier | F...
# 220774  5uTTj6DWjSc  Le Fier Rebelle (Western Américain) Film compl...
# 220775  hfBjJXrBdnM  Le Château de la Terreur | Thriller | Film com...
# 220777  owQit9hUNAo  L'homme par qui la vengeance arrive (1970) Wes...
# 220778  ICc2Fz5PDL8  Charade : Trois maris plutôt qu'une veuve | Ro...
# 222058  ra5JMrjy5a4  John Wayne | McLintock! (1963) Western, Comédi...
# 222060  HRewjfpMmOI  Jared Leto | Chapitre 27 (Thriller, Histoire v...
#
#                                  manual_caption_languages  \
# 30378                       bn,en,en,gu,hi,kn,ml,mr,ta,te
# 38783   ar,az,bg,bn,bs,cs,da,de,el,en,es,fa,fi,fil,fr,...
# 59528                                               en,nl
# 123890                                              en,es
# 123891                                              en,es
# 219529  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
# 219532  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
# 219533  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
# 220580  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
# 220584  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
# 220767  ar,de,en,es,fa,fr,hi,hu,id,ja,no,pt,ro,ru,sr,s...
# 220770  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
# 220771  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
# 220773  ar,de,el,en,es,fa,fil,fr,fr,hi,hu,id,it,iw,ja,...
# 220774  ar,bg,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,...
# 220775  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
# 220777  ar,de,el,en,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,...
# 220778  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
# 222058  ar,bg,da,de,el,en,es,fa,fi,fil,fr,hi,hr,hu,id,...
# 222060  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
#
#        automatic_caption_orig_language language
# 30378                                        en
# 38783                                        en
# 59528                               nl       en
# 123890                                       en
# 123891                                       en
# 219529                              fr       en
# 219532                                       en
# 219533                                       en
# 220580                         unknown       en
# 220584                                       en
# 220767                                       en
# 220770                                       en
# 220771                                       en
# 220773                                       en
# 220774                                       en
# 220775                                       en
# 220777                                       en
# 220778                                       en
# 222058                              fr       en
# 222060                              fr       en

# %%
temp_1 = set(auto_lang_en["id"]) - set(lang_en_auto_lang_en["id"])
temp_df_3 = auto_lang_en[auto_lang_en["id"].isin(temp_1)]
view_lang_cols(temp_df_3, 20)
# Out:
#                id                                              title  \
# 90    so8TfVlMuVs  COMING SEPT 2021 - NEW MUSIC FROM "CUSTOM"! - ...
# 433   tFtImC8E0wY  My Heart And Seoul 😍 | 15 Days Around Seoul - ...
# 865   -2auYFne_l0  Adventures of Zalke West : Tenerife Part II - ...
# 866   dM2FwfPBC2A  Adventures of Zalke West: Tenerife Part I - Teide
# 1511  4cz74eJittA  20 Days in CA Exam | Must Cover these things! ...
# 8014  C3oJo-J3lTo  Setting Up Our Christmas Tree 2021 ft. Rayan &...
# 8015  cMOHF0BWKTw  400 to 1000 Rs Kurti Shopping | Meesho Haul | ...
# 8016  VDWdvB8JYVs  Fun Baking Cookies with Rayan 👩‍🍳😎🧒 | Cooking ...
# 8017  tNpSQure4iA  5000 Rupees For A Lunch 😵 | Most Expensive Res...
# 8018  HPY1tat23pI  Masala Chowk Street Food Review 😋♥️ | Jaipur S...
# 8019  Oytplrjbw_Q  Jaipur Street Shopping 🛒🛍| Bapu Bazar | Shoppi...
# 8020  1TjecnoE5os  Samyuktha's Wardrobe Tour 👗💃 | New Dress Colle...
# 8021  q-Xa3pJ32S8  My Trip to Jaipur 😍 🤳| Travel Diaries 🛩 | Samy...
# 8023  -4Q5qDL12fQ  My Kerala Garden Tour ☘️🏡🌱  | Small Space Home...
# 8024  u0oTXU5EojU  Rayan Birthday Celebration 😍🎉🥳| Rio & Jithen R...
# 8157  wPgGlEqMXQ8            Как кормить попугая зеленью? Как часто?
# 8534  ZcACqSivyn8  What's in My Makeup Bag ft. Samyuktha | Makeup...
# 8535  UkA4q85T4U4  Rowdy Baby Dance Workout with Samyuktha | Samy...
# 8536  SN0njFCH3b4          Samyuktha's Kitchen Tour | Samyuktha Shan
# 8537  Zn53stiG9Ds  What's Inside My Fridge?🍟🍕 ft. Samyuktha | Fri...
#
#      manual_caption_languages automatic_caption_orig_language language
# 90               en,live_chat                              en
# 433              en,live_chat                              en
# 865              en,live_chat                              en
# 866              en,live_chat                              en
# 1511             en,live_chat                              en
# 8014             en,live_chat                              en
# 8015             en,live_chat                              en
# 8016             en,live_chat                              en
# 8017             en,live_chat                              en
# 8018             en,live_chat                              en
# 8019             en,live_chat                              en
# 8020             en,live_chat                              en
# 8021             en,live_chat                              en
# 8023             en,live_chat                              en
# 8024             en,live_chat                              en
# 8157             en,live_chat                              en
# 8534             en,live_chat                              en
# 8535             en,live_chat                              en
# 8536             en,live_chat                              en
# 8537             en,live_chat                              en

# %%
any_lang_en_id = set(lang_en["id"].tolist() + auto_lang_en["id"].tolist() + lang_en_auto_lang_en["id"].tolist())
temp_2 = set(only_en_2["id"]) - any_lang_en_id
temp_df_4 = only_en_2[only_en_2["id"].isin(temp_2)]
view_lang_cols(temp_df_4, 20)
# Out:
#               id                                              title  \
# 11   hWQZq0wHIwQ                           rimne - First Color / MV
# 19   4w-OpSyV5dw            Sangat Sedap | Semua Pasti Menyukainya!
# 21   JiHuFJ9RoHM  DEI UMA PASSADA NO CANADÁ ANTES DE IR PARA O B...
# 22   YhPHqdGcCQ4  MINHA COLEÇÃO INTEIRA DA SUPERESTRELA DA NBA, ...
# 23   zwPpeXqHsZs  JOGUEI O NBA 2K23 (PS4) CURRENT GEN PELA PRIME...
# 24   VdlUZgEL1Qs  JOGUEI BASQUETE COM OS GRINGOS EM UMA QUADRA A...
# 56   9wY84F2-aUQ  DOĞADA HAYAT 44.BÖLÜM |  LİFE İN NATURE EPİSOD...
# 92   OFZyHn-GP48                                Control Z - bad guy
# 106  SI7nWeZJsaE  अब रोबोट पुलिस करेगी अपराधियों का एनकाउंटर/Now...
# 107  -ruaKTKQuvM  Ayam Penyet Cheese & Kambing Bakar Madu - Menu...
# 108  AbEu5_Rn7P4  Kopi 434 - Jenama Kopi PADU Dari Muar! (ENG SUBS)
# 109  bYbhnr-aQ6o  "Pernah Jual Keropok Lekor Tepi Jalan, Payung ...
# 110  TTPbel0c3Qk  Roti John Western Cheese Tarik Paling Dahsyat ...
# 111  A2lbnq1_ma8  Bertarung Untuk Pasang ANDA SEAT! Gaming Chair...
# 112  HmMeWO8lPuo  Melantak Thai Food Sampai Lebam Di Soi 55 Thai...
# 113  wDVOnlvcEM4  Aku Ketagih Makan Kerepek Belinjo! 👨🏼 | Belinj...
# 114  Uj51y43wPcM  Berhabis RM3++ Makan Di Beard Brothers BBQ | B...
# 115  UiWrPNGTp0Q  Tealive Buat Flavour 'Mercun' Pop Pop?! (ENG S...
# 116  tjNoXLmB92Y  Kasi Hirup Sampai Licin! Spicy Ramen TERPADU D...
# 145  _1Nt7LgUc4Q  KISAH MISTIS PENJUAL BUAH-BUAHAN YANG MELAKUKA...
#
#     manual_caption_languages automatic_caption_orig_language language
# 11                     en,ja                         unknown
# 19           en,live_chat,ms                         unknown
# 21                     en,pt                              pt       pt
# 22                     en,pt                              pt       pt
# 23                     en,pt                         unknown
# 24                     en,pt                              pt       pt
# 56                  en,ko,ur                              tr       tr
# 92                  en,es,pt                         unknown
# 106                    en,hi                              hi       hi
# 107                    en,ms                         unknown
# 108                    en,ms                         unknown
# 109                    en,ms                         unknown
# 110                    en,ms                         unknown
# 111                    en,ms                         unknown
# 112                    en,ms                         unknown
# 113                    en,ms                         unknown
# 114                    en,ms                         unknown
# 115                    en,ms                         unknown
# 116                    en,ms                         unknown
# 145        en,en,en,id,tk,tr                              id       id

# %% [markdown]
# ##### Filter fully established here

# %%
en_ids = set(only_en_1["id"].tolist() + lang_en["id"].tolist() + lang_en_auto_lang_en["id"].tolist())
len(en_ids)
# Out:
# 27441720

# %%
approx_en_only = list(en_ids) + id_downloaded
len(approx_en_only)
# Out:
# 29890220

# %%
with open("data/metadata/approx_en_only.txt", "w") as f:
    for video_id in approx_en_only:
        f.write(video_id + "\n")

# %%
en_not_downloaded_df = not_downloaded_df[not_downloaded_df["id"].isin(en_ids)]
view_lang_cols(en_not_downloaded_df, 20)
# Out:
#              id                                              title  \
# 0   LwJv3vSd8no                                Free Art Wednesday!
# 1   XXjYyBCNJEY                                 FREE Art Wednesday
# 2   OREjUtUT2Sc                     New Intro | I keep losing them
# 8   nmRxk7k3kvU                           Meditation Music video-2
# 14  m18UlcXg3Xg  ' YOU LADYBUG SONG' |MIRACULOUS LADYBUG & CAT ...
# 20  y1yb_WnCfUA                       Video Editor is. Thastefuel?
# 30  sIKsodQRvlc                                MYO Hand Letter Art
# 31  v8uKybpMJdM          Nature Moment | Common Blue Violet Flower
# 32  IkiTwxRtQUk                                 MYO Whipped Coffee
# 33  VvPE3uB7O1A                    Nature Moment | The Holly Plant
# 35  Nj4wCms-Xko         NSFW Shego (Kim Possible) Speedrun #Shorts
# 36  8SnK7mWezWw  Jobs for Veterans: Janine Hardman RN, BSN, Arm...
# 37  D0TBEM3oUtk         Meet Medical Oncologist, Matthew Kulke, MD
# 38  t1EwgfdBn-0                       BMC Faces: Sarah Kimball, MD
# 39  qjXauRp1uaU               Jobs for Veterans: Joseph Blansfield
# 40  7TZ02EP-VaE  BMC Presents: Donate Life - Marta and Brenda's...
# 41  lVBVy0EY0I4  BMC Presents: Donate Life - Bob & Mike featuri...
# 42  ln8Tgp4NsOg  BMC Presents: Donate Life - Dan & Susan's Kidn...
# 43  1CDSz94YRGk                         Meet: Gregory Grillone, MD
# 44  Dvyxal7xrfI  Inflammatory Bowel Disease Care at Boston Medi...
#
#    manual_caption_languages automatic_caption_orig_language language
# 0                        en                              en       en
# 1                        en                              en     None
# 2                        en                              en     None
# 8                     en-US                           en-US     None
# 14                    en-GB                           en-GB     None
# 20                    en-GB                           en-GB     None
# 30                    en-US                           en-US     None
# 31                       en                              en       en
# 32                       en                              en       en
# 33                       en                              en       en
# 35                       en                              en       en
# 36                       en                              en       en
# 37                       en                              en       en
# 38                       en                              en       en
# 39                       en                              en       en
# 40                       en                              en       en
# 41                       en                              en       en
# 42                       en                              en       en
# 43                       en                              en       en
# 44                       en                              en       en

# %%
en_not_downloaded_df[en_not_downloaded_df["manual_caption_languages"].str.contains("en-")].head(20)
# Out:
#               id                                              title  duration  \
# 8    nmRxk7k3kvU                           Meditation Music video-2      1295
# 14   m18UlcXg3Xg  ' YOU LADYBUG SONG' |MIRACULOUS LADYBUG & CAT ...       157
# 20   y1yb_WnCfUA                       Video Editor is. Thastefuel?        12
# 30   sIKsodQRvlc                                MYO Hand Letter Art        80
# 52   0Yt4JoCW8oU                        G Gundam Screenshop Repaint      1233
# 54   orWh_OLaRg4  All Goals | Final Copa America | Argentina (1)...        77
# 93   y3o-baXQT0Q                             VLOG #1 - Introduction       123
# 131  zHGwE0ritgk       Let's Play Minecraft: Greatest freakout ever       122
# 133  1N2Q2-veW8Y  Changing the Roofing Industry by Building Trus...       128
# 134  7CRyjEyWjP4  Schneider Roofing & Remodeling - Show Me St. L...       164
# 135  GhnyvKtQm7w   Do I Really Need a New Roof? - Schneider Roofing       158
# 136  BGl0TRn-kdY           Schneider Roofing - St. Louis Cardinal's       107
# 161  _vcLAPLnv4o  1Granja Helio,  2 Aniversario Alvaro , 3 Brasilia      3608
# 162  dBUOZQZpODA                                  natal joao pessoa      1227
# 163  Kfdc3s1hl9k                                         Natal 1996      3245
# 164  5BTrs5Uvi0s                                              Vidéo      3611
# 166  TYmnAQT88qw                       Ano Novo 1989 e Aniversarios      3589
# 190  qwNlru5_Ej4  Undertale Minecraft RolePlay (UTRP) [UPDATE VI...       656
# 200  uEDPh2HOxDI  Friendly Compadre 18 (ENG CC) - My EX and my a...       530
# 207  u_TgMlq6rQA  Advancing Health Equity through Community COVI...       288
#
#      view_count             categories  comment_count  like_count  \
# 8          44.0                  Music            1.0         2.0
# 14       2433.0                  Music            NaN        57.0
# 20         25.0                  Music            1.0         1.0
# 30         24.0          Howto & Style            NaN         1.0
# 52         27.0          Howto & Style            NaN         1.0
# 54         17.0         People & Blogs            NaN         0.0
# 93        169.0         People & Blogs            7.0         7.0
# 131      2620.0                 Gaming            3.0        14.0
# 133         1.0          Howto & Style            NaN         0.0
# 134        13.0          Howto & Style            NaN         0.0
# 135         2.0          Howto & Style            NaN         0.0
# 136         1.0          Howto & Style            NaN         0.0
# 161        34.0         People & Blogs            NaN         5.0
# 162        24.0         People & Blogs            NaN         0.0
# 163        55.0         People & Blogs            NaN         0.0
# 164        85.0         People & Blogs            1.0         3.0
# 166       120.0         People & Blogs            NaN         3.0
# 190      2069.0                 Gaming           66.0        14.0
# 200        18.0          Howto & Style            NaN         2.0
# 207      1629.0  Nonprofits & Activism            NaN        10.0
#
#                             channel                channel_id  \
# 8                  Meditation music  UCaHJfbRk8gnOZGrJTm5ZI4Q
# 14     miraculous ladybug season 06  UCBgXfZj6cVvu8cz0AX66HZQ
# 20                   FrostyBallz Jr  UC-uKNbvsFlLqBaVI_ysSvig
# 30    Roanoke County Public Library  UCRDIW4cJil7ls67SLQs9a4Q
# 52                         TkayArtz  UCHH2EHqaELDc2Lq9Ct5tn5w
# 54                  North Direction  UCDWbla2PIao9c6DnQNENkDQ
# 93                          Rikzaaa  UCkWADUHEgSPEdLlpdsc6pAA
# 131              Riftenthecoolish93  UC_eV8_QSpMKm7ouQrs__qew
# 133  Schneider Roofing & Remodeling  UCA0DTNFRM-GrtGH_DpH9vYA
# 134  Schneider Roofing & Remodeling  UCA0DTNFRM-GrtGH_DpH9vYA
# 135  Schneider Roofing & Remodeling  UCA0DTNFRM-GrtGH_DpH9vYA
# 136  Schneider Roofing & Remodeling  UCA0DTNFRM-GrtGH_DpH9vYA
# 161                      aabPalitot  UCENZUDVWbiekZNefJjTh_bA
# 162                      aabPalitot  UCENZUDVWbiekZNefJjTh_bA
# 163                      aabPalitot  UCENZUDVWbiekZNefJjTh_bA
# 164                      aabPalitot  UCENZUDVWbiekZNefJjTh_bA
# 166                      aabPalitot  UCENZUDVWbiekZNefJjTh_bA
# 190             The Almighty Hotdog  UCGEH5eyg5RfuPD-dObKZNNQ
# 200                  Compadre Amigo  UCrNP-93yRcJMKo1BtAdAOYQ
# 207           Boston Medical Center  UCCsieriDUNU-2-nNmXngYAw
#
#      channel_follower_count  ...      abr      vbr  \
# 8                       3.0  ...  124.292  124.292
# 14                    524.0  ...  131.965  131.965
# 20                      3.0  ...  130.202  130.202
# 30                    217.0  ...  138.620  138.620
# 52                     34.0  ...  139.683  139.683
# 54                      NaN  ...  122.410  122.410
# 93                    306.0  ...  115.805  115.805
# 131                   776.0  ...  156.967  156.967
# 133                     4.0  ...  115.743  115.743
# 134                     4.0  ...  103.942  103.942
# 135                     4.0  ...  116.439  116.439
# 136                     4.0  ...  123.846  123.846
# 161                    16.0  ...  130.630  130.630
# 162                    16.0  ...  124.008  124.008
# 163                    16.0  ...  123.808  123.808
# 164                    16.0  ...  127.808  127.808
# 166                    16.0  ...  131.259  131.259
# 190                    40.0  ...  149.189  149.189
# 200                    87.0  ...  123.836  123.836
# 207                  7460.0  ...  138.457  138.457
#
#                            vcodec      asr audio_channels chapters  \
# 8                     avc1.640028  48000.0            2.0     None
# 14   vp09.00.31.08.01.05.01.06.00  48000.0            2.0     None
# 20                            vp9  44100.0            2.0     None
# 30                  vp09.00.50.08  48000.0            2.0     None
# 52                    avc1.640028  48000.0            2.0     None
# 54                  vp09.00.21.08  48000.0            2.0     None
# 93                    avc1.640028  48000.0            2.0     None
# 131                 vp09.00.30.08  48000.0            2.0     None
# 133                   avc1.640028  48000.0            2.0     None
# 134                   avc1.640028  48000.0            2.0     None
# 135                   avc1.640028  48000.0            2.0     None
# 136                   avc1.640028  48000.0            2.0     None
# 161                   avc1.4D401E  48000.0            2.0     None
# 162                           vp9  48000.0            2.0     None
# 163                   avc1.4D401E  48000.0            2.0     None
# 164                   avc1.4D401E  48000.0            2.0     None
# 166                   avc1.4D401E  48000.0            2.0     None
# 190                 vp09.00.31.08  48000.0            2.0     None
# 200                           vp9  48000.0            2.0     None
# 207                   avc1.640028  48000.0            2.0     None
#
#           manual_caption_languages  automatic_caption_orig_language  \
# 8                            en-US                            en-US
# 14                           en-GB                            en-GB
# 20                           en-GB                            en-GB
# 30                           en-US                            en-US
# 52                           en-US                               en
# 54   en-JkeT_87f4cc,en-uYU-mmqFLq8                               en
# 93                           en-US                               en
# 131                 en-18WT74-rBWA                               en
# 133                          en-US                               en
# 134           en-US,en-uYU-mmqFLq8                               en
# 135                          en-US                               en
# 136                          en-US                               en
# 161                 en-uYU-mmqFLq8                               en
# 162                 en-uYU-mmqFLq8                               en
# 163                 en-uYU-mmqFLq8                               en
# 164                 en-uYU-mmqFLq8                               es
# 166                 en-uYU-mmqFLq8                               en
# 190                          en-GB                            en-GB
# 200                          en-US                               es
# 207                 en-eEY6OEpapPo                               en
#
#       location  license
# 8         None     None
# 14   AUSTRALIA     None
# 20        None     None
# 30        None     None
# 52        None     None
# 54        None     None
# 93        None     None
# 131       None     None
# 133       None     None
# 134       None     None
# 135       None     None
# 136       None     None
# 161       None     None
# 162       None     None
# 163       None     None
# 164       None     None
# 166       None     None
# 190       None     None
# 200       None     None
# 207       None     None
#
# [20 rows x 34 columns]

# %%
en_not_downloaded_df["man_cap_langs_2"] = en_not_downloaded_df["manual_caption_languages"]
# Out:
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_73078/761563661.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en_not_downloaded_df["man_cap_langs_2"] = en_not_downloaded_df["manual_caption_languages"]

# %%
en_not_downloaded_df.columns
# Out:
# Index(['id', 'title', 'duration', 'view_count', 'categories', 'comment_count',
#        'like_count', 'channel', 'channel_id', 'channel_follower_count',
#        'age_limit', 'upload_date', 'is_live', 'was_live', 'format',
#        'format_id', 'language', 'filesize', 'stretched_ratio', 'width',
#        'height', 'fps', 'dynamic_range', 'aspect_ratio', 'abr', 'vbr',
#        'vcodec', 'asr', 'audio_channels', 'chapters',
#        'manual_caption_languages', 'automatic_caption_orig_language',
#        'location', 'license', 'man_cap_langs_2'],
#       dtype='object')

# %%
view_lang_cols(en_not_downloaded_df)
# Out:
#              id                                              title  \
# 0   LwJv3vSd8no                                Free Art Wednesday!
# 1   XXjYyBCNJEY                                 FREE Art Wednesday
# 2   OREjUtUT2Sc                     New Intro | I keep losing them
# 8   nmRxk7k3kvU                           Meditation Music video-2
# 14  m18UlcXg3Xg  ' YOU LADYBUG SONG' |MIRACULOUS LADYBUG & CAT ...
#
#    manual_caption_languages automatic_caption_orig_language language
# 0                        en                              en       en
# 1                        en                              en     None
# 2                        en                              en     None
# 8                     en-US                           en-US     None
# 14                    en-GB                           en-GB     None

# %%
condition = (
        en_not_downloaded_df["man_cap_langs_2"]
        .apply(standardize_dialects_2)
        .apply(lambda lst: set(lst) == {"en"})
)
temp_df_5 = en_not_downloaded_df[condition]

# %%
temp_df_5["manual_caption_languages"].unique()
# Out:
# array(['en', 'en-US', 'en-GB', ..., 'en-CA-UFjxr4OIYz8', 'en-FpQ6dhQAASY',
#        'en-LQRErUK_jpw'], dtype=object)

# %%
list(temp_df_5["manual_caption_languages"].unique())
# Out:
# ['en',
#  'en-US',
#  'en-GB',
#  'en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-18WT74-rBWA',
#  'en-US,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8',
#  'en-eEY6OEpapPo',
#  'en-IN',
#  'en-CA',
#  'en,en-GB',
#  'en-cvfXDfbeED0',
#  'en-US-anMIXjicSL4',
#  'en-s8TMdDjdYe8',
#  'en-IE',
#  'en,en-US',
#  'en-rX01gsAdUfU',
#  'en-nP7-2PuUl7o',
#  'en-zL7EZQmMa4Q',
#  'en,en-IN',
#  'en-imjcPpJerPk',
#  'en-zL_pKPa_d08',
#  'en-cFSbaKj2OKY',
#  'en-anMIXjicSL4',
#  'en-UMYBvvsXfqo',
#  'en-1oAFzPNiuC0',
#  'en-ehkg1hFWq8A',
#  'en-vleHeMwJqgw',
#  'en-0hllRZe4s5s',
#  'en-US-eEY6OEpapPo',
#  'en-K3JFmAG0FTI',
#  'en,en-zL7EZQmMa4Q',
#  'en-GB,en-US',
#  'en-PQgNkSoyyBk',
#  'en-TW7qhz_uLiI',
#  'en-Zixs6prhbeE,en-nPk3V-duwf8',
#  'en-US-YfeEIUII1AU',
#  'en-y01yHln2iAs',
#  'en-uYU-mmqFLq8,en-zL_pKPa_d08',
#  'en-y7ZDYfb4tI8',
#  'en-GusEpHUv8yI',
#  'en-1FAeErPlCAc',
#  'en,en-CA',
#  'en-fGGqjO4aYg8',
#  'en-q_HRRye8iTM',
#  'en-nPk3V-duwf8',
#  'en-A8Ln5B_8GBo',
#  'en,en-UDggLCECq8g',
#  'en-lqO-PPJy4Bc',
#  'en-qoXxhA4oLYo',
#  'en-m9hPnTBjEoU',
#  'en-wILyS7txfUA',
#  'en-IN,en-US',
#  'en-6Effb_CP71k',
#  'en,en-uYU-mmqFLq8',
#  'en-nHenYwqXk4s',
#  'en-d6gV6WVcwQQ',
#  'en-oEkF-RzuXbU',
#  'en-WPGPOmZxCFk',
#  'en-HmwMawKq9bY',
#  'en-ZW6bPmS_ILY',
#  'en-2WL_udbGxQs',
#  'en-Uym2X1t3MTA',
#  'en-puBa_fWWqOc',
#  'en,en-ehkg1hFWq8A',
#  'en-VuAxBFMsp20',
#  'en-vP3gpS-n2EU',
#  'en,en-Uym2X1t3MTA',
#  'en-NjKQ6KFPTeM',
#  'en-OkkdIt_1FtE',
#  'en-8k-bGVCfGYE',
#  'en-Ofml0VSlMyE',
#  'en-MPV48gM7bqQ',
#  'en-US,en-US-Az1uF2nEdyo',
#  'en-LUU0EuDKgKo',
#  'en-6UJrWS5jR_I',
#  'en-6UJrWS5jR_I,en-gG13fOM8Dfs',
#  'en-FmoQciUtYSc',
#  'en-gG13fOM8Dfs',
#  'en-6UJrWS5jR_I,en-LUU0EuDKgKo',
#  'en-tyWfmtkyBQo',
#  'en-SJ_OorK2o0k',
#  'en-LUU0EuDKgKo,en-gG13fOM8Dfs',
#  'en,en-LUU0EuDKgKo',
#  'en-bo0751DuF0A',
#  'en-6UJrWS5jR_I,en-GB',
#  'en,en-GB-6UJrWS5jR_I,en-LUU0EuDKgKo',
#  'en,en-0kNkGc9-BfI,en-GB-6UJrWS5jR_I,en-LUU0EuDKgKo',
#  'en,en-0kNkGc9-BfI,en-GB-6UJrWS5jR_I,en-LUU0EuDKgKo,en-vYdUoF8TkEk',
#  'en,en-GB-6UJrWS5jR_I,en-vYdUoF8TkEk',
#  'en-GB-6UJrWS5jR_I',
#  'en-GB,en-SJ_OorK2o0k',
#  'en,en-0kNkGc9-BfI,en-GB-6UJrWS5jR_I',
#  'en,en-6UJrWS5jR_I',
#  'en-zOnwy86eUkk',
#  'en,en-GB,en-LUU0EuDKgKo',
#  'en-GB-6UJrWS5jR_I,en-LUU0EuDKgKo',
#  'en-ZBvqvWAExS0',
#  'en,en-xMpCOKC5I4I',
#  'en-Sxg7wWGnGNg',
#  'en-76oVOw9oKuU,en-xMpCOKC5I4I',
#  'en-7MvIfktc4v4,en-yB5yjZ1ML2M',
#  'en-LUU0EuDKgKo,en-M-WisMIBVug',
#  'en-LIpNJOgiZG4,en-gG13fOM8Dfs',
#  'en-islCoqYLrbY',
#  'en-iGJpuh49ngc',
#  'en-cAKMgbCC-fs',
#  'en-Fn5MF40AHlI',
#  'en-2avXrs-sA5o',
#  'en-gHD45WmuTUk',
#  'en-iGRNtWUgfHc',
#  'en-ngggGVIunHc',
#  'en-if-_5MVq4Oo',
#  'en-xqMIxE5vx4g',
#  'en-WMWuJvsuvM0',
#  'en-Phs7HaRpmxc',
#  'en-vWpxECmUytM',
#  'en-gjf-1tSwjvQ',
#  'en-9H6bSekVbKY',
#  'en-GHQATvmmdhE',
#  'en-MvXeHcEkV6M',
#  'en-HfU1kBDaoeU',
#  'en-tn2FgxsJXPs',
#  'en-zsweiKMxjbg',
#  'en-DvHdX2kI9hs',
#  'en-S1Q9ONhyWlE',
#  'en-1Hzps0N_MPU',
#  'en-upRjq0FRvOM',
#  'en-3t0pjotC4o8',
#  'en-g_D0HJdf2ak',
#  'en-Hvkv0GLQGe0',
#  'en-61rj6qWJFLM',
#  'en-6biY9mi3trE',
#  'en-1yERvTPwLfs',
#  'en-gQs2rYpr-Bs',
#  'en-yMosIl2z1s0',
#  'en-llJczrNKcy4',
#  'en-T7MrD1YrYNQ',
#  'en-xf0PX6EkjBE',
#  'en-fcVymTUPpeI',
#  'en-EqpVbppp6GY',
#  'en-H_h6RMPrfCg',
#  'en-Ea2cOYhJJN8',
#  'en-meBFpKW-w_Y',
#  'en-BL_DZqyFfhQ',
#  'en-d4e-sftakyk',
#  'en-US,en-nP7-2PuUl7o',
#  'en-FhOyXW7vw1Q',
#  'en-gpLhevRF8rA',
#  'en-eojh1S_pMNM',
#  'en-jFK5kpDRP3M',
#  'en,en-21M8WI-ZtuA',
#  'en-O5gwMiep5w8',
#  'en-cmGzvRTCcoM',
#  'en-zWSztBjdBA0',
#  'en-qmp7RGYOjJQ',
#  'en-HrjNrJ83ADA',
#  'en-rro1-ZU-JXE',
#  'en-S5keeP5-mFg',
#  'en-v9B2qqWVzdQ',
#  'en-AU',
#  'en-GB-duqIB3Ivo2c',
#  'en-dE8xcS92EcM',
#  'en-REjPv0WzLGo',
#  'en,en-dZAhw2Veuag',
#  'en-TGqiiJw2dmI',
#  'en-y4fwKszN_rY',
#  'en-BCIa9Uq2gpQ,en-GB',
#  'en,en-GB-uMN-M9795Rw',
#  'en-gmhThQ938Kc',
#  'en-ZMpglypuySY',
#  'en-wUbgmG6Sv_I',
#  'en-qD-qwlB2ZC0',
#  'en-FetHzM0RQJU',
#  'en-dBnIPyQn-7E',
#  'en-VzZ7z7gID6c',
#  'en-DX1xJ45FbHc',
#  'en-Pn_zu28Dr6A',
#  'en-j3PyPqV-e1s',
#  'en-qlPKC2UN_YU',
#  'en,en-qlPKC2UN_YU',
#  'en-US,en-j3PyPqV-e1s',
#  'en-JkeT_87f4cc,en-j3PyPqV-e1s',
#  'en-US-BfshbuJ9u2Q',
#  'en-US-qhidoPi0w8c',
#  'en-US-7VqXalgof68',
#  'en-US-iLtzV24hzLM',
#  'en,en-j3PyPqV-e1s',
#  'en-0GZSgHK00aQ',
#  'en,en-CA,en-GB,en-IE,en-IN,en-US',
#  'en-US-Tz2g3Ok69lM',
#  'en-US-KeiurSZEkPo',
#  'en-US-T4OLh11_lkI',
#  'en-6ebHVfu6BsQ',
#  'en-LncXMvopwAc',
#  'en,en-GB,en-IN,en-US',
#  'en-GB,en-IE',
#  'en-LtWZwabQMh4',
#  'en-ovhHx95i6Ho',
#  'en-Jyun0WSqg2k',
#  'en,en-6J3Fe4Pss0Y',
#  'en-GHEw9DUond8',
#  'en-GB,en-uYU-mmqFLq8',
#  'en-bFjpeiP6wzQ',
#  'en-YbU81EbFwnU',
#  'en-Hod1tDuSZpQ',
#  'en-g3sZi71aORs',
#  'en-ejYvIAw3rm4',
#  'en-3EZ2SlE8DSw',
#  'en-jr_ntwmUyqk',
#  'en-CUBnaAm_WCg',
#  'en-1oAFzPNiuC0,en-uYU-mmqFLq8',
#  'en-N4kgRcPSw6A',
#  'en-uKpN1tTG93w',
#  'en-RPMGl4fB8OA',
#  'en-eHloqz0DtQ0',
#  'en-5iccchR9oVs',
#  'en-SAlmeBsx6eA',
#  'en-yY28IvSfG0o',
#  'en-xzT-nJHltPQ',
#  'en-CvmWTchUDqY',
#  'en-L7Y8rZWawzA',
#  'en-aL_5_v9zbBM',
#  'en-mI7aUCLzdjE',
#  'en-2qxE-mwDpSU',
#  'en-bSRtDOqDE9o',
#  'en-KyVObD-42KU',
#  'en-IujS0_XVVrw',
#  'en-GB-anMIXjicSL4',
#  'en-OxbJ1MTIVs4',
#  'en--gxqKfNj5XA',
#  'en-23PnzzdJvos',
#  'en--FB6cFtFezg',
#  'en-0ONhgy-lWvo',
#  'en-yR6JfUoAWYg',
#  'en-1mR-xBGZEZ4',
#  'en-64EvSf-i32o',
#  'en-8P0-Z2SKhy4',
#  'en-xWCTb4ASxWo',
#  'en-3oY-wYEVjgY',
#  'en-DI1FT9YnJxw',
#  'en-mqT_bUH1f74',
#  'en-nWZJSqx27Co',
#  'en-wrkgf4iBZSg',
#  'en-p-a8_cEWdOk',
#  'en-z32Y2Axx7Xs',
#  'en-bdFBGmYVkEA',
#  'en-1dfyypFS06k',
#  'en-3BbmkACe_Ck',
#  'en-hUGJy75jDp0',
#  'en-QLlkAr8DpK0',
#  'en-gcgg6QaEclI',
#  'en-fT_tyvG74RA',
#  'en,en-nP7-2PuUl7o',
#  'en-G1jV0keXEkQ',
#  'en,en-1oAFzPNiuC0',
#  'en-t8dcvQ4hAi0',
#  'en-jm5Qn7oS3ns',
#  'en-C98BKmi_tmk',
#  'en-7rk6kshSjAg',
#  'en-ZLqp32PlplQ',
#  'en-_Hof7-ZAGIA,en-uYU-mmqFLq8',
#  'en-iktMRMbGemc,en-uYU-mmqFLq8',
#  'en-3MbBqDa1_xg,en-uYU-mmqFLq8',
#  'en-B1i59iwuZlM,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-wbPQmIjmQP8',
#  'en-76Rj-GuXV8A,en-uYU-mmqFLq8',
#  'en-8K7HLuWh9lI,en-uYU-mmqFLq8',
#  'en-FltNKKLDWYo,en-uYU-mmqFLq8',
#  'en-MGaoCWZxdkw,en-uYU-mmqFLq8',
#  'en-TG_nCj5ASpU,en-uYU-mmqFLq8',
#  'en-Q6Y_6uU4N38,en-uYU-mmqFLq8',
#  'en-EfSslzmZKw0,en-uYU-mmqFLq8',
#  'en-ywMsn8eDCTc',
#  'en-JRakUmdHCC8',
#  'en-fBJ7WLCgqx8',
#  'en-GtDsi6WLVPc',
#  'en-VqxSfNneakA',
#  'en-Ofp0J1P2Fj8',
#  'en-dIsCpYIEZ-A',
#  'en-CY5OQ3YEjy0',
#  'en-DU6Y4mlPvmE',
#  'en-0raYX-fjB-Y',
#  'en-A2Vm0pEh5-Y',
#  'en-yd_sspvDACE',
#  'en-6DGfwZopUls',
#  'en-ab5nJ29o4es',
#  'en-BEo9_LMRxWY',
#  'en-oD20rO7Phvo',
#  'en-d9VYABo4dik',
#  'en-AKTRZJ-NMNI',
#  'en-xEM73oi3n3M',
#  'en-UgyXJBR6AFs,en-uYU-mmqFLq8',
#  'en-qAfPFHriwdk,en-uYU-mmqFLq8',
#  'en-QylZedUUFiA,en-uYU-mmqFLq8',
#  'en-O6wkUz5wElU,en-uYU-mmqFLq8',
#  'en-jIpDolMlEmA',
#  'en-QiHwL5tfpfI',
#  'en-dSf3a27VGm8',
#  'en-ssLC1dOyF34',
#  'en-JWp4A7VQiG0',
#  'en-9qd52hCbh0o',
#  'en-UQOvE_COaTM',
#  'en-8DarVTzXFEE',
#  'en-5X6CBLEIevk',
#  'en-u_ZFxZ4Iwxw',
#  'en-FF1NwU-wxK4,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-x80YNd3z25Y',
#  'en-cHMI6a8ww9E,en-uYU-mmqFLq8',
#  'en-FcsVn2rKMtI,en-uYU-mmqFLq8',
#  'en-0qs7cWpj4rA,en-uYU-mmqFLq8',
#  'en-e3NusTPrr30',
#  'en-ZvsrR0Q_eXs',
#  'en-UNfGon_hYfo',
#  'en-DhOS5gtZfZk',
#  'en-_CqfN_LT9aE',
#  'en-9v0ZI75fiZE',
#  'en-EJnfUyAiN2g,en-uYU-mmqFLq8',
#  'en-iT7qnIhNJWA,en-uYU-mmqFLq8',
#  'en-tTbOJDVqCbI',
#  'en-Rhz_4ijIPaQ',
#  'en-i3qf1mbYapA',
#  'en-11ZdSa6hooI',
#  'en-lurLXvJcXvI',
#  'en-tkYzxHx4p5Q',
#  'en-3GFUKXcb7WM',
#  'en-uVxC6Conj38,en-uYU-mmqFLq8',
#  'en-1UNkydfJV24,en-uYU-mmqFLq8',
#  'en-mWAmV_B9GV8,en-uYU-mmqFLq8',
#  'en-NpXwbx70etE,en-uYU-mmqFLq8',
#  'en-0XFuZABDzVk,en-uYU-mmqFLq8',
#  'en-V9jSuAjJEbI,en-uYU-mmqFLq8',
#  'en-qZlK2sLnnoo,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-ySYwVaaeHaY',
#  'en-iN6F7OcXyNY,en-uYU-mmqFLq8',
#  'en-PWabrcnD3Z8,en-uYU-mmqFLq8',
#  'en-8F2EDzgHxtg,en-uYU-mmqFLq8',
#  'en-cAkvJR0zB90,en-uYU-mmqFLq8',
#  'en-jhHEXAO2I0o,en-uYU-mmqFLq8',
#  'en-jx4UCXjwadg',
#  'en-efEyZfXswYU',
#  'en-0nRMqpa1Hr0',
#  'en-NFcLRpr5wbM',
#  'en-RFC1Y7VVULk',
#  'en-MPUBBCWfl68',
#  'en-xCMTqQGUYLg',
#  'en-7D5_z6-AsQ4',
#  'en-80RURFZ4zuI',
#  'en-i-yJDRLzc9k',
#  'en-dp6BXKpHKFo',
#  'en-dmhUiaHExf8',
#  'en-xG2L3wN5MZY',
#  'en-eLuuvKe3-1Q',
#  'en-s7haLhmWpG4',
#  'en-N26N9DLURLo,en-uYU-mmqFLq8',
#  'en-7LiXD61PwAc,en-uYU-mmqFLq8',
#  'en-Anbi2vIZBTk,en-uYU-mmqFLq8',
#  'en-tsgj_oGjMgw,en-uYU-mmqFLq8',
#  'en-TZAATuirJ_Q,en-uYU-mmqFLq8',
#  'en-BgBHMiEXI_o,en-uYU-mmqFLq8',
#  'en-H7ZOto6JJT8,en-uYU-mmqFLq8',
#  'en-l6QjZcGF8aw',
#  'en-zoEa883gshU',
#  'en-bV6djx43ixY',
#  'en-FZX3Xl_7zRI',
#  'en-Q9iUvTQL9FE',
#  'en-Z5N4aknX6OI',
#  'en-GpK8vawI_Io',
#  'en-DzJWn9OFqRc,en-uYU-mmqFLq8',
#  'en-MSHQHP5KFLc,en-uYU-mmqFLq8',
#  'en-sDADfminFcM,en-uYU-mmqFLq8',
#  'en-4YnTPw1gmr0,en-uYU-mmqFLq8',
#  'en-Mpg_1Va2K9k,en-uYU-mmqFLq8',
#  'en-VNj6tqF9Oo4,en-uYU-mmqFLq8',
#  'en-H_1Mk8KB8K4,en-uYU-mmqFLq8',
#  'en-120rn_vNGx8',
#  'en-uVRFU16Reas,en-uYU-mmqFLq8',
#  'en-cQ1llC5r_N4,en-uYU-mmqFLq8',
#  'en-TDNdoLvhUmM,en-uYU-mmqFLq8',
#  'en-3LFvsy878l0',
#  'en-_t72HAHLm4A,en-uYU-mmqFLq8',
#  'en-MEPSEoivOZM,en-uYU-mmqFLq8',
#  'en-dxJE3C5Pgys',
#  'en-UlnzoFdN954',
#  'en-hewyImnU_PU',
#  'en-w_XpXbpNjaI',
#  'en-d1xiFG08gjs',
#  'en-t7rWrKd8Ad4',
#  'en-h9Qm8Wn81Qc',
#  'en-YElYWYZYBsE',
#  'en-VZXvqQ1HUM0',
#  'en-IbwESjAIKIM',
#  'en-Od1s-yjzCk4',
#  'en-xSbralMSyL8',
#  'en-vdMGBCErqgs',
#  'en-6274TbjLkDI',
#  'en-YbU4xl3NPKY',
#  'en-ig-_8-DReig',
#  'en-M-EM8ZJR5TY',
#  'en-9K8SNO-JzzM',
#  'en-Bgj8gkOBno0,en-uYU-mmqFLq8',
#  'en-idzNd7o7AJc,en-uYU-mmqFLq8',
#  'en-Iab1tzXpOWE',
#  'en-Wzivx_W_sbs',
#  'en-lCdwCUkWeJc',
#  'en-Ycc3eL1B2yA',
#  'en-wbkKCiI2CMM',
#  'en-z5LQBEn4dek',
#  'en-pZZLShZpWcM',
#  'en-L3CV-TGVGgQ',
#  'en-ONET0Yaghao',
#  'en-XZJdMyFfkRg',
#  'en-3ikBRqOBHzg',
#  'en-lBFmVTJlG5U',
#  'en-cHH2Vv6QkUk',
#  'en-OobyRLDl1NE',
#  'en-s_gezPJHA58',
#  'en-0eQpfQgW5No',
#  'en-3fk7h0swSlQ',
#  'en-hJoysNUZZ7U',
#  'en-XYa62Rh3toU',
#  'en-zljFX1uHcD0',
#  'en-OcUZzOF9GkM',
#  'en-uYU-mmqFLq8,en-z7LZbhxneiw',
#  'en-A05o5yoyJLE,en-uYU-mmqFLq8',
#  'en-Yb3ad0LoV-g,en-uYU-mmqFLq8',
#  'en-nVStdFdGyZo,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-z6Cp3yGtK4o',
#  'en-stM_8fv3fe4',
#  'en-VcWfqzZUl2g',
#  'en-5OEB2XOeUUM',
#  'en-cWhQ94lMBLs,en-uYU-mmqFLq8',
#  'en-FXiSFqPbPqs,en-uYU-mmqFLq8',
#  'en-DhteUWac6pc,en-uYU-mmqFLq8',
#  'en-n-QYkRU47BE,en-uYU-mmqFLq8',
#  'en-Ap3T694wA6g,en-uYU-mmqFLq8',
#  'en-BM0WI_iALvk,en-uYU-mmqFLq8',
#  'en-RzgOMvnhUvI,en-uYU-mmqFLq8',
#  'en-BpqEfjDo2BA,en-uYU-mmqFLq8',
#  'en-kHNDB91_-QU',
#  'en-3U7Dqf--y-Q,en-uYU-mmqFLq8',
#  'en-jGvZftyZcEo,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-vGD_FQdQeLM',
#  'en-T9qhxQRJRmc',
#  'en-ulPx8tGYPGw',
#  'en-jnHY8P9_ks0',
#  'en-FFxRwzh0muQ',
#  'en-ArhI5MAV3NA',
#  'en-09Ux-9GNvKI,en-uYU-mmqFLq8',
#  'en-Rv828-gT8jc,en-uYU-mmqFLq8',
#  'en-e8JF94SJ4NQ',
#  'en-U0YbS-QWxd4',
#  'en-gsXMwymIud0',
#  'en-e_Xh7w9Epkw',
#  'en-2P9uztvhaeA',
#  'en-IeNvToZgHPg',
#  'en-0eZ0TCi15HI',
#  'en-qTlCOyMhOSw',
#  'en-kJfiWXfUCLU',
#  'en-tVVXmG2kB7g',
#  'en-uJHoRATdkm8',
#  'en-Qcc1GOdpamE',
#  'en-hUIoxyi-030',
#  'en-Wd5ne0NZlm4',
#  'en-SPZjhkhweMk,en-uYU-mmqFLq8',
#  'en-Axcy-8KW7e0,en-uYU-mmqFLq8',
#  'en-DtCDVLpE9O4,en-uYU-mmqFLq8',
#  'en-ofSVbU4YSJQ,en-uYU-mmqFLq8',
#  'en-NthDPQrGQAQ',
#  'en-XquW9nIuafg,en-uYU-mmqFLq8',
#  'en-uoLYTLJz9cA',
#  'en-iLuGeEx0xbk',
#  'en-3JhTMIiRCvg',
#  'en-ds50qUua7D0',
#  'en-FoTemYs0spk',
#  'en-z3-LawTILdw',
#  'en-q-Hi8ef2nGk',
#  'en-RJGMsfRKmMo',
#  'en-pUhGHX3gKk4',
#  'en-GB,en-ehkg1hFWq8A',
#  'en-i-Xj9hVqayE',
#  'en-zb626elTQfI',
#  'en-zrhEfMSreNI',
#  'en-mjBqq25IgRg',
#  'en-NyJtIHtZVhA',
#  'en-_UV89z7lq1I',
#  'en,en-DLxmEfVUC9A',
#  'en-GB-HREnMOppNQQ',
#  'en-QCotXvb3gqc',
#  'en-4_3WYQr9MRA',
#  'en-EWlhny-7MOA',
#  'en--ez3iVCnwCg',
#  'en-M6DkMKzioWg',
#  'en-GhBJkI-ZY6I',
#  'en-pUqyR1dH3z0',
#  'en-gqf8ywQ2sow',
#  'en-Jt9r_xG_fDg',
#  'en-xsdh2DrdsNs',
#  'en-yumAWoW7qWU',
#  'en-5eFA4iUleFw',
#  'en-J2TymM82MtI',
#  'en-clf6ljnzPtE',
#  'en-cGdqV1w3puY',
#  'en-b2Dj6g88f9c',
#  'en-2h3TFzHPqXs',
#  'en-fkRIyfeeA9w',
#  'en-Bs1qkbsohDQ',
#  'en-kK23sFf5UBg',
#  'en-K2FocqUpHRI',
#  'en-o5JzkzEIPbY',
#  'en-mP2Grm9Ss5w',
#  'en-tuKINWKc7CA',
#  'en-7-YRqxZY-jc',
#  'en-US,en-ehkg1hFWq8A',
#  'en-gY_yrt0x_8w',
#  'en-VKj_Zw7S2zI',
#  'en-QdaCGHhfh14',
#  'en-RYczKem2P_o',
#  'en-GDlQFzyoy3k',
#  'en-GQwauXgAcv0',
#  'en-fLe3xL7M3l8',
#  'en-uBTuqohGLvI',
#  'en-3QM-Ihr9bGQ',
#  'en-oUH2mtTh3i8',
#  'en-nnNTxpgfZCo',
#  'en-I8wvA-91FLs',
#  'en-jeRO6oyMib8',
#  'en-EMtBlLA2w_E',
#  'en-mkIqslO62RE',
#  'en-85vgYh-5Y4w',
#  'en-MUHkQi6Jj1s',
#  'en-rw12mh_SfIk',
#  'en-DzWYXXbsT4g',
#  'en-DBVgrKn_J2Q',
#  'en-p8nSjUMMvuc',
#  'en-mY6jaOMW3PY',
#  'en-TBD5uZH-UAE',
#  'en-iI3gF-Y9AAI',
#  'en-EipA9Y1I8h4',
#  'en-z7ILyPzY03I',
#  'en-KwtO0Ql93wA',
#  'en-7Px4sdc5n3E',
#  'en-i7LFIGUQP0g',
#  'en-P0tcqV_XoMw',
#  'en-ItWavQTbn9E',
#  'en-JBfyDMnnLCU',
#  'en-COr59TqeAPE',
#  'en--R-guCm8R6g',
#  'en-6p4UjyuXlSs',
#  'en-Lcy4KIe2XhE',
#  'en-NqLLpdiUBc8',
#  'en-PR2LyS0iiqY',
#  'en-KhWKOo0qF3w',
#  'en-5U1EGHNmTyY',
#  'en-ZzZt-22CG70',
#  'en-AzcRNGUccjw',
#  'en-7EXKh1JJ0ls',
#  'en-WMxZjK83e88',
#  'en-0E-uKd5Fs0g',
#  'en-Pam56VcfJwc',
#  'en-YYWuqi_RG-k',
#  'en-69I7iLY-3a4',
#  'en-zWeQYJZSa9I',
#  'en-_hYnLvTXczw',
#  'en-uEeDvB13UpI',
#  'en-gspU9OLearw',
#  'en-viWK5tKAY5o',
#  'en-pMl9FArDVss',
#  'en-AXwwrOrXLh8',
#  'en-vnl-vWORp4I',
#  'en-F2jLaidLhvw',
#  'en-6iulBvwACy4',
#  'en-NI3JxG4jWzo',
#  'en-UGVyG7Vq28g',
#  'en-RQ5ovr9l5BY',
#  'en,en-Z718QvEZyWc',
#  'en-5XR7eC0ZFeo',
#  'en-3RqRCbsr_xg',
#  'en,en-_MQS1NmgeQw',
#  'en-OrMU4aRBs8k',
#  'en-NKbu1RTbYuo',
#  'en-iQqhxWOvnbg',
#  'en-ITdJ2ruQ_Is',
#  'en-3UcICQ1-yA8',
#  'en-5FeuvWizfG8',
#  'en-Jljv6wib23c',
#  'en-r0AnDEQp_fg',
#  'en-oTp_B_xOvu4',
#  'en-VVRlss9RIU8',
#  'en-cXA6z0YDJuA',
#  'en-LPnVTah3NPQ',
#  'en-d3JHjS3jU64',
#  'en-YW1aiZ9-g60',
#  'en-US-YGQ902-g2TI',
#  'en-IUYXXmWEt8E',
#  'en-XxpTnCbIytc',
#  'en-D8dBMXirXhQ',
#  'en-Hz9YoeZmCxY',
#  'en-BAUxXoJBx7Q',
#  'en-eNrGvamCrqo',
#  'en-UbksbRvzyXo',
#  'en-1oAFzPNiuC0,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-FD6xoZsyAlw',
#  'en-gjixCfCnBvA',
#  'en-jRnxSnnJKsE',
#  'en-GB-8Mke0_njMzM',
#  'en,en-IE',
#  'en-t_rK2yKGuew',
#  'en-UwNGZaUp4Nk',
#  'en-_rgNrs8ZQd4',
#  'en-eq4NNW_4HrA',
#  'en-H4i0Z74JAMg',
#  'en-SL3JhRiwRdo',
#  'en-bdCIdPg1B-k',
#  'en--QfmURZHiTQ',
#  'en-DegjjUawlm8',
#  'en-hAJjRapOVVQ',
#  'en,en-slp2VzjvzuY',
#  'en-9gIChYjjc9I',
#  'en-CVDiK9g50bs',
#  'en-okvGocAgwdk',
#  'en-w0I42LU0b2k',
#  'en-5UsapxdRFf8',
#  'en-rE8lCltoHlw',
#  'en-C_fBn36sO_o',
#  'en-vr3ZgywzNpA',
#  'en-gAYYlDAlMV8',
#  'en,en-anMIXjicSL4',
#  'en-GB-xtDBcRnqi9Q',
#  'en-g0bN4mhb0hs',
#  'en-87T3pm9SGDM',
#  'en-vXfWBg8Pqq8',
#  'en-Od8H0Ugbovk',
#  'en-vmz9EZNj_jY',
#  'en-KiF8PLhXDeA',
#  'en-tjXMsETQXaE',
#  'en-z7V-MSjyksA',
#  'en-S3pdBb-CH08',
#  'en-EP2_IH4RNQY',
#  'en-CA,en-GB',
#  'en-Qmus90MA7kU',
#  'en-BtgOsMULSaU',
#  'en-2XqNNQ0SglU',
#  'en-h7RozCqfl1I',
#  'en-LG8d_i9VuVg',
#  'en-x4JPPU1fey8',
#  'en-GB,en-LG8d_i9VuVg',
#  'en-s7xBf6vQ5LM',
#  'en-n9AlwhLaAlE',
#  'en-WfEfoHUd5QE',
#  'en-0zfjSeGzKME',
#  'en-WIECNI8hvGc',
#  'en-MD7z0qR4F_g,en-mSoz6_ISHv8',
#  'en-cYotUUH_ne0',
#  'en-3pK74FgVxOs',
#  'en-jJhZPlUrNCo',
#  'en-W7D_rH2z_y8',
#  'en-ilDNOedWomQ',
#  'en-DBKy2q3Vaj4',
#  'en-JkeT_87f4cc,en-uYU-mmqFLq8,en-zL_pKPa_d08',
#  'en-A9bSQE2doEM',
#  'en-VZQDQwedvKw',
#  'en-XdJbaBj1uRs',
#  'en-rAB9mvXiy_k',
#  'en-pdfOssWbjO4',
#  'en-2PqpQm6lhas',
#  'en-Skcuu5dovbQ',
#  'en-BI_H8fHGEws',
#  'en-WR81p6BYZBg',
#  'en-5mF1M-yAtaA',
#  'en-2G0bp8YxGws',
#  'en-anM8ms4cips',
#  'en-eEL_dW8EI4k',
#  'en-Glkapzp1npw',
#  'en-W1a5XUwgNpE',
#  'en,en-US-8yztapuhZMQ',
#  'en-ZDIZLd0TxZ4',
#  'en-_wo7fz2u8EA',
#  'en,en-x_yxDECDNlQ',
#  'en,en-O7lMj7lDYkQ',
#  'en-rxsI4JzibH4',
#  'en-cKSc6s98mtQ',
#  'en-whyRX1JI64w',
#  'en-B-aJ56r1SFg',
#  'en-xiKGd7TT90g',
#  'en-l3Tlt9MJgXY',
#  'en-JsFt_iul1zU',
#  'en-La0keTR7_Pw',
#  'en-K83W_w3D6DM',
#  'en--wekYWsJexA',
#  'en-qUDwV093yHw',
#  'en-DUiGB2B0BrI',
#  'en-tjfWAt_T5jg',
#  'en-DuL8Rh9qgXY',
#  'en-r1sv6oAp6j0',
#  'en-mrPbNs1k-xM',
#  'en-BIYDkt-ixA4',
#  'en-KGDwxvm6OD0',
#  'en-VboTa6TI5jk',
#  'en-a0nESNfPRAE',
#  'en-Bq1w29tYyIw',
#  'en-Uz4xcAVwOGc',
#  'en-zjT3E6tEukw',
#  'en-tXnlHtoo830',
#  'en-bTEEku7m_dI',
#  'en-RFfUQIcK1tQ',
#  'en-LZg5jBUGuhg',
#  'en-hzkUZk8SLLc',
#  'en-koWG0Cdscjc',
#  'en-irkgdZGKe_0',
#  'en-XRrE9oflpbU',
#  'en-UJFdZw25Jdc',
#  'en-FgNQ6gnITdM',
#  'en-S9eLTse3JGw',
#  'en-QUQY448TsWc',
#  'en-3E88c8m_-SA',
#  'en-pK8Av3W7mj0',
#  'en-HoKbdB4Dzo4',
#  'en-W3H6IVN677s',
#  'en-9Xdcvl7IH6I',
#  'en-ePZrFTdGZoQ',
#  'en-i5kVHc3lf-U',
#  'en-q-Xiya00Df0',
#  'en-z0T8M3jsoU0',
#  'en-jf7xKtvxgLM',
#  'en--BbGSwzns0s',
#  'en-0agDWbfTB_I',
#  'en-wM-1q7pMLrI',
#  'en-ONFNSJSopns',
#  'en-lX9jl0kvZfs',
#  'en-ftylmGiorMU',
#  'en-pi34-gP0-qk',
#  'en-smFHrho8E_Q',
#  'en-Ixyetto8H3Q',
#  'en-aSY2uweTGnI',
#  'en-Dcru9dW5ODM',
#  'en-WGOd9r5UQuI',
#  'en-8kZLnIB6dFI',
#  'en-XUp_RpzxaUo',
#  'en-gwKGy7jbExw',
#  'en-T-iV2Vc9ehU',
#  'en-m6UlexV5PgI',
#  'en-V2YjA2e6Fyo',
#  'en-TsqtZXIWL0g',
#  'en-9Pux1EfLFnE',
#  'en-US--N8GEju60NE',
#  'en-VzJZ2D_l_ls',
#  'en-L-XHGaFuMC0',
#  'en-dzJ4Lf5JT0A',
#  'en-Zvyn-r40YsU',
#  'en-j4VkGyWwQv0',
#  'en-j0pxzQv08Ak',
#  'en-lzoA4I-_t5w',
#  'en-sMU_b-kxkdQ',
#  'en-ciZSKPjj5rA',
#  'en-2bxU0UIufCQ',
#  'en-fkqKbO096WE',
#  'en-2UQqoD9FHzk',
#  'en-V6i59PheuiQ',
#  'en-pl-_xl-0R3M',
#  'en,en-CYLbD2oks0A',
#  'en-GB-I3Gx6yWtFIU',
#  'en,en-KpaL35C_-HI',
#  'en-f36Xvv2vzjQ',
#  'en-onfSNiZjPxU',
#  'en-JqoeKhp1TL4',
#  'en-7YCFbWGMOFU',
#  'en-koc11vLGO-4',
#  'en-xsbwZ6Pq2c4',
#  'en-ENncpMFwm2U',
#  'en-gdn8-xps-JE',
#  'en-AXs3i2UoW1A',
#  'en-EM-BgM-Qqj8',
#  'en-w6WvNZBbuYE',
#  'en-pAHgNybY8WI',
#  'en-GTssHSoeDGo',
#  'en-Tl0ZgSThE5Q',
#  'en-kwA0cidvQrg',
#  'en-QnTdjL2_qUI',
#  'en-lTcNyPIB5U4',
#  'en-qAB5Fq03yBw',
#  'en-xV7KiDBj6Fg',
#  'en-tAQ4hImcKYA',
#  'en-uJDqTZqIpmE',
#  'en-rBr0ouVbIOY',
#  'en--UH-iNULyHo',
#  'en-qa9qbEes5cg',
#  'en,en-j7St9X4Tetw',
#  'en,en-6aBbT7oRxLM',
#  'en-vRZYVqSZfRI',
#  'en-n4HivAs74FI',
#  'en-bpsZiO6Z6z0',
#  'en-5m06k7pTjso,en-eEY6OEpapPo',
#  'en-Fd4hxnCufD8',
#  'en-pq_E5OO3DMc',
#  'en-PtLxtQKJUe8',
#  'en-m-XBGA6iMgQ',
#  'en,en-AU',
#  'en,en--Os4ayKvP8k',
#  'en-YzjTkubKa6s',
#  'en-D4Em8AAJKTg',
#  'en-RtQ3btr4J3w',
#  'en-bpcHtLLHgbY',
#  'en-pJiaWBX8SGg',
#  'en-XC-n5_xFQhU',
#  'en-IYi0QQw2yb8',
#  'en-GyZ2GcSBLMQ',
#  'en-U3rlr0shWvg',
#  'en-Dc642RRnt6w',
#  'en-TUoASCAVR04',
#  'en-vKqGZxjE-X4',
#  'en-lWQ7bK81pqg',
#  'en-vAf3QoYfjS4',
#  'en-hdzLK19xFbc',
#  'en-GB-lWQ7bK81pqg',
#  'en-hrRiEqQrYMk',
#  'en-VZaPj70E-cQ',
#  'en-ZbwDLHY73wk',
#  'en-VRQZutW6exs',
#  'en-Mc-l5KuhysI',
#  'en-0hllRZe4s5s,en-iGJpuh49ngc',
#  'en-yKueVqfHYdU',
#  'en-8zkrV7GAeQg',
#  'en-I4NqW1OuItw',
#  'en-PHizVQKyaT8',
#  'en-6GcSGw81TyM',
#  'en,en-GB,en-IE,en-IN',
#  'en-LZLVDZ90HJg',
#  'en-rdGFSo6YWYw',
#  'en-uaodlqUtGlk',
#  'en-j7CkrLLB2No',
#  'en-3pag1knAp8U',
#  'en-cEVAqP0f_G0',
#  'en-S3doMV87xA4',
#  'en-JxeEcfLEAZw',
#  'en-ZyY-uO77toM',
#  'en-I8U16adu9Ao',
#  'en-yUGZRbwkFHY',
#  'en-wVtCXo_byE0',
#  'en,en-8juMyiLfTHE',
#  'en-jzS_7j95uRA',
#  'en-GB-0ukLhsivnNw',
#  'en-xp8wTkmrYBk',
#  'en-zHAsX2OD_Ck',
#  'en-aVFqY5T1TS0',
#  'en-US,en-anMIXjicSL4',
#  'en,en-jwR4iCu2oeQ',
#  'en,en-GB-rSJfcHgCuhE',
#  'en-NSlS7dtTG5o',
#  'en-6ei4hcl37co',
#  'en-SP4rODexMfI',
#  'en-PYsvNJU8zrc',
#  'en-5EatZTF0P8E',
#  'en-yv1qnlVLzoQ',
#  'en-ERHTqSDmRBA',
#  'en-CA-ym5edNzE7Ow',
#  'en-XO6biEujy9M',
#  'en,en-UAf0XEz263s',
#  'en-LHfzsWHceM8',
#  'en-TRqv_jJCFUc',
#  'en-d9EZkvuWXSY',
#  'en-yxUYmUNzXbA',
#  'en-ugpt3ZTHNpg',
#  'en,en-fmYsiOyK3-g',
#  'en-9feNz6QFbwo',
#  'en,en-ta2EIo-0Agw',
#  'en-_0blXBczMBo',
#  'en-eqP-X6xk9NE',
#  'en-v8dpQGAc-d8',
#  'en-6hIILe6Z3Qs',
#  'en--ZoC_Py8hU4',
#  'en-Kz2KN9hZJG0',
#  'en-wjj9m-wANHQ',
#  'en-tFFT0E3L5KY',
#  'en-A19OKdotbTE',
#  'en,en-gbiht3Bo0G4,en-lKWUz2CgtmE',
#  'en-GB-eEY6OEpapPo',
#  'en-7bo4ePph0HE',
#  'en-e0ONNn-Kl-w',
#  'en-LjR8n7Lz-p4',
#  'en-k_wf--qsiAA',
#  'en-US-Iiw-2QMjdD8',
#  'en-EQQL0p207Jk',
#  'en-GnmjnzQ_IiQ',
#  'en,en-CA,en-IN,en-US',
#  'en,en-IN,en-US',
#  'en-Cz1sVjP1r1o',
#  'en-k-RbSZKoSCk',
#  'en-pnZHtGsjvhY',
#  'en-HlcGwNfXzkU',
#  'en-US-zOFsReYi2c4,en-nP7-2PuUl7o',
#  'en-eEY6OEpapPo,en-nP7-2PuUl7o',
#  'en-GB,en-nP7-2PuUl7o',
#  'en-E-ab62m56P0',
#  'en-DwjU7rTr-pQ',
#  'en-Aq89wfGisj4',
#  'en-mIBiXa3O-aM',
#  'en-GB-Rj6tISS247k',
#  'en-IE,en-IN',
#  'en-yU1tISHR1cU',
#  'en-vlqMvZ_EagY',
#  'en-XFdwTH7buVA',
#  'en-US-b3nrla8N478',
#  'en-_yASqOZhnrs',
#  'en-yPS3IiLDWzY',
#  'en--xcNaj9_GHs',
#  'en-5b2-yZHucJo',
#  'en-WVU3oZ6sBt8',
#  'en-US-nPk3V-duwf8',
#  'en-aOBkoefI5-4',
#  'en-GB,en-GB-eEHGWr0Dx3k',
#  'en-mA7n3IYAKQ8',
#  'en-bVoBjau-9u8',
#  'en-6AFV7OuUDIk',
#  'en-9LnJK7YkjGQ',
#  'en,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en,en-CA,en-GB,en-US',
#  'en-CA,en-GB,en-US',
#  'en-0yHdmxR001I',
#  'en-hPGx1GpLXXM',
#  'en-M-wMdNpa-sk',
#  'en-GjwumeVy7HE',
#  'en-GB-sMbCfrtAnXE',
#  'en-XKJ3-9EPpfo',
#  'en-wDaok4uyq2c',
#  'en-6PYU4BfXJRw',
#  'en-Mm-WBSbQgVg',
#  'en-kuJ60RHvJe8',
#  'en-QLSqRHAqJSA',
#  'en-1oAFzPNiuC0,en-uYU-mmqFLq8,en-zL_pKPa_d08',
#  'en-NmRnE_m57ik',
#  'en-UmuJL7B34v8',
#  'en-GB,en-IN',
#  'en-tPYWh49b7dY',
#  'en-16blpPmVDXw',
#  'en-JkeT_87f4cc,en-WhMMu4FR6EA,en-uYU-mmqFLq8',
#  'en-D5BAJqcz8o0',
#  'en,en-GB,en-US',
#  'en,en-mTWoFxlQXE4',
#  'en-Vz6lb-KycrM,en-frRR1ShdaF0',
#  'en-zwzribV5jpg',
#  'en-9upq1y_Il_w,en-uYU-mmqFLq8,en-zL_pKPa_d08',
#  'en-mqEgSABiK3A',
#  'en-w2A1RLSdsBo',
#  'en-4EAJVydkbtI',
#  'en-iw-hPWzcsKk',
#  'en-5Y4u1IzkH2A',
#  'en-M3FTz6BDvH4',
#  'en-sAXuvQpvP94',
#  'en-i6PQtgqa41g',
#  'en-_BZ0tSw-zX4',
#  'en-kVgEwsc-Yzw',
#  'en-etK2C2H8QxQ',
#  'en-gYFX_jzdutk',
#  'en-LowWcOfbRz0',
#  'en-xp7AIyTVSDM',
#  'en-PiSUR-H3p-A',
#  'en-7coGiDq3oJE',
#  'en-oeetDVbazqM',
#  'en-Pobwd6b-BQI',
#  'en-opvMIlCf6yU',
#  'en-ne1kkAzzDEo',
#  'en-l9ZAytQDX8s',
#  'en-AVI3SstIgVg',
#  'en-US-3pK74FgVxOs',
#  'en-EKy-uLtZUwM',
#  'en-AzINBuNud_A',
#  'en-QhNKIcv0o9w',
#  'en-uV_xnKPqpTA',
#  'en-Xq4d7oZ7WUs',
#  'en-40ni5xyRDYc',
#  'en-3JZJhEiiEO0',
#  'en-apj47bPOE6E',
#  'en-0n_kkREWipc',
#  'en-iroYDGvjVPs',
#  'en-qABeYVmG2T8',
#  'en-tWoY4OrN9Ro',
#  'en-75HoPQdITQk',
#  'en-E40TfOK3xzE',
#  'en-KF5XjG2vvvs',
#  'en-LEq064LOwdU',
#  'en-SRUAhgHqNeM',
#  'en-7uKXVR-sleM',
#  'en-MUKFLdkALs8',
#  'en-Easc7SnxoFA',
#  'en-sMO8DSWpiJw',
#  'en,en-YME_-BQi2ZM',
#  'en-ZRr7aanC-Bg',
#  'en,en-ukxnAB508a8',
#  'en-ce1CQ-vJEQM',
#  'en-DAVCo9jsrrQ',
#  'en-M8YHoxz5ms8',
#  'en-PDEGDhA4w_4',
#  'en-ycXGX7SvnPk',
#  'en-QFGQiasiaDw',
#  'en-VCBnncJ4KZ4',
#  'en-35qsMs3jRUM,en-Jyun0WSqg2k',
#  'en-1ECGQ8y9foM',
#  'en-hCy5EFxFrxQ',
#  'en-J9ntHtLQLhQ',
#  ...]

# %% [markdown]
# #### Checking if data downloaded from 1st round is a subset of data collection subsampled from and downloaded in 2nd round
# It is.

# %%
with open("data/metadata/approx_en_relaxed.txt", "r") as f:
    approx_en_only = [line.strip() for line in f]

# %%
set(id_downloaded) - set(approx_en_only)
# Out:
# set()

# %% [markdown]
# #### Getting approximately English data to download (3rd round)
# - This entails the same conditions (to get approx English data) as 1st round

# %%
with open("logs/data/download/2M_en/2M_download_ids.txt", "r") as f:
    id_downloaded = [line.strip().split("\t")[0] for line in f]
with open("logs/data/download/6M_en/subsampled_ids.txt", "r") as f:
    id_downloaded.extend([line.strip().split("\t")[0] for line in f])
print(id_downloaded[:5])
print(len(id_downloaded))
# Out:
# ['05xOF5ubabQ', 'GjTPw_aQmgg', 'T9_3s_yybq8', 'nKZSV-h0SGA', '3993tVeKd-w']
# 8448500

# %%
all_ids = set(main_df_dedup['id'])
downloaded_ids = set(id_downloaded)

not_downloaded_ids = all_ids - downloaded_ids

not_downloaded_df = main_df_dedup[main_df_dedup['id'].isin(not_downloaded_ids)]

# %%
not_downloaded_df.reset_index(drop=True, inplace=True)

# %%
print(not_downloaded_df.shape[0])
# Out:
# 51649651

# %%
not_downloaded_df["std_man_cap_langs"] = not_downloaded_df["manual_caption_languages"]
not_downloaded_df["std_man_cap_langs"] = not_downloaded_df["std_man_cap_langs"].apply(standardize_dialects)
view_lang_cols(not_downloaded_df, 10)
# Out:
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_1581/2348566584.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_downloaded_df["std_man_cap_langs"] = not_downloaded_df["manual_caption_languages"]
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_1581/2348566584.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_downloaded_df["std_man_cap_langs"] = not_downloaded_df["std_man_cap_langs"].apply(standardize_dialects)
#             id                                              title language  \
# 0  LwJv3vSd8no                                Free Art Wednesday!       en
# 1  XXjYyBCNJEY                                 FREE Art Wednesday     None
# 2  OREjUtUT2Sc                     New Intro | I keep losing them     None
# 3  cNPxiPUdyvA                         (Примьера дораммы 2021!!!)     None
# 4  2XitiLKk6rM                                 Анонимки в тик ток       ru
# 5  IPxXLQpOJRU                                      Marisa Marisa     None
# 6  ug5TkquQEHo                                      Marisa marisa     None
# 7  Ar-XwEnnFPY              Formation des Classe D | Serveur UPRP       fr
# 8  nmRxk7k3kvU                           Meditation Music video-2     None
# 9  y9v4phX48UA  عودة ملوك العواصف الى سيرفر الجامعة/لعبة الامب...     None
#
#   manual_caption_languages automatic_caption_orig_language std_man_cap_langs
# 0                       en                              en                en
# 1                       en                              en                en
# 2                       en                              en                en
# 3                       sv                              sv                sv
# 4                       sv                              ru                sv
# 5                       it                              it                it
# 6                       it                              it                it
# 7                    fr-FR                              fr                fr
# 8                    en-US                           en-US                en
# 9                       ar                              ar                ar

# %%
condition = (
    not_downloaded_df["std_man_cap_langs"]
    .str.split(",")
    .apply(lambda lst: set(lst) == {"en"})
) & (not_downloaded_df["automatic_caption_orig_language"] == "en")
only_en_man_auto = not_downloaded_df[condition]

# %%
only_en_man_auto.shape[0]
# Out:
# 12745843

# %%
sum(only_en_man_auto["duration"]) / (60 * 60)
# Out:
# 2290777.251388889

# %% [markdown]
# #### Established conditions for English-only data for training
# ```
# df_1["man_cap_langs_2"] = df_1["manual_caption_languages"]
# condition = (
#         df_1["man_cap_langs_2"]
#         .str.split(",")
#         .apply(lambda lst: set(lst) == {"en"})
#     ) & (df_1["automatic_caption_orig_language"] == "en")
# df_2 = df_1[condition]
# ```
# - To download transcript w/ specific language code, just use the 1st language.

# %% [markdown]
# #### Established conditions for English-only data (for statistics and future exploration/filtering)

# %% [markdown]
# ## Is number of hours proportional to number of audio-transcript pairs? As in, can you estimate the number of hours from number of audio-transcript pairs?
# No, it is not.

# %%
# calculating total duration from all trainable audio-transcript pairs
with open("logs/data/download/2M_en/2M_trainable_ids.txt", "r") as f:
    trainable_ids_2M = [line.strip() for line in f]
trainable_ids_2M_df = main_df_dedup[main_df_dedup["id"].isin(trainable_ids_2M)]
total_dur = trainable_ids_2M_df["duration"].sum() / (60 * 60)
print(total_dur)
# Out:
# 411584.1433333333

# %%
print(len(trainable_ids_2M))
# Out:
# 2300152

# %%
trainable_2M_dur = total_dur

# %%
# calculating total duration from all audio-transcript pairs subsampled randomly for downloading and training
with open("logs/data/download/2M_en/2M_download_ids.txt", "r") as f:
    durs = [int(line.strip().split("\t")[-1]) for line in f]
print(sum(durs) / (60 * 60))
downloadable_2M_dur = sum(durs) / (60 * 60)
# Out:
# 438202.3872222222

# %%
# if 438202 hours correspond to 2448500 audio-transcript pairs, then how many hours correspond to 2300152 audio-transcript pairs?
est_trainable_2M_dur = (len(trainable_ids_2M) * downloadable_2M_dur) / len(id_downloaded)
print(trainable_2M_dur, est_trainable_2M_dur)
# it looks like they're quite close, so it seems that the duration of the subsampled audio-transcript pairs is quite 
# representative of the total duration of all audio-transcript pairs
# but let's check again...
# Out:
# 411584.1433333333 411652.8884516924

# %%
# getting the video IDs after best filter
with open("logs/data/download/2M_en/2M_bestfilter_10_12.txt", "r") as f:
    bestfilter_2M = [line.strip() for line in f]
bestfilter_2M[:5]
# Out:
# ['pkp_MM22ivE', 'q7QPE66HoNY', 'qHeOWpL7uCI', 'qJoGRiG_iOQ', 'qPUT1ovOqjc']

# %%
bestfilter_2M_df = main_df_dedup[main_df_dedup['id'].isin(bestfilter_2M)]
bestfilter_2M_df.shape[0]
# Out:
# 1175427

# %%
# duration of all audio-transcript pairs after best filter
bestfilter_hours_kept = sum(bestfilter_2M_df['duration']) / (60 * 60)
print(bestfilter_hours_kept)
# Out:
# 122121.75833333333

# %%
# if 411584 hours correspond to 2300152 audio-transcript pairs, then how many hours correspond to 1175427 audioo-transcript pairs?
est_bestfilter_dur = (bestfilter_2M_df.shape[0] * 411584.1433333333) / 2300152
act_bestfilter_dur = sum(bestfilter_2M_df['duration']) / (60 * 60)
print(act_bestfilter_dur, est_bestfilter_dur)
# they're quite different, so the duration of the subsampled audio-transcript pairs is not representative of the 
# total duration of all audio-transcript pairs
# Out:
# 122121.75833333333 210328.3238872344

# %% [markdown]
# ## How to systematically calculate how much to subsample from raw data pool and download
# - Calculate reduction in data by **hours** after filtering (percentage and hours)
# - If this reduction leads to number of hours **<440K hours**, then
#     - Using percentage of reduction in data hours, calculate how much might be needed to enable reduction and yield minimum number of data hours to fulfill 440K hours (reduction in data hours)
#     - Also account for how much might be removed when trying to download (downloadable) and segmented (trainable)
# - Randomly subsample from the raw data pool iteratively until total duration of sample meets requirement

# %% [markdown]
# ### For 2nd round of downloading, when only had 122K hours of filtered data (from 1st round of downloading)
# *Note: Using variables from previous portion, don't delete!*

# %%
# calculating the reduction in data hours
bestfilter_hours_red = trainable_2M_dur - bestfilter_hours_kept
print(f"{bestfilter_hours_kept=}, {bestfilter_hours_red=}")
perc_kept = (bestfilter_hours_kept / trainable_2M_dur) * 100
# calculating the reduction in data hours by percentage
perc_reduced = (100 - perc_kept)
print(f"{perc_kept=}, {perc_reduced=}")
# Out:
# bestfilter_hours_kept=122121.75833333333, bestfilter_hours_red=289462.385
# perc_kept=29.671152378294973, perc_reduced=70.32884762170502

# %%
approx_hours_needed = (440000 - bestfilter_hours_kept)
approx_hours_subsample = (100 * approx_hours_needed) / perc_kept
print(f"{approx_hours_needed=}, {approx_hours_subsample=}")
# Out:
# approx_hours_needed=317878.2416666667, approx_hours_subsample=1071337.7007197093

# %% [markdown]
# ### For 3rd round of downloading, when only had 230K hours of filtered data (from 1st and 2nd round of downloading)

# %%
approx_hours_needed = (440000 - 230000)
approx_hours_subsample = (100 * approx_hours_needed) / perc_kept
print(f"{approx_hours_needed=}, {approx_hours_subsample=}")
# Out:
# approx_hours_needed=210000, approx_hours_subsample=707758.1528434976

# %% [markdown]
# ## Randomly subsample English data for downloading to get sufficient data to filter down to 440K hours
#
# (subject to change for non-English data)

# %% [markdown]
# ### For 3rd round of downloading

# %%
subsampled_ids = subsample_data(df=only_en_man_auto, per_iter_sample=1000000, hours_to_subsample=700000)
# Out:
# dur=180319.0113888889
# len(subsampled_values)=1000000
# dur=360395.36805555556
# len(subsampled_values)=1000000
# dur=539037.1127777777
# len(subsampled_values)=1000000
# dur=719333.1136111111
# len(subsampled_values)=1000000

# %% [markdown]
# #### Checking subsampled data

# %%
subsampled_df = not_downloaded_df[not_downloaded_df["id"].isin(subsampled_ids)]

# %%
view_lang_cols(subsampled_df)
# Out:
#              id                                              title language  \
# 1   XXjYyBCNJEY                                 FREE Art Wednesday     None
# 33  VvPE3uB7O1A                    Nature Moment | The Holly Plant       en
# 36  8SnK7mWezWw  Jobs for Veterans: Janine Hardman RN, BSN, Arm...       en
# 40  lVBVy0EY0I4  BMC Presents: Donate Life - Bob & Mike featuri...       en
# 50  0Yt4JoCW8oU                        G Gundam Screenshop Repaint       en
#
#    manual_caption_languages automatic_caption_orig_language std_man_cap_langs
# 1                        en                              en                en
# 33                       en                              en                en
# 36                       en                              en                en
# 40                       en                              en                en
# 50                    en-US                              en                en

# %%
[lang for lang in subsampled_df["manual_caption_languages"].unique() if "en" not in lang]
# Out:
# []

# %% [markdown]
# #### Getting language code for transcript (random choice)

# %%
subsampled_df["man_cap_langs_list"] = subsampled_df["manual_caption_languages"].apply(lambda langs: langs.split(","))
# Out:
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_1581/2082786853.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subsampled_df["man_cap_langs_list"] = subsampled_df["manual_caption_languages"].apply(lambda langs: langs.split(","))

# %%
rng = np.random.default_rng(42)
subsampled_df["download_lang"] = subsampled_df["man_cap_langs_list"].apply(lambda langs: rng.choice(langs) if len(langs) > 0 else langs[0])
# Out:
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_1581/2294997270.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subsampled_df["download_lang"] = subsampled_df["man_cap_langs_list"].apply(lambda langs: rng.choice(langs) if len(langs) > 0 else langs[0])

# %%
view_lang_cols(subsampled_df, 20)
# Out:
#               id                                              title language  \
# 1    XXjYyBCNJEY                                 FREE Art Wednesday     None
# 33   VvPE3uB7O1A                    Nature Moment | The Holly Plant       en
# 36   8SnK7mWezWw  Jobs for Veterans: Janine Hardman RN, BSN, Arm...       en
# 40   lVBVy0EY0I4  BMC Presents: Donate Life - Bob & Mike featuri...       en
# 50   0Yt4JoCW8oU                        G Gundam Screenshop Repaint       en
# 52   orWh_OLaRg4  All Goals | Final Copa America | Argentina (1)...       en
# 59   P4xDdWmDdsY  DOĞADA HAYAT 39.BÖLÜM  ATEŞ KUTUSUNDA SUCUK | ...     None
# 76   XuAsD43fbSU  Hokkaido Sweet Corn & Meal Pouch For Travelers...     None
# 77   jMT8OdDL_hE  Spicy Miso Ramen In Kyoto! | 15 Days Around Ja...     None
# 80   KpHg0kxFtMo  Beef Burger & Cheese Yang SUPER DAHSYAT | Burg...     None
# 83   _VxLBZkZRek  Z*nger Cheezy Burger Yang SUPER MURAH & SEDAP ...     None
# 86   gPgI_OsFk0g  COMING SEPT 2021 - NEW MUSIC FROM "CUSTOM"! - ...     None
# 90   y3o-baXQT0Q                             VLOG #1 - Introduction       en
# 94   NVeVNuC34wI  VACATION with my EGYPTIAN INSTAGRAM CRUSH *cri...       en
# 126  zHGwE0ritgk       Let's Play Minecraft: Greatest freakout ever       en
# 153  kpbzCl6_zwQ           Mobile Legends || RANK PUSH || SUBSCRIBE       en
# 154  _vcLAPLnv4o  1Granja Helio,  2 Aniversario Alvaro , 3 Brasilia     None
# 156  Kfdc3s1hl9k                                         Natal 1996     None
# 183  rpzuQAFXBf8             [BLENDER] The Watchers TEASER No audio     None
# 189  yheXewLTg3U  Opal- Mirror Man but every other beat is missi...       en
#
#           manual_caption_languages automatic_caption_orig_language  \
# 1                               en                              en
# 33                              en                              en
# 36                              en                              en
# 40                              en                              en
# 50                           en-US                              en
# 52   en-JkeT_87f4cc,en-uYU-mmqFLq8                              en
# 59                              en                              en
# 76                              en                              en
# 77                              en                              en
# 80                              en                              en
# 83                              en                              en
# 86                              en                              en
# 90                           en-US                              en
# 94                              en                              en
# 126                 en-18WT74-rBWA                              en
# 153                             en                              en
# 154                 en-uYU-mmqFLq8                              en
# 156                 en-uYU-mmqFLq8                              en
# 183                             en                              en
# 189                             en                              en
#
#     std_man_cap_langs                man_cap_langs_list   download_lang
# 1                  en                              [en]              en
# 33                 en                              [en]              en
# 36                 en                              [en]              en
# 40                 en                              [en]              en
# 50                 en                           [en-US]           en-US
# 52              en,en  [en-JkeT_87f4cc, en-uYU-mmqFLq8]  en-JkeT_87f4cc
# 59                 en                              [en]              en
# 76                 en                              [en]              en
# 77                 en                              [en]              en
# 80                 en                              [en]              en
# 83                 en                              [en]              en
# 86                 en                              [en]              en
# 90                 en                           [en-US]           en-US
# 94                 en                              [en]              en
# 126                en                  [en-18WT74-rBWA]  en-18WT74-rBWA
# 153                en                              [en]              en
# 154                en                  [en-uYU-mmqFLq8]  en-uYU-mmqFLq8
# 156                en                  [en-uYU-mmqFLq8]  en-uYU-mmqFLq8
# 183                en                              [en]              en
# 189                en                              [en]              en

# %% [markdown]
# #### Converting subsampled dataframe to JSONL batches

# %%
rng = np.random.default_rng(42)
shuffled_subsampled_ids_langs = subsampled_df[["id", "download_lang"]].values.tolist()
rng.shuffle(shuffled_subsampled_ids_langs)
shuffled_subsampled_ids_langs[:5]
# Out:
# [['CpqFbRHQ4u0', 'en-SUqXwpdmyfE'],
#  ['acHsTL-bGE0', 'en-nP7-2PuUl7o'],
#  ['XlzA78sVUcw', 'en'],
#  ['ZupL8HxoSRA', 'en'],
#  ['jCvdxiTm6qM', 'en-uYU-mmqFLq8']]

# %%
len(shuffled_subsampled_ids_langs)
# Out:
# 4000000

# %%
subsampled_batches = get_subsampled_batches(shuffled_subsampled_ids_langs, 250)
print(len(subsampled_batches))
subsampled_batches[:5]
# Out:
# 16000
# [{'videoIds': [['CpqFbRHQ4u0', 'en-SUqXwpdmyfE'],
#    ['acHsTL-bGE0', 'en-nP7-2PuUl7o'],
#    ['XlzA78sVUcw', 'en'],
#    ['ZupL8HxoSRA', 'en'],
#    ['jCvdxiTm6qM', 'en-uYU-mmqFLq8'],
#    ['yiWXOwrVITY', 'en-US'],
#    ['j9l_OFYuDtM', 'en-uYU-mmqFLq8'],
#    ['UoOMKnzYcNU', 'en'],
#    ['yx7e8Oi-8dQ', 'en'],
#    ['-esQO8EqlGc', 'en'],
#    ['yGrXM9v2JLQ', 'en'],
#    ['aYMOIrScCg0', 'en-uYU-mmqFLq8'],
#    ['BZJ4yMKK96s', 'en'],
#    ['9Ud1oYgf-Gk', 'en'],
#    ['Zl2_koMI5ns', 'en'],
#    ['CSV1teyQKj8', 'en-uYU-mmqFLq8'],
#    ['8xBhsHbEfbo', 'en-US'],
#    ['2GNcGt9mFQs', 'en-nP7-2PuUl7o'],
#    ['A4wjXqyMCtU', 'en'],
#    ['5RnJ8Qs7xzM', 'en'],
#    ['0t0FfURt0Xs', 'en-US'],
#    ['XcOSh2hF1nw', 'en-US'],
#    ['i-reXVO2FpY', 'en'],
#    ['9WAMMi_yIzI', 'en-uYU-mmqFLq8'],
#    ['BYPASyonibk', 'en-US'],
#    ['cI1viD2hiLI', 'en-LUU0EuDKgKo'],
#    ['37f_qFubHAM', 'en-US'],
#    ['rE0kUQwqwv4', 'en'],
#    ['cvvoZ9Or0xo', 'en-uYU-mmqFLq8'],
#    ['6lBZ4eUUA-w', 'en'],
#    ['d8qUCEY__Ys', 'en-uYU-mmqFLq8'],
#    ['iyUm25vNQ9A', 'en-US'],
#    ['dPhbUavjSKc', 'en'],
#    ['E_VQwBN5XSI', 'en-GB'],
#    ['qRU1dWQlO4s', 'en-US'],
#    ['RSxtEXqobrc', 'en'],
#    ['yxO5e6tcdWQ', 'en-US'],
#    ['KNcZ4IYf47Q', 'en-uYU-mmqFLq8'],
#    ['j1w2f26iQEI', 'en-GB'],
#    ['jDDiuAgPy3M', 'en-uYU-mmqFLq8'],
#    ['vcSs3iNpxGU', 'en-nP7-2PuUl7o'],
#    ['_L_yb781iI4', 'en-uYU-mmqFLq8'],
#    ['pO_TMjAxQSg', 'en-US'],
#    ['doa28-YrTBQ', 'en-JkeT_87f4cc'],
#    ['HFDJDmgIZ3k', 'en'],
#    ['hkWJMqGzgMw', 'en'],
#    ['kgdFNgySMj4', 'en-Fu8PMtSvQF4'],
#    ['xBIEIKFMo6g', 'en-GB'],
#    ['0O2AlxocZ60', 'en'],
#    ['qR41sLd8xZ8', 'en-GB'],
#    ['kZUX5ZD-qaI', 'en'],
#    ['QwiSt0eBXiw', 'en'],
#    ['GTOzZCUlnmg', 'en'],
#    ['WY-KN1cO4M4', 'en-US'],
#    ['fiE_V4tNjXk', 'en-US'],
#    ['whyUtRypkS0', 'en-Rn4wFefFgng'],
#    ['xG8mQA7DtSc', 'en-uYU-mmqFLq8'],
#    ['GRftBW0KB-c', 'en-uYU-mmqFLq8'],
#    ['ah5Uy9Z3R88', 'en'],
#    ['beuOG00sDjY', 'en-uYU-mmqFLq8'],
#    ['HbpR0mCzjfU', 'en-US'],
#    ['cymogGp2Mpk', 'en-nP7-2PuUl7o'],
#    ['bsC3k4cnbf8', 'en'],
#    ['qEB8LjgG3Jo', 'en'],
#    ['PugTe8cuQTc', 'en'],
#    ['WJJjp_x1JIg', 'en'],
#    ['6mfkWEONP1Q', 'en-nP7-2PuUl7o'],
#    ['zrLChHm3LRg', 'en'],
#    ['6ohSi4ogVAw', 'en-US'],
#    ['8SW7-pqVLW8', 'en'],
#    ['c4zEhkSFigY', 'en'],
#    ['JxxFiGT9d_w', 'en'],
#    ['CChOqII6uPc', 'en-uYU-mmqFLq8'],
#    ['uEhbpAt2TT8', 'en-GB'],
#    ['uA2uqyiPNfg', 'en'],
#    ['g2EE4YkMR84', 'en'],
#    ['tBanLdTL5nI', 'en-uYU-mmqFLq8'],
#    ['6AKzkaN1iE0', 'en-US'],
#    ['Z-yx2k5tv5w', 'en'],
#    ['LpaOwSJSpFs', 'en'],
#    ['UVEitkUHIck', 'en-nP7-2PuUl7o'],
#    ['nSMCMZo_Zsc', 'en'],
#    ['lpT5xd3KE-E', 'en-l3E-OcoDogs'],
#    ['9x7ujcRUnog', 'en'],
#    ['XHSumkIFDtw', 'en-uYU-mmqFLq8'],
#    ['8xlt0Oe7fSw', 'en'],
#    ['zU0Op0V0MTM', 'en'],
#    ['JzwgT2nAsKY', 'en-nP7-2PuUl7o'],
#    ['Q0k73jmoEj8', 'en-1oAFzPNiuC0'],
#    ['47qWvqKNotM', 'en-uYU-mmqFLq8'],
#    ['fKvHJFtPD8o', 'en-US'],
#    ['F_uYZjxxC38', 'en-US'],
#    ['JKnqfwr8hrg', 'en'],
#    ['Lj80daNf7io', 'en'],
#    ['EQYRhLyj91M', 'en'],
#    ['woD6eCDUyg8', 'en'],
#    ['GsJlP0gvbsQ', 'en-nP7-2PuUl7o'],
#    ['9UHXEwDAb3k', 'en'],
#    ['iLGl80d9Hy4', 'en'],
#    ['R11dalGB-qQ', 'en'],
#    ['BoHYlDBHIGY', 'en'],
#    ['vsE54kD3m-I', 'en'],
#    ['nrpTED_MzHw', 'en-uYU-mmqFLq8'],
#    ['5mEh52xkMnc', 'en-uYU-mmqFLq8'],
#    ['JSBUXNCGLd4', 'en'],
#    ['y6SNQw7Rg74', 'en-US'],
#    ['w9b3CS7SpWY', 'en'],
#    ['siTQXmm1oIQ', 'en-US'],
#    ['ZRQlpDBeAA8', 'en-nP7-2PuUl7o'],
#    ['0e5qt15IGV0', 'en'],
#    ['Vbl7z4G97XY', 'en-uYU-mmqFLq8'],
#    ['BJG4BHGF8zU', 'en-RTbB2cpHawQ'],
#    ['tyS72dsB4bI', 'en'],
#    ['tEIBF9zrz9g', 'en-US'],
#    ['9GOHeEatKRk', 'en-US'],
#    ['-yIuoSazSSA', 'en-GB'],
#    ['nuXCsZSYt9c', 'en-nP7-2PuUl7o'],
#    ['2ELvZlJ278Y', 'en'],
#    ['o8H_nyD01co', 'en-cvfXDfbeED0'],
#    ['IAfMBWlWpLs', 'en'],
#    ['QVPPGjxtl6Q', 'en'],
#    ['p_zrJlXC8_E', 'en-GB'],
#    ['Oe5MsYXEB5U', 'en-uYU-mmqFLq8'],
#    ['_Bo8bgw8KPw', 'en'],
#    ['qGmhqFy2QI0', 'en'],
#    ['s3dL6cCagaU', 'en-GB'],
#    ['-uXfwA_XaaU', 'en'],
#    ['UpBJJ5yYaSw', 'en'],
#    ['7mvhgsEe9yw', 'en'],
#    ['nxahqzNLBfU', 'en'],
#    ['QORIgHTq8gI', 'en'],
#    ['0vsPu__6KII', 'en'],
#    ['dGy1K5ri26g', 'en-eEY6OEpapPo'],
#    ['Z5XB9u7OyE8', 'en'],
#    ['1Hw3xHGW--0', 'en'],
#    ['lRWjPdYWJL4', 'en-nP7-2PuUl7o'],
#    ['PCrCqZ_RTf8', 'en'],
#    ['3XBSeHGIVTA', 'en-eEY6OEpapPo'],
#    ['5Xr8XJw467A', 'en'],
#    ['Ow6oz7anpjM', 'en-nP7-2PuUl7o'],
#    ['2I40IfDEZsc', 'en-nP7-2PuUl7o'],
#    ['KER_ToELCM4', 'en-GB'],
#    ['PFV-Scy1FeA', 'en'],
#    ['tZVqG2ZxnFY', 'en-uYU-mmqFLq8'],
#    ['9dunbzrmEk4', 'en'],
#    ['XKk_lQ6S7t0', 'en'],
#    ['nlJ_I33QaVY', 'en-US'],
#    ['tDT7fZnZodc', 'en-KG216eMdtEE'],
#    ['1Ew9yDp8RZs', 'en'],
#    ['zWtiweJtHKo', 'en-uYU-mmqFLq8'],
#    ['Q6uFKlzQs7c', 'en'],
#    ['pDiIGxG2SCg', 'en-US'],
#    ['CMla4q_W-tc', 'en'],
#    ['qNvZky1vASA', 'en-uYU-mmqFLq8'],
#    ['CrGHGwH2wlg', 'en'],
#    ['Fmv6cXeXaUM', 'en-uYU-mmqFLq8'],
#    ['1u4ujuLGevU', 'en'],
#    ['u6uadbTYPls', 'en'],
#    ['QmUYL8e9gjw', 'en-ehkg1hFWq8A'],
#    ['37oPMUC0qXA', 'en-nP7-2PuUl7o'],
#    ['8jZJS273g3U', 'en-j3PyPqV-e1s'],
#    ['GOOmalRan6U', 'en'],
#    ['o7jjCvr4RtI', 'en'],
#    ['B44Sd5dHDbg', 'en'],
#    ['KnZkIxbBKRw', 'en-1oAFzPNiuC0'],
#    ['v6cCGva8SL0', 'en'],
#    ['qhZRrtU2D5M', 'en'],
#    ['7JIhweByZtM', 'en'],
#    ['EfYuVUTkt7k', 'en'],
#    ['2INWDKj_UKM', 'en-JkeT_87f4cc'],
#    ['il3x1Y21X5I', 'en'],
#    ['DVM4PMbdcaM', 'en'],
#    ['rvIi7Zn8u0I', 'en-uYU-mmqFLq8'],
#    ['VsGITySlq5c', 'en-uYU-mmqFLq8'],
#    ['agFpLT4Lh8Q', 'en'],
#    ['Kgyc8Knh88k', 'en-uYU-mmqFLq8'],
#    ['WP6M354Q88Y', 'en-uYU-mmqFLq8'],
#    ['5ZelWHxkQAU', 'en-AU'],
#    ['U0jr3uy2BPE', 'en'],
#    ['wlWdA4pEODA', 'en'],
#    ['hL-YnDXa4fo', 'en'],
#    ['Q8uXJBiAj00', 'en'],
#    ['tCg8D1OLAMY', 'en-uYU-mmqFLq8'],
#    ['VtiW3fArZ8g', 'en-CA'],
#    ['uyc9lzCp1EM', 'en'],
#    ['9LF-jkDbS8o', 'en'],
#    ['qhyZOtOG1Iw', 'en'],
#    ['10NQ5T6Nj-U', 'en'],
#    ['qyKmCZl4HpU', 'en'],
#    ['uPYwKOwQW14', 'en'],
#    ['c3Z44P9GwHA', 'en'],
#    ['T9ubOMg1XX8', 'en'],
#    ['bF1qAxxIEqI', 'en'],
#    ['Y1RZZvJfoNQ', 'en-nP7-2PuUl7o'],
#    ['z7Z6Zhe0w-8', 'en'],
#    ['Zs5pbL1u5e8', 'en-US'],
#    ['Np1pxLCiMsU', 'en'],
#    ['nCTpzRdeX1g', 'en'],
#    ['bhUasXKGqM0', 'en-US'],
#    ['foLakeYugpg', 'en'],
#    ['u3sXjwePY-c', 'en'],
#    ['kCxinQyHQBg', 'en-nP7-2PuUl7o'],
#    ['r4Ru6h_Pf0A', 'en-US'],
#    ['8q0p6TxTqJI', 'en-IN'],
#    ['RLqc3Vtt2E8', 'en'],
#    ['33C3xF9Nxpk', 'en-vlW2OHFw3ww'],
#    ['V178pc7u-E0', 'en-JkeT_87f4cc'],
#    ['SYZDmwYM7nk', 'en'],
#    ['ohwrTS0fNc8', 'en-nP7-2PuUl7o'],
#    ['AXhrmg58f2s', 'en-JkeT_87f4cc'],
#    ['Fzcui5zaNyY', 'en'],
#    ['H9sNIiMcF3w', 'en-GB'],
#    ['TmafdWfkvAY', 'en-uYU-mmqFLq8'],
#    ['3RTrq0aiDnk', 'en-uYU-mmqFLq8'],
#    ['9uF4ZlU0V40', 'en'],
#    ['yyITM66-jj4', 'en-uYU-mmqFLq8'],
#    ['Rx1YHAnowwo', 'en-US'],
#    ['0KgwzBoQOko', 'en-US'],
#    ['xkMGuF7Q2DA', 'en-US'],
#    ['3_6kwqP1kGU', 'en-GB'],
#    ['Fz5HAUTbqsc', 'en-nP7-2PuUl7o'],
#    ['Pq_D9lFSs4o', 'en-JkeT_87f4cc'],
#    ['onCFCmEm6Uw', 'en'],
#    ['kFSEQxSFGpM', 'en'],
#    ['qaHwzTJixxY', 'en-RTbB2cpHawQ'],
#    ['cTBuf-pJsm4', 'en'],
#    ['fu8C5fXPqQg', 'en-uYU-mmqFLq8'],
#    ['tjJXWVLd2D0', 'en-GB'],
#    ['e22V28av1ek', 'en'],
#    ['FoGcK2bqXIc', 'en-nP7-2PuUl7o'],
#    ['l46Mf72h5is', 'en'],
#    ['n5CKLQwApcQ', 'en-anMIXjicSL4'],
#    ['XKXYxuzw6a0', 'en-nP7-2PuUl7o'],
#    ['RzCwjkUPKGU', 'en-US'],
#    ['6etENAQo9Is', 'en'],
#    ['Wtb0totOXcI', 'en-GLTvy4jNFQs'],
#    ['ko1zmf7EiMk', 'en'],
#    ['B_tNbZQkvQQ', 'en-US'],
#    ['rBmVh21gTSU', 'en'],
#    ['H89IlAYEnO4', 'en'],
#    ['QY3lYwJl3P8', 'en'],
#    ['6kWuKXQ7YVs', 'en'],
#    ['gg3IFyl592E', 'en'],
#    ['Dua3jepLw0k', 'en-GB'],
#    ['lGc1YFifSec', 'en'],
#    ['U_nIABuBNW0', 'en'],
#    ['f5DN80d614w', 'en'],
#    ['i0sQ7U8pNZI', 'en'],
#    ['hMLFi5mbznY', 'en'],
#    ['PtYkMsRBXWo', 'en']],
#   'batchIdx': 0},
#  {'videoIds': [['QWTSjq19dSg', 'en'],
#    ['otnAE6IU9P0', 'en-ehkg1hFWq8A'],
#    ['-ibc5tLT2_c', 'en-JkeT_87f4cc'],
#    ['Yg19NJgVEcI', 'en'],
#    ['wYjhUicbO-g', 'en-nP7-2PuUl7o'],
#    ['GyghWDK0B4E', 'en'],
#    ['-_Ke8dl7FqI', 'en'],
#    ['fK_YB07Wdr8', 'en'],
#    ['lBYzVYfaJhg', 'en'],
#    ['v-6-ujg-Oqs', 'en'],
#    ['PPOwd3JNuhE', 'en-VCyuJicDkwk'],
#    ['Vq-kX2Bpb0U', 'en'],
#    ['8C7PUlPWQJs', 'en-nP7-2PuUl7o'],
#    ['-aA0hnwsoA4', 'en'],
#    ['G43pOVvRk3A', 'en'],
#    ['m4XVRvL7CuE', 'en-nP7-2PuUl7o'],
#    ['NzGsCNHR5Mc', 'en'],
#    ['SgLESBcu7uo', 'en'],
#    ['J1Q6DK4Ku6U', 'en-uYU-mmqFLq8'],
#    ['Ylom4xBCo1k', 'en'],
#    ['Mz_9prar2rQ', 'en-uYU-mmqFLq8'],
#    ['4dIy5GT4gmo', 'en'],
#    ['4umc2l5DaPo', 'en'],
#    ['qLKoM6O79rI', 'en'],
#    ['0s1gEIQACOs', 'en'],
#    ['g6jeSuHYhyY', 'en'],
#    ['472X0YVXk0A', 'en'],
#    ['A0y4adfd-3A', 'en-uYU-mmqFLq8'],
#    ['PmRVesNbqYc', 'en'],
#    ['HIqai0NuBU4', 'en'],
#    ['maYdR8bl0UQ', 'en-nP7-2PuUl7o'],
#    ['KkSj2w4FAl4', 'en'],
#    ['vscNAXr2DvI', 'en-US'],
#    ['cftCvd-9o6A', 'en-uYU-mmqFLq8'],
#    ['aVHKtSqCreU', 'en-GB'],
#    ['ZArwNZdKSpI', 'en-JkeT_87f4cc'],
#    ['jcrxADcy1Ys', 'en-eEY6OEpapPo'],
#    ['ix33PM2oa2I', 'en-W6XwBH-tLyY'],
#    ['NTl0IssrNOw', 'en-US'],
#    ['KRT2ehET1xU', 'en-uYU-mmqFLq8'],
#    ['-VxZMYaxgsk', 'en-US'],
#    ['0dEz4m9vwE8', 'en'],
#    ['DvnmlyTou-Y', 'en'],
#    ['FxGC0dpeS4g', 'en'],
#    ['fgb0gmFkYM4', 'en'],
#    ['amSWWYxHlwU', 'en'],
#    ['SOS66CrF_GY', 'en-US'],
#    ['U844NdJtOP4', 'en-nP7-2PuUl7o'],
#    ['v6N8F_ezAc0', 'en-uYU-mmqFLq8'],
#    ['4u_KQjVnAFI', 'en-ehkg1hFWq8A'],
#    ['FGRUpRnjBPY', 'en'],
#    ['x98fPdN89cU', 'en-qlPKC2UN_YU'],
#    ['ordy9dlYQ-0', 'en'],
#    ['jEzdziTnjbg', 'en-CA'],
#    ['FyruAZVEULI', 'en'],
#    ['xZbVHhfdZGo', 'en-nP7-2PuUl7o'],
#    ['eQmLdgp-xRU', 'en'],
#    ['E_PNA-lIEU0', 'en'],
#    ['tROyfAwSKNM', 'en'],
#    ['rSvX1YDiOKY', 'en'],
#    ['Tu5q11WjI7w', 'en-nP7-2PuUl7o'],
#    ['JbFV3gNvVx8', 'en-uYU-mmqFLq8'],
#    ['dEup7FycHwY', 'en'],
#    ['at6GWX0pO1s', 'en-uYU-mmqFLq8'],
#    ['MRC196M6pJU', 'en-uYU-mmqFLq8'],
#    ['Gx1xT0B__Eo', 'en-YD9w56fD1Sw'],
#    ['7hpQKVp2iEQ', 'en-ehkg1hFWq8A'],
#    ['m5YTmH5cubE', 'en-uYU-mmqFLq8'],
#    ['FnyBZHSe1_k', 'en-uYU-mmqFLq8'],
#    ['2mLGZH7YCVA', 'en'],
#    ['dKqOA-Kf6hE', 'en-US'],
#    ['I3yYPpBE4hc', 'en-nP7-2PuUl7o'],
#    ['Ei_Hey6T68Q', 'en-US'],
#    ['Qex_ctPpz3o', 'en'],
#    ['kkw1XbVac5I', 'en-US-j2MDp-89Ry4'],
#    ['pr19vmKpWTE', 'en'],
#    ['Sfuj-9kAuKE', 'en'],
#    ['nH8n0Y-6H-k', 'en-JkeT_87f4cc'],
#    ['mQke1L_fF-c', 'en-uYU-mmqFLq8'],
#    ['ktZJFaxlZN8', 'en-qoXxhA4oLYo'],
#    ['M1aJXfC3Foc', 'en-l7WQcsdt50o'],
#    ['cwglWRDw29s', 'en'],
#    ['OIuo7tp7zmU', 'en'],
#    ['EBYq5N592Eg', 'en'],
#    ['UY01n1RGHVM', 'en'],
#    ['jqoIbSNEQk0', 'en'],
#    ['74wOvNu9PkE', 'en-uYU-mmqFLq8'],
#    ['M4tM7LarIdw', 'en-uYU-mmqFLq8'],
#    ['d9KZFHU9c48', 'en'],
#    ['Dl0N23S6EJM', 'en'],
#    ['oQTHydCIixA', 'en-US'],
#    ['xrMBeB7-bn8', 'en-uYU-mmqFLq8'],
#    ['ofK_yvkc-4U', 'en'],
#    ['MCV_l2yRKMY', 'en-uYU-mmqFLq8'],
#    ['309jYirMc8M', 'en-GB'],
#    ['g7BKfoW6xYo', 'en-US'],
#    ['5YP6VppkByM', 'en'],
#    ['KCnALY1Yolg', 'en-nP7-2PuUl7o'],
#    ['oqDmDHtmsaI', 'en-uYU-mmqFLq8'],
#    ['zingmnDWSdg', 'en-nP7-2PuUl7o'],
#    ['ZcryKpvM1B0', 'en'],
#    ['AGGLYuZZBE8', 'en-uYU-mmqFLq8'],
#    ['1iJGgr7Syxg', 'en'],
#    ['qYVHZ45klHc', 'en'],
#    ['T7HPSvlCPEI', 'en-uYU-mmqFLq8'],
#    ['8twm8tCYMSg', 'en'],
#    ['Z4OcERlmte4', 'en'],
#    ['Nsy6Wtb9SYI', 'en-uYU-mmqFLq8'],
#    ['XF8Hci_VIzM', 'en-1oAFzPNiuC0'],
#    ['iIo8B_v_uuc', 'en-GB'],
#    ['6YPreu5ba1M', 'en'],
#    ['3G20y7iskR0', 'en'],
#    ['cJgkvcmOkNw', 'en'],
#    ['6rSKc6UWXmo', 'en-UMYBvvsXfqo'],
#    ['A9PZUL7H1FQ', 'en'],
#    ['mMz0qia6xGE', 'en'],
#    ['671pPsxOgko', 'en-US'],
#    ['K3yFovs9B8I', 'en'],
#    ['NtPnVBO3nhY', 'en'],
#    ['LBap5nd-pVE', 'en'],
#    ['6t0YttEkYvk', 'en-nP7-2PuUl7o'],
#    ['CuL1qUh8Tt8', 'en-uYU-mmqFLq8'],
#    ['oIKdNV5ZQhg', 'en-uYU-mmqFLq8'],
#    ['dRGEAbiqZfM', 'en-uYU-mmqFLq8'],
#    ['Fkf2Gh8Ndig', 'en'],
#    ['Cl5P3sKDQ0o', 'en'],
#    ['BZeFpJD3IsI', 'en'],
#    ['MDgcyLiKr6M', 'en-uYU-mmqFLq8'],
#    ['i6CIrFbd83A', 'en-BGBnSLWxig0'],
#    ['u1AHgUnouJE', 'en'],
#    ['Aqfrdq3Fsq4', 'en'],
#    ['5TXIFjSdweI', 'en-uYU-mmqFLq8'],
#    ['Fx39y31QLn8', 'en'],
#    ['ZDCRIGR0Q_w', 'en'],
#    ['Z0d4z8FdmR0', 'en-j3PyPqV-e1s'],
#    ['biq4Voe0YpM', 'en'],
#    ['hR65N-Lf3Ps', 'en'],
#    ['nuVqcJ4iI8U', 'en'],
#    ['apcOw7iR6aY', 'en'],
#    ['0ffRah-oRtk', 'en'],
#    ['jl1Sf2GkJiQ', 'en-nP7-2PuUl7o'],
#    ['9HrJF5oRSAM', 'en'],
#    ['YUjmERrriHM', 'en'],
#    ['EG7csaYLEa4', 'en-ehkg1hFWq8A'],
#    ['B3vKraqaP6I', 'en'],
#    ['6F_FqLw3478', 'en-US'],
#    ['7NqA49Lb4nU', 'en-j3PyPqV-e1s'],
#    ['njJ5QX6Wo8Q', 'en'],
#    ['OOSesuEPXmQ', 'en'],
#    ['RmA50gqOrHc', 'en'],
#    ['BjR9QwPMPKQ', 'en'],
#    ['ULGF-Kqy1k8', 'en-uYU-mmqFLq8'],
#    ['k5tlg6lt6as', 'en-dExSdMds8NU'],
#    ['Rr8mooqOoFg', 'en'],
#    ['xiKLcetFq_Y', 'en'],
#    ['zfstPz-sZOA', 'en'],
#    ['6SGCQ7sKcmA', 'en'],
#    ['ifodZuF8J5k', 'en'],
#    ['COY_dnjM3aw', 'en-vlW2OHFw3ww'],
#    ['Y8TSpZ4v2-c', 'en'],
#    ['LRn0hZJZ_KM', 'en-nP7-2PuUl7o'],
#    ['v3D5rHcuQ6E', 'en'],
#    ['JT2RD_cHgT4', 'en'],
#    ['ii9RlICa7cg', 'en-GB'],
#    ['aJw0-Vt-I9g', 'en-d0bG1KeXDGg'],
#    ['h5jSsEhF0So', 'en'],
#    ['cvtI-xU7IME', 'en'],
#    ['tuzHNSs4NAk', 'en'],
#    ['zdyZMPjkEtQ', 'en'],
#    ['s1C40LAUf4c', 'en-uYU-mmqFLq8'],
#    ['LR9C6n6q9yk', 'en'],
#    ['9p0zhqZEtZs', 'en'],
#    ['p_Zcz4Q3yzw', 'en'],
#    ['UbafXlO6YcU', 'en-uYU-mmqFLq8'],
#    ['LqT_KjyoMtQ', 'en-US'],
#    ['1MBzzoMQvLk', 'en'],
#    ['B00MvbMC72c', 'en-nP7-2PuUl7o'],
#    ['indxbwOZLaw', 'en-uYU-mmqFLq8'],
#    ['cRImUDzk0Xk', 'en'],
#    ['kq9JM9tjynQ', 'en-US'],
#    ['glR7JutHIwI', 'en-nP7-2PuUl7o'],
#    ['mlxxZVxjRjk', 'en-j3PyPqV-e1s'],
#    ['Z2shW8vgaCY', 'en-nP7-2PuUl7o'],
#    ['vHPwi_lxJ9w', 'en-GhSz_x8gVRk'],
#    ['_pEEJfpDJ7w', 'en'],
#    ['HkeTF5M0MyQ', 'en'],
#    ['UHMF0PYa094', 'en'],
#    ['LBeRCIM6EE4', 'en-uYU-mmqFLq8'],
#    ['8p_Wdh78fro', 'en-nP7-2PuUl7o'],
#    ['MTIDaLhxkFY', 'en'],
#    ['l-qlDWcyI8A', 'en'],
#    ['mpYYOlooZQ4', 'en'],
#    ['IuoJIkPNpJE', 'en-gjPViSVonVU'],
#    ['MkZg08u-BUU', 'en-nP7-2PuUl7o'],
#    ['KVnEBJtg418', 'en-nP7-2PuUl7o'],
#    ['_8iPwWxBVXg', 'en'],
#    ['MB5E-6qr0Ek', 'en'],
#    ['TM7gwmV8NqQ', 'en-GB'],
#    ['RcJ2MqXtrtQ', 'en-US'],
#    ['Cgvz7nQzu4g', 'en-nP7-2PuUl7o'],
#    ['XCCNoKDoZEs', 'en-GB'],
#    ['GynerdRLPgM', 'en-0CjIv5dezHE'],
#    ['PXlgGHHRzgQ', 'en'],
#    ['-Rh2Y-WqwaA', 'en'],
#    ['94ISQTra9IY', 'en-nP7-2PuUl7o'],
#    ['nmzona6WEjg', 'en'],
#    ['udI-Go8KK2Q', 'en-GB'],
#    ['BGjLog7m4RU', 'en'],
#    ['nLrlM24hlyI', 'en'],
#    ['4dqgbx4ePo8', 'en'],
#    ['zMMSR914mOI', 'en-uYU-mmqFLq8'],
#    ['u62whUedQkg', 'en-pH0sNhRzOr4'],
#    ['DZkwCqIGixo', 'en-uYU-mmqFLq8'],
#    ['uhBJfQN0VJQ', 'en-j3PyPqV-e1s'],
#    ['e_DNLpdbkKQ', 'en'],
#    ['EGcT6gewfNI', 'en-US'],
#    ['qeU-WmPyILw', 'en'],
#    ['YJAy71U1rrI', 'en-US'],
#    ['d0TC_-rX26U', 'en'],
#    ['M4LWJYKxVAs', 'en-IE'],
#    ['eGO7OW93CDw', 'en'],
#    ['uhwzQWojlNs', 'en'],
#    ['CDjw-Scr97s', 'en'],
#    ['hcDPLNN13v0', 'en'],
#    ['5vnftH-0OGc', 'en'],
#    ['jManPl9wo8o', 'en-nP7-2PuUl7o'],
#    ['JcF6XbzvMYg', 'en'],
#    ['pkl1zDyNcu4', 'en-GB'],
#    ['W8F07NfSZig', 'en'],
#    ['z__oIhpSRkg', 'en'],
#    ['fWdgSTIyV1c', 'en'],
#    ['3UAUte7CF0k', 'en'],
#    ['sH6JJnn-2qs', 'en'],
#    ['46H9B6m0Ms4', 'en-uYU-mmqFLq8'],
#    ['tAviSdHRwqc', 'en-uYU-mmqFLq8'],
#    ['b-Da1RlfKao', 'en-uYU-mmqFLq8'],
#    ['uCQSLVfmnrg', 'en-GB'],
#    ['ubTPZ55Gz80', 'en-nP7-2PuUl7o'],
#    ['jLKY-wSe7tA', 'en-zL7EZQmMa4Q'],
#    ['_JK3yS4QLys', 'en-nP7-2PuUl7o'],
#    ['b7k6yDFsqs8', 'en-GB'],
#    ['1_O1DNtGF-Y', 'en-uYU-mmqFLq8'],
#    ['TzuMqLoReGQ', 'en'],
#    ['I4RmsRz6m10', 'en'],
#    ['X8rIlpzUk2Q', 'en'],
#    ['sr4uhQ3XkZQ', 'en'],
#    ['rOFdSe2wSys', 'en-uYU-mmqFLq8'],
#    ['W1XuJHF42WU', 'en'],
#    ['ObuUXK75FAk', 'en-__au0PeNDVQ'],
#    ['LEVc_94NKoc', 'en']],
#   'batchIdx': 1},
#  {'videoIds': [['f8EPKmdvhW0', 'en-nP7-2PuUl7o'],
#    ['CtJsEO1p-Ac', 'en'],
#    ['S-Aea0FSbtM', 'en-JkeT_87f4cc'],
#    ['kE1TKSAvsX4', 'en'],
#    ['906ydfOX0TM', 'en'],
#    ['cmh3WEsZvxQ', 'en-zL7EZQmMa4Q'],
#    ['b6VVAvSzRMM', 'en'],
#    ['4GcJMl9t36Y', 'en-uYU-mmqFLq8'],
#    ['-oxCLpDPMs0', 'en'],
#    ['E-J9lxItKKo', 'en-uYU-mmqFLq8'],
#    ['bM5N63zVn8E', 'en'],
#    ['MGxEGLCwqFU', 'en-US'],
#    ['2no76vBI8X4', 'en'],
#    ['fuA5VKPtRck', 'en-US'],
#    ['DDTiMRmbut0', 'en'],
#    ['yCAoXbS1T5w', 'en'],
#    ['N7JYTcsaHos', 'en'],
#    ['vT0ldbe2CfQ', 'en'],
#    ['EAjhFIvdzCg', 'en-uYU-mmqFLq8'],
#    ['mnQBhNxV1HE', 'en-cfzE2rxAw7g'],
#    ['51kJ_dLZDl8', 'en'],
#    ['3cwmZ19KWYk', 'en-KoHep7H8LxA'],
#    ['GmH-tdVHuQ0', 'en'],
#    ['Cn6dt0z4RC4', 'en'],
#    ['uAwwp708TjE', 'en-US'],
#    ['yAwkxEKZjZw', 'en'],
#    ['1ZKAOdU7oWk', 'en'],
#    ['ZNy6FFeIll4', 'en'],
#    ['0A1p22_v2kk', 'en-uYU-mmqFLq8'],
#    ['QlhKJWKIsKI', 'en'],
#    ['lb5gmDZbPD4', 'en'],
#    ['gAQqEMSCUGY', 'en-US'],
#    ['MX8cLpWschM', 'en-JkeT_87f4cc'],
#    ['d52VsHXFGlk', 'en-CA'],
#    ['01U8S-IAVUk', 'en'],
#    ['j4TEIPICuvg', 'en-GB'],
#    ['GwFbZkSiJVw', 'en-uYU-mmqFLq8'],
#    ['oguJmronFeA', 'en-US'],
#    ['y3UsKn0UuKk', 'en'],
#    ['xod83XZzmKw', 'en'],
#    ['2eT4x4GaJFA', 'en'],
#    ['kIuU7rTbTnU', 'en-nP7-2PuUl7o'],
#    ['cdue0ZTrp3I', 'en'],
#    ['-evIrESG8rc', 'en'],
#    ['U8vlkszG2W4', 'en'],
#    ['LYFBJDWmWmA', 'en'],
#    ['YH7GlvrIbS8', 'en-US-ULDDPlCZews'],
#    ['scrL9UhKX7w', 'en'],
#    ['vzaL6cy9p2I', 'en'],
#    ['IiCoZPgI1oU', 'en'],
#    ['0WXRzPu2svQ', 'en'],
#    ['eqvPbpEbT1A', 'en'],
#    ['nYLR7Y5JpRo', 'en-JkeT_87f4cc'],
#    ['wgUydabB8TE', 'en'],
#    ['T4IchhYPSKA', 'en-uYU-mmqFLq8'],
#    ['6TuW0aTL7fQ', 'en'],
#    ['UPT7gLYZ3ek', 'en'],
#    ['ZuZcPXtHHdA', 'en-US'],
#    ['tsW9dxbZ7xk', 'en-uYU-mmqFLq8'],
#    ['Nvcsr21q2vE', 'en'],
#    ['rgyzXAnwu3s', 'en-uYU-mmqFLq8'],
#    ['PXb4Y5dX9A4', 'en-uYU-mmqFLq8'],
#    ['jG95bwhdTqM', 'en-RTbB2cpHawQ'],
#    ['n4pGi7RN_w8', 'en-US'],
#    ['LFDIYG6XPVE', 'en'],
#    ['W1Us8KUvauk', 'en-RTbB2cpHawQ'],
#    ['ZYfCgZWqQk4', 'en-eEY6OEpapPo'],
#    ['aDqOXWtQZMk', 'en'],
#    ['yE_tIxapr3c', 'en-XfhHc4TaVXo'],
#    ['CM2xR4jBXu0', 'en'],
#    ['pcPMHGNX7QA', 'en-uYU-mmqFLq8'],
#    ['lRgzEDRDXU8', 'en-GB'],
#    ['6l8AZfM2E4U', 'en'],
#    ['Xmw6Kc8FMos', 'en'],
#    ['bW9fmfNY7a4', 'en-US'],
#    ['yJaoZKpF5rQ', 'en'],
#    ['neCXfcZxs8o', 'en'],
#    ['hPaVSHwK98U', 'en'],
#    ['o7MFrDP8TuQ', 'en'],
#    ['artK-s4HRc0', 'en'],
#    ['X3GPvF3lblo', 'en-JkeT_87f4cc'],
#    ['6WJBU5RRPOY', 'en'],
#    ['KdYCgKNQkj4', 'en'],
#    ['nVCOYQUXojw', 'en-US-Uy4SdKLRphE'],
#    ['3SwBlEDQVfw', 'en-US'],
#    ['LBJEATvpslQ', 'en-GB'],
#    ['zEO-xaAwfmo', 'en'],
#    ['Bk0GnHVDbM8', 'en'],
#    ['f3I_ojzdjLA', 'en-GB'],
#    ['R9lUiGJQgxM', 'en-uYU-mmqFLq8'],
#    ['hhyN3vtNUsA', 'en'],
#    ['S0GwjyR_QJ4', 'en-nP7-2PuUl7o'],
#    ['QO3iPDas6wg', 'en-uYU-mmqFLq8'],
#    ['4smbLfXm6YQ', 'en'],
#    ['H3V5FzKWcP4', 'en-US'],
#    ['1VNlR40M8_4', 'en'],
#    ['Nh-ghDEYHF0', 'en-VjEpQ-RlAYk'],
#    ['daxgXiuSL3w', 'en'],
#    ['xIBBbbdw3Ic', 'en'],
#    ['SGgXUq1KC1Y', 'en-qoXxhA4oLYo'],
#    ['pTvfrETpves', 'en'],
#    ['Za34ZRnyzQ8', 'en-nP7-2PuUl7o'],
#    ['RG85idxUO6k', 'en'],
#    ['Dnm4KrYds8s', 'en-US'],
#    ['72n80q2hpog', 'en'],
#    ['17G9xihXTH0', 'en-uYU-mmqFLq8'],
#    ['y-itVQnhXTw', 'en'],
#    ['VlAxcQ2h8mk', 'en-GB'],
#    ['3OK5WmvKdOM', 'en-uYU-mmqFLq8'],
#    ['mLZ28v6ukrg', 'en'],
#    ['_qVy8EE-QqE', 'en-hnCuwW0TCiQ'],
#    ['NHKfqT2o8Mo', 'en'],
#    ['WSq-ugsivD8', 'en-haCt2RwZfUY'],
#    ['EzbNnverbsE', 'en'],
#    ['zNgI6PUDA_Q', 'en-GB'],
#    ['1oiktoDMoww', 'en'],
#    ['MquXg4OIvjg', 'en-US'],
#    ['3TUbEqBgCPQ', 'en'],
#    ['eaXQlnd6Law', 'en-US'],
#    ['M4iH4YGoS1c', 'en'],
#    ['axgQ9iUr2qk', 'en'],
#    ['pkpbDy8Jm7k', 'en'],
#    ['n3JEKhmWp7o', 'en'],
#    ['sxPzOlJTEC0', 'en-eEY6OEpapPo'],
#    ['H177xwFE0N0', 'en'],
#    ['007xyTRmtvA', 'en'],
#    ['LZ4u7faym4c', 'en-nP7-2PuUl7o'],
#    ['1rF1uuw9gsI', 'en'],
#    ['sa6feZvNS60', 'en-sMFOkpfLtG0'],
#    ['UAvl0K_DmNs', 'en'],
#    ['4o1921g97BM', 'en'],
#    ['uT40XLKpb68', 'en'],
#    ['zdL01TCxAa8', 'en'],
#    ['hT535u7kqUE', 'en'],
#    ['x-7QW115emc', 'en'],
#    ['K_TAuX3JX1g', 'en'],
#    ['-CHL6q-tsu0', 'en'],
#    ['vBDM6VsXC10', 'en'],
#    ['fZnOXTqVmXY', 'en-CA'],
#    ['46XUw86lXTo', 'en'],
#    ['7t1uZGDRBq0', 'en-npamNM1ElKs'],
#    ['9IycQDuWZR0', 'en-uYU-mmqFLq8'],
#    ['GSOwFJMWkT4', 'en'],
#    ['gHyl0fqNcyM', 'en'],
#    ['IPuGwgX6C68', 'en'],
#    ['0DgYXLbFPA8', 'en'],
#    ['Sfidg3430dc', 'en'],
#    ['K3egHyOs2Jk', 'en-GB'],
#    ['F2s89znrA94', 'en-US'],
#    ['z8WQ72LN1sU', 'en'],
#    ['ixkUXlJaj9k', 'en'],
#    ['LoyVK4oAdCs', 'en'],
#    ['NYxDzzuXX6E', 'en'],
#    ['i_XipfNaq_A', 'en-nP7-2PuUl7o'],
#    ['MADlwHlEMcw', 'en'],
#    ['xyamwFovwDw', 'en'],
#    ['mdEwTbjpB5c', 'en'],
#    ['eLHUhJ_Bn2s', 'en'],
#    ['WgEumODHRCE', 'en'],
#    ['zUIGF21BCFM', 'en'],
#    ['Vm1VG51jVRk', 'en-uYU-mmqFLq8'],
#    ['ZLKVpsBZT-I', 'en-GAg08fRpEM4'],
#    ['_7iN1n8GB5Y', 'en'],
#    ['RV0_kQyfuzc', 'en'],
#    ['LnoZGouDKbU', 'en'],
#    ['qHyiOK16IXI', 'en'],
#    ['0j7yK0nk3iA', 'en-uYU-mmqFLq8'],
#    ['WyqcvCDUZw4', 'en'],
#    ['G-WmqXE1gJM', 'en'],
#    ['ul37BjtczsI', 'en-nP7-2PuUl7o'],
#    ['KbfOwXkqb2Y', 'en'],
#    ['lBrViWm6Sgk', 'en'],
#    ['oSx13Zf-HDU', 'en'],
#    ['Isnr73WVv4E', 'en-US'],
#    ['FU37np-J_Qc', 'en'],
#    ['z28R2WWjF7E', 'en'],
#    ['i_t5NBJuxds', 'en'],
#    ['VxVejLOxXwQ', 'en-JkeT_87f4cc'],
#    ['WybyscCic_E', 'en'],
#    ['WPd8DcGBlWk', 'en-uYU-mmqFLq8'],
#    ['CAsO5KXqhPs', 'en'],
#    ['ejBDcF9aqDQ', 'en'],
#    ['Vsizy-cLlLE', 'en'],
#    ['P4_U-2a8TcQ', 'en'],
#    ['WjmmP1rE_3A', 'en'],
#    ['ZYmiM12NBuk', 'en-uYU-mmqFLq8'],
#    ['qj9__tNCSOs', 'en'],
#    ['bNRGcK-TmOc', 'en'],
#    ['Wn0BONC1bZQ', 'en'],
#    ['xvGD1uRi-Qk', 'en'],
#    ['EG_CWMyO38Q', 'en'],
#    ['oW62GSpe8-s', 'en-US'],
#    ['I_pgtOE-KsE', 'en'],
#    ['QpAMLsoy5y0', 'en'],
#    ['A74nKNwewUU', 'en-US'],
#    ['NF3x1yKfB9Q', 'en'],
#    ['8zfSAhyx3Vo', 'en-US'],
#    ['h3NpNSt60Do', 'en'],
#    ['hlt9m74PVsk', 'en'],
#    ['0RwNGCHzW_g', 'en-nP7-2PuUl7o'],
#    ['AxuDbeVQ-oM', 'en'],
#    ['FjiITNWlSfA', 'en'],
#    ['227HOo8HA3A', 'en'],
#    ['276YzsfEg3U', 'en-US'],
#    ['YJbW3Jh3nSE', 'en'],
#    ['EkQHejA7iA4', 'en'],
#    ['P-ZgZ1tsW8I', 'en-US'],
#    ['C4ScdNtTeik', 'en'],
#    ['luDhTOswe3g', 'en'],
#    ['fvpVn_PjXMk', 'en'],
#    ['wVMLvR-tNZ4', 'en'],
#    ['LoTUMqsuv7A', 'en-GB'],
#    ['3vAbho4FIRw', 'en'],
#    ['OEtHC02m8q0', 'en'],
#    ['jzxudIKhXGw', 'en'],
#    ['tm1PiEcBm_o', 'en-rsVeCaZmlEE'],
#    ['ZQRF7fN0SuY', 'en-TW7qhz_uLiI'],
#    ['9ItW9GpP7ls', 'en'],
#    ['ccd0IT9ms_Q', 'en'],
#    ['1ef_ICyS0fI', 'en-nP7-2PuUl7o'],
#    ['RcRXW1k42Qk', 'en-GB'],
#    ['_stq5BMJOpM', 'en'],
#    ['_v_6Iawb-eI', 'en'],
#    ['NFaAGvCRo3Y', 'en-uYU-mmqFLq8'],
#    ['2pElHCUk7jA', 'en'],
#    ['iHm0UpAoCYI', 'en'],
#    ['-Hzn879ttf0', 'en'],
#    ['HKt6H847PJk', 'en'],
#    ['6IGMB0kBRgo', 'en'],
#    ['hKNtBGJ5njo', 'en-VjEpQ-RlAYk'],
#    ['XA36AMYLYbY', 'en'],
#    ['GG2_QSP0YAw', 'en'],
#    ['B5f8Qsk3gKA', 'en'],
#    ['0Z_X--9iZpM', 'en-US'],
#    ['aVawiWOyKtk', 'en-uYU-mmqFLq8'],
#    ['op3ikpGC0tg', 'en-JAcxB_V84i0'],
#    ['BLX9fR19-mU', 'en'],
#    ['1prlFNeOnPo', 'en-uYU-mmqFLq8'],
#    ['cKztdtJ7xIg', 'en-vlW2OHFw3ww'],
#    ['xC7N83QjkPY', 'en-US'],
#    ['E2CyUGuGsbM', 'en-mQ7L-AgNtCw'],
#    ['7l1ytyCWsCM', 'en-US'],
#    ['Vh8zayHM_Kw', 'en-US-lanEHnLdKUw'],
#    ['E4kwmGgD6vs', 'en-8pqiNTfjOVU'],
#    ['q-Px36RyEP0', 'en-uYU-mmqFLq8'],
#    ['gb59Mlb7N8o', 'en-US-muTJmegbndA'],
#    ['Or0CN86uNzc', 'en'],
#    ['oxsx0mq74Lw', 'en-nP7-2PuUl7o'],
#    ['ZysdNV_2qGw', 'en'],
#    ['3JlLQ2g02v8', 'en']],
#   'batchIdx': 2},
#  {'videoIds': [['1cXJBrNDdGo', 'en-uYU-mmqFLq8'],
#    ['C_QlKsFJ0ZA', 'en'],
#    ['0Rl7t9jvP-s', 'en'],
#    ['1Yde0RJjqKg', 'en'],
#    ['jKR9E_Ew5r8', 'en'],
#    ['JLuTTbNR--c', 'en-uYU-mmqFLq8'],
#    ['b6a6s-X0VAU', 'en'],
#    ['OmJ1M_nShmU', 'en'],
#    ['v022H0DUu9E', 'en-US'],
#    ['32leSrBa6Co', 'en-uYU-mmqFLq8'],
#    ['jgInhnAE1cE', 'en'],
#    ['xYd9yw8qcKU', 'en-JkeT_87f4cc'],
#    ['MyQUX3F_wHk', 'en'],
#    ['XBCW42aITu4', 'en'],
#    ['S41yi0QUicI', 'en'],
#    ['EKhq4QATspo', 'en'],
#    ['uZDJtn5C65w', 'en'],
#    ['9BWtjZ5TafU', 'en-uYU-mmqFLq8'],
#    ['MbjJ3lsSFwc', 'en'],
#    ['MeL4ZHwohj8', 'en-ehkg1hFWq8A'],
#    ['g4Z4GSHZASQ', 'en-ehkg1hFWq8A'],
#    ['n0VMJosE4Vw', 'en'],
#    ['2-LfNpEvVSI', 'en'],
#    ['95KCbCTrdGs', 'en'],
#    ['f5qedwvWEAA', 'en-uYU-mmqFLq8'],
#    ['kxQ48JE1ruk', 'en'],
#    ['hQs98QYiXNQ', 'en'],
#    ['u8I7i1aHLbQ', 'en'],
#    ['UBVgqWf24Bs', 'en-uYU-mmqFLq8'],
#    ['HrvUlvHxUyE', 'en'],
#    ['da46sreZWJk', 'en-VjEpQ-RlAYk'],
#    ['gWyRLDyloZc', 'en'],
#    ['6EvZ8WOi5F8', 'en-nP7-2PuUl7o'],
#    ['06WPJwdd0gQ', 'en-US'],
#    ['pwcEsvPbVzc', 'en-uYU-mmqFLq8'],
#    ['k2uA3_NW5Jo', 'en'],
#    ['HlD6lUr1Au0', 'en'],
#    ['Amr4fve-o28', 'en'],
#    ['9ynUM606yhc', 'en-nP7-2PuUl7o'],
#    ['O7mBvzDuY88', 'en-nP7-2PuUl7o'],
#    ['DLZVTZWY7oM', 'en'],
#    ['zGAlNDx0Eyc', 'en'],
#    ['QNoERsS-7k4', 'en'],
#    ['0vQU4s86sAI', 'en-US'],
#    ['iLL7sQ7GKEE', 'en-uYU-mmqFLq8'],
#    ['DYDtMNoHopo', 'en-US'],
#    ['2_GrRaPBamI', 'en-nO-wyhRpHPY'],
#    ['5fuJjzdCn28', 'en'],
#    ['LDjxbvk2X84', 'en-nP7-2PuUl7o'],
#    ['7QFfA8Q_-VU', 'en-uYU-mmqFLq8'],
#    ['kVIAWmVMIvY', 'en-nP7-2PuUl7o'],
#    ['ehDRIYSi95g', 'en-nP7-2PuUl7o'],
#    ['3qkbvvq8LS4', 'en-RTbB2cpHawQ'],
#    ['hsq6xVQVjo4', 'en'],
#    ['v9bSOYiqh08', 'en'],
#    ['7duG34dBK2w', 'en-JkeT_87f4cc'],
#    ['japSuRr4cGg', 'en-IN'],
#    ['hh5ZYTlsPwA', 'en'],
#    ['t-JpAQuyFSs', 'en'],
#    ['qXlgBPOgHOA', 'en-uYU-mmqFLq8'],
#    ['M_9xjZLnOlE', 'en'],
#    ['eO5dz-0Q6kU', 'en'],
#    ['X20KhtDtxhw', 'en-nP7-2PuUl7o'],
#    ['Vp4jyoAgzQw', 'en-GB'],
#    ['huyX7qPWs2A', 'en'],
#    ['nIiaKDWlbUw', 'en-uYU-mmqFLq8'],
#    ['git1NaLQEl0', 'en-uYU-mmqFLq8'],
#    ['yn18AsIGdf0', 'en'],
#    ['OlfNVkK-rgQ', 'en'],
#    ['PGBVCIp-W4s', 'en-uYU-mmqFLq8'],
#    ['mTdyNHG1ym4', 'en-US'],
#    ['7sit8A-WF48', 'en-uYU-mmqFLq8'],
#    ['wf2bdoZmpLc', 'en-nP7-2PuUl7o'],
#    ['Jav8JKOrcPw', 'en-tXgd4Wq1ffQ'],
#    ['-j5JfM_03bs', 'en-US'],
#    ['wEuSaZYL_aE', 'en'],
#    ['ztiY5CJw-g4', 'en-nP7-2PuUl7o'],
#    ['o7VAzmc7u5E', 'en'],
#    ['qb17b_QnxT8', 'en-nP7-2PuUl7o'],
#    ['4ifHDzClw_k', 'en'],
#    ['aFCJtfJqkxs', 'en-uYU-mmqFLq8'],
#    ['qpO3w5-Hi8c', 'en-GB'],
#    ['ghTcMAtMwPU', 'en'],
#    ['MfapiivlgSo', 'en'],
#    ['X6mpfG1olpk', 'en'],
#    ['V3mXQIvKOXw', 'en'],
#    ['qW5nhoT_4zc', 'en'],
#    ['obuEJ_MJddk', 'en-nP7-2PuUl7o'],
#    ['IBiW2dmuO7g', 'en-uYU-mmqFLq8'],
#    ['n6JnWW2Us14', 'en-uYU-mmqFLq8'],
#    ['OKz3yj2eatA', 'en-GB'],
#    ['FzVvS0Zu1Yw', 'en-uYU-mmqFLq8'],
#    ['x7VAJBBQ4r0', 'en'],
#    ['5WRCtOZAXpA', 'en'],
#    ['QfLho_f-HSw', 'en'],
#    ['WUEEvDmBtSg', 'en'],
#    ['CNuB1jAVPbs', 'en-GB'],
#    ['ZIKiBW9EAGI', 'en'],
#    ['HhiMfYmpCGI', 'en-GB'],
#    ['RxgeO2RmC6M', 'en'],
#    ['ga4aP2I-tvM', 'en-uYU-mmqFLq8'],
#    ['_sVL6QyBe_4', 'en'],
#    ['t9RFhkiN-14', 'en-US'],
#    ['-eIJ-9uN5yY', 'en-uYU-mmqFLq8'],
#    ['i5RKKQDilSg', 'en'],
#    ['dDFpFvR2el4', 'en-IN'],
#    ['BZPybmd0INo', 'en-nP7-2PuUl7o'],
#    ['19i8VL2GYQ4', 'en-AU-eEY6OEpapPo'],
#    ['XoM3YMtdRnE', 'en'],
#    ['BrB3qdKoYpg', 'en-uYU-mmqFLq8'],
#    ['6qthdqoUoyU', 'en'],
#    ['_cJoS_Wi-TI', 'en'],
#    ['gjCEzbxcKPM', 'en-NxllrVOXiTY'],
#    ['Oa_p8DnqY1U', 'en'],
#    ['Ri8Q0u2WWY0', 'en-Q8VSUiGLCHE'],
#    ['K27ky0-3lCc', 'en-GB'],
#    ['54vSTyJBx1E', 'en'],
#    ['45KBoN4yryc', 'en'],
#    ['eNTOkgjXZ4Y', 'en-iRiwEnZ2qCE'],
#    ['K09qTWgYYPs', 'en-RSVueXivq2A'],
#    ['mBJ-Z_ihS1k', 'en-uYU-mmqFLq8'],
#    ['uH1Bx1y6gWQ', 'en'],
#    ['GVl-EnaIyXg', 'en-uYU-mmqFLq8'],
#    ['60sR0FiPbjU', 'en'],
#    ['WzIdYIqV-f4', 'en-1oAFzPNiuC0'],
#    ['3q9uzuHSOJ4', 'en'],
#    ['qBMPO8lqKY8', 'en-peaiLC0FWmc'],
#    ['7OWmop3lc70', 'en-GB'],
#    ['mMN1EmK9KKI', 'en'],
#    ['c9h7NsTqYe0', 'en'],
#    ['4Bep7K-3MpI', 'en'],
#    ['VnnRm9c20ZU', 'en-US'],
#    ['qh-QdyWb_tY', 'en'],
#    ['qxvmgcqPCmo', 'en'],
#    ['G9NjbNqeEGA', 'en-ehkg1hFWq8A'],
#    ['W0S3xfheycU', 'en'],
#    ['Pl0YUnt60hA', 'en'],
#    ['oTW_F689MNc', 'en-uYU-mmqFLq8'],
#    ['r0HqoR4RK_c', 'en-US'],
#    ['8SLeqV7l5Bo', 'en-BkW4kUU6508'],
#    ['xxp6IyWEFtI', 'en-uYU-mmqFLq8'],
#    ['F8oVKeZ7km0', 'en-JkeT_87f4cc'],
#    ['-GwuHDmurPs', 'en'],
#    ['YMp3AD99bXU', 'en'],
#    ['1_43MW2W-L4', 'en-US'],
#    ['ksuaa0Jcd5c', 'en-ehkg1hFWq8A'],
#    ['5pqxw9eZd68', 'en'],
#    ['rpnyY5CvcRU', 'en'],
#    ['qkf1gjAZ9pI', 'en'],
#    ['dwQNN8XTlRA', 'en'],
#    ['c2cVXl6c958', 'en'],
#    ['_XmXdAZWRMs', 'en-4kUM5ZqKEMc'],
#    ['e-D6orxgAj4', 'en'],
#    ['xRQhxqheEnQ', 'en-uYU-mmqFLq8'],
#    ['jZdQcZfHavE', 'en'],
#    ['cUbADoNrN84', 'en-US'],
#    ['AdwuKV1e3hs', 'en'],
#    ['IHtV08b6tNA', 'en-nP7-2PuUl7o'],
#    ['fCQV4yWoMLU', 'en-nP7-2PuUl7o'],
#    ['g84WaS3dhOQ', 'en'],
#    ['tiy3qdmTF1w', 'en'],
#    ['y5-facjMsGM', 'en-pu9VSwG9GQM'],
#    ['A2oGHV01des', 'en'],
#    ['ba_cgDmTuT8', 'en'],
#    ['0R1a5vul5f4', 'en'],
#    ['xtIg75_46mw', 'en'],
#    ['Z8fihfSVD-A', 'en-US'],
#    ['3Y3DjRdO1XE', 'en'],
#    ['QcPliY9xJE0', 'en-nP7-2PuUl7o'],
#    ['EAH4YXNKNWk', 'en-uYU-mmqFLq8'],
#    ['zomO9QkSG6o', 'en'],
#    ['FeUZw5qZwpY', 'en-US'],
#    ['r6bhyuPOfp8', 'en-nP7-2PuUl7o'],
#    ['akATA3d8KD4', 'en-US-u7XbU0UxadQ'],
#    ['Y4Mic5MLokM', 'en'],
#    ['BReV7NADisY', 'en'],
#    ['mGti-5yIr74', 'en-nP7-2PuUl7o'],
#    ['TBqP-QF2pvg', 'en-uYU-mmqFLq8'],
#    ['giqk1cKBnwk', 'en'],
#    ['ac7GJoVZYxo', 'en-nP7-2PuUl7o'],
#    ['Lw3WTmGwRMA', 'en'],
#    ['K8jUck5Z04M', 'en'],
#    ['yE-BGFnNlFw', 'en-GB'],
#    ['b3rp5Yl-XO4', 'en'],
#    ['rDpzMjWl2kc', 'en-ehkg1hFWq8A'],
#    ['H44-3dFbTXk', 'en'],
#    ['VYKu5WIO1QE', 'en'],
#    ['PCMTsMQmmpQ', 'en'],
#    ['vgdWSyWfiws', 'en'],
#    ['_mGd4Ug_M0I', 'en-obl2yfGW38w'],
#    ['9PKjaZavBk0', 'en'],
#    ['IUjgV8U_8W8', 'en'],
#    ['4vFByvsegaA', 'en'],
#    ['4sHBkDXRoOg', 'en'],
#    ['iDhgsbcwoo4', 'en-US'],
#    ['VaWEZfMz6XI', 'en'],
#    ['avB_rc7fXOM', 'en'],
#    ['3a_qljWEl5k', 'en'],
#    ['LKojilDXvOE', 'en'],
#    ['z9ljhsZRVfw', 'en-nP7-2PuUl7o'],
#    ['3Ohb4E9_gOw', 'en'],
#    ['i34OLlr3ny8', 'en'],
#    ['7Abcq23QUE4', 'en'],
#    ['Go6DuPzVLaQ', 'en'],
#    ['Z1R2rsdFd1s', 'en'],
#    ['gvUIkR5Z6EE', 'en'],
#    ['1ZyK3CzMrIQ', 'en'],
#    ['Q8UE_AbcgwE', 'en-uYU-mmqFLq8'],
#    ['hrBOnSclqZo', 'en-US'],
#    ['BCTFS8f_6iA', 'en-uYU-mmqFLq8'],
#    ['SrtvXoqyjrE', 'en'],
#    ['NXvJ2TIuqIw', 'en-US-FCtDXVxtbQk'],
#    ['IU_-dustixc', 'en'],
#    ['PX2sVj5q1rQ', 'en-IN'],
#    ['Q-yIBi442ag', 'en'],
#    ['AXy3dhfXYZ8', 'en'],
#    ['94VziLMsQtA', 'en-uYU-mmqFLq8'],
#    ['CdBZGWEqR5o', 'en-nP7-2PuUl7o'],
#    ['2KSvu06RY-I', 'en'],
#    ['NcJtC5ohJdo', 'en-XW7J46QecyI'],
#    ['yyGrI-MnF0A', 'en-US'],
#    ['sRVNgplSimY', 'en'],
#    ['LvOUbF-VIPE', 'en-US'],
#    ['SEmm-a2owsg', 'en'],
#    ['oIgyhIhzrFY', 'en-GB'],
#    ['0YVVxiI8WFI', 'en-uYU-mmqFLq8'],
#    ['0vQU8vsCMPY', 'en'],
#    ['xHUGcw2rFMM', 'en'],
#    ['atNix59EqHg', 'en'],
#    ['ScX07vbAWT4', 'en-uYU-mmqFLq8'],
#    ['RhZ1gaZRgM8', 'en-uYU-mmqFLq8'],
#    ['udyoLQ-w7bE', 'en'],
#    ['fl4L0-KbN88', 'en-GB'],
#    ['x82ntcP4Vj0', 'en'],
#    ['4K-dbK0fX1g', 'en-nP7-2PuUl7o'],
#    ['Cw3VUphRMCE', 'en-uYU-mmqFLq8'],
#    ['NQy_czQKxBw', 'en'],
#    ['_8uPWNP6rEU', 'en-ehkg1hFWq8A'],
#    ['8hYHy0WV1zA', 'en'],
#    ['0me2d3xU8yI', 'en-US'],
#    ['_xFMb1V3aQo', 'en'],
#    ['reoAdrZ-mus', 'en-US'],
#    ['r3JyVVYEWHY', 'en'],
#    ['p7AW0e2OHfo', 'en'],
#    ['bctBcGFfgE4', 'en'],
#    ['q0wpOD4uqdQ', 'en'],
#    ['O42bev19M8w', 'en'],
#    ['3e2B1sSl6qE', 'en-uYU-mmqFLq8'],
#    ['oNDiBQw86eE', 'en-uYU-mmqFLq8'],
#    ['34nr8ZUeHWc', 'en-US']],
#   'batchIdx': 3},
#  {'videoIds': [['-fNwXc8Qit0', 'en'],
#    ['D2jQzrvr9D0', 'en-uYU-mmqFLq8'],
#    ['Kn9jZ7mxyFo', 'en-uYU-mmqFLq8'],
#    ['Ux2wWFg9xRE', 'en'],
#    ['R4y8s_XYboQ', 'en-JkeT_87f4cc'],
#    ['sLnWce39zKo', 'en-uYU-mmqFLq8'],
#    ['U0xNGP2f_O8', 'en'],
#    ['ZaXw4rBOInc', 'en-uYU-mmqFLq8'],
#    ['sZMQLIaeqzw', 'en'],
#    ['weMSZfeO9kI', 'en-nP7-2PuUl7o'],
#    ['13NpwOurW4k', 'en-eEY6OEpapPo'],
#    ['8aU9It_tDKI', 'en-GB'],
#    ['IDk9zjEIcDc', 'en-US'],
#    ['P3zZ664T-6A', 'en'],
#    ['pOh1Cp9g6Oo', 'en-uYU-mmqFLq8'],
#    ['w6wVdWLYnEk', 'en-GB'],
#    ['1k7lfELy88k', 'en-US'],
#    ['erPUe6E5HYI', 'en-LKBGzWr0CTo'],
#    ['HQZJCRrnYVY', 'en'],
#    ['dlHJ2BfbPPQ', 'en-vlW2OHFw3ww'],
#    ['CufHeke1LOY', 'en'],
#    ['blYtzNvyiKE', 'en'],
#    ['1q5ciCgiUsw', 'en-uYU-mmqFLq8'],
#    ['GMPL1hMgQ4w', 'en-LUU0EuDKgKo'],
#    ['DtQSlJlbqCA', 'en-uYU-mmqFLq8'],
#    ['-Gbw6S2cAA0', 'en'],
#    ['SxGoSYociSU', 'en'],
#    ['sLHt08xyWN8', 'en-uYU-mmqFLq8'],
#    ['jbLiN_mi4hU', 'en'],
#    ['1D_XWaXiIQE', 'en-nP7-2PuUl7o'],
#    ['HhLpVDsnhb4', 'en'],
#    ['SibaquLChg8', 'en'],
#    ['HDZySzpYw0g', 'en'],
#    ['vUAzUpjxhdo', 'en-ehkg1hFWq8A'],
#    ['zu7cHMndsGw', 'en-DjaROd6K7qg'],
#    ['-GN3OcNMDRI', 'en'],
#    ['SUQQVUIVVGI', 'en'],
#    ['GgtHVDWbHH4', 'en'],
#    ['dVtCV0aTWI0', 'en'],
#    ['lhrI1hvoLHo', 'en'],
#    ['_v5meuot1j4', 'en'],
#    ['qeb2cbcFU8E', 'en-US'],
#    ['jFHT5wbSPOc', 'en-cvfXDfbeED0'],
#    ['61usejY3O70', 'en-uYU-mmqFLq8'],
#    ['Wuz8XwiXsbs', 'en-nP7-2PuUl7o'],
#    ['LzF1Cq-1MuY', 'en'],
#    ['54OjUeTvKlk', 'en'],
#    ['dUaByxB15UQ', 'en-uYU-mmqFLq8'],
#    ['7M7PDoAPkgk', 'en'],
#    ['lSvKNmgjB1I', 'en-uYU-mmqFLq8'],
#    ['eg3b9NP3tdI', 'en'],
#    ['T7oNYWFwEvs', 'en'],
#    ['d9SF_jmvL70', 'en'],
#    ['x2W1qR5OS58', 'en'],
#    ['c_wefNE1adQ', 'en'],
#    ['QawzVY2VKmY', 'en'],
#    ['ya5u_OtZCK0', 'en-uYU-mmqFLq8'],
#    ['nDVudLCcaPM', 'en-uYU-mmqFLq8'],
#    ['9t4afJIyxbI', 'en'],
#    ['biSDW6PaVGM', 'en'],
#    ['dP6Uty5Fw0A', 'en-US'],
#    ['WNBtEKb7Oq8', 'en'],
#    ['qRtX7QlRAHc', 'en-nP7-2PuUl7o'],
#    ['Su-e3SvOKqE', 'en'],
#    ['wHgdQ4Pid0g', 'en-US'],
#    ['nyGMSuPOaXU', 'en-US'],
#    ['W3B8nvp1k3c', 'en'],
#    ['o97V0HMUJS0', 'en-uYU-mmqFLq8'],
#    ['7ZfaevekfdU', 'en-uYU-mmqFLq8'],
#    ['UaFz9etsUX8', 'en'],
#    ['hQj3WqUQCEk', 'en-US'],
#    ['ESRZEsXzy4I', 'en-uYU-mmqFLq8'],
#    ['2BD2qIoPong', 'en'],
#    ['odr_P0EDTPY', 'en'],
#    ['JsOpskM6MxU', 'en'],
#    ['xLiO-vj0BhM', 'en-uYU-mmqFLq8'],
#    ['ad7W1wVoPZE', 'en'],
#    ['gXKxxJebDZU', 'en-GB'],
#    ['Az9Z8ibJNcs', 'en'],
#    ['7VDZU6XxAuE', 'en'],
#    ['Xan0vAqZVFY', 'en-US'],
#    ['hkMWVS3n3N8', 'en-uYU-mmqFLq8'],
#    ['6LfBB7Mi5OA', 'en-ehkg1hFWq8A'],
#    ['Zz5NtFJdH8o', 'en'],
#    ['Bigp64jUnAs', 'en-miqYfKwkhnM'],
#    ['4jK2lV3rZqM', 'en-6UJrWS5jR_I'],
#    ['3PEtvHHobHs', 'en'],
#    ['wFszX1MGnvc', 'en'],
#    ['7zGnS9hpc7A', 'en-uYU-mmqFLq8'],
#    ['9hU7VOpTE8s', 'en'],
#    ['e2AtrriSDOI', 'en-uYU-mmqFLq8'],
#    ['nidSrXJqVHw', 'en'],
#    ['HezijfgdlTw', 'en'],
#    ['A0KcmdYbUuY', 'en'],
#    ['nU1Sx3gRb68', 'en'],
#    ['pJGDK3AxJps', 'en-uYU-mmqFLq8'],
#    ['THWZru1MeLA', 'en'],
#    ['bOy3g64OrGg', 'en-US'],
#    ['XFEEJM15SJc', 'en-uYU-mmqFLq8'],
#    ['5_O_vzDxPN0', 'en-US'],
#    ['9nMcU74vPBw', 'en-ehkg1hFWq8A'],
#    ['srXEQlUMqX4', 'en'],
#    ['O8LeiF5CryU', 'en-nP7-2PuUl7o'],
#    ['SR5hy6FVIDg', 'en-uYU-mmqFLq8'],
#    ['ZQ2PnsckSVg', 'en'],
#    ['Ex42q0GNPSg', 'en'],
#    ['5vYCI0SpAvg', 'en-GB'],
#    ['BOfPeqtqFrk', 'en-ehkg1hFWq8A'],
#    ['0ifhfXd9w-A', 'en'],
#    ['L-BbrTxPkhU', 'en-uYU-mmqFLq8'],
#    ['xbv7GsWUaDY', 'en-US'],
#    ['OEUW0CrVRXM', 'en'],
#    ['xrGarVG6LK8', 'en-nP7-2PuUl7o'],
#    ['5amVuMqFmCE', 'en'],
#    ['N4Ud_UXL_48', 'en'],
#    ['807MeGzxSYY', 'en-JkeT_87f4cc'],
#    ['MNkgdmcC_ek', 'en'],
#    ['G12OK3oX-5Q', 'en-uYU-mmqFLq8'],
#    ['xaHOMhJcyzs', 'en-uYU-mmqFLq8'],
#    ['eWAMhN6twG4', 'en'],
#    ['QCPQVYBzXGI', 'en-nP7-2PuUl7o'],
#    ['iYjL_BJybIU', 'en-uYU-mmqFLq8'],
#    ['kjZrm-A4_U4', 'en'],
#    ['pnK2ND2zQnM', 'en'],
#    ['MYm4lLpKD7E', 'en-US'],
#    ['ZgIXEtDgEa4', 'en'],
#    ['BM8svOGenwk', 'en-US'],
#    ['VelrOk3a8Oc', 'en-UMYBvvsXfqo'],
#    ['oem1mfJfnN0', 'en-uYU-mmqFLq8'],
#    ['RX40cxpFsSg', 'en-RTbB2cpHawQ'],
#    ['JDPN790as3w', 'en'],
#    ['nGtc-XUXBkg', 'en'],
#    ['JPkI37hDcNU', 'en'],
#    ['dOq5cktIdKQ', 'en-nP7-2PuUl7o'],
#    ['iIbuqx2uGKI', 'en-eEY6OEpapPo'],
#    ['FkmnbcILxA0', 'en-uYU-mmqFLq8'],
#    ['tWWbyRKerMw', 'en-nP7-2PuUl7o'],
#    ['ptrnI4Eh7Jg', 'en'],
#    ['4Qy-f6ifvQs', 'en-nP7-2PuUl7o'],
#    ['hUNilomfRi0', 'en-j3PyPqV-e1s'],
#    ['Ap1w7n65vxQ', 'en'],
#    ['kSpNZn63244', 'en'],
#    ['2JaOy-nRZRU', 'en'],
#    ['dB884WDp7hE', 'en-US'],
#    ['q1N_SYQmjXk', 'en'],
#    ['owjtRUrR4SI', 'en'],
#    ['fIo9E_l6hOY', 'en'],
#    ['nub0oGidE48', 'en-GB'],
#    ['H7x5mMufSVg', 'en'],
#    ['kYHOBL1IFJU', 'en-GB'],
#    ['FI-iyacZRj4', 'en'],
#    ['iqSkqK6vEgE', 'en-nP7-2PuUl7o'],
#    ['fMSFfaJUBw8', 'en-uYU-mmqFLq8'],
#    ['wZ9rWt-K9Xs', 'en'],
#    ['A-vEC3BrMeE', 'en-uYU-mmqFLq8'],
#    ['anB4X5ei3nE', 'en-US'],
#    ['OauPytu_waQ', 'en-nP7-2PuUl7o'],
#    ['HkU1pF1PRWA', 'en'],
#    ['06UaiSQtNQ8', 'en-US'],
#    ['B6yqVPywpzY', 'en'],
#    ['KsgQ1k3Ccfg', 'en'],
#    ['MXGuzjATBD4', 'en-US'],
#    ['xDf4vWr7r9w', 'en'],
#    ['nIW2dBMbaBc', 'en-pGTPg5dXcA4'],
#    ['dW3RgeWGPmg', 'en'],
#    ['WauhiEDmSBA', 'en-nP7-2PuUl7o'],
#    ['s8pC-Fm72E0', 'en'],
#    ['lp0-Tl6dE0k', 'en-nP7-2PuUl7o'],
#    ['8wM0MMHHsiE', 'en-uYU-mmqFLq8'],
#    ['dEui6gVSAAU', 'en-nP7-2PuUl7o'],
#    ['n5j6JysfzRg', 'en-uYU-mmqFLq8'],
#    ['0GB2hxHoQ5o', 'en'],
#    ['vOCRIuc8-ms', 'en-JkeT_87f4cc'],
#    ['rdkODwxwHhs', 'en-hnCuwW0TCiQ'],
#    ['wrjzlPpARp4', 'en-uYU-mmqFLq8'],
#    ['36BKqltm2NA', 'en'],
#    ['_v1RxRFwXjY', 'en'],
#    ['hc98H_HMlVA', 'en'],
#    ['ZChOliBmlJs', 'en-eEY6OEpapPo'],
#    ['DRcZqSjXzHw', 'en-ehkg1hFWq8A'],
#    ['U2oI6WTLVFs', 'en'],
#    ['vHpXo2gzfFI', 'en-US-aFM4R31P1vo'],
#    ['CmepcqAAQI0', 'en'],
#    ['eCzNv1vw83I', 'en'],
#    ['YDUxxbRc1Yg', 'en-US'],
#    ['_7j_0ypWmxA', 'en'],
#    ['n6ovsg14dck', 'en'],
#    ['fPUNq2uMxw4', 'en-uYU-mmqFLq8'],
#    ['bR4Nsg0wXhU', 'en-US'],
#    ['sy9c-QVVGk8', 'en-6VdCiLQhDUg'],
#    ['WQASF8wLo0o', 'en-uYU-mmqFLq8'],
#    ['1CJF4XehUMQ', 'en-IuAjc0hSeoI'],
#    ['ejJUFHMtH0c', 'en-ehkg1hFWq8A'],
#    ['DCuLynITxCk', 'en'],
#    ['R2pPnQmKcak', 'en'],
#    ['WBW2SW4wihk', 'en-US'],
#    ['h-LKVkRz5o8', 'en'],
#    ['3BTtTvVO23A', 'en'],
#    ['0J2-5qyj2nY', 'en-nP7-2PuUl7o'],
#    ['aGrVM_Y6uJ4', 'en-PP0LPbfO_us'],
#    ['EsulptLyAJQ', 'en-rX01gsAdUfU'],
#    ['q9iPbwepTck', 'en'],
#    ['BlrUV4A0HKo', 'en-JkeT_87f4cc'],
#    ['YlsHBowT_N4', 'en'],
#    ['ns8NLsCckW8', 'en-US'],
#    ['IEG3HCnOuPI', 'en'],
#    ['37XzK-YB_iQ', 'en-pitMCzmnPiQ'],
#    ['74hIhbHeDGE', 'en'],
#    ['CWMrZJ3uy94', 'en-GB'],
#    ['rV-S1QdH1EQ', 'en'],
#    ['Iq--poK24KQ', 'en'],
#    ['JAYx4EHVe-0', 'en'],
#    ['zvFJEkYeE0k', 'en'],
#    ['6KhD5fk9g-Q', 'en'],
#    ['IfBb9Pmm7HM', 'en-hSEj8T-oYjU'],
#    ['Rxr5srOYOG0', 'en'],
#    ['4QV8JVaZYlM', 'en-GB'],
#    ['wBI9OHKNdgg', 'en-nP7-2PuUl7o'],
#    ['q6RB_oNeZyc', 'en'],
#    ['ijDHaxVzRMo', 'en'],
#    ['Z83K-XOQ9ao', 'en-uYU-mmqFLq8'],
#    ['ZyPynQK-OJ4', 'en-nP7-2PuUl7o'],
#    ['DceqmPSh0l8', 'en-nP7-2PuUl7o'],
#    ['VabzVzmnkcE', 'en'],
#    ['ShN9yawAWAs', 'en'],
#    ['pe1vmx367Nc', 'en-uYU-mmqFLq8'],
#    ['GuJxwdl6Rqs', 'en-US'],
#    ['J6yEUnpt6-k', 'en'],
#    ['-FWXOkiPObc', 'en-nP7-2PuUl7o'],
#    ['7p2_tj76OVA', 'en'],
#    ['nE4P9-D9tl4', 'en-CTc8n-qLeoQ'],
#    ['J88X9mnlElU', 'en-nP7-2PuUl7o'],
#    ['W8Bm2o-pHWQ', 'en-QObcOOYZhS4'],
#    ['XeDh-f6U7YM', 'en-uYU-mmqFLq8'],
#    ['WnFWrSH8NCc', 'en'],
#    ['GwroxOlOSO8', 'en-uYU-mmqFLq8'],
#    ['RoAVzKA-ZxA', 'en'],
#    ['imL-zwtE6Cs', 'en-rX01gsAdUfU'],
#    ['FUn4KLhW-T4', 'en'],
#    ['w_yQuzIl38s', 'en'],
#    ['yNhO9kFdAvo', 'en-GB'],
#    ['HM2NE1Kwx08', 'en'],
#    ['tszpUavtjiw', 'en-uYU-mmqFLq8'],
#    ['-psJsNx8EyQ', 'en'],
#    ['onJ3dHsWJFs', 'en-uYU-mmqFLq8'],
#    ['aLGcoQM4hHc', 'en-Q8VSUiGLCHE'],
#    ['I4PWuqPwQUQ', 'en'],
#    ['V6T1qOP107o', 'en-US'],
#    ['jSWL95WHsek', 'en-uYU-mmqFLq8'],
#    ['IWvL2I2_0-E', 'en-i7LFIGUQP0g']],
#   'batchIdx': 4}]

# %%
print(len(subsampled_batches[0]["videoIds"]))
# Out:
# 250

# %%
with open("logs/data/download/4M_en/shuffled_subsampled_batches.jsonl", "w") as f:
    for batch in subsampled_batches:
        f.write(json.dumps(batch) + "\n")

# %% [markdown]
# #### Getting remaining that isn't subsampled to download only transcript (for text-only filtering, will download paired audio later)

# %%
subsampled_ids_4M = subsampled_df["id"].values.tolist()
with open("logs/data/download/4M_en/subsampled_ids.txt", "w") as f:
    for video_id in subsampled_ids_4M:
        f.write(video_id + "\n")

# %%
only_en_man_auto_text = set(only_en_man_auto["id"].values.tolist()) - set(subsampled_ids_4M)
only_en_man_auto_text_df = only_en_man_auto[only_en_man_auto["id"].isin(only_en_man_auto_text)]

# %%
only_en_man_auto_text_df["man_cap_langs_list"] = only_en_man_auto_text_df["manual_caption_languages"].apply(lambda langs: langs.split(","))
only_en_man_auto_text_df["download_lang"] = only_en_man_auto_text_df["man_cap_langs_list"].apply(lambda langs: rng.choice(langs) if len(langs) > 0 else langs[0])
print(only_en_man_auto_text_df.shape[0])
# Out:
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_1581/2640168966.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_en_man_auto_text_df["man_cap_langs_list"] = only_en_man_auto_text_df["manual_caption_languages"].apply(lambda langs: langs.split(","))
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_1581/2640168966.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_en_man_auto_text_df["download_lang"] = only_en_man_auto_text_df["man_cap_langs_list"].apply(lambda langs: rng.choice(langs) if len(langs) > 0 else langs[0])
# 8745843

# %%
view_lang_cols(only_en_man_auto_text_df, 20)
# Out:
#              id                                              title language  \
# 0   LwJv3vSd8no                                Free Art Wednesday!       en
# 2   OREjUtUT2Sc                     New Intro | I keep losing them     None
# 31  v8uKybpMJdM          Nature Moment | Common Blue Violet Flower       en
# 32  IkiTwxRtQUk                                 MYO Whipped Coffee       en
# 35  Nj4wCms-Xko         NSFW Shego (Kim Possible) Speedrun #Shorts       en
# 37  t1EwgfdBn-0                       BMC Faces: Sarah Kimball, MD       en
# 38  qjXauRp1uaU               Jobs for Veterans: Joseph Blansfield       en
# 39  7TZ02EP-VaE  BMC Presents: Donate Life - Marta and Brenda's...       en
# 41  ln8Tgp4NsOg  BMC Presents: Donate Life - Dan & Susan's Kidn...       en
# 42  1CDSz94YRGk                         Meet: Gregory Grillone, MD       en
# 43  Dvyxal7xrfI  Inflammatory Bowel Disease Care at Boston Medi...       en
# 44  X27WzfT3NGA                            Meet: Stephen Huang, MD       en
# 56  RHK7gjNfuZ4  DOĞADA HAYAT 42.BÖLÜM MANGAL/ACEM KIZI  |  LİF...     None
# 60  Iis9VJXgzKI  DOĞADA HAYAT 38.BÖLÜM   |  LİFE İN NATURE EPİS...     None
# 65  o9x7TM75yhM                             Unusual Cowling how V8     None
# 66  k7lN1DCopXM                             unusual Cowling how V6     None
# 67  ZmrcKeD4Hqk  Nak Makan Steamboat Kat Rumah? Korang Kena Ada...     None
# 78  RMlWF2KOC_4  Standing 3 Hours In Line For SUMO Tickets! 😃 |...     None
# 79  Hd5B3JgJ_w0  Serious Terbakar Lidah Makan Jinjja Chicken Le...     None
# 81  qnfwM7F-q_Y  Ayam Double Freaking Hot by NeNe Chicken Pedas...     None
#
#    manual_caption_languages automatic_caption_orig_language std_man_cap_langs  \
# 0                        en                              en                en
# 2                        en                              en                en
# 31                       en                              en                en
# 32                       en                              en                en
# 35                       en                              en                en
# 37                       en                              en                en
# 38                       en                              en                en
# 39                       en                              en                en
# 41                       en                              en                en
# 42                       en                              en                en
# 43                       en                              en                en
# 44                       en                              en                en
# 56                       en                              en                en
# 60                       en                              en                en
# 65                       en                              en                en
# 66                       en                              en                en
# 67                       en                              en                en
# 78                       en                              en                en
# 79                       en                              en                en
# 81                       en                              en                en
#
#    man_cap_langs_list download_lang
# 0                [en]            en
# 2                [en]            en
# 31               [en]            en
# 32               [en]            en
# 35               [en]            en
# 37               [en]            en
# 38               [en]            en
# 39               [en]            en
# 41               [en]            en
# 42               [en]            en
# 43               [en]            en
# 44               [en]            en
# 56               [en]            en
# 60               [en]            en
# 65               [en]            en
# 66               [en]            en
# 67               [en]            en
# 78               [en]            en
# 79               [en]            en
# 81               [en]            en

# %%
rng = np.random.default_rng(42)
shuffled_ids_langs = only_en_man_auto_text_df[["id", "download_lang"]].values.tolist()
rng.shuffle(shuffled_ids_langs)
shuffled_ids_langs[:5]
# Out:
# [['ZigZZ7Cqvfg', 'en'],
#  ['RVHmlK3mLv0', 'en-uYU-mmqFLq8'],
#  ['vTfXBjO_z1E', 'en-RuL_K9RGzgg'],
#  ['JTnAdquASPo', 'en'],
#  ['MKof6QkOHgk', 'en']]

# %%
shuffled_batches = get_subsampled_batches(shuffled_ids_langs, 250)
print(len(shuffled_batches))
shuffled_batches[:5]
# Out:
# 34984
# [{'videoIds': [['ZigZZ7Cqvfg', 'en'],
#    ['RVHmlK3mLv0', 'en-uYU-mmqFLq8'],
#    ['vTfXBjO_z1E', 'en-RuL_K9RGzgg'],
#    ['JTnAdquASPo', 'en'],
#    ['MKof6QkOHgk', 'en'],
#    ['0K1jOM3CHYo', 'en-US'],
#    ['9sfF_2Xu7pM', 'en'],
#    ['fiK9v1YI3XA', 'en-uYU-mmqFLq8'],
#    ['7o8-NOxnYc4', 'en-US'],
#    ['8TB_k1cpQaY', 'en-US'],
#    ['5oFKx8Vt8Gs', 'en'],
#    ['K5evSiB1iPY', 'en-JkeT_87f4cc'],
#    ['dYvyUE3zbqs', 'en'],
#    ['X5ArokuXesU', 'en-uYU-mmqFLq8'],
#    ['isDBXqD0YHQ', 'en'],
#    ['pI0kiftW1n8', 'en'],
#    ['l2rDYpAos4Q', 'en'],
#    ['XC8UxiZJPxo', 'en-US'],
#    ['eE6N8MPVhRw', 'en'],
#    ['muLPYSChruI', 'en-uYU-mmqFLq8'],
#    ['DA4jC82hqFw', 'en-US'],
#    ['JRsjuzCaX9o', 'en-uYU-mmqFLq8'],
#    ['3nZWCqeQQKw', 'en'],
#    ['HWyFwGtv7Tw', 'en'],
#    ['QoQ12rjKDWM', 'en'],
#    ['UgQ2_bGoHe4', 'en'],
#    ['4_U77heiMt8', 'en-US'],
#    ['mXG8k5OevHU', 'en'],
#    ['dXAhK-nUQHI', 'en-PqWgEQDUTmg'],
#    ['BPwI4C9ssTU', 'en-uYU-mmqFLq8'],
#    ['DEHgp_OBGc4', 'en'],
#    ['9L3QdbVhW1w', 'en-uYU-mmqFLq8'],
#    ['rrv1xjd2D9Y', 'en'],
#    ['-T4iirif3Cw', 'en'],
#    ['7A9dWwgEkDY', 'en'],
#    ['lvcROOsBSos', 'en-US'],
#    ['JG06tSX9xNE', 'en'],
#    ['WHfA6ZuMLm0', 'en-US'],
#    ['j8M3wwazZS8', 'en'],
#    ['AhZUr4muz1U', 'en'],
#    ['t3Ih5H8od2c', 'en-uYU-mmqFLq8'],
#    ['3nwvqXuxx3w', 'en-nP7-2PuUl7o'],
#    ['oy5ochSav0E', 'en-uYU-mmqFLq8'],
#    ['TZVlQxQpjcU', 'en-US'],
#    ['Dt3TSGkHBSc', 'en-eEY6OEpapPo'],
#    ['LahC9S5fij0', 'en-nP7-2PuUl7o'],
#    ['kaSZPldO82s', 'en-nP7-2PuUl7o'],
#    ['UQHoFM_GOUE', 'en-uYU-mmqFLq8'],
#    ['sPk7hQbA66w', 'en-j3PyPqV-e1s'],
#    ['g8Ap9mEdmKI', 'en-rS9ixhUSfAE'],
#    ['EVdNTAEhVjo', 'en'],
#    ['PGNc1n5xIlg', 'en-US'],
#    ['4XD4DY0LE8w', 'en'],
#    ['1KsGDtpegRY', 'en-uYU-mmqFLq8'],
#    ['uG4OgwsTxqQ', 'en-Rs3USlB13Vw'],
#    ['F779ywFxFa4', 'en'],
#    ['B8eDElrpz7Q', 'en'],
#    ['Znwfbdpfq3A', 'en-ehkg1hFWq8A'],
#    ['98BnnuCQ3Q4', 'en-uYU-mmqFLq8'],
#    ['EXo3e58rZ7U', 'en-Ryk4R_vy0gs'],
#    ['1b0iqSnvtu4', 'en-uYU-mmqFLq8'],
#    ['B0IQdU8VbB0', 'en'],
#    ['uGu_MMorC-E', 'en'],
#    ['1v_9_n1vcCI', 'en'],
#    ['JNbsRQLfL1o', 'en'],
#    ['wVjkajNP2Uk', 'en'],
#    ['811glyeS_AE', 'en'],
#    ['E0sXB5oaJ4o', 'en-US'],
#    ['X6p-fAXVGDg', 'en'],
#    ['qFM86S8Z7Us', 'en-uYU-mmqFLq8'],
#    ['Z6ZSo_IAZcQ', 'en'],
#    ['fmjdAIP5WU4', 'en'],
#    ['_MMZ7rrwmyk', 'en-JkeT_87f4cc'],
#    ['UHPyV8X8h2w', 'en-eEY6OEpapPo'],
#    ['S_6YWfbFiT4', 'en-ehkg1hFWq8A'],
#    ['CbGt87T3JxY', 'en'],
#    ['vvDLsCAUN7s', 'en-JkeT_87f4cc'],
#    ['MKUu-ttHS-A', 'en-GB'],
#    ['YzVuWflTa3U', 'en-uYU-mmqFLq8'],
#    ['L-TwcTN-2mA', 'en-uYU-mmqFLq8'],
#    ['qSLXHjjtbwI', 'en'],
#    ['hftZiZghL14', 'en'],
#    ['u0mdu1FKrHs', 'en'],
#    ['KJ-xzO_hwjI', 'en'],
#    ['qCN9GhMedDM', 'en'],
#    ['28R-z-ELHpU', 'en'],
#    ['JsYdl0rernE', 'en'],
#    ['8cvz9EnsmjQ', 'en'],
#    ['sPRJCaMriNg', 'en-US'],
#    ['HJpt4DFpDf4', 'en'],
#    ['uF7cuDmr4d8', 'en-hnCuwW0TCiQ'],
#    ['r4x67eOPXFo', 'en'],
#    ['WGAYPA92xDE', 'en'],
#    ['5CSp3cplm3s', 'en-aQJOphK5QyA'],
#    ['fMwDbYZdGH4', 'en'],
#    ['0y1ymrm1erk', 'en'],
#    ['8AecsUHkq0s', 'en-US'],
#    ['2qzBC91vF9o', 'en'],
#    ['cfE3qSmgfiE', 'en'],
#    ['Dns31FXAO6U', 'en-US-SDDpUtgAfGc'],
#    ['exF_SeA8gQ0', 'en-US-N4-h0TFpcMI'],
#    ['rixvveY4470', 'en-JkeT_87f4cc'],
#    ['vB40y91zf7s', 'en'],
#    ['wOHvarCQQvU', 'en'],
#    ['toGKWmSZzMY', 'en'],
#    ['XldJLpyYU2I', 'en'],
#    ['grJy1-plwAg', 'en'],
#    ['eAyjJFbbWxs', 'en'],
#    ['Ao2wfPf_mvQ', 'en-uYU-mmqFLq8'],
#    ['2pDIgIHF3mI', 'en'],
#    ['xMFUB5kJg1U', 'en-US'],
#    ['9uqghFY3XTA', 'en-ehkg1hFWq8A'],
#    ['V5LkE2Ixg3Q', 'en-US-k3B8hBabmvs'],
#    ['3uh3f69OoI4', 'en'],
#    ['stPRzhl6bFk', 'en'],
#    ['y19XxotEjlo', 'en'],
#    ['KPLBu_EhAyA', 'en'],
#    ['Ip66yrvSGig', 'en'],
#    ['uhewY89iK3E', 'en-GB'],
#    ['QrbZsxeFoJ4', 'en'],
#    ['oSt3EoUFXKs', 'en-ehkg1hFWq8A'],
#    ['B4Trkg87rsk', 'en-US'],
#    ['AkzGec0fJoQ', 'en'],
#    ['1udUqHkCJk8', 'en-US'],
#    ['Bzv6psCcN48', 'en-US'],
#    ['0Cp_FXTDl5o', 'en'],
#    ['pIIlM-_mLp4', 'en-uYU-mmqFLq8'],
#    ['Syq2WxKqQFQ', 'en-uYU-mmqFLq8'],
#    ['cp4Mk0cV2R0', 'en'],
#    ['duL4MtkPyEE', 'en'],
#    ['8YoOat-g9fU', 'en-LUU0EuDKgKo'],
#    ['8hvruR_YJQ0', 'en-uYU-mmqFLq8'],
#    ['uUjVvRrwVRE', 'en'],
#    ['yaR_tj7BKb4', 'en'],
#    ['LV9H-TgMn6k', 'en-nP7-2PuUl7o'],
#    ['fqEB8rsfeFg', 'en-US'],
#    ['VLhwauPgTuw', 'en-US'],
#    ['ROJSWUjqXjc', 'en'],
#    ['xJrS9n2E8m0', 'en-uYU-mmqFLq8'],
#    ['HnVwMTt5hUQ', 'en-eEY6OEpapPo'],
#    ['2vJKpQ2GDD4', 'en'],
#    ['ou5wch-6MsI', 'en-nP7-2PuUl7o'],
#    ['WvhBFxo40U4', 'en-US'],
#    ['8gWE_lphMEk', 'en-US'],
#    ['KzEv1YWexcM', 'en'],
#    ['IdO5U1ZV2MM', 'en-Ss45fKQ3WAY'],
#    ['qxYU4pI9SLw', 'en'],
#    ['pjWnrr8px8I', 'en-uYU-mmqFLq8'],
#    ['ZJxAV-_Cifo', 'en-US'],
#    ['nfdasMqmWTY', 'en'],
#    ['mu2rbmZ2LmM', 'en-US'],
#    ['0IgPpw0cO18', 'en'],
#    ['4-PPT9fAlls', 'en-uYU-mmqFLq8'],
#    ['cMaHyTDUsY4', 'en-nP7-2PuUl7o'],
#    ['Ii04yreVdJ8', 'en-nP7-2PuUl7o'],
#    ['9iEomJFKcXY', 'en'],
#    ['qS9RKZrtcfI', 'en'],
#    ['swjKaXaoZRk', 'en-uYU-mmqFLq8'],
#    ['8AXyllJA28U', 'en'],
#    ['FIwdsSUf29c', 'en-US'],
#    ['x5MDpceRyaI', 'en'],
#    ['zEOxAZFBpZo', 'en'],
#    ['sGwJfTxqeHE', 'en'],
#    ['6m1lgZfdds0', 'en-nP7-2PuUl7o'],
#    ['PLzJJc3Aaoo', 'en'],
#    ['N-vJDukn8sE', 'en'],
#    ['t7_DWqXh3Lo', 'en-uYU-mmqFLq8'],
#    ['VUlHKT6HRd8', 'en-GB'],
#    ['W0sWXPBTMzs', 'en-US'],
#    ['1Rergitk6qs', 'en-zL7EZQmMa4Q'],
#    ['OzRhGwQ6YNU', 'en'],
#    ['j6PjtGKTSXo', 'en'],
#    ['GSJ1arOsk5I', 'en'],
#    ['e8gG4Mz4QL8', 'en'],
#    ['aQnvbOtV7Pk', 'en-US'],
#    ['Yq6Ip6Z-XjQ', 'en-GB'],
#    ['DNPjE3qXyrA', 'en-ehkg1hFWq8A'],
#    ['aBzIQ-yvEGU', 'en'],
#    ['s5vn3WVkUxg', 'en'],
#    ['hWD4uXvjjVo', 'en-GB'],
#    ['Y5j-H0pYJgs', 'en-nP7-2PuUl7o'],
#    ['1oPGM2ioL3c', 'en-nP7-2PuUl7o'],
#    ['t070p0Msrxc', 'en'],
#    ['ymFjR1yyfMs', 'en-nP7-2PuUl7o'],
#    ['xRpBPfoIAj4', 'en'],
#    ['4VjhN8LWVwg', 'en'],
#    ['XfmLbJLVeJ8', 'en-uYU-mmqFLq8'],
#    ['tb1WsZHAv2I', 'en'],
#    ['pT3NkztEzic', 'en-US'],
#    ['zJx8QJtelu4', 'en'],
#    ['MHy2jruMPjY', 'en-1oAFzPNiuC0'],
#    ['cUluNsknNWw', 'en-JkeT_87f4cc'],
#    ['Tbc_LQB6lzM', 'en-GIF-dMSnKOc'],
#    ['LCRbePkXZVw', 'en-hVnZ8CMNGL8'],
#    ['LBucHtAX9CQ', 'en-uYU-mmqFLq8'],
#    ['PG2Rebgm_n0', 'en-ehkg1hFWq8A'],
#    ['eRcuUMVA9o0', 'en'],
#    ['SLDzqxb-RNc', 'en-Ue-mEpKRpUo'],
#    ['cIri79huWwI', 'en'],
#    ['1IAR6EaXi6I', 'en-uYU-mmqFLq8'],
#    ['FczwcwTCKY8', 'en-5659OAhiP08'],
#    ['41vTVg5O0RI', 'en-6UJrWS5jR_I'],
#    ['WAMlcEYoCVw', 'en'],
#    ['xrma1hnOUhM', 'en-nP7-2PuUl7o'],
#    ['QFQKNiKaMvA', 'en'],
#    ['ZwT1zMY3bVA', 'en-US'],
#    ['-e5q-DlNAvo', 'en-MAr2jwfVOv8'],
#    ['j_jUSsY2xeo', 'en'],
#    ['zN-o0A3dwjI', 'en'],
#    ['xePJ6uA0en8', 'en-CA'],
#    ['jgdwCCC3mpQ', 'en'],
#    ['-GLvjxYNliM', 'en-nP7-2PuUl7o'],
#    ['v7wGLqRzrSQ', 'en'],
#    ['q6cKJe-8Ho4', 'en'],
#    ['Vpwh1iVuG_Y', 'en-GB'],
#    ['cAtjo87XazE', 'en-ZjdFO5nG7L8'],
#    ['GV8qYoKzWLI', 'en-uYU-mmqFLq8'],
#    ['rPhbRj0yxN8', 'en-GB'],
#    ['ef6uC5tqyds', 'en-GB'],
#    ['BiLNOWIpDpQ', 'en'],
#    ['NHXGgABM3I8', 'en'],
#    ['luz_YsZ7Xs4', 'en-US'],
#    ['K6sqtiDShdg', 'en-US'],
#    ['LKtdYLNQLYQ', 'en'],
#    ['wWakyeJhNO4', 'en-nP7-2PuUl7o'],
#    ['YNCvvOzzqY8', 'en-CA'],
#    ['LpLa3HqNAH0', 'en'],
#    ['hIqE8rHZd_8', 'en-US'],
#    ['-rQH9lhR5Kw', 'en-ehkg1hFWq8A'],
#    ['TPXjEOZCtY4', 'en'],
#    ['v7Mt4GAqklQ', 'en-US-ttLAmp2-FKI'],
#    ['0KGcwHkVYj8', 'en-nP7-2PuUl7o'],
#    ['hRH5dg-VZGg', 'en-nP7-2PuUl7o'],
#    ['wswk8QpLmLM', 'en'],
#    ['AWtwClU_ixo', 'en-US'],
#    ['k_rFcjFiKhU', 'en'],
#    ['nF6VtFgepmY', 'en-GB'],
#    ['hmNxUPdNlHY', 'en-JkeT_87f4cc'],
#    ['m1w3ir3kiKM', 'en'],
#    ['4A8Gh2dKXR0', 'en-uYU-mmqFLq8'],
#    ['cLQen88J2Lw', 'en-JkeT_87f4cc'],
#    ['I8Cc3_gPO1s', 'en-US'],
#    ['XfloZxxewQI', 'en-GB'],
#    ['9792m1-ZhgA', 'en-uYU-mmqFLq8'],
#    ['6jUTQNZoNts', 'en-uYU-mmqFLq8'],
#    ['hMwdKUxLwDA', 'en'],
#    ['SEx3SM56L8c', 'en-uYU-mmqFLq8'],
#    ['Dn1WBFaFif0', 'en'],
#    ['i7uyZ64LMXM', 'en'],
#    ['GWwnSso7n28', 'en']],
#   'batchIdx': 0},
#  {'videoIds': [['zJRdAT12-7k', 'en'],
#    ['M71C_UDH0TY', 'en-GB'],
#    ['q-Qx9bFORQU', 'en-qoXxhA4oLYo'],
#    ['j533HGGOQ2M', 'en'],
#    ['anU2EzPGfqQ', 'en'],
#    ['4Q68vvx4-JI', 'en-US'],
#    ['Zr2_hlogiMU', 'en'],
#    ['ehx55vtWbaQ', 'en'],
#    ['NzSO3nQj944', 'en'],
#    ['DFYQ5HiI8Kk', 'en-j3PyPqV-e1s'],
#    ['X4mimcYg-kw', 'en'],
#    ['jyws7m2CYT8', 'en-uYU-mmqFLq8'],
#    ['7IRLdG_cRFQ', 'en-NuKogFS7V8Q'],
#    ['8pZ7rXey8Hs', 'en-uYU-mmqFLq8'],
#    ['XJ7j8pkf8Jk', 'en'],
#    ['mkXiIu_rwzk', 'en-uYU-mmqFLq8'],
#    ['NDsLxfnyoiE', 'en-nP7-2PuUl7o'],
#    ['g785Fi97ZrA', 'en'],
#    ['3CKBO8giCBY', 'en'],
#    ['ZY7iymiMz3Y', 'en'],
#    ['aO8kPKuG0QE', 'en'],
#    ['lCDuv_ddH1g', 'en'],
#    ['mTzHwzN6DnU', 'en'],
#    ['RVHnB4tuwqE', 'en'],
#    ['D1cPtvfxZU4', 'en'],
#    ['0VJ37aIXtY4', 'en'],
#    ['hdVskA4GeDE', 'en'],
#    ['Qlpp0FnTErU', 'en'],
#    ['kouGeiO_otY', 'en'],
#    ['TFIwuWMeSOg', 'en-eEY6OEpapPo'],
#    ['hFNkJL1_flw', 'en-GB'],
#    ['1R5RCaqRmto', 'en-US'],
#    ['mVGEROYt67E', 'en'],
#    ['kRk04kqzRdQ', 'en'],
#    ['rGZtqFb61x0', 'en'],
#    ['de0hNMpclJI', 'en-uYU-mmqFLq8'],
#    ['PJ23V04CMjk', 'en'],
#    ['65s5rk8s_K4', 'en'],
#    ['cwoO0NSvwKc', 'en'],
#    ['kHV-tKgQq2E', 'en-uYU-mmqFLq8'],
#    ['z6ZkAOy0YIA', 'en'],
#    ['nYNAH8K_UhI', 'en-CA'],
#    ['X2SXDgve4OM', 'en-uYU-mmqFLq8'],
#    ['PFoOuOp7u3U', 'en'],
#    ['rXvn5bMypaw', 'en'],
#    ['mrvtTyAKWIA', 'en-JkeT_87f4cc'],
#    ['5kmZWbrH6N0', 'en'],
#    ['xY7hY92-ZAM', 'en-uYU-mmqFLq8'],
#    ['wUeDkrqhAnI', 'en-US'],
#    ['z8_N4tjkwu0', 'en'],
#    ['3XwGSN99Xbs', 'en'],
#    ['GkqVuVZwAkk', 'en-US'],
#    ['PWRYWUilBHo', 'en-uYU-mmqFLq8'],
#    ['Sf2ZtVJfhaM', 'en'],
#    ['LiaFEvbFVFE', 'en'],
#    ['Qi8-kH-1hlw', 'en-uYU-mmqFLq8'],
#    ['rlFqH5oq_8s', 'en'],
#    ['h3e9---24Mk', 'en'],
#    ['BkVfoLtFCIM', 'en-nP7-2PuUl7o'],
#    ['uiNMWi-B6dk', 'en'],
#    ['FN6Al8aD5mM', 'en'],
#    ['TkwIfD7qqFU', 'en'],
#    ['doQd2SyBU0U', 'en'],
#    ['x9B81_r81-4', 'en-CA'],
#    ['hbdLTgtnFsg', 'en-US'],
#    ['b20p6KWltmE', 'en'],
#    ['38OXkfQox_Y', 'en'],
#    ['6-TnMS2cpGM', 'en'],
#    ['O8nyaZn5fls', 'en'],
#    ['v13PJkplDJU', 'en'],
#    ['avf_Y8se9kY', 'en'],
#    ['VRdRdXt-U48', 'en-acDb81a2Cfk'],
#    ['JKmRk8FAAIM', 'en-uYU-mmqFLq8'],
#    ['qeQH-72cono', 'en'],
#    ['kof8JL8lbiM', 'en-GB'],
#    ['nNSR1IzflQw', 'en-uYU-mmqFLq8'],
#    ['HY_LS2Ns5HU', 'en-US'],
#    ['RveOq-I1RLQ', 'en-uYU-mmqFLq8'],
#    ['aYpLBHCNp0Y', 'en-nP7-2PuUl7o'],
#    ['Y_d6O7AiLKg', 'en-RTbB2cpHawQ'],
#    ['iwpEl8VR8ao', 'en-GB'],
#    ['Y86hoqV4TME', 'en-uYU-mmqFLq8'],
#    ['acrcy07LqGQ', 'en'],
#    ['Za-59akMxZU', 'en'],
#    ['SzyoPX6GcPI', 'en-US'],
#    ['QKVHCjZXoIY', 'en-T8wO0chuPkU'],
#    ['nMUFhANRDV8', 'en'],
#    ['JY5S0NrkKFA', 'en'],
#    ['18uvZvyolcw', 'en'],
#    ['jspyyUW54E8', 'en'],
#    ['I95yyTcWRGg', 'en-US'],
#    ['PkyaAcAITBQ', 'en-nP7-2PuUl7o'],
#    ['t118dhoKiYM', 'en'],
#    ['sH4hsnhDbjY', 'en-US'],
#    ['Js6Fz3e6FBE', 'en-YNm4XUiSLe8'],
#    ['3BOLctKKyrs', 'en'],
#    ['-jtRypquQ-U', 'en'],
#    ['_V3ojCiKskk', 'en'],
#    ['77p4XKaIQHY', 'en'],
#    ['3Ad9LbuSbPE', 'en-GB'],
#    ['IUI-S9GBQt8', 'en'],
#    ['Ef1kaO6yNtA', 'en'],
#    ['Df0i4H2CKWI', 'en-US'],
#    ['rOnSLKYq5Cc', 'en-US'],
#    ['EqF-Y1EmVU0', 'en'],
#    ['AWKSSb8yJP0', 'en-uYU-mmqFLq8'],
#    ['pO_TH22lhRo', 'en-ehkg1hFWq8A'],
#    ['a-ZxLWPj6KM', 'en'],
#    ['eNdoE3WZq4s', 'en-nP7-2PuUl7o'],
#    ['tkIR6O26xAU', 'en-uYU-mmqFLq8'],
#    ['Ncsc1FLTVr4', 'en'],
#    ['wDYpuCtK-u0', 'en'],
#    ['-_Ny8YjPY-U', 'en'],
#    ['yDmTw-xRp0k', 'en'],
#    ['zvU-H2ikcpM', 'en-uYU-mmqFLq8'],
#    ['JAdppOCqbBQ', 'en-US-zOFsReYi2c4'],
#    ['uC0gMzmxDIA', 'en'],
#    ['7R61s-Kivsw', 'en'],
#    ['wS8s1ErYFrE', 'en'],
#    ['__18d8OgmgI', 'en-K7hk9tNAXqg'],
#    ['74Ib6mDaOtY', 'en-nP7-2PuUl7o'],
#    ['_7Adfyqx2vM', 'en'],
#    ['upO-0hEa4MA', 'en'],
#    ['oCQR-p7RX4U', 'en-US'],
#    ['1YtZiD9gzfI', 'en'],
#    ['XJuDo_Ccr60', 'en'],
#    ['NlxAhzLMhSo', 'en'],
#    ['C4TN59UB3B0', 'en-nP7-2PuUl7o'],
#    ['UrGIG085MGI', 'en-US'],
#    ['tpGVDeavuYU', 'en-US'],
#    ['sVMoKj7kmfY', 'en'],
#    ['avX7ILtjUfU', 'en'],
#    ['h0vtEnNs7GY', 'en'],
#    ['G1uzZPx8OVQ', 'en-uYU-mmqFLq8'],
#    ['vvWPgn_JHqY', 'en'],
#    ['Pi87xjd0Dm8', 'en'],
#    ['BPidYiRkVyc', 'en'],
#    ['yE1TF_KTlmM', 'en'],
#    ['qNHn-SVdOVE', 'en'],
#    ['XhedsMg_9W0', 'en'],
#    ['YJKaJ0s2VzE', 'en'],
#    ['zQu-zzhrbnQ', 'en'],
#    ['a5HOHPB4pmg', 'en'],
#    ['d6wJ2GftCnY', 'en'],
#    ['wCCoF1wT1j4', 'en'],
#    ['dAxKGp3DHcI', 'en-uYU-mmqFLq8'],
#    ['xZDAYog-BUk', 'en-ehkg1hFWq8A'],
#    ['H7Hxq6AgtLk', 'en-nP7-2PuUl7o'],
#    ['bMWTYoz4Xtk', 'en-uYU-mmqFLq8'],
#    ['SDEABO-H4c0', 'en-GB'],
#    ['hZL0CPTKE44', 'en'],
#    ['J64L5I5cf0Y', 'en-US'],
#    ['x3KcCF2ITQA', 'en-GB'],
#    ['cGZ6zPGJoyI', 'en-uYU-mmqFLq8'],
#    ['EJjVJv1XPdw', 'en'],
#    ['Y7QZW8k825s', 'en'],
#    ['IKnO_uD6iyM', 'en'],
#    ['97LtGWJ27b4', 'en-CA'],
#    ['ViJ4SxkFsb0', 'en'],
#    ['zDiD4xzVCew', 'en'],
#    ['OXW7wfchkAc', 'en-mtjSGeRrclY'],
#    ['TwNngfFNPag', 'en-ehkg1hFWq8A'],
#    ['h2dlmtRXMxM', 'en'],
#    ['tqJEvJd_wb0', 'en'],
#    ['9SlPasbwois', 'en'],
#    ['I2KmoAyeyug', 'en-nP7-2PuUl7o'],
#    ['sqfm37vlXYY', 'en'],
#    ['7QdWW01Y1WI', 'en-nP7-2PuUl7o'],
#    ['vXmTZmxwrfY', 'en-US'],
#    ['foJE5CL9pmk', 'en-CA'],
#    ['eeis8LesOz8', 'en'],
#    ['lb5glupCMP8', 'en-US'],
#    ['5kEbeN6DlMQ', 'en'],
#    ['iTZhennpYpI', 'en-EfnGcgMiFfY'],
#    ['vD_5gWzwCy0', 'en'],
#    ['4gT8e1Cx1YA', 'en'],
#    ['u5ylkHtYjN0', 'en-uYU-mmqFLq8'],
#    ['yE-fG7HJwzQ', 'en'],
#    ['hHchjdKlyf8', 'en-Jyun0WSqg2k'],
#    ['DJLgDYyMoFo', 'en-US'],
#    ['EkgYNG1WqXo', 'en'],
#    ['1swb10O831E', 'en'],
#    ['NTyumcc8Wic', 'en-US'],
#    ['Hyek0KJXW40', 'en-uYU-mmqFLq8'],
#    ['qc_hvhp8Acs', 'en'],
#    ['9iMH24KAKE0', 'en-uYU-mmqFLq8'],
#    ['9qucN5GvZPU', 'en'],
#    ['Ce6AdIX0N3o', 'en'],
#    ['oVzXkKnDgCA', 'en'],
#    ['8gQi2ATu1_w', 'en-US'],
#    ['cMWAPouTFIc', 'en'],
#    ['r8rVAdGmKvU', 'en'],
#    ['gUGUmkkYbvc', 'en'],
#    ['-tItgx5N0Uc', 'en-US'],
#    ['d2Agjo0Be3k', 'en'],
#    ['StG-MBi6bnE', 'en'],
#    ['w6KwcU9bRUM', 'en-US'],
#    ['QjZOciTOeig', 'en'],
#    ['gKcs1lrTm9s', 'en-JkeT_87f4cc'],
#    ['dDhQhrlCMsA', 'en-US'],
#    ['422_I7PtYfE', 'en'],
#    ['hoCX1cZtINE', 'en'],
#    ['L9-RHQQeWIY', 'en'],
#    ['qUOjN2XOFxo', 'en'],
#    ['mxNnxpuYXdo', 'en'],
#    ['xF9IeoNoQ80', 'en'],
#    ['wLi0lkddTH8', 'en-eRC6fHhkjFQ'],
#    ['KP1B6L_5iD4', 'en'],
#    ['LvjeTpvkKaY', 'en-ehkg1hFWq8A'],
#    ['40zEb61p9a8', 'en'],
#    ['lC0w_pnYbb8', 'en'],
#    ['lo-CeGqi3xo', 'en'],
#    ['BR0l7Lw9J08', 'en'],
#    ['Mp-APyfhPiY', 'en-j3PyPqV-e1s'],
#    ['iQ7T2v8P-I0', 'en'],
#    ['Ouer3ASW-S8', 'en-GB'],
#    ['Bqdz72gs_xQ', 'en-rX01gsAdUfU'],
#    ['5NXYP5JDxco', 'en-nP7-2PuUl7o'],
#    ['6N7zis4aziw', 'en-US'],
#    ['kfrinohyW_s', 'en-NB9kbuytmcY'],
#    ['jD_oA5TOKhk', 'en-LUU0EuDKgKo'],
#    ['7eUPnKNXUsE', 'en'],
#    ['Ri8n63PHm5U', 'en-ehkg1hFWq8A'],
#    ['VW30Z9gxr_4', 'en-i7LFIGUQP0g'],
#    ['XEh9gLqPhVY', 'en'],
#    ['5sUYBL2XD9o', 'en'],
#    ['eUBz_k-zIIY', 'en-uYU-mmqFLq8'],
#    ['popbIhGxCi8', 'en'],
#    ['AGmtssj_0vY', 'en-ehkg1hFWq8A'],
#    ['C8ijWrosWak', 'en-K89zrwN-f8w'],
#    ['MoHVQiYB5d4', 'en'],
#    ['TaOf6JsOpD4', 'en'],
#    ['l3Sn84eH2nA', 'en-ehkg1hFWq8A'],
#    ['iEMfBb3o-E8', 'en-uYU-mmqFLq8'],
#    ['Wbw3mksrWTk', 'en'],
#    ['VMxz_T8A_2s', 'en-US'],
#    ['2VQml1f_Fto', 'en'],
#    ['rdEHxwNYGeI', 'en-OGgDzoxRy28'],
#    ['YHmf5RzKT9A', 'en-Squ3aT4R3gw'],
#    ['WOX6hNFTFtg', 'en'],
#    ['umLUq_HtcD4', 'en-eEY6OEpapPo'],
#    ['way2KK1cet0', 'en'],
#    ['Q2Qt8C7vtcg', 'en-uYU-mmqFLq8'],
#    ['aBpvI2VBgQ8', 'en'],
#    ['EN8ThV1465s', 'en'],
#    ['qFUd6p_9Rdg', 'en'],
#    ['hr3biybfZWE', 'en-US-cvfXDfbeED0'],
#    ['X8QESKn4xyU', 'en'],
#    ['-11mdWaLpSk', 'en'],
#    ['KepBZRmd71U', 'en-uYU-mmqFLq8']],
#   'batchIdx': 1},
#  {'videoIds': [['ryhcSsNzuzc', 'en'],
#    ['PVQPmLR2zW8', 'en-nP7-2PuUl7o'],
#    ['oHRatWWNwiY', 'en-g0wW8Gh3lgg'],
#    ['Fsk2aD0aPT8', 'en-nP7-2PuUl7o'],
#    ['cezZUxdTjvM', 'en-rX01gsAdUfU'],
#    ['KN9mEC_k6oI', 'en-ehkg1hFWq8A'],
#    ['upt8JhtC9PQ', 'en-JkeT_87f4cc'],
#    ['3RDbF-iM-DY', 'en-US'],
#    ['sQt_K26lEdw', 'en-uYU-mmqFLq8'],
#    ['0fWfI9v7nHo', 'en'],
#    ['xibEPOsvpjE', 'en'],
#    ['NfjNusBcuZs', 'en-US'],
#    ['ClNA-_rw-FY', 'en-US'],
#    ['ou-1XbyRHxM', 'en'],
#    ['xZhqqrC9grw', 'en'],
#    ['hfT_C-uMElU', 'en-ehkg1hFWq8A'],
#    ['v6YGVzODUyM', 'en-uYU-mmqFLq8'],
#    ['tPrYTVjzeIU', 'en-ehkg1hFWq8A'],
#    ['dsZwx1lO6hw', 'en-nP7-2PuUl7o'],
#    ['n9qs8dFsroA', 'en'],
#    ['d_yStv6FJbE', 'en'],
#    ['9YQEVrGtm0w', 'en-GB'],
#    ['kpLAZ6tDpr8', 'en-uYU-mmqFLq8'],
#    ['45U8sOv9GSM', 'en'],
#    ['dJ1mkRQ-oRs', 'en'],
#    ['zuoFG1A_AOE', 'en-hnCuwW0TCiQ'],
#    ['Z13QiLPeIWE', 'en-nP7-2PuUl7o'],
#    ['Y7iTcJQAiU4', 'en'],
#    ['4XfJSUw9MOI', 'en'],
#    ['epn84vGbei4', 'en-US'],
#    ['ORpogHTT1SU', 'en-nP7-2PuUl7o'],
#    ['aMdbjB3SGa0', 'en-vlW2OHFw3ww'],
#    ['Gj0WbtTaXyU', 'en-US'],
#    ['ewtN9K5WuE4', 'en'],
#    ['Y1-80DW_pLs', 'en'],
#    ['_n9Tq8c0fHc', 'en'],
#    ['n5_rrc3La88', 'en-uYU-mmqFLq8'],
#    ['4l3GH4SNWQY', 'en-nP7-2PuUl7o'],
#    ['TQVddpnPO1E', 'en'],
#    ['DVBxyeOSVtA', 'en'],
#    ['YoI5b5GV6wk', 'en'],
#    ['YjDUrdfrR1c', 'en'],
#    ['55rcufCjHps', 'en'],
#    ['Kmc9fKiaPP0', 'en'],
#    ['sovaqUpXD9Y', 'en-uYU-mmqFLq8'],
#    ['omYLhZEOxiQ', 'en-uYU-mmqFLq8'],
#    ['coUyxbJqqj0', 'en-IN'],
#    ['VvaQjxrFgrQ', 'en'],
#    ['8-UZJQnUHag', 'en-uYU-mmqFLq8'],
#    ['otn-qG3iXj4', 'en-uYU-mmqFLq8'],
#    ['U6LrrmxHTT0', 'en-nP7-2PuUl7o'],
#    ['ZSr6AAX1sPU', 'en'],
#    ['5lAJ5EItCYc', 'en'],
#    ['b3Rfk73OaRs', 'en'],
#    ['-Q3kTx99VhQ', 'en'],
#    ['TFv7C1taJ4g', 'en'],
#    ['QaVFPGJ3O2M', 'en'],
#    ['_SmnMhpJhlk', 'en-US'],
#    ['EFW6UV1mq-U', 'en'],
#    ['slJnwk6TU0A', 'en-IN'],
#    ['vSfT863KMx4', 'en-US'],
#    ['lXrqGzrtuB4', 'en-uYU-mmqFLq8'],
#    ['sydpSIekqoA', 'en-uYU-mmqFLq8'],
#    ['-SsatLKm7HY', 'en'],
#    ['7kEVzVYaHzU', 'en'],
#    ['aoHkf-KCjiQ', 'en'],
#    ['ZGbJyfJjbLA', 'en'],
#    ['VAIORxxEUzE', 'en'],
#    ['K_PK5SNsWAU', 'en'],
#    ['VLnR9bdMK4Q', 'en-uYU-mmqFLq8'],
#    ['CO--S1NHHwQ', 'en'],
#    ['scnF_q3-VdU', 'en-nP7-2PuUl7o'],
#    ['YXNLOmqOl7Q', 'en-nP7-2PuUl7o'],
#    ['F25cK6gE5tE', 'en'],
#    ['soNqg1ko2bw', 'en-JkeT_87f4cc'],
#    ['Tl8IMdFYEYM', 'en'],
#    ['r5g3mbVmblw', 'en'],
#    ['RCM2OJvC1LQ', 'en'],
#    ['d446pVfyLts', 'en-US'],
#    ['QX2YRjJ79es', 'en-uYU-mmqFLq8'],
#    ['decJVSam7Y4', 'en'],
#    ['vLzn_Zb6OD8', 'en'],
#    ['b_mIS-tzglk', 'en'],
#    ['Z8D8IXCrlZk', 'en-uYU-mmqFLq8'],
#    ['IHFxQw1BmdA', 'en'],
#    ['IxYBwP1LJfo', 'en'],
#    ['5FTQmvLBIhA', 'en-US'],
#    ['wzGbIwPo3lw', 'en'],
#    ['E8saFNBbB0k', 'en'],
#    ['rPrfD9_RbCg', 'en-US-dOaosRHqfaE'],
#    ['pcZu8qQC0y8', 'en-uYU-mmqFLq8'],
#    ['7JYpH007-R4', 'en'],
#    ['_Z20dUX1ifI', 'en'],
#    ['1GyUcIcOwmU', 'en'],
#    ['lT9a--Ts9to', 'en-uYU-mmqFLq8'],
#    ['s1f3jSjlTjI', 'en-uYU-mmqFLq8'],
#    ['Fo0fY1s_V_M', 'en-uYU-mmqFLq8'],
#    ['jb8sAJzoHxs', 'en'],
#    ['j9n1fcXK4XU', 'en'],
#    ['LJLo6MafPVM', 'en'],
#    ['eLVyOyOh8oI', 'en'],
#    ['NSGV8bP-LOQ', 'en-US'],
#    ['-a9CkxWYL48', 'en'],
#    ['ryhk7CtGNXE', 'en'],
#    ['0ITTgmTshWI', 'en'],
#    ['ukPp4eov9yg', 'en'],
#    ['62CPgB9ZE1M', 'en'],
#    ['1DLcO09sAU0', 'en-uYU-mmqFLq8'],
#    ['YAysMqfrdr4', 'en'],
#    ['k_Z5rDjmLnU', 'en-nP7-2PuUl7o'],
#    ['7i0e8rPhqFo', 'en'],
#    ['HqLgaKbNb6o', 'en-nP7-2PuUl7o'],
#    ['D9XM6OlK01Y', 'en-hnCuwW0TCiQ'],
#    ['PKNtkCvvaiM', 'en-US'],
#    ['E1VuoNyAgsg', 'en-US'],
#    ['Z1-oz9gFYZU', 'en-US'],
#    ['JUslROmJDR4', 'en'],
#    ['YutbJwjDhh8', 'en'],
#    ['tsdWjZXFJ3s', 'en'],
#    ['ZXrmE2Jum7Y', 'en-uYU-mmqFLq8'],
#    ['w-tYHAN_4Is', 'en'],
#    ['JH98j7W7BYg', 'en'],
#    ['zJUoUlWYZXo', 'en-US'],
#    ['_MfzAeEhJ9Y', 'en'],
#    ['XIEKF_hqFl4', 'en'],
#    ['ZDh1oeCbiKg', 'en-j3PyPqV-e1s'],
#    ['Dj_MjF6bZKQ', 'en-US'],
#    ['o4Qd2JNPKIk', 'en'],
#    ['Cj17IbVcT6A', 'en-J3BaQtBnZuc'],
#    ['UCSI7Zba41s', 'en-nP7-2PuUl7o'],
#    ['gi7I8HQEJ7Q', 'en'],
#    ['QsMHiXtH-4Q', 'en'],
#    ['f__LmiZykUI', 'en-US'],
#    ['2jdtUy-k49s', 'en-8k4n8tHBXFc'],
#    ['OZFJkfsgmes', 'en'],
#    ['oe0UBKcT0ac', 'en-nP7-2PuUl7o'],
#    ['51ELmB8QXxE', 'en'],
#    ['XLgDB92Wlms', 'en'],
#    ['f8T6MjfyQFk', 'en-US'],
#    ['rKVv2n5Jr_0', 'en-US'],
#    ['lGcimpv1rlg', 'en'],
#    ['wbBrzhX56oc', 'en-uYU-mmqFLq8'],
#    ['2HV86JH5Zn0', 'en-uYU-mmqFLq8'],
#    ['jFmVv6jiAIs', 'en'],
#    ['CibsgNlJl_c', 'en'],
#    ['i2AhGkopMag', 'en'],
#    ['FV2y2ooQTy8', 'en'],
#    ['hTJn9IcbNHA', 'en'],
#    ['okAaMqK_ufM', 'en-US'],
#    ['WTOzqp6kwPM', 'en'],
#    ['41KSL3bSqC0', 'en-US'],
#    ['YSMipIRUo4c', 'en-JkeT_87f4cc'],
#    ['PyxXxY7JJyE', 'en'],
#    ['Y_S_aQxuJos', 'en'],
#    ['yvKYqOA_MVU', 'en-GB'],
#    ['15keRbhgDys', 'en-nP7-2PuUl7o'],
#    ['uICV-GXavd0', 'en-vlW2OHFw3ww'],
#    ['rI56nBmutWo', 'en'],
#    ['GKBRpmYFhbQ', 'en-nP7-2PuUl7o'],
#    ['pr3bq--VCaw', 'en-ehkg1hFWq8A'],
#    ['Hu1zerSNNxg', 'en'],
#    ['ltvWv_CbDGs', 'en-RTbB2cpHawQ'],
#    ['JRMpLcar0aY', 'en'],
#    ['4kHpdDMY0Yc', 'en-nP7-2PuUl7o'],
#    ['_xWyHKU2ixM', 'en'],
#    ['3-CmubtLGas', 'en-uYU-mmqFLq8'],
#    ['a8MMgwy47rM', 'en'],
#    ['Mv2TP5kTeWw', 'en-nP7-2PuUl7o'],
#    ['FIWbVhvFsXY', 'en'],
#    ['N3F4LMiOUOY', 'en-GB'],
#    ['KTJEpCLyq8M', 'en-uYU-mmqFLq8'],
#    ['6UDfYDyMVAQ', 'en'],
#    ['32Q7ypKMbeI', 'en-uYU-mmqFLq8'],
#    ['ZOdbljyqQrs', 'en'],
#    ['TaOVVI_Oufk', 'en-uT3gf2JfQwA'],
#    ['RNx7T3pF_C4', 'en'],
#    ['bU3j4ECujxo', 'en'],
#    ['dApq5Gr5T8g', 'en'],
#    ['iErCF1797L8', 'en'],
#    ['arsMOnN19Sg', 'en'],
#    ['kidgJXYvQdc', 'en'],
#    ['0wdWVfTFhbA', 'en-uYU-mmqFLq8'],
#    ['anELi_Q4ewg', 'en'],
#    ['llp1KD7T93s', 'en'],
#    ['Y0ideLNVTX0', 'en'],
#    ['hFRsP8shFhs', 'en'],
#    ['axqIgB6hNxA', 'en'],
#    ['6D3Zvec7tMY', 'en-uYU-mmqFLq8'],
#    ['GBR6lygKBF8', 'en'],
#    ['eAnu1CTRrSk', 'en'],
#    ['prwGM6L-Nb4', 'en'],
#    ['uk8N_k29DL4', 'en-US'],
#    ['b_JmwK7QYz0', 'en'],
#    ['aFLN3sipWH4', 'en-j3PyPqV-e1s'],
#    ['j5lBPZsPJIg', 'en-uYU-mmqFLq8'],
#    ['NYOttRyhl7E', 'en-7DeyQimNDqA'],
#    ['058tCR5lbBk', 'en-US-eEY6OEpapPo'],
#    ['XW5Xev-WWcU', 'en-vBTcuymDyuY'],
#    ['RAzjdc73q6I', 'en'],
#    ['ihOfvD6MW-I', 'en'],
#    ['B4MQG5NYFqk', 'en-KiF8PLhXDeA'],
#    ['-2d93sD7uQE', 'en'],
#    ['vDA2jK5EWaU', 'en'],
#    ['ABPX4CakcW8', 'en'],
#    ['6vt87BtS6yk', 'en'],
#    ['S2MBswjm8SI', 'en'],
#    ['IuoaDrUiGPk', 'en-LLufkcctGb8'],
#    ['48dMtE-moZs', 'en'],
#    ['u_GRdo0lKdA', 'en'],
#    ['B3KD83vrP74', 'en-US'],
#    ['zwaWMUvM36U', 'en'],
#    ['-2EpGpUi1Bc', 'en-nP7-2PuUl7o'],
#    ['YwJPbl4R7qk', 'en'],
#    ['ABxCOX3I7iE', 'en-uYU-mmqFLq8'],
#    ['ZMFE7uM8Vkk', 'en'],
#    ['ZNf-0gjDL3M', 'en-JkeT_87f4cc'],
#    ['i4p4ZW1xXXU', 'en-CA'],
#    ['q6xZLPIWFkc', 'en'],
#    ['MAq-Aqaz0J4', 'en-nP7-2PuUl7o'],
#    ['9mysjJ9KGtU', 'en'],
#    ['IsC1-mcxCf8', 'en'],
#    ['wYKh36okj2U', 'en'],
#    ['h3I20xqH4kc', 'en'],
#    ['qGndPcbrHxk', 'en-GB'],
#    ['A8BVege7EOY', 'en-US'],
#    ['h-btHKJ9TrU', 'en'],
#    ['o9Myj61pUaY', 'en-uYU-mmqFLq8'],
#    ['hjXlxTPgCrY', 'en-uYU-mmqFLq8'],
#    ['VCFJPDqKPgc', 'en'],
#    ['fNXI25LgUhk', 'en-NhN6quT04VA'],
#    ['tXZfOxLUxP0', 'en-uYU-mmqFLq8'],
#    ['JRQ2U86-VPc', 'en-nP7-2PuUl7o'],
#    ['thFsY81bW2s', 'en'],
#    ['BbX41IXkRNk', 'en-nP7-2PuUl7o'],
#    ['tB7oRljJZts', 'en'],
#    ['3hIhIlmRySg', 'en'],
#    ['QIviCIaupSs', 'en-GB'],
#    ['S3vHjxonOeg', 'en-PHizVQKyaT8'],
#    ['H5Esvtp1j9Q', 'en-uYU-mmqFLq8'],
#    ['7rQQXDcx60I', 'en-nP7-2PuUl7o'],
#    ['9EYBy9Wsaak', 'en'],
#    ['UcYFifFNbes', 'en'],
#    ['Fg__d3HCj0E', 'en-nP7-2PuUl7o'],
#    ['T0uM11voS4Q', 'en'],
#    ['8MLxiBIjde8', 'en'],
#    ['HtUlqc5L2g0', 'en-US'],
#    ['E3l6zqG2Qrc', 'en'],
#    ['834uYTODmfM', 'en-US'],
#    ['jq5ASt-g57Q', 'en'],
#    ['wVeweUpoTyg', 'en']],
#   'batchIdx': 2},
#  {'videoIds': [['0Qxsw4DDXU8', 'en-uYU-mmqFLq8'],
#    ['VSwRwvN63zU', 'en-US'],
#    ['1Vq-5-ZWKw0', 'en'],
#    ['UjOOKzRlbLU', 'en-US'],
#    ['REpsbFVUwrA', 'en'],
#    ['-V3UFtJwBZ0', 'en-US'],
#    ['5UhW4SNjgGw', 'en-uYU-mmqFLq8'],
#    ['RphpiIYgsms', 'en-uYU-mmqFLq8'],
#    ['tfCdqKwhy0w', 'en'],
#    ['s8QgDd1VuwI', 'en'],
#    ['XkpgIVnecss', 'en'],
#    ['XGVc0xcl2rs', 'en-uYU-mmqFLq8'],
#    ['5euUH_FjXaw', 'en-uYU-mmqFLq8'],
#    ['ejt4Dogn28o', 'en-nP7-2PuUl7o'],
#    ['aSXO7kclZoM', 'en-uYU-mmqFLq8'],
#    ['YNoQKtDUkoQ', 'en-id0PbFh636o'],
#    ['9idS5NT2bH8', 'en-nP7-2PuUl7o'],
#    ['AEwUIrhZsx8', 'en'],
#    ['_IA0P1m-ONU', 'en'],
#    ['OvL3ptyUTdU', 'en'],
#    ['Ga4Q53OQ5NU', 'en-uYU-mmqFLq8'],
#    ['9ksulNBGs2g', 'en'],
#    ['SlyDv9R6RVY', 'en'],
#    ['fp6liNmqCfg', 'en'],
#    ['DO95H33VD-4', 'en'],
#    ['sRSohwfvk8g', 'en'],
#    ['U9y8rUXVUXw', 'en-uYU-mmqFLq8'],
#    ['yO3SaWJjVp4', 'en-uYU-mmqFLq8'],
#    ['qhjYCKPndaY', 'en'],
#    ['zA0BnE0H_e0', 'en'],
#    ['qDk-2pu93Dw', 'en-GB'],
#    ['B96JX0q-6rM', 'en'],
#    ['NkHStde5rrk', 'en'],
#    ['7ypbWY_yjkU', 'en'],
#    ['YhdWgI7F9GE', 'en'],
#    ['alm97sb_H-A', 'en-ehkg1hFWq8A'],
#    ['KT1R2FwJLrw', 'en-uYU-mmqFLq8'],
#    ['XI4JzdPpL4I', 'en'],
#    ['bsSYd-qUCpA', 'en-uYU-mmqFLq8'],
#    ['OWGgbQpgfgM', 'en'],
#    ['ZZBbecOOLc4', 'en'],
#    ['4iFrp9kM50s', 'en'],
#    ['nxfIYC_Pses', 'en'],
#    ['kvP_AAooNLc', 'en-US-Azf5Kyti3dw'],
#    ['yfJunWuQZKA', 'en'],
#    ['E0Ia89c3VUY', 'en-ehkg1hFWq8A'],
#    ['eXYsQLWSl5Q', 'en-nP7-2PuUl7o'],
#    ['nj6wYxVTZXE', 'en-GB'],
#    ['m-jy9ewfxO4', 'en'],
#    ['eoeLn8SyDW8', 'en'],
#    ['fAKJHEZomGM', 'en'],
#    ['kJRZOcNt7Sc', 'en'],
#    ['hwmFXxnEznY', 'en'],
#    ['TY1KTsaUWK8', 'en-ehkg1hFWq8A'],
#    ['2qzaalmyR4M', 'en-US-xWIRW7eF-uQ'],
#    ['UuJnw29zE98', 'en-US'],
#    ['aVL7dfo33fQ', 'en'],
#    ['inrWImUXTno', 'en'],
#    ['AkJJPmNxJ08', 'en'],
#    ['Rl5lXaM9LVM', 'en'],
#    ['FMmHo5m9V9I', 'en'],
#    ['CqYOyVG8mvE', 'en'],
#    ['Clk2luhI0Pw', 'en'],
#    ['GMaj935wrzk', 'en-uYU-mmqFLq8'],
#    ['sFdyL-2OQxk', 'en-eEY6OEpapPo'],
#    ['QKFekO92gKA', 'en'],
#    ['5BOB-Itl3x4', 'en'],
#    ['G9RC-tWm2CU', 'en'],
#    ['q-3kM-b04So', 'en'],
#    ['NHtJ0xWXYOA', 'en-GB'],
#    ['sB4cwpua0yU', 'en'],
#    ['A1uwfDbafh0', 'en'],
#    ['2Eo2RB2FV0c', 'en'],
#    ['UhQvx425ToE', 'en-uYU-mmqFLq8'],
#    ['mi5Hk2IR2mg', 'en-GB'],
#    ['mYWYQc1KPXE', 'en'],
#    ['GmPNkH4GWrE', 'en'],
#    ['s4FnQQefMXQ', 'en'],
#    ['ZFuzTAG7I_Y', 'en-shJ29GrHSw4'],
#    ['Ovp4XKNounQ', 'en-uYU-mmqFLq8'],
#    ['MZsKDtH-3i0', 'en'],
#    ['FWmg0sBR1tk', 'en-IN'],
#    ['SUB3uGtqegg', 'en-ehkg1hFWq8A'],
#    ['MiAaCJ2AebY', 'en-nP7-2PuUl7o'],
#    ['JSor3D8Lg4o', 'en'],
#    ['MGVsWkS06HQ', 'en'],
#    ['Cp531ishMdU', 'en'],
#    ['rnXL-grmYPI', 'en-uYU-mmqFLq8'],
#    ['e2E4LZQOUu8', 'en-JkeT_87f4cc'],
#    ['WrOJ5xXKFPI', 'en-uYU-mmqFLq8'],
#    ['W-Ib-gxNMlY', 'en-uYU-mmqFLq8'],
#    ['8XXqw1Lqjr8', 'en-GB'],
#    ['WwPVY-k0OqY', 'en'],
#    ['_F-LWB2mWNM', 'en'],
#    ['HfB7R1PUaJ0', 'en-i7LFIGUQP0g'],
#    ['s0Sb61Xy-qw', 'en'],
#    ['qjFwwB6g-rE', 'en'],
#    ['zVLiS2WdL5c', 'en-uYU-mmqFLq8'],
#    ['9dcaJYHIR-o', 'en'],
#    ['L46TliZpnto', 'en-j3PyPqV-e1s'],
#    ['BUkVestPE28', 'en'],
#    ['GUQuSadzjKs', 'en'],
#    ['hINgQHBDeIo', 'en'],
#    ['EpKlwW5TU3Q', 'en-nP7-2PuUl7o'],
#    ['HWDh1Ph1dZs', 'en'],
#    ['0KV2OBuxQRI', 'en-uYU-mmqFLq8'],
#    ['HoiHzn0l-Fs', 'en'],
#    ['dqEh9aBz_zw', 'en'],
#    ['uihhmy08_nk', 'en'],
#    ['iU5sQmuYwrc', 'en'],
#    ['RrIRkYzYvzM', 'en-uYU-mmqFLq8'],
#    ['7kTom5dnPOc', 'en-US'],
#    ['qSqkeam6k54', 'en-uYU-mmqFLq8'],
#    ['DLTlRsWfilc', 'en-4eECQV7hJmo'],
#    ['9W591QK0RFk', 'en'],
#    ['aEQv7J57uwA', 'en-nP7-2PuUl7o'],
#    ['_04MpHAmt-o', 'en-GB'],
#    ['O9a5y7bB2WQ', 'en-US'],
#    ['Bd60S-RSESU', 'en'],
#    ['nDb3q0US04o', 'en-uYU-mmqFLq8'],
#    ['mU5j-WYsqxM', 'en-uYU-mmqFLq8'],
#    ['pl9gOhdR2xA', 'en-E3euOu7LhIg'],
#    ['EjFoYz9gF80', 'en-US'],
#    ['j2QsK6w3ecw', 'en'],
#    ['_4X6qHcgulA', 'en'],
#    ['y4iP-fDEQP8', 'en-US'],
#    ['B4VmfW3stl4', 'en-US'],
#    ['J8Uztn7i4tg', 'en'],
#    ['qjigC3wARyE', 'en'],
#    ['jP_H8mQifN4', 'en-uYU-mmqFLq8'],
#    ['1cdXg5MVRFI', 'en'],
#    ['eKYvBnSePTE', 'en-US'],
#    ['vm2DxT37rRo', 'en-nP7-2PuUl7o'],
#    ['l_eSZzxx4Mo', 'en-eEY6OEpapPo'],
#    ['nZK1NPv6O1Y', 'en'],
#    ['BY8-WCMoK7I', 'en-IE'],
#    ['er1MJOI66bU', 'en'],
#    ['huH_R1QiNw8', 'en'],
#    ['TNk2b9rBqbY', 'en-US'],
#    ['GwPanKIcpoI', 'en-ehkg1hFWq8A'],
#    ['wj9cVeWew3s', 'en-uYU-mmqFLq8'],
#    ['5Rx7s0p4Gzk', 'en-j3PyPqV-e1s'],
#    ['GUoDMM57yv8', 'en'],
#    ['R70SPvTOl-I', 'en'],
#    ['hHWyUf7OCJM', 'en'],
#    ['BeCVmndbY34', 'en-US'],
#    ['8jh5CN7jYpE', 'en'],
#    ['MehUxxO7xYs', 'en'],
#    ['kC-0iaD2Y-4', 'en-uYU-mmqFLq8'],
#    ['XLCTSh2HUNo', 'en-uYU-mmqFLq8'],
#    ['ueDkvTHfG9M', 'en'],
#    ['R6yvZmRtMz4', 'en-uYU-mmqFLq8'],
#    ['WgvA0D8S-88', 'en'],
#    ['salsmH0L_5Q', 'en-uYU-mmqFLq8'],
#    ['EuCBFad77Bo', 'en'],
#    ['qqAj6dAId2w', 'en'],
#    ['83jJln4McQI', 'en'],
#    ['-jqjQXqyrUA', 'en-uYU-mmqFLq8'],
#    ['T6gp4A9ZsYw', 'en'],
#    ['NdVtEEdsYlQ', 'en-imRckOgFRag'],
#    ['wwj6g8vO-3k', 'en'],
#    ['X3hk57smkvg', 'en-UUEcy1ExmXU'],
#    ['Q0cejrXAuyQ', 'en-uYU-mmqFLq8'],
#    ['jbqxm8oKPhI', 'en'],
#    ['gZZT_Ye-jIY', 'en'],
#    ['qVcuy9TNUbs', 'en'],
#    ['X4fxBxWdB7w', 'en'],
#    ['NJaX92SODAo', 'en'],
#    ['A1WnBmrpCAo', 'en'],
#    ['ZnKm5fKSCZI', 'en'],
#    ['RLJYLFAjAz0', 'en'],
#    ['hAKyxMzU-EE', 'en-vlW2OHFw3ww'],
#    ['GEXeZPAHGvA', 'en'],
#    ['qzvE91522GM', 'en-uYU-mmqFLq8'],
#    ['T1ReiwLWVn8', 'en'],
#    ['0dvvcGi08iA', 'en-qlPKC2UN_YU'],
#    ['6UZdSlomha4', 'en'],
#    ['cMig7hAuuwE', 'en-uYU-mmqFLq8'],
#    ['tmENfMSOUW4', 'en'],
#    ['ODGQvPwkMcw', 'en'],
#    ['RVf9ybMvKBE', 'en'],
#    ['9TaMJdqoDhk', 'en-US'],
#    ['MHolOL66Br0', 'en'],
#    ['nzGfogQqmyE', 'en'],
#    ['hTt_exrAqkE', 'en-uYU-mmqFLq8'],
#    ['N4LzGXpA3Dg', 'en-GB'],
#    ['XCKDmkiguDs', 'en'],
#    ['RGmWLiXNARU', 'en'],
#    ['8IntjyW9qlc', 'en-uYU-mmqFLq8'],
#    ['1ZqaAAgcco8', 'en-US'],
#    ['67BirG7k9xQ', 'en-GB'],
#    ['7Pr7DmMxjXk', 'en-JkeT_87f4cc'],
#    ['jKg8Kalmwhk', 'en'],
#    ['pDxCVOP_HQw', 'en-nP7-2PuUl7o'],
#    ['pp6MUlSFRX4', 'en'],
#    ['SLVscxUBwOY', 'en-F_g_ck8kK7s'],
#    ['63OE15XuTIk', 'en'],
#    ['DluM9sJCMqg', 'en'],
#    ['-DKVQmPxpeA', 'en'],
#    ['fC1dWtUGdqM', 'en'],
#    ['nhwcLGK2CgQ', 'en-nP7-2PuUl7o'],
#    ['cXEDfhHKEh4', 'en'],
#    ['ry4E-pYG2vg', 'en'],
#    ['tvUxJ8HVUDY', 'en'],
#    ['z-Qxui2m0-c', 'en'],
#    ['iZpf3uqsaDU', 'en'],
#    ['tC1Or7r-mdI', 'en-US'],
#    ['jyhzA0Fe8v4', 'en'],
#    ['LcUkHDdc-Hc', 'en'],
#    ['d2pCfForYqA', 'en-uYU-mmqFLq8'],
#    ['rLBWIspIO5I', 'en-US'],
#    ['jKrt189IeKA', 'en'],
#    ['prYZZI6Obpk', 'en-nP7-2PuUl7o'],
#    ['irKmSJGnI-M', 'en-uYU-mmqFLq8'],
#    ['Kz9J2KUyl2o', 'en'],
#    ['MWE7Uu0gAmQ', 'en-GB'],
#    ['wA-mrxHPJV0', 'en'],
#    ['Ne_kv9NW2b0', 'en'],
#    ['4UlFfYDWvrU', 'en-GB'],
#    ['2z5Yl8n6wow', 'en-uYU-mmqFLq8'],
#    ['yQjPT4MZOhs', 'en'],
#    ['Cx_aISz47Ec', 'en'],
#    ['AtX0rW8BTQU', 'en'],
#    ['SdNEq9i0xE8', 'en'],
#    ['Qoa2IbVDxio', 'en'],
#    ['oi8NytpxWBA', 'en'],
#    ['v-7u9b06d2k', 'en'],
#    ['3nRWbnE0YZE', 'en'],
#    ['HPsRWq4imHk', 'en'],
#    ['XZX-juSCcys', 'en'],
#    ['h94y-3is7Jw', 'en-US'],
#    ['yjrWOR0B6N4', 'en-nP7-2PuUl7o'],
#    ['MpQg91LTUAM', 'en-nP7-2PuUl7o'],
#    ['xAxozsYZQXY', 'en-uYU-mmqFLq8'],
#    ['a8lWoXReYiQ', 'en-uYU-mmqFLq8'],
#    ['b4ZWa5InxYc', 'en-uYU-mmqFLq8'],
#    ['AsaqGs692BU', 'en'],
#    ['6-6ZGZbFHDw', 'en'],
#    ['DFr4AmnxIXw', 'en'],
#    ['DgBPkpmICdY', 'en'],
#    ['Kkc4La-Oig4', 'en'],
#    ['XEfuc5VQjv4', 'en-uYU-mmqFLq8'],
#    ['JywhwtNGwwk', 'en'],
#    ['Sq6MZsvNKTY', 'en-ehkg1hFWq8A'],
#    ['4snruzJZ54M', 'en'],
#    ['NV8JNlyMDTg', 'en'],
#    ['c2R9WM-Pc_E', 'en'],
#    ['-lv9ot75TIk', 'en-US'],
#    ['31l_hlny6_E', 'en-uYU-mmqFLq8'],
#    ['bSrwWmpHqEM', 'en-nP7-2PuUl7o']],
#   'batchIdx': 3},
#  {'videoIds': [['30UdRcUp2Tk', 'en'],
#    ['7ZPAPkIMmW8', 'en-uYU-mmqFLq8'],
#    ['qkVuDAI2Ow4', 'en'],
#    ['a6mlfxkKAxg', 'en'],
#    ['dBPuklIvLl8', 'en'],
#    ['QJtgk_lrzUU', 'en'],
#    ['Sft9VUtzF4Q', 'en'],
#    ['rDhVHB5w_DE', 'en-nP7-2PuUl7o'],
#    ['IQgC2V_vPwk', 'en'],
#    ['FNLNswvavvs', 'en'],
#    ['eGTiA4FbnVo', 'en-uYU-mmqFLq8'],
#    ['onmmKGgqefg', 'en'],
#    ['Ixci9EVGDXI', 'en-RTbB2cpHawQ'],
#    ['eRtJLg9UjoA', 'en'],
#    ['Ylmil53-XD8', 'en-jCLboYI24Wg'],
#    ['0c-h-MVsJoc', 'en-US'],
#    ['UzYbyyO4wEo', 'en-nP7-2PuUl7o'],
#    ['oIIyJVB33uI', 'en-US'],
#    ['CkeNG7ZDeNc', 'en'],
#    ['vIh6x9U0hRY', 'en'],
#    ['hZNyX9D2pC4', 'en-nP7-2PuUl7o'],
#    ['r5n43QOShno', 'en-rYfk1HGjE0s'],
#    ['jcpBWLc6RO0', 'en-uYU-mmqFLq8'],
#    ['rLv2HA42044', 'en'],
#    ['UBfYHXRGriY', 'en'],
#    ['jZ-ac1FsuH0', 'en-uYU-mmqFLq8'],
#    ['3QIL0fo23IE', 'en-US'],
#    ['tzL_2-XI0dc', 'en'],
#    ['JyQbugIOtDM', 'en-US'],
#    ['WltHrN34_IU', 'en-uYU-mmqFLq8'],
#    ['aPOUMQP_xrM', 'en'],
#    ['efkzRZcGdZE', 'en-GB'],
#    ['A3OIbrKPdJw', 'en'],
#    ['IXVL5leWp-A', 'en'],
#    ['nNxr0B3iyhA', 'en'],
#    ['DjVzsYp___4', 'en'],
#    ['KK_BjYYtXpw', 'en'],
#    ['xnr1XLRyyV0', 'en'],
#    ['h6m9hCEDi_g', 'en-JkeT_87f4cc'],
#    ['1gB4nS376h8', 'en'],
#    ['6D8esMZfFEg', 'en'],
#    ['qiDWf3bnRPY', 'en-nP7-2PuUl7o'],
#    ['Jd1-SIWFDdc', 'en'],
#    ['wSMzKafmr5g', 'en'],
#    ['Md5hbuPuhE8', 'en'],
#    ['ZFqQUrb7yX0', 'en'],
#    ['YMLCCFDZf60', 'en-uYU-mmqFLq8'],
#    ['wbqK-vvWr7A', 'en'],
#    ['OIe26nYgrxc', 'en'],
#    ['ha8gML3QN5o', 'en'],
#    ['R4k3Pisa8rA', 'en'],
#    ['K8bLBF05vlM', 'en-uYU-mmqFLq8'],
#    ['SPCDd3CxWmI', 'en'],
#    ['aDTf6FE1TC8', 'en'],
#    ['TdfZvyu3E40', 'en-US'],
#    ['AOAwitlZ_F8', 'en'],
#    ['J-DBa7dte-I', 'en'],
#    ['Jbw4RU51NQE', 'en'],
#    ['sLtvHDXQ4SE', 'en'],
#    ['3_LowXkn2RU', 'en'],
#    ['wagMqhC2QuQ', 'en'],
#    ['FcUzenfhuBs', 'en'],
#    ['rqRSjA-SC2U', 'en-eEY6OEpapPo'],
#    ['70kOAzvOqDw', 'en-nP7-2PuUl7o'],
#    ['YqSMWWXKP3U', 'en'],
#    ['GkbTZgJsxuk', 'en-US'],
#    ['ivvhNpq751I', 'en'],
#    ['IWe9zAi_8bc', 'en'],
#    ['yA4zkkXnGIQ', 'en'],
#    ['DOkvs_JvjEA', 'en-GB'],
#    ['ykdNG26JXZI', 'en-nS86xo7i_ao'],
#    ['UHPkrLSCac0', 'en'],
#    ['ElXUY0ygvoA', 'en-uYU-mmqFLq8'],
#    ['sMxkl6bXBhQ', 'en-uYU-mmqFLq8'],
#    ['vSHQndU6vPw', 'en-nP7-2PuUl7o'],
#    ['hJQvDjYlUS8', 'en-GB'],
#    ['3qrtQCM_J-o', 'en-fAPXfJMmqgY'],
#    ['dJGaHlk-uXY', 'en-US'],
#    ['YCVrFeDdftE', 'en'],
#    ['HtSOTLldSWc', 'en-uYU-mmqFLq8'],
#    ['j71Ot3uWljs', 'en'],
#    ['pQ-RCDNkIWQ', 'en'],
#    ['Ets-aMFFE8M', 'en-US'],
#    ['BhDLEk2VguY', 'en'],
#    ['nDzqQTBHh5c', 'en-uYU-mmqFLq8'],
#    ['lLleICb7a_g', 'en'],
#    ['Lm4-nYpcYMQ', 'en-uYU-mmqFLq8'],
#    ['26s9VDOMOCE', 'en-uYU-mmqFLq8'],
#    ['nEasBf9eXd4', 'en-TaFgHjZLtPo'],
#    ['oomuREEKLg8', 'en-nP7-2PuUl7o'],
#    ['ISCrdaGmrLs', 'en'],
#    ['Rs9hciRLvDM', 'en'],
#    ['d28YChZvTxY', 'en-US'],
#    ['FTt8ibcrYeY', 'en'],
#    ['ab8KOVlAxqo', 'en-GB'],
#    ['RP8B-n6mQgM', 'en-nP7-2PuUl7o'],
#    ['hA1-zBOlM1U', 'en-GB'],
#    ['xQFYu0fgvio', 'en-uYU-mmqFLq8'],
#    ['EYARGrLhhXA', 'en-8P2-b3K5E0w'],
#    ['5EBDGUq6Bhk', 'en-uYU-mmqFLq8'],
#    ['3RC1yMsy3k8', 'en-GB'],
#    ['zxMBg7hFAmM', 'en'],
#    ['YJwJdd5fYik', 'en'],
#    ['iOMR_GXqYy4', 'en-uYU-mmqFLq8'],
#    ['H37QHY7131E', 'en'],
#    ['oq4wTjC33ZU', 'en-6UJrWS5jR_I'],
#    ['60aajlM7bME', 'en'],
#    ['k5bE3GPk990', 'en'],
#    ['KIhQiNhDVLw', 'en-k_qSPpSAwHU'],
#    ['ESBXt-SBTdk', 'en-uYU-mmqFLq8'],
#    ['1FH00VZDvTM', 'en'],
#    ['aKpFhG4dqMM', 'en-nP7-2PuUl7o'],
#    ['a8CDY9y1ZHY', 'en-uYU-mmqFLq8'],
#    ['FfY3dgEhVuU', 'en'],
#    ['73vV8VDSQ9o', 'en'],
#    ['F5rVvaLqgY4', 'en-GB'],
#    ['swFacFDnct0', 'en-Hn2lXfh-6Tw'],
#    ['2wZwEQQyQU4', 'en'],
#    ['IJqgzVG41aA', 'en'],
#    ['FvUdVYEhvHo', 'en'],
#    ['YUMZxuRr9GI', 'en-US'],
#    ['NIMda0JpYEM', 'en'],
#    ['BVt_UEhxHBw', 'en'],
#    ['ulP-sK3xpCE', 'en'],
#    ['xjC9q6er9fk', 'en'],
#    ['cIkIIxSZ724', 'en-eEY6OEpapPo'],
#    ['bjwofQt8Wp4', 'en'],
#    ['FHx280ek12k', 'en-IN'],
#    ['cGZ4URxX7Y8', 'en-US'],
#    ['zfbkaIJo9Co', 'en-nP7-2PuUl7o'],
#    ['GgHenmnMjjY', 'en-ehkg1hFWq8A'],
#    ['Qzhz1BIjez8', 'en-i1P-7HrjLPE'],
#    ['5gWyydFp4mw', 'en'],
#    ['sq3qDqT_UqQ', 'en'],
#    ['xJL-eX765k0', 'en'],
#    ['4MhgNtmvic0', 'en'],
#    ['OVqZ5aHFfEE', 'en-US'],
#    ['8Q9awcCJ9Ds', 'en-US'],
#    ['jhjUM4W1iNg', 'en'],
#    ['zgc5A4mePn8', 'en'],
#    ['3edUWErNnIk', 'en-nP7-2PuUl7o'],
#    ['9MbJr4o4g20', 'en'],
#    ['kV0hSFGB0sM', 'en-UHvnJhTASmI'],
#    ['thcykFxH_F4', 'en'],
#    ['mczrzJuzmc8', 'en-ehkg1hFWq8A'],
#    ['Vedw1SBtr6g', 'en'],
#    ['mE4CAXzz1_Y', 'en'],
#    ['uUR15v9n3EI', 'en'],
#    ['cDJAGdPIySY', 'en-US'],
#    ['FXzyFLWaQII', 'en-IN'],
#    ['nWRZa1Q0NYA', 'en'],
#    ['xkWhTiA58og', 'en-xYXo8e6Ty5w'],
#    ['wy6oo3zvzpU', 'en'],
#    ['AlBNTrlCUI4', 'en'],
#    ['KIIj3Fcum2I', 'en'],
#    ['f1tnt-TzQdQ', 'en-nP7-2PuUl7o'],
#    ['ndTjIXzdVDk', 'en'],
#    ['emZcSvFdRhY', 'en'],
#    ['tul9Q7xNC2w', 'en'],
#    ['qbUh-Bj9DTo', 'en-uYU-mmqFLq8'],
#    ['6JeyUDQf7cA', 'en'],
#    ['OvJbXTK09Pw', 'en'],
#    ['omfTPWurDMQ', 'en-nP7-2PuUl7o'],
#    ['SLeanBHOIo0', 'en-uYU-mmqFLq8'],
#    ['k7ZKACG6eOs', 'en'],
#    ['wd0Omju5RNM', 'en'],
#    ['3Ef6i1v4Rhc', 'en'],
#    ['qadxKzD66Z0', 'en-uYU-mmqFLq8'],
#    ['PfQBd4l_jJY', 'en'],
#    ['yUumYzDtFI4', 'en'],
#    ['UMNmbs5IXYw', 'en'],
#    ['wG5M7sz9XKA', 'en'],
#    ['jg9UbgvnLuo', 'en'],
#    ['smRiQjPeuJ8', 'en-uYU-mmqFLq8'],
#    ['X34eJ4OQIbw', 'en'],
#    ['LcDMN_Ktg4M', 'en-eOZQfopbfmY'],
#    ['VUX_W7o6d0Q', 'en-JkeT_87f4cc'],
#    ['p1BDKxTVQR0', 'en'],
#    ['OHNqbNOthiA', 'en'],
#    ['_vLVv1HX6pA', 'en'],
#    ['RpCxaCzIV2c', 'en'],
#    ['-ZXUOAe61mo', 'en-uYU-mmqFLq8'],
#    ['NXDkEwMJuEw', 'en'],
#    ['6oRWhXBUl28', 'en'],
#    ['8kfU4IPPwrs', 'en-uYU-mmqFLq8'],
#    ['1NYFIpEj7DQ', 'en'],
#    ['EzxzlO1BLCU', 'en'],
#    ['4Re99tVlW0Y', 'en'],
#    ['GQNbCFYkCbI', 'en'],
#    ['NyKnnBmK0vA', 'en'],
#    ['G4R-UVwUltI', 'en'],
#    ['pLE1HbNjzlw', 'en'],
#    ['vqYQBNZINP8', 'en-uYU-mmqFLq8'],
#    ['aW1lDXmi8Nc', 'en-nP7-2PuUl7o'],
#    ['wbMk5r5-wXc', 'en-uYU-mmqFLq8'],
#    ['v4ox3Hq7pBk', 'en'],
#    ['Dn6yrKvRQww', 'en-uYU-mmqFLq8'],
#    ['w8EUVnvE07Y', 'en-uYU-mmqFLq8'],
#    ['mYs062qQneg', 'en'],
#    ['6JVhJD0tdP0', 'en-BBjtdBtULUo'],
#    ['hOBz8r7tDbY', 'en-uYU-mmqFLq8'],
#    ['wTW0a6MUCds', 'en'],
#    ['ZlKMikBh9Vk', 'en-US'],
#    ['9uYMEMMlP8E', 'en-uYU-mmqFLq8'],
#    ['iMQpR8WPjYk', 'en'],
#    ['Y6cd8AoKa8E', 'en'],
#    ['UfxP8H6rz3w', 'en-US'],
#    ['Lva4R0HxbPM', 'en'],
#    ['bAFsy3I9Hp4', 'en'],
#    ['SJfTTeLIyT0', 'en-uYU-mmqFLq8'],
#    ['8SHmlMSlxCs', 'en'],
#    ['JJ-yPL3Q44U', 'en'],
#    ['40SCzXoZemU', 'en'],
#    ['5z85V34vZJU', 'en'],
#    ['tl6BkTNP_5U', 'en'],
#    ['CPb81NeyYKw', 'en'],
#    ['LGy3LNfRkZc', 'en'],
#    ['QhO19F3lK_I', 'en'],
#    ['Lry2P1FzDMc', 'en-US'],
#    ['GZWHmnQdt4k', 'en-US'],
#    ['JK5PBwMVELA', 'en'],
#    ['mlKdydGaFf8', 'en'],
#    ['tAYJpchIRDA', 'en'],
#    ['5Rx0c8uNoaM', 'en'],
#    ['QsJ9SRNL8uY', 'en'],
#    ['OpVdqgprIJM', 'en-JkeT_87f4cc'],
#    ['liKA5yGJido', 'en'],
#    ['P5Bu_yGtjq0', 'en'],
#    ['wp0XHoJqi_o', 'en'],
#    ['Idt_iwxLF5A', 'en-nP7-2PuUl7o'],
#    ['_G0fVkgbHsk', 'en'],
#    ['FeTw1RcW5Dc', 'en-GB'],
#    ['m2yn83V6myI', 'en'],
#    ['Vkccs_Sblog', 'en'],
#    ['NKO3dfPCVsk', 'en'],
#    ['tgrjlHyZ59c', 'en-1oAFzPNiuC0'],
#    ['hBh6byHxlqA', 'en'],
#    ['jtw2U2TaN48', 'en-uYU-mmqFLq8'],
#    ['f2Hg5icIluI', 'en'],
#    ['nh4QySF-FgA', 'en'],
#    ['KYCNyqpg9dc', 'en-eEY6OEpapPo'],
#    ['LhHctqyQJbE', 'en-US'],
#    ['-M08g1Lguns', 'en-nP7-2PuUl7o'],
#    ['TPK7e1Ao8E8', 'en'],
#    ['cpCn6CA6tjQ', 'en'],
#    ['lavTjJiKwJk', 'en-US'],
#    ['RGpYjHGB8Ow', 'en'],
#    ['UOC3cBjsj40', 'en'],
#    ['LOyNTQPpytM', 'en'],
#    ['J7FIMsJWoGc', 'en']],
#   'batchIdx': 4}]

# %%
with open("logs/data/download/8M_en_text_only/shuffled_batches.jsonl", "w") as f:
    for batch in shuffled_batches:
        f.write(json.dumps(batch) + "\n")

# %%
with open("logs/data/download/8M_en_text_only/subset_ids.txt", "w") as f:
    for video_id in only_en_man_auto_text_df["id"].values.tolist():
        f.write(video_id + "\n")

# %% [markdown]
# ## Data Statistics

# %%
main_df_dedup["man_cap_langs_2"] = main_df_dedup["manual_caption_languages"]
main_df_dedup["std_man_cap_langs"] = main_df_dedup["manual_caption_languages"]
main_df_dedup["std_man_cap_langs"] = main_df_dedup["std_man_cap_langs"].apply(standardize_dialects)
# Out:
# /var/folders/kx/lt3wgk4d3ldg6yfn3g233bj40000gp/T/ipykernel_13939/1236306115.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_df_dedup["man_cap_langs_2"] = main_df_dedup["manual_caption_languages"]
# /var/folders/kx/lt3wgk4d3ldg6yfn3g233bj40000gp/T/ipykernel_13939/1236306115.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_df_dedup["std_man_cap_langs"] = main_df_dedup["manual_caption_languages"]
# /var/folders/kx/lt3wgk4d3ldg6yfn3g233bj40000gp/T/ipykernel_13939/1236306115.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_df_dedup["std_man_cap_langs"] = main_df_dedup["std_man_cap_langs"].apply(standardize_dialects)

# %% [markdown]
# ### en-only-v2

# %%
condition = (
    main_df_dedup["man_cap_langs_2"]
    .str.split(",")
    .apply(lambda lst: set(lst) == {"en"})
) & (main_df_dedup["automatic_caption_orig_language"] == "en")
df_2 = main_df_dedup[condition]

# %%
df_2.shape[0]
# Out:
# 9907059

# %%
df_2["duration"].sum() / (60 * 60)
# Out:
# 1567039.9983333333

# %%
condition = (
    main_df_dedup["std_man_cap_langs"]
    .str.split(",")
    .apply(lambda lst: set(lst) == {"en"})
) & (main_df_dedup["automatic_caption_orig_language"] == "en")
df_3 = main_df_dedup[condition]

# %%
df_3.shape[0]
# Out:
# 18761823

# %%
df_3["duration"].sum() / (60 * 60)
# Out:
# 3369060.4058333333

# %%
with open("logs/data/download/2M_en/2M_download_ids.txt", "r") as f:
    subsampled_ids_2M = [line.strip().split("\t")[0] for line in f]
with open("logs/data/download/4M_en/subsampled_ids.txt", "r") as f:
    subsampled_ids_4M = [line.strip() for line in f]

with open("logs/data/download/6M_en/subsampled_ids.txt", "r") as f:
    subsampled_ids_6M = [line.strip() for line in f]
    
with open("logs/data/download/8M_en/shuffled_batches.jsonl", "r") as f:
    shuffled_batches_8M_10K = [json.loads(line.strip())["videoIds"] for line in f][:10000]
subsampled_ids_8M_10K = [tpl[0] for batch in shuffled_batches_8M_10K for tpl in batch]

# %%
print(f"{len(subsampled_ids_2M)=}, {len(subsampled_ids_4M)=}, {len(subsampled_ids_6M)=}, {len(subsampled_ids_8M_10K)=}")
# Out:
# len(subsampled_ids_2M)=2448500, len(subsampled_ids_4M)=4000000, len(subsampled_ids_6M)=6000000, len(subsampled_ids_8M_10K)=2500000

# %%
df_2M_mod = df_2[df_2["id"].isin(subsampled_ids_2M)]
print(f"{df_2M_mod.shape[0]=}")
df_4M_mod = df_2[df_2["id"].isin(subsampled_ids_4M)]
print(f"{df_4M_mod.shape[0]=}")
df_6M_mod = df_2[df_2["id"].isin(subsampled_ids_6M)]
print(f"{df_6M_mod.shape[0]=}")
df_8M_10K_mod = df_2[df_2["id"].isin(subsampled_ids_8M_10K)]
print(f"{df_8M_10K_mod.shape[0]=}")
# Out:
# df_2_mod.shape[0]=1278530
# df_4M_mod.shape[0]=2116800
# df_6M_mod.shape[0]=1886686
# df_8M_10K_mod.shape[0]=1322858

# %%
with open("logs/data/download/4M_en/4M_trainable_mod.txt", "r") as f:
    trainable_ids_4M = [line.strip() for line in f]
with open("logs/data/download/6M_en/6M_trainable_mod.txt", "r") as f:
    trainable_ids_6M = [line.strip() for line in f]
with open("logs/data/download/8M_en/8M_10K_trainable_mod.txt", "r") as f:
    trainable_ids_8M_10K = [line.strip() for line in f]
with open("logs/data/download/2M_en/2M_trainable_ids.txt", "r") as f:
    trainable_ids_2M = [line.strip() for line in f]
print(f"{len(trainable_ids_4M)=}, {len(trainable_ids_6M)=}, {len(trainable_ids_8M_10K)=}, {len(trainable_ids_2M)=}")
print(f"total length: {len(trainable_ids_4M) + len(trainable_ids_6M) + len(trainable_ids_8M_10K) + len(trainable_ids_2M)}")
# Out:
# len(trainable_ids_4M)=1933350, len(trainable_ids_6M)=1728307, len(trainable_ids_8M_10K)=1208895, len(trainable_ids_2M)=2300152
# total length: 7170704

# %%
temp = df_2[df_2["id"].isin(trainable_ids_2M)]
temp.shape[0]
# Out:
# 1215816

# %%
all_trainable = trainable_ids_4M + trainable_ids_6M + trainable_ids_8M_10K + trainable_ids_2M
all_trainable_df = df_2[df_2["id"].isin(all_trainable)]
print(all_trainable_df.shape[0])
print(all_trainable_df["duration"].sum() / (60 * 60))
# Out:
# 6086368
# 943460.7775

# %%
all_trainable = trainable_ids_4M + trainable_ids_6M + trainable_ids_8M_10K + trainable_ids_2M
all_trainable_df = main_df_dedup[main_df_dedup["id"].isin(all_trainable)]
print(all_trainable_df.shape[0])
print(all_trainable_df["duration"].sum() / (60 * 60))
# Out:
# 7170704
# 1164319.161388889

# %%
len(all_trainable)
# Out:
# 7170704

# %%
print(2300152 + len(trainable_ids_4M) + len(trainable_ids_6M) + len(trainable_ids_8M_10K))
# Out:
# 7170704

# %%
with open("logs/data/download/4M_en/seg_fail_4M.txt", "r") as f:
    seg_fail_4M = [line.strip() for line in f]
with open("logs/data/download/6M_en/seg_fail_6M.txt", "r") as f:
    seg_fail_6M = [line.strip() for line in f]
with open("logs/data/download/8M_en/seg_fail_8M_10K.txt", "r") as f:
    seg_fail_8M_10K = [line.strip() for line in f]

# %%
df_seg_fail_4M_mod = df_2[df_2["id"].isin(seg_fail_4M)]
print(df_seg_fail_4M_mod.shape[0])
df_seg_fail_6M_mod = df_2[df_2["id"].isin(seg_fail_6M)]
print(df_seg_fail_6M_mod.shape[0])
df_seg_fail_8M_10K_mod = df_2[df_2["id"].isin(seg_fail_8M_10K)]
print(df_seg_fail_8M_10K_mod.shape[0])
# Out:
# 55604
# 1210
# 33623

# %%
1933350 + 55604, 1728307 + 1210, 1208895 + 33623
# Out:
# (1988954, 1729517, 1242518)

# %% [markdown]
# ### en-only-v1

# %%
condition = (
    main_df_dedup["std_man_cap_langs"]
    .str.split(",")
    .apply(lambda lst: set(lst) == {"en"})
)
df_3 = main_df_dedup[condition]

# %%
df_3.shape[0]
# Out:
# 27956301

# %%
not_df_3_id = set(main_df_dedup["id"]) - set(df_3["id"])
len(not_df_3_id)
# Out:
# 32141850

# %%
not_df_3 = main_df_dedup[main_df_dedup["id"].isin(not_df_3_id)]
not_df_3.shape[0]
# Out:
# 32141850

# %%
not_df_3.columns
# Out:
# Index(['id', 'title', 'duration', 'view_count', 'categories', 'comment_count',
#        'like_count', 'channel', 'channel_id', 'channel_follower_count',
#        'age_limit', 'upload_date', 'is_live', 'was_live', 'format',
#        'format_id', 'language', 'filesize', 'stretched_ratio', 'width',
#        'height', 'fps', 'dynamic_range', 'aspect_ratio', 'abr', 'vbr',
#        'vcodec', 'asr', 'audio_channels', 'chapters',
#        'manual_caption_languages', 'automatic_caption_orig_language',
#        'location', 'license', 'man_cap_langs_2', 'std_man_cap_langs'],
#       dtype='object')

# %%
df_4 = not_df_3[not_df_3["std_man_cap_langs"].str.contains("en")]
df_4.shape[0]
# Out:
# 9991767

# %%
df_4["language"] = df_4["language"].fillna("")
df_4["std_lang"] = df_4["language"]
df_4["std_lang"] = df_4["std_lang"].apply(standardize_dialects)
df_5 = df_4[df_4["std_lang"] == "en"]
df_5.shape[0]
# Out:
# /var/folders/kx/lt3wgk4d3ldg6yfn3g233bj40000gp/T/ipykernel_50494/3292825017.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4["language"] = df_4["language"].fillna("")
# /var/folders/kx/lt3wgk4d3ldg6yfn3g233bj40000gp/T/ipykernel_50494/3292825017.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4["std_lang"] = df_4["language"]
# /var/folders/kx/lt3wgk4d3ldg6yfn3g233bj40000gp/T/ipykernel_50494/3292825017.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4["std_lang"] = df_4["std_lang"].apply(standardize_dialects)
# 1933919

# %%
approx_en = set(df_3["id"].values.tolist() + df_5["id"].values.tolist())
len(approx_en)
# Out:
# 29890220

# %%
with open("data/metadata/approx_en_relaxed.txt", "r") as f:
    temp = [line.strip() for line in f]
set(temp) - set(approx_en)
# Out:
# set()

# %%
approx_en_dur = main_df_dedup[main_df_dedup["id"].isin(approx_en)]["duration"].sum() / (60 * 60)

# %%
approx_en_dur
# Out:
# 5612925.527222223

# %%
not_df_4_ids = set(not_df_3["id"]) - set(df_4["id"])
len(not_df_4_ids)
# Out:
# 22150083

# %%
not_df_5_ids = set(df_4["id"]) - set(df_5["id"])
len(not_df_5_ids)
# Out:
# 8057848

# %%
approx_non_en = list(not_df_4_ids) + list(not_df_5_ids)
len(approx_non_en)
# Out:
# 30207931

# %%
approx_non_en_df = main_df_dedup[main_df_dedup["id"].isin(approx_non_en)]

# %%
approx_non_en_df.columns
# Out:
# Index(['id', 'title', 'duration', 'view_count', 'categories', 'comment_count',
#        'like_count', 'channel', 'channel_id', 'channel_follower_count',
#        'age_limit', 'upload_date', 'is_live', 'was_live', 'format',
#        'format_id', 'language', 'filesize', 'stretched_ratio', 'width',
#        'height', 'fps', 'dynamic_range', 'aspect_ratio', 'abr', 'vbr',
#        'vcodec', 'asr', 'audio_channels', 'chapters',
#        'manual_caption_languages', 'automatic_caption_orig_language',
#        'location', 'license', 'man_cap_langs_2', 'std_man_cap_langs'],
#       dtype='object')

# %%
approx_non_en_df[['manual_caption_languages', 'automatic_caption_orig_language', 'language']].isnull().mean() * 100
# Out:
# manual_caption_languages            0.000000
# automatic_caption_orig_language    39.167300
# language                           50.327495
# dtype: float64

# %%
view_lang_cols(approx_non_en_df, 20)
# Out:
#              id                                              title language  \
# 5   cNPxiPUdyvA                         (Примьера дораммы 2021!!!)     None
# 6   2XitiLKk6rM                                 Анонимки в тик ток       ru
# 7   IPxXLQpOJRU                                      Marisa Marisa     None
# 8   ug5TkquQEHo                                      Marisa marisa     None
# 9   Ar-XwEnnFPY              Formation des Classe D | Serveur UPRP       fr
# 11  y9v4phX48UA  عودة ملوك العواصف الى سيرفر الجامعة/لعبة الامب...     None
# 12  UMvzlMuBnt0            Sabuwar wakar sadiq saleh darasul Awwal     None
# 13  hWQZq0wHIwQ                           rimne - First Color / MV     None
# 14  IjhDUC8nbXk                   A VONTADE DE DEUS- Regis Moreira       pt
# 15  kKTrQhL6Zq8                   #short,आ चले ,हिंदी कविता ,#feed     None
# 17  LTSQG7x7e84                  רוקט ליג פרק 2 גולים מטורפים!!!!!     None
# 18  kwxzIYqbQ-I  פרק 1 NBA LIVE מצחיק רצח!! קצת חיקויים באמצע ש...     None
# 19  Euuuiz_rbbY  y tu como eres jugando duelo de escuadras? -yo...       es
# 20  6mgKiScaTJc                       Ievan Polkka free fire - Dam     None
# 21  4w-OpSyV5dw            Sangat Sedap | Semua Pasti Menyukainya!     None
# 23  JiHuFJ9RoHM  DEI UMA PASSADA NO CANADÁ ANTES DE IR PARA O B...       pt
# 24  YhPHqdGcCQ4  MINHA COLEÇÃO INTEIRA DA SUPERESTRELA DA NBA, ...       pt
# 25  zwPpeXqHsZs  JOGUEI O NBA 2K23 (PS4) CURRENT GEN PELA PRIME...     None
# 26  VdlUZgEL1Qs  JOGUEI BASQUETE COM OS GRINGOS EM UMA QUADRA A...       pt
# 27  Wn-MEviNFjg  ЭЛЕКТРОСКУТЕР для детей и взрослых - SmartOne ...       ru
#
#    manual_caption_languages automatic_caption_orig_language  man_cap_langs_2  \
# 5                        sv                              sv               sv
# 6                        sv                              ru               sv
# 7                        it                              it               it
# 8                        it                              it               it
# 9                     fr-FR                              fr            fr-FR
# 11                       ar                              ar               ar
# 12                       ha                              ha               ha
# 13                    en,ja                         unknown            en,ja
# 14                       pt                              pt               pt
# 15                       hi                              hi               hi
# 17                       iw                              iw               iw
# 18                       iw                              iw               iw
# 19                       es                              es               es
# 20                       es                              es               es
# 21          en,live_chat,ms                         unknown  en,live_chat,ms
# 23                    en,pt                              pt            en,pt
# 24                    en,pt                              pt            en,pt
# 25                    en,pt                         unknown            en,pt
# 26                    en,pt                              pt            en,pt
# 27                       ru                              ru               ru
#
#    std_man_cap_langs
# 5                 sv
# 6                 sv
# 7                 it
# 8                 it
# 9                 fr
# 11                ar
# 12                ha
# 13             en,ja
# 14                pt
# 15                hi
# 17                iw
# 18                iw
# 19                es
# 20                es
# 21   en,live_chat,ms
# 23             en,pt
# 24             en,pt
# 25             en,pt
# 26             en,pt
# 27                ru

# %%
approx_non_en_df['man_cap_langs_count'] = approx_non_en_df['manual_caption_languages'].apply(lambda x: len(x.split(',')))

# Get the distribution of rows with 1 language, 2 languages, etc.
language_count_distribution = approx_non_en_df['man_cap_langs_count'].value_counts().sort_index()

# %%
language_count_distribution[:10]
# Out:
# man_cap_langs_count
# 1     20481762
# 2      4367971
# 3      1053415
# 4       502791
# 5       554458
# 6       394308
# 7       318037
# 8       251343
# 9       227189
# 10      205953
# Name: count, dtype: int64

# %%
approx_non_en_1_lang_df = approx_non_en_df[approx_non_en_df["man_cap_langs_count"] == 1]

# %%
view_lang_cols(approx_non_en_1_lang_df, 20)
# Out:
#              id                                              title language  \
# 5   cNPxiPUdyvA                         (Примьера дораммы 2021!!!)     None
# 6   2XitiLKk6rM                                 Анонимки в тик ток       ru
# 7   IPxXLQpOJRU                                      Marisa Marisa     None
# 8   ug5TkquQEHo                                      Marisa marisa     None
# 9   Ar-XwEnnFPY              Formation des Classe D | Serveur UPRP       fr
# 11  y9v4phX48UA  عودة ملوك العواصف الى سيرفر الجامعة/لعبة الامب...     None
# 12  UMvzlMuBnt0            Sabuwar wakar sadiq saleh darasul Awwal     None
# 14  IjhDUC8nbXk                   A VONTADE DE DEUS- Regis Moreira       pt
# 15  kKTrQhL6Zq8                   #short,आ चले ,हिंदी कविता ,#feed     None
# 17  LTSQG7x7e84                  רוקט ליג פרק 2 גולים מטורפים!!!!!     None
# 18  kwxzIYqbQ-I  פרק 1 NBA LIVE מצחיק רצח!! קצת חיקויים באמצע ש...     None
# 19  Euuuiz_rbbY  y tu como eres jugando duelo de escuadras? -yo...       es
# 20  6mgKiScaTJc                       Ievan Polkka free fire - Dam     None
# 27  Wn-MEviNFjg  ЭЛЕКТРОСКУТЕР для детей и взрослых - SmartOne ...       ru
# 28  owrmM2SX0lM  Моноколесо: ПОКАТУШКИ и ТРЮКИ на моноколесах i...     None
# 29  d45kReHbfA8  Электросамокат Kugoo S3 PRO (КУГО С 3 ПРО): НО...     None
# 30  YhJ-dUsU0Oo  Электросамокат с ГИДРОИЗОЛЯЦИЕЙ Zaxboard (Закс...     None
# 31  LmLTxJTb3SY  Тест-драйв ЭЛЕКТРОСАМОКАТА KUGOO || Достоприме...     None
# 37  ucd2rlakSWs                          video 2013 11 16 22 13 50     None
# 51  Iy-BJ_28EGk  PINAKAMATANGKAD NA TAO SA PILIPINAS - William ...     None
#
#    manual_caption_languages automatic_caption_orig_language man_cap_langs_2  \
# 5                        sv                              sv              sv
# 6                        sv                              ru              sv
# 7                        it                              it              it
# 8                        it                              it              it
# 9                     fr-FR                              fr           fr-FR
# 11                       ar                              ar              ar
# 12                       ha                              ha              ha
# 14                       pt                              pt              pt
# 15                       hi                              hi              hi
# 17                       iw                              iw              iw
# 18                       iw                              iw              iw
# 19                       es                              es              es
# 20                       es                              es              es
# 27                       ru                              ru              ru
# 28                       ru                              ru              ru
# 29                       ru                              ru              ru
# 30                       ru                              ru              ru
# 31                       ru                              ru              ru
# 37                       es                              es              es
# 51                      fil                             fil             fil
#
#    std_man_cap_langs  man_cap_langs_count
# 5                 sv                    1
# 6                 sv                    1
# 7                 it                    1
# 8                 it                    1
# 9                 fr                    1
# 11                ar                    1
# 12                ha                    1
# 14                pt                    1
# 15                hi                    1
# 17                iw                    1
# 18                iw                    1
# 19                es                    1
# 20                es                    1
# 27                ru                    1
# 28                ru                    1
# 29                ru                    1
# 30                ru                    1
# 31                ru                    1
# 37                es                    1
# 51               fil                    1

# %%
approx_non_en_many_lang_df = approx_non_en_df[approx_non_en_df["man_cap_langs_count"] > 1]

# %%
approx_non_en_many_lang_df

# %% [markdown]
# ## Generating CSV file mapping IDs to durations (`dur_dict`)
# - This is done to add duration data to text-only JSONLs generated at downloading time

# %% [markdown]
# ### Retrieving all relevant IDs

# %%
# whatever subset don't have set of known trainable ids, use set of known downloadable ids
# 6M_trainable_mod is the subset of the 6M subsampled for the 2nd round of downloading that uses the better quality English metadata conditions
id_files = ["logs/data/download/2M_en/2M_trainable_ids.txt", "logs/data/download/4M_en/subsampled_ids.txt", "logs/data/download/6M_en/6M_trainable_mod.txt", "logs/data/download/8M_en_text_only/subset_ids.txt"]
video_ids = []
for id_file in id_files:
    with open(id_file, "r") as f:
        video_ids_batch = [line.strip() for line in f]
        video_ids.extend(video_ids_batch)

# %%
len(video_ids)
# Out:
# 16774302

# %%
dur_dict_df = main_df_dedup[main_df_dedup["id"].isin(video_ids)]

# %%
dur_dict_df.shape[0]
# Out:
# 16774302

# %%
dur_dict_df[["id", "duration"]].to_parquet("logs/data/download/8M_en_text_only/dur_dict.parquet", index=False)

# %%
df = pd.read_parquet('logs/data/download/8M_en_text_only/dur_dict.parquet')

# Ensure there are at least two columns
dur_dict = dict(zip(df.iloc[:, 0], df.iloc[:, 1]))

# %%
dur_dict
# Out:
# {'LwJv3vSd8no': 372,
#  '3TwThCtZGVI': 313,
#  'XXjYyBCNJEY': 293,
#  'fG3DqJ_YqAs': 781,
#  'OREjUtUT2Sc': 11,
#  'sndzyEYbmTA': 112,
#  'v8uKybpMJdM': 122,
#  'IkiTwxRtQUk': 88,
#  'VvPE3uB7O1A': 121,
#  'Nj4wCms-Xko': 19,
#  '8SnK7mWezWw': 59,
#  't1EwgfdBn-0': 58,
#  'qjXauRp1uaU': 57,
#  '7TZ02EP-VaE': 60,
#  'lVBVy0EY0I4': 60,
#  'ln8Tgp4NsOg': 60,
#  '1CDSz94YRGk': 112,
#  'Dvyxal7xrfI': 277,
#  'X27WzfT3NGA': 46,
#  'ybPciSw7vyE': 55,
#  'kWpOGMfmyFI': 831,
#  '4H2n-qfwvZ8': 310,
#  'vDAana0qFmU': 163,
#  '0Yt4JoCW8oU': 1233,
#  'orWh_OLaRg4': 77,
#  'RHK7gjNfuZ4': 1821,
#  'P4xDdWmDdsY': 1453,
#  'Iis9VJXgzKI': 1107,
#  'o9x7TM75yhM': 57,
#  'QC3enpDiB1A': 69,
#  'k7lN1DCopXM': 59,
#  't224ya1UUz8': 90,
#  'ZmrcKeD4Hqk': 667,
#  'HqO20KiYMAM': 449,
#  'XuAsD43fbSU': 1037,
#  '3Iasm0Dv3bc': 616,
#  'jMT8OdDL_hE': 503,
#  'SVd654PgTp4': 716,
#  'RMlWF2KOC_4': 708,
#  '3Mr8lg5kvIU': 906,
#  'Hd5B3JgJ_w0': 637,
#  'KpHg0kxFtMo': 383,
#  'qnfwM7F-q_Y': 525,
#  '-oyDwlEwxnU': 659,
#  '_VxLBZkZRek': 366,
#  'EOI4kjC34LQ': 343,
#  'gPgI_OsFk0g': 37,
#  '7Bj1BbavrMo': 286,
#  'y3o-baXQT0Q': 123,
#  'gOHyy_6Kd2U': 434,
#  'PcQPFzmG3mw': 603,
#  'qkrJulbUA3U': 668,
#  'z-S9VILXS9Q': 601,
#  'NVeVNuC34wI': 516,
#  'dJZjgO67mFk': 589,
#  'zHGwE0ritgk': 122,
#  '1N2Q2-veW8Y': 128,
#  'cuwXd3DN5JU': 37,
#  'GhnyvKtQm7w': 158,
#  'BGl0TRn-kdY': 107,
#  'IvWZLNiYFVc': 194,
#  'kpbzCl6_zwQ': 4199,
#  '_vcLAPLnv4o': 3608,
#  'dBUOZQZpODA': 1227,
#  'Kfdc3s1hl9k': 3245,
#  'rpzuQAFXBf8': 4,
#  'yheXewLTg3U': 31,
#  'O5TmYt6m6HM': 325,
#  'LQ1kAABebes': 518,
#  'B1H9LtOH8PM': 885,
#  'bTLaG1HjR0I': 816,
#  'oU2XC49MLEk': 374,
#  '8UdhghTfM28': 29,
#  '7iN6lI05sqI': 220,
#  'iUqRVU-OPh4': 179,
#  'AM-U_O0cR4w': 281,
#  'Sne_BZcBROM': 85,
#  'PfTUGYdrb1c': 159,
#  'u_TgMlq6rQA': 288,
#  '-BXEwHv9OKI': 60,
#  'NZTYb5ruwCc': 282,
#  'NnJlXSEH3VY': 120,
#  '3l1P8D0EYE0': 60,
#  'rmZdW3p_Vwc': 104,
#  'SbY-znXGRFc': 82,
#  '-HZ7-0hRe1Q': 131,
#  'DOhIrUcQ5es': 568,
#  's1uiN7OgwjM': 876,
#  '4JNJQR2KVKs': 731,
#  '5GPxO1AEAwc': 375,
#  '3OAEjZSGax4': 292,
#  'nyqSvqeiOFo': 435,
#  '21Sk4c8UpVY': 92,
#  'Ac-L2nopy5s': 100,
#  'oQMOO5An1SQ': 167,
#  '60jIYPL-JHw': 307,
#  'D7EISazUjm4': 572,
#  'MgNdHh6YfDY': 3687,
#  'JG7hy0VZr3c': 4750,
#  'hTbc2g6tHMs': 185,
#  'HsyxE7irZSc': 187,
#  '4r-sb3a_Uys': 368,
#  'nZc5BzJULlU': 5134,
#  'hCE0wWqQmSs': 430,
#  'WWvbB7PQlxA': 28,
#  'qjOp_rUtwLQ': 30,
#  'cSpA0Lywc14': 40,
#  'iOYZG5wcnl8': 88,
#  'RlPilHhS7oM': 13,
#  'mNSdlhJw6ys': 61,
#  'cgaoT3ygXd8': 233,
#  'bH83Sf55oTE': 274,
#  'weUqu4a2vsg': 688,
#  'a_NpFeiyasQ': 136,
#  'KPyxHaa8Bng': 811,
#  'FeStqVr81Cw': 1010,
#  'BtDfJt8JmmE': 883,
#  'yXwcsy0Hp7s': 573,
#  'DLJeaDYSkRI': 973,
#  'PlAfEczgoBM': 343,
#  'MT2IF-FMQsI': 482,
#  'HPQ9M_z8EdU': 594,
#  'EDrLeNEkTTA': 400,
#  '9eV3MaQobO0': 286,
#  '6i0zeUNRahA': 267,
#  'juNmHBUrpeY': 171,
#  'kzze6E2i1b8': 273,
#  'q7JhxXHvZV0': 260,
#  'BNu0iKYQqz0': 217,
#  '-RqgS_jkHiw': 297,
#  'moWhWCdCa3Y': 569,
#  '_cugZHUDzx4': 627,
#  'JjHZeLGEJaY': 3893,
#  'K1rwFID0fdg': 221,
#  'ACWsYeYWx60': 400,
#  'JYPf4C4w84s': 364,
#  'Y8LHRJznmmY': 357,
#  '95eGjeIVJ5k': 931,
#  'WW9FhIXW6O4': 1073,
#  '00r5-CWPXmk': 1023,
#  'beLxHhnQ8Vg': 518,
#  'UBvhOj0HztE': 31,
#  'eus2hK3_j7w': 29,
#  'abBdmIDt8io': 111,
#  '4azOXaWK8Z4': 209,
#  '7Zd4hKxnXd4': 37,
#  'jR9gGNmK9Xk': 141,
#  'cy1Vjz9dTRU': 341,
#  'oSYQ1tIA_UE': 19,
#  '6LpOFrS1-RE': 15,
#  'n-C0cMBNJwU': 92,
#  'RZYGYRti2ko': 1050,
#  'KWszRt6gKW8': 1192,
#  '87rQEEx0xV8': 387,
#  'RQFKB51vqMA': 553,
#  'LkN8wt6quPs': 58,
#  'XLUskGNGHDI': 95,
#  'y2m3qWIZjuU': 47,
#  'oyax9t9n0I0': 56,
#  'Ot5e-rfc7IY': 63,
#  'OxGWtexwDGo': 146,
#  'wdEqarMMqH4': 64,
#  'MlkoUWE3IRU': 24,
#  '0DjoQ3PdCEw': 100,
#  'cOS9juotTLM': 201,
#  'mKHn4HmyOEI': 181,
#  'fGaINvskFYI': 30,
#  '9JF8cG3zYP4': 202,
#  'roDX43FYYLQ': 164,
#  'UokeBHBX6YU': 30,
#  'kpxkkK6czaU': 20,
#  'uOiPqO6ZM4M': 91,
#  'WkvSn-FTyKQ': 94,
#  'TqAg0Psn9Tw': 152,
#  '8jV8V9A1ZcA': 31,
#  '2ah2RSmzwYw': 30,
#  'qxvtYeh2EUs': 42,
#  'kRl-5AhO4cs': 537,
#  'aKNRBRE2Rbc': 312,
#  'WDLdEXujTSo': 58,
#  'EDy-1_S8Tn0': 30,
#  'oyKTWDs997M': 214,
#  'EO70wJR_9Q8': 72,
#  '5qi5r3dciL0': 39,
#  'sCjRZanT7GY': 192,
#  'VbT0LJJjBl0': 65,
#  'PKa3YcdBTX4': 211,
#  'L3-l4ovfdvk': 135,
#  'L1eaU1kWNQ4': 140,
#  'Y8CwTVI6aGA': 163,
#  'cItEeZpuTbg': 155,
#  'mNnWujUykTc': 144,
#  'nBnhhZNFH-w': 154,
#  'tfdKPBiTpE4': 149,
#  'gLsADA4XP7k': 82,
#  'Q5gmIyby48M': 54,
#  'qV_OyYyGxR4': 222,
#  'IPjrN6mcvg0': 85,
#  '5wmGZjsOLLI': 201,
#  '8UtKRZoDxgI': 165,
#  'lZqv25d3HxU': 165,
#  'fv5Fu4wLEsA': 175,
#  '4NdEFiDppOo': 460,
#  '8WDrxWrH2NU': 37,
#  'EMgIixn59fY': 118,
#  'ALbfTpm_-ug': 1261,
#  'rucEKMMMJ8E': 207,
#  'c1y5Te-rzTM': 734,
#  'mBa9Sh3FfWg': 709,
#  '3aAFzGUn2hQ': 917,
#  'F7MH6eWIIJA': 243,
#  'u3x1yT8Csdk': 287,
#  'fP0GEL3Bn58': 12500,
#  'JbfMm1twa5g': 181,
#  'oe-qyuNq9mw': 39,
#  'MQh2mDf4Im0': 72,
#  'YIJQCa-8Tes': 72,
#  'ZArK8yMugyI': 375,
#  'f9H_7GtS48Y': 34,
#  'qVjSTc510fI': 32,
#  'C_6HQ9Tyjbw': 136,
#  'Tw3HpCJ2tNA': 155,
#  'WAeDVc8zUhA': 322,
#  'GYWHrst2-tc': 75,
#  '1D0NMvn1tRs': 45,
#  'KYec4MeJtqg': 162,
#  'Z5bGdnAazSc': 161,
#  'blax3iqeE68': 29,
#  'd04YBh_p268': 216,
#  'bePaMaDPngs': 272,
#  'XZasCxhSrK0': 1629,
#  '_EmYGPciUUs': 380,
#  'jRIcysLt7P8': 56,
#  'HjbrV7GlpnU': 69,
#  'x-mUomPzpfo': 65,
#  'jKnguwfVY6Y': 126,
#  'W3ts5xuhaZ8': 176,
#  '9qBidHh1weI': 66,
#  '8iAqL8PKK70': 53,
#  'q5fEG33h6Kk': 117,
#  'AGD2qp34hmQ': 494,
#  'Wvt280P8ZsE': 515,
#  'WJaZuayzDas': 512,
#  '1Ya83G3pLcI': 539,
#  'tTESh9GYRnI': 3975,
#  'iaA5718LTiM': 3317,
#  'lc65NClkXPA': 3828,
#  'BhAqOUzr0RY': 2893,
#  'JBySwaGvwoo': 2471,
#  'ylMxKBlPUD0': 1945,
#  'G4IUAO7ILCg': 1650,
#  '3o61mE4dH3c': 912,
#  'cbuCNGlG_NA': 944,
#  'dd33SJgpCmk': 475,
#  'lah_Qb40qDM': 1154,
#  'prCFpHU31sc': 38,
#  '6UqcL_RRxkc': 90,
#  'Mz23Rawi63g': 16,
#  'pppN7s-tzrI': 22,
#  'bbngPKCnEMw': 519,
#  'akXli5WOq7s': 599,
#  'i5jFVNi8Zcw': 155,
#  'MQmKj5QneAQ': 42,
#  'vDeS1h8bNak': 96,
#  'fvXOSbTvtQY': 95,
#  'UXYax3XRNo8': 90,
#  'xMj6WpM8XeQ': 87,
#  'YQXjzDpDOTc': 101,
#  'CnVil18-WLY': 78,
#  'N3a4YIlWX5U': 86,
#  'P-hKoFHU90Q': 98,
#  'kS-XYLXDCuE': 95,
#  '3Ir4h3qi8e4': 90,
#  '4mi5TZWMfm0': 84,
#  '13SJQ1npJqA': 112,
#  'wddvX7Kqwtk': 113,
#  '32pTX3tSDyQ': 969,
#  '3nqTJ-U4kN8': 1035,
#  'cZ_Imm9y2kM': 73,
#  '6gniitAi2MY': 60,
#  'bVHYwym_uX8': 64,
#  'eUUu8oR-RC4': 81,
#  'Rfsy4B3fxeQ': 1058,
#  'FLz2uJzOZy0': 40,
#  't28LlLKJwdg': 252,
#  '7BaFQydsz5U': 8,
#  'dzBjxGMJcgc': 826,
#  'IU1MkPcwBCI': 180,
#  'Mn0-VEk7tso': 32,
#  '4Hr9ky4LFrQ': 35,
#  'TkV8NLlgIqg': 271,
#  'mw8VM5wLL6s': 595,
#  'MTC2T91cvvM': 199,
#  'WaqZBYHmbBo': 21,
#  'tDE1Ky-U0yQ': 338,
#  'fpKxgYx5COU': 79,
#  'SC7-7Z96JWk': 1050,
#  '3TpyNz1WRdA': 10,
#  'JSxzGRI-Mdk': 152,
#  'su9tMqGDpqg': 280,
#  'FxVomBvA4LI': 231,
#  'l7qt6GByji8': 380,
#  'eD0ZbnymG5k': 363,
#  '1oH9AtUdZs8': 763,
#  '_LiTVhQdRL8': 544,
#  '0NTBEEasTIc': 4599,
#  'yoEG_fcATXI': 831,
#  '_YRE_1UJ24Q': 4569,
#  'eZUzgnfK62E': 950,
#  'X-xWtHtwVMQ': 3465,
#  '0UNUaFTtP98': 2150,
#  'p8xzN-rNuTU': 162,
#  'U_zR3pw172g': 148,
#  'GKPXI7209Og': 69,
#  'r0GdFGYFCJ0': 64,
#  'CdbLxn0MeE8': 50,
#  'e9IgpYRIpfA': 98,
#  '0d1nN2WfKo0': 45,
#  'Qq_2HBdxrBE': 310,
#  '6UPtcS5DdEA': 191,
#  'QMsNJClZmRY': 379,
#  'BwFnyN5Xwqs': 1004,
#  'hN735M3ZK_c': 483,
#  'VCOYX-jkUcI': 435,
#  'mF_qDSLqnvA': 494,
#  '2f6JUqz5iOI': 503,
#  '6WK8BuYMkOQ': 463,
#  'cOhJ85qJ21Q': 487,
#  'Ihiir-aXBfw': 445,
#  'x0JUp-czRcg': 541,
#  'xbKUvTTdano': 406,
#  'UZpDIUYfdoY': 407,
#  'Xbon7yWBuX8': 440,
#  '4R7bd2ka06M': 439,
#  'qBMYwW-r8-8': 463,
#  'uhwAWy1O2Pg': 459,
#  '4UkqCzOrS-M': 500,
#  '324sIalDaKw': 424,
#  'R_JV4PXErGE': 439,
#  'jJAkTxoIX3c': 287,
#  'Bf7YtgjHXrM': 411,
#  'Y5fZQwK4YlA': 37,
#  '8LYRk6UNei0': 3547,
#  'PxR3cP8LI3Q': 6198,
#  'IHYAouYHRnY': 6854,
#  'r1v5jdpC6_w': 7185,
#  '3misD6kZGOc': 92,
#  'bqzRU5cdX-M': 99,
#  'glf2W_t5hzk': 649,
#  'A8SOfaiq5eQ': 994,
#  'xXLOjpAhWrI': 1461,
#  'lr6po6raQG8': 204,
#  'ne927IxloRc': 14,
#  'VHnvFKmxWLY': 60,
#  'j8UeJdN-WXc': 313,
#  'PwnCBw7WbSk': 786,
#  'G_WHtkjqrWk': 165,
#  'WGdlOe0RBzg': 28,
#  'B506YqQ-laU': 241,
#  '1vxFaJzH5FM': 195,
#  'uh-4k8LcyUE': 60,
#  'rNHvk4FhgIg': 42,
#  'so2v9udAd8g': 40,
#  '1BViOkFKtV4': 60,
#  'YLmuNOEKyWM': 357,
#  'VT-4syD6QEQ': 150,
#  'cjBuLQUgqmM': 193,
#  'tc667sTj3Pw': 293,
#  '24rkxRugg6c': 142,
#  '9KUBnFtUMLI': 199,
#  'fsrZZ7r6Nd8': 146,
#  '-QYNTSBXG64': 582,
#  '8NsYDi--Kzs': 133,
#  '8-8mci8hZ24': 152,
#  'mkeXxunmsjs': 99,
#  'Ne_KSucg2dM': 3176,
#  'R4TkoIpFOBg': 187,
#  'EX1LWrrKICk': 399,
#  'uVz7OvL7j8c': 52,
#  'WmwgZfGkIEY': 364,
#  'oSWVOXUD-80': 2015,
#  '5z8HSpxve20': 1703,
#  'GH2gXihsFBA': 4515,
#  '1DdDRmIY1qs': 44,
#  'FILjxb54Gqo': 59,
#  'J3wBXGPmYw0': 62,
#  'WlggoQQsdq4': 161,
#  'luX3mOhZoz4': 255,
#  'x-pNYAJ8Cik': 95,
#  'ngjO0fnaouE': 301,
#  '6Xde_NnadQY': 237,
#  '5FDyn4nO92A': 163,
#  '97y1tj9T7PM': 77,
#  'Tbk9ff3_86M': 82,
#  'v-28GTVUjz0': 35,
#  '9bLj1ElQA_g': 147,
#  '_opGwUmADjs': 198,
#  'wSybVCjOoEE': 323,
#  'YgjRS2e9Nkc': 1308,
#  'ouC3RqWPOSM': 58,
#  'MtQ_1bPpsbA': 60,
#  'o9FGCTLEX6U': 236,
#  'Z32GqnFs-S4': 135,
#  'AhApoLpI3l4': 161,
#  'SokBFZmwcsU': 151,
#  '3zkNXOA2X2I': 412,
#  'bahK-cADMDE': 45,
#  '2euJtnG1qt4': 35,
#  'fSnZsbQyosg': 35,
#  'YnqvbgwDrH4': 1081,
#  'JH-8B7x_lTw': 165,
#  'TyX4HK0Yq4A': 160,
#  'n9WI3ZON-D8': 39,
#  'lp8oMxQDIV0': 124,
#  'g163jwgNXuo': 137,
#  'cQPOBmHCcsw': 29,
#  'MjAlHOYRlOQ': 157,
#  'migFTlKlwO4': 32,
#  'Q-6PbiOkT94': 113,
#  'Ygo25nV4l8A': 101,
#  'V5NsgmvheaU': 153,
#  'P0KDJ3U-rSE': 97,
#  'RXTsA4PbFoQ': 60,
#  'I90CAIdv3Z0': 435,
#  'Fr1CDEgxpZ4': 742,
#  '86xfEuRa9b8': 646,
#  '93oDs4X9DnQ': 296,
#  'e9JZ-7k3bBc': 1088,
#  'Pw5PbuBGmRA': 783,
#  'g7LIBaNpvxk': 154,
#  'ZcJ7uRp8eL8': 26,
#  '1q1-V8lDppE': 96,
#  '67LrQ_cXk-4': 109,
#  '7nIWRxgEClI': 470,
#  'f7jZeZIm-CU': 141,
#  '3MwhyOqyZxg': 591,
#  'RGP-DeYuT08': 361,
#  'iDJL7WdmheQ': 596,
#  'bGMBNRl7gW4': 15,
#  'SQq7lZ013OU': 201,
#  '9MyIR1yh0So': 88,
#  'ZnLbI4-7KyM': 159,
#  'T5GF0RhEn94': 167,
#  'GkBjzSQ6lXo': 69,
#  'qt3XvS-XF8g': 742,
#  '8DbS6YrP58Y': 395,
#  'w0xPJDeTOc8': 601,
#  '2zKKJHymg_I': 774,
#  'QLCfc9tvo2s': 439,
#  'ZMI-R5y80_M': 233,
#  'oYe-QM8ZimI': 592,
#  'mgXc47nzjHk': 547,
#  'QxeVJGVR6iI': 200,
#  'qbA42wQoWAs': 455,
#  'Qbf6OQ_BeE0': 443,
#  'TuDRY0Paiq0': 372,
#  'upocZq6ymAg': 589,
#  '2u7DLQQzriY': 640,
#  '8LDkfpG3r5g': 1190,
#  'hPSaELQocSs': 977,
#  'wmyXPySUSQQ': 908,
#  'PqAlZFAe7Ow': 895,
#  '1s3xP-jNwz8': 1039,
#  '4AyZ_tD_alw': 105,
#  'dH8jsTnEnt0': 115,
#  'O8uXrS9-Dbg': 1182,
#  '0rAg4W4R4uE': 1104,
#  'SwJAJZwCFa8': 874,
#  'hzl7LXZUApw': 1257,
#  'aRTLBbSX4-U': 101,
#  'VqRccpEUZRE': 107,
#  'ia-aYNEVZnw': 98,
#  'q8y27XeRVI8': 112,
#  'NDht3pBFrt8': 106,
#  'LccPjhorUTI': 868,
#  '7nJv1sPVpd8': 775,
#  'jKbOmTmJMhk': 481,
#  'WjEkxGxbKKM': 289,
#  'HBz9NvD_B0E': 541,
#  'kUTYSyd3LR0': 618,
#  'la_rP5E-avM': 609,
#  'wB8MAZyd0VA': 950,
#  '0woLcss7_fk': 252,
#  '4N_bmZEddJk': 181,
#  'EiXFDjt1L0w': 369,
#  'N1cdRrhqtes': 487,
#  'mnpe350EtsE': 393,
#  '4-vmhOA_fbE': 270,
#  'ipLKP9GfHgM': 742,
#  'cv49r6UvdbU': 726,
#  'oFOoEX4hbJU': 457,
#  'B5kqoNnHGz4': 345,
#  '0X78s51C0nM': 208,
#  'R9nQADrQ5vo': 368,
#  '6SDKHDreODM': 273,
#  'xUUqyILzbfo': 179,
#  'QGf_fu6zuiA': 320,
#  'w7MTczVx21w': 283,
#  'zIB2RdC-dZ8': 482,
#  'urng26H7tGg': 470,
#  '-FiinwdPlLg': 323,
#  'mYF-L2ysRMU': 529,
#  'sMCu6g3MbB4': 353,
#  'ptqz-sQIy_U': 374,
#  'pRvfNo0dxmo': 301,
#  'Lq6rAftZl5k': 455,
#  'eQmQ-NOz63Y': 481,
#  '1-bVtOvDR4I': 775,
#  'h012J4p40Bg': 192,
#  '1ehXG6LdVeE': 464,
#  'qrVHbp7wxqI': 171,
#  'j8AzRAtYyA4': 304,
#  'tQ7su86FRKc': 726,
#  'ku1z9z4QmEY': 502,
#  'nlLGKSKFRVk': 377,
#  '9pbZIgOK9i0': 629,
#  'f0dx3-ZYRyY': 629,
#  '7SqkTlgNVzg': 877,
#  'K5X05dX1pTQ': 641,
#  'rnFA22qoKNI': 390,
#  's5cn01KFV2c': 603,
#  '9wHAuxrqdCQ': 710,
#  'rK765Rv8H7o': 261,
#  'EwcPC9RnUE4': 133,
#  'vq1Oo8_jzEE': 255,
#  'r1hBOrknT1g': 1502,
#  '5RrZF4uShOY': 92,
#  's6jSqt39vFM': 262,
#  '8fKXBBalCZU': 312,
#  'BvcVzwku-c4': 315,
#  'YoeuJgHUETA': 223,
#  'r343tW6eKWY': 389,
#  'Xc6hi-ZbBGk': 1006,
#  'lHjxqk6A6Ig': 1242,
#  'z0WyRKloBvQ': 287,
#  'bFSOsXNZBxQ': 344,
#  'ZTCDXtuUxX0': 553,
#  '5cbMSAzddaw': 1714,
#  'V_La4Va-_jU': 648,
#  '6nO0fI-C468': 2646,
#  'TZfEYRIzjXE': 1528,
#  'gdcGpq7KnPk': 2115,
#  'VA2ePX6KIeM': 2341,
#  'lxYPGXMpjpM': 2766,
#  '01RdiA8Bzxg': 3225,
#  'Gc-6zrxqBdc': 2648,
#  'yvJq5_UFQec': 3203,
#  '6a3f75fPKT0': 181,
#  '5AGRDbvl-gk': 354,
#  'xN6OsStfPUk': 438,
#  'bB98ohJ-4Hk': 289,
#  'mlXjKO5AqQc': 187,
#  '1IQW_pqspHE': 155,
#  'aiM9TwqyIaY': 117,
#  'rhFu-gcNhUA': 520,
#  'p2FE6rs00uk': 172,
#  'hVH4zqJOH8g': 117,
#  'Yrwu5MjqevY': 104,
#  '3LzpSb6k1e0': 115,
#  'NzLjzl_wV6E': 107,
#  'Rrtvauf_0aM': 94,
#  'B2j08l9AFWU': 143,
#  'gmBhSxV9eS0': 143,
#  'k3LQqOykZQM': 95,
#  'uT3Nzb8IeFM': 140,
#  '6JCkB5W_ePE': 72,
#  'WbLMivO3-lU': 360,
#  'cRY4hv5EjHo': 1133,
#  'fDYXzfSWPPk': 228,
#  'pm7r7yC_91M': 70,
#  '5KRqwcyaonc': 130,
#  'iPR6y5SYk50': 102,
#  'HfctfZB51Pc': 139,
#  'TS9km3VXFgE': 61,
#  'cEg3RLOns9Q': 49,
#  'X7GZ10OOAiU': 85,
#  'ki2JbUE9FiQ': 97,
#  't5dw16lA4b0': 101,
#  'tDphY-BrTso': 95,
#  'Ox4896TR7pg': 184,
#  'aVQ0Jf73td8': 45,
#  'm4WIEcTsiuM': 607,
#  'Jto2KtmCe1Q': 195,
#  '79fFZDH5HNk': 175,
#  'U_qgNsiwYxc': 209,
#  'X_ph9vw0ZcM': 350,
#  'vP8PhrRzN5w': 713,
#  'kSN-hZnOMUI': 570,
#  'myNs0diNjII': 623,
#  'FfSJBA9NBCo': 260,
#  'k9GgkuciQSo': 137,
#  '2yqyd4tq0Gw': 114,
#  'w2GEsbmI17E': 124,
#  'dfKscSxvsl0': 125,
#  'CyjPc_6-Iqs': 164,
#  'p7zEQQio1ZA': 8670,
#  'vbXzttoLAPg': 6994,
#  'IXFBO1Db0ck': 9212,
#  'zwxK-UUfq7E': 5199,
#  'Mp0IMB0juTo': 8697,
#  'YGoQF-YFvBM': 1129,
#  '2qn0gQmVGRk': 40,
#  'Z6_U9_iO_Eo': 877,
#  'xUdxZy5E4_k': 128,
#  'YJCcRwRhyoE': 210,
#  'T__1U8VU38w': 4549,
#  'jSIta3lNYwg': 431,
#  'F_IwlCi2Xys': 2813,
#  'hMN6DOVjavo': 1057,
#  'm0Q3p06ZkmQ': 227,
#  'yTVwqdDqBOs': 455,
#  '2QCVsfiRJ80': 244,
#  'yGVRo7TdG2w': 359,
#  'OUCkttUKPsI': 933,
#  'Kg1wFXOyH2Y': 541,
#  '2eGdHNohLdA': 97,
#  'zChiW3nlYpA': 428,
#  'kjRvHLB5RnY': 614,
#  'jTz4BJTOvCY': 381,
#  'VSf1dx6ixYo': 231,
#  'HG-eZlS5adc': 456,
#  'MctA0jsjZuc': 800,
#  'CQNSUTyW_K0': 702,
#  'amHvlvWTV1A': 742,
#  'gIFcmWYasgM': 677,
#  'wWo-OOPFgFI': 553,
#  '2uumG8uUfe8': 872,
#  '9cDmM1SxxmU': 534,
#  'RnnveGDhjlg': 544,
#  'Q-tWHSFPw4c': 629,
#  'L_DwRb0SoH4': 651,
#  'ZqWqrFq7rMY': 1162,
#  'qrDdrLSsWCY': 319,
#  'Iv3R17CNQOM': 300,
#  'gGMcl3sa--0': 177,
#  'T91amUYdpnE': 257,
#  'k63ta6CklLM': 77,
#  'B8JdAFYrM8Y': 141,
#  'sdFE_sTT5C0': 271,
#  'g5q_7XkLZu8': 187,
#  'PyPL4oynYms': 3661,
#  'J0kvbmCAyr4': 5288,
#  'LIENhwVlneI': 5134,
#  'LRaJ8s4FiQg': 5168,
#  '3BzYxTGpPgU': 5422,
#  'AcKxjrEu6wQ': 5364,
#  'diVtL_wXX_c': 3601,
#  'e4Tge91ahxM': 5238,
#  '1YpVHQP5kj8': 5500,
#  '3E75yTSQKuk': 4961,
#  '26yxHxDy668': 5307,
#  '09m-9-ReWrY': 6191,
#  'ntqBECgfM6U': 234,
#  'YEad6XR6dTA': 220,
#  'fJt4AITKXMs': 804,
#  'L3ZtYWTVW4k': 125,
#  'VZ-6ne4_V_A': 551,
#  'HVizvEqmErI': 309,
#  'dqZii8dZ5jA': 324,
#  'BkIW1PzKwhI': 325,
#  '3hXHVJwoovI': 463,
#  'FBGi5bc7UVs': 308,
#  'M55vcsil2_I': 302,
#  'YqJDUq-lCpc': 349,
#  'c9UgegXOuvg': 372,
#  '_32NIgztluA': 545,
#  'KMim1KtZwKE': 330,
#  '4Q_tzaKcmWk': 359,
#  '9rlnrYCy2eo': 358,
#  'ZmQoXPPXI1Y': 429,
#  'x15DgfX9OYk': 328,
#  'unbdd0A2KGA': 455,
#  '-_E0jr0Mn-Y': 268,
#  'e11FswdY_J8': 323,
#  'CTPNfLAmF8k': 292,
#  'saSH5X2WDso': 129,
#  'uR46fhzh2ac': 92,
#  '0yDgq3tn7P8': 157,
#  'vdYQ9GSQtoI': 163,
#  'w0DybIZ8bKY': 406,
#  'PLG2klHWTdY': 331,
#  '5C-jWxgMJsc': 417,
#  'ARSJBfSkaIs': 306,
#  'PbIcYZCLG8c': 526,
#  'YOByVUs5g7Y': 454,
#  'KEbGYSwKVTM': 306,
#  'htVAJl2p2AA': 520,
#  'WmS7XkjfxsQ': 540,
#  'KWdUDf8u3Oo': 394,
#  '5iKAKpiHRCI': 643,
#  'R8H1ONNZNo4': 562,
#  'owsSLT0fCl0': 528,
#  '_hn2eFm9V28': 421,
#  'YsmrOlR0Fv4': 585,
#  'W4Ym21swqVA': 594,
#  'xUOREhAr_FU': 381,
#  't3WbDCu2FvY': 808,
#  'tV8bj66gHsw': 3720,
#  'RoZzFwCJr7k': 225,
#  'Ae2rMjjpZZ8': 172,
#  'xyTJ9RIiuM4': 249,
#  'sO2Dbys2FKI': 247,
#  'nDQ4rX5T_H8': 167,
#  'k5Pd8UC1wQg': 193,
#  'zNvW-cUopvU': 220,
#  'e4epImRW2VQ': 152,
#  'PS-ErGo5Cjs': 182,
#  'szrO-wnf9cw': 198,
#  'xmzXi4JxXqE': 243,
#  '6jDgN8DoMQY': 225,
#  'p5jx9maoijw': 212,
#  'uBbuMeQPq_o': 231,
#  'Wt2_riOviKU': 190,
#  'Aa1LOcDTbQE': 171,
#  'SHBX2ZTOKVU': 166,
#  'fXJhzF7kfHU': 214,
#  'yOfhP8UMu_s': 204,
#  'E6UABPRpr3M': 235,
#  '61_4TsdgjeY': 209,
#  '19xLC7w0Gdc': 209,
#  '5oeTyEORaw0': 1909,
#  '6mw4nvE6a9Y': 112,
#  'bJsBFLy7uQE': 105,
#  'QbQEMZyWWGk': 139,
#  '8fyKTZ3BLgU': 123,
#  '0XOY0YE6494': 1422,
#  's4QGV6xKZL8': 1567,
#  'm0t4uSjFabM': 849,
#  'fqzKnni2GlQ': 1029,
#  'SQ1v05yR_2E': 716,
#  'yEyaAnZt5nY': 583,
#  'Q-_-D7gehEU': 567,
#  '_cpppozPXN4': 411,
#  'kFkM1grbiuE': 436,
#  'colRok_5-eE': 325,
#  'sn8ibCNHKDQ': 452,
#  '-fRgghpnGJY': 165,
#  'Cet3LoKq-J0': 356,
#  'HHBasDWFmt0': 419,
#  'TrL-dNBJhoY': 428,
#  'wpV1kUUWFTU': 450,
#  'HAPttLd8LQM': 424,
#  'y6BDcLGSiv0': 420,
#  '6eKO5EqLB1E': 469,
#  'Z1j7P39n2F4': 490,
#  'QSGu98t1AP4': 5426,
#  'dDaPjEoWCBg': 4973,
#  'Y2NViFLMwuk': 212,
#  'FVkMHCHaQd0': 122,
#  'M60s0ZhxjO4': 183,
#  '4v_DhoG3np0': 145,
#  'JBYFf9iJNSU': 279,
#  'bPEgLw9IOtI': 158,
#  'TMaBOjcPUfA': 231,
#  'nf1IB4lNgAg': 240,
#  'J4RavmW5Z5M': 240,
#  'iX2EM7cpJGg': 216,
#  'K2CGq9YvuIM': 213,
#  'B-v9h7RALrQ': 181,
#  'DZtLW2heNXA': 122,
#  'g3bvLpw9mVc': 267,
#  'j0eiI9-Km_s': 164,
#  'ngabqyn4s1w': 174,
#  'KF6vjdE1zv0': 184,
#  '55xF_bSZaTM': 202,
#  'Qx0g1O4ZOJ4': 173,
#  'pc0B4edRyBI': 169,
#  'BFI--5eH-gM': 262,
#  '0PJqgjMPx0c': 258,
#  'JN7XWWta5Zg': 232,
#  'HOT9cUzGgYQ': 158,
#  'ZnmdC88z8UE': 624,
#  'YX-YXgujNls': 911,
#  'cAszPdZpYhY': 1172,
#  'ghqa_rtdQKg': 423,
#  'MPnoyjmHkIs': 463,
#  '06Wmdrh8ZqU': 1003,
#  'qN370Q_K64U': 1279,
#  'iKp9eDcknus': 109,
#  'O_Bj9YBEDF0': 119,
#  'eKn8PCpVGYQ': 93,
#  'xnO9dVddIg0': 136,
#  'DT3Vzd95hwc': 489,
#  '1wmvvt4_jp8': 311,
#  'bnjsrx-ToKs': 88,
#  '3liY-0FcjLo': 58,
#  'XvIfitDDGHQ': 88,
#  'EkUS3B4mAXw': 114,
#  'ZlcsQALCXVA': 210,
#  'UQJ8SrSNg5U': 3181,
#  'KxC-LCYoyW4': 1951,
#  'E7o4mIkMSeo': 1980,
#  'FLzJl5ObSqs': 855,
#  'bc9noM5oeU8': 197,
#  'LGHHz8QDNaQ': 245,
#  'PZ6oLGvxoQk': 172,
#  'woq_0w3f-7U': 203,
#  '2jnerh7-vYg': 241,
#  'nAiD9Qd4iXA': 217,
#  'AIezoR_djUo': 241,
#  'gRuPyp7SjCc': 270,
#  'Z772vSllwSw': 175,
#  '9w1X9GvoGU4': 269,
#  '5up-OLPqZTk': 288,
#  'NSE0QfxZS9k': 234,
#  'Tt9h_yyctvg': 207,
#  'dMO3JvbQ1Wk': 295,
#  'x-Ila7pxBEg': 185,
#  '4uWkVd5h3mY': 271,
#  'Tpo_5jjaaj8': 243,
#  'qLs4e84CSCk': 130,
#  'jkhf5Gz_Jcg': 192,
#  'LL4MYvpyHnc': 233,
#  'rZJTk9Re3Qc': 151,
#  'BtR4s_SATYo': 236,
#  'ookVzp7Etu0': 340,
#  'QrrKTsdM9N8': 168,
#  'peJqrYySDI0': 32,
#  'o9MkZ2LBPFA': 34,
#  'ZxvgpR6z1Qw': 35,
#  'nBBi3Rls6NA': 45,
#  'PVQpP4lU__I': 42,
#  'Nme2POpvms4': 35,
#  'M_Ve0q9QyZc': 45,
#  'mqsmjmTUYJg': 51,
#  'I_RkriMwhOk': 41,
#  'YZS_387lllI': 181,
#  'nXdgGUHpm7k': 336,
#  'EO4-Q7-e42I': 721,
#  'WIFxMwMqw9w': 869,
#  'bL20IJ1PO5g': 38,
#  'Sm2K7niGRN4': 307,
#  'c4nOdgGkk1Y': 292,
#  '_Irq8ZMgSBw': 2304,
#  'gCeNgV6DV-E': 517,
#  '9-LYAWIoLsY': 455,
#  'iSrARoa4TT4': 733,
#  'uZGehNqy2dU': 576,
#  'gjY265yvEYU': 474,
#  'y-yuaUcSd1s': 582,
#  'SjlDQlDe73w': 424,
#  '6mbA2O8lqQM': 644,
#  'khm_1dW-Fx8': 664,
#  '-EBw5kPb0x8': 503,
#  'F39zVMFoZ8s': 528,
#  'lBvqzTa7TrU': 495,
#  'X_jZgpfKnCw': 535,
#  'fQ2ogaltVxI': 466,
#  '4rS5E-CXSNo': 537,
#  'C0bPjAx2k_4': 565,
#  'sDHJfmHAtzc': 631,
#  'MPpznIB8PGY': 542,
#  'PYt1B0jaUjo': 501,
#  'JuElEX4mL-A': 1115,
#  'EVKwSTFD6SU': 601,
#  'nXSspJdoHuQ': 813,
#  'XbCU1CsnQIQ': 843,
#  'xpTxlxAgYHA': 2312,
#  'bw9tZmGneCs': 354,
#  'eZJ9yA83P8k': 419,
#  'SPGBuJtYYmY': 1634,
#  'Af9XT-AuYQA': 1360,
#  'eccza8l8yS0': 814,
#  'vcaAbdw0nzY': 2098,
#  'B7FWeDSJsTo': 760,
#  'uS7yHTIDL_A': 1533,
#  'Tlj3we0p-qE': 1985,
#  'NYL79xsjLXE': 808,
#  'fl0KL6cHYmE': 661,
#  '_btgdFvR4NY': 601,
#  'XySH4y5HheU': 801,
#  'oHb6aW0-TUw': 2119,
#  'wn53LiaKI2o': 826,
#  'CGvQ9K5SM5o': 1906,
#  'P9MwBVV9YBA': 880,
#  'oAHzBTzNB2c': 2082,
#  'nxV2NwO6MZs': 762,
#  '0iem9RUyMC0': 122,
#  'D9dG-W3CQdM': 406,
#  'gCChnMyScmk': 285,
#  'X-I2v2iULto': 41,
#  '8Y1GHlvTEzo': 179,
#  'MioXMDb43HQ': 149,
#  'sqZPq1ju8j8': 292,
#  'ofdYadm3VKg': 349,
#  'WAV7EOyRmj4': 362,
#  '-sWmyaoyd14': 358,
#  'Q2WZzQNY_uo': 409,
#  'OmoaIxLQ5PE': 432,
#  'UYztzzBbI60': 355,
#  't_2NENs60gk': 594,
#  'o0wcXv0vEB0': 574,
#  'zyaFxQ4p0P0': 400,
#  '0iuiBQdWFew': 577,
#  'RCLhrkNn0Xk': 415,
#  'nx9Q9sMW2HY': 416,
#  's_N2WAnWgLk': 389,
#  'cxcUQNNFRYo': 326,
#  'iuFPmTIPitQ': 596,
#  '2gnoyM1dslA': 619,
#  'fA1y3KxRGRQ': 730,
#  'pXuwpa-gxgY': 695,
#  '1RNBC3SG-wM': 653,
#  'RL8ME842ttk': 722,
#  'LI2Yq0aSpj0': 556,
#  'HxBswJdTTbQ': 612,
#  'EgnaWFN4XhM': 594,
#  '8JzZOu7BRrs': 652,
#  'JoEpxThnKlY': 610,
#  'SsG366WaShY': 490,
#  'fX55q_GKVYo': 738,
#  '0FX49_9JLhI': 557,
#  'DAgsb4qnApg': 593,
#  '2Ccixhw9gRY': 722,
#  'dyhq9-knBGY': 624,
#  'Ygy0NWgcnxY': 624,
#  'oHNisrgQwhc': 581,
#  'aTl9DxPM_oE': 658,
#  'NL9Et_3i4dc': 752,
#  'rAH9t73MGFI': 711,
#  'g75i02hQ-qU': 925,
#  'tca7fqZNDO0': 773,
#  'hZH1LO3K-S4': 747,
#  'l8aNZH4RP_U': 2427,
#  'SapqTvXaAIo': 1354,
#  'JS-tmyTzimE': 1354,
#  'KR2uXSn40I8': 5449,
#  'wcytM6IcJb4': 156,
#  'S23BnSh2XLE': 456,
#  'Ld_LhK8jSvk': 331,
#  '7wkzczaPTFo': 41,
#  'r6l-fRQ-d3U': 249,
#  'bhXKr2U7Nmw': 251,
#  'WpHuLIaaIV8': 253,
#  'RDZiPaw1P80': 255,
#  'wBkBbG7BhZ8': 259,
#  'JtrpcpN7AYs': 269,
#  'NDuXIW4D-KE': 238,
#  'ppA_wYQcMo8': 252,
#  'QgLhCDyjXHE': 279,
#  'ppqAQChvnSA': 279,
#  'tgtA5pMf5PY': 259,
#  'abeQ6ijBy9w': 270,
#  'rgwiYh2hgFY': 256,
#  'EudYLU3zCh0': 184,
#  'JnwMmCcltxI': 1278,
#  '54LL1kNzEZk': 1641,
#  'mf0_U6G9WGQ': 1408,
#  '4Hc5oiVKEyA': 1363,
#  'MbgvU1qUPbU': 2277,
#  '_717-2V1pNI': 1259,
#  '0BW8xMRPMb4': 510,
#  'IsXf0plgL3c': 1393,
#  '_kC8MAaU6JY': 666,
#  '2iRSAdBqhnI': 859,
#  'tjSTrYNGLfw': 958,
#  'gtsBOTdFnxM': 1851,
#  'y-Rq03iHmVM': 1323,
#  'PfSxP_RRC6s': 2122,
#  'Jl3pE-lZ51o': 1425,
#  '3F4PB7T4bu8': 739,
#  'TxQeYzqU8ao': 1724,
#  'YEzNY3Ar54U': 237,
#  'S-LqZKf-RWE': 1392,
#  'yjOTExcVvTA': 1179,
#  'm70u2uLbkro': 485,
#  'KQdN000kpqM': 1454,
#  'uH2N2gmjhl0': 1264,
#  'sinONyOHfW0': 1888,
#  '_c01Q4iVUNs': 1001,
#  'lAN-MMq2VKI': 177,
#  '_v3FG_r8F4U': 377,
#  'QPZzY7iRo5A': 267,
#  'uwg3oU7cVhg': 2326,
#  'ZQa7uAvfSZk': 62,
#  '004U9OIPTWU': 1820,
#  'OeJJdxYk_Ow': 785,
#  '9AWkz3iWfjM': 2136,
#  'LTcs7pLrgh4': 643,
#  'RRWeq0joB14': 353,
#  '7BxMq0JRpFs': 732,
#  'xF3gKx6Zqdo': 946,
#  'rzZV3jpyNHY': 1202,
#  'n1Zru3jpAJ4': 843,
#  '-I-nZ-I3JEM': 1156,
#  'EngJmAXFWc8': 319,
#  'OMXa_sOiRmw': 246,
#  'RY8EBtwv5Z0': 762,
#  'gQa69hFA4bs': 323,
#  'E6xdnMy6HyY': 295,
#  '9wTElfMqFyM': 308,
#  '28_kjqP56FA': 253,
#  'W_61Z539XLs': 328,
#  'BBS3bp89nbk': 339,
#  '7lpPGDKfh7s': 640,
#  'Ta04dpcRxVY': 302,
#  'ULkmebwh4lQ': 414,
#  'v51Ss00cWkY': 324,
#  'Q2KBhh2LHuc': 209,
#  'xTjQ8M4W8nQ': 208,
#  ...}

# %%
view_lang_cols(dur_dict_df, 5)
# Out:
#             id                                             title language  \
# 0  LwJv3vSd8no                               Free Art Wednesday!       en
# 1  3TwThCtZGVI                                   Etsy Commission       en
# 2  XXjYyBCNJEY                                FREE Art Wednesday     None
# 3  fG3DqJ_YqAs  PANGANDARAN SAAT INI | DRONE VIEW | DISAAT MALAM       en
# 4  OREjUtUT2Sc                    New Intro | I keep losing them     None
#
#   manual_caption_languages automatic_caption_orig_language
# 0                       en                              en
# 1                       en                              en
# 2                       en                              en
# 3                       en                              en
# 4                       en                              en

# %%
dur_dict_df[["id", "duration"]].to_parquet("logs/data/download/8M_en_text_only/dur_dict.parquet", index=False, compression="gzip")

# %% [markdown]
# ## Debug

# %% [markdown]
# ### Debugging (part 1)

# %%
main_df_dedup["std_man_cap_langs"] = main_df_dedup["manual_caption_languages"]
main_df_dedup["std_man_cap_langs"] = main_df_dedup["std_man_cap_langs"].apply(standardize_dialects)
# Out:
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_1523/1072421247.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_df_dedup["std_man_cap_langs"] = main_df_dedup["manual_caption_languages"]
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_1523/1072421247.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_df_dedup["std_man_cap_langs"] = main_df_dedup["std_man_cap_langs"].apply(standardize_dialects)

# %%
condition = (
    main_df_dedup["std_man_cap_langs"]
    .str.split(",")
    .apply(lambda lst: set(lst) == {"en"})
) & (main_df_dedup["automatic_caption_orig_language"] == "en")
only_en_man_auto = main_df_dedup[condition]

# %%
with open("logs/data/download/2M_en/2M_download_ids.txt", "r") as f:
    id_downloaded_2M = [line.strip().split("\t")[0] for line in f]

# %%
with open("logs/data/download/6M_en/subsampled_ids.txt", "r") as f:
    id_downloaded_6M = [line.strip() for line in f]

# %%
all_ids = only_en_man_auto["id"]

# %%
set(id_downloaded_2M) - set(all_ids)
# Out:
# set()

# %%
with open("logs/data/download/4M_en/subsampled_ids.txt", "r") as f:
    id_downloaded_4M = [line.strip() for line in f]

# %%
set(id_downloaded_4M) - set(all_ids)
# Out:
# set()

# %%
len(set(id_downloaded_4M) - set(id_downloaded_6M))
# Out:
# 4000000

# %%
with open("logs/data/download/6M_en/6M_trainable.txt", "r") as f:
    id_trainable_6M = [line.strip() for line in f]

# %%
len(id_trainable_6M)
# Out:
# 5284868

# %%
df_1 = main_df_dedup[main_df_dedup['id'].isin(id_trainable_6M)]

# %%
df_1["man_cap_langs_2"] = df_1["manual_caption_languages"]
condition = (
        df_1["man_cap_langs_2"]
        .str.split(",")
        .apply(lambda lst: set(lst) == {"en"})
    ) & (df_1["automatic_caption_orig_language"] == "en")
df_2 = df_1[condition]
# Out:
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_1523/4027748111.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1["man_cap_langs_2"] = df_1["manual_caption_languages"]

# %%
df_2.shape[0]
# Out:
# 1728307

# %%
df_1["std_man_cap_langs"] = df_1["manual_caption_languages"]
df_1["std_man_cap_langs"] = df_1["std_man_cap_langs"].apply(standardize_dialects)
condition = (
        df_1["std_man_cap_langs"]
        .str.split(",")
        .apply(lambda lst: set(lst) == {"en"})
    ) & (df_1["automatic_caption_orig_language"] == "en")
df_3 = df_1[condition]
# Out:
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_1523/3348326071.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1["std_man_cap_langs"] = df_1["manual_caption_languages"]
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_1523/3348326071.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1["std_man_cap_langs"] = df_1["std_man_cap_langs"].apply(standardize_dialects)

# %%
df_3.shape
# Out:
# (3191446, 36)

# %%
df_3.shape[0]
# Out:
# 3191446

# %%
with open("logs/data/download/4M_en/4M_trainable.txt", "r") as f:
    id_trainable_4M = [line.strip().split(" ")[0] for line in f]

# %%
df_4 = main_df_dedup[main_df_dedup['id'].isin(id_trainable_4M)]

# %%
df_4["man_cap_langs_2"] = df_4["manual_caption_languages"]
condition = (
        df_4["man_cap_langs_2"]
        .str.split(",")
        .apply(lambda lst: set(lst) == {"en"})
    ) & (df_4["automatic_caption_orig_language"] == "en")
df_5 = df_4[condition]
# Out:
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_25195/2913100492.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4["man_cap_langs_2"] = df_4["manual_caption_languages"]

# %%
df_5.shape[0]
# Out:
# 1933350

# %%
df_5["manual_caption_languages"].unique()
# Out:
# array(['en'], dtype=object)

# %%
with open("logs/data/download/4M_en/4M_trainable_mod.txt", "w") as f:
    for video_id in df_5["id"].values.tolist():
        f.write(video_id + "\n")

# %% [markdown]
# ### Debugging (part 2)

# %%
with open("logs/data/download/4M_en/4M_trainable_bad.txt", "r") as f:
    id_trainable_4M_bad = [line.strip().split(" ")[0] for line in f]

# %%
with open("logs/data/download/4M_en/shuffled_subsampled_batches.jsonl", "r") as f:
    ids_lang_tpl_list = [json.loads(line.strip())["videoIds"] for line in f]

# %%
ids_lang_tpl_list[0]
# Out:
# [['CpqFbRHQ4u0', 'en-SUqXwpdmyfE'],
#  ['acHsTL-bGE0', 'en-nP7-2PuUl7o'],
#  ['XlzA78sVUcw', 'en'],
#  ['ZupL8HxoSRA', 'en'],
#  ['jCvdxiTm6qM', 'en-uYU-mmqFLq8'],
#  ['yiWXOwrVITY', 'en-US'],
#  ['j9l_OFYuDtM', 'en-uYU-mmqFLq8'],
#  ['UoOMKnzYcNU', 'en'],
#  ['yx7e8Oi-8dQ', 'en'],
#  ['-esQO8EqlGc', 'en'],
#  ['yGrXM9v2JLQ', 'en'],
#  ['aYMOIrScCg0', 'en-uYU-mmqFLq8'],
#  ['BZJ4yMKK96s', 'en'],
#  ['9Ud1oYgf-Gk', 'en'],
#  ['Zl2_koMI5ns', 'en'],
#  ['CSV1teyQKj8', 'en-uYU-mmqFLq8'],
#  ['8xBhsHbEfbo', 'en-US'],
#  ['2GNcGt9mFQs', 'en-nP7-2PuUl7o'],
#  ['A4wjXqyMCtU', 'en'],
#  ['5RnJ8Qs7xzM', 'en'],
#  ['0t0FfURt0Xs', 'en-US'],
#  ['XcOSh2hF1nw', 'en-US'],
#  ['i-reXVO2FpY', 'en'],
#  ['9WAMMi_yIzI', 'en-uYU-mmqFLq8'],
#  ['BYPASyonibk', 'en-US'],
#  ['cI1viD2hiLI', 'en-LUU0EuDKgKo'],
#  ['37f_qFubHAM', 'en-US'],
#  ['rE0kUQwqwv4', 'en'],
#  ['cvvoZ9Or0xo', 'en-uYU-mmqFLq8'],
#  ['6lBZ4eUUA-w', 'en'],
#  ['d8qUCEY__Ys', 'en-uYU-mmqFLq8'],
#  ['iyUm25vNQ9A', 'en-US'],
#  ['dPhbUavjSKc', 'en'],
#  ['E_VQwBN5XSI', 'en-GB'],
#  ['qRU1dWQlO4s', 'en-US'],
#  ['RSxtEXqobrc', 'en'],
#  ['yxO5e6tcdWQ', 'en-US'],
#  ['KNcZ4IYf47Q', 'en-uYU-mmqFLq8'],
#  ['j1w2f26iQEI', 'en-GB'],
#  ['jDDiuAgPy3M', 'en-uYU-mmqFLq8'],
#  ['vcSs3iNpxGU', 'en-nP7-2PuUl7o'],
#  ['_L_yb781iI4', 'en-uYU-mmqFLq8'],
#  ['pO_TMjAxQSg', 'en-US'],
#  ['doa28-YrTBQ', 'en-JkeT_87f4cc'],
#  ['HFDJDmgIZ3k', 'en'],
#  ['hkWJMqGzgMw', 'en'],
#  ['kgdFNgySMj4', 'en-Fu8PMtSvQF4'],
#  ['xBIEIKFMo6g', 'en-GB'],
#  ['0O2AlxocZ60', 'en'],
#  ['qR41sLd8xZ8', 'en-GB'],
#  ['kZUX5ZD-qaI', 'en'],
#  ['QwiSt0eBXiw', 'en'],
#  ['GTOzZCUlnmg', 'en'],
#  ['WY-KN1cO4M4', 'en-US'],
#  ['fiE_V4tNjXk', 'en-US'],
#  ['whyUtRypkS0', 'en-Rn4wFefFgng'],
#  ['xG8mQA7DtSc', 'en-uYU-mmqFLq8'],
#  ['GRftBW0KB-c', 'en-uYU-mmqFLq8'],
#  ['ah5Uy9Z3R88', 'en'],
#  ['beuOG00sDjY', 'en-uYU-mmqFLq8'],
#  ['HbpR0mCzjfU', 'en-US'],
#  ['cymogGp2Mpk', 'en-nP7-2PuUl7o'],
#  ['bsC3k4cnbf8', 'en'],
#  ['qEB8LjgG3Jo', 'en'],
#  ['PugTe8cuQTc', 'en'],
#  ['WJJjp_x1JIg', 'en'],
#  ['6mfkWEONP1Q', 'en-nP7-2PuUl7o'],
#  ['zrLChHm3LRg', 'en'],
#  ['6ohSi4ogVAw', 'en-US'],
#  ['8SW7-pqVLW8', 'en'],
#  ['c4zEhkSFigY', 'en'],
#  ['JxxFiGT9d_w', 'en'],
#  ['CChOqII6uPc', 'en-uYU-mmqFLq8'],
#  ['uEhbpAt2TT8', 'en-GB'],
#  ['uA2uqyiPNfg', 'en'],
#  ['g2EE4YkMR84', 'en'],
#  ['tBanLdTL5nI', 'en-uYU-mmqFLq8'],
#  ['6AKzkaN1iE0', 'en-US'],
#  ['Z-yx2k5tv5w', 'en'],
#  ['LpaOwSJSpFs', 'en'],
#  ['UVEitkUHIck', 'en-nP7-2PuUl7o'],
#  ['nSMCMZo_Zsc', 'en'],
#  ['lpT5xd3KE-E', 'en-l3E-OcoDogs'],
#  ['9x7ujcRUnog', 'en'],
#  ['XHSumkIFDtw', 'en-uYU-mmqFLq8'],
#  ['8xlt0Oe7fSw', 'en'],
#  ['zU0Op0V0MTM', 'en'],
#  ['JzwgT2nAsKY', 'en-nP7-2PuUl7o'],
#  ['Q0k73jmoEj8', 'en-1oAFzPNiuC0'],
#  ['47qWvqKNotM', 'en-uYU-mmqFLq8'],
#  ['fKvHJFtPD8o', 'en-US'],
#  ['F_uYZjxxC38', 'en-US'],
#  ['JKnqfwr8hrg', 'en'],
#  ['Lj80daNf7io', 'en'],
#  ['EQYRhLyj91M', 'en'],
#  ['woD6eCDUyg8', 'en'],
#  ['GsJlP0gvbsQ', 'en-nP7-2PuUl7o'],
#  ['9UHXEwDAb3k', 'en'],
#  ['iLGl80d9Hy4', 'en'],
#  ['R11dalGB-qQ', 'en'],
#  ['BoHYlDBHIGY', 'en'],
#  ['vsE54kD3m-I', 'en'],
#  ['nrpTED_MzHw', 'en-uYU-mmqFLq8'],
#  ['5mEh52xkMnc', 'en-uYU-mmqFLq8'],
#  ['JSBUXNCGLd4', 'en'],
#  ['y6SNQw7Rg74', 'en-US'],
#  ['w9b3CS7SpWY', 'en'],
#  ['siTQXmm1oIQ', 'en-US'],
#  ['ZRQlpDBeAA8', 'en-nP7-2PuUl7o'],
#  ['0e5qt15IGV0', 'en'],
#  ['Vbl7z4G97XY', 'en-uYU-mmqFLq8'],
#  ['BJG4BHGF8zU', 'en-RTbB2cpHawQ'],
#  ['tyS72dsB4bI', 'en'],
#  ['tEIBF9zrz9g', 'en-US'],
#  ['9GOHeEatKRk', 'en-US'],
#  ['-yIuoSazSSA', 'en-GB'],
#  ['nuXCsZSYt9c', 'en-nP7-2PuUl7o'],
#  ['2ELvZlJ278Y', 'en'],
#  ['o8H_nyD01co', 'en-cvfXDfbeED0'],
#  ['IAfMBWlWpLs', 'en'],
#  ['QVPPGjxtl6Q', 'en'],
#  ['p_zrJlXC8_E', 'en-GB'],
#  ['Oe5MsYXEB5U', 'en-uYU-mmqFLq8'],
#  ['_Bo8bgw8KPw', 'en'],
#  ['qGmhqFy2QI0', 'en'],
#  ['s3dL6cCagaU', 'en-GB'],
#  ['-uXfwA_XaaU', 'en'],
#  ['UpBJJ5yYaSw', 'en'],
#  ['7mvhgsEe9yw', 'en'],
#  ['nxahqzNLBfU', 'en'],
#  ['QORIgHTq8gI', 'en'],
#  ['0vsPu__6KII', 'en'],
#  ['dGy1K5ri26g', 'en-eEY6OEpapPo'],
#  ['Z5XB9u7OyE8', 'en'],
#  ['1Hw3xHGW--0', 'en'],
#  ['lRWjPdYWJL4', 'en-nP7-2PuUl7o'],
#  ['PCrCqZ_RTf8', 'en'],
#  ['3XBSeHGIVTA', 'en-eEY6OEpapPo'],
#  ['5Xr8XJw467A', 'en'],
#  ['Ow6oz7anpjM', 'en-nP7-2PuUl7o'],
#  ['2I40IfDEZsc', 'en-nP7-2PuUl7o'],
#  ['KER_ToELCM4', 'en-GB'],
#  ['PFV-Scy1FeA', 'en'],
#  ['tZVqG2ZxnFY', 'en-uYU-mmqFLq8'],
#  ['9dunbzrmEk4', 'en'],
#  ['XKk_lQ6S7t0', 'en'],
#  ['nlJ_I33QaVY', 'en-US'],
#  ['tDT7fZnZodc', 'en-KG216eMdtEE'],
#  ['1Ew9yDp8RZs', 'en'],
#  ['zWtiweJtHKo', 'en-uYU-mmqFLq8'],
#  ['Q6uFKlzQs7c', 'en'],
#  ['pDiIGxG2SCg', 'en-US'],
#  ['CMla4q_W-tc', 'en'],
#  ['qNvZky1vASA', 'en-uYU-mmqFLq8'],
#  ['CrGHGwH2wlg', 'en'],
#  ['Fmv6cXeXaUM', 'en-uYU-mmqFLq8'],
#  ['1u4ujuLGevU', 'en'],
#  ['u6uadbTYPls', 'en'],
#  ['QmUYL8e9gjw', 'en-ehkg1hFWq8A'],
#  ['37oPMUC0qXA', 'en-nP7-2PuUl7o'],
#  ['8jZJS273g3U', 'en-j3PyPqV-e1s'],
#  ['GOOmalRan6U', 'en'],
#  ['o7jjCvr4RtI', 'en'],
#  ['B44Sd5dHDbg', 'en'],
#  ['KnZkIxbBKRw', 'en-1oAFzPNiuC0'],
#  ['v6cCGva8SL0', 'en'],
#  ['qhZRrtU2D5M', 'en'],
#  ['7JIhweByZtM', 'en'],
#  ['EfYuVUTkt7k', 'en'],
#  ['2INWDKj_UKM', 'en-JkeT_87f4cc'],
#  ['il3x1Y21X5I', 'en'],
#  ['DVM4PMbdcaM', 'en'],
#  ['rvIi7Zn8u0I', 'en-uYU-mmqFLq8'],
#  ['VsGITySlq5c', 'en-uYU-mmqFLq8'],
#  ['agFpLT4Lh8Q', 'en'],
#  ['Kgyc8Knh88k', 'en-uYU-mmqFLq8'],
#  ['WP6M354Q88Y', 'en-uYU-mmqFLq8'],
#  ['5ZelWHxkQAU', 'en-AU'],
#  ['U0jr3uy2BPE', 'en'],
#  ['wlWdA4pEODA', 'en'],
#  ['hL-YnDXa4fo', 'en'],
#  ['Q8uXJBiAj00', 'en'],
#  ['tCg8D1OLAMY', 'en-uYU-mmqFLq8'],
#  ['VtiW3fArZ8g', 'en-CA'],
#  ['uyc9lzCp1EM', 'en'],
#  ['9LF-jkDbS8o', 'en'],
#  ['qhyZOtOG1Iw', 'en'],
#  ['10NQ5T6Nj-U', 'en'],
#  ['qyKmCZl4HpU', 'en'],
#  ['uPYwKOwQW14', 'en'],
#  ['c3Z44P9GwHA', 'en'],
#  ['T9ubOMg1XX8', 'en'],
#  ['bF1qAxxIEqI', 'en'],
#  ['Y1RZZvJfoNQ', 'en-nP7-2PuUl7o'],
#  ['z7Z6Zhe0w-8', 'en'],
#  ['Zs5pbL1u5e8', 'en-US'],
#  ['Np1pxLCiMsU', 'en'],
#  ['nCTpzRdeX1g', 'en'],
#  ['bhUasXKGqM0', 'en-US'],
#  ['foLakeYugpg', 'en'],
#  ['u3sXjwePY-c', 'en'],
#  ['kCxinQyHQBg', 'en-nP7-2PuUl7o'],
#  ['r4Ru6h_Pf0A', 'en-US'],
#  ['8q0p6TxTqJI', 'en-IN'],
#  ['RLqc3Vtt2E8', 'en'],
#  ['33C3xF9Nxpk', 'en-vlW2OHFw3ww'],
#  ['V178pc7u-E0', 'en-JkeT_87f4cc'],
#  ['SYZDmwYM7nk', 'en'],
#  ['ohwrTS0fNc8', 'en-nP7-2PuUl7o'],
#  ['AXhrmg58f2s', 'en-JkeT_87f4cc'],
#  ['Fzcui5zaNyY', 'en'],
#  ['H9sNIiMcF3w', 'en-GB'],
#  ['TmafdWfkvAY', 'en-uYU-mmqFLq8'],
#  ['3RTrq0aiDnk', 'en-uYU-mmqFLq8'],
#  ['9uF4ZlU0V40', 'en'],
#  ['yyITM66-jj4', 'en-uYU-mmqFLq8'],
#  ['Rx1YHAnowwo', 'en-US'],
#  ['0KgwzBoQOko', 'en-US'],
#  ['xkMGuF7Q2DA', 'en-US'],
#  ['3_6kwqP1kGU', 'en-GB'],
#  ['Fz5HAUTbqsc', 'en-nP7-2PuUl7o'],
#  ['Pq_D9lFSs4o', 'en-JkeT_87f4cc'],
#  ['onCFCmEm6Uw', 'en'],
#  ['kFSEQxSFGpM', 'en'],
#  ['qaHwzTJixxY', 'en-RTbB2cpHawQ'],
#  ['cTBuf-pJsm4', 'en'],
#  ['fu8C5fXPqQg', 'en-uYU-mmqFLq8'],
#  ['tjJXWVLd2D0', 'en-GB'],
#  ['e22V28av1ek', 'en'],
#  ['FoGcK2bqXIc', 'en-nP7-2PuUl7o'],
#  ['l46Mf72h5is', 'en'],
#  ['n5CKLQwApcQ', 'en-anMIXjicSL4'],
#  ['XKXYxuzw6a0', 'en-nP7-2PuUl7o'],
#  ['RzCwjkUPKGU', 'en-US'],
#  ['6etENAQo9Is', 'en'],
#  ['Wtb0totOXcI', 'en-GLTvy4jNFQs'],
#  ['ko1zmf7EiMk', 'en'],
#  ['B_tNbZQkvQQ', 'en-US'],
#  ['rBmVh21gTSU', 'en'],
#  ['H89IlAYEnO4', 'en'],
#  ['QY3lYwJl3P8', 'en'],
#  ['6kWuKXQ7YVs', 'en'],
#  ['gg3IFyl592E', 'en'],
#  ['Dua3jepLw0k', 'en-GB'],
#  ['lGc1YFifSec', 'en'],
#  ['U_nIABuBNW0', 'en'],
#  ['f5DN80d614w', 'en'],
#  ['i0sQ7U8pNZI', 'en'],
#  ['hMLFi5mbznY', 'en'],
#  ['PtYkMsRBXWo', 'en']]

# %%
from itertools import chain
ids_lang_tpl_list = list(chain(*ids_lang_tpl_list))
len(ids_lang_tpl_list)
# Out:
# 4000000

# %%
id_to_lang = {}
for tpl in ids_lang_tpl_list:
    id_to_lang[tpl[0]] = tpl[1]

# %%
id_to_lang_bad_4M = {}
for id in id_trainable_4M_bad:
    id_to_lang_bad_4M[id] = id_to_lang[id]

# %%
len(id_to_lang_bad_4M)
# Out:
# 1636616

# %%
id_to_lang_bad_4M
# Out:
# {'gARhAiWfgQk': 'en-uYU-mmqFLq8',
#  'Imj66qr5GKc': 'en-nP7-2PuUl7o',
#  '7D2Ar1Sfl90': 'en-uYU-mmqFLq8',
#  'OitkJWm2bII': 'en-vlW2OHFw3ww',
#  '1CSiCftovHo': 'en-8we0KTnfFCk',
#  'r6o_JVqaJgc': 'en-nP7-2PuUl7o',
#  'xuUq8srwES0': 'en-US',
#  '-IGoZ35FHDE': 'en-uYU-mmqFLq8',
#  'WE_pi17usnQ': 'en-uYU-mmqFLq8',
#  'IaJYMIeGq9E': 'en-U5ILRQKRVmc',
#  '4q-BByqHORA': 'en-DgTNZJhXds8',
#  '-7jfsU3Kswo': 'en-nP7-2PuUl7o',
#  'VXru3bhJRK4': 'en-nP7-2PuUl7o',
#  '8D2m38q5JLU': 'en-uYU-mmqFLq8',
#  'i4-1sZUzHJQ': 'en-uYU-mmqFLq8',
#  'eDuLdz-dD0Q': 'en-uYU-mmqFLq8',
#  'uzlq2TiVz2g': 'en-US',
#  'qO7VucjhcAo': 'en-nP7-2PuUl7o',
#  '8JUPqtkzR60': 'en-GB',
#  'FjKEpQuII5k': 'en-nP7-2PuUl7o',
#  'QgoOfCxKkgc': 'en-GB',
#  'e8nXqz5D5-I': 'en-nP7-2PuUl7o',
#  '_X7CqCNHdY0': 'en-US',
#  'b6bd7leQvz4': 'en-US',
#  'CZtOR4_F7fA': 'en-uYU-mmqFLq8',
#  'PxVj7FnCVnQ': 'en-j3PyPqV-e1s',
#  '3GejB11e9Zg': 'en-uYU-mmqFLq8',
#  'UB4YY5asVfc': 'en-nP7-2PuUl7o',
#  'ige9pq_mTkc': 'en-uYU-mmqFLq8',
#  '61oqInPEBPM': 'en-uYU-mmqFLq8',
#  'Z2LE_bHQKvs': 'en-CA',
#  '66N2zXN4t8k': 'en-nP7-2PuUl7o',
#  'Sy1_UmblZ-I': 'en-JkeT_87f4cc',
#  'GIDGN073vFA': 'en-uYU-mmqFLq8',
#  'yACoSpCTfmw': 'en-uYU-mmqFLq8',
#  'UUbJYoZmiZw': 'en-uYU-mmqFLq8',
#  'l8kb91ocQdA': 'en-GB',
#  '7WJHCfey71M': 'en-uYU-mmqFLq8',
#  'h7bs878CMmA': 'en-uYU-mmqFLq8',
#  'R7dYCiUqONY': 'en-R3bQkW-GLU4',
#  '7ATGWsClZUo': 'en-nP7-2PuUl7o',
#  'PFWNYCKBj_A': 'en-US',
#  'cKL8Xkv3NSk': 'en-s77dJF71-Co',
#  'Hwy_P372kQk': 'en-GB',
#  'dx6btbYPWIg': 'en-01ofOkYcM-Y',
#  'kN6Ioa_Q6n0': 'en-uYU-mmqFLq8',
#  'ZW6qQWpYLXQ': 'en-US',
#  'f0Au6-pNsAg': 'en-US',
#  'iIJeFyh9p3U': 'en-vlW2OHFw3ww',
#  '406S2lrEy70': 'en-US',
#  'fgHperEeErE': 'en-qoXxhA4oLYo',
#  't6G66fvx-Qc': 'en-nP7-2PuUl7o',
#  'Azy0-6gtkNY': 'en-US',
#  'ulEV5OykinI': 'en-eEY6OEpapPo',
#  'WBSdsINYFO4': 'en-US',
#  'mvpHKabs664': 'en-US',
#  'S9gzsqdYEWc': 'en-IN',
#  '_618k1qVoHk': 'en-ehkg1hFWq8A',
#  'T4b1fHAbOFc': 'en-uYU-mmqFLq8',
#  'l-IE0KkVLHE': 'en-GB',
#  'CcK3ti8_lpg': 'en-uYU-mmqFLq8',
#  '-qWIrxvKpbM': 'en-uYU-mmqFLq8',
#  'KytAq0RBhuE': 'en-GB',
#  'O23CUVINK80': 'en-uYU-mmqFLq8',
#  '7-CHyKjNBNw': 'en-US',
#  'EfWpdU7CzOs': 'en-nP7-2PuUl7o',
#  'JP4nezpWb30': 'en-uYU-mmqFLq8',
#  'X7vaLDVFfjA': 'en-uYU-mmqFLq8',
#  '2NENBlCEd9M': 'en-US',
#  'gWsYZIb_HtA': 'en-GB',
#  'yP-Ej2rvmS4': 'en-US',
#  'y9ulOWZHmME': 'en-US',
#  'CH-jzC3Epqw': 'en-JkeT_87f4cc',
#  'zeRsfzXcUVw': 'en-GB',
#  'Ut1wzhG9Xf0': 'en-JkeT_87f4cc',
#  'xl6TLs1LNZI': 'en-uYU-mmqFLq8',
#  'buwey1MkOh0': 'en-JkeT_87f4cc',
#  'QvzT9blY6Zo': 'en-GB',
#  'uga2Az4nYmA': 'en-US',
#  '8pAcOX18UQY': 'en-US-vML_eHX69kQ',
#  '__6XogzLUII': 'en-uYU-mmqFLq8',
#  'U6Z3J9HehYw': 'en-uYU-mmqFLq8',
#  'fcwxIBf4Yhk': 'en-US',
#  'FmqwV57gm5M': 'en--yQzTQoq_tY',
#  '6zX4JNY96XU': 'en-JkeT_87f4cc',
#  '6wtoQ0Us4mA': 'en-qoXxhA4oLYo',
#  'SAk9I6bd1sI': 'en-JkeT_87f4cc',
#  'mAu5kaXY77c': 'en-uYU-mmqFLq8',
#  'hUk_GCwuYR8': 'en-uYU-mmqFLq8',
#  'gxCu5TEmxXE': 'en-j3PyPqV-e1s',
#  'mVfqyDRRul4': 'en-nP7-2PuUl7o',
#  'zvRkGtrvgIY': 'en-US',
#  'Kyq7qIp4LLQ': 'en-US',
#  'xDNhdszoGGQ': 'en-nP7-2PuUl7o',
#  'KssNHxTHsuM': 'en-uYU-mmqFLq8',
#  'EYpgraf1YBI': 'en-GB',
#  'RC3DL60vF5E': 'en-nP7-2PuUl7o',
#  '4B7mGeVUqjs': 'en-1oAFzPNiuC0',
#  'bX645s7x7mw': 'en-uYU-mmqFLq8',
#  'GNR40IZ4XdI': 'en-Ykt5-cacvZU',
#  '_NpzsNZIJIU': 'en-GB',
#  'tw2Plnjkab4': 'en-nP7-2PuUl7o',
#  't5ymuzwqUkA': 'en-US',
#  'p2k3p9D387Q': 'en-uYU-mmqFLq8',
#  'O6pfD9uA0Ko': 'en-ehkg1hFWq8A',
#  'OS1hivvnhYI': 'en-uYU-mmqFLq8',
#  'Cu6DOfuKQOE': 'en-uYU-mmqFLq8',
#  'xA7tEtf9qts': 'en-ehkg1hFWq8A',
#  'e2ghnqwxkT0': 'en-US',
#  'zhrxE44pN68': 'en-US',
#  'KMmQntlFjQ0': 'en-uYU-mmqFLq8',
#  'wtWxWyfeSAw': 'en-q201XhIS8GY',
#  'dyCVeDZVLsI': 'en-uYU-mmqFLq8',
#  'MoqjXx8aKz4': 'en-US',
#  '-MbQZwss6IA': 'en-uYU-mmqFLq8',
#  'wi77z6zn6JI': 'en-kxGyRVAS94M',
#  'bUeu9PW_Neg': 'en-GB',
#  'TgDsHAdMIbc': 'en-nP7-2PuUl7o',
#  '3QwAl4T5s4w': 'en-GB',
#  '5ZLi1QGDVek': 'en-US',
#  'ptbbAQMSzv4': 'en-US',
#  'hNcydyY01YY': 'en-US',
#  'APRWopxiu60': 'en-US',
#  'mj7PQFl3afU': 'en-US',
#  'WQLYNdIh1Og': 'en-szusfkNFjsg',
#  'j8Qy-2YTl1U': 'en-ehkg1hFWq8A',
#  'OPnzxK549OQ': 'en-US-8-mTs6Ce2js',
#  'STxZFWUZI6w': 'en-US',
#  'n4qQ0Ev_SLE': 'en-nP7-2PuUl7o',
#  '2K5uZ1gK0sE': 'en-JkeT_87f4cc',
#  'tea0C7zm6TQ': 'en-GB',
#  'JueX4biivOM': 'en-uYU-mmqFLq8',
#  '8yahL6ajnQg': 'en-GB',
#  '_vf638j69nQ': 'en-nP7-2PuUl7o',
#  '0k3ozTszI1A': 'en-GB',
#  'NCbdsGgQN3k': 'en-uYU-mmqFLq8',
#  '4-UwNvAkLR8': 'en-IN',
#  '6hB29Er8jCE': 'en-GB',
#  '84iixulMiyc': 'en-US',
#  '2eSzpi8Wybk': 'en-uYU-mmqFLq8',
#  'yGqI57mOBvw': 'en-ixP_xQzbhRo',
#  '8_w4kCOxNOU': 'en-vlW2OHFw3ww',
#  'QujNXR-rhbE': 'en-GB',
#  'xP1KVXsglEg': 'en-uYU-mmqFLq8',
#  'nW1RvoWU72I': 'en-US',
#  'hAu0Gu9foFI': 'en',
#  'zeH5BPh68QE': 'en-GB',
#  '7YfGeOO2Vqg': 'en-uYU-mmqFLq8',
#  '8aS2AqIfqcU': 'en-US',
#  'M-YglOxkuGc': 'en-US',
#  'yxjjp_Xvu38': 'en-nP7-2PuUl7o',
#  'iWG0vqhAWyE': 'en-uYU-mmqFLq8',
#  'PLw0Hi9e0a0': 'en-uYU-mmqFLq8',
#  'A2-g2gmigYg': 'en-uYU-mmqFLq8',
#  'v2caPdd3Spk': 'en-US',
#  'Ip9HZ0tqUX0': 'en-uYU-mmqFLq8',
#  'AMmN4-gNVIQ': 'en-US',
#  't8k-QpEyGV0': 'en-JkeT_87f4cc',
#  'ZTy-B9pVATg': 'en-cn8DiSNOAWQ',
#  'ueSEqMJH1IU': 'en-rX01gsAdUfU',
#  'yp0MFt2pQr0': 'en-nP7-2PuUl7o',
#  'PklJnJXpaQ8': 'en-US-4hYNYihg0Uc',
#  'Tlhd_qmFne0': 'en-US',
#  'g5lajUnWONE': 'en-nP7-2PuUl7o',
#  'klEq9BOXbH0': 'en-US',
#  'bldhgV1fzRk': 'en-US',
#  'SNnXo8DvDhw': 'en-nP7-2PuUl7o',
#  'Zd8zVs7iZ4o': 'en-uYU-mmqFLq8',
#  'vcJYA1xI6_M': 'en-US',
#  'GHH93P9lSSo': 'en-GB',
#  '3w3Si1dYWvA': 'en-uYU-mmqFLq8',
#  '65igT7ZM5WY': 'en-ehkg1hFWq8A',
#  'VhulGFGWqQQ': 'en-uYU-mmqFLq8',
#  'mxgBAIYtP0k': 'en-US-eEY6OEpapPo',
#  'as02tEchQfo': 'en-ehkg1hFWq8A',
#  'HM6Dmywl30s': 'en-GB',
#  'C2anjywq5qY': 'en-uYU-mmqFLq8',
#  '74GskJyOH6c': 'en-uYU-mmqFLq8',
#  'wspIRcha03c': 'en-uYU-mmqFLq8',
#  'TGV5oke_R3I': 'en-uYU-mmqFLq8',
#  'H0hYSmfUpJk': 'en-US',
#  'jlLWs6X2SNU': 'en-ehkg1hFWq8A',
#  'MhYT_2M0680': 'en-JkeT_87f4cc',
#  'qyQ3BQkOtVU': 'en-QI0tuGaiba8',
#  'Dq7vVDY8gxg': 'en-US',
#  'gWChU9eqSlY': 'en-uYU-mmqFLq8',
#  'TQECElbZFCM': 'en-GB',
#  'MraGmz1Mgh8': 'en-US',
#  '4NUqedGL3vA': 'en-GB',
#  'YGwJsdAem8o': 'en-US',
#  'dz1R2fpbj_Q': 'en-uYU-mmqFLq8',
#  '3gfRefWPXUU': 'en-eEY6OEpapPo',
#  '3GspUUMqdw4': 'en-nP7-2PuUl7o',
#  'EF1COfX0lvc': 'en-nP7-2PuUl7o',
#  '85bLHloyK5I': 'en-ehkg1hFWq8A',
#  'vlyATIZUd20': 'en-uYU-mmqFLq8',
#  'Dcl0hj7_Idw': 'en-ehkg1hFWq8A',
#  'LBa0nkHV7qs': 'en-GB',
#  'FgtYDVsIFuk': 'en-ZG2nU9fW6eE',
#  'F0omt1EJC0c': 'en-nP7-2PuUl7o',
#  'qg7WlvLBDJA': 'en-j3PyPqV-e1s',
#  'usLMVEYg0ms': 'en-nP7-2PuUl7o',
#  'TYrsMXPZJnk': 'en-US',
#  'VITEGn6T_u4': 'en-uYU-mmqFLq8',
#  'O-Vxe-IUoD4': 'en-uYU-mmqFLq8',
#  'rzb32U4gZx0': 'en-US-9Qudf-V9AKA',
#  'wGvTSNJP-EE': 'en-Q8VSUiGLCHE',
#  'C7UblfCsbqM': 'en-BASGHn3chTo',
#  'r-zRDNZlw14': 'en-US',
#  'cme58OmMKCc': 'en-uYU-mmqFLq8',
#  'bfNqI1WVy5o': 'en-uYU-mmqFLq8',
#  'Ua5xVHwV7pI': 'en-uYU-mmqFLq8',
#  'cqYMaN-DHfU': 'en-nP7-2PuUl7o',
#  'zUPs5TPzi6g': 'en-US',
#  'u6KEbcDzteY': 'en-j3PyPqV-e1s',
#  'kbDgJIhld7U': 'en-uYU-mmqFLq8',
#  '1sLTDTjV7c0': 'en',
#  'gYtTK30Tbmk': 'en-US',
#  'xi_xhUnTa_k': 'en-uYU-mmqFLq8',
#  'oTxFauUD97U': 'en-US--cGUVPQbq5U',
#  'FqCDaL-cSlA': 'en-VjEpQ-RlAYk',
#  'IBQGUGbg3AA': 'en-JkeT_87f4cc',
#  'lI25JYWwUm8': 'en-j3PyPqV-e1s',
#  'yQok_ADKMoE': 'en-nP7-2PuUl7o',
#  'vAtWHSWNHas': 'en-uYU-mmqFLq8',
#  'mIUbMqmIO5w': 'en-j3PyPqV-e1s',
#  '4WIQqQ0Rj4I': 'en-nP7-2PuUl7o',
#  'sCsR8jU9tag': 'en-uYU-mmqFLq8',
#  'q3VycbflgKc': 'en-uYU-mmqFLq8',
#  'HEDlLV46UYA': 'en-uYU-mmqFLq8',
#  'eXM9rvoJHc0': 'en-uYU-mmqFLq8',
#  'jM9laCrDE-I': 'en-uYU-mmqFLq8',
#  'T14Y5wmwovA': 'en-US',
#  'iluwt4AukNA': 'en-nP7-2PuUl7o',
#  'w9jrgCTsRBU': 'en-eEY6OEpapPo',
#  'UMWyHVlwlhc': 'en-uYU-mmqFLq8',
#  'BDR8jwPVBbQ': 'en-uYU-mmqFLq8',
#  'vw2NKpU0vY4': 'en-nP7-2PuUl7o',
#  'LMnnP1aaif0': 'en-nP7-2PuUl7o',
#  '4amq43c0h9E': 'en-2APL__RorAs',
#  'GtFSzw9K6Qk': 'en-uYU-mmqFLq8',
#  '87fMfMlEEeI': 'en-rX01gsAdUfU',
#  'VAwbf5X_aLI': 'en-US',
#  'StnA4U0jKq8': 'en-JkeT_87f4cc',
#  '5aQ8rafQf0c': 'en-ehkg1hFWq8A',
#  'gwpitMsN3cw': 'en-gMxbn-ruv10',
#  'sjBTnWtyfuk': 'en-IN',
#  '8pNOk4f9k1w': 'en-uYU-mmqFLq8',
#  'xxPc3t5Weis': 'en-GB',
#  'G92KMciyO9c': 'en-GB',
#  '5VVNASKjiI4': 'en-US',
#  'q9DiouX8TJQ': 'en-uYU-mmqFLq8',
#  'hZGCsI_C25M': 'en-uYU-mmqFLq8',
#  'rD__-0Kz51g': 'en-nP7-2PuUl7o',
#  'lGoHIONFS1s': 'en-xDsBn_4-J90',
#  '7dil2yqxmaY': 'en-GB',
#  'yRaQPDpp_58': 'en-US',
#  'oifSd23wQtQ': 'en-34AnZ-gERTE',
#  '7xL07rzaCNM': 'en-nP7-2PuUl7o',
#  'j8Iji2JbNPE': 'en-rX01gsAdUfU',
#  'JUDW6i8SbXo': 'en-uYU-mmqFLq8',
#  'lMf-MKjQUPI': 'en-US',
#  'NFW6uVQXZw8': 'en-rX01gsAdUfU',
#  'jhwTGznqeEo': 'en-US',
#  'EK4KaHGKPBc': 'en-ehkg1hFWq8A',
#  'wY82eUBd8lk': 'en-US',
#  'Muq9S7mV2e8': 'en-uYU-mmqFLq8',
#  'F8RatoggpBo': 'en-uYU-mmqFLq8',
#  '1ui9xhSL7l4': 'en-nP7-2PuUl7o',
#  'P7RjhuiTJIg': 'en-US',
#  'eQKJ-kPG7ms': 'en-RJD8LYRzd_Y',
#  'sJeYufnIX7Q': 'en-GB',
#  'Mjfp7-tKqMY': 'en-uYU-mmqFLq8',
#  'hqnuZUpLJC4': 'en-uYU-mmqFLq8',
#  '_n1TQhL5ERM': 'en-nP7-2PuUl7o',
#  'YrDfUyBnA40': 'en-US',
#  'SVY5F4xsoew': 'en-US',
#  'ayf6lrAeVIQ': 'en-uYU-mmqFLq8',
#  'Qc2GYVRC1tI': 'en-US',
#  'KQghs9hWits': 'en-nP7-2PuUl7o',
#  'XmK6KJf4KsQ': 'en-9tTD9Uyn490',
#  '9i4k8JtduKk': 'en-JkeT_87f4cc',
#  'NL6q_ZqjoFo': 'en-uYU-mmqFLq8',
#  'E5DlpONIW5M': 'en-US',
#  'nKB6BP3n3XQ': 'en-i7LFIGUQP0g',
#  'dcX2vzUNFCE': 'en-nP7-2PuUl7o',
#  '0EGnKXlYIbU': 'en-uYU-mmqFLq8',
#  'rCkkL9NtzVw': 'en-US',
#  'i6xkzQNg1d0': 'en-GB',
#  'F47w7rxk-OM': 'en-GB',
#  'C_ucylSE6z8': 'en-nP7-2PuUl7o',
#  'srGwbihpGVU': 'en-uYU-mmqFLq8',
#  'Yz5cwZcJL9Y': 'en-GB',
#  'jL9Tfu12gtU': 'en-US',
#  'vSRmcpc-Dvs': 'en-US',
#  'tY8rvI0G3og': 'en--uucv3IT5BM',
#  'rtRy0nbekTg': 'en-nP7-2PuUl7o',
#  '1fCH5uyN2KQ': 'en-uYU-mmqFLq8',
#  'lPEvxfMj7h4': 'en-US',
#  'WQsv7z7S-HM': 'en-nP7-2PuUl7o',
#  'WZhRU1Y1RZw': 'en-GB',
#  'JstkQdcZMwI': 'en-JkeT_87f4cc',
#  'kwqxysVvejY': 'en-JkeT_87f4cc',
#  'Xg9xh9DkVV8': 'en-uYU-mmqFLq8',
#  '7rZG9HV9FjY': 'en-uYU-mmqFLq8',
#  'vFxKtPL38g0': 'en-uYU-mmqFLq8',
#  'hc7PcQ0WAoE': 'en-i7LFIGUQP0g',
#  'Y7pmxtTAEeo': 'en-uYU-mmqFLq8',
#  'Gvev7cBdRQo': 'en-uYU-mmqFLq8',
#  'JZe2ZgVKcXQ': 'en-uYU-mmqFLq8',
#  '6S4NZxTFl8c': 'en-nP7-2PuUl7o',
#  'G1PnCUAIxxo': 'en-mE9PDbMIjjE',
#  'ffsx5yCNrXc': 'en-uYU-mmqFLq8',
#  'vhYnYu4UKJc': 'en-uYU-mmqFLq8',
#  'TZFw3nL4DWU': 'en-uYU-mmqFLq8',
#  'xO_jnRjXXwo': 'en-US',
#  'c7j2_TCwZA4': 'en-US',
#  'PLk8I-FAW5U': 'en-uYU-mmqFLq8',
#  'XRBf1tAmFt0': 'en-uYU-mmqFLq8',
#  'jsG_p53oJ-U': 'en-uYU-mmqFLq8',
#  'Ca_XQxuYQT8': 'en-uYU-mmqFLq8',
#  'rEEKR86iJ_Q': 'en-Vji3DfCwlcc',
#  '3Sf9kPeT2jw': 'en-uYU-mmqFLq8',
#  'lvsiktXGeAc': 'en-cvfXDfbeED0',
#  'QKrWn2eaM9A': 'en-uYU-mmqFLq8',
#  'PoPKeEBto6k': 'en-US',
#  'rAd9Z-iqw7c': 'en-US',
#  'LZYA_iwdNuQ': 'en-JkeT_87f4cc',
#  '0NmQEwx-dYk': 'en-ehkg1hFWq8A',
#  '7aLre7O0bKs': 'en-nP7-2PuUl7o',
#  'hq-r0C7dMj4': 'en-ehkg1hFWq8A',
#  'Ct3DHBztnpA': 'en-GB',
#  'pzyjQPCzB9U': 'en-uUvdYdBmH5Q',
#  'QPK2I0ec6tQ': 'en-US',
#  'kLmY2ECmy7k': 'en-US',
#  'dJJzmyca_QE': 'en-US',
#  'EmU2fotA4Ow': 'en-qoXxhA4oLYo',
#  '_eupwLNkNxE': 'en',
#  'pW3sosviZsI': 'en-Henzc2G1Zw4',
#  'kw-k8_NJppQ': 'en-Q8VSUiGLCHE',
#  'IfcoS21D3kw': 'en-uYU-mmqFLq8',
#  'lY2TO5qF-gI': 'en-nP7-2PuUl7o',
#  'YhMjEgYOBsQ': 'en-nP7-2PuUl7o',
#  'OsGhiW5mDJY': 'en-uYU-mmqFLq8',
#  'nUJw_x-VLN4': 'en-US',
#  'RooRdltO_Jo': 'en-uYU-mmqFLq8',
#  'Du7Z_qK2n3E': 'en-e_PXL4Dh8V8',
#  'NouUNiI-bMQ': 'en-GB',
#  'qvwwYp36eQA': 'en-uYU-mmqFLq8',
#  'YmdrrjhftwI': 'en-uYU-mmqFLq8',
#  'ot589WhNT6w': 'en-US',
#  '0OVW6J1_ivQ': 'en-IN',
#  '53WKdaKFPps': 'en-IN',
#  'ahA30Agl_8s': 'en-CA',
#  'Uyme-wMYshQ': 'en-nP7-2PuUl7o',
#  'LpRSRhZdThY': 'en-uYU-mmqFLq8',
#  'Z5KTo6s-rrs': 'en-uYU-mmqFLq8',
#  'WlEKxzsppX0': 'en-uYU-mmqFLq8',
#  '-iHlA3Ey_9Q': 'en-nP7-2PuUl7o',
#  'uD2k98UjJi0': 'en-ehkg1hFWq8A',
#  'NuXsvGVqegA': 'en-nP7-2PuUl7o',
#  'y_YDZQasYeQ': 'en-uYU-mmqFLq8',
#  '8B4e2Y_z21o': 'en-uYU-mmqFLq8',
#  'iKVIlZSYg68': 'en-US',
#  'IEZ-ikO9XLU': 'en-7avW1qEZYxc',
#  'Z5XzGBs1oEA': 'en-nP7-2PuUl7o',
#  'g9W8gNqn_P0': 'en-eEY6OEpapPo',
#  't8kjCNGOVWc': 'en-US',
#  'rHvaDlmkOcs': 'en-uYU-mmqFLq8',
#  'zuG4Vd0NkGY': 'en-US',
#  '34sjpSzwP5k': 'en-9fkpfT0t9No',
#  'gMbHELih1S8': 'en-GB',
#  '324_L2n2lO4': 'en-nP7-2PuUl7o',
#  '5av4-PgaO8U': 'en-GB',
#  'qbG9OkNrvdA': 'en-US',
#  '-UnQ17P4Ln4': 'en-US',
#  '1bA1-vKcdoA': 'en-ehkg1hFWq8A',
#  'xJ0jH5Ptf3U': 'en-uYU-mmqFLq8',
#  'w7zOjJbnya8': 'en-qlPKC2UN_YU',
#  'X2zB3uxxHKA': 'en-uYU-mmqFLq8',
#  '2PkrGltWV6w': 'en-GB',
#  'ypQz5AyOk8k': 'en-US',
#  'VLrywXf37Ho': 'en-GB',
#  'UlUschqjw4I': 'en-US',
#  'VzabyQVZ2wQ': 'en-uYU-mmqFLq8',
#  'Id8QDAiB4D0': 'en-PsyZA7lWBS0',
#  'pSVROBRVnyg': 'en-US',
#  'JG0Fyqq_kZU': 'en-uYU-mmqFLq8',
#  'VC0FOxZ0TtE': 'en-uYU-mmqFLq8',
#  'Le4WMnxxrdA': 'en-uYU-mmqFLq8',
#  'Kt9wNZrwUTY': 'en-US-zOFsReYi2c4',
#  'xUoUtoNDD8A': 'en-JTHbSiup2Go',
#  'Ci37lbr7QzA': 'en-uYU-mmqFLq8',
#  'MX-ektXHq5A': 'en-US',
#  'wI5k-SfHGyU': 'en-GB',
#  'ClCyT0cpVqw': 'en-GB',
#  'Cs4dkGBfZG8': 'en-US',
#  'yOfGZysL7DQ': 'en-US',
#  'mp-iQ7fdBz8': 'en-uYU-mmqFLq8',
#  'oKbcsXXgsHQ': 'en-uYU-mmqFLq8',
#  'uhJp_x-uhew': 'en-JkeT_87f4cc',
#  '5FBaelCXox0': 'en-uYU-mmqFLq8',
#  'cj4be6BlHQ8': 'en-uYU-mmqFLq8',
#  'dcTGkMyKqDk': 'en-uYU-mmqFLq8',
#  'w1WXmodNeqE': 'en-CA',
#  'C3D-aTDjX8M': 'en-tP1Ag5__1tI',
#  '2goqH94UG8E': 'en-uYU-mmqFLq8',
#  'J3AWQ95_imQ': 'en-uYU-mmqFLq8',
#  'INJhH8RZ3QE': 'en-nP7-2PuUl7o',
#  'ZYzgNVjAKtM': 'en-US',
#  'jzO4T3TDZs0': 'en-PkKT1klUNmE',
#  'noXMAR_smG4': 'en-US',
#  'Asy3ZVgvmgI': 'en-nP7-2PuUl7o',
#  'sv2UQUfK18g': 'en-nP7-2PuUl7o',
#  'FrLbe5lS5Nc': 'en-uYU-mmqFLq8',
#  'GULeXt8XSAo': 'en-eEY6OEpapPo',
#  'WNJoq4VQ_GI': 'en-ehkg1hFWq8A',
#  '-UhFOrTi7ec': 'en-CA',
#  'kAjT4hVX52E': 'en-GB',
#  'yFC66MqQnK8': 'en-uYU-mmqFLq8',
#  'ILd022ro1X4': 'en-uYU-mmqFLq8',
#  'zAJHUv2JS7w': 'en-nP7-2PuUl7o',
#  'xsmjYLWIdJY': 'en-GB',
#  '8gs01a87xkE': 'en-nP7-2PuUl7o',
#  '6yzdPd2o3Cg': 'en-GB',
#  '_Xgrx8G_lTc': 'en-A0nImYYJZk8',
#  'thgJd1qjcqQ': 'en-US',
#  '2A1tK4xClfA': 'en-US',
#  'A5xTsJ5d3gY': 'en-US',
#  'cH6p2-bbTvc': 'en-I-S_gwt8jek',
#  'J-QC07dUlCA': 'en-nP7-2PuUl7o',
#  'Z1-2QUKBwaA': 'en-GB',
#  'Xjrjf11bnYo': 'en-uYU-mmqFLq8',
#  'JRJW3dboG6Y': 'en-uYU-mmqFLq8',
#  'rsEC4yRvi_0': 'en-JkeT_87f4cc',
#  'Hxn1DpeLR2M': 'en-uYU-mmqFLq8',
#  '55wysi1_9Ug': 'en-US',
#  'ACG5b8cnPrs': 'en-US',
#  'iXDiJa2j_Mk': 'en-uYU-mmqFLq8',
#  'RHcap04iQ6w': 'en-uYU-mmqFLq8',
#  'ZZV_13H9iaY': 'en-nP7-2PuUl7o',
#  'ZTNH3wVu668': 'en-IN',
#  'hsPIu_ZFHv0': 'en-uYU-mmqFLq8',
#  '3Uo1tAWekP8': 'en-nP7-2PuUl7o',
#  'R8u1g_2kFQM': 'en-GB',
#  't3FTDUUvFts': 'en-uYU-mmqFLq8',
#  'EoMWyOEXHFc': 'en-uYU-mmqFLq8',
#  'mYDsA87EDWE': 'en-nP7-2PuUl7o',
#  's3AnFiYyQFk': 'en-IN',
#  '57Awxk-12Vk': 'en-uYU-mmqFLq8',
#  '5Fbl-oHbE3o': 'en-uYU-mmqFLq8',
#  'hZ1J64qNIkI': 'en-uYU-mmqFLq8',
#  'aQ8IToR8_hI': 'en-uYU-mmqFLq8',
#  '_pKNoENI65g': 'en-US',
#  '-f9nEv96F2Y': 'en-JkeT_87f4cc',
#  'c9h7tk5wtF0': 'en-nP7-2PuUl7o',
#  'FsnJ6Wyd52k': 'en-US-tlKWArHu0kg',
#  'wZTb19X5-KM': 'en-US',
#  'tPDbUKXVJLs': 'en-uYU-mmqFLq8',
#  '_0bHPiVRkhc': 'en-uYU-mmqFLq8',
#  'g6UzT6-eLk0': 'en-05mG7t8jzIQ',
#  'rEpeJ3bQMU8': 'en-GB',
#  'tOq-Igtd-H4': 'en-uYU-mmqFLq8',
#  'A1zwimqc1e0': 'en-CA',
#  '0VPSMIq3j8U': 'en-CA',
#  'MD3RmIB9Dm4': 'en-uYU-mmqFLq8',
#  'wdmF2mpN7VY': 'en-nP7-2PuUl7o',
#  'JJ27WebKFzE': 'en-uYU-mmqFLq8',
#  'UU2Mx1IsyXY': 'en-GB',
#  'Fcxmm2B6Y1A': 'en-nP7-2PuUl7o',
#  '0wtIUfMMbN4': 'en-JkeT_87f4cc',
#  'tLllKxYSSUw': 'en-AU-eEY6OEpapPo',
#  'EG7csaYLEa4': 'en-ehkg1hFWq8A',
#  'gQ8ydy8AGYs': 'en-US-y-JJSUA13BM',
#  'q6zbeHZhZVQ': 'en-GB',
#  'jydpRngOd6c': 'en-uYU-mmqFLq8',
#  'pAdRUtdhOMg': 'en-ehkg1hFWq8A',
#  'HZQpNcQJMEE': 'en-nP7-2PuUl7o',
#  'DW7RpKZmJXI': 'en-qoXxhA4oLYo',
#  'WYZIbUy-4oE': 'en-GB',
#  'pCV65QA28Zs': 'en-nP7-2PuUl7o',
#  'sqbQKKoEBYw': 'en-U8s8BQ0Tv2Y',
#  'B8xE-GkSIyg': 'en-GB',
#  'zqUNwsxORsc': 'en-US',
#  '1dVf3-jKmlg': 'en-nP7-2PuUl7o',
#  'RmwFyVVcTQk': 'en-_0NIP2uKK2Y',
#  'vQ5Dv0DCey4': 'en-uYU-mmqFLq8',
#  'QmVmQURIrS4': 'en-US',
#  'mCXjB1-97-g': 'en-GB',
#  'kMeSjHLKcd4': 'en-uYU-mmqFLq8',
#  'lRS25iunixQ': 'en-US',
#  '0w8QmB0U-8Q': 'en-US',
#  'ZaRHiJ0VgoA': 'en-uYU-mmqFLq8',
#  'K0tThpk3BFo': 'en-uYU-mmqFLq8',
#  'e7VCekPtdkQ': 'en-nP7-2PuUl7o',
#  'RHRz4OOqwsM': 'en-US',
#  '94ZPZOK3L90': 'en-nP7-2PuUl7o',
#  'AiLYYBTAXyQ': 'en-uYU-mmqFLq8',
#  'zkS8tQw_tFk': 'en-US',
#  'Uawhw3WfA-U': 'en-J_3MO06zu8s',
#  'I4EguPxQz6E': 'en-ehkg1hFWq8A',
#  '25MuC3yjpdo': 'en-GB',
#  'fPH26Cr4aR8': 'en-nP7-2PuUl7o',
#  'nBQRwHsFKnc': 'en-uYU-mmqFLq8',
#  'av_kw2jpQF4': 'en-nP7-2PuUl7o',
#  'cCs3g4ssOb8': 'en-nP7-2PuUl7o',
#  'Q7yUu1rFdJ4': 'en-US',
#  'QMoQ7rl2mno': 'en-uYU-mmqFLq8',
#  'kairgTbW6zU': 'en-lA78xYDXv94',
#  'URCT7rH6oU4': 'en-US',
#  '3LZnTIy06qY': 'en-GB',
#  'qC7ZfK_1L3s': 'en-JkeT_87f4cc',
#  'NmA_DuCTXPw': 'en-US',
#  'vmfWNpaHXZE': 'en-GB',
#  'vbkDmZhU39w': 'en-qlPKC2UN_YU',
#  'ZmRTQd58p2c': 'en-US',
#  'YIZfWI1-TT8': 'en-nP7-2PuUl7o',
#  'uw9ZpHuaX_E': 'en-nP7-2PuUl7o',
#  'OznJTqDuVFc': 'en-US-Wb5fHEoI2z4',
#  'DZOyahVvtls': 'en-nP7-2PuUl7o',
#  'IaQLntJkJ64': 'en-uYU-mmqFLq8',
#  'o2zZJQvxRRw': 'en-uYU-mmqFLq8',
#  'NNDRM8vtQbU': 'en-uYU-mmqFLq8',
#  'Q876o5PiNBg': 'en-nP7-2PuUl7o',
#  '14YjgRbW6Q0': 'en-j3PyPqV-e1s',
#  'ktPGh01ZVSM': 'en-nP7-2PuUl7o',
#  'eYlBB3Sl4qw': 'en-US',
#  'tqPjWqHj4WQ': 'en-nP7-2PuUl7o',
#  '-ub4OWRsCOs': 'en-CA',
#  '9R_m7jaF7Gw': 'en-nP7-2PuUl7o',
#  'ngtKsJxX1QI': 'en-GB',
#  'ZXi8DSExO3U': 'en-US',
#  'yuesV-BF6s8': 'en-US',
#  'BemWDrCwLAo': 'en-US',
#  'Pg23BV0JH90': 'en-9vvcndbraTw',
#  '00ZzJVsPLSA': 'en-US',
#  'NgOq73WAImE': 'en-GB',
#  'dUewRD9FPjU': 'en-US',
#  'c7H5wHNDG2k': 'en-uYU-mmqFLq8',
#  'xoRqLEX1_mk': 'en-US',
#  'FrmkJmXMTn8': 'en-GB',
#  '6uC2wi9SBSo': 'en-uYU-mmqFLq8',
#  '3aFPzxPpDSQ': 'en-uYU-mmqFLq8',
#  'NW8FGvkRpKM': 'en-uYU-mmqFLq8',
#  'qdIMcWZnGYU': 'en-uYU-mmqFLq8',
#  'rnatM-LZxts': 'en-uYU-mmqFLq8',
#  'Ah-jmSbVJis': 'en-JkeT_87f4cc',
#  'DWoKXQWRyQo': 'en-uYU-mmqFLq8',
#  'a-kqC6ZJ01I': 'en-nP7-2PuUl7o',
#  'ujAppKORFeQ': 'en-0hllRZe4s5s',
#  'dGdwzqO6QBc': 'en-uYU-mmqFLq8',
#  'yYhMHomU1zQ': 'en-zZjq6IRLR9Y',
#  '8WK18WpVbJA': 'en-uYU-mmqFLq8',
#  'RR-IhwPezN4': 'en-GB',
#  'vu6zQoOTRnw': 'en-nP7-2PuUl7o',
#  'gHb6cySuj20': 'en-US',
#  'i-C9UI_2gAE': 'en-US',
#  '2n9r5LkJOOE': 'en-j3PyPqV-e1s',
#  'gwSxNy1rfVs': 'en-ehkg1hFWq8A',
#  'l4wpl9W_08g': 'en-nP7-2PuUl7o',
#  'IjAPSaU86Io': 'en-CA',
#  'E8KVH8KHqfs': 'en-GB',
#  'str9fHRJ434': 'en-uYU-mmqFLq8',
#  '6l7XzmtLsss': 'en-US',
#  'T2LYeawfPAU': 'en-uYU-mmqFLq8',
#  '8gk6CWxlJ1o': 'en-uYU-mmqFLq8',
#  'KQUDDiJIlsA': 'en-nP7-2PuUl7o',
#  'kDcKgcEAdQg': 'en-bUFvd4bb5Yg',
#  'dtOcvdZLqpw': 'en-uYU-mmqFLq8',
#  'Fb4lSPOiqmA': 'en-uYU-mmqFLq8',
#  'l9YhZcLA5oY': 'en-JkeT_87f4cc',
#  'AVACeNa7-sE': 'en-JkeT_87f4cc',
#  'D_VxoQobBBk': 'en-CA',
#  'iJJlQmSa1zw': 'en-US',
#  'U3pIznFHM2A': 'en-uYU-mmqFLq8',
#  'Btq1wtd9GTE': 'en-US',
#  's3L0GxwyOxI': 'en-lthCK8UjCvg',
#  '3p-fGn5QfdU': 'en-uYU-mmqFLq8',
#  '2NLBxHllmqY': 'en-uYU-mmqFLq8',
#  '5mBMbxxfpS8': 'en-US',
#  'q2wADmZq_Qs': 'en-US',
#  'A_GrA5Y2qFg': 'en-0dTwf77VHd0',
#  '0bLAJUI8ajQ': 'en-uYU-mmqFLq8',
#  'Ed2sW_vudmQ': 'en-uYU-mmqFLq8',
#  'd5gdQ0Oreec': 'en-US-5N4df0oMbgo',
#  'QCcBPR9pnxQ': 'en-GB',
#  'Cb0vU7-iVbM': 'en-ehkg1hFWq8A',
#  '17yNUYMcdws': 'en-uYU-mmqFLq8',
#  'DGL5edVdJwU': 'en-uYU-mmqFLq8',
#  'U-1OLS8pwJo': 'en-uYU-mmqFLq8',
#  '-Xafs96pTpQ': 'en-US',
#  'Vul6vxd6RlA': 'en-8hB0aIWAANI',
#  'YftlqKEQEG8': 'en-uYU-mmqFLq8',
#  'AEVIVzfhW_0': 'en-uYU-mmqFLq8',
#  'yVe2RCRojcQ': 'en-uYU-mmqFLq8',
#  'kXAk1mnBeYs': 'en-uYU-mmqFLq8',
#  'lMzTgL3xJhA': 'en-US',
#  'yqAf5HPutOo': 'en-nP7-2PuUl7o',
#  'rPvLB7XjqvE': 'en-GB',
#  'YNFP8Z1VZ9E': 'en-dPkTXTcEUoI',
#  'F0eS4ELl5lg': 'en-IN',
#  'Cf57lDanhbg': 'en-uYU-mmqFLq8',
#  'XIFT7BMUTms': 'en-uYU-mmqFLq8',
#  '12KI_AXjJwY': 'en-uYU-mmqFLq8',
#  'w7XBxl0eqp8': 'en-GB',
#  'VN-3faJGsbM': 'en-nP7-2PuUl7o',
#  'WY50KcOAgQo': 'en-uYU-mmqFLq8',
#  'ck-WhP9C4_s': 'en-US',
#  'BvAp2ljFjeQ': 'en-uYU-mmqFLq8',
#  'fBdjdQPtvZQ': 'en-JkeT_87f4cc',
#  'FxXeh_NDK9c': 'en-US',
#  'oAa7iegAIQ4': 'en-nP7-2PuUl7o',
#  'hy-4R-niA5g': 'en-ehkg1hFWq8A',
#  'klMLRH0tNR4': 'en-uYU-mmqFLq8',
#  'LKvNo5Gp5gA': 'en-uYU-mmqFLq8',
#  'VeNJNopIEy0': 'en-uYU-mmqFLq8',
#  's9hjreOs7FE': 'en-JkeT_87f4cc',
#  'pq1lkn6mOVg': 'en-US',
#  '06hGEBjWGZE': 'en-nP7-2PuUl7o',
#  '2iIDZu5eWgI': 'en-nP7-2PuUl7o',
#  'Llymhqt_9_s': 'en-uYU-mmqFLq8',
#  'wx9IINZlxXA': 'en-j3PyPqV-e1s',
#  '25VZutsCCDY': 'en-zjj7KuVaCtg',
#  'JEphd60v7ic': 'en-US',
#  'QbkRQg1Y464': 'en-nP7-2PuUl7o',
#  'J9bmJTxRL44': 'en-IN',
#  '3p8kZpT56lQ': 'en',
#  'Udq1zw4GUsc': 'en-US',
#  'PR-1tMih0fM': 'en-US',
#  'rWyWvyD8uRo': 'en-AOd53cNDw7M',
#  'v8DUb0btL3w': 'en-US',
#  'CUROxmg_gyU': 'en-US',
#  'YzcoiwMNkZk': 'en-US',
#  'Korh-e8tVFg': 'en-nP7-2PuUl7o',
#  'zUOCU2YzgAw': 'en-3pK74FgVxOs',
#  'Feydqcmrfbg': 'en-CA',
#  'b1QHr5QNJ8M': 'en-JkeT_87f4cc',
#  'BsSlE29hQdA': 'en-GB',
#  'w48TEjPqhJ8': 'en-US',
#  '9eoLV9Vy348': 'en-uYU-mmqFLq8',
#  'UCoJINO_hNg': 'en-US',
#  'MfQ1ZH3mvrA': 'en-ehkg1hFWq8A',
#  'hqCkg_gQ0BY': 'en-US',
#  'FF-b-G9E2Eo': 'en-R5kLMIN4ySo',
#  'Ugkg-P0WD6c': 'en-uYU-mmqFLq8',
#  'CC-pVClSydE': 'en-uYU-mmqFLq8',
#  'yylg1_nE6Ik': 'en-uYU-mmqFLq8',
#  '0cK_ZhXzP2E': 'en-US',
#  '1PvcPQsbtcY': 'en-US',
#  'yPT4N43-ZPQ': 'en-nP7-2PuUl7o',
#  'IUbcEFn6BUk': 'en-IwaGJauz0-Y',
#  'TQ5svNRCDec': 'en-eEY6OEpapPo',
#  'F4LbljGoQuc': 'en-nP7-2PuUl7o',
#  'Qybpp4v63xc': 'en-nP7-2PuUl7o',
#  'Ez8eBtLh8PU': 'en-nP7-2PuUl7o',
#  'W5F0gQ-S6o4': 'en-uYU-mmqFLq8',
#  'LpPER79lbO8': 'en-J4-ze_D1PHo',
#  'XXUufVe40eU': 'en-nP7-2PuUl7o',
#  'uRf4UHcHeas': 'en-US',
#  '9_j2cCHXOlk': 'en-CA',
#  'T6ZDFSVb5Ic': 'en-GB',
#  'hTGV9Z1Bj9w': 'en-JkeT_87f4cc',
#  'au3GMNZuQpk': 'en-US',
#  '2Ta51YTFiio': 'en-IN',
#  '92cq5IS_BmA': 'en-uYU-mmqFLq8',
#  'tbwxCqtbReE': 'en-GB',
#  't9iWg67qguw': 'en-uYU-mmqFLq8',
#  '-G29TQMkp1Q': 'en-GB',
#  'S7bYwvhPhAs': 'en-t1tRc3F3FZo',
#  'J3DHSvl3RVA': 'en-uYU-mmqFLq8',
#  'HWYio2XBOek': 'en-GB',
#  'eDYJ6jE6NwY': 'en-uYU-mmqFLq8',
#  'b9Gy9-9MSbg': 'en-ehkg1hFWq8A',
#  'zvt_Qwkp2GQ': 'en-GB',
#  'Bv_lc06c1Cc': 'en-US',
#  '4VaAeucxrEY': 'en-US',
#  'txiDJ_05qqU': 'en-uYU-mmqFLq8',
#  'afOY1SRR3fw': 'en-uYU-mmqFLq8',
#  'aQUOkgb9NlI': 'en--97oD6DqBwI',
#  '1xvKoA1WKnw': 'en-ehkg1hFWq8A',
#  '0rC7U-ea8kc': 'en-uYU-mmqFLq8',
#  'cTguXwJ9-14': 'en-uYU-mmqFLq8',
#  '-PLAFQTSqHE': 'en-JkeT_87f4cc',
#  'slX7gSbB3lk': 'en-uYU-mmqFLq8',
#  'QK5xkDE_eiA': 'en-uYU-mmqFLq8',
#  '9IXQ63VXpg0': 'en-nP7-2PuUl7o',
#  'jfSbf2-Rs0M': 'en-GB',
#  'LSFMcp43FVw': 'en-uYU-mmqFLq8',
#  '14ed0OTfN0Y': 'en-uYU-mmqFLq8',
#  '9DpwQwfC3sY': 'en-nP7-2PuUl7o',
#  '2qQGvV_jFjU': 'en-uYU-mmqFLq8',
#  '9A4wovNc-QU': 'en-ehkg1hFWq8A',
#  '6a090iBNFHU': 'en-GB',
#  'gXCsRlpbqPM': 'en-0hllRZe4s5s',
#  'AT08vnDNTI8': 'en-US',
#  'PljKmqwz0o8': 'en-uYU-mmqFLq8',
#  'cKpjPJ1LSgo': 'en-uYU-mmqFLq8',
#  'nx0ihuDlD2g': 'en-RYfin79u0RQ',
#  'xs0u_pW3b9U': 'en-uYU-mmqFLq8',
#  'zki3pDFG4IM': 'en-nP7-2PuUl7o',
#  'A9dtXPhbA7k': 'en-uYU-mmqFLq8',
#  '4RIxwcO8P7A': 'en-uYU-mmqFLq8',
#  'ZFyh5EvLWso': 'en-uYU-mmqFLq8',
#  'HJCbby4DcKI': 'en-uYU-mmqFLq8',
#  'aXs5mDjUeCo': 'en-4IS76ajagA8',
#  'rHaWiPIE2Jc': 'en-uYU-mmqFLq8',
#  'EVG97w1Bm8U': 'en-uYU-mmqFLq8',
#  '6ebQ4-CbO8o': 'en-US',
#  'a4tYZcJar6Q': 'en-nP7-2PuUl7o',
#  'JkWipjoClEY': 'en-uYU-mmqFLq8',
#  'MhU2Odakn6A': 'en-uYU-mmqFLq8',
#  'VdB4HwkHlTE': 'en-GB',
#  'SzhOJ_iM7Pw': 'en-nP7-2PuUl7o',
#  'JF920wpd9dM': 'en-US-Yzk4JRHhugc',
#  'PJijJ8jE1LA': 'en-ehkg1hFWq8A',
#  'SruMzj5deZc': 'en-US',
#  '-NztqjCOb50': 'en-CA',
#  'HcrAbL-T8Xs': 'en-nP7-2PuUl7o',
#  'LhUtMO9HndE': 'en-nP7-2PuUl7o',
#  '0IqdbyChqaY': 'en-US',
#  'pt-Xju6j2VU': 'en-eEY6OEpapPo',
#  'tvPXEQOZ94o': 'en-8gTOZXtIMYI',
#  'Gnqyx35xEnM': 'en-nP7-2PuUl7o',
#  '57cbh3CI3XY': 'en-ehkg1hFWq8A',
#  'GQ77hNaqEO0': 'en',
#  'LsjLnlKcHqw': 'en-nP7-2PuUl7o',
#  'DkA2Vg0Uxdc': 'en-oH8ygqlU7dg',
#  'gi4SOP2ElAw': 'en-US',
#  '9ZooQYCTD1o': 'en-GB',
#  'M0uvSpwqncU': 'en-US',
#  'OM3kbCqBxiA': 'en-GB',
#  'NyofByy1Wb0': 'en-nP7-2PuUl7o',
#  'jBQlNNXzyjw': 'en-US',
#  'ZPmWK9izSjg': 'en-nP7-2PuUl7o',
#  'OCqbS76vS_E': 'en-uYU-mmqFLq8',
#  'kibXTXrDHoI': 'en-US',
#  'ElPGZv5cOUo': 'en-uYU-mmqFLq8',
#  'wvhH70kH0IQ': 'en-feyM3B_Bzws',
#  'N1i3xlDEVpM': 'en-nP7-2PuUl7o',
#  'hdrca8Ytjpo': 'en-uYU-mmqFLq8',
#  'hWfiLE9S7E8': 'en-uYU-mmqFLq8',
#  'OPsri1Jo-IQ': 'en-nP7-2PuUl7o',
#  'CYCJygEovjo': 'en-nP7-2PuUl7o',
#  'oXqO37LTPBg': 'en-JkeT_87f4cc',
#  '1_uppN7km_Y': 'en-nP7-2PuUl7o',
#  'jXUbUP9ark8': 'en-uYU-mmqFLq8',
#  '4eh8VGXjarg': 'en-uYU-mmqFLq8',
#  'AQr7bCrJtwM': 'en-GB',
#  'SgCGywQphNo': 'en-US',
#  'jv2atMpm3O8': 'en-uYU-mmqFLq8',
#  'zGy5kkGIvuI': 'en-US',
#  'vQchanFGVrU': 'en-uYU-mmqFLq8',
#  'c8-vb8cfU4E': 'en-nP7-2PuUl7o',
#  '3A5wKlMyuJ0': 'en-GB',
#  '9QHB-Db8aUA': 'en-qoXxhA4oLYo',
#  'T4_OAgoVmQg': 'en-p7F-05TaKe0',
#  'jurmW73gw_M': 'en-uYU-mmqFLq8',
#  'W94-kuxSJio': 'en-uYU-mmqFLq8',
#  'bTywIoWaMQA': 'en-US',
#  'cT8IvQGum5I': 'en-uYU-mmqFLq8',
#  'NsrGagAAjI0': 'en-GB',
#  'GiFQNevrxYA': 'en-j3PyPqV-e1s',
#  'AvCG477Vdhk': 'en-US',
#  'ECiyZ-2UFtU': 'en-NLrEr_pdCGM',
#  'c3m1Uxe9b9A': 'en-uYU-mmqFLq8',
#  '_nOzAsz6EHI': 'en-j3PyPqV-e1s',
#  'PQ1tA5prEoQ': 'en-US',
#  'zpyxi3Qo7GU': 'en-uYU-mmqFLq8',
#  'SJs_ANOJdL8': 'en-nP7-2PuUl7o',
#  'PMk-mFTxyM8': 'en-GB',
#  'wfqizAD8AYM': 'en-nP7-2PuUl7o',
#  'PAXQT_Xz1yg': 'en-GB',
#  'S7Db4wJkXAU': 'en-GB',
#  'Z016JTr8ptg': 'en-nP7-2PuUl7o',
#  'HOQUW6ZKwgI': 'en-j3PyPqV-e1s',
#  'X_fEFWZV6Yk': 'en-2RBgzsUSzFk',
#  '-rSdtP2CLOk': 'en-uYU-mmqFLq8',
#  'txaHwzhXCEQ': 'en-US',
#  'SqnJF63YzIo': 'en-uYU-mmqFLq8',
#  'oJT4Y7ZTVAw': 'en-kosWLcAI5Lg',
#  'KtJkZakzyIY': 'en-US',
#  'MvI1rlElL1E': 'en-LK58Pkw2f-Q',
#  'TBZgXO6y0d8': 'en-US',
#  'GnzNozIO8Z4': 'en-uYU-mmqFLq8',
#  '7dDvcNmugmc': 'en-uYU-mmqFLq8',
#  'EfknvxxsfVM': 'en-uYU-mmqFLq8',
#  'TyMlGXX_KQs': 'en-IN',
#  'qmZhIkvQdKE': 'en-US',
#  '8AvXDbmbjEI': 'en-uYU-mmqFLq8',
#  'x0XdbJadniY': 'en-uYU-mmqFLq8',
#  '4WR2bNy2zNQ': 'en-nP7-2PuUl7o',
#  'ZVHpmR4aJlk': 'en-uYU-mmqFLq8',
#  'pGEu8mdeDho': 'en-GB',
#  'wVdwpKvMARg': 'en-uYU-mmqFLq8',
#  '-jEV_CtP9Zc': 'en-US-XNUBsHab2FE',
#  'M5R0V-Pakqk': 'en-uYU-mmqFLq8',
#  '5drgUsN7b08': 'en-qoXxhA4oLYo',
#  'w5keaSndwW4': 'en-IN',
#  'KCQvpdNytk4': 'en-uYU-mmqFLq8',
#  'pkLp9sH-YZo': 'en-US',
#  'WcMpZO6GjgY': 'en-uYU-mmqFLq8',
#  'bP-djWlSGlU': 'en-US',
#  'K9D3cy169HY': 'en-US',
#  'p9BT4XvGYdY': 'en-US',
#  'EZqrJoFG-Hc': 'en-uYU-mmqFLq8',
#  '8eRdle8OlSE': 'en-nP7-2PuUl7o',
#  'Lsr0OXj-EVM': 'en-US',
#  'cNjEukp8nws': 'en-GB',
#  '-0EUHud5Rhk': 'en-US',
#  'N6QNZ1Xz5C0': 'en-uYU-mmqFLq8',
#  'vB6SBzPRpHc': 'en-nP7-2PuUl7o',
#  'vHUErDONKuE': 'en-ehkg1hFWq8A',
#  'OBHUrAFLQW8': 'en-j3PyPqV-e1s',
#  'a6ZN2zXGlTc': 'en-uYU-mmqFLq8',
#  'cq359vYQCJQ': 'en-uYU-mmqFLq8',
#  '6gICj9yO3SQ': 'en-xMpCOKC5I4I',
#  'qjvt4TGW8Jc': 'en-US',
#  '2-cmEZypCoc': 'en-US',
#  'VJBo9kMzMMU': 'en-uYU-mmqFLq8',
#  'icj10UFsFhE': 'en-dQs7zDoAYDs',
#  'SwUxSbz0_q8': 'en-uYU-mmqFLq8',
#  'Du4N7xDMQB4': 'en-US-cvfXDfbeED0',
#  'tm73eqav9Mo': 'en-nP7-2PuUl7o',
#  'kBU-1-XkQzQ': 'en-uYU-mmqFLq8',
#  'vLfayj_DBkk': 'en-nP7-2PuUl7o',
#  'ks3doDVDV-E': 'en-US',
#  'TDEaWvHd-90': 'en-uYU-mmqFLq8',
#  '23r2K0HMORw': 'en-6ie113TWF7c',
#  'AOQ803mEpJ8': 'en-uYU-mmqFLq8',
#  'XeiNr_h9kOg': 'en-nP7-2PuUl7o',
#  '1R3pIIWVF8A': 'en-CA',
#  '70OQZqqFEcY': 'en-nP7-2PuUl7o',
#  '6MxRrdR114s': 'en-GB',
#  'Lazpmm1ScP4': 'en-uYU-mmqFLq8',
#  'bHLrfQkDEY4': 'en-US',
#  'v48xP2q36do': 'en-uYU-mmqFLq8',
#  'Pl-Z4bhK5X0': 'en-uYU-mmqFLq8',
#  'U7_fvwCV2Aw': 'en-uYU-mmqFLq8',
#  '8FYJpim5i8w': 'en-nP7-2PuUl7o',
#  'VialzXpDEOY': 'en-US',
#  'ByMXDE1U560': 'en-US-eEY6OEpapPo',
#  'faBJYhxDnUQ': 'en-nP7-2PuUl7o',
#  '3l8RDnYib2E': 'en-XI-GZoXF2NY',
#  'OWcutkCxuyI': 'en-JkeT_87f4cc',
#  '3ZpWNoUpVC0': 'en-US',
#  'QCWCXQ6bPWE': 'en-US',
#  'UD-85pXLI6Y': 'en-JkeT_87f4cc',
#  'RC-6maGDctk': 'en-nP7-2PuUl7o',
#  'Zt3PPcaw5ng': 'en-nP7-2PuUl7o',
#  'JH4xZ-RXPZQ': 'en-US',
#  'GLwykybPNzc': 'en-NFc95htUTDQ',
#  'BelzIs8R4iY': 'en-US',
#  'FwgWXXTh-Wk': 'en-i2MEHlY8kCY',
#  'BFlYWmJ-oPY': 'en-US',
#  'qfo56INiBk0': 'en-uYU-mmqFLq8',
#  'CN869FkI_lc': 'en-uYU-mmqFLq8',
#  'iEb-Z1n7rgY': 'en-uYU-mmqFLq8',
#  'JI4E-zRmvFk': 'en-nP7-2PuUl7o',
#  'zZRmNisY6AQ': 'en-nP7-2PuUl7o',
#  '-p_n0E3tD1o': 'en-JkeT_87f4cc',
#  '6no9bS79dHI': 'en-GB',
#  'cUuBYQs4Auc': 'en-US',
#  'KSmG-uMsXag': 'en-US',
#  '-VxLdKpyB_k': 'en-JkeT_87f4cc',
#  '8lZ63ki8Nrw': 'en-uYU-mmqFLq8',
#  'LpXZQvxWIWw': 'en-US',
#  'W8XkNf72VOM': 'en-uYU-mmqFLq8',
#  'swXh4TImZxs': 'en-uYU-mmqFLq8',
#  'IL0gcBN-Dok': 'en-xSwrDzZ4aNU',
#  'g_mi-JGG7PI': 'en-nP7-2PuUl7o',
#  'z5QIrNuMaEU': 'en-uYU-mmqFLq8',
#  'E0asvBob338': 'en-uYU-mmqFLq8',
#  'BuYxaSxshrs': 'en-uYU-mmqFLq8',
#  'cE13uzwOgrs': 'en-nP7-2PuUl7o',
#  'GK_CYZ1zJXI': 'en-uYU-mmqFLq8',
#  'G-xZoOhz8Qw': 'en-uYU-mmqFLq8',
#  'SjpXMzWGWzw': 'en-US',
#  'A5z3vxIK-cE': 'en-US',
#  'AjRbbyMmjX0': 'en-uYU-mmqFLq8',
#  '9SUXN39e6gE': 'en-nP7-2PuUl7o',
#  'X8bchntUB_8': 'en-uYU-mmqFLq8',
#  'S74UizGSKTQ': 'en-nP7-2PuUl7o',
#  'cbnPUfFNLaQ': 'en-ehkg1hFWq8A',
#  'ncT9_lMfWSE': 'en-eEY6OEpapPo',
#  'HXSJlu0oKGE': 'en-uYU-mmqFLq8',
#  'gfDcamy726E': 'en-1oAFzPNiuC0',
#  'VufTcmYHKLQ': 'en-ehkg1hFWq8A',
#  'f7FFZzdr-9U': 'en-uYU-mmqFLq8',
#  'WCHMNODrX9Y': 'en-ehkg1hFWq8A',
#  'XQf60w0MF2s': 'en-uYU-mmqFLq8',
#  'qSatw1cCIyU': 'en-eEY6OEpapPo',
#  'kmmhOlhdxaA': 'en-GB',
#  't4w5qdCYLd4': 'en-US',
#  'JX-rRGEnmjo': 'en-HO3O79DivUk',
#  '3EmLF3xrJYo': 'en-JkeT_87f4cc',
#  'lNbLvvW24PU': 'en-uYU-mmqFLq8',
#  'f3NdjzC0QF0': 'en-rX01gsAdUfU',
#  'WEw2JgbDxXc': 'en-JkeT_87f4cc',
#  'W0oohS9MlOw': 'en-JkeT_87f4cc',
#  'vbgqwIL-deg': 'en-US-cvfXDfbeED0',
#  '49D84bJQbDQ': 'en-GB',
#  '1dJFQy2iehA': 'en-JkeT_87f4cc',
#  'JX_4NIS8Le0': 'en-dM3xbKeYRKM',
#  'WQG1u6gW3Ug': 'en-GB',
#  'Ivtp2KkwKRo': 'en-US',
#  'skKqZYTL8lM': 'en-nP7-2PuUl7o',
#  'lS2YEryHsgI': 'en-US-dOaosRHqfaE',
#  'ZU4AeV5Yx1o': 'en-IN',
#  '-nv99rhkBR4': 'en-uYU-mmqFLq8',
#  'MatCOmY1hKU': 'en-US',
#  'Jpaqlz4csD0': 'en-IN',
#  'THT-GYx08UU': 'en-US',
#  '-s5qegPYyJE': 'en-QmQwybuXnYs',
#  'l0yWTw6N0NQ': 'en-GZFbkuVOZWc',
#  'qdmEI_44tJw': 'en-US',
#  'WGuToJoNtvY': 'en-JkeT_87f4cc',
#  '6UMxVHd_qO8': 'en-uYU-mmqFLq8',
#  '9H1sDcmNtyU': 'en-JkeT_87f4cc',
#  'uFP0Fz924vU': 'en-uYU-mmqFLq8',
#  'Tjx3CZ7IdoU': 'en-US',
#  'CAb8QyjGcUE': 'en-nP7-2PuUl7o',
#  'KPKqtCrB2GQ': 'en-US',
#  'uzCqbdPp7q4': 'en-US',
#  '8lXAOGYlYBY': 'en-ehkg1hFWq8A',
#  'KEJZt9D7T_o': 'en-uYU-mmqFLq8',
#  'Mr3XU2Z-Egc': 'en-GB',
#  'E0YY0bTwUdo': 'en-US',
#  'R2jntDlxqLc': 'en-vlW2OHFw3ww',
#  'OIP-aph8qeg': 'en-GB',
#  'qlfHxgg5Yak': 'en-uYU-mmqFLq8',
#  'FbjIQWH7Lp4': 'en-CA',
#  'qR9kW13EqcM': 'en-uYU-mmqFLq8',
#  'PnxLGCK7xMQ': 'en-nP7-2PuUl7o',
#  'pEB1VKnhOPw': 'en-uYU-mmqFLq8',
#  'mFYR3Dn6Z7g': 'en-nP7-2PuUl7o',
#  'etH1P0rNgh8': 'en-uYU-mmqFLq8',
#  'xgnJFTlhVe8': 'en-uYU-mmqFLq8',
#  '02fuTRDCVpY': 'en-US',
#  '2P-gJmAqaPo': 'en-ehkg1hFWq8A',
#  'DrbXhbmLTMU': 'en-US',
#  'KXwAwDDzMLA': 'en-US',
#  'Fr_UFneCLMo': 'en-uYU-mmqFLq8',
#  'yRtMzZ5axpM': 'en-US',
#  'M72DdaEYGuk': 'en',
#  '8EVWpczIspM': 'en-IN',
#  '0_y7jSX-uno': 'en-nP7-2PuUl7o',
#  'nn88ueTsqyA': 'en-US',
#  'mElFXx9LaQU': 'en-US',
#  'MCDg8EGRZ9o': 'en-uYU-mmqFLq8',
#  'JEMvizDlvkA': 'en-RTbB2cpHawQ',
#  'TS5Dg3nfXlA': 'en-uYU-mmqFLq8',
#  '-27hb78RIvE': 'en-uYU-mmqFLq8',
#  'zs1fnkUI3jU': 'en-GB',
#  'MXvSc4VkID4': 'en-uYU-mmqFLq8',
#  'jJ9fAg0QnGY': 'en-ehkg1hFWq8A',
#  '8fVtuts5mtk': 'en-ehkg1hFWq8A',
#  'Er4L3-NsX44': 'en-US',
#  '1Ij38hSMZSA': 'en-zL_pKPa_d08',
#  'GPZ_cLc-HrY': 'en-uYU-mmqFLq8',
#  'evRupil8SQo': 'en-GB',
#  'NtcXcAM3nUU': 'en-9sW8misHUUY',
#  'P8QJBcoeXsc': 'en-US',
#  'gIf6ca5DeT4': 'en-IN',
#  'B7K7Nbmr3vk': 'en-gbV_7iublQM',
#  'VeMYY0umawg': 'en-uYU-mmqFLq8',
#  'csr1yn_8u7c': 'en',
#  '6ZwQoMDYbdw': 'en-cQ5IbZMGU-A',
#  'TnAOh5jToWo': 'en-uYU-mmqFLq8',
#  'NDsAvT_b364': 'en-nP7-2PuUl7o',
#  'ZxeAEiMXkDA': 'en-nP7-2PuUl7o',
#  '6-3QOREupvk': 'en-nP7-2PuUl7o',
#  'OEHcT2EX1-w': 'en-US',
#  'gvnCus79a7E': 'en-nP7-2PuUl7o',
#  'U56adtH0HSM': 'en-uYU-mmqFLq8',
#  'QNC1uhnuPe4': 'en-uYU-mmqFLq8',
#  'uz_LZj7QOQE': 'en-nP7-2PuUl7o',
#  'jPEKHJA792Q': 'en-VdzfAXtR_JY',
#  'X597s7ofl3U': 'en-US',
#  'YfTWgimQa4U': 'en-nP7-2PuUl7o',
#  '_6QGcmATGiA': 'en-uYU-mmqFLq8',
#  'EDsRzTno77Q': 'en-uYU-mmqFLq8',
#  'H8BfmwB6iAo': 'en-GB',
#  '9FND39596DQ': 'en-US',
#  'jWZfndLjZXg': 'en-1oAFzPNiuC0',
#  'AXbzqptppvw': 'en-uYU-mmqFLq8',
#  'OOf11sBfAAI': 'en-hFTHNXuRrhA',
#  '6JSQBLOjKCo': 'en-US',
#  'wJWt0dcgafs': 'en-LUU0EuDKgKo',
#  '2qhtTxwzwbk': 'en-ehkg1hFWq8A',
#  'MwhFsaiib14': 'en-uYU-mmqFLq8',
#  'xsKUKOtC5rQ': 'en-CA',
#  'vGeoJSZUBxc': 'en-qoXxhA4oLYo',
#  'TfA7lPlkG5M': 'en-uYU-mmqFLq8',
#  'g8d6UbVCuuw': 'en-ehkg1hFWq8A',
#  'cmYLeWj-emI': 'en-uYU-mmqFLq8',
#  '2kYoZw3O5_E': 'en-GB',
#  'fgXg2TWkz7I': 'en-GB',
#  'e39ReiYasLU': 'en-nP7-2PuUl7o',
#  'NR2FVOGEoGg': 'en-uYU-mmqFLq8',
#  'A1prdSze0Bw': 'en-nP7-2PuUl7o',
#  ...}

# %%
bad_4M_df = df_4[df_4["id"].isin(id_trainable_4M_bad)]
bad_4M_df.shape[0]
# Out:
# 1636616

# %%
view_lang_cols(bad_4M_df, 30)
# Out:
#                id                                              title language  \
# 61    orWh_OLaRg4  All Goals | Final Copa America | Argentina (1)...       en
# 106   y3o-baXQT0Q                             VLOG #1 - Introduction       en
# 146   zHGwE0ritgk       Let's Play Minecraft: Greatest freakout ever       en
# 288   5GPxO1AEAwc  KC & HR COLLEGE 2021 STEP BY STEP ADMISSION PR...       en
# 498   KWszRt6gKW8                                  Mr Indestructable       en
# 677   9qBidHh1weI  Manchester bin collection and street cleaning ...       en
# 812   xMj6WpM8XeQ                               When Time Management       en
# 814   CnVil18-WLY                     He Won't Work on Your Marriage       en
# 826   3nqTJ-U4kN8        Power of Saying No | 8- Priorities for Life       en
# 843   6gniitAi2MY                                       Mirror Intro     None
# 846   eUUu8oR-RC4                                         Leap Intro       en
# 882   MTC2T91cvvM  Make Me Real - The Cloudrunner, feat. David Ly...     None
# 998   yoEG_fcATXI  Ceylon versus cassia cinnamon - which one can ...       en
# 1161  B506YqQ-laU    Solomon Grey - Wonderful World (Official Video)     None
# 1171  rNHvk4FhgIg                               #31 5413 Highway 579       en
# 1172  so2v9udAd8g            2025 Birch Crescent SE Calgary, Alberta       en
# 1225  oSWVOXUD-80                        Constipation considerations       en
# 1244  J3wBXGPmYw0                    Miraculous Love Triangle part 4       en
# 1246  WlggoQQsdq4                    Miraculous Love Triangle part 2       en
# 1247  luX3mOhZoz4                    Miraculous Love Triangle Part 1       en
# 1397  86xfEuRa9b8  PASTOR PAUL ENENCHE EXPOSEs THE TRUTH 😱 breaks...       en
# 1442  GkBjzSQ6lXo                   Miraculous Love Triangle part 28       en
# 1463  Qbf6OQ_BeE0  Casa Mira Labangon Cebu City Philippines | Lau...       en
# 1482  1s3xP-jNwz8            A Healthy You | 2 - Priorities for Life       en
# 1487  0rAg4W4R4uE         Allow for Differences | Fall in Love Again       en
# 1488  SwJAJZwCFa8         Balance Work and Life | Fall In Love Again       en
# 1493  ia-aYNEVZnw                 Stay Positive | Women of Influence       en
# 1497  LccPjhorUTI         He Needs to Be Needed | Fall in Love Again       en
# 1747  Yrwu5MjqevY               Don't Interrupt | Women of Influence       en
# 1762  6JCkB5W_ePE                           Our # 1 Problem as Wives       en
#
#            manual_caption_languages automatic_caption_orig_language  \
# 61    en-JkeT_87f4cc,en-uYU-mmqFLq8                              en
# 106                           en-US                              en
# 146                  en-18WT74-rBWA                              en
# 288                           en-IN                              en
# 498                  en-uYU-mmqFLq8                              en
# 677                           en-GB                              en
# 812                  en-uYU-mmqFLq8                              en
# 814                  en-uYU-mmqFLq8                              en
# 826                  en-uYU-mmqFLq8                              en
# 843                  en-cvfXDfbeED0                              en
# 846               en-US-anMIXjicSL4                              en
# 882                  en-s8TMdDjdYe8                              en
# 998                  en-uYU-mmqFLq8                              en
# 1161                 en-nP7-2PuUl7o                              en
# 1171                          en-CA                              en
# 1172                          en-CA                              en
# 1225                 en-uYU-mmqFLq8                              en
# 1244                          en-GB                              en
# 1246                          en-GB                              en
# 1247                          en-GB                              en
# 1397                 en-uYU-mmqFLq8                              en
# 1442                          en-GB                              en
# 1463                          en-GB                              en
# 1482                 en-uYU-mmqFLq8                              en
# 1487                 en-uYU-mmqFLq8                              en
# 1488                 en-uYU-mmqFLq8                              en
# 1493                 en-uYU-mmqFLq8                              en
# 1497                 en-uYU-mmqFLq8                              en
# 1747                 en-uYU-mmqFLq8                              en
# 1762                 en-uYU-mmqFLq8                              en
#
#                     man_cap_langs_2
# 61    en-JkeT_87f4cc,en-uYU-mmqFLq8
# 106                           en-US
# 146                  en-18WT74-rBWA
# 288                           en-IN
# 498                  en-uYU-mmqFLq8
# 677                           en-GB
# 812                  en-uYU-mmqFLq8
# 814                  en-uYU-mmqFLq8
# 826                  en-uYU-mmqFLq8
# 843                  en-cvfXDfbeED0
# 846               en-US-anMIXjicSL4
# 882                  en-s8TMdDjdYe8
# 998                  en-uYU-mmqFLq8
# 1161                 en-nP7-2PuUl7o
# 1171                          en-CA
# 1172                          en-CA
# 1225                 en-uYU-mmqFLq8
# 1244                          en-GB
# 1246                          en-GB
# 1247                          en-GB
# 1397                 en-uYU-mmqFLq8
# 1442                          en-GB
# 1463                          en-GB
# 1482                 en-uYU-mmqFLq8
# 1487                 en-uYU-mmqFLq8
# 1488                 en-uYU-mmqFLq8
# 1493                 en-uYU-mmqFLq8
# 1497                 en-uYU-mmqFLq8
# 1747                 en-uYU-mmqFLq8
# 1762                 en-uYU-mmqFLq8

# %%
condition = (bad_4M_df["manual_caption_languages"].str.split(",").apply(lambda lst: len(lst) == 1))
bad_4M_df_2 = bad_4M_df[condition]
bad_4M_df_2.shape[0]
# Out:
# 1237771

# %%
bad_4M_df_2["manual_caption_languages"].unique().tolist()
# Out:
# ['en-US',
#  'en-18WT74-rBWA',
#  'en-IN',
#  'en-uYU-mmqFLq8',
#  'en-GB',
#  'en-cvfXDfbeED0',
#  'en-US-anMIXjicSL4',
#  'en-s8TMdDjdYe8',
#  'en-nP7-2PuUl7o',
#  'en-CA',
#  'en-US-YfeEIUII1AU',
#  'en-ehkg1hFWq8A',
#  'en-anMIXjicSL4',
#  'en-1oAFzPNiuC0',
#  'en-fGGqjO4aYg8',
#  'en-IE',
#  'en-rX01gsAdUfU',
#  'en-Uym2X1t3MTA',
#  'en-8k-bGVCfGYE',
#  'en-MPV48gM7bqQ',
#  'en-LUU0EuDKgKo',
#  'en-6UJrWS5jR_I',
#  'en-tyWfmtkyBQo',
#  'en-SJ_OorK2o0k',
#  'en-gG13fOM8Dfs',
#  'en-eEY6OEpapPo',
#  'en-zOnwy86eUkk',
#  'en-Sxg7wWGnGNg',
#  'en-DvHdX2kI9hs',
#  'en-fcVymTUPpeI',
#  'en-H_h6RMPrfCg',
#  'en-jFK5kpDRP3M',
#  'en-v9B2qqWVzdQ',
#  'en-FetHzM0RQJU',
#  'en-dBnIPyQn-7E',
#  'en-UMYBvvsXfqo',
#  'en-j3PyPqV-e1s',
#  'en-qlPKC2UN_YU',
#  'en-US-qhidoPi0w8c',
#  'en-0GZSgHK00aQ',
#  'en-6ebHVfu6BsQ',
#  'en-ovhHx95i6Ho',
#  'en-0hllRZe4s5s',
#  'en-zL7EZQmMa4Q',
#  'en-5iccchR9oVs',
#  'en-GB-anMIXjicSL4',
#  'en-yR6JfUoAWYg',
#  'en-xWCTb4ASxWo',
#  'en-QLlkAr8DpK0',
#  'en-fBJ7WLCgqx8',
#  'en-GtDsi6WLVPc',
#  'en-VqxSfNneakA',
#  'en-yd_sspvDACE',
#  'en-6DGfwZopUls',
#  'en-QiHwL5tfpfI',
#  'en-JWp4A7VQiG0',
#  'en-e3NusTPrr30',
#  'en-UNfGon_hYfo',
#  'en-tTbOJDVqCbI',
#  'en-3GFUKXcb7WM',
#  'en-NFcLRpr5wbM',
#  'en-MPUBBCWfl68',
#  'en-xCMTqQGUYLg',
#  'en-80RURFZ4zuI',
#  'en-s7haLhmWpG4',
#  'en-l6QjZcGF8aw',
#  'en-Q9iUvTQL9FE',
#  'en-w_XpXbpNjaI',
#  'en-YElYWYZYBsE',
#  'en-vdMGBCErqgs',
#  'en-0eQpfQgW5No',
#  'en-hJoysNUZZ7U',
#  'en-OcUZzOF9GkM',
#  'en-kHNDB91_-QU',
#  'en-ulPx8tGYPGw',
#  'en-FFxRwzh0muQ',
#  'en-e8JF94SJ4NQ',
#  'en-IeNvToZgHPg',
#  'en-Wd5ne0NZlm4',
#  'en-uoLYTLJz9cA',
#  'en-ds50qUua7D0',
#  'en-zrhEfMSreNI',
#  'en-4_3WYQr9MRA',
#  'en-gY_yrt0x_8w',
#  'en-z7ILyPzY03I',
#  'en-KwtO0Ql93wA',
#  'en-ItWavQTbn9E',
#  'en-3RqRCbsr_xg',
#  'en-OrMU4aRBs8k',
#  'en-NKbu1RTbYuo',
#  'en-3UcICQ1-yA8',
#  'en-r0AnDEQp_fg',
#  'en-oTp_B_xOvu4',
#  'en-eNrGvamCrqo',
#  'en-FD6xoZsyAlw',
#  'en-w0I42LU0b2k',
#  'en-Qmus90MA7kU',
#  'en-0zfjSeGzKME',
#  'en-ilDNOedWomQ',
#  'en-_wo7fz2u8EA',
#  'en-whyRX1JI64w',
#  'en-zjT3E6tEukw',
#  'en-hzkUZk8SLLc',
#  'en-koWG0Cdscjc',
#  'en-FgNQ6gnITdM',
#  'en-S9eLTse3JGw',
#  'en-QUQY448TsWc',
#  'en-3E88c8m_-SA',
#  'en-z0T8M3jsoU0',
#  'en--BbGSwzns0s',
#  'en-ftylmGiorMU',
#  'en-pi34-gP0-qk',
#  'en-smFHrho8E_Q',
#  'en-Dcru9dW5ODM',
#  'en-gwKGy7jbExw',
#  'en-T-iV2Vc9ehU',
#  'en-V2YjA2e6Fyo',
#  'en-m6UlexV5PgI',
#  'en-sMU_b-kxkdQ',
#  'en-fkqKbO096WE',
#  'en-V6i59PheuiQ',
#  'en-xsbwZ6Pq2c4',
#  'en-f36Xvv2vzjQ',
#  'en-kwA0cidvQrg',
#  'en-lTcNyPIB5U4',
#  'en-rBr0ouVbIOY',
#  'en-PtLxtQKJUe8',
#  'en-AU',
#  'en-lWQ7bK81pqg',
#  'en-hdzLK19xFbc',
#  'en-LZLVDZ90HJg',
#  'en-6GcSGw81TyM',
#  'en-yUGZRbwkFHY',
#  'en-yv1qnlVLzoQ',
#  'en-_0blXBczMBo',
#  'en-v8dpQGAc-d8',
#  'en-nPk3V-duwf8',
#  'en-M3FTz6BDvH4',
#  'en-_BZ0tSw-zX4',
#  'en-Pobwd6b-BQI',
#  'en-opvMIlCf6yU',
#  'en-ne1kkAzzDEo',
#  'en-l9ZAytQDX8s',
#  'en-EKy-uLtZUwM',
#  'en-0n_kkREWipc',
#  'en-qABeYVmG2T8',
#  'en-E40TfOK3xzE',
#  'en-KF5XjG2vvvs',
#  'en-MUKFLdkALs8',
#  'en-J9ntHtLQLhQ',
#  'en-8CWLZoVoTBE',
#  'en-1DS0n4-nWWY',
#  'en-_yASqOZhnrs',
#  'en-_LSb1t-mI0Y',
#  'en-L0QjHYAemIU',
#  'en-T_rjDjiwoP8',
#  'en-0-QVAPFSxbc',
#  'en-Q8VSUiGLCHE',
#  'en--QfmURZHiTQ',
#  'en-D-1AySDLMOY',
#  'en-V4NuC3_BJDc',
#  'en-tq0T-s17VGg',
#  'en-kgkl1tXXujo',
#  'en-AAu_mpmHZQo',
#  'en--PrLvBcB8Ek',
#  'en-ULSD5tgcf7k',
#  'en-qi7JcUb7_XA',
#  'en-7O86mi-P1UA',
#  'en-j-xH8vJAx-Y',
#  'en--60SG-VK0W0',
#  'en-5OfvH5zO_EM',
#  'en-rEniwbYzA6I',
#  'en-fjnIjTz3oAM',
#  'en-QT3vLmipRlA',
#  'en-W8SMHYbo_pw',
#  'en-KdkRqFau058',
#  'en-CaXO0Pnsm0Q',
#  'en-lUBtIqrZV0Y',
#  'en-JnlaX8B8Bps',
#  'en-7LAwKS_1XP8',
#  'en-Nf0tMBxFXpw',
#  'en--QKyp8DsHMY',
#  'en--Hsh-Y7Yf0w',
#  'en-CYNI3x7yGsc',
#  'en-VR7Kdv_z56o',
#  'en-tmUH2RyvMa8',
#  'en-JklGgZl7L6w',
#  'en-4F9XGGSVwEA',
#  'en-0_yuuTuwNzs',
#  'en-2Ntn6mWDa2k',
#  'en-8tiHcVVQHn0',
#  'en-m42ynW4qNMw',
#  'en-NkH0WvidbFw',
#  'en-_CSeKeJlDjY',
#  'en-HK4fnXyUlvs',
#  'en-aehWHAFiLTY',
#  'en-EnerrhCKwBE',
#  'en-KD_-LE4nLNg',
#  'en-cKdkNYdLGH8',
#  'en-5fKSzopxoDM',
#  'en-Cs5WvfKaFIA',
#  'en-IaMN8Lz2lC4',
#  'en-QLRXMXMVA2M',
#  'en-lKhe2w08ovM',
#  'en-p7QfcTXh7f4',
#  'en--ADm2BBnFKk',
#  'en-qhDJDPsZ7XI',
#  'en-lR7KRTU9h_Q',
#  'en-uy9v8zn29KY',
#  'en-03zWaVCye9c',
#  'en-PdT7JkQgC6M',
#  'en-51DbPQkee6s',
#  'en-Oa-GmfO34a8',
#  'en-1GigWvJtPpA',
#  'en-L_KV90W1bXo',
#  'en-kjU7-Z65_vc',
#  'en-vpstItSENDg',
#  'en-3BwRYPK3yD0',
#  'en-kFq-YndZaM4',
#  'en-XAkKQzjw23g',
#  'en-IEz5TY_I7XY',
#  'en-_82AQ77zgAQ',
#  'en-pTUUfFpYZTk',
#  'en-isn8kbaZneg',
#  'en-OwjOYKHJJBE',
#  'en-aVMVphxLvz8',
#  'en-_XRQXii7hd0',
#  'en-0KfcLOJytsk',
#  'en-9LYACmTwzlU',
#  'en-OFl1106r74I',
#  'en-LWwLSsr0DCo',
#  'en-Ndtz8Hj-xAE',
#  'en-tssk2LmV-w0',
#  'en-QMDEVBXMKfw',
#  'en-qljbUm4TNLI',
#  'en-6JoCrqJdopM',
#  'en-6e27M83A73c',
#  'en-Ko6fLslfoME',
#  'en-knFguPgaBr0',
#  'en-6h-uFhG0fCM',
#  'en-68pVfRN4CxE',
#  'en-faukGdcyDCA',
#  'en-F5UZApCtC3o',
#  'en-hxmdnwS0-7w',
#  'en-pCkcH_T91NM',
#  'en-5nlWTe-qDHw',
#  'en-fluq8bGmOuk',
#  'en-hJUvjFxEZzE',
#  'en-CADSvAb6HJE',
#  'en-sSh_VrMFe6E',
#  'en-MbdJCI8Nxco',
#  'en-bSUGShQcOvU',
#  'en-YhOnb8xo30I',
#  'en-82E3ODSKPMw',
#  'en-zkXCNpTdMck',
#  'en-tMVb5y9_buY',
#  'en-aHkkbpuDirE',
#  'en-XB3ejoumyhw',
#  'en-_MKti03Oh_Y',
#  'en-3oXv-U-Q5ZU',
#  'en-B0qaBJccTl4',
#  'en-OWJ6__8dg7g',
#  'en-sO3SMTVfz2M',
#  'en-0dOD8YjzwUg',
#  'en-5Q9AXoDNAJQ',
#  'en-rjthvGJ-ZOM',
#  'en-fGDDNG7MU-E',
#  'en-rH6n6ph7KeI',
#  'en-UvxoWZ1_3rw',
#  'en-cTYohVh4ELw',
#  'en-pKaiBACX9wU',
#  'en-vjQmXJALm2Q',
#  'en-z0lHwxICqAE',
#  'en-vSbew4xD4Mw',
#  'en-rOlhnfWDpRA',
#  'en-_fUMl6PTaBE',
#  'en-5LG3nVf-bxk',
#  'en-je7_juVXOFg',
#  'en-gGUR3N64PFg',
#  'en-w6l1e3pE0jY',
#  'en-kepmYpSOxJQ',
#  'en-pHUylXYZZLo',
#  'en-Lem_UvmrI7I',
#  'en-odZ5V_pwjec',
#  'en-y8DCANeGYyU',
#  'en-ksTMdDU2OGg',
#  'en-mNPBoxSsjSU',
#  'en-YEQ_C0QSwyA',
#  'en-Udkwln-PFHg',
#  'en-JcgjdUH-SnM',
#  'en-1PE6NElQeas',
#  'en-FWafmsbWzqs',
#  'en-5dPEVTk02wE',
#  'en-tIztzdFpatE',
#  'en-oqn3QKYN2Xg',
#  'en-6MwIu2-7ytQ',
#  'en-3yjWbmBsk4s',
#  'en-O4v5uEbh0hQ',
#  'en-n25ct6EqzYI',
#  'en-2ACcSsbtSl0',
#  'en-5e--vP1d420',
#  'en-Pohp-MY13d8',
#  'en-Urk2ZaHT3hM',
#  'en-zmdlXnm8Ux4',
#  'en-MGpediGuesA',
#  'en-nHyjzXcC8Yg',
#  'en-tK5LB4S-wZk',
#  'en-h24Kmen0u2o',
#  'en-TeS8SOGj7cs',
#  'en-rlsRwcn8sws',
#  'en-9HaO4RqMKUQ',
#  'en-abMvXAtvjTQ',
#  'en-CcjnCVoL7WA',
#  'en-03JKH6oLumo',
#  'en-SpwjJ3lKfXg',
#  'en-E5kG9NAai5I',
#  'en-hnT6agGqbY8',
#  'en-a7qRCc6Btjw',
#  'en-hbryQPGDHzY',
#  'en-3KIOLzop0i0',
#  'en-AuysDZ0S7Ws',
#  'en-W4gMiJdo_To',
#  'en-rxWJKgVXEiU',
#  'en-gZ6zfS8jeTI',
#  'en-sl64egjQ3Ag',
#  'en-JvkxdxCuhsU',
#  'en-SBtrUx1xpfs',
#  'en-8LX0vmKxAvY',
#  'en-uB6dX2SvScU',
#  'en-pi9_kXRtTeA',
#  'en-CYLbD2oks0A',
#  'en-cXz9uBLdeEQ',
#  'en-wCrg0BM1hN4',
#  'en-KjQ3RSa8_v8',
#  'en-Hc_wMwGkewQ',
#  'en-e8dP0TWvQec',
#  'en-pE-UwjTAFDg',
#  'en-IhuTzUh_KJc',
#  'en-Vr8lJLWwcfY',
#  'en-RHRLozkkEjY',
#  'en-TWyxagbqsaI',
#  'en-5KIqRqlcyC4',
#  'en-3pK74FgVxOs',
#  'en-OdchAswaIjs',
#  'en-cplbomZ9y30',
#  'en-KPEgy71wmY8',
#  'en-cK6OtUh8kWk',
#  'en-iLPIu9cjRE4',
#  'en-qZGBRysxZAM',
#  'en-oYy2EF5p0Kw',
#  'en-UqJrMcpbrzY',
#  'en-71JQrA6ijzU',
#  'en-pQ-rHiB0u-U',
#  'en-K6BJjJP1qsc',
#  'en-5676iZ8IKkY',
#  'en-y5gNDcXMDX4',
#  'en-VxmIbTer_Qw',
#  'en-TfDadef0JLM',
#  'en-Dy3ULUnsxIM',
#  'en-g5vuJ2lwX88',
#  'en-BndJPkjQG1k',
#  'en-6dHyf5gSVE0',
#  'en-3jOlfo3rXo8',
#  'en-8CUtC8gBD9w',
#  'en-8nQ8lZLW0xs',
#  'en-vOsWDc3Iy60',
#  'en-DlSIxnjIF9k',
#  'en-C16DjHDqO6M',
#  'en-ExJph6llqMY',
#  'en-t9rmp_T1XVg',
#  'en-nGSvmpwiGzQ',
#  'en-7PbT6Xjg-v8',
#  'en--Fe-yeu4VJM',
#  'en-zV9rpV_N98g',
#  'en-nVsS-NJuVx8',
#  'en-uTvqldkDrRI',
#  'en-CkFZnOLxrwY',
#  'en-apY_AW2X7Hs',
#  'en-IAz9ea9y8eE',
#  'en-tPQFLuoqlsY',
#  'en-VlVbftXrQNo',
#  'en-_pBsd0RMIxQ',
#  'en-3XwmgslcQaU',
#  'en-A3Ecrlu9biM',
#  'en-BgazF1UhuJ4',
#  'en-Ry5-ZX_sZT4',
#  'en-TnEhYEp-aBM',
#  'en-wzL3lAF6jn0',
#  'en-CJeEC_K6L8k',
#  'en-5C5ittmwZkU',
#  'en-j3pyxrBC5jg',
#  'en-YjNuoVHOkXM',
#  'en-BFWaVFkdOww',
#  'en-k0KYjG2_O70',
#  'en-6TVh8pW53uI',
#  'en-GS5SOBHwq6Q',
#  'en-jKxtItBJ32A',
#  'en-foNObZQXe5o',
#  'en-scsKJQqHrBo',
#  'en-Wzs8OJn4Rzc',
#  'en-zfy_7IBw6EI',
#  'en-Pz6nZWV1jRc',
#  'en-6tghadoMHrs',
#  'en-1S0vpP4vjJM',
#  'en-hvlunLOMMCE',
#  'en-4L4CIJcbyXE',
#  'en-cnkpDH6r75A',
#  'en-l2Bwkppuzj4',
#  'en-xMpCOKC5I4I',
#  'en-MbMvfbDbGcs',
#  'en-b-R4jApv2TM',
#  'en-DeEyq2vGb8A',
#  'en-US-AqhDACjA8z8',
#  'en-US-ZxyPNntM7rQ',
#  'en-LKrsOOeZozg',
#  'en-ESfBPZqkH38',
#  'en-a0kjzbC90A8',
#  'en-zc0Vi5xGEfo',
#  'en-IQ7H2o7j0c8',
#  'en-Dd54unfXcE8',
#  'en-vocerhI87fE',
#  'en-MigqkjNOw58',
#  'en-jjBJH7lTUKg',
#  'en-hwX3LfZTULE',
#  'en-fh48_QrE1hY',
#  'en-xsH4GkZmY4U',
#  'en-xp8wTkmrYBk',
#  'en-SATcPBM7EVg',
#  'en-HwNRUj8FeQ8',
#  'en-qJZESNn_AxU',
#  'en-holatrtIUCQ',
#  'en-JJGXnKCQq4g',
#  'en-Qg9lQ1T6Y7o',
#  'en-QhtH_9lGygg',
#  'en-b6iyEpXIBjo',
#  'en-PxRD9FUKcPM',
#  'en-EGeYWqoRqAY',
#  'en-HcpzABuoILQ',
#  'en-5IebwaT_cAk',
#  'en-ibp-KIDPdFM',
#  'en-cQRnRtfsWNs',
#  'en-j-DUVgSMDs4',
#  'en-tAZiNMKolyo',
#  'en-jz9b5BRHp6o',
#  'en-ejq1kKl2Nr4',
#  'en-biwO9NlAmzI',
#  'en-oCFeSHm1PK0',
#  'en-BI5VxhDaKcU',
#  'en-X4llK2BHGVk',
#  'en-HEP_f80angE',
#  'en-AZzuwjkK7VU',
#  'en-AUlNl43RLUY',
#  'en-BThSmalEtiA',
#  'en-QXfiIUpeSOU',
#  'en-WWbHFJ2ygpw',
#  'en-CDttcHhRL4Q',
#  'en-kGFIlJjZeYM',
#  'en-YEHvvy0yz3g',
#  'en-qSoyhvm6BFI',
#  'en-YdrzNOc_U3M',
#  'en-4LigGaBYn68',
#  'en-bLgCjrlniDQ',
#  'en-jYrba1QEd0k',
#  'en-XJeq9C0sX3Q',
#  'en-rC2Dig-a18E',
#  'en-Ud06ITxUzzU',
#  'en-am9hPfzk9iI',
#  'en-k7USmNIY_2c',
#  'en-wRoEKfvjmgc',
#  'en-W0OIEICHx_Y',
#  'en-VOG3HjyvQlk',
#  'en-tZkqH-jWRkA',
#  'en-luNYi-aYuT0',
#  'en-fFlHgtwCwRk',
#  'en-l9RF4bnB1D8',
#  'en-8VDO28V8hj4',
#  'en-VrZWbCFgoEs',
#  'en-sAI1gFA6wGg',
#  'en-DIU76F0j7tQ',
#  'en-lOx6T3JTY10',
#  'en-EaQeC02svKY',
#  'en-sLwHoeeseCE',
#  'en-SK8mKEr0nnI',
#  'en-BCuI6ukauNA',
#  'en-xoWSyw3VCMo',
#  'en-qan6oo_wMrU',
#  'en-dwmJd08dOAg',
#  'en-FYUoNZY1mQI',
#  'en-4a3x7CQV1y0',
#  'en-poZMLriuctg',
#  'en-OS9sha6d5RU',
#  'en-PgAHCvmtOAk',
#  'en-vVzZYejqbtw',
#  'en-2W4EtWJlK-M',
#  'en-5d7Xm4anl04',
#  'en-Tj5hQL8p4M0',
#  'en-32yIRCNHjSA',
#  'en-qQgQLjMtvso',
#  'en-iGJpuh49ngc',
#  'en-1YTKc5uBuX0',
#  'en-VtYbQoTezbY',
#  'en-N3OJnwe05UE',
#  'en-AA-YRhqqprM',
#  'en-5JZeL29-zso',
#  'en-s79-lbO7vlA',
#  'en-ytwtKSECq4g',
#  'en-jY1ADopF0sc',
#  'en-8EmMRk0l0j8',
#  'en-h6JOLvD1ROk',
#  'en-tQxeuzSQLzo',
#  'en-gyTlw2MWSM4',
#  'en-d00nSg3Cfyo',
#  'en-o_saPiyfYr4',
#  'en-dK3ueAivHc4',
#  'en-_KJvEI781m4',
#  'en-QRmnt5SAfu4',
#  'en-8bnHk9XIbXk',
#  'en-wKsaL39ekjo',
#  'en-iVVdvKroLnA',
#  'en-Jyun0WSqg2k',
#  'en-pM_7I_z4dMw',
#  'en-Y4XppJeFzlE',
#  'en-US-hfOJEiqFd8M',
#  'en--t9nn0_j-bE',
#  'en-JyYAHjjqNOA',
#  'en-dFudY6t5X7A',
#  'en-nj5jOKOMbdU',
#  'en-iQ-YAam1haw',
#  'en-BgWtjaf8YKw',
#  'en--lY1rW47D0Q',
#  'en-0wvDNVok4p4',
#  'en-i3xbGV-UktA',
#  'en-3KZFvNN-gGo',
#  'en-1aDXNDe7x-Q',
#  'en-gUMswmtE6iA',
#  'en-ec-P7YLM2Dw',
#  'en-HisvpXgdYA4',
#  'en-LzNmH45Y04Y',
#  'en-bYYkeHbwhRI',
#  'en-FtGa9rf7tQo',
#  'en-riYuw1Q8daM',
#  'en-Osp3y-v7HRo',
#  'en-mZF8sD4_fS8',
#  'en-4FGGYKP-6ms',
#  'en-1WI-SLbLzsQ',
#  'en-XX-rOsATJ30',
#  'en-2VFdN33bd9A',
#  'en-kv1NZ_-NwTQ',
#  'en-l0o-PP3fNu0',
#  'en-JnNAwlyGHI4',
#  'en-y8IQRxU3RH0',
#  'en-aJiMr4erhSU',
#  'en-b0r1qA4uSFg',
#  'en-yuEqmD2iaC8',
#  'en-ZEFLAQKG-Kc',
#  'en-PPLzREGga6Y',
#  'en-h9ZjJHYCM6s',
#  'en-T6bZS44dnXU',
#  'en-uZNow-RLKkI',
#  'en-RvHU4dUN0nY',
#  'en-etvPrloiS94',
#  'en-G03uQPjZUvc',
#  'en-tjNQfWE3dzw',
#  'en-KQATFxyCPlI',
#  'en-dFGlgm97Xlc',
#  'en-myU4rfYNiMk',
#  'en-Ns-C-Txg8mU',
#  'en-hwCpdVLsz2Q',
#  'en-tvU_qYknnzI',
#  'en-lnZ9iJ0FBjI',
#  'en-RsqbpyYmt4A',
#  'en-mWjhSW77dlA',
#  'en-Fm3Ogt84EFo',
#  'en-fxvPob8O8Us',
#  'en-exnUePiwlh0',
#  'en-O8opXNGnD_Y',
#  'en-Ay6deuzj_Fs',
#  'en-ve56ZO5AnFI',
#  'en-kapru27K85w',
#  'en-9GqlIkd9Vag',
#  'en-w0oOfB7_TRc',
#  'en-kuH_dVQYIM0',
#  'en-3rMTuinRtOU',
#  'en-yHSRlCQc2gc',
#  'en-t4eEig8Uahs',
#  'en-M43HNTq__w4',
#  'en-YOPfLO0Wah8',
#  'en-qiEgTyMPuh4',
#  'en-zLbge8FqRFg',
#  'en-xdqx7aXycSQ',
#  'en-1t09etvDupk',
#  'en-1YVi06dOzOI',
#  'en-lng_mWKnSbU',
#  'en-AnpdouvEVjY',
#  'en-Elu8Px_PWK4',
#  'en-8oCZgFuG6pw',
#  'en-Zn2UPEUjtGQ',
#  'en-Gbyw1ZKnlc0',
#  'en-DL7_EMEJYuM',
#  'en-CZJ4ki4C5YU',
#  'en-4Ww3tqA-L0c',
#  'en-j2yLJ7zq7SY',
#  'en-Anvvp3twMeY',
#  'en-5IzUjYH8ebI',
#  'en-j779am_f-wk',
#  'en-g_PPN-9N_zA',
#  'en-KWJzdJHquRs',
#  'en-OZxov6QiMUI',
#  'en-DMF60q_CbA0',
#  'en-iQs7wIorhP0',
#  'en-UOTcx8cQzGc',
#  'en-5bfyAkdqAGU',
#  'en-PLje9GMx-vg',
#  'en-SPyV2tOLitc',
#  'en-d_AtKRxbH9Y',
#  'en-IHFK3vBOnGs',
#  'en-2dHdNwhv5qk',
#  'en-Fv_fF7okKFM',
#  'en-lIO6DKEqe9s',
#  'en-lLxJ2PfwYHo',
#  'en-9TvAL9l_170',
#  'en-ymNW8s5r7u4',
#  'en-TCRix4xU62A',
#  'en-FWthRi99Tf0',
#  'en-8UtQBZbmIms',
#  'en-EDSxBVUWF_k',
#  'en-UOGAHUJjd6Q',
#  'en-omFn5SV5cog',
#  'en-8tUsliqDHuw',
#  'en-di1xDVb1O0w',
#  'en-ll-HOv8cLYE',
#  'en-jHgmPujjTmk',
#  'en-e581ZLkQzuY',
#  'en-KOeuOC1rItA',
#  'en-w1kX2Hgbwjw',
#  'en-TnDwn4HhXzo',
#  'en-vfYc3N67YcY',
#  'en-EUsEfGupNy4',
#  'en-XTegyMbq9OE',
#  'en-enOC6jJi_HY',
#  'en-_zNFOF2fCUU',
#  'en-BNEdRiwbhMU',
#  'en-ch84qudUBmc',
#  'en-M8q54waQejw',
#  'en-R_wTi8Uv8ds',
#  'en-DwukCe1LIrg',
#  'en-LQjmZIKTLto',
#  'en-Z0ATkRMC2Ao',
#  'en-UVHnuheB50s',
#  'en-3hcZntO7uF4',
#  'en-7yfzWTJj67g',
#  'en-VhCdYKm_9jg',
#  'en-bvUAhe4-GuI',
#  'en-Rp4QDWZLk6g',
#  'en-j7ND1gUZnJQ',
#  'en-wa9lvz84I0Y',
#  'en-8lPv4wLTKrI',
#  'en-TW7qhz_uLiI',
#  'en-zpe_0llnNAM',
#  'en-0xhupAQKumU',
#  'en-A19OKdotbTE',
#  'en-vUATTBopHz0',
#  'en-TviDKZZdmds',
#  'en-Z-1t232JCyM',
#  'en-UqHaEbs4GmY',
#  'en-yB5yjZ1ML2M',
#  'en-qCFHKpUhyjk',
#  'en-pybomlPBVAM',
#  'en-b3nrla8N478',
#  'en-ZENaCr0atrw',
#  'en-OgcjcBmmEZI',
#  'en-BVMBxWq8gt0',
#  'en-xIP2zoUcns0',
#  'en-O-pQdyNgKEs',
#  'en-9HeNTlM9ZSk',
#  'en-5CO4vem_v9c',
#  'en-gYtoQ0m4uXI',
#  'en-ry1llo_oQGM',
#  'en-8O2Jz64HBEg',
#  'en-y9yxbi4NzJI',
#  'en-TDiCYXlbDkY',
#  'en-bocKBzXrx5g',
#  'en-US-xp8wTkmrYBk',
#  'en-t4oyI1A4lnI',
#  'en-PCppR7YTWCE',
#  'en-phnZdGWPPnQ',
#  'en-OZ92FyDE8ps',
#  'en-F1HFA3D10Hs',
#  'en-xSC8k09R1b4',
#  'en-WSRFbp9AnDU',
#  'en-L7Y0O6H27Ss',
#  'en-fql_4DCNcvM',
#  'en-8Bj4hvHO-4Q',
#  'en-MQ9WiDCd2YA',
#  'en-XAZVtJ2lNCU',
#  'en-lf2H5xNwklI',
#  'en-OolyXUnJn5Q',
#  'en-MJh3ONyxbl0',
#  'en-k6_V0DHOLv8',
#  'en-fvljIKucTW8',
#  'en-NJTdi-L8AvA',
#  'en-_CmQIdZcT_Y',
#  'en-xiO0SzMwdJI',
#  'en-_HJzAacdsAo',
#  'en-ljdn0F-Hi4U',
#  'en-M2QYbqjQb48',
#  'en-ywhOJIWs288',
#  'en-Nd9rjzhufAA',
#  'en-t-_dZfrLIcw',
#  'en-YWDb3gDAtvQ',
#  'en-tKS346G9R-Y',
#  'en-vlXvBvzdejA',
#  'en-yKnSH4XXYog',
#  'en-0AdYWwNI9XU',
#  'en-bQRV2x1IOtE',
#  'en-M3Hjt3fO9V8',
#  'en-XxS71bbhHRs',
#  'en-B93zKT5APNA',
#  'en-CNaPR4CDsZQ',
#  'en-MRy7lnAFIhg',
#  'en-v5vzJZbGwYk',
#  'en-EMg_yBD-niU',
#  'en-Z55bU9Djwr8',
#  'en-aBoudrOcvcw',
#  'en-EsEnpfvSPLc',
#  'en-UZ_75mBzC8Q',
#  'en-1Az8h73Oryw',
#  'en-j4zR3Ybodb4',
#  'en-vq5CGhSjT4M',
#  'en-w38AW50bQPw',
#  'en-zhVot1Lz44c',
#  'en-pI4wVfOuC6g',
#  'en-FIeSGty7qZQ',
#  'en-ujfgx3Mcwl4',
#  'en-JbVGJ5YVCmQ',
#  'en-peaJvapWiM4',
#  'en-_lAkpe2hStE',
#  'en-DLAhhdw-dys',
#  'en-RTbB2cpHawQ',
#  'en-jO-1S7bRnDM',
#  'en-UG6ArUNztS4',
#  'en-o7EPVSnA9rg',
#  'en-p9dJo5MbMgw',
#  'en-NE9aqoTkWLk',
#  'en-5pnBo7yJKHs',
#  'en-vJpbnpJZGZo',
#  'en-7xrIwpv9jTQ',
#  'en-GB-gR37TAiHgbs',
#  'en-qDZhSy3RbrI',
#  'en-0rdOipdQVYk',
#  'en-1wio4ycAOlw',
#  'en-w2TOVZ1QFek',
#  'en-US-yRTVp9dEmuA',
#  'en-US-fkWfzGpaM5U',
#  'en-US-lHDFPjrImWk',
#  'en-US-GGdF8jv1gQ0',
#  'en-_OqSD3QStdo',
#  'en-B2ikPfar7I8',
#  'en-8gSXBWIRgDI',
#  'en--yyvk-w204M',
#  'en-Ejo-BUL0uTc',
#  'en-cDP6_EPPGSo',
#  'en-LG8d_i9VuVg',
#  'en-U8UKx1dDRMk',
#  'en-KUR8XP-XFAQ',
#  'en--NiJPS5vRm4',
#  'en-0s-uy-8ZclY',
#  'en-574NXbkqqIk',
#  'en-US-6qOgrvYwYZs',
#  'en-lZfHCuL_mFs',
#  'en-UzGKZfsT4Xc',
#  'en-faTH1oTU7vY',
#  'en-US-ov-bBqE7obA',
#  'en-VALzq8MGic8',
#  'en-qqdTyfKvCxI',
#  'en-TqavBDFL8sE',
#  'en-Szg_r67Ef8s',
#  'en-DYLCI8g7QaY',
#  'en-qKal7JmFUEY',
#  'en-dBSi4JN31fw',
#  'en-pw0AswWwyDM',
#  'en-GHEw9DUond8',
#  'en-1KfrDQ_4T0c',
#  'en-GB-qtKPkDP1qx4',
#  'en-DCiYnyifnwY',
#  'en-qJznlvl_CrE',
#  'en-R3oB6LELdLs',
#  'en-nWdkcXlP39E',
#  'en-ZbO1wkqGseo',
#  'en-ITHqFL5B7Gc',
#  'en-WV9HkJAdVBc',
#  'en-US-zNJ1nOmq8FA',
#  'en-qtKPkDP1qx4',
#  'en-NqVqXTUkKhM',
#  'en-STUutXTUdc0',
#  'en-dLhzN0VCANQ',
#  'en-US-zOFsReYi2c4',
#  'en-US-zfxP1DU5ttM',
#  'en-2JIezzybkFU',
#  'en-edktoeXOHuk',
#  'en-U2rv5V8iHr4',
#  'en-5kcAUxIuri8',
#  'en-emAXxjRTU7k',
#  'en-y7dQRWowDOc',
#  'en-XfSOwY0Mh4Y',
#  'en-FkPiI1JB-Ek',
#  'en-qoXxhA4oLYo',
#  'en-285T90m6grI',
#  'en-OS3c6c0jqDE',
#  'en-lYilVQqFNCc',
#  'en-OO9wEeaBFKU',
#  'en-QlpfAxpVYQ8',
#  'en-wLkQp79ECks',
#  'en-FpB8gaq1beU',
#  'en-ces5WQ-bhxs',
#  'en-ACKccdfFlSU',
#  'en-Z_VCyaTNcJE',
#  'en-NYWFwJPdEPc',
#  'en-Xn_Ej4nDaM8',
#  'en-8Fe8s_l5nV0',
#  'en-BIYaK4pZrG0',
#  'en-MFdV3jS_VJw',
#  'en-nPSgtM3y5WY',
#  'en-T0oVSwuOKq4',
#  'en-IRDTswvZtYs',
#  'en-wA_k1bvj3yo',
#  'en-uO9lcfI3d00',
#  'en-AnQ0jseWrBo',
#  'en-y_CAzI-3OYs',
#  'en-5cKmUtHuj8U',
#  'en-zCr2L5MQxO0',
#  'en-oCyDp9vZYpU',
#  'en-ugpt3ZTHNpg',
#  'en-Mc_Ao8Aa4Rg',
#  'en-t22mztutYp4',
#  'en-ctopLtZXsKI',
#  'en-GB-9YAcIVH3vwc',
#  'en-ClLaegOm3js',
#  'en--lW5ij6VpWI',
#  'en-xjCGHgdqcSQ',
#  'en-0JM7PlxQWio',
#  'en-gID_ZZElmJs',
#  'en-IMXD_wR0228',
#  'en-SyApD4WiMxU',
#  'en-BlD2WH2l1cM',
#  'en-LFUw5oOVd8E',
#  'en-35qsMs3jRUM',
#  'en-qT6hygNN9tg',
#  'en-IPICgexbSio',
#  'en-US-EP72IGCJZ2Y',
#  'en-L_oXDHH7lAU',
#  'en-3CGAkvYoNqM',
#  'en-TgYkKSMIGlc',
#  'en-dteu3E6tmMg',
#  'en-Ns7VaV6HZmw',
#  'en-N7KVyJ0sPHg',
#  'en-eQpyjGaKT5I',
#  'en-3_QN-DJkT88',
#  'en-VwdcyLH0R6Q',
#  'en-umh5piK3U-A',
#  'en-QsgWJy-dFt8',
#  'en-2S3C9gO8h8M',
#  'en-Np4rYsLJFNE',
#  'en-PpFmytKS25w',
#  'en-0U2HcXs5mnQ',
#  'en-0EHHyoIOVqU',
#  'en-4iAZ0O2TOTk',
#  'en-dZhp99YEDSU',
#  'en-BBM9-a7P_cA',
#  'en-u-ZjYex4kOI',
#  'en-h-aT-LoH4FE',
#  'en-I0BfNXTKQ08',
#  'en-CXHByXDFUt4',
#  'en-H7mG5M2uRc8',
#  'en-YyZiockxlB8',
#  'en-UEPQezxLMJE',
#  'en-87goFPCi6Bw',
#  'en-uuIW9_4H-6Y',
#  'en-8b5QK2tcv34',
#  'en-WuWtA7jf-Qw',
#  'en-noKQIrXensA',
#  'en-1sGL68ZAsPM',
#  'en-zxacnGnLwyQ',
#  'en-7XnjFg_Aunk',
#  'en-IZmhVuH4xko',
#  'en-w7kt1Ip6Csg',
#  'en-wunJtVs-osk',
#  'en-P9Mav3cA8rQ',
#  'en-N9P0sl9h4Do',
#  'en-VqaCkJ-HYII',
#  'en-MiCQirWEZgY',
#  'en-A_CeeZgG9Gw',
#  'en-UkT54lkS9o8',
#  'en-NKW4P_65ptA',
#  'en-cdbBIhL5fck',
#  'en-pcBy-pR8D1Y',
#  'en-UH3VSByxSEQ',
#  'en-cle4oQObjkM',
#  'en-ZdayYTVZCFo',
#  'en-jaKm7YKNL7c',
#  'en-neJsWgJ6p-E',
#  'en-Z0CJZZwoafY',
#  'en-5SEid7gbbic',
#  'en-s4iVkCKjtII',
#  'en-rzDUoivqtZI',
#  'en-KbXzD9t7OQA',
#  'en-LsA4hb1BqBs',
#  'en-MlaD_crJMHs',
#  'en-4coCF7KHMFY',
#  'en-diDUGZwosPk',
#  'en-suy4TXxcX7k',
#  'en-z7G7yg2Wr5k',
#  'en-eUYiETVOm4s',
#  'en-TWzXyfYTEtI',
#  'en-NTYem3CvX1A',
#  'en-0F12ZQI1J6c',
#  'en-7RkuBd3ryjM',
#  'en-UqzPdI4wWLs',
#  'en-lhAm1LaXT8k',
#  'en-_YdLbD8Erbo',
#  'en-V_qMosfx-Og',
#  'en-l1qxrdK5aUo',
#  'en-VFov8RmKaTk',
#  'en-tLIRs_ONjFo',
#  'en-mNJjsMSxEPs',
#  'en-_jnNrv2AApc',
#  'en-S77zH0rRMHU',
#  'en-kLNlFZUrLqk',
#  'en-kDvwLNvzoXU',
#  'en-5hT1vBMcvs8',
#  'en-BJaIKb57W4I',
#  'en--HvDisuv3DU',
#  'en-u8gIWBDLUT0',
#  'en-bQBT9NHmgTs',
#  'en-wceyOJUaWWo',
#  'en-e7AbtTyboDA',
#  'en-naWzbP-9sYU',
#  'en-iM09lmWrfOE',
#  'en-CAEO7Nm307E',
#  'en-M9GJQwA2pPs',
#  'en-bNcUEFHmmJ4',
#  'en-6HGVhQpAJ4g',
#  'en-w4h12_UqLKw',
#  'en-5e1n064AEDc',
#  'en-WP-ReZ1BjS8',
#  'en-OUgJt5564yw',
#  'en-KO9_aWmS358',
#  'en-kF1hcwd3zUk',
#  'en-68CEOFgH-YU',
#  'en-TJke2-xp-gE',
#  'en-dHUVknVUAu0',
#  'en-SmmGFpRHk0A',
#  'en-OpZ4rvTSEOM',
#  'en-3mfdl2u5hW8',
#  'en-8I1z6nph6U4',
#  'en-8j7-ZXSRZCc',
#  'en-zGRbMiR5h8M',
#  'en-6TOqxqCPX1U',
#  'en-BbzR8CxdoiM',
#  'en-wYxld7DRoA0',
#  'en-PM07seUvkVI',
#  'en-dJ5DkJt46fE',
#  'en-dYyXDaID_lk',
#  'en-_5R1AlZR_t4',
#  'en-iEo7JbHC-0g',
#  'en-BedcS_0ZIQE',
#  'en-jeQXPLP9aJ8',
#  'en-cRMy2MCvqnw',
#  'en-TET0_5maZhU',
#  'en-aVKXiD3iEf8',
#  'en-ghzFZpqMqxI',
#  'en-Y8WNLQpIVHk',
#  'en-n7PWN4P6MiY',
#  'en-ynG_1Kpp8Xo',
#  'en-ZQFG46aEmc4',
#  'en-GXEjFT5DZa4',
#  'en-4SAf8I4ozw0',
#  'en-5DoERbW5mG8',
#  'en-BFN_toKzRc0',
#  'en-geFmVJUnfCA',
#  'en-PgiNWh4Nwqw',
#  'en-TjHUV1tly5Q',
#  'en-UPX_Rr_6EoI',
#  'en-8bDH7d3DAyY',
#  'en-zaT5CihTRSU',
#  'en-wffyL7oz-l0',
#  'en-HriO8ysysvY',
#  'en-D84RIvDi0VI',
#  'en-iRn-p1Wp78o',
#  'en-QHK0OGIBz2k',
#  'en-eZbrvm6znPA',
#  'en-IxQxwLrRgpM',
#  'en-qeWLctqM-us',
#  'en-7Ka_9kBECqs',
#  'en-IWDqFjB11kw',
#  'en-29YEzjC4vP4',
#  'en-pvb_Wl_d91s',
#  'en-sC6YFQDWfIs',
#  'en-Ff978Ty2QpE',
#  'en-_p-JTifub8M',
#  ...]

# %%
bad_4M_df_2["manual_caption_languages"].value_counts()[:50]
# Out:
# manual_caption_languages
# en-US                340387
# en-uYU-mmqFLq8       260000
# en-GB                143094
# en-nP7-2PuUl7o       126966
# en-ehkg1hFWq8A        60954
# en-IN                 26036
# en-CA                 25484
# en-eEY6OEpapPo        18269
# en-j3PyPqV-e1s        13300
# en-1oAFzPNiuC0         8244
# en-LUU0EuDKgKo         5574
# en-qlPKC2UN_YU         4898
# en-hnCuwW0TCiQ         4627
# en-rX01gsAdUfU         4440
# en-RTbB2cpHawQ         4290
# en-qoXxhA4oLYo         3708
# en-VjEpQ-RlAYk         3673
# en-US-eEY6OEpapPo      2970
# en-i7LFIGUQP0g         2840
# en-Q8VSUiGLCHE         2537
# en-zL7EZQmMa4Q         2496
# en-0hllRZe4s5s         2365
# en-vlW2OHFw3ww         2329
# en-IE                  2296
# en-Jyun0WSqg2k         2097
# en-US-cvfXDfbeED0      1865
# en-6UJrWS5jR_I         1649
# en-cvfXDfbeED0         1623
# en-anMIXjicSL4         1347
# en-dQs7zDoAYDs         1288
# en-US-dOaosRHqfaE      1197
# en-US-zOFsReYi2c4       993
# en-UMYBvvsXfqo          922
# en-E3euOu7LhIg          884
# en-n7b14AlKMnA          828
# en-GHEw9DUond8          808
# en-810jCDypfJE          663
# en-C_fBn36sO_o          610
# en-UmXsJi774Ak          542
# en-dPkTXTcEUoI          493
# en-_yASqOZhnrs          429
# en-KiF8PLhXDeA          417
# en-LS-YPGm-czI          380
# en-S3doMV87xA4          351
# en-A19OKdotbTE          336
# en-8k-bGVCfGYE          306
# en-gG13fOM8Dfs          300
# en-PecspfweHZs          288
# en-AU                   261
# en-US-xp8wTkmrYBk       244
# Name: count, dtype: int64

# %%
bad_4M_df_2["manual_caption_languages"].value_counts()[:8]
# Out:
# manual_caption_languages
# en-US             340387
# en-uYU-mmqFLq8    260000
# en-GB             143094
# en-nP7-2PuUl7o    126966
# en-ehkg1hFWq8A     60954
# en-IN              26036
# en-CA              25484
# en-eEY6OEpapPo     18269
# Name: count, dtype: int64

# %%
sum(bad_4M_df_2["manual_caption_languages"].value_counts()[:8])
# Out:
# 1001190

# %%
accepted_langs = {"en-US", "en-uYU-mmqFLq8", "en-GB", "en-nP7-2PuUl7o", "en-ehkg1hFWq8A", "en-IN", "en-CA", "en-eEY6OEpapPo"}
condition = (bad_4M_df["manual_caption_languages"].str.split(",").apply(lambda lst: (len(lst) == 1) & (lst[0] in accepted_langs)))
bad_4M_df_3 = bad_4M_df[condition]
bad_4M_df_3.shape[0]
# Out:
# 1001190

# %%
with open("logs/data/download/4M_en/4M_trainable_mod_2.txt", "w") as f:
    for video_id in bad_4M_df_3["id"].values.tolist():
        f.write(video_id + "\n")

# %%
sum(bad_4M_df_2["manual_caption_languages"].value_counts()[:4])
# Out:
# 870447

# %%
accepted_langs = {"en-US", "en-uYU-mmqFLq8", "en-GB", "en-nP7-2PuUl7o"}
condition = (bad_4M_df["manual_caption_languages"].str.split(",").apply(lambda lst: (len(lst) == 1) & (lst[0] in accepted_langs)))
bad_4M_df_3 = bad_4M_df[condition]
bad_4M_df_3.shape[0]
# Out:
# 870447

# %%
with open("logs/data/download/4M_en/4M_trainable_mod_2.txt", "w") as f:
    for video_id in bad_4M_df_3["id"].values.tolist():
        f.write(video_id + "\n")

# %%
accepted_langs = {"en-US", "en-GB"}
condition = (bad_4M_df["manual_caption_languages"].str.split(",").apply(lambda lst: (len(lst) == 1) & (lst[0] in accepted_langs)))
bad_4M_df_3 = bad_4M_df[condition]
bad_4M_df_3.shape[0]
# Out:
# 508965

# %%
with open("logs/data/download/4M_en/4M_trainable_mod_2.txt", "w") as f:
    for video_id in bad_4M_df_3["id"].values.tolist():
        f.write(video_id + "\n")

# %% [markdown]
# ### Debugging (part 3)

# %%
with open("logs/data/download/6M_en/6M_trainable.txt", "r") as f:
    id_trainable_6M = [line.strip() for line in f]

with open("logs/data/download/6M_en/6M_trainable_mod.txt", "r") as f:
    id_trainable_6M_mod = [line.strip() for line in f]

# %%
len(id_trainable_6M), len(id_trainable_6M_mod)
# Out:
# (5284868, 1728307)

# %%
id_trainable_6M_bad = set(id_trainable_6M) - set(id_trainable_6M_mod)
len(id_trainable_6M_bad)
# Out:
# 3556561

# %%
trainable_6M_bad_df = main_df_dedup[main_df_dedup["id"].isin(id_trainable_6M_bad)]

# %%
condition = (trainable_6M_bad_df["manual_caption_languages"].str.split(",").apply(lambda lst: len(lst) == 1))
trainable_6M_bad_df_2 = trainable_6M_bad_df[condition]
trainable_6M_bad_df_2.shape[0]
# Out:
# 2739853

# %%
trainable_6M_bad_df_2["manual_caption_languages"].value_counts()[:50]
# Out:
# manual_caption_languages
# en                   1019176
# en-US                 550734
# en-uYU-mmqFLq8        281748
# en-GB                 247014
# en-nP7-2PuUl7o        139677
# en-IN                  84448
# en-ehkg1hFWq8A         61016
# en-CA                  37492
# en-RTbB2cpHawQ         23390
# en-eEY6OEpapPo         19557
# en-j3PyPqV-e1s         14124
# en-1oAFzPNiuC0         10235
# en-rX01gsAdUfU          8920
# en-LUU0EuDKgKo          7493
# en-Q8VSUiGLCHE          6241
# en-E3euOu7LhIg          6163
# en-qlPKC2UN_YU          5275
# en-0hllRZe4s5s          4956
# en-qoXxhA4oLYo          4096
# en-hnCuwW0TCiQ          4078
# en-zL7EZQmMa4Q          3564
# en-VjEpQ-RlAYk          3399
# en-IE                   3246
# en-i7LFIGUQP0g          3086
# en-US-eEY6OEpapPo       2890
# en-_yASqOZhnrs          2611
# en-vlW2OHFw3ww          2327
# en-6UJrWS5jR_I          2253
# en-anMIXjicSL4          2190
# en-Jyun0WSqg2k          1947
# en-UMYBvvsXfqo          1927
# en-US-cvfXDfbeED0       1874
# en-cvfXDfbeED0          1558
# en-dQs7zDoAYDs          1435
# en-US-dOaosRHqfaE       1150
# en-US-zOFsReYi2c4       1025
# en-n7b14AlKMnA           842
# en-GHEw9DUond8           835
# en-810jCDypfJE           686
# en-C_fBn36sO_o           651
# en-dPkTXTcEUoI           562
# en-UmXsJi774Ak           548
# en-KiF8PLhXDeA           432
# en-nPk3V-duwf8           411
# en-S3doMV87xA4           410
# en-A19OKdotbTE           362
# en-LS-YPGm-czI           359
# en-iGJpuh49ngc           329
# en-AU                    320
# en-PecspfweHZs           318
# Name: count, dtype: int64

# %%
condition = (trainable_6M_bad_df["manual_caption_languages"].str.split(",").apply(lambda lst: len(lst) == 1)) & (trainable_6M_bad_df["automatic_caption_orig_language"] == "en")
trainable_6M_bad_df_2 = trainable_6M_bad_df[condition]
trainable_6M_bad_df_2.shape[0]
# Out:
# 1106647

# %%
trainable_6M_bad_df_2["manual_caption_languages"].value_counts()[:50]
# Out:
# manual_caption_languages
# en-US                304049
# en-uYU-mmqFLq8       232641
# en-GB                127683
# en-nP7-2PuUl7o       113267
# en-ehkg1hFWq8A        54606
# en-IN                 23053
# en-CA                 22747
# en-eEY6OEpapPo        16221
# en-j3PyPqV-e1s        11962
# en-1oAFzPNiuC0         7446
# en-LUU0EuDKgKo         5024
# en-qlPKC2UN_YU         4491
# en-hnCuwW0TCiQ         4024
# en-rX01gsAdUfU         3899
# en-RTbB2cpHawQ         3820
# en-VjEpQ-RlAYk         3399
# en-qoXxhA4oLYo         3263
# en-i7LFIGUQP0g         2610
# en-US-eEY6OEpapPo      2565
# en-zL7EZQmMa4Q         2326
# en-Q8VSUiGLCHE         2263
# en-0hllRZe4s5s         2209
# en-vlW2OHFw3ww         2124
# en-IE                  1985
# en-Jyun0WSqg2k         1764
# en-US-cvfXDfbeED0      1661
# en-6UJrWS5jR_I         1500
# en-cvfXDfbeED0         1394
# en-dQs7zDoAYDs         1203
# en-anMIXjicSL4         1192
# en-US-dOaosRHqfaE      1066
# en-US-zOFsReYi2c4       920
# en-UMYBvvsXfqo          835
# en-E3euOu7LhIg          818
# en-GHEw9DUond8          751
# en-n7b14AlKMnA          749
# en-810jCDypfJE          631
# en-C_fBn36sO_o          588
# en-UmXsJi774Ak          505
# en-dPkTXTcEUoI          419
# en-_yASqOZhnrs          403
# en-KiF8PLhXDeA          386
# en-LS-YPGm-czI          352
# en-S3doMV87xA4          338
# en-A19OKdotbTE          312
# en-8k-bGVCfGYE          262
# en-PecspfweHZs          260
# en-gG13fOM8Dfs          235
# en-US-xp8wTkmrYBk       222
# en-AU                   218
# Name: count, dtype: int64

# %%
accepted_langs = {"en-US", "en-GB"}
condition = (trainable_6M_bad_df["manual_caption_languages"].str.split(",").apply(lambda lst: (len(lst) == 1) & (lst[0] in accepted_langs)) & (trainable_6M_bad_df["automatic_caption_orig_language"] == "en")) 
trainable_6M_bad_df_3 = trainable_6M_bad_df[condition]
trainable_6M_bad_df_3.shape[0]
# Out:
# 431732

# %%
with open("logs/data/download/6M_en/6M_trainable_mod_2.txt", "w") as f:
    for video_id in trainable_6M_bad_df_3["id"].values.tolist():
        f.write(video_id + "\n")

# %% [markdown]
# ### Debugging (part 4)

# %%
with open("logs/data/download/8M_en/8M_10K_trainable.txt", "r") as f:
    id_trainable_8M_10K = [line.strip().split("\t")[0] for line in f]
len(id_trainable_8M_10K)
# Out:
# 2231027

# %%
df_1 = main_df_dedup[main_df_dedup['id'].isin(id_trainable_8M_10K)]

# %%
df_1["man_cap_langs_2"] = df_1["manual_caption_languages"]
condition = (
        df_1["man_cap_langs_2"]
        .str.split(",")
        .apply(lambda lst: set(lst) == {"en"})
    ) & (df_1["automatic_caption_orig_language"] == "en")
df_2 = df_1[condition]
# Out:
# /var/folders/kx/lt3wgk4d3ldg6yfn3g233bj40000gp/T/ipykernel_19642/4027748111.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1["man_cap_langs_2"] = df_1["manual_caption_languages"]

# %%
df_2.shape[0]
# Out:
# 1208895

# %%
with open("logs/data/download/8M_en/8M_10K_trainable_mod.txt", "w") as f:
    for video_id in df_2["id"].values.tolist():
        f.write(video_id + "\n")

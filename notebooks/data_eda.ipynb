# %%
import os
import glob
import numpy as np
import pandas as pd
import multiprocessing
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
os.chdir("/Users/huongn/Desktop/open_whisper")

# %%
metadata_files = glob.glob("data/metadata/*.parquet")
metadata_files
# Out:
# ['data/metadata/captions-0001.parquet',
#  'data/metadata/captions-0008.parquet',
#  'data/metadata/captions-0009.parquet',
#  'data/metadata/captions-0010.parquet',
#  'data/metadata/captions-0000.parquet',
#  'data/metadata/captions-0002.parquet',
#  'data/metadata/captions-0003.parquet',
#  'data/metadata/captions-0006.parquet',
#  'data/metadata/captions-0007.parquet',
#  'data/metadata/captions-0005.parquet',
#  'data/metadata/captions-0004.parquet']

# %% [markdown]
# ## UDFs

# %%
def standardize_dialects(s):
    words = s.split(",")
    transformed_words = [word.split("-")[0] if "-" in word else word for word in words]
    return ",".join(transformed_words)

# %%
def standardize_dialects_2(s):
    words = s.split(",")
    transformed_words = [word.split("-")[0] if "-" in word else word for word in words]
    return transformed_words

# %%
def get_percent_empty(df):
    return df.apply(lambda col: (col == "").mean() * 100)

# %%
def clean_df(df):
    df = df.copy()
    # fill in missing values with empty string
    df["automatic_caption_orig_language"] = df[
        "automatic_caption_orig_language"
    ].fillna("")
    df["language"] = df["language"].fillna("")

    # maybe don't need code above because this takes care of en case as well
    df["manual_caption_languages"] = df["manual_caption_languages"].apply(
        standardize_dialects
    )
    df["automatic_caption_orig_language"] = df["automatic_caption_orig_language"].apply(
        standardize_dialects
    )
    df["language"] = df["language"].apply(standardize_dialects)

    # check if all "en" types have been changed to strictly "en"
    if "-" in df["manual_caption_languages"].unique():
        print("dialects still exists in manual_caption_languages")
    else:
        print(
            "all dialects have been changed to strictly family language in manual_caption_languages"
        )

    if "-" in df["automatic_caption_orig_language"].unique():
        print("dialects still exists in automatic_caption_orig_language")
    else:
        print(
            "all dialects have been changed to strictly family language in automatic_caption_orig_language"
        )

    if "-" in df["language"].unique():
        print("dialects still exists in language")
    else:
        print("all dialects have been changed to strictly family language in language")

    return df

# %%
def check_in_col(row, ref_col, tgt_col):
    words = [word.strip() for word in row[tgt_col].split(",")]
    # Check if the second column's value is in the list of words
    return row[ref_col] in words

# %%
def get_duration_ml_t(df):
    condition = (
        df["manual_caption_languages"]
        .str.split(",")
        .apply(lambda lst: set(lst) == {"en"})
    )
    not_strictly_en_df = df[~condition]
    condition_4 = not_strictly_en_df["manual_caption_languages"].str.contains("en")
    no_en_df = not_strictly_en_df[~condition_4]
    condition_5 = (
        no_en_df["manual_caption_languages"]
        .str.split(",")
        .apply(lambda lst: len(lst) == 1)
    )
    one_man_lang_df = no_en_df[condition_5]
    condition_6 = (
        (
            one_man_lang_df["manual_caption_languages"]
            == one_man_lang_df["automatic_caption_orig_language"]
        )
        | (one_man_lang_df["automatic_caption_orig_language"] == "")
        | (one_man_lang_df["automatic_caption_orig_language"] == "en")
    )
    condition_7 = (
        no_en_df["manual_caption_languages"]
        .str.split(",")
        .apply(lambda lst: len(lst) > 1)
    )
    many_man_lang_df = no_en_df[condition_7]
    condition_8 = many_man_lang_df.apply(
        check_in_col,
        axis=1,
        args=("automatic_caption_orig_language", "manual_caption_languages"),
    )

    temp_2 = many_man_lang_df[condition_8]
    # getting data complement of condition 8
    temp_3 = many_man_lang_df[~condition_8]
    # getting data where automatic_caption_orig_language == ""
    condition_9 = temp_3["automatic_caption_orig_language"] == ""
    temp_4 = temp_3[condition_9][
        temp_3[condition_9].apply(
            check_in_col, axis=1, args=("language", "manual_caption_languages")
        )
    ]
    condition_10 = temp_3["automatic_caption_orig_language"] != ""
    temp_5 = temp_3[condition_10][
        temp_3[condition_10].apply(
            check_in_col, axis=1, args=("language", "manual_caption_languages")
        )
    ]
    condition_11 = (
        condition_4
        & (not_strictly_en_df["automatic_caption_orig_language"] != "en")
        & (not_strictly_en_df["automatic_caption_orig_language"] != "")
    )
    condition_12 = not_strictly_en_df[condition_11].apply(
        check_in_col,
        axis=1,
        args=("automatic_caption_orig_language", "manual_caption_languages"),
    )
    temp_6 = not_strictly_en_df[condition_11][condition_12]
    condition_13 = (
        (not_strictly_en_df["manual_caption_languages"].str.contains("en"))
        & ("" == not_strictly_en_df["automatic_caption_orig_language"])
        & (not_strictly_en_df["language"] != "en")
    )
    condition_14 = (
        (not_strictly_en_df["manual_caption_languages"].str.contains("en"))
        & (not_strictly_en_df["automatic_caption_orig_language"] == "en")
        & (not_strictly_en_df["language"] != "en")
        & (not_strictly_en_df["language"] != "")
    )
    condition_15 = (
        (not_strictly_en_df["manual_caption_languages"].str.contains("en"))
        & ("" == not_strictly_en_df["automatic_caption_orig_language"])
        & (not_strictly_en_df["language"] != "en")
        & (not_strictly_en_df["language"] != "")
    )
    condition_16 = not_strictly_en_df[condition_15].apply(
        check_in_col,
        axis=1,
        args=("language", "manual_caption_languages"),
    )
    temp_7 = not_strictly_en_df[condition_15][condition_16]
    condition_17 = not_strictly_en_df[condition_14].apply(
        check_in_col,
        axis=1,
        args=("language", "manual_caption_languages"),
    )
    temp_8 = not_strictly_en_df[condition_14][condition_17]

    ml_dur = (
        one_man_lang_df[condition_6]["duration"].sum() / (60 * 60)
        + temp_2["duration"].sum() / (60 * 60)
        + temp_4["duration"].sum() / (60 * 60)
        + temp_5["duration"].sum() / (60 * 60)
        + temp_6["duration"].sum() / (60 * 60)
        + temp_7["duration"].sum() / (60 * 60)
        + temp_8["duration"].sum() / (60 * 60)
    )
    t_dur = (
        (not_strictly_en_df[condition_11]["duration"].sum() / (60 * 60))
        + (not_strictly_en_df[condition_13]["duration"].sum() / (60 * 60))
        + (not_strictly_en_df[condition_14]["duration"].sum() / (60 * 60))
    )

    return ml_dur, t_dur

# %%
def get_duration_en_only(df):
    # getting data that's strictly en in manual_caption_languages
    condition = (
        df["manual_caption_languages"]
        .str.split(",")
        .apply(lambda lst: set(lst) == {"en"})
    )
    manual_en_df = df[condition]

    temp = df[~condition]

    # getting data where en in manual_caption_languages (not exactly "en") (temp) and en == automatic_caption_orig_language
    condition_2 = (
        (temp["manual_caption_languages"].str.contains("en"))
        & (temp["automatic_caption_orig_language"] == "en")
        & ((temp["language"] == "en") | (temp["language"] == ""))
    )

    # getting data where en in manual_caption_languages (not exactly "en") (temp) and "" == automatic_caption_orig_language but en == language
    condition_3 = (
        (temp["manual_caption_languages"].str.contains("en"))
        & ("" == temp["automatic_caption_orig_language"])
        & (temp["language"] == "en")
    )

    # returning total duration
    return (
        (manual_en_df["duration"].sum() / (60 * 60))
        + (temp[condition_2]["duration"].sum() / (60 * 60))
        + (temp[condition_3]["duration"].sum() / (60 * 60))
    )

# %%
def view_lang_cols(df, num_rows=5):
    return df[["id", "title", "manual_caption_languages", "automatic_caption_orig_language", "language"]].head(num_rows)

# %%
def view_lang_cols_2(df, num_rows=5):
    return df[["id", "title", "manual_caption_languages", "automatic_caption_orig_language", "language", "man_cap_langs_2", "filtered_langs"]].head(num_rows)

# %%
def view_lang_cols_4(df, num_rows=5):
    return df[["id", "title", "manual_caption_languages", "automatic_caption_orig_language", "language", "man_cap_langs_2", "filtered_langs", "download_lang"]].head(num_rows)

# %%
def get_num_rows(df):
    return df.shape[0]

# %% [markdown]
# ## Getting Video IDs

# %% [markdown]
# ### Loading in data from parquet files

# %%
df_list = []
for path in metadata_files:
    df = pd.read_parquet(path)
    df_list.append(df)
main_df = pd.concat(df_list)
main_df.reset_index(drop=True, inplace=True)

# %%
len(main_df)
# Out:
# 60102381

# %%
main_df_dedup = main_df.drop_duplicates(subset=["id"], keep="first")
len(main_df_dedup)
# Out:
# 60098151

# %%
main_df.columns
# Out:
# Index(['id', 'title', 'duration', 'view_count', 'categories', 'comment_count',
#        'like_count', 'channel', 'channel_id', 'channel_follower_count',
#        'age_limit', 'upload_date', 'is_live', 'was_live', 'format',
#        'format_id', 'language', 'filesize', 'stretched_ratio', 'width',
#        'height', 'fps', 'dynamic_range', 'aspect_ratio', 'abr', 'vbr',
#        'vcodec', 'asr', 'audio_channels', 'chapters',
#        'manual_caption_languages', 'automatic_caption_orig_language',
#        'location', 'license'],
#       dtype='object')

# %%
# downloaded already
with open("logs/data/download/440K/440K_download_ids.txt", "r") as f:
    id_downloaded = [line.strip().split('\t')[0] for line in f]
id_downloaded
# Out:
# ['05xOF5ubabQ',
#  'GjTPw_aQmgg',
#  'T9_3s_yybq8',
#  'nKZSV-h0SGA',
#  '3993tVeKd-w',
#  'CI6V07nPBzk',
#  'colODoThH3Q',
#  'w9B7VcQDkaU',
#  'wEozeRtGOss',
#  '9-c1cjfcMWA',
#  'slKm_e5BlM8',
#  'DlShMKZnO3M',
#  'Trwb7V7DUpw',
#  'klwH8qyun8E',
#  'z3F53ixYOhg',
#  'SpU-wjIq-ks',
#  '2LMwCAOc3Z8',
#  'SAuyecc22os',
#  'XtKeJ6KGabo',
#  'v82FvnlLrJI',
#  'BjrJJHsRGzM',
#  '4T7CX48QfNU',
#  'Ta77u4_QFE0',
#  'sJTxmp8Sgxo',
#  '3Y0IOS9MjrQ',
#  'YOJ5tb7djtE',
#  'rHJl01EJLxI',
#  '9QreGvzk0EE',
#  'uipO3h824ls',
#  'A_62KQA43N8',
#  'wlQyW9653_Y',
#  '8kFbaTuCx7o',
#  '_86o9kvgGZ4',
#  'wXamXakPR7g',
#  'RC75WARX6VQ',
#  'D81VRIRbZN8',
#  'K7itE9u35YA',
#  '2INSSypNeSI',
#  'IZ7KXOG-pa4',
#  'VnUz01iG340',
#  'qbdksuS94w4',
#  '_H8e8A_Z6a0',
#  'xjeluIUSk3c',
#  '8xlS5loCooI',
#  'Tu3C6P3hZC8',
#  'Y475Yx-aLDo',
#  'OvrulSLqjGg',
#  '0w8VX8fe1uw',
#  'Rluzhtv24Cg',
#  'cKKq3HFW5zg',
#  '183f15W-fy4',
#  'bNNC9VLUi4A',
#  'slZktP6GB70',
#  'f94-KGDotIs',
#  'hOgmWpTFkEk',
#  '4x6cR9IpPLw',
#  'Cu_fzUDAXPk',
#  'At-90RplBsw',
#  'UPZoZyGZI8M',
#  '9Lhgx3ZqPTU',
#  'jpNSYkltC0w',
#  '3tXG-TloXfY',
#  'BFk-sidgFWI',
#  '9C2l-wkXSJ0',
#  'UuEM0_PdXjg',
#  'Nh1jOPrAj3Y',
#  'FTB2nIIvcqg',
#  'YZma9sm2cbE',
#  '28nvgM_hQFE',
#  'j_Z5nJBJB5M',
#  'sQOk4h4hhwo',
#  'zmT2eGxEf7Y',
#  'mWDyY3fprQM',
#  'JpDX41Yvyks',
#  'ke4ZASQSO7s',
#  'tB-LatQFQ6w',
#  'egRdN50wCl4',
#  '9vUSrDPSsB8',
#  '3zKbiRE41h4',
#  'LrqsNH8iLrk',
#  'KWCr2vLbdWw',
#  'byiR385nSQg',
#  'jX1Sa21rmNI',
#  '_DBhwN49x_g',
#  'qWK8gDWpICQ',
#  'UC6g08WomyU',
#  'emSUcOCzCQc',
#  'Q_JIeko4xDI',
#  'j8X_XKzJTmI',
#  'K0pCx70zcgk',
#  '4I_ndgMaAng',
#  'gWr_raMdx54',
#  'tNAQ8lc6hAw',
#  'cRltfVn23OE',
#  'cZwLjBNMJKM',
#  'gNhGIJsBy2s',
#  '9DLs1Jfx0lo',
#  'ZJcIIKUGy7Y',
#  'l1nqDBMz1a0',
#  'q28u_xRNN-Q',
#  'G-5jf3bZR78',
#  'ppxl4jFuFTw',
#  'v1uaqfyTYaA',
#  'xbS8T2RVif8',
#  'Cfel3IIq5Gw',
#  'yjRiKl8zyYs',
#  'V-6UlVOz73s',
#  'SM8ntDaHjm4',
#  'NfoEMdx6Ilc',
#  'pD5EKwO6tb4',
#  'E4e9G-QvG0o',
#  'OkqDaSLavlo',
#  'KqzFH-xBbRg',
#  'yE0sfojG2LU',
#  'Am1-Sp2Kktc',
#  '5lJ_o9Qxuyc',
#  'irOSQeCmsRI',
#  'bKFRQb2p3V8',
#  '60Xf1GRIMdI',
#  'wPLsMj3Mmmo',
#  '3Y66vKwR-2o',
#  'wwLsFjYJn_o',
#  'dywgmiayRG0',
#  'YLld7SZW3Dk',
#  'ksmhUd7DqWM',
#  'Bqig3hjWaXM',
#  'qx1uughTMXg',
#  'Ovar9waGfsw',
#  '8L83HC4bqHE',
#  'iv9D0um9GyA',
#  'vhSq3YmwmYc',
#  'NfB_pbpYuV8',
#  'gpZAVKN8Ol0',
#  'yHut_haTDaI',
#  'niB5rlqFqL8',
#  'Sgv706aaoQU',
#  'Y0hHVFFwQt8',
#  '7xI9pDtxStc',
#  'l_iB5h_uDGQ',
#  '3LUrSJfHr7o',
#  'FL06yjzOjww',
#  '67FEQTicGoU',
#  'hF2fbrF1bPU',
#  'RRU5Cfpz2n0',
#  'UaZGUNzkwy8',
#  '-BjK20lEGNc',
#  'lQXweRv9oRg',
#  '70t3n7W45ro',
#  'jPU1EpmKhjI',
#  'W2JZQ9j8Prg',
#  'ONrZ1SincoY',
#  'bQ2e-vINvYk',
#  '-VTFX_dQuso',
#  'zFnBdxl6EZ4',
#  'V1YYZlHjTDg',
#  '3TiSYmPkplw',
#  'CELZUDroYWo',
#  '3f318Jh3izc',
#  '5aUiuy2r6kQ',
#  '_pBFmlqCUVg',
#  'BH60n3PbyTE',
#  'e0ZHgvA-bM8',
#  'bm8KH_gjvYg',
#  '8dQsHv06u6A',
#  '3sm028jlBtY',
#  'IBoYPZL_O5M',
#  'x_mzvVPNlVY',
#  'B99AVTqdyp0',
#  'hvcOknZ52m8',
#  'G_H2R2mjN9E',
#  'SDQ_FxD0fOc',
#  '3nI-Gg80UXM',
#  '4Ky-ZjoNg2Q',
#  'McdNDCku0h4',
#  'PP9lvLaHCAE',
#  'gr4WFCjV3hw',
#  'CJnQ4TPLIWs',
#  'EgZUOASE5l4',
#  'sRPZx5VSYy4',
#  'QetwgGFSWoQ',
#  'N_OhApvf6_c',
#  '4yhmZ2WkEvs',
#  'Ubv5Q-aPNmI',
#  'WHbbgYVFiy4',
#  'LN0bx7cxUKE',
#  'g-zc_96CPPc',
#  '858UT_h0j_A',
#  '-llXmNuY7bo',
#  'r_efpsVq5Wc',
#  'iA7Epl4Qc1o',
#  'oDxCrcYoXwk',
#  '1aZi8V8tiIg',
#  'KFscn0HQcb4',
#  'foL2OuuVvyY',
#  '7AhIKKJ79V8',
#  'OErvU-ZSEgA',
#  'nsGdoQiCQV4',
#  'VeVUL07UG-Q',
#  '5Cxuq7J8aC4',
#  'UwwC7Uwc2Vw',
#  'dox0JJpKrZQ',
#  'P6efIjcCqhY',
#  '2py_x87j3jo',
#  'p6jWVgCIhxM',
#  'cZvb3f5aBRc',
#  'bwjCh8aI030',
#  'lrs18tbXflk',
#  'dfQKNpGD0tc',
#  'jPqbfvmIymA',
#  'IZ35qoGSack',
#  'o_rPXJ6vIQ0',
#  'ATXBlK078Xs',
#  'AtfGPDeTQwU',
#  'Q9ibs25pDwY',
#  'Gr1JsdoiOxo',
#  'GeecbbZ7jfc',
#  'cfHwo0NIhD0',
#  'TpkuuUyEAC8',
#  'RuswPU6TOTE',
#  'mF9LEXXY8jI',
#  'WIeEAECg7nA',
#  'BnnVbtmG2A8',
#  'M0IdAz6O8FA',
#  'LDl1rWqN1gs',
#  '9BXvQGhoFZE',
#  'oF3wYrz05_0',
#  'RgudGFz-s4g',
#  'BtfyYyTfIvU',
#  'xAwXZji3JNU',
#  'oS7OUT6Z3-Y',
#  'zYpo0yWAaS4',
#  '4ob41Rl02Wo',
#  '8YA1UUyzUaY',
#  'Q7FK41BtaRo',
#  'IZdsTSWBEbQ',
#  'hEwzZ6YDfts',
#  '71w9F61l2kA',
#  'YhkFS-b9GiU',
#  '4Sx_qBNtWog',
#  '5-GWqGpPQzA',
#  '8EOEfbuCyYc',
#  'emT8EhHy7U8',
#  'meJb6wK7T7M',
#  'LNhH4laxhjA',
#  'wuOd5_M9yDQ',
#  'JtBcmf1AiUc',
#  'rjZJLPQNrfg',
#  'BMshLF1rwzE',
#  '8kkadA5lm70',
#  'Cd8KEx79dEM',
#  'n10b1DtaZGM',
#  'NsvR-tNs954',
#  'ShvZdF41qHE',
#  'OVxoRfP6E_k',
#  '0tKoXEJH1c8',
#  'DfnrWMUFGnI',
#  '7NZhmOIyYQM',
#  'acSr4HxBHS0',
#  'uJNUhk2CWcc',
#  'Nd8pouOBUiU',
#  'Dk_AeHPSldM',
#  'elf4s4iWpyU',
#  'DU_KMP9QHO0',
#  'b1D1JHV6hx0',
#  '11C49LXrswM',
#  'lm9yl9tzuSw',
#  'XQV3ztTMKZ8',
#  '8KPW8oNk1RU',
#  'Udl26Il4-BY',
#  'YRMOctGda3g',
#  'Z7r43R2IrbA',
#  'ehU-RorLMjg',
#  'hZd0G3mWlOI',
#  'r9Jamm3-OgQ',
#  'LGrft_mZjzo',
#  'qvhYE8joymY',
#  'w3szPNK2o3g',
#  '5VsQtsNig14',
#  'TcG4PNfWklo',
#  '6qNbcmWbZ3M',
#  'wAbHISeYCjw',
#  'MrV193hIJxM',
#  '5K1ZnT9suXg',
#  'nimGDtZkuJ8',
#  '2wiYQuJquVc',
#  'i2PlU8ZiwI4',
#  'FnoPogOBQH8',
#  '7HOsQDD1Res',
#  'Ggvdf23WsAg',
#  '7eygnFgzgzo',
#  'LYie-Qt8Wi8',
#  'YaOQmce_e5Q',
#  'tz8Pj_4O_q8',
#  'A9WhdU7bc7A',
#  '6uVV0z-a93w',
#  'w3CHw9wGCcM',
#  'q5eARAE4A50',
#  'PnUGIuRvtHc',
#  'a3kiFyiNSmI',
#  'HLGZOtdxahc',
#  'OA8k0BzIFKQ',
#  'OsdZqIhjUBM',
#  'CiGErixl4lk',
#  'HuxR2aE31hQ',
#  'ckaGko4d8WM',
#  'x6VasHT_Hdw',
#  'LHrcmfVPb2o',
#  'SO9G95ghhzE',
#  'aKz5rVt367E',
#  'beEpxM3Jjvs',
#  'aPP8o0sTvCg',
#  'hjqG5FH6w0Y',
#  'xwDUhPCbio4',
#  'lhEOxnFdoKM',
#  'OCXFbAfmFx0',
#  '7OvvrLaTlXQ',
#  'onf93pNtVK0',
#  'WyJsUHlZmqE',
#  'ndihTUbNbGY',
#  'r7xGHWJge24',
#  'FX3lSr-8ZZM',
#  'qtJqxur-WdY',
#  'VYTJxTEJ_GA',
#  'oVTC0bPiFQU',
#  'yVulHQYLMC8',
#  'DnQszhC416w',
#  'GhHJ3wE-u-w',
#  't9xKzn66quk',
#  'sjIu4tHPjjg',
#  'cBq89DgHxRw',
#  'R6dlQTNz_sQ',
#  'LZXVP0FIA_Y',
#  'XaMDiSKjBRA',
#  'KWV-6j_Lza8',
#  'rYaSeYDGC14',
#  'H6VB0S4DZys',
#  'TjoE7IZgXfc',
#  'Vb-1V0k-AWA',
#  'GA1ZNJ0jvKY',
#  'VbNsnZdYdxM',
#  'Px0uxnHwjdA',
#  'mG9rj8J1rWY',
#  '2AK2JYb-Xa4',
#  'A8tKvNFsLxQ',
#  '-1EKruEOAZw',
#  'CxUbl3yO6ZI',
#  'JJDl-C2sPgc',
#  '0pbbjYRSsU4',
#  'DynA5PXna0Y',
#  '0DqI3v7G1A8',
#  'kNh5Gw1v16A',
#  'rDJR8RgvlYI',
#  'h4U7Of942sA',
#  'aS2HzlsNv7M',
#  'rhU0b6_4Xrg',
#  'QC4hRjh5S0k',
#  'H1Ga1G-xDOA',
#  'QQjd-C0Rt0k',
#  'EKi1Q9JJpA0',
#  'TvcFoURKBnY',
#  '1L-DnzWed34',
#  'M_y1sO-IHA4',
#  'GsPbvikhN7w',
#  'cKT95yspTEk',
#  'BQZGHdiBcAI',
#  'SU6A1wE6W9c',
#  'RDngr6kRd3s',
#  'TuBKmPMNRnk',
#  '1zFKV9hZsBE',
#  'wzRBQpnV00U',
#  '2vxPfVCimNc',
#  '7y_aMTDIHM0',
#  'rcf4RV9otZA',
#  '0hNgS7ZmNBw',
#  '0M2EoUmSmOQ',
#  '1M7kKGqSa14',
#  'FowWcrBTmtM',
#  'uOnvnNAufeA',
#  'Nrjh3N4GIrQ',
#  'c711etjGA9g',
#  '2mpUmmeg-54',
#  'DMTffMM5xro',
#  'IuF6s2j3MB4',
#  'kL6atXYWxNI',
#  '9moWzpfAeZ0',
#  '9qNc-jobAP8',
#  '8NGskP5dr5Y',
#  'YFGhRqb2G-I',
#  '9eVuQN82L2I',
#  'sUbXF81EjhQ',
#  '4wPejXSY8Bk',
#  'LATX3CDpLg0',
#  '3V56hrE8NnE',
#  'TOMLCwDT3rw',
#  'kffuQ-qN8NA',
#  'F8iFMFFwiK4',
#  '3sLvahUwZgI',
#  'VFogM8Le0Iw',
#  'oIZ77VcdwK0',
#  'yy03rTEZe-s',
#  'a7HYO_yta-c',
#  'J-qLsDMmqIo',
#  'FK0LL8zi7AQ',
#  'gDL1Rm5sJ5E',
#  'xRD2m5Fiz90',
#  '5tQ50RrXCrM',
#  'yoXFs-bn-A8',
#  'UA7iA4gQ830',
#  'YFomjEoX20w',
#  '44Ho-gb9rRU',
#  'ZhVL9bheCaM',
#  'CHm6Jhf4w3Q',
#  'zb5F9Gq8AHc',
#  'Gf7Dfz2YcJI',
#  '5YfI5-8-mhk',
#  'O3bQVvB6OL4',
#  '5j09jMb9pgY',
#  'LnO_Pu4C4kg',
#  'yv1_uiPqSqA',
#  'bCM4uqDjXK4',
#  '48_u42JFNYs',
#  'uNvtyJAVTwQ',
#  'fJS8gthnhsM',
#  'pLgX_r5mRas',
#  'NVQSrsnBT9Q',
#  'b-a8SfqkqE8',
#  '_YrKkxZvowM',
#  'kL1175_PK60',
#  'KewphrBiYAo',
#  '09tUa_svSmw',
#  'gHHHP0-0A6w',
#  'Puo6HLeLnTc',
#  'jFYiToBeNEg',
#  't0KFHjnjfEs',
#  'H8Zyl6YQmlo',
#  '8k1mvpLDAgM',
#  'mTX_wm7d1ZY',
#  'iz6dZK3ESSQ',
#  'pqhxjVrOWII',
#  'NGHmMAoPtEE',
#  'JLp8cEVhp9c',
#  'gYsQRQFnUcI',
#  'Qo70Fcad8NA',
#  'exM8SusaOy8',
#  'JLZul-iyuiI',
#  '4en5B-UUgEM',
#  'o8_BV0DkFFk',
#  '15dUSPvCPTg',
#  'eEVJsSxd-Xw',
#  'UvUOkELGUYs',
#  'KQizzUbjf84',
#  'Uafa6ROC1gU',
#  'k16_EDebS4k',
#  'FqVOeI-pO88',
#  'x1Ypaz27H-s',
#  'AKIKlYFkqv0',
#  'IHZGK25kA2s',
#  'lUgzWGUoATE',
#  'fzTzlUIjKTc',
#  'dJ83ehnB4SA',
#  'QqfTOZ1Tgb4',
#  'alqm9mRKTVw',
#  '5dQuS2jK2oo',
#  '3DhDbXHOCeY',
#  'RINRpt1KU84',
#  'EeoziJkm7Yw',
#  'HP4g9XsHMuQ',
#  'xJj69ZEJ1us',
#  'Kn_wwrru8tQ',
#  'Sae2iJqOgOU',
#  'eBDah2nSVKg',
#  '13x3OTgC1z0',
#  'tsaNaY4IVnk',
#  'GcKBm9tE8tQ',
#  'NweD0kVwJWM',
#  'Dxbps5EQpwE',
#  'jXWeICGYm_8',
#  'OLS2IFHah2w',
#  'UPhI-VpEFgM',
#  'TKHm3mMnMgU',
#  'wsAdFDCtyAk',
#  'd6nGo8MAsK4',
#  'WNM0IqhHty4',
#  '8T0HOMT8WEU',
#  '3OtTdHzD8BM',
#  'iUHFiEb5l1E',
#  'W68f2znp17k',
#  'XdsbBJvH5RI',
#  'VNTBa4sngHE',
#  'ZDrHAcOWScg',
#  'a355xICAJ54',
#  '27UnMJ9mpxY',
#  'ObmLwBxnqKk',
#  'wymyC3uD4Yk',
#  '-wbvzTkUqKg',
#  '5QRpQogK01k',
#  'xKzNYuvAV7E',
#  'VghKPJedkQQ',
#  'ebqjs5UunFY',
#  'A3GqLeiRqww',
#  'k8L6dDEtRl0',
#  'Ns8VImg-SD0',
#  'xRd1xnYen18',
#  '4fx4aJeNjhg',
#  '3PHfyGqTz_U',
#  'deiLHhJHu0I',
#  'Px8abCmCABk',
#  'OEqNfktg-8A',
#  'oFCYzH1cxdA',
#  'nU8XBpOJLQM',
#  'we_vtZ40-f0',
#  'fXYs3Qb8A9M',
#  'HgRE_Q-EkHw',
#  'LtlyeDAJR7A',
#  'cOamo0G-Bwc',
#  'ECLYMLi0Q9Y',
#  '4PSAyFNwges',
#  'MTuwh3jX0fo',
#  'vqKaUtPQE2g',
#  'KoyzlVrpB00',
#  '0mrbKSouNgQ',
#  'FGB6vqRRjMg',
#  'kLBrAmvwQwc',
#  'AERCUQ973c8',
#  'styztNyDIro',
#  'slaEWM5ZKD8',
#  'va1g8rNO_Fs',
#  'DolG-pTiCDs',
#  '5TeVxz4MTa0',
#  'l01UAf54PCg',
#  'eN3g0zR0FWo',
#  '8We5Uv29KAM',
#  'INR5E0H10_I',
#  'fJHOM6TCfLE',
#  'aUFZWpDWML8',
#  'Rlc2piyZm7g',
#  '3bscJhsON-Y',
#  'AaAMppES87U',
#  'Y9K4ylaoM5Q',
#  'YkI8GKGKHtk',
#  'Sb5FMia_Vs8',
#  'DNqPNsPd2Os',
#  'dsV_tViYnn0',
#  'Lq6bWJL39vc',
#  'zcUrUE6-ZCw',
#  'c6KskH8ttkc',
#  'O1Vm-EiKTqE',
#  'S-tBhxi6JQA',
#  'BN7qLPlh9cA',
#  'JNUIpL9ZVgk',
#  'luIfK7njMXM',
#  'NTNuH44bbGI',
#  'kR1FBhHbX-s',
#  'j8S2ZoupW9U',
#  'R24TNQ8WMKk',
#  'mpV8-YaJ2p4',
#  'PBex1Pv8qKY',
#  'jOiV9ynb-GU',
#  'ss5914XBAT0',
#  'eir_HChNMjI',
#  '3a7EjWShH1Q',
#  'mBX_rbfpAII',
#  '17D2rQCgiO8',
#  'VhpkGyH-GUM',
#  'hXloRHqJ3MA',
#  'IWtohuwL_VI',
#  'VaeCZsKzZEw',
#  'JNqCUH86tz8',
#  'Ow4oLLbTvHs',
#  'j1NQ2dmJNf0',
#  'mtq61ktPn7s',
#  '09mdTgA0bAU',
#  'NO_W6kVy0xM',
#  'FLj8Fh2ITUU',
#  'hi7AWKbECvM',
#  'c5WBkqWFnVY',
#  'eI3-9YryaXc',
#  'KzKW1E9OPN8',
#  'L5_KSaWIdrg',
#  '0PezNgKnhm8',
#  '0aRmfSU0z4w',
#  'axPkLt509_Y',
#  '1biZfFLPRSY',
#  '1dlQFPwYsoU',
#  '2GXYaFYg8Uc',
#  'Wbr85p7a_eQ',
#  'pU7UYWV9KM0',
#  '_s4GqM0giOE',
#  'QNkrfZKGmiA',
#  '5kIVb3a8cYI',
#  'Y7fvKGJZG0s',
#  'O8jI4iWNuFc',
#  'CqJ3kRcYxis',
#  'sChm07VXgbc',
#  '755IPi_cVtg',
#  '6mNgQFUShEg',
#  'ZCz-ZDtbtys',
#  'FDDCiUvHZVQ',
#  'yCPQMIMZo6o',
#  '8oiW_TRaO9I',
#  'vEc9NcRV1_4',
#  'hldlvznCdJo',
#  'HhL-jS7KPDg',
#  'W9ziavKyj24',
#  'sGXxiQP-sMA',
#  'JnBN3q0WFrI',
#  'uGJAc4wlIX4',
#  'qgTuSkubL6g',
#  'foQSonqXex0',
#  'gqVyuBzJ4j4',
#  '3mnY_m_XiZE',
#  'n3vki3QdCmA',
#  '_g69X9aP2DA',
#  '_kbZPiU4COE',
#  'cPTRSYxZszU',
#  'laMMNrtjqTU',
#  'dLm9a7FiWr8',
#  'LAI5_MHM5NQ',
#  '75bshTwwYws',
#  'RyKGhiz779A',
#  '6Ns7BfRlDDo',
#  'wS7O9sJiE4k',
#  'qj5kSX4dUpA',
#  'C-S9EjiujrQ',
#  'GEAqwVmPpBE',
#  '-8ls-FjVmN8',
#  'EcLeGnWUM1E',
#  '46ByJsog97Q',
#  'JXe-n10xNdI',
#  '3a_yd7AlFdg',
#  'Mjt15HD_8H4',
#  '7y7LOB2Z0EA',
#  'Dj6r8JsctDc',
#  'afG7kVTWs4E',
#  'fEiDlfGenr8',
#  'DWi6R8nZWvM',
#  'N3a-jQpDt5s',
#  '-RUfbFy0-08',
#  'TqSJZRYORZI',
#  'HNNQSe6SJ-I',
#  'XChSp0Mgruw',
#  'ejOts-CbFFE',
#  'lxYUMJa8ScE',
#  'oPuoDC_p5KY',
#  'ee996QHUCfU',
#  'Rw8VQvmWIdo',
#  'cChdMO3XvEQ',
#  'Ag3MogxUnjk',
#  'vefmUL7k7HE',
#  '0TMX73o513I',
#  '8BWhbPhahv4',
#  'WdU14xnxxoo',
#  'AlYqaAi1y1o',
#  'Y7Rixp_taUk',
#  'ej9B8wWww6w',
#  'mSRgD-pYBJg',
#  'EBRYHGkOYrs',
#  'izTzSYupcgI',
#  'O-CDQa3lq9w',
#  'y_mveVlZDV8',
#  'XwnMtvGI6Mo',
#  'uYIJxTQrf_E',
#  'SUUJBBcpEpI',
#  'JzVwb8a9fVg',
#  '_U3n1BG5brU',
#  'czwfUys75Ww',
#  'pzDkRtQwbLA',
#  'hOMvu6SNHRQ',
#  'wd2o--xZK5M',
#  'DovT2y9G50Q',
#  'vJ6dCNjMaCs',
#  'P1tYTXzwWcQ',
#  'JDtSqv1uKzA',
#  '7rJZlmCz7WU',
#  'QiyNepvG9HE',
#  'fVLVKSaGXAY',
#  'Gbmhut1Aw_4',
#  '1h2Ski3cnYE',
#  'nexFH-3gG5w',
#  'lDTosYJHEA4',
#  'cJrsmxtn52U',
#  'SZUx6e4WXC0',
#  '51ps9sQ6eDU',
#  '6K1rHkIzPFM',
#  'hZenRBr7meU',
#  '9cnE_46uUuU',
#  'q82Wk6Ps_VM',
#  'b8ZGN_jt4DM',
#  'u422LOQfZbw',
#  '6rMndNj18rA',
#  'oBDTfuXE3MM',
#  'emw51v0mysc',
#  'AqJQmBlZhFI',
#  'GfgIor3UYb0',
#  'ZZQ2ElI662Q',
#  're13YkkwC6c',
#  'G8C0xAZR4QE',
#  '9o2-vUYEjVc',
#  'CycT4_9FuxY',
#  'oQTYwfZCNyA',
#  '_sWrUoSuFEk',
#  'oKe43cZR5Xw',
#  'gBbTbbUoB08',
#  '3KyIB6z8EZw',
#  'cpzugLxsIes',
#  'ntfawYhryyc',
#  'IC7GIICQKOI',
#  'GW-3I2deS_U',
#  'N1ZozHb9COY',
#  'PAD3sRsqbKo',
#  'e0m_qxTuyjk',
#  '4GQ12F4WihQ',
#  '5TGG2DnfqLE',
#  'P0Krtz9eT1M',
#  'OpAZ_O80EzI',
#  'iSJyV9rxWGk',
#  'uXoKUMeCcNQ',
#  'cVROrGjuy3g',
#  '7Xhpbc9UNTA',
#  '7XF68mF3EUU',
#  'pXR87jXzlN0',
#  'J-wh2Os66Vs',
#  'gcGKYHdRrXQ',
#  '6SRyzHZGPUU',
#  'S3ZZ8f79StU',
#  '-Q3O_5P6ctc',
#  '-YNIKymk_64',
#  'v_rWyKUTOLM',
#  'GyV1UxDiSYk',
#  '9BV8X76iLF8',
#  '_aD2VV44dEY',
#  'mHRCe-rzoBU',
#  '3cHR5m7c0-8',
#  'eouETT1bJ_g',
#  'yzm3iW4qeO4',
#  'A-36UUghCn0',
#  'BGZry2AQz4E',
#  '40yzPXJtssg',
#  'UJfaAg9c0qo',
#  'yal4FhXPbE8',
#  'z4Lp_ySCfLY',
#  'D8koyO_zNog',
#  'U5RyIJ8pDIs',
#  '_Val_FAvMQg',
#  'qRL3UPijb8c',
#  'LA9YxMKjouM',
#  'DQ4z-waZrcs',
#  'En2Gn5ViJjI',
#  'AyPW5dnK05k',
#  'XlyaRp9eV7E',
#  'RODtPUq_PUo',
#  'oZtw7r5J9F8',
#  'HVOeQmx_2po',
#  'CRFJ1SD_2Zo',
#  'VS3aoSyfnUk',
#  'uYPy83LUgZ4',
#  '77GHeOlP34I',
#  'WmekGxKG3RE',
#  'cON78rNeTWI',
#  'QFbMEJt40ag',
#  'I9shYokUQhM',
#  'qUIVgonXHTA',
#  '9jmsYI_L4Tg',
#  'FkOk4e_-AmE',
#  'NWXA46FuBws',
#  'qWJe6tdOycI',
#  'pxDmMfBYtrw',
#  'Mah4n7TkYZc',
#  'j1Okduot5pw',
#  'KEDZScqNIwo',
#  'NH1wCBhtHZc',
#  'pnWUZ9mAM2Q',
#  '3WgHyXHOBVY',
#  'ECF-EH8FGBc',
#  'xGIEj5KbaQw',
#  'mnPR5ogBsOg',
#  'VvNNQ6bon4E',
#  'WyIIvKLqAJk',
#  'U5MlvnPLvE8',
#  'vnS7915eL_s',
#  'mcZBL66KK6g',
#  '7BPw3f5Y5hw',
#  'AoH0YCIyqyQ',
#  'gVea2SqSWxo',
#  'JVQOBHqxVUM',
#  'uqtx8eebtPw',
#  'i_BxLZzUW_A',
#  'T5I-yEkajRc',
#  '3VSRhlxLvHw',
#  '2dEO4N47unY',
#  'd1ouNUkVg_U',
#  'dUW1jyGVTVE',
#  '6VlN68-8BRU',
#  'PeZm30ybbSY',
#  '8oY3wUaJynU',
#  'd9hBQuJAyTM',
#  'xbVn5wqZg-s',
#  'hmjzBQ78m9o',
#  'Z1RKE5p655Q',
#  'a965vTydg6I',
#  'k-b4CiJCeMI',
#  'gFNZ2HkNPK4',
#  'Kkq7uAv3INc',
#  'iLNos9pOO88',
#  'Ya3KyT6DShs',
#  'XOPgSC2I2zM',
#  'IGDn8apNZMw',
#  'SNtK1Q3HIFI',
#  'qtxnIUhQoEk',
#  'BvkFubeYAQs',
#  'TOajpiOJV-s',
#  'R-N2iiGyqUU',
#  'lhN0NC5SGyk',
#  'E5uUBXOo0l4',
#  '7fWzaVcMyLI',
#  'Qe2TXOL4-8A',
#  'bwkuE_1r6qQ',
#  '3CvZugYxLns',
#  'aiWkKNtdugc',
#  '7qmyF4if_Wc',
#  'SRQPRmsBtyw',
#  'N_Yrge8gRDw',
#  'Y6JBB8DZabc',
#  'P29hoEL4MUM',
#  'LCORr8Kx2_g',
#  'dJKD-hc2mCM',
#  'LuhCS_ICGvI',
#  'D7b3oQmOXRs',
#  'Qp9aXKtUoEI',
#  'N4IyiMzSZSA',
#  'XPD5Pf3IoSM',
#  'uasxSj7UWLo',
#  'Tekmpe5pnMA',
#  'PrgoapZltLc',
#  'bmoboolrVQQ',
#  'v2TyDKtxLks',
#  'BKwEwHAq8jQ',
#  'cOxQZAXVeCs',
#  'PGWyRPCG2Dg',
#  'qachzDTxho4',
#  'Ii3MxLpnRic',
#  'aMFWFNCZVQo',
#  'P4jpngXioHE',
#  'PXMx9hNG0R4',
#  'r8p_w4-rv74',
#  'Al7mVj6AuIk',
#  'oLMiSZ92s_g',
#  'zj5tbOOokpQ',
#  'y-7-nlZh65g',
#  'ZD4aayFUJ3k',
#  'nVgzFbFmctc',
#  'qsBVOTpyC5g',
#  'D4DNXwyKf0k',
#  'wLV1Mb35v80',
#  'ikLQT-sLErM',
#  'p9yiDufnRZ0',
#  'KcwT2lkcSgA',
#  'j_mUU7rWURY',
#  '2ARydjmu2V8',
#  'k_sSh1CgSgk',
#  'xwk6dq1HNTI',
#  'F2CYBODWsog',
#  'zkTfppJJilo',
#  'YduSZ1AeZJQ',
#  'xwVRw8pXDXE',
#  'ixoaAY_cFkw',
#  'F0jVUOA2vxw',
#  'gTNP9wV1KrU',
#  'NsjbtGUQGzI',
#  'f0JkGB3RvTM',
#  'IWWp4LfTDtM',
#  'TtudvmZvx7w',
#  'iGQJxnGDxWQ',
#  'vcI5TNFrq-c',
#  'YfefS8N0zvM',
#  'gcaIA-8ZMX8',
#  'eMeB7ZsZozk',
#  'u84ZoZy9VPw',
#  'CvuJvr4kTbY',
#  'C0hB3BCy3GU',
#  '1sPto972Wxw',
#  'dH0fBgejL1A',
#  'Rsn5JzBMVns',
#  'GPCquSUkaj8',
#  'w1fbgu8rDBE',
#  'sk64BplMsVo',
#  'w-MpWfUA3_o',
#  'b9Gu4qqe3WA',
#  'NkxMZMllCSA',
#  'hcfXGMVu4oU',
#  'mc8Eu4cy9WE',
#  'K4niZzl3YPI',
#  '42zRwBZJfLo',
#  '_T5Ap69OpSc',
#  'U523efqwVqs',
#  '5_d2ReFT5c0',
#  '1MVykdmJ7tw',
#  'g-IhZSciCLQ',
#  'ahCPnfkjDk8',
#  '8MvT7z6P0IE',
#  'TQramOgqgD4',
#  'Rn8lBed3_Xw',
#  'wcsc0Zuz8cA',
#  'JisOkz0Aj9Y',
#  '-2H8HKPT6ZE',
#  'i6nOI8bLjfM',
#  'X5avhkB8It4',
#  'ksTc6kbfsy4',
#  'P6YVK0bTnK0',
#  'aG2eWBLGtnA',
#  'LGaIxErhPFE',
#  'FmUoIpfpMak',
#  'eRhEU9Yn-F4',
#  'krOzW2vfYRg',
#  'o9-IWbFxUtk',
#  '11xr4cUOmGw',
#  'iMG5llD-FoU',
#  'ml3ie-_ulWE',
#  'Bx84-AGzgIs',
#  'lDWC1xKO5I4',
#  'cS31Zk8HTDI',
#  'grpnoC6USQY',
#  'MHmWpdTjHrQ',
#  'JL5ANjIf3hc',
#  'QkwbGFLNp5g',
#  'JZMap4ojkWI',
#  'LJc4CwHaUj8',
#  '4hWVAjQUQIA',
#  '-PSs6GMcbCE',
#  '_IHihaFwSAY',
#  '7HQ0yVRDlEM',
#  '5wrpU81F9xs',
#  'o2Seui5SHNo',
#  'RYLwC8YTGpU',
#  'Un6M7SCqYlw',
#  'Drdvcf_wIzA',
#  'Ym1qw338caI',
#  'HpRlyCCgR5c',
#  'XmI260swiss',
#  '5h8GPfLTnMk',
#  '8HHH9RlkW88',
#  'g-X4OeSfJJs',
#  'U4Ih8ix1i-U',
#  '81cdNDbH6AE',
#  'G0AZsQ_UCbg',
#  '0gZ7l_67sAM',
#  '-mNIMjXoBAw',
#  'Szd5A8OQQrw',
#  'rLOzw52WMmA',
#  'U4-xg52tS1Q',
#  'b0hzvwNVNOQ',
#  'zLPmKvj-70s',
#  'FDf35XchhJY',
#  'xLUyErMdkXg',
#  'wpjzTOwjpWM',
#  'HU9i7y9gDiQ',
#  'jVp9cgdTguM',
#  'BuHLZCQ41d0',
#  'DVOxRAcR3TI',
#  'P7Aob-DlfXo',
#  'qVJPnnQhIV4',
#  'iUSvhyfEYL8',
#  'Dd4H_BCLoVA',
#  '41VXw-1G-VU',
#  'KKIBUVnUvnM',
#  'Wd01cYOCL_k',
#  'ARyvVq5TEYs',
#  '06lfRmze1BE',
#  'xiHzyTcxsOo',
#  'Gbaairdc_Bg',
#  'sFskv8SBF-o',
#  '16Se5Wo7fms',
#  'awoQza1PeoU',
#  '3Z1n_X0TCLw',
#  'uhkEXOysU9s',
#  'ZoaqfS-bTFI',
#  'DonOj5A-IfA',
#  'QIAVQDoyK5w',
#  'tiJ3L2M5UwE',
#  'xx_0ATAs_Fw',
#  'q2yt8GrnMqU',
#  'iRl-z0gOJk8',
#  '1HS6T5xq7R8',
#  'FE-cv2a4IGs',
#  'ltKv7OnfybE',
#  '-2GPnjkoTOU',
#  'U31VlhdoHyM',
#  'B3eW6SuPCUI',
#  'CVrJhiTfrvQ',
#  'IoUgs7tsnLI',
#  'QyzCKXia_C4',
#  'nly3cxgsXOA',
#  'bTPn1Eyl01o',
#  'HMcmSCMsvVY',
#  'PnAUiABHKhQ',
#  'QFp_pKY_0lQ',
#  '-mo0A3RctJw',
#  'dJRJnE7BWfg',
#  'Y-ExAIYRxbw',
#  'ifPC1Aguzx4',
#  ...]

# %%
len(id_downloaded)
# Out:
# 2448500

# %%
# downloaded already
with open("logs/data/download/440K/440K_download_ids.txt", "r") as f:
    duration = sum([int(line.strip().split('\t')[-1]) for line in f]) / (60 * 60)
duration
# Out:
# 438202.3872222222

# %% [markdown]
# ### Duplicates in df from joining parquet files

# %%
len(main_df)
# Out:
# 60102381

# %%
len(set(main_df["id"]))
# Out:
# 60098151

# %%
len(main_df["id"]) - len(set(main_df["id"]))
# Out:
# 4230

# %% [markdown]
# #### Confirmation that there are duplicates when joining all parquet files

# %%
from collections import defaultdict
d = defaultdict(int)
for id in main_df["id"].tolist():
    d[id] += 1

# %%
for id, count in d.items():
    if count > 1:
        print(id)
# Out:
# fyvEDS-PQO8
# QIySuiQ3_Yw
# -t-J098gF10
# QAgrHKTqkIE
# 5F5oJyZv0Dc
# LLIwgjSQnj0
# X3-I_5gdZ00
# 2We5HvMPLFY
# EcqahSwiJRo
# xqS5zApPnKw
# V7gZj9C9OUk
# liPcdDFouP0
# lqNAbx1nXkc
# xFAckAQoIFs
# OdJyNoOeYHo
# XdC3qMWmap8
# xUC88-IuEkM
# kNgP0TF-ENQ
# Rz8zo1iPr0k
# Gm-zwbxzzOQ
# LK4r2ePVb1U
# wseZE-FzyQw
# WG7XUDDBnpM
# L6Hi4HSVBDQ
# Woa4MU04aVk
# slUYJZ1Fm3E
# _MjflJq6f7w
# I2ADZMmP0Uc
# CpxeV9XMvdg
# gfv9EjSMQ60
# FKvAfEpijPE
# ScRAOOK-Vlc
# ppAk683jX_0
# BnQ_T-rjeJA
# EaYAwNY5OHw
# 8mGu6xP74Hk
# dtrfTUw6vKc
# XfdnPE7bQ_A
# bzWAKI7lFp4
# D3Fn3914hOI
# s6vH0tYrh9o
# L7joInxvxkw
# YKXT1oMhCWk
# ML_d9o0eQ7g
# 6lhiTVDJzio
# tSuKLGf1jXE
# e_MzXz3D8qQ
# X80Epyyy450
# r3jSMTmdhP8
# ew0w8-StOb4
# nkesANaBEBc
# sD4tmb_VYUU
# XKIC5ZAcumE
# C42IcopodNE
# yHwFqC8k4bE
# KH8HYrX-JvY
# GvIyZ1kVoTw
# 3-4RV5d9w4U
# 7Nt_W_TM1yw
# YELcmcSY1eA
# SlNh4aRMRT8
# _0j9JoWm9Uo
# 877UTIzw_Oo
# I51gsm0FHTg
# mdXmMblgj9Y
# ojnM5FfSHNY
# gmpdNWFCLwk
# LIk59pRMU58
# F_LESLVzU_M
# MlZvjMePLaM
# cVnZuq1XBa0
# O9npRJ6OVvM
# PCyiFADtKHY
# xLdrfWIs84Y
# KlkqaZuqkoo
# 5wy9JRzJ7aM
# ohc5qPk3y6w
# wE6-OYTH7ks
# C5SaOTC0tIM
# Qd1HedDfZRU
# ucg0U4qZ1UU
# XKhHI3wMcdc
# LRjt2rDtQok
# t7liAk1JPrc
# 7Ik3qUjzgFQ
# ogoLrcU-w5w
# EmRqwvk1KgI
# DXdTAK8lTcY
# A427cYw9QQs
# S254Z2CgEGw
# JiXNATXxjnw
# EM_u1CR82rY
# BT3Jsgimp20
# uF_Mu-7aaIs
# 6O-inTztoXo
# XPzxni16Iuo
# YDzHynGv_d4
# 8V6Q3SumXJM
# NhbGVsYM2Eo
# WFYlv2ItG44
# hcniaZE55D4
# Oy_CW5iaP18
# Hi-TEFvUn7w
# H1CG0w62E_c
# o5PNEjn2szo
# 6pJ3_dvwELI
# srQ_knBrxtI
# HfCfr9AzuRU
# pmJq3tfQ698
# 6UlEhexCim4
# WjPkLKadT9Q
# TTWvpShMbEQ
# BiYP9eYVZxk
# QrsKF6d6tug
# WpEWFm7C0xY
# 2wQb2f4pMCQ
# 7efZKfDDDgU
# NQqvhKAHdlM
# ifAa8wlraXk
# vFMKZbfM-A8
# ZRsIi8_2kVY
# EgUnnFJSJ7M
# 9sMICIUmKOU
# bQGDMrwxZtQ
# iJSRfXGJMNo
# daUnuvs_8V0
# T4NWKWknWw8
# MoKTpfq1t88
# OBCD5Lzz5T4
# NEIGWQdKf9M
# zIlf4tXqvqw
# QBi7p_jqdQw
# RKrVrl2tMBw
# jDwJawAsDbg
# RalP4zAYDDI
# wO2gGpX9h4E
# D437KwiHuts
# r1M_pSse70M
# YEGGwAASmMY
# 48g3oIlxngM
# yOrzMYlBPvs
# _rChf46fIjU
# 17qV9hXin8Y
# A5AIfuw9QDY
# O7bVeraRGL4
# Q0Z31JqwzEQ
# DOrbRovUVl4
# tOoOB263dGQ
# xDLvGzI0seA
# ML-FiO1syrw
# 6iWEBhlgUTU
# dCRk_KRwGuM
# 3U--g4iDHgo
# SHK9bt4Ofi4
# L-aqfGKaFto
# iuvL6uPsM_w
# qMLjSncsQaM
# ycJ0MnvxWQU
# lNK5rrD14GI
# khxkKuR5BAA
# zaa7FhfTNq0
# F1EFSUeSAvI
# ckC5SMCIAe0
# 9EZRJGOV4cE
# Zbgy1yZl8Dk
# h6nBFoEQ21k
# hZDUpXaSkIA
# dD7nflI7KPc
# MG0sT9gvHX4
# HWT1c-J672M
# yrf3dNp9yBc
# v_HYZkuMQw0
# Ecmf6betSZ8
# NJDCNpdUR-w
# E9doqPpeGcA
# OGyD2KkrRxQ
# mZ_QggQou8U
# a8MdoxOLO40
# WgkTDouZYl0
# a7Q0Y7zFyHc
# GY1CgLWpbcI
# 6za4kBb32Mc
# 6TpKc0KT02w
# snK8vWdpCGs
# _FZ03xExT0E
# pTLotb4cZh4
# zWlZCVADCOc
# ONCxzJYLemk
# DOveJ-XFHcE
# D1UBOzYkxaQ
# 3BsLDw98vyI
# -wUij-4lmJc
# XvredyBYnOA
# BINSjbNN74Q
# gcpXJSndz20
# 02_0FqpyJnQ
# _m56_mCdQFU
# 9v9zCExtCSI
# EqcQARkXw0U
# QYc4UKC6f3s
# x8dAPxu927Q
# lIiJkpyxPiE
# 0bSF19lBzao
# RlRshcwdY7E
# XiFw2iW83as
# FcuUv35bhG8
# npxNKvLcUTA
# YT40s5-zhEs
# DZnK2xU0od4
# 4q54M2VxPaQ
# wdEHzIWB-Ak
# haJpsec2fRM
# bWf5a5W51sk
# TCdfdDzAueY
# Ttfs7juBFUg
# vm2MVeKVrAg
# ufdF0XUTbMI
# 1csSrd0TG6Q
# 9UPQ6B34HDk
# nwCsjXgKZfQ
# 8ALMd3lQxJ0
# YQzgAqQFR2k
# yZS-9V4HdL4
# wyBJFb2LV4k
# 2DOP3jhEo-U
# dMAtxWuGaQk
# Z4x9nXzV12I
# E2Vo9YaOqKk
# LieJoFurgZc
# gBkwXHDnNQA
# GHo4KW6gDg4
# XCnIRWZVE4U
# x8oEZN2buY4
# yw8dIf4SNQM
# zE1sv71_u9s
# WNoSIa8--ZE
# a_xKOuq9XOE
# gnlNVlWdGuM
# XoQX0zr2UNg
# GvnMX6npaBk
# bseRddB38BE
# oSHz6FEYsWM
# q2GUwRBq5pY
# qLhL9p_uuvM
# NrPEG9zLXWw
# qzPgCpUIEV0
# yi6aYKxYEvU
# q9FeJtac65s
# wpg_NaXs6bA
# KinzfviHC9Y
# 7e-y1tX8EP4
# wI09n224avQ
# yS_8oL3alWo
# P8yVSDWXFeM
# 23TDL-Ksu7s
# qENpOVAiB4g
# 6qhKZRP6Lhs
# Gh4hQpL9gc4
# cbMkDDOMzFM
# LUQPJU5kt54
# tVR7XwdqVE0
# cwI8pf_-9lE
# 9SEiUujbjtI
# gSEo20CXe0Q
# no1Cxm8b4M0
# _go0sYYgU8o
# vhVc2KorDUc
# y6JYeSekeFI
# YGdTXtWA1Tg
# HuVk6nKNpQM
# cK613OrNI7Q
# nNVKhXNV7_U
# ah6WMZ1jFoI
# 0ZtOGQFVKM8
# Nf2wKRulFz8
# fJ0YywdMx_E
# JL2RpBSOSyI
# 0f8nJdIrRuE
# uEN2KNAxHrY
# rdQqbxkIqfw
# CkmfdQZ2-7s
# kx97vuBTexU
# YnmpLhhWRlY
# iyIo19C4JFI
# A7SWcc0ENow
# x9PgxTSbo0o
# sdZxSxRGVlk
# f9PIosD__fA
# KUQhiDWFT_Y
# eCNHFRJrUpI
# lxEMXt99tQw
# MviQ-YdayaU
# esuyHyBkDXY
# CU2yQxzkvFg
# S_73G8Qca9c
# j-b9TgMD-eE
# exQrNh99I0Q
# aDfKUHPIFKg
# 2DOTHkqbd_8
# bNu0hPMb9jQ
# FS1cK6vzY7o
# Qoym7QNilcs
# qp_Zf_i12Vk
# G6uT8IEtVXk
# 2nJlBh40DKY
# DtCZh9CVRGU
# 7JXQBQ6wre4
# 47UvD9YI9IU
# UBoIy2CKW08
# wyjVL9_tWew
# iZ6mMFRq6fc
# AY1jEKMxewQ
# 1xMiC2wWBaU
# 9yRClH6eZE8
# UHkOgU8mMCo
# NfvbMkzjPMk
# _VT2CA6uREY
# 0PGyNieM93w
# Y2D2XhBQJHo
# JeAbM_wJ-iM
# wWmNyU5nJmQ
# Bjfe3wT1b-0
# lCnH_SJBYZE
# ofOYAMhINeA
# TX07Ewvm7eY
# iWtsjUKlHec
# w9JJinOPJI0
# _WjaMRqXDp8
# KSto2hHxBEI
# NPCr6hXMde8
# SkIFj3PNMXQ
# VDl5Sp2mUqM
# Yn8pWy5fDSQ
# 9xX3SNvOwVw
# WauHn0zA4K8
# Y6Qwm0C19xM
# ruu2HO_ue_0
# Ovknk7B9XzU
# DoYMqYk1RRo
# 2O_1HDwIm6s
# nfFW8zs8nVo
# KlTZTjM4uew
# daJ1AJ708bw
# cw2n49-yTpw
# Qswx7IAAESU
# 0zGqaAEmmVU
# PPZXmYHynzc
# l1a0SUd3rKE
# ZMJEMUTWHBE
# _LExdLKXmRY
# KZz49YN9JU0
# BnZ-xIWzXJ4
# MpCjMqoQctI
# gMTe6YrDKLo
# eh77AUKedyM
# zfaOQmXTwQY
# zU14wZPV128
# BomaHfDnJjc
# IFwuwo5aW4I
# v2b2E1v4BkY
# 8lojzxNznmI
# yA-TrgTDil0
# 63x3Jr14Ih4
# afNoaGO212I
# XrWKbCmpjjU
# DS9T0sUn75I
# T1Qo_nCkgac
# seWUQgYsuGg
# k82ZYEGjh_M
# svJfG2WuxdM
# Pd1QYpvnhaw
# trNWGDcL5Do
# sVWxqmFwTgo
# UN5fzu7O7UQ
# R10G9ABqwWA
# 2CCDJr0GLPc
# Dn5u5A41fiM
# ym_WnZ5cu2E
# 5erxDoYYCOM
# TF-7J3LhpNE
# LXmwlbt0hlo
# tR1R-NOTxZ4
# cendNj0K5u4
# z74yKLL1O_I
# 91mbHKlhQvU
# EMgELLmFdrs
# nebg8dip8xM
# 1MwMsz2O0cc
# r9l48abLlL0
# TnnoF_2NlPs
# 2HF9kCfxo38
# TaR7hMgsntc
# ps29ajwb_O0
# VViqBUth0mg
# 05-BZ8RByf0
# jCrP6qRODEk
# pdWlmeQZLEg
# rue0DygTr2U
# O5nCl8M19GE
# VWI0niUrOXA
# FUafRTTAw04
# yhcnYReSIZc
# X8pMEWa0rEk
# jVgoDgy0I-s
# sLZOE7MlIl8
# 6_2lRdufhRY
# Fb7AvBIzwzw
# jlYSN40AQqY
# 7BGT79c6CtI
# 0KG5NxohISE
# 9GPrWUvGtoE
# uZts2wmT394
# IyMWH7LoFMc
# HH_OZcmyNRQ
# ZgEP7mIVmbQ
# bBFsHh2PK10
# H2F9oGSnxsg
# rmdxUNB4FgI
# B9DEyawblQ8
# mur6P3kyyFo
# GRWcb41ZTC8
# zmxQeg4Rbx4
# S5rd0MceP0A
# syWmPMrPMDI
# zgEA-qD8lVo
# qyB0Vtgt05M
# 8xUM9LjERO8
# TP9zUkdZgNQ
# MQ2XTE2Oyqg
# kTJbdb-5ej8
# CkJA-rPMup4
# YzVqrcgBjhE
# A54rEIU34YI
# w6Gt-3_TEK4
# cBK80Uzmx7Y
# ZaSMmaCnFpw
# ZkCDVsy4sDk
# RuzHsHQIYlw
# UYt24IT79HI
# JIoJ0MwTPog
# P9xJj7KiAQQ
# FnBc3nugk50
# uwgPfcYfiSc
# UGAw9AhTisE
# ClwjgkhK1yg
# X6lzd1V5q08
# KFjFQFqoC88
# JVZAswVQ41o
# UebzsoAIX9Q
# rpWvj3O-01M
# 5U6cAK9lBO0
# 4X2WQZHPqsc
# wQMcKHOAYQk
# kwB_kuwJdLM
# CBk27qKXcEQ
# ufSmYg7HycY
# b1I2FuoZwvA
# qCnWmz0Cb2g
# Fk4ZGRrz07o
# iIenBzu8-Bk
# OO03qGnCozc
# jhnjLhHd8ak
# h_ZnNDUigFg
# Cdsp3vDapuA
# -wk5h5V4orU
# auLsRn0KDX8
# RiT3tSF3SBY
# Swl5JBGeGtg
# 80jGlFd7y28
# SZBbqHxhaTo
# li4s14JJ84g
# X8uNMu4geTA
# SAPfL-Ss0kA
# V7gJQIWzXzQ
# 44qIcwaa6Vg
# 6zy_ZuqktKg
# o31YAUBiqN0
# 7T8_0KWKVpI
# bUooL3JhKFg
# t8gh08eoDY8
# SeQDIDyAxHc
# 3c5T0Q7eHHg
# G-ui9g82-I0
# kfiCjM8ZF5Y
# G0xkimqgRLE
# k-k17fHZhw0
# eP3qod07v_0
# l794-4bm4w0
# FE9DhDzyTxk
# alXsD72eEuU
# HuZKW4imQTU
# bZPZrLqbU0o
# jRenlzLUQLY
# r1yLQigTvvg
# icoRPDNHbCA
# wcrkbNfmvfE
# jdzREV9t-58
# we96wX2Tlm0
# SI18uD8inLI
# x8staFCa0mY
# HfFCw4eF28M
# 1_aBJ7Lh1Co
# n7-o-BA_2NU
# MmbcCnmyVjI
# m8aeybfblSU
# 6gdMG09l4aY
# Y-CNXOvlVf0
# 9AvpCX5i0j8
# domA3wnbcQc
# FDVEJ5tSJ2Q
# JioXzRNXV6k
# jRi-h4iseLg
# RLEE4zxJ4Oo
# HO0MJxetN-4
# bvtCbp7Bo-0
# FlkeRVyVGv4
# aEwzb3BWvD8
# bygcIdYyqqE
# 4bZsyRWPD_Q
# STDhuDcME9M
# 6kvY2zXBvGc
# -_LKCgoQhpQ
# UT0lmiOBjmE
# Bo9QHtTeoMs
# qyhuKnVzvqY
# CmkOsXDUNrk
# je_TUH3oVnc
# 9OTvrxD1PeY
# 8nYI4Do_Kbs
# NHnOCqDf6Z8
# so24gof2ZPA
# aaUCmMf8oAM
# 6ImvPs4kY38
# iunzKylTE28
# cL88TI31Umo
# rmpazHi33MI
# NuOHmv_LiFc
# QU4Tg5kBmrs
# dAWS28jbKBs
# 1BN3hEGhsk0
# gqHk9WuBGPk
# AXvHNyGELok
# AwWGQX8adIk
# YJDrSRyXfX4
# rCPz-N0ht_s
# FVWQzpyf3qw
# 2nR5PH_3QsM
# nTXx0OLg5C8
# 1TIV7O7BPe4
# hi6nFNkvxhY
# UTYYyD8Caio
# ydXc9EQczWU
# heeTHeJmRmI
# fLJ4DZ1jIZc
# moa4gLa2c9g
# tBgVJikg-K4
# XCprLBu5ytg
# xVy7MlQ0eqA
# -64qs9BEHns
# cWWKNtKh_YY
# JLAfYeqXbAk
# enmKIzu02eM
# rTPbsRK-7Qk
# QkNvy_PsHGI
# wOfOCnopkxU
# MoMRfBheqBM
# CgWLHYi--CI
# XxLM6w7GxWQ
# PkTBqrA6PCc
# yI1jChwqcfU
# Y4Dw6iUKWh0
# gC28B8HEWSI
# 37iKlUuDSu0
# yUhxWO-5EvA
# jiZUUvf3oNc
# WtBltvLVua8
# t1aU98NUBR4
# ejM-FEzvg9w
# WLXrPnoBVnE
# Wt5H38bkQ0A
# LUc5LRIArnw
# oeLB7THRw44
# gvL2fWIFPAE
# -xBm-DEUaRo
# Lt5miwgwTcY
# ad098WzSK5s
# Q1g_UQMIzrA
# XK3VXMwAQT8
# j5e1_d4GVSI
# Jzl1RaeRgFY
# 18GbNoJ6slA
# 3xJBjO7FQE4
# VfVlsoC09Zs
# qvLjMfo6bpU
# ptdrZd58pCg
# kdgDFFLce3c
# AzYNNOZa_8c
# LT4cABTPdxI
# PPMokAwFRao
# 59IzbMeUvtY
# 8q8ZM7hAosQ
# Y-h6AL2_uH0
# XGR8o8r2IFQ
# wWukmjbEuwI
# cM5iGFby6xg
# tcw20ffg02I
# OozOKOCvN0s
# eME8Hcfvotk
# jG0gL0YYIfY
# a1Iw5xmSFoE
# wT8c3cGEUNc
# PQN1xKeUmH4
# ZBrJK9G-FEw
# 7fV9sfH74Bc
# yp-YZXqOTgo
# YwE25R436DI
# IzwlEneS_to
# yo6xRG9NuVs
# aCou0tbP59k
# io32Em77zQk
# _bAilu-cieI
# vw20JYjO4H8
# GtSGylfSb-I
# f_JqG9Vp02o
# XmSA_eCwbD8
# J3rojBHV_3s
# g2Izp-QsC1Q
# KtZUVICCk_E
# fSC850gIRJU
# mdzYZVzTJS8
# hrzCLbx8gjI
# 3iiXTXXJUQI
# rSeC0zciuy8
# VTCDelqNxCo
# UKOVrw7GOVw
# Cnh-aNk4ed8
# ADpbdo751bY
# WJwod1hjdNk
# bLPdN6C9v5k
# 3B8AIlI2MWE
# Z60SqMwnBJc
# wj1IpPTkXSo
# 0kPaUQ1SqeI
# yPENHDYIvKM
# jqfo4Tp8IFA
# tm8J2i6sRjk
# _L6IwdfB63c
# hQnj6FZlZW4
# gaZIqfughEU
# s4OVNbT_D60
# M-R9Tu7mOdI
# U8Xci3exoJk
# r0g56THDCOE
# _0nbB6YYHk0
# SyI-0Vpyq_o
# hZ5RoHNoTyI
# ywKcV9nDBIg
# z1DEdJ0K48M
# E2VLdRT-Uds
# 0Z1Uyu5ZbOY
# 3xmMipSfM9s
# IedsVStS7N8
# 6BKSLnaurVE
# WZhqY4tOtUs
# _dyeSne49E0
# _bEQnRL4kL8
# v_HQUxposO4
# KSLX1FxWNFk
# Yr30XFhvwLA
# LAJFag8rLtA
# D_-ULaR5h_k
# ScGxHy9-nM4
# fkrt240uAFM
# jlsvP4PRZqI
# B2OWnpaUIUE
# ZPdTa88iWt8
# YBrimPqj8kg
# bike6HAPP28
# EJ51spNW24A
# 9XbAmo728Yk
# 7ziM8j21nnU
# WFUo3XTxG0w
# NYEdzCl_jzk
# XLMtOJVQqUQ
# bNh8a6EMHJ0
# Rd7hcPE-ys0
# 0gfDzACgbj4
# StYBHG1weeU
# gxwSZ9VCx4E
# 0ouQpcpKPZc
# m2ttJpjftbY
# qnzIWeW7x6Q
# lMzbSf4oWCM
# TF9fpaBh-1E
# NJu372K6RUU
# uH10Mqd42HQ
# tXOQ-fz1ywA
# 3QvDAR9Z5l0
# ppYIoHHzyB0
# ItrpsYLFdHY
# Px0N3WxZn3A
# wwwjWZlVLzU
# NN2utb-QXZg
# WMP170wfiJw
# CIL_g5OOPeU
# JVXu_cb0_6w
# H5BcTP4OUVk
# YOuQUKFbptw
# BbNABus0qfY
# JJGPjIUes0I
# q814B_St5Os
# -o7RBOkuZpY
# yp_ig_Vg00k
# yLIeRJWVtso
# aAT1BRiTFLg
# OyxXcG9dMX8
# nr6lUM-7MR0
# 0ODXCKtyMCk
# -wWARmk_p-k
# MyzOkjLTb4Q
# c-hs8RAk10o
# uThFbWBdYks
# xj-NH8kM5cQ
# eRZuNFjItaE
# VYreM31EGC0
# 5CYDhPXYT_g
# 8qd47V-ciQo
# QszQxxD8Piw
# 1R1C4iX0010
# AqUTuJF0VqI
# U-_3E5Ymre8
# z6wGSzfnznU
# O_xr4NseL2Q
# bCKZDyqsufY
# JIfTetq0fT4
# awUg2GI3skU
# Iu3MjRcekRA
# t-99DvrMFpE
# POBx7y89zc4
# yYxVMYf04n4
# 9G8ftwqFwes
# SenwO5aTsZ4
# LUUPFu5-Ur0
# zX5ULewm38c
# 151HZav7ODk
# xogVkeyMfVM
# r1ufw0iG3Ns
# PYo2v2WGTjw
# GbCH2AEjVhc
# z7J6HplqrBQ
# QxVoG2lCx5M
# Eux1Xdcvwig
# IzF3EzdcTok
# P9_-x9OwXBY
# yEUYomA3rPY
# ZFOSSZDF4e4
# SpPsiNJEC2A
# x0Mqg15hCUU
# wlVC0R8pc64
# k7NE3hlrG8o
# Zxpc7fz8WVQ
# tT1BKpgK6A4
# S58Z2flRNkw
# G-DWwBQFgSI
# 1UBXFdbDgy8
# Xz1pxDO-qIE
# IM76yBJfb7g
# CKOdzEofppo
# L-4wOWB733w
# XPCOfL1YJPE
# fJy5s66IMKI
# nCudx9z7CIg
# D66uCe8S9zU
# 80zxw9ZtAfI
# 4hK_9xSlK00
# 2bXDUbRxGUw
# _2khPdWX6eI
# AgrJ1_vqIHg
# gY_THHkVW40
# BvJbJvi7Gmo
# 2CWmrpsN41E
# KPE5W8MuRF8
# GkXOtldEFWk
# UGVo48CwetI
# lJTrOxYDj4E
# veHrtVLz0uE
# RbuHUYofCjQ
# tEVmKL_Z25s
# 1Ntv9l4xAWQ
# UbHuyaun3Tc
# k6GhQFaNQuc
# VXBUXsDxMpQ
# _YtI_GuLhdg
# pgHWk1cX0vc
# LY5nXTI3N54
# ySlBwdiyM68
# JCsrFWd6wn0
# L6lE3AkdTaQ
# UgirAoeCgU0
# n7EAQWCBUtU
# gDhsiJxa5w4
# 81DZzgzs2KU
# 7LO6M1UgdGg
# KdbvTuXWiPY
# 6MIHqRgYtWE
# HUfL8h28SvQ
# wNc6T2ZY2qM
# AWC7D2qLm5I
# KoZ-Vn2jKmw
# uxzqFkgkuTA
# VfeB-GcQt70
# OfgOtCdUeX0
# 7FL2cfCSRpQ
# _PkXq8y70yA
# UgjNymiVlLk
# Gzv11LWSaFo
# muBSMdrvjRA
# _RRnenJD8W8
# o_Aj04LiQTQ
# xSwOH8wsf78
# wEcI8bKpkX0
# P0_qlR7fr14
# E6-Z6Xjocrg
# G1NiTlCtxPQ
# aIZSSN2NZ6E
# jf4KTjefzZc
# MGcqnK70iPA
# 5-e6qZPqUtw
# wdeLFQneSNs
# zj5CGCVVkJ8
# 3Em6i804kvY
# osiB4oWMSHM
# W5bZ1bEXuFU
# T7VQ6OwJAyc
# Nka19f_VUts
# TjW6Z7EmxtY
# 1VhH3GNAM1k
# C-NLNLaatEI
# W0RyJ7L_bgw
# FeBPlcQc0EE
# AcA6EeGDpNo
# LPSf0stqkvY
# MFMTfPaHyww
# mui70_KJmho
# NrJD-25sa18
# _96VHrdT1oM
# B9z1q5_Kt_Q
# etBUx4ZAReQ
# 24pcuXiZJ1U
# F_pEIgdiKRk
# 59-116339I8
# Ll4V5pMVOE8
# TJCF42W3-oM
# mk3WarBPHQ4
# JJM3JUeamVg
# 4UTUGFNczk4
# vAFtLikKBY8
# Qtkj9EFcYYk
# 3FjMyfc-gNY
# fqvbeZjRCS8
# itChKmP2zb0
# 8xF0a73Q-Rc
# yLv0Aqi1ef4
# dYXl8pWX69U
# 3D5B6MQ2Nr4
# UeMk__KvSGQ
# cSl4POL0-VU
# smte1VPq7J4
# SKSuFTDn_DQ
# m4ObF9K5TJU
# MBxkXI2NRJk
# z1MDwV32qD0
# oJ5-Aqeottg
# rp3FcVJDaMA
# NsYiIncDvQM
# p5DXou9Exx4
# 15t8j_X-C-0
# lCei05KynXc
# kyS5zOoygUY
# I22O9cNiRIA
# HPweLiMKVwA
# gMnow7b-r34
# tFtwcKxsS4M
# g1sb3UGThyo
# TuHlyjWI7Ws
# OnlP6mEi2Do
# 6KQjmfx7Ipk
# CE9nNQ-EK7w
# M_cCXADIClQ
# yH2yvFceZIA
# UCall9dEsUM
# ppvCzIfvSAU
# p0KcF4aJndE
# E5RV8ZR2RXM
# Qma6j1b3HKo
# RdiL4ekbxOY
# M6xowDMqOGw
# psimLbWf8Yc
# zWNHd5mhjtI
# kAFF1sRLIJA
# 1PyH_4eZoz4
# scZ-goRaYFE
# HrcxooUZqm0
# p-JWFySCzeg
# SwSakR-1SNM
# OV8Au6MPJew
# oUg-TdxP-MI
# 7-MWM_Tnn2Q
# 36FctF5Lf5o
# -LUm213hQCI
# bDC1kaR3Guk
# JV3lSWnxEps
# iNNSQtRI4Ys
# WfIJwXbLMCc
# W-Um-v_34Vs
# JZUqRzRWzFs
# 6kty59qaPYs
# FQleDy2qFh0
# KtoVd4FDirg
# 3CEpZSsSZXw
# PUFsCrX4q6E
# aAtwO0pit3A
# lYyCyJQBGGE
# Nr2F6Tlrxfg
# kxlcW2qRXc4
# qq8YWazlBig
# vuwOyih_5Q0
# WNfTWYvgKWg
# ErN3pWN4yN4
# SNexLVRwEAo
# qqb0JgSuFDA
# p67b3EGLbAM
# sql9XkaaW1E
# OBqvUyKOwq4
# 38WEWEezMU0
# atL3u3mq7Kg
# Zz2EPdtbSr0
# BDAspF5NBNE
# hWzwZPVZfU0
# ZQGEnkfpexU
# RWS0hRN714M
# QQtGhPrxGGE
# LqMb_fluxls
# WXGCgaZjTKM
# nZtmfgQOuTk
# k9aUccXtNPc
# AIKNes235RA
# dyOdQxaTBrw
# KAHlifC6q-Q
# LwDDEIx63cA
# oiX3Hjt8Ekw
# KZaEhGtR8-o
# 4EKwPWJz7pA
# 2Xs8om4xDYA
# JLhaF1QNEnw
# YRzYwyV1EaM
# xqehxMwcAFg
# AuwrD0zjQj4
# GHVjzs-X19M
# PSixaklYywA
# IQtnt4RnxXU
# NHxO2Va95RI
# oyeVw5IpknA
# ldMqUGYFHkg
# 3-eAqbC4QGM
# GWOFF5tMv_A
# ShXswHycXbs
# gxr7lUtlRHM
# 001bZCFyoUw
# VJndvuIvcbQ
# qGAqJCKAy5Q
# XK23IQHJay4
# qFIunKHoEYQ
# q7augf0AMAE
# I0ml8iE0tt4
# nR4bKRcIRXQ
# e5joOUPINiU
# Qt8Ijd68Mfo
# Znf6m1kVlGE
# 5_u35V7jRdc
# 5dBI0LLMzQk
# ifbE_xAlJUc
# na9xE6s0b60
# DRsTqtxHysk
# UCJk14oMfXI
# Pa8k3miH-5U
# G8V0yjTxZ-g
# cA4Q8icc1Yk
# QfDYz_c6cao
# ISTyD_TmX2A
# GQzGddSSo1I
# lw5MkyXPPnI
# 8vAa4GdUACQ
# t47rPl3EIU0
# pek08EhZTIc
# AM7NwZWmssY
# d79aX_xxaTM
# YKq2ajPA-ms
# nnULRhMZhn0
# XGGtpA0SW1k
# pIC-ahUfEo0
# JanDJpiSvL0
# i4Ui9TFw4WY
# OxvHLi_cvAQ
# crXh39yPIvY
# 4KeMLsYLAyA
# PkLxOeNUIQo
# 1hvU6jIuAB8
# p1t_14tKZ2c
# qO_h5qpS-9g
# ulnjcVZZWno
# b08guVrXAm0
# O5rdhcwhQAE
# CubLUR6OwUg
# uBXDNx4TPSQ
# eLtqJm6VAvg
# SBV4_tPJ8zg
# bgzBOPuDEVk
# h72NHbcpS_8
# vjZ_sfNOU7o
# zAVGR6gLBDE
# qVgey1e-HbU
# ZBYrBA90atM
# Uw63CkFU-po
# gUKBFznvGe8
# 1aJ6xXuH5k4
# FY1ZVo73Jfw
# xgsX0CDnLHc
# xRdd2yr2Vuw
# pbfUjpGNHWY
# 4NQ_T1lFofI
# Kps2ZnHLXYc
# -fNp0OvCckE
# -y4WLGyRyOQ
# 9GksCPkzk9E
# Nzu8ED3dR24
# ugmUMmaTul4
# HFeqe41sILU
# cneYNtd00mM
# qG-8QA_KJVI
# hGOea_saUTg
# gHehSgF0S6I
# RFG_XSqzkBc
# MyGbfe3P5j0
# WaqbhvLZtH4
# fhViWB-EfwY
# bzlpBj5UzMA
# rfDuZyNCSx0
# BCoSnksLMfw
# BGRGEa6KDJA
# 1X79viZeXzE
# j-ESFjGxivw
# MsGMnqeYJRw
# t0HXDuG2bro
# L7OiS-k6NFc
# TO4ycvBHNqM
# Z-HM2Ew_I74
# _6v9aunoSQk
# RxTuVwloo_8
# RsCnKV_au5A
# hGIWH3g4NHo
# Hjlece9rovo
# 4oczbdAaQdI
# O-JgvMocRvs
# wACq5cTi7v4
# 1ge1tgBZN_w
# WT9U18LszdE
# 7t_FAt85Gto
# hlSw355TOmk
# UFOQmPHVdFY
# eRannHDo_LU
# esZgaDZelJg
# PDVmRPfC0bQ
# DqzA2WFcw7s
# L2EbD8MCbAc
# v9Z_QR-XREg
# PwtDHFCPnt4
# oIcQlr9sQqU
# UsT3gqunXWU
# TGBj6Ri6jcE
# JMO5nquRJv8
# Nv3qI2S4isw
# _KjyOnoWtpA
# vF9Sqsbi7aY
# 30jFr78QZKY
# fDS3uxH8d5A
# s_xs_oPfZ98
# ZgX3O2xM5dA
# wPUcxeAtZsk
# nZ-NjNZpKnE
# mUBZl8Hg3Kw
# b-KZO-JIx2g
# LgpKv2ehKI8
# _V7bu0oXJE4
# GgwWGq3Rme8
# WKVx0e6hhDU
# r5b325Y2K4Q
# MH85B8GFwPY
# zk0ir6bZ2DY
# RZ5PG9-CEY0
# CyUcKc6ZDRM
# D_KkMRpZxiw
# inAl_Wa4cds
# 8GNrf17SkVo
# fw2n1WxBiYU
# HDh3qINW1hk
# 2B4Zsq4hf-c
# xMvg_WBN9G4
# 5qKNKnZGUCA
# oSszi1gVK1Q
# VkjMthOEoLg
# T3wCN3qviM8
# w5Ba-0yvIz0
# sb4rIZB4Vt0
# MLnJW7-yxrA
# qNMj3_DdQKI
# 1BBPhKKzDjc
# exIJVSKz7Vo
# o0EeH3DKlCA
# 1L-RFOO5-QQ
# MV7J5OrpLg0
# 8T9NwWOmHgQ
# x6PPeLnPRTY
# WPDvu9vYX98
# LVc5-NDM8pk
# zGfTID9-ZLY
# YNARQGbWQxE
# uyFBJPQocPs
# g-Kd95CWGDM
# TbzA_REDtMQ
# mDRpN4ywXzw
# oOqkAIOnOHU
# gyBQ1lsseds
# qvitrN2cEik
# UCjvWq0pCrY
# dRVy1vG3Kos
# ytrbBBpM0pU
# Pc5ZfcNLehs
# uooOTRzA0k0
# 0H1E1vkw3ik
# pC1tThK9hek
# IFym45dgP_g
# 9B7qeApWtGE
# vs9KqFqUtLs
# 8T1mKEirzNs
# -1gfOcdkjQU
# GG68CJEndpM
# QTZXZXbDHBQ
# hx3thRb3Eko
# 7hG-gy04GNo
# f0dfVveiDD4
# sW9feENESOE
# UvzRIj3A8Z8
# 5Kal8Z5-ZGQ
# Lb7f6Or2iBU
# xJfjOAc1R0I
# ZxSDUXViTHo
# 6RgYaPFkBdE
# KgWOd0jBxDw
# B-zygAV5AAU
# kHb9-O0Rmwk
# 3XW0cmCo6RI
# tzg6pQoaxq4
# OorAXYg5ucY
# 4E_iu5i6v3g
# hVyvWQlm2hg
# -FanvfvN1g8
# jzOd2QW2Dik
# jzYjq-Uhtzs
# GKs28fD0N8s
# QHySbLw5_4I
# nzLRzsiKTA4
# FkM-7jHKa98
# PK23Nvl0DRI
# 1Kd55aRVEcI
# FegZdNkhBr8
# FUXjKgccJzU
# fpR56_364zI
# oUPWEx9iN78
# StpCebRyefU
# now0TSUi90Q
# GmXw6o24P78
# M70NMEWN-GM
# Iy0z7Jv85fc
# hr3ldOx9-aQ
# s6lgGWcoWLk
# a_tU6ecW6TA
# 3PF8jjmkP1Y
# U34yk9uzki0
# IB-gD15u_yM
# pPDtjFnthKA
# Oxd6MW-jFaE
# J4yclxGr998
# SEfzLYYKRmo
# ct9xeYKfaPA
# KxzwYd93fT0
# SDRDe1EMong
# cWNHB_AUbZY
# RNcb9RmHjPE
# Lx2q7whZVjA
# 3yf1A5PI0Iw
# zE9nGJlRHP4
# MQ5kJISWhWg
# lUMI-sA7654
# 0d-17afSJUI
# O59CwHwp6k4
# w7ra0eZD72Y
# Fqx-JBBJO90
# Wp-X5eg4ywk
# Y8MCmtxYhjM
# pF8LxH_1N7s
# LgqEhBu4tP4
# l5GjFGowaRY
# HJ8eN7NvoRY
# KsVyVIugrCI
# ZHZE7jssKU8
# wHzSXKnseKM
# 59cDVtf-I3o
# RXx7BfoYjd0
# azLP9Xg37LU
# Tp9mJ3OlsDU
# UGdsMev3Vro
# cD9Ilvl8PIE
# 2frrpsG9Rls
# x0aY2a5HNb8
# BXVeqUH7kyc
# ifX8zauiWLY
# KD8e2286CW4
# DU1f6D7D3po
# xxL7v_PC3vU
# xnQyvUdl5PU
# nyV51j06Bis
# 5yC0twey3cQ
# 2NoixLFLTg0
# ARorXiLttZc
# qy2qlUaBA_U
# CkyRkI_JNwI
# IdkYjECqLXM
# dBlzF4QpjUc
# 98MA1j3CWR8
# psYSUjok5r4
# 5YNQ1lxMoa0
# oIXPx51Qq1k
# N3n6RyZW4v0
# UkTQr8fyWFU
# aC7PXRiN4-I
# E76VibL6qzI
# fzxtZEqgf4g
# AXQuP3VAdSU
# nwfInS-HfJc
# BTt_ZvDNFsg
# EMEEdOAG6Kg
# c5wZwk4msAo
# Fakfzpgcxbo
# CzvL6JqIv6M
# qkOhmk0Jp_A
# cbygPmvNkP0
# 5OcxHkaJjw0
# N4ZWqeXuPG4
# Xc3LENxxD2Y
# v8Z5N5UpFfk
# klDxhjrbO8w
# XyKTMOyWHjo
# Ymk7ppILwS4
# jt2oi2sz1-Y
# KfsgPzEDtiw
# kJX2Ph9y20k
# qoB0BjzOTUw
# iKBXqfxh4qk
# w3ck1OoA9tA
# 9v8CLrPRKFA
# NJ3Ws9BQ-tI
# w6NSxA5ZWpw
# RWcFmtvhjW8
# At31UkWxdsQ
# kA3AsXLn-aI
# cG6fUXKZsKo
# -UnSdAXWwY4
# gRR_YRbXVr0
# P6gJczr980s
# lCIXbhFW5SU
# ytFKorKcr4I
# _5C6OuIhI2Y
# _mLIw86yqPM
# epHrd39z3t4
# 347EqcC_ciI
# VOO0uUsqfE8
# AxPVUJxwcM8
# IFqMcoj42VU
# PPnZ22WrH88
# EfVID0ebKJc
# 7AtHw0F-XNo
# kVp2XN4mI84
# K1K0RWgM8L0
# WLwLjf9dsgk
# FsgcLKQBcIY
# iP_xi3nhScM
# 6celcTghn-I
# xY-u1PPE-io
# vdz_9qW4z_A
# uqIXNL9NikE
# y96sWYKl_y0
# YZH1myCaeVo
# HL7mC2WryLA
# 7RsbkTnbrZM
# MAUWVD0Oa6c
# Bnm4zm4PGrM
# IS8gnL_PkU8
# abVRjzaVo4U
# -Ndk8lbFn4g
# p10rZAKB0-M
# UpJ-iU9vwqo
# viSDpK7-52g
# gKwlp_nAlyA
# -W8JEuPtPR0
# 4nvwjd9Jy-g
# k5JAUmm53uU
# SiGB9MbcMok
# FRgo9RyMEcY
# FSLsEjfiXQ4
# 28ecrJ3rzwY
# 0nRZRTbHQXA
# 6hDhfQe5skg
# Q3bTcO__qPw
# pf54EflZxN4
# KJrSFzRcbtU
# rCNOnhvGvQQ
# fT5MI2zvpYY
# 7ch83blSdE4
# RwbGuHpggCE
# tsLVYv84XJc
# T_sgSX-EjPQ
# lO4_QNXTFJg
# 2tLZEvLj02g
# RjN8zT9D46U
# cZ-Ew21nsvI
# YGKJxm_u_Yg
# FRiPpCPoNs0
# ND4Xgydof7I
# Wzb8DQtUUDU
# 2o8BDSPZ6WM
# ij2dL9R3r60
# 1kCVt7bZXIU
# 5GGI4YaFHl4
# jg_2x_Loc2U
# N7oD7qh5Gt0
# jjGVv5vrRpY
# 3sNqzIMF_lw
# I7c8RdIMLWE
# vCTeclcsgVs
# YgdOLQyq6HE
# Zys39GL42-E
# DK73wQEghZc
# ZonACAW3aws
# OXQKRi6_Fk0
# aBX5G6v3DAg
# l-mcI9XIkQs
# Y5z2JQeYPz0
# F-rmTlxdVKQ
# PuIcKGgvdU0
# jWgYhZlWs0U
# 08lYdKNRxyU
# vbz0Q-meed8
# Ra6hbKkA4CU
# _aWM4LXIY7s
# k5mZJvayfVs
# rGbsK0NSM6g
# BuApn8ZN-kE
# Uq-Y7n8EM9Y
# ZUEhpZnGCNA
# wzZZ7pEJMJ8
# 4qB_haktUb0
# dz10Xi3dFEY
# 5rKaYcsITBQ
# 7cZBPJj3ivs
# HU2odSwriY0
# aX_JgOhWqHQ
# l8q3CvKt8os
# 657CTzZpp0o
# 3JsPBEXAeO4
# aT7sRxAA1tw
# bFLOeH7rkxw
# hOIrvBKlUKc
# 9ThPR2d27PY
# WuQVwnwih9w
# i2X4E3tl_kU
# cbFmvgWvIhg
# ouehRn4oz60
# CKrd34nIkbQ
# lmc3lJmqAXk
# _FSvyTVytT4
# 685q94f61iA
# qDbg8ccPSrY
# dBpJgIXss2k
# x_sNLoQezxw
# 70sCVCHNGIM
# TI6HV0XmbBA
# kLmGmB-xLio
# gaa0pSlaF_I
# UWhW-2A3EK4
# won51T1wS34
# MPAZ3siVTzI
# SbpM-oTUQCY
# X1q3ru-ej6I
# uWBXdplpqOw
# YksNHSYKxYQ
# P3OlqDXODO0
# nOw1uUoMviQ
# wSNsAkIQe1E
# VM2BDBz5Vss
# bTBmI49ZHSY
# 4seV3pMINwE
# gsDX_SW4XBs
# wv0i-Ud2sYk
# MweaZW8CRfs
# oKNBvUSpmgs
# lMkSF6fzgeI
# 4VxQfSpg8Uc
# 0u_22xgfnRU
# o_tX8uw8IrE
# MTHY8gX3EZs
# zn0jmURafvQ
# owgBWNTBjoI
# aimUpaNieK4
# He2jbyjeUuk
# bLE9awPsFbA
# 0T20jkTYm1k
# mr8c7_oRf0A
# 5h738CZAjm8
# KqpoFjoUpdA
# ZvTYDmHXV7A
# MndJXhLLpgk
# 0pHn0TcUSNc
# a82aH5ZKYBU
# 4j-FXCJTCXs
# EY4CIY9bCRs
# wK3sSSMoguU
# hJTpnMifCe4
# DRu9bzCAX_Q
# Da6Sq9h6_JM
# FL-gVf_osy4
# oKwysvAfaO0
# FArPausB02U
# Tv0Oxd7rZ10
# 4xmApwb622I
# IAGK58643Vw
# IpAYumhCtkw
# h7-GOZDx-iQ
# Ttadpjp6Ufs
# h73a-dvu6Ig
# MO6Gyhvj0kU
# utanlrzR1Ng
# VPrFX43DxBw
# CH_y-VDH_Z8
# bHeUW4z8KAo
# GpOQnzIYcmY
# esnd2KVjXPs
# iM3ssaSktbk
# VqKUmbacOGM
# h1lpVIDiFs0
# D_hpdO6X7Ks
# vfQd0xG4rlc
# GP6r2WOkU2s
# qcN_c5rPsc0
# AX6FW0chhnY
# TM9TNONoxiQ
# hZ-aTDhRM-Y
# AeNjF4w22mc
# EiP3NQsOfGE
# QGM134U35Dw
# Uy2rSAssKpU
# 9W5E1VCzCEc
# tepp2G2u7y0
# Qcju6QNOCDQ
# PIQ09WwKk3M
# g8mdIXhWH0s
# IZVxVf9H9ag
# VSd7wJtdHoE
# tPufy6AcAlQ
# 5LrHMeT9oto
# wagON4Gvh-c
# _c9S2SVuOTA
# NxATocnQDEI
# Lp9N8TfPF0k
# 49jo3WSTSM0
# hB2JDYWUQto
# U8_Zabxa6tM
# KLOb1R_4BBI
# Gao5v2fE6zs
# jJc6PF8SwNw
# HCSPaRBAFfY
# 3fVCWKJXo5o
# s6U_T8fO-RU
# K096r-6pUgQ
# 3Se55NBBfBg
# HNzks1qZ83A
# -bCxl1oRWKg
# y0C7rEpGcoQ
# qJJHNatmrPs
# x9N3ZH2YSSM
# sKF5sEqzPjg
# vm1m5JP1Uuk
# kYV2fshuksY
# 0UJhEpX2Vhc
# QL__QdI7hCg
# _PKeYzJE-8w
# dNSWVibmwrM
# ho24yTXlRB0
# jlUtNJXhyAs
# YzXQP6sQ6v8
# oOeQ6E8gxJM
# U1tZvQl3MUQ
# 8nDpFYeZEO0
# gjYa8cCQCFs
# PeQjwBiTukI
# 6NoQrUP3EVY
# 95tSAuR_mIU
# GLT-81aZSlc
# TmxG7R6_oGo
# uX4r0Xa3zmA
# Fqyul1UPDzc
# 9wu3gyQ5iKc
# LqpXU9eiNFE
# lbjWdF6vElo
# HsVabyKEyhg
# TgpKMEcKuk4
# IcVUs90Ee0w
# IVjl4r9ZCHI
# 00BWaji2tW8
# cr6pP94wqB0
# o71hTmuezm4
# ITC5Bcj_reg
# Oa7SXDEcGkQ
# vYmpJEQynEE
# 66sAqxLAr44
# 8ybs0GyTuFI
# WU_ZYzzwhH0
# NZaYB29bjZk
# yKJwYbB_OYU
# safQr3sV-rE
# ZvPsBLp28yo
# _qHWQDvqSE0
# uD3RFznjEnQ
# mqHXFP90ssE
# IeKcjavaC7k
# ZyfrNm7lW64
# DdyQwJ80UbM
# U6h2aol191o
# W5b8R4r7rU8
# DkQXa-EKz1M
# JpVcQ2blnKM
# rJdKOvxHwZo
# WPqAaB8DbnY
# mWtu-9vJaXs
# W048Pr_TFRA
# tWoQFFIMRNU
# HC_QCY24LJk
# Vw_eK01EkS8
# qhlb1hgrWws
# Onp00jfJUbY
# M32ke3JgTw0
# 47eLk1d5t6A
# _Ti_zR6M0Aw
# HReF2Hur39g
# Jw0gbbsW2SE
# JUPFQl2mzgI
# KmXl7ReFNb4
# AX2XMUlVUAw
# SwVc5HJDXoA
# XA534EUz0sk
# UhmAKZpYBqI
# q4QmG1CXRXs
# DfAKxP8K8Jo
# DP1APoZW23U
# 5sylNfmVF_0
# AitfDr3AUNA
# P9w8usDXaA0
# HwigyT9IYLA
# Hy8Q7hd10Xw
# _kzGdqomvec
# 2QUvHI9l2rc
# g51cIqAlzyg
# AZoYBaM021Y
# I74KhbQPQjk
# mvuA_8rRB0k
# KcKmLL3xSPk
# yOa8saI88ik
# iLIXBkzNwU0
# uQ3JlsWWs0w
# gMMhIo-uIMI
# wEYiGMM9QSg
# 60cuDzcWqTA
# wNG0ucj87LQ
# Jlo1WooLvu8
# bsRDtP6ta38
# 9pJU-H2O-Ik
# cJKMLhylEuE
# oXNYYaBm82U
# 1K1u6d3aYTw
# dRW7VhST7OE
# 846U97ZOAJ0
# JgbP5vH3Uls
# 9YFtISOCELU
# 4RpRSXSC3bA
# pmwSsRZgEGQ
# PNJgCqCxEKw
# GApnkmOkBLI
# 0d4rGkNhYO8
# lMkhOBHDm5g
# qkzVQ9e8m3g
# kRQBiq5l3WE
# qW0UDomvLq8
# sG_2ayK79B4
# EPlG6UQUT4E
# G34W6xi50IQ
# 7ZXV7tS7jO4
# Jz3rhbS5Jp0
# qx-LwsSuH8k
# JoN37lmc_SA
# GC24ep_sgJQ
# H2EaqTk4wbI
# bN03pwSC5W8
# abp2IzWY1lI
# T3K6qacyM9I
# OJ7vPqaRrnU
# -wTVDeBOnU4
# VXyl1TeGZOI
# S1zlVjuL9vE
# wn_RHKBqAcs
# d72gIFjmUEE
# p5nMWRgUcio
# 16OXiK0-GP8
# -SxGLKuhgUA
# OG1VJdjWIg4
# lkRva8muMAc
# A3VqZ1V7j5Y
# U0ewMr-d-Zg
# _d77_s4EcNc
# lY-c_T9ZCHk
# WdNDtkd3xNs
# d70TikRVxbw
# ZtOI1MZNIdI
# ceq3Tw0krA8
# UfH0h869vqM
# pvZCBiwEIr0
# 8vkZRtKAmD8
# -bhFf2txEcY
# nNsWq4FEAvU
# 0XEavg-W3lM
# MI5uZR3Vixk
# yoQs_sAqmW8
# ujPUO9sLijo
# siIAkA67fC0
# 6ipMp8WxNnU
# jrQySaDmuQc
# 7UF8Zl0BFKE
# _1J5SLVExrA
# F4ob5EG8ixw
# qilEFziSe3Q
# Yi4-8lt1Bvw
# g3XOp5xhbXo
# 7zOS9sANITY
# vN1jRuLwFLc
# OMsBe8Tt7D0
# akt6as0dYAQ
# NgFxd0IOR28
# FxKo3t1D7a4
# EuGuxZ7zij0
# K3nf115_0gA
# SYeW3c8yUfU
# w9FWGKeyubk
# Y0aY88t18SU
# rh9Vizi9r_o
# KbeG5x2AhUI
# Jr97ZWgEZV8
# ulfY-wdWjkU
# 7ooOcXYHRq8
# tBXkOQ10Qq8
# r-iesGeo5IU
# v7pusxn_mcU
# tXMqsWAwKww
# qmIlC2ndgjM
# ePDGHlJYht4
# Q4VSIQ3ObFw
# MuIoqsqG84g
# fpZYyAqQSrY
# cChgbcv7HN4
# MjM6VmskWGw
# h_bGDD-s6ys
# dEGlVa9ThvU
# jndiEYCpuS4
# eOaU80s-gR8
# LL0JT_6xoJc
# v3Kfl63HRzw
# MFR9xsjVsZY
# 6MCTLpazzjI
# jIrG8MFwGsg
# _MwaEBX19sw
# qVset7msGaU
# Zz_jfbQkMTQ
# seTATdw-qdI
# tiZrQgKptyg
# BxbnjFDkEYw
# bU4kVzGyzLQ
# wKPqbdC2uls
# LUViWPhalfE
# h3NPXlZUbJ4
# IsBnSSyT_jE
# -wrBNJ3nm1c
# hca6C5JuPQ4
# auCULXWOeao
# 7tcFSdOna0A
# 6bdsvjSsHm8
# XT23a91pBo0
# Ji4EhAVZQGA
# mdKbHm3-F-E
# BrI7xJJZSog
# hFAj1wqy62U
# gS8XmWBcJgA
# RbCjigXrqrE
# _Uv7fTS71ZA
# wH7D2z-6H0k
# AEEyJaB97GU
# 4PHHh2I3adE
# SgOwbhz6GGY
# h2wIjL9UUdU
# -hQebZNLJiE
# GB2mBkHdkXA
# p6RQofzSgc4
# 9PUxwOaFGbU
# t6wBJkL5MBw
# PJkxcSZRH28
# k9wiEA03HKo
# GEvyCVeE7Fk
# osSnONXFi4U
# 1FwmYh-FoM0
# u0JGDY2YC-k
# y5fGvAal6wk
# TCKMvHPr3Ew
# OQAuBNLadws
# cllorceYICY
# A3AthwH2bfI
# 6Xag3Z5usPM
# mO1V_OFOjTE
# 76IwpdJNJBc
# k_wpZo6PmPY
# N-mI3Yn-BM0
# Nh3GLUZpR2s
# nMk2E1aoy9Y
# sYnDfoSMlS8
# VBB9jrq_bhs
# UWeta-4iQm0
# V9sd4YCUsL8
# cBF1rDFlnKE
# 0pjqEI0uLGY
# Te0dmkMmyE4
# 6aqv0I37s5g
# LAnsnzsKG7w
# gS-a6_ceIWY
# izzs6l0qpxI
# zc9_mGhCNoA
# cxWma6niubQ
# W7vj1yhZTEg
# DzkLJRNSnG4
# wPCFLNmW5dg
# i_Rt3LkGRBw
# JJPvKNz1DxA
# 8DrB3LnBCO4
# qlseQShxbso
# SPB2FR52-gY
# -hpoo0uonRA
# AMIG-kycW_k
# 182wSRAqgbc
# rbQKrdV5dro
# p1PYierF_N4
# k9DJAZICG3Q
# krsaZHIEmU8
# vifSWEOqwuU
# qRudqqBA_5c
# K6kUSl3zh-c
# 0zdovDHoaOw
# 8DgDKePn7Bo
# FNL0qzJkB0Y
# gFOlneD7OTg
# SlOo8oZ3URo
# axNTYcYRY2Y
# HohTV1hv2CM
# h-8ADSD8yvk
# akLi3t877GY
# 2hz1M1xG0kQ
# 5a1rrEYTZcI
# Kj_WV21T6Cg
# 2dCdnj6TX40
# esWbHMDSceE
# jwC9z647qZM
# CMnyXVPm0P4
# 7TgCA1JzfHo
# QqOhYjGSfzo
# Ry5a3Xgczyo
# xx329zblJ8o
# nCl3XUK2aMk
# 3oNnHGpkLx4
# 8Wm5tZYHL2g
# RdSkqs5n_kQ
# hrwdHUyvkjw
# h6xVux4plV0
# VWBawpGeCLQ
# s2IyE0AoBRY
# WWDRsvgPRYE
# wBybvvXgESI
# V5hPE2SOj6o
# 37ySuT43T-c
# 0ACK4BIKd8Q
# w_o5urFbwB8
# BGG6MSq4MlY
# M3wxYjop_Ew
# xee7uZ7IDik
# zY2lSR5of8I
# s5yWqonxxPI
# XHwe9fEkCgU
# 3GLGcw9wyPU
# G-UCinmbkVE
# v_XwMClcMr4
# kL-S_6mfqR8
# aLxdMS5OJ4k
# GkoO6kpG5k8
# osk1bS-Q4p4
# Bp9ZYD8URF4
# Ez6OSdilGZ0
# cel9XLaF_DI
# ASD-FTRc36w
# q1nM7oFJcTM
# a5S1gQNkhFc
# Eskxli32JXo
# ULNta1ORkUM
# 0uRFSRti4L4
# 2GJmcr8hlPE
# DRcx3EPckVc
# HqUM7OWNGiU
# GTY9X15-8MU
# uaTT7JvbRk8
# 7-TWbID7z70
# PaAuqoM11z4
# WUJ5sm3yEt0
# Gs9oJczh9Uk
# ioNu_4FAc8o
# HCV7PM5T7LY
# 33BSzd8Weag
# 5bKlTlxjm-s
# rIG5rLqaTa8
# OyCj8h0nOyk
# 1TfRWgJnSUY
# S_t1dh_hCz4
# ty8u6WHK7U4
# dtoCoz3A9RA
# efT9fjk-psg
# TyCfCnrc2vM
# bMwJkWuoBeY
# CyBHQbSp3qo
# Eu9qipblFTQ
# -sZlEQLN96U
# nILbFBRSaTY
# yQulO5J0buc
# qHNMRxITikg
# oqNokwVxxCM
# 3nCkEO26GoE
# _YQU_tUz7pM
# uUDDYbF5s7A
# T5XrvtooEeM
# vKcmq2spE0Q
# OxzzYeyEiMo
# SBlLUzKgRpE
# 5Ox5ERQRU40
# xJ68alrgDjU
# nF1cQO4Vi28
# 4e6B92UAK7k
# REQelEdHlus
# xWbAvZZqxFY
# K4AbkNml6tw
# KZZIFHDbLwo
# dPCZRvBI3XE
# THQcPLztFVA
# vU-ShrWXLKA
# 7X88sO7I0Sw
# Myb1mBboixw
# S4SgSsR_JMo
# wBbUnaoUSsE
# 8RZtv20pExk
# 6EbyA7WY_X0
# 1AC6NTmFkDY
# geyAR667c2A
# OGA-OTC6k2c
# 5cpBYn7Fu2Q
# 58cRL2C3Q1w
# mzVOqEWd8ts
# kD-Wi5yj_kM
# BDCCaLtmUZI
# oqPs500w0x4
# gzvRKTBpK9o
# JiZ0m8mb0rs
# YsDJAJ4hzqU
# 0K9hKOBV-Ag
# 8h8fql1_g4o
# D2nXVa82Opc
# vajBDQU_0ao
# _yThYx_oG8g
# bVyp8dHEM8I
# CdAH14nwaZ4
# 9uSDVY_uZp0
# dfyROUdgXCg
# jlGDuVr1IJs
# 5qy7vGJw_2w
# J2wJWG1Ihdw
# IJJBPQoIxw4
# F8xvs52wWTY
# 1zgD3flNJrk
# fsMBHgjFAlg
# xxMzm95ahfA
# XF4MmoP4qOE
# zVOX44eNDK8
# yxt0k_9MSI4
# dKb5EPKa1gM
# nSdBwpubr28
# 7pSxI6As7jE
# h4xB_bIjoCE
# plzlIrdG-rk
# GAT_jt0pTk0
# KZx5p9Y9-fM
# _L9c-xiBVU8
# 89FeAkdCL-U
# 9LVAwe4Kq6M
# xvDkSo-vu3w
# Ze6czo_P7qg
# M3lH3Z3FKbM
# O7APD4fnJ-A
# DKaXGUSgNL4
# lAv9Kmttk1Y
# 4umLBidNLvM
# -F8cl7jlAtQ
# cog782YWZaI
# yH3z4Qx9n_o
# waj59B9NABU
# P660XGdQHCc
# LxJPOeT2bIo
# Vsgvbw05QOE
# 5I4kE-ofAbs
# iOs2m3f-g7I
# ZTZoMRWhTOk
# gStIENaGt3c
# YAf0sM9is_w
# YHvfrDhWIq0
# L6647BJMfPE
# N8l5ZofsviY
# xmNLjUhqjJA
# 70R0WlNkGLY
# jtv8zNCwEIk
# oVBYjdlCnmM
# H_7jbEljwss
# _6NtaIYoLHY
# GXbm8DkvNuI
# VFA2iwcU3PE
# VPeRceZ6hSA
# fOrTxaMsZ3I
# xCpv5fD9KPI
# P2PCMwgujNg
# pM49cXTZFsk
# q451Iqu-gew
# BeSmNT0MikM
# z0UhsTEPK_s
# JX-pug0p_Lw
# _EYt4X-RMXM
# qxlCAdTl3o0
# P_YdI-AGLL0
# 4Hth52kKdII
# LPGJl8k9WF0
# 9Jp7TxDjbL8
# 7tu5fB3X-WQ
# 7nMNuNpym7g
# ASuO4QB38VE
# yN2JCFdXpT4
# BuyXWhWoDg4
# zXO0ciiRlw4
# Rin4aOYCQ8I
# KTa-4F7Q9ig
# ZSausEfok3E
# NE1oGBrzUTw
# HtRnUOC-VPo
# blax31jp7mU
# GowtwK5ttyg
# pUDKkuaqXe0
# umZwzOvNxzo
# Ro3MBuFlre4
# kyKUy6qoK44
# Qf2Ujsv5d78
# g8LqKwgUcb0
# UhG8MRcZCGo
# lUSOO5Vog2M
# rL4IabCb-b4
# SNss9Zk1nTE
# xsnDw3oeH5o
# d_h6J9_QCbM
# uNkumQ0v-H8
# SdJrCB92p7U
# KKb4jzDlsw4
# bIsjQI-BRak
# 1XhT5bxzwFs
# 08pszQi2Ch8
# 1aqu3NlR0SU
# AkJZ16OuwLg
# 4THav6m345k
# keCylioh3eo
# WGHMeMLeOVw
# BDq29_hMvlk
# KWvZWHY2yYs
# wrAesS8c9rk
# 6IMZ-_45TBI
# eQBeoGK0Kgg
# 0wROK-7Oz_g
# j3r4i4pn5OY
# B1AjhlhR8_k
# ovLyDbhW5wU
# SvU3Ynmcrvg
# 5ICkMYqb9R4
# QCU1pia10WQ
# rvGrUkK5gXw
# vEsbKUxYxj8
# CCAKZkAz-28
# hX7OLiZVC6k
# 3FStu3IF4vU
# tSdgutzVjRY
# 8r1AEjpD2Jg
# uB41u8chlvk
# LmMaB1urlLI
# 3OdMNeljUeY
# Cql6xL1U8vk
# YFIB9odsB1I
# 2R0zobExFjE
# LFNdurs06GQ
# cBI055j5a-E
# lbS4BrMEJOU
# Ma8zmrkGJN8
# sjtEYHnqP_A
# SuqjflJKxgk
# Am4bGwZkzUQ
# WUbFApNoWcc
# 7cH4xK6Xl2s
# Kl2O-C1sXY0
# Q_4E8PU-xsY
# iVbHjaKNmNU
# 0Z8P1xfM14Y
# Sl7Wxq_AOmo
# iEeqzNQjkEo
# xolWfyAsy4M
# wSzJzA-bhh8
# QWpYj-xI-hE
# Jc-i7x13zUo
# yw4zErr8tQY
# k7koNG2f7DI
# uGOMj8s5GOA
# N0v4NhV6bwE
# Zo9ce43El3Y
# DphPRo087NM
# apQC3R1O8Ok
# Gj4iFWcLcA0
# XICImoDCXhE
# qoGGAsy0yL4
# 9IZ766ogMfQ
# wEGKDAo469U
# ES9gUrse5NI
# WwdeHaIG608
# BTat7sWpxcg
# Fqr_ai4pXYg
# PBo_dN_KRDo
# aY0Y0fSEcWQ
# e_GDmUhb9NU
# cz0p41YYSw8
# KFInlNoabS0
# xAyu2gbh8Iw
# DZ9NbLzkyz4
# uhweVy6FAQU
# YsmxT5o-9i8
# a6cyk5FvP6U
# C_6Waf1LVXA
# 2LylRFxMBB4
# HLGjQ6BRbJk
# HQHKzrxEp9I
# Dc0P8AdmBko
# iFD240Up2p8
# M9n4kzJwpr4
# O7NdbFnxAfY
# BCQ_L2BLBZs
# M3i7vtZhb38
# LODLkrw_zR4
# cR-aGYFSM4g
# a01UFb-Cls0
# Uc5B1k-kPjU
# 5Xr9fyhIfCM
# ZmJc_rwQSu4
# 6OoUD7lbGDA
# 4M0K2FOH_DI
# JfVbkz3DHIc
# ck9y2eZxHCo
# SxOGjEeB4yw
# wXb9N4lQ0Ic
# 4NX-AG9Ss0E
# JuNqtmdSHAM
# rXC-pMCulzg
# 52g3PBacZVk
# 00vscq_n5J8
# 2cGZdfpxvdU
# QmBUW2YNAnk
# 5_06GW8ZcFM
# 95W1rCrXB0Q
# haQ-RebcnIw
# TQv09m9fJXY
# 8F5AlvcYBY8
# 3pndACAToh8
# PMEelyMgoJE
# sY5bO2kDI-M
# EEo0q9z9Sdk
# HwHgkLnHMPg
# 9fR3dCqgEhg
# kqtjnHfU1qc
# jf2Z1ZJM1R8
# 8lZ1tnEv00w
# H6OzLPfKShE
# Zi9u6rlWtpk
# xIYNCCLd1bA
# 5f64Ui8jes8
# u4yEFD4JFMI
# ZJiFG2hoUGs
# 4TgwnZLW3nI
# yHdZkXHNiqg
# 6m8NSEgQqcw
# 6zGdXmBklBs
# ng8ZgZ7ADxA
# pSUUnmQHA8Q
# Yt9WgdBS16M
# 4bW6Itl8AGc
# fj_txM9ywFU
# J428R3ZF5bA
# vwX86jQ2lDk
# 0ZivqkRXapo
# sNZsfWjedCQ
# nLuExoAC0hQ
# N2ZG5baRCZA
# iuZIUsNrdfQ
# E96j9tPofGU
# COg6npzOhEA
# lz_52SOlm-A
# aPXDra11XIw
# mzNTiuMzAQE
# uUX0UCXr9uA
# qIDrq6iM3Ck
# gw5jXzw7xK4
# 3CS7dAnwpoQ
# 7qO8Y9m3O50
# h-EQNyN1c2A
# YzqaEgOgXw4
# es4SCX2bgNw
# Pq3H484BrKI
# M-enbyKnGoY
# kC4VUKlfAqE
# 7gRxQ_9gkdY
# B9hm2A9-fTc
# ZUr-QmRrBM0
# iga578pSs7k
# bTvLO3_rVWo
# 1gKUnmCArDY
# gAFRhSbkKcA
# MuPAOJ_Ds4c
# Ap00kfjaLTg
# IF9nnATZ86I
# BK_6duGJREQ
# NebzmaKI6aE
# 8-gaQAuf42s
# TEiiGxsVmoI
# ts8-h0yW4e0
# AxKwE5OIXsM
# 2e5tIBtg0P0
# eD2zZzXyBeo
# Nn695I1DqkQ
# aaYskG4mXQc
# UnCvSKGeLnI
# F0m-aC8Yh0E
# WsW7yo8fGNI
# sOmJnCammTY
# ZC9MVHcsyGg
# K0Hp-qar6vs
# Vj-wihg7K8w
# Mf4cpXWRzoM
# Tuat2Pfm234
# OrhnP9EzLdA
# PQ-bDRT2-u0
# QQPQa2wfGLE
# JHMuIEHZz4M
# esob5PeuNrM
# 8HTN2JR56nY
# FCZqMhwZMGk
# PTP_iIR7q0Y
# P4nNJk76xFo
# sI8K4tiAQd0
# yiFNfhRtxvs
# WMPqT3QcHlg
# jqPSOcb0klA
# Y3otj3eeUu8
# oi55auCGA4I
# Y0swbFoTM8Y
# 2znKTxw4SF8
# NySrvB3Q32I
# jP3DXkfGXuk
# w9jfgD52m6s
# 6xPUjn-AP4U
# u8z5DgQ62FY
# 8mCmM9IJfT8
# vrZ1M-swA8Y
# 2LVST6OE3X4
# _9NcWjjQ8-Y
# oqXXbsmiFEg
# wGGzNGZRYAI
# z-Q5kQJ-25E
# ld_CifXlMcc
# GEysj2yBPeQ
# EheP26NEzHg
# caFWaPEWlHI
# NV0Zb8B_LBg
# 3b0CGOAqWgA
# 1ELjRuGdhM8
# YZbhJb6_q9I
# EeKsgAbn-5k
# t-tjiPliVYQ
# YcoStSkIzqY
# GEu4Fv-GPfQ
# bLlLU9YaCKk
# 1l2HsLvjW_w
# ArF7feyqfIA
# ALuzzJzrY2o
# F0_8ymTFk9M
# d5L-d3bE6gU
# -l3BLcyW2pE
# D7_fty_Z0eo
# oqA7EAtMdfA
# ZkToCvmRgYU
# snYJ6wwzEqo
# I-cSIZRnkJI
# tFc8ax55a74
# JZYtcrmWQYA
# vD4LLxt4_cs
# jfTTxYCmOrQ
# J2ZuhUJNIaQ
# Jx8O9oKRZgE
# 4w-TeoxkT3A
# ajiEGc9mCNY
# tMTXKVfTC9M
# g1YZQeMjxuo
# FjyUM_8uI6w
# sCwN2hnSTAw
# XCm4hvMOYgA
# 82x7UlS22vY
# aMb8RgGhlxM
# 2OUoDe1kkK8
# fRwsj6vwLao
# 3kmR3Gw_5CI
# hh-2YxP4pSk
# qNmr4UfKEuc
# XeiLUFIRclc
# eaPNXzx7g5Y
# 2dSmuPSFKxM
# izUBP1BbBV8
# saDX-1pakAQ
# blLcCZHafRM
# qYs1bCqkgSo
# C9w7xDPbCuk
# kr9go1cBanw
# 5oMbMNZCbx4
# YMNU1dwj40k
# _DntTuGEVAg
# K9VhjH5mlyo
# CkuNU42zPnU
# GoV_ikO4oL8
# 80y2NaUbDhg
# nDY-YzHkfpI
# tmClMOtBWdM
# K8WjPoXCmHU
# Ub5jlww4i9c
# -_nJUtGhkuw
# km05o7DUcX0
# SVSQPEFyk0M
# FEYjybo5Oos
# 12pwH4q2R5A
# nQjLDCKeErE
# 77K4i0DrIqU
# 3f9x6IGMrBg
# Dua-GjYbjwo
# yVUfzPH1XWc
# _3K8XyBGsJY
# NDbUYyDXVzs
# il1Hq0KUq8I
# DsmKZplDTpE
# ZjdJuCDcDTE
# uiLz97gFlPI
# uMYO8ZNw-Bg
# HIeJP5VDfu0
# qRaKGPz_15o
# baMh2-HmoI0
# j2_-dH7C4Mc
# d28DY0TJF1s
# GMVurPnEGnQ
# 4XQB3TbXAos
# cqeBi-mYh6A
# LiPRmPKKYao
# C5scBUJXoaQ
# u7N3tdORUpw
# FdlWNnDyj7g
# EKDlu90bTgA
# 9eA-IEOcafQ
# MJqWjOF5YVA
# yIbWB_sQ7No
# 6mM9-QTx-_k
# yYdG2KfUwPk
# pfxmh4q5oOI
# sJ5OA578npg
# 9XKcm5Wt_Fo
# Sy5qD4LibSI
# _e8-RcSii0A
# YGd1z7RdfUw
# FEhrsZSQxSI
# nwcRf54-U4Y
# oidFodUsdF0
# E1RGJnKuGIw
# 9HQJZVSVukU
# xZCJOnCuKW0
# rIFC26-xQE4
# pY6ULY60GD4
# du5xDFMTFaY
# wGBePeL5naw
# Z8vU8VitN_k
# 6PCkds9Ucog
# 59ji3bD_Yxk
# 6krtMs8mUFE
# 7UIPlhb4f-A
# ew9RVRoQ_fE
# aoZrVEXd7r8
# WUwSvvBDlU0
# 109ilBiYmrs
# vg7xq-vAab0
# 3WpJ_vxt2b0
# eQs-KLNf9a0
# FEn5zLHzbZM
# GjX2wV7R6RE
# KAdjeGZtWd4
# 5YImqAkoAQE
# pG96UVXsCVA
# HWGrhxYaPN0
# i_XxKMy5_uM
# jRMzjp3TaLw
# IlUUZtDS_G0
# b-JQRiEG4kk
# 2utJqqalkFg
# hfhsChrHlhc
# rEN63bFqtT0
# ji0XuygWByo
# iSWrOLEM1Eo
# X71HmXHdpx0
# eE16oisoMZk
# 98Hdzehd0Zs
# LFkxRJGDmR8
# iZx2k7cUgtk
# 4q_T8rT0leU
# k8BFidCMMDE
# XLvZ93bpr-Q
# abm30dIPPoE
# _MXFxAho5Rs
# AArPGeYdoNU
# s8cmhyxcQ1U
# sFsgSO19SUw
# qyr2G17U14g
# hxEj5MI806s
# blsZ8MAD6Z0
# gzTwMI2ryKQ
# Up_8OdWKTrs
# TAXinhFue98
# CO02s5DHqKo
# _eMhC5u9LQA
# 7KZKH8FmK34
# 7s6kL7XuNlU
# I0kKsgYXZeg
# -Miy-y0MFMw
# rc2-pUcO3UI
# bL0Mng6isu0
# RLH_VVUj4UY
# TMvgGwjR-d4
# DZKfpHORbhk
# FIDsnB_K3Ko
# 1pfm02kdgiM
# u5mCk8lVQdo
# YToldh0MOJU
# LXurKQdY9Us
# Am9pGYNr5Oo
# o0fHU_w9T04
# zkf7ficMSbk
# 3JH8fiqGjEc
# 8WkBfXVCBwI
# MfvMtRmvmtY
# ju90i-ZCA0k
# bO615GBSSyI
# 1Y330bu9CF8
# GvIGcXVUF18
# R4K7eFSaTZE
# e12usFH64GM
# zUN7y0tvqqU
# 4cc83hOeJX4
# x7DaPBEIBp8
# CBLj7Ph3mdc
# IddD4QXVdiI
# 1oL56XFzMro
# a0R4wZCpQTQ
# oc1bX3cbcb0
# bV-TIun35Oo
# vRpnnVJzPCo
# dLL1Y3wVL6E
# 8zbXypcOWWU
# as4aDRhs5Fw
# PPWcliuU1EQ
# M6S9l-qjH2Y
# xt-Y7OI83y0
# ghqmai_TSM8
# 1UTmxJrijAM
# zbzMtH67ZiE
# Ghx8I8BgFAU
# c9cTkXRSoDA
# l0mmHqbnhF8
# sOBcF5NKtxA
# qmiVa_ns4gw
# MELDkDSgBdY
# scrlgBKDGBI
# JaM99Bm9MpA
# Xg8q2EbCP8Y
# tO5MAwYOSW8
# V5o-pHzRAOE
# 4VGLb3Q1440
# kuMsnDN5al8
# _p8Ob80L_ZY
# MmLpevXDu9E
# PrEkPeJvQgY
# O3QNNIggdkI
# 3PjEw4koY_Y
# GMei4IRI2I8
# Jg6fpgCuanc
# H0_x7518_II
# jSe3odU-r_c
# KcnKMuMrYP0
# -Xi0VJ_gXU4
# sIedqZILqsc
# LE9Ho9AAoNw
# 16OveF8mRTM
# XdU81V3z1U0
# vCs2DqKTVTI
# NLjib2jmEfs
# RC06uIFb6nw
# _Z08BV3VcoU
# _HcU_Zcc1yo
# XPVYlIRVhkk
# -jcOE0jKZo0
# b4tESqWJn6k
# EHCely4lqoU
# 8q79DLUMd2I
# jrA6djHImWg
# sU0OI9lgeyo
# 1Zhrt6E7bkk
# WBjih_CDLbU
# kOPlmk66KzQ
# hATiFx_Wz1Q
# EaBH-FcUAec
# aCqV_x6YT-4
# NJtqYDBcyA4
# LiKNQS5gcdg
# eCfH0cLj26Q
# FDW3lz5aNQg
# doNidSEXCrE
# D90VC21nx2Y
# wjtfxUkv0AY
# XhD87j5c8QQ
# jUn0cLYoub4
# dMeKcomSEu0
# 9QC0JNKYVxQ
# ct4JdFOiUVQ
# qa4WK9_4_V4
# TxxtXHKjtf0
# qBU-VuWAPsc
# vmxbW-ZOF_A
# DdyqChGWiTI
# vVtdfxlP1m4
# 2u3w7XsndZI
# TZ_nndd-gH4
# ovIGjn4Z5rg
# D4-F5I8_wtg
# ZLzy3PRNk8I
# RhoKhNaikXI
# S_JgwifNR6g
# v9Ml_1khJLY
# dUcVf_qHlfs
# nWQXDExja9g
# Da2m0wiFYPo
# aTvgtF88vtQ
# oXsoSuoUBiY
# H_PJcZ7ZCrY
# 2n8gzdtkpuc
# xjCVUAM8u-c
# HfWNMmd_qCw
# 5H9v2aDchNc
# INDImg2iOh4
# 44K6rvEDv3k
# -aNvHlFnnIc
# 3A8pWgE7rrA
# G_HAelnOmAc
# ErCtwCkIU2M
# 96pRe1Un3nM
# vL5hQDSqH_0
# fLj0wdI9DtU
# hjoBrY1yDUc
# PYML31hX8Ro
# EgOTyR5ynb8
# Y7Kwv8Z8qRI
# BhsivGwQPEs
# F61p6rn5JCE
# NrYo5yqTsUA
# 5Q-iIHukVvU
# iW9KY7tTypQ
# sW2Mn5Ny48g
# 8O8QgPz2d60
# 6_2QC70zP5U
# To33gI5saoI
# q3cobe5qMP8
# Jp0IZYlzFF0
# 1DbUIb1SHrg
# 4OW-idDro2E
# w_QC6SbUZiE
# SV4KkGfl_o4
# dqvh5ZHK-hY
# OQCJIJaaDb0
# GLp_EF9WxVc
# 2U694sdSTmE
# Szfh3dpLqfw
# cDmQvW_l79E
# Bx7yFtVo2CA
# -_L4NIgbPVA
# 3lKwLPR6rm8
# 5CqSrvy5cxk
# yRP3d1-oUzI
# 72hz-apUiRI
# prk2l_M6b7g
# MfJQxA08sRY
# ts9Mrs4fC-o
# Bv44YB7qRq8
# hsdlTyYQOVg
# -P5v5j90h_I
# 6OnUaFUweSM
# SvUp73i28UM
# UjHEGuaKbdc
# nIYXEtLzIk4
# wkepmjK6uzA
# UaPVPdnvg0c
# VLtrO-1ucec
# Wv-IcSEiNeY
# jwKHwzUpzxE
# egivCSi9Vas
# 4mXjRbo1cu0
# Qa7pzU6kBmQ
# oE4FiowI7wA
# uuVEIuWJq8Y
# -a-TaRl6onk
# hZB6Qk7BwyA
# ddoriE0UdRE
# eiB9XM0cPgg
# qsu43tztGM0
# ECmjo6v_bIA
# m1YaAGN95-U
# M3M-MYA5weA
# SXy3GqUAmO4
# BBTxakmQCAw
# tEzlOAIMPvs
# Q58KczBUxUo
# xNfzr0awdfQ
# CrQLomhenNU
# P-X3pUdB0VA
# 3y1t5FE2sR0
# wPuhA1r_9mo
# 0YTAK_IIg24
# yl6Os2VG86c
# bmlRwStsOx8
# TF8M4dYyMZk
# PYXCA004SXU
# 4eaGxGK8NR8
# hgOfFXrdRcw
# D3ZBrDKQ7zY
# 1WIcz4yBruY
# _PAv3bduYK0
# KGrlFXXWNjk
# mq1N917cqk0
# NbWmKt2sznY
# Eh9_ncpzAqE
# bF_wETnoYbI
# UStp3q_BoUw
# tcGhyLHVVdM
# BWfk_ysYJnk
# HksiHUTimqQ
# N6Z59PVqTM0
# Gaa7TzM-ouo
# ocJV3ktleNE
# mj0B43bXUTM
# smB_saXJM-w
# vW66AfVBRZg
# IlQOeJZ9w9k
# wSEUdwLbzHo
# pbEopqxpM10
# 6Lmxh21RDUo
# se7p3u1ssh4
# xX6MioBi8lY
# tysbBg1nhk0
# FoL-CDxBHy4
# 3iE1kbyTdFk
# Gw_boRf-OSw
# sdxl_vwje7k
# o0Wt6Oxw9p0
# LQ1L80We2C0
# UI8VdfSRuBg
# YPf1pHKRRPk
# lW1I2x8D9MU
# mBUZA1W4YWo
# kX_Mf2qxVRU
# _38TO9yiRCk
# 9otQseL9YVA
# KgQQZZWVYH0
# QkC8lLpV0mE
# saZs43Ft7h8
# iDqQ4MVLHu4
# uSXHz4t0CBc
# v2c46Mqi_v4
# omYKsldXoZk
# _Y16Vm9p_xc
# cuHScB5zGRA
# YHul1eMhCzA
# M6d-dsfOW8Y
# 9qKek4_lLLY
# 33Tc3O6QA9I
# 5Jem9jcH2VE
# 62ps5BwU5GU
# VSZyd0YYPug
# whNXHxpcoKs
# dWiLbl1lImU
# RjyLPMvzVaI
# kIb3C59eUZM
# cqe3vDeUoKU
# _rK4huLRLQM
# AMmFfcfZV1I
# C_-cD6xSrPw
# cAU1L5ntipI
# -KyQlNVKMfM
# F1risUxfy_E
# sYUhFgIaXRw
# fB95HC8vFr0
# BO51UDBh-sc
# cK9hyMLtv8M
# Hecw3cFzYUg
# gyb-Rt20CfY
# 1lPgcJ113fo
# 63XODvtmC7I
# 8xt09aQ9Fv4
# SXMajFVImNs
# xXPJA3SDsvU
# DsDQIl7PJZg
# 8SMcmwta6KM
# -xTZYWT587Q
# XwwRTcPSETQ
# ixmRy5Y0xd0
# JfVwH8Akj6k
# NtK4vxzQihg
# 9xs-KwvTsPQ
# j4CYPphHQUE
# EpmM-du0Qag
# XRucrWss-pk
# wyqo2eHoyyE
# pfbLsnVbyJE
# Oh_C7Muq9dA
# qoAEy99yy14
# _NeYUxlAZnE
# yUC7IPJJFQI
# -NaU7gbzJ6k
# zCIGeR0RTyI
# VSmCsPY6rcw
# W5v0yGL7fPc
# zE8OuC5om5Y
# pqXVvbEdJbk
# eTXkjuu-l7s
# AAfz92vBX6M
# k2uzXgKmCRg
# j_MbMyJ0MVc
# mEzzZWaMqkY
# XOA-__R3pNc
# mGx9WHNX0zw
# aECqxTNQ2vI
# _eQmi9QNPJg
# pOnJHwktbu0
# xxwzdNC9oI4
# gWWu7eGeOG8
# voLJsG3embM
# umH3SeIvrjU
# 9LMjwLuEFmM
# 22UKjC9NG9g
# rpLmhETfFBU
# IyNyt3nBbNA
# EK5N2VLhwQM
# iaNrfkaaZVs
# kJnlANMKZGw
# -u5mNzEoUdM
# mDkSOYP0-gc
# 1V58DzlqPhk
# rfySWp9_kq8
# JkQkT_PrvcE
# v_ALA8-CscQ
# OsHOPbcKA7g
# Ifwk5fBMFb0
# cTLvHAwiAuw
# PrlijjAt-uA
# 4sm1YJtqBmc
# NAXEZ6v7vPw
# Qf9enRgh34U
# uK5yWa3DMuk
# vEw6bADXcQk
# xKgpBoR9ZuE
# H6RrZjYCnQ8
# G0PIk2nQLus
# GN0Z8mWmU7U
# QyN8hhnRGug
# ExrPSrbbaGM
# rFdxeqEhZKs
# WhUbx_NCbbo
# -x-Xy2OqTYA
# fI_SWZTMz50
# 0UG1lVP46Wk
# JrTY3j6O7dQ
# VvomlhtS050
# lX8fMYogFV4
# hvX5XtKzYz0
# fYNHZZNMpqs
# URB5R9aajFc
# XYtJA6d94DY
# 7yv1vMBDviw
# aflypWVIbkw
# _9YvihTMZXs
# Pwr1F3NmWmQ
# Ls0e7MuGHi0
# o0LWfOwQbdQ
# c2t_Hllwei4
# H8vty9y_y40
# NRMAjgkOTj0
# jFhgmYlACE8
# oiFt57TDqOA
# xPoL41zZIE0
# bDvdNzPsYs8
# L6m2U8ZvfLk
# coo0X3oUQCM
# CFQrvzloAMQ
# rLTKoqycjcw
# Dn941lIy84k
# NyIdbZZIPjc
# 3aHbCgyfUIU
# CTNYDJ5BLZ4
# qrcQr4njA-0
# N5HqPPGEiBY
# xO_Y-WIJX_A
# h8xq6mg161o
# 9CRZGxKHtDo
# TX-Ot_7Ma80
# sJY8iKqFS8I
# KUh8tp5gz5k
# 0ZR9NytRTIk
# SR8tSwlqDn8
# 09BALTsXmk0
# QaR66QXA3q0
# dquP8JmxU-4
# qaJXXmp1hnE
# Os_Zoh7DthM
# 5rSF9IrSRuA
# YB2ZHsELPuI
# 3epeWBX_3P0
# Oa_uyOfID2w
# z0IdO4PcAuI
# _Z2C-zhqu14
# sUp6vYt-TMw
# FdY5M0tL25Q
# ARqXbH8OUQM
# xksweTlNV90
# GzQmqP04VFk
# q05CDbqroWg
# rcQLNFKyh_Y
# DQxsoKmJnOE
# frtUncKb3Rs
# 5pxIzlyLwls
# n73rtwpTfxo
# pnrq_49xSoY
# ZcgFq7aFoLM
# cKjg22CFGT4
# DGPfs_0mXoY
# HbcXK44sN6s
# YNeNri4Mtxo
# OQTd72DezEY
# cRreQ-14Sc4
# 4j5fhFq4Ces
# C4sNmgAjoqo
# Z9AiJTDZBqY
# OeD1Bfz8fLQ
# H2TJv58E1ps
# 0SURTMDPkUQ
# xBNx_qRPdU8
# UcmWtweNnS0
# 7gZCNBZ8hzw
# VWEVXiUPhwQ
# TKy7I_0vuE8
# F_7acZOdcAs
# 6x-0Gww2qro
# 8R8OTUu4fxQ
# VcuBJ3DmqTY
# 6asJKGaXTgk
# wkeW1uF9JVc
# T-RBdyXe7Es
# i3c-E0_yF3g
# ctAWaIz965U
# 3wytOO7V-bM
# U417eBBXpqY
# uvJAuZndaIs
# qRTYhj2AXUY
# QXPs_hnGDmo
# Zzxgmv6jv_I
# LiuAgokqDFc
# ay3P4oC0eWw
# 5N2cy8nogvI
# 6pZijj2eBTA
# LJ9o3IcivgY
# 3f36-D1Iw7Q
# G74Mefmn2JE
# YAFEU2W9lak
# 7cokG_NWh3k
# eq7FZbOYGig
# K7aoM46Fu0k
# 126rYi8ZuKc
# K2AqNC42vOI
# nd9uyXUvMf0
# 4AKaAlM-nbE
# b3J3a2YFeuo
# 1KEY6GRXYeo
# 9M5MIIkDqlI
# XbhDEbEKdLo
# KEusRFn8LHM
# uK5Jx0U2gT4
# yAlmV8CbERk
# d0h3khHH-Vc
# qZpmmZewA1U
# Pd8r4XhsRXM
# TX8vbPYdUUU
# F2EHRsSxYvE
# 0umoT5uXpdQ
# MWDwpWtwXb0
# DbiaNyhrly0
# fKLXnSOwqM0
# Ss8_RmyTPIY
# WH5EONfc11I
# 4P_yIVzvj4c
# bCaiM4tFMgU
# G1ELDkzXSL0
# MzvRV62cTqM
# Bh3Qlq63Btk
# dwJ6RUqF7Ko
# a1mknpYpERE
# v64Dp_EskdE
# bLaAFq8qn74
# VGTDX7L6RKU
# D0A6ldOcAvY
# CoWByZ8S5mc
# qHSklDRIuCc
# ucli7Iltglk
# fe4HpcNyqHE
# s1h6bZ-WWzE
# 7HBkdYIAGBE
# w2mORNsLwH0
# NVAFE7i3h18
# b13NlXxflrA
# jMGNWb9M2Cs
# H5R_kVno_4k
# JJw_SEFSRks
# SFhRQVXt9Jk
# iUGwfLNKjoc
# 21J-RTWrzho
# bh9LVgPACn4
# YiE464OqKO4
# qc8akIksqAk
# RbHm6y757n8
# sGU3xNyoa3Q
# VX-m4t-MQqg
# 6kMIuPAQB-0
# w4y9VOU6F_Q
# 9ahXhoCGmg0
# oN65Thp3nmM
# PIhnqo1CFH0
# WqZVWA7j8_g
# GdIARjOu6AA
# AEs_O3dUa3k
# dqjMoK36XJE
# 38rsJSOF4so
# xSJv5aUOmuY
# urXpt5L3vmU
# lhuV7MvLgew
# e7jCdciai-g
# MS7GDU-fvK0
# _O-b9Dl6YPY
# xLlfCwO6jrM
# foPU37VgG3I
# jCGnLtIAE5g
# XvFcitdTpUA
# HMnK0tSsHdE
# JJ4FTjBjZD0
# Fb5RIAWFXZw
# 2m-sq2vXSyo
# YpioD8LltSY
# RDoYj9gfmYI
# J9HI1uRFcW8
# LkcjJa8inxs
# 4tqm8s77xjo
# QuTPytysnrA
# vKqVlUabxMM
# 1np47QVtgB0
# A7nW75d2kJY
# XZNF7BkWesY
# VfGNssjzchI
# sz9UL3WR_qI
# O2zVUp2Iauk
# zsS7HyFParo
# KEB1l1gUzdA
# kt6RqIbTjJU
# hsG2vF1b0Z8
# 9fbhCPlKN90
# 19dWAYE-9Iw
# 4enJ8BvqzOI
# aMxTHESe2Ss
# HhS4v1mqa6Y
# 2sM971Hsf-g
# sa9BnbirmbI
# -9ZR0wvc57I
# A9yRKjgl6Cg
# XxEBLHydUEU
# RTGSwlp9nAE
# mHfRBT8BkSk
# QT_LtVbZAzU
# rCkgYskPndM
# U-OpJetFszk
# VzwmTZPZBaY
# Z242u6bOaPU
# e08QiCvPny0
# fv7l_9xcDHU
# XsYDRLcQBFg
# ZLWeHM8P7rU
# RR2qIrZHP10
# EOttef29t9Y
# himTcqgJKHI
# yudC-1O0hRo
# XYOfcPgr4DA
# MetuwUUvT2w
# NS4JCJAQMSU
# 0w9wvW-tBY8
# 2nROGmULPWY
# zHhi9N7LYcc
# VRIrcsxw27g
# BFilmeLftyk
# sj_QLkcMLac
# ietcaHKvJXA
# btDmskZ5_Kk
# WHBjlubDIVk
# hzGNz7hSKeA
# hHmjc7cnvUc
# xxODzezlveo
# PKND9z0Ot0o
# avr1JVcf-wM
# Ntd4GnBBVPY
# 39VmPkzJApA
# DqSJCL8zHnM
# KjBfH7L7rO0
# tHmnRjIKsGk
# CxB8CCsYQc0
# awVV1qSSUew
# 3-J34Eb3fmU
# ICHiFg1c3fo
# khvDPP-lfb8
# Zgf8-Uy9iGI
# GUZklhLQErc
# GnTdoB1V9hc
# eq3Z5y-1COE
# K3Su56Nysrg
# Zis1-D7zkOw
# 3JXN1Qceevk
# 0y5UM7tG1VA
# 9rgF7vfMK3A
# jpqqQ1Odds0
# PUV9_OdMcCA
# -7OmGcjkO_Y
# qW1hpmDjG_M
# 8Vu38kVVQxQ
# Pr67zLsIELU
# IeIq3JeSvjs
# JOU52X6Gcy8
# hP4gTcrwn5M
# LNOkOsOEEJw
# 5t33swWOH4M
# szGq6J5hbi4
# VSWmlR8__FY
# oVDXKYkbTnU
# TylrgNS_xe8
# RqIfnYbuePQ
# mpLkEiEKoJQ
# HrD595c2pzo
# qv1Xa_EY7sE
# gsPK93fi6EE
# fkIcrhWazpQ
# eDpC_LxzqQ4
# bI91lV0DbhY
# PV0dq1Secp0
# cNiGmAaYHpw
# KO7vUgfeWrw
# imdpGhH5QsU
# -KPES4rsnaQ
# KvT-C4C1VNM
# xONmK4-9nLk
# cbUg_H3d9XE
# N96xdWV39kQ
# fl3Dfazaxos
# tJ_sSmSOUqo
# vab670m3ZqA
# QYyh3ooSLNU
# pVn3hCNazQw
# 4Ddnqrpfpsw
# 31tMXVS9fyk
# RRAjL2BRScY
# -s75DlPohl8
# ACXQwCgHe_8
# jHRvigZvAEY
# JK9aBtpggn0
# rFoNl3AsoGM
# utqQHWae6Ro
# lnrs1OT2NFE
# B2FeDiLGFL4
# 1bESq9UEOG0
# bfBuMtO9QG4
# -T7u6M2mRW0
# 0OBVPdy5QWY
# cjIKzaXNxTc
# GICEYWJx61k
# g-06sDLT8is
# b06sQ3VNH4o
# 7-MS_8kjR8Y
# IwiYh-1gTL8
# izlCIRDaYYw
# U2J4Qpcwqhk
# y9ism2zYq-U
# nCq7_vBPJmI
# OqhdNSdqn54
# mjvmEjfIfgo
# aLmEiO_d4Bs
# tkiKQrxQbJI
# nnvs2dr-EyM
# uQYKtZWGydM
# 95np0iMCCsM
# R310Dxh_uj8
# CdwFSgovnV0
# 01RRQbZ7Pyg
# RMF1ZnZoTUE
# gmN9IaSU4j8
# PqGEP-GVI5M
# 4O5pw3AfSJI
# 5CBu0pACqeI
# hi32FdiN8Yg
# LuOv5d_Bnbo
# VbS1bAbzVnM
# qAXFfyVZ5Ks
# yYTZUfJh9dQ
# -UOLneIAg9o
# 0oMbtyV1L9Y
# KreQq8mcHEg
# eLu4TmxJPE0
# bGjDHtY-Gr8
# v2JeVe-p_ng
# 8gHdsgVa-QA
# SdXQAEsP2Mk
# 1LPezNcRsUU
# hDz8gLilFFA
# oZU_b0ncZK0
# XqFx5xOPTZo
# ehfRBvBL18E
# haQJ-7Vzp9E
# pwaCLU11vI4
# ZfN4ECGKQsk
# o-rsJ91nrRQ
# RBdY2lxtg2Q
# QISuLbP1AhE
# DF-NK8e3W3o
# Djcr3pYQGMk
# WyTxRQIAiU8
# npMA4AxuK4I
# chRRscr_m94
# rYY4wCtcsq8
# LegG4gZcXys
# Ah-pdcB-Xa4
# oDuSjyc5kZk
# 8lI0P6ZpRrI
# MyhlKblrTOk
# D3KSSoN4E-0
# 8pi-j6WSOY4
# ZAUCjBxbsGk
# zMGDWYm2dnM
# _WQUxTEpTlM
# CfN64rw1TzE
# 433MQ7mtKt4
# CAS0-uH_YLc
# 3wkVQQafONM
# mj737Fn3Wp4
# 4f9kFadnwU0
# 7aETrYob98c
# E5WLEtthlqk
# 5Purfu_ji_0
# t2ftv8tOlXE
# 3jxEqWlXiWY
# IqU28B0lHPM
# EJAyImVeyDs
# WeKX7SKwT2g
# eV3YOSsdXQI
# gcKapP7NOxo
# FzoCxiPejtw
# 2NVlgI2XNj4
# Fg4ObEAxIro
# i0hYrZ-lMWU
# mb9VSENQjxY
# UB05Q5FGzO4
# BUsIjFD0pBs
# iLW0hsJfJ7Y
# uLvY0zzb9Eo
# h5BhdJHbovA
# SE7224zvyVg
# Ro2M0452oiI
# g1iMCvysRCs
# 1wInrEzWAsk
# 04slcZfmFe4
# zdMp31ns8bI
# U3grtR_nxKQ
# TKhnW4pbvo0
# 4Ha5X8tuHwM
# 2ADDJ6nL6RA
# HJGvkFShwws
# 7DFA26doN_I
# nC6jHaM5c8o
# yz-NHNcFrQY
# gCcDNUxL0gE
# XLY_qhBYm_I
# i42IfJ3Da2w
# KIOW1eLItfY
# 5nkWQZvomVA
# -2M-owk-10s
# jMVS7JTKH8I
# ozkCTE_al3A
# _acA-ThYCXM
# 4B-gd3y_XyM
# B9YCoU9h93E
# 3MIcxh5MLAI
# OGCaXsmVvS8
# Rf0WcbCD5YI
# jurApsYzvxI
# CInn1mpc67M
# POnzdG9EQiY
# EMRSHAWHtzU
# Cio22GgTM5M
# 8Yt34YCTAPM
# px9Khrji5ng
# OzDeQwE-hGI
# 9xbY3Sj1Skk
# -oJM3qzX6J0
# Ji3bo7fWSlg
# beaYRRFbY40
# pkrJLTRsGxA
# esLOm_Z-Rys
# nPUnapR2uxo
# 5lbgmjQ3RRQ
# iSXarpm-WSA
# abNXvRv-DQ0
# CDVzTf0Gkb4
# Y-ePQKBtasg
# t2BG3P_owpY
# gel33fyC-lk
# f0KxMgG9kIE
# YHJV2YL41Z0
# l61Krp_ER0A
# ryYGDm-mt9M
# sn96atV2xQ4
# T2O6dxlQhp0
# HVtywSELn3A
# UZQL75WCv_4
# 3vSkRj2RvYg
# hws2DfBa6lc
# xaa5CStvTE8
# 38G4V-imPQI
# HlR9blhbHgE
# VyFeHiQuvSQ
# 9IRYNOgXQ0Q
# L0amDVBDZlw
# TjSvWXte3u4
# OMPiv_cpy5U
# 9F-um4BYpf4
# rRD0tjIi5u8
# zISHPHz8QEQ
# uWeyNmY2U40
# Ec5L3MjjM7w
# rM6BP1i6TOk
# ijXPipS8qWk
# f72HafZzWFs
# nfGboX7T4WI
# 0yqeVeLflMs
# w3ZDdCsyaNk
# yxPKPF7Kfzg
# qsFw3uFhzcw
# STxoUQ1hRj0
# s6za2rDjQDc
# n-Phcz-Wwu0
# glqE5CCxdLs
# Em1u-0UBzKE
# K2t15Dzf_E8
# 5YAlsWi1JL8
# qMyE5kWRCCg
# FxyZXf_e8n0
# tfcotZry2DI
# _kaX2b1J-J8
# IDtM0jaCQJU
# YCde1ic-1vE
# U3rl6z53R5Y
# yPsuAvBgsK8
# OD6fwn6hYqU
# -vOwwmbbfIE
# t40fSSl7jeM
# J-DUdrx6Opk
# SFWWBNIcpZ0
# mEH48eu_ga8
# MRGFx3cR7Sc
# aeT2AcQRUQs
# XKR50eqJ4Rk
# B8GLN9zqqQU
# aYZacc9uu-8
# OhEu0ydh2eY
# IFtq8dY2eoE
# nIMYr3A7u6I
# ka27AdvuHuM
# YhOsjV4HjmQ
# -GXDL51qmyU
# U6K2_2BqHGw
# SUPDaCGkyaM
# BmLfwtKySqo
# Y3s0EdDme8U
# OIdTMeYYHaw
# bEEacxeseTE
# BJciHaS7i8o
# usNUCVRZXMk
# 6nSNLRW2rAM
# l0tIfHBtwuQ
# piuYSM09ixk
# Go8MITMsSn4
# idRut93qI1E
# H-cN7rpNUMQ
# mX-wrqqwc8k
# epN0TnYspZ8
# 1TJrhiMA1JU
# QSsnKEZck5w
# NlnGCbQutPE
# FMDC0KpnduQ
# mWOa2WHzZWc
# gOAn12ojVYo
# Nr2pzjH-28k
# dtTFUI0HvIU
# CjYU3i2IcE0
# EgB51Ah_ABQ
# HV5s3sPTorM
# rwep_-a2G-I
# Z9IAR2-uPeQ
# KAwriJBhSZg
# r07t9FwHy1Y
# YX4H4ESDn9I
# QbpMvSZAN8I
# A_0VHx4ZcbE
# Pit3xJj3GWE
# -qr7uZiwC44
# BavTxBE1k1c
# xSeyzbpVBp4
# 05EpD6rd0X0
# -jb5TbofDvI
# kXO4FxYXZkY
# FcruFi5HsyI
# Zm4MoOU_P3w
# sRwBM_2RQQY
# MU6hGgsPrXI
# fcNxgHrxsV4
# SrGbc5fs20g
# M7w_QDoxEpc
# 9O5viqjz9co
# n5EG6Aak11w
# TxEahv_TulQ
# QgSJOcvIvj4
# TXCFoV3NNfo
# tgEAaNYYQJ4
# mOnwDsiTGNw
# r_gumncraOg
# TmzzHrdjOIs
# 3BB7O2YRCEo
# ogsHFW-MKy0
# -GzmpgFA6pY
# 0koRcmPDR5Y
# szNpoZgjiDU
# sXkWuX5nm1M
# sRQPU6Sqjj8
# cqV78ora704
# s3ab22g64vQ
# RVHqRrcmQCA
# am7IH38rN8M
# eFEwJcjQvDU
# Czrk_QDecdI
# 7w9sjEsq7PY
# ylvVfG4Zvm8
# 01kaWABuCk0
# xPJZjEdBQxY
# 0M5uRvRtZ_s
# AOVVGOKwLnk
# 718Ob2Ajk_E
# qDYpPy6zf4E
# yGcCLwqs1ds
# XXAQG4p6ed0
# e9qvnf2oXzo
# NBAt-jBE-xE
# Pxj-kU-KERA
# R5zAmTVxZfE
# jcUOh28mcnU
# F0ewu021R_0
# nU6Md4Rjs50
# BD77De5rim4
# MxbJxo5GaUw
# Gvi6EZj8mA4
# jVGSTIf_PDY
# ZXZQweUoXrc
# ffnKz9jqTjM
# PkE0mx1hX-M
# Pe5rJkYL8r0
# DCDpzt58XmE
# FgH-Bdx9Psc
# WgueU0cPljA
# 8STX53w9-JE
# 7Wa00TGR1fk
# 8DWrgSIRzLs
# CDR7LLKyxxc
# D6-YlbqBgI0
# bYxhUp1DTc4
# 2lICE16oBc4
# fln7068S1VA
# ulSwxU2mDG0
# A638pkuTG7w
# fwDD461HtGs
# DAK1HKIuksU
# mtAQ3niETj0
# layQ22XBPGQ
# da6qPDHKg0g
# hJ-XFQVSKJw
# TI4_1WOq_ec
# ywMmVW_5ojs
# WLzpt01KAHk
# fTy_x_3SkFQ
# L0AgtvJIjCo
# z2KAOSdrqds
# 1yjf0E2LO7Y
# jA_fgng7_NI
# 95N9R4fhBDw
# AAGpSClNkhk
# KDwrCJOqMtM
# rN6oaBLGl9g
# SrlauL7WLLI
# h7xwI9VNt6A
# 76JOGWVYHwo
# OMAff4DpqGM
# BW-NXu3bWjE
# xPa-CwRP024
# pHU6zxLxr68
# QTgKm4uaJE8
# c_SSLELG5f8
# k2gmHJ_7kA8
# -yLujnry1Wc
# j42Rem7kWvI
# EYZ1w2cVg3Q
# g7BIs9Hm6qM
# wbOunXS03yM
# BTDdNHs5Ryw
# qBKFw3wvvjE
# tcYsaOTiVf0
# thDxpyxwsGk
# 4XKoaBGnScc
# kFuhe4w14Cs
# OQl7bJs4LOU
# 10wMCwcJWZk
# BHxqYWaBV0w
# GDQWFirSIb4
# emTiCc0vr0I
# Squ3gHHXaWs
# AhrkccdAc7M
# 5ScwrIPL5jU
# PspGfxUF1mw
# JGNySbo2SqE
# WESGvh29rjM
# EyuT1x-lgUA
# JzO3_qAZwtw
# MNJ0v8jWTWY
# TR-fR57kONY
# wJMQ3ARnW_g
# Fm5Ir11VEb8
# 6ppqBZCjugA
# 0Dzm-dYguzw
# 71VvLekZ7cg
# gk0Su2Y2UF8
# -3Wcvffy9LA
# i35mA0Q-mbg
# pdGVV9VYQOA
# f4UubOwU2Fo
# ieZe2M-uZA4
# 9E-FuQ5hTVg
# IDTZHjH2ej4
# ftp6LRl608g
# 4c2an8LWGwQ
# EsOR5P0TUI4
# o1ErbfvycZs
# aLHbTwhPQ64
# NEPD621SH7M
# M2n2PyyXvyM
# AHx5N-uoZFA
# MRxychIrboM
# 5-pLy7MeZcw
# 4j0dqV_Xn_E
# 745D77Vvhtk
# a_S2nPIIAJs
# OkMqT3P2cSE
# xcp5cvjoR3A
# P2LsLrEj2Ms
# ZGVgF0jgSkc
# HHEbjXbJNeQ
# mjtpEacFfDU
# Xkpr2XIPfrY
# ZQQ5H4scfdA
# Lx0prfa2h3c
# uhKRXH-7Rdk
# l6dfiYI4Ah8
# qLwDyl7PbXw
# EVvWYXcTXDM
# Baavf-VyCzM
# YiVAJbzmzCY
# ZMlxVVF4hkI
# wmChE9nxwk4
# k7E_CeUfoJw
# FHYXoFuhywk
# P8rOLfwY6SQ
# CHzqIl5LDCY
# u83Uqi0zjiw
# U8kcPCAtqLg
# tobl_yyL7NY
# trBurFq8Mjw
# 9kJ_7xVnI4U
# 4Zytp8SqpVY
# HXh_V5z-VzI
# Ih7hqdhZUw8
# MxB4fRQ4He8
# n0xmrZnpc1I
# PP6I8JqNfGM
# DOWT-MbA4Gs
# qq6R1P69HjA
# c2bflmXnAAE
# KZhGjelNS2g
# 3CnXoIiQE6M
# 1FhwRZbp6Mg
# lTnacz8zvTI
# GwS1iXBuiYI
# yH0rV5dbM5g
# hhZdGkSfyCA
# U0GCHVrjaIQ
# j0BttAhc--8
# SR36Qw0qJcM
# 0p9dZbNFCa0
# aUZR-4Bkkzk
# pBmkVlTjqUs
# TP0hly8A2TY
# S4My9lTwCfE
# 5jqFFQqV-hU
# RM69Sl6_Eo8
# xoOmK52t8lM
# 3Y2A_tcJyEU
# 1K3n0zYG4V8
# Z958g5D8IME
# FZWdTfFDwGE
# HaGujyUuRK0
# TowxFsENnJk
# yzgA91ZCuAI
# CHJhTXU_7gE
# cdBjcUTKZ2k
# 7xdZZ703hOg
# BT9Mx5jh9sg
# 90tLpfsq78s
# -XFOPID2kp8
# 7HrTipdq8z8
# DKLRsMim6tE
# OfZ4zPaXfr4
# sbgYT6JDeAM
# 3-k8sapQFE4
# yPuxSK8qvxc
# 7_1sGi4dLPM
# nm8-qB4O7Jo
# bdPlgDdIU-8
# hY80557MXZQ
# BGoHVjKrTcc
# QSYu2_gilfw
# uW3ViIIs8Z0
# ITJsM91NUVQ
# IEY-PhbVdus
# iwaG6RzMJuw
# u35aCxjNOQw
# g7mU9ITXhzc
# iKAzt377pLY
# 2sIvSPbwTgs
# KnPxB4vOsyg
# q3Mvbxn2s1M
# 6dMKnhM4UVQ
# D9sqbSn9C3U
# RQTW9kXk2q4
# UaOkALLIp6c
# CthUO4uQjcs
# sozz8z_gs5A
# vJuy--Umkh4
# kp9U_0v6rp0
# H4RSO0pQ28A
# cESxIgTw-CM
# aizSV4PqCWk
# aB8ZASQzekk
# 7vi2VAolr4s
# 2amOGfzu1t4
# sOLdkEG8CKM
# UhL44ERrEHw
# IXj1-Rl58Ik
# vxecFHk6020
# 0sZT1lc5rf4
# DL5kmdhV3ok
# Pf_lV7dUefo
# -IgLOSd9iZA
# BI4fZZ0TLT0
# ZFr_A73gadM
# PuLaHAmynlk
# AbkTNb5LSR4
# 113_giijpBw
# cbcxaLw_gco
# hG1rDS4b9Rk
# 12AuC4ay070
# qL9GoFXl4nA
# sGGgqNOq6NE
# w69PYfwgmQY
# wl7BKkpcqRI
# AjP9HWiQOZA
# wPOdJ22bwVs
# cF71Dic8E1w
# uS5dFhFYUt4
# C9TePsEYEic
# EmaRX8Ylads
# xJcQxRVY8rM
# gl17D-6kIZ4
# f4KhsRLRemU
# Im2E368ITnw
# suInbkXpfpo
# vt2SQVABqeI
# TbJjdh21zPg
# Lfve_hdETR0
# DXdQeI2mEhQ
# HgM3BpVetoc
# b3teRO-R2RE
# q81aEx1t-f0
# q5PyxtuYFUM
# MwX6jZbTOA0
# dLZsaZP8Zos
# jcbyTPOSM30
# bH04qdF97kk
# oQLL5o98tks
# pJIfF0EMKRw
# -PkLYnAce7Q
# l_GScSyUBxc
# rDMcxlbweZE
# WPcmzL-PLu8
# KHxJoGtPx1E
# JyBshEY2OX8
# 0hyfNYJsjBc
# PwN98c0cpyk
# nxzasruSHsE
# qmVSePowHPw
# WxvVHqKsTkE
# POp_m-r0TpY
# wCSI0IUa-Ds
# ikdwTq9zBbQ
# riKZdUVRo2w
# xqC6a_358HE
# FgsKQdjWfOU
# PpkoNfsUu-U
# ztU9IhbpyZs
# r7vNLd5oTEw
# YRKEmCBvtRY
# CjCx7VbyvK0
# ky3sME_qGLg
# HUCDEX02A00
# BhlEqps_g34
# 3lHFUhmhTsA
# zMopIMop4qI
# cu__WAmPd2U
# o5SHKoZzfPU
# qm0XAAUyZpQ
# aFah_SZLw4g
# mdOZ6qqbgC4
# Ececv8l_47U
# xCgrc6rg0WU
# QyLctnxJ2os
# oAknQ3GQoLo
# i6FYEkudCHw
# 5yyi87dPbMo
# Z6hf6duAi1g
# AnjL0XEnYms
# -IWxxJ5sYMA
# KufeBVL48tE
# Pvr-GhQbFVA
# Tlm2yPSxq2s
# fg70lCRsdMA
# C2achKP9px4
# k1MQhe5RuEg
# m54QHXnzXUw
# vsGNxl3uHZ0
# E9WeIDs2QAQ
# m_Wi_QncGxo
# fqGslb-3SeQ
# N6fMSthsJww
# zs7soucwxRk
# WOqW5N1WdVg
# GivR5fSMhuM
# dNoD847GM-g
# 6LHRWhpTJ-o
# DG44zosL6Y8
# tdig1IWZb8Y
# H7MkN9pb1W8
# refxowQopoQ
# ZM_vSsUhVGM
# ioWb64i7S_0
# Dt142RhPkrs
# Zr2Tmqidki4
# cdV48c_RWwQ
# MPLMSSba_uA
# iXJWyFZYDSU
# od_kmhpSvOI
# e9s_jUDFWNI
# SnJw9Lx2eX4
# jNdFIPxVVeU
# aUVxa2y-ARA
# kipzH-naP5U
# jAJur6XGXIc
# C5aQsDbTUpQ
# 3RSF_efqK6U
# 5F_wLx9_ymk
# 4UdlYblUlvI
# _6AjDVSqGfI
# Dkie3rRMPGQ
# NdybquSkB3M
# C0rCySPm-mM
# AAhs3YaZWh4
# cGyqFdezJ_8
# zqccS-NMQfo
# xzNdTC1ZBmY
# R154EEpNfEY
# B1rDh2nsaS4
# 6qSKZ7IQSf4
# 7ME-_oYuAWE
# 6T69CpjrxHg
# WJFXu8E1zmI
# Sn12CPJ1BKc
# rbg6rbwWzck
# dFRX-9JZzKw
# z3_F5NR4ARA
# h2w0ZfBdubY
# tiQl1kp8KF4
# BBzux3C4hbg
# NY-mMlMmCtM
# 8xPYbpEIjcw
# 0up__7_mabs
# 2btVJD68-AU
# zyvTTYsPfDk
# J7tcWjlTSWM
# QgRYOQyeQSE
# bLc9wi1Naqs
# CXvkVXCXZmM
# nuvLV5P5yM0
# NRkrRDc_eH0
# tecuI29MZI0
# yb4_PrUb_GI
# cmyHdxbEgjw
# WdX4_3bUVuM
# dY9fJsCTdSY
# Iw9JLdvy2h4
# uur9F9xfl1g
# ogjNegD_2ok
# rx_3OgjYsZQ
# LovoxX9AeBw
# zJTuvzMY6pE
# XLgkJaKiMlw
# iyMTa9uBzVQ
# qDbDzC1ICtI
# d0WWfdi9n04
# C8eqYgC9urI
# BjAe6PcbjDU
# 5VnB4mljzcE
# cXBmfOAnVis
# RdVqSK3Q8E8
# mfnyftoQ3-c
# 9DrljRevBF8
# SoSpNgH0B3U
# xpDB6rllstw
# aLIF51VNqBw
# Q1UhOVdICLM
# cH8zGJ1s2nU
# UHfxLaokLJ0
# zi_1HLyOFT4
# VDEcroRIraM
# obZnlirdSp8
# 0jP1eJfDCpQ
# GS65Y3GmLa4
# 8Doca9OeAms
# dZMbA-csLYI
# WdVsc67u9ms
# 2HBV_Ra2Fu4
# VJvg8E-lhEk
# gEIj3b9MfwU
# QNGFxEqFZG4
# T3XMqz412_4
# L3jGksVnCts
# 7EzZwvS-mz8
# hjJZ0iyTqDI
# wsk7w0TuezE
# aUG-zqhX_UE
# AK4Ep7ZfBP8
# wlx5BP11SEQ
# Ot2ncfG4Gyw
# GqOWC8dOEEg
# r8ZuxImkV0g
# _SOd_DisgWM
# Wu5WJ7wrb-U
# sV2XGpQJZMI
# Z1mgBOWePys
# IJR1Hj40sl0
# 89WcuaQukEk
# A94UiWyH0GE
# QfXEvIdVpb4
# MHUx64D8QhY
# B42qhjNduFE
# ZF1tyg4axBs
# hMg5s2LnqmA
# BNkW-qeGnPg
# rUcc5PePhRY
# Rk2L0H7MUx8
# Hlzxr8Gaxv0
# vCkEjIO8jCc
# yVekOx5xVPc
# huWQ_fFyYac
# yZKdrXuJrbM
# KhglC1ISRlM
# jyY-Est-Wbo
# HyiZxD_sz_c
# kDs6K4xNQkI
# 7aQkzZcDslQ
# loF1S1XLiUE
# 2ADkE9zFTlI
# fA531PanwRo
# jFTmN1QXchw
# N43nJP7QErM
# ea-X1HWnWds
# 0_5kkaNmCVw
# QCrcpLjN2lM
# kX9e-hg5oUA
# FeNOSoo7WlY
# 7VtGYtvvlxI
# kBsROmnh3T8
# y_AYYE_ORpA
# JnjYVKPUPMQ
# jYriPSzpkPI
# Ze7xWTWBpys
# vm_zhSNT5lw
# p3H8X8PNwFg
# JAk3os4vq7I
# po9ICRzjYVU
# j-fwpkjMaLM
# T5naLs65RmM
# ycWJlmdSnwA
# hcj7Ix9LetI
# SQnrQCcQvps
# dcMmxHibYw8
# 2bV8gXmv5wk
# kmV9-ce14OE
# L--KKX4nkM0
# jT74YrnjfYs
# yRSCsop1JJQ
# u2do_d6RLGc
# ShzRKbhrKOA
# NmUFm94eCgg
# QmecSdTp0zo
# PO0x5n-fEk0
# C8erHyNXwqY
# fPsDPbVbOTg
# bGigncv7kuc
# uj6avHWXTGQ
# NJXjHvyxvMs
# 6FKLeeBljdE
# LWNVQJguEsI
# Gog-IcYLUpQ
# FTNOTzm1Q8Y
# qcABcwb_spg
# OItQmT6bRNs
# 7HpV7aU3yVc
# VQ3X9_-EEDU
# 756BAcmRgYQ
# hNrDJkqxm2s
# 2KLcA3xDKBk
# gis5Y9oCOq0
# 6oNqSePeqIk
# H8XBb9vbb0I
# c_Yc1Pcq19Y
# VjUT1YDQZss
# 9l-EcX7uarw
# ewH3gU4yV-s
# jNnVxBvs-ug
# vlHDP9P8P5k
# nx0KARU5B_I
# kGdilCDEvZI
# NxgyDU8FwRQ
# HieEvbozlO0
# 6p_Mdo378So
# ivrJcdjFpjk
# RNqTDkRRWv8
# dvu3fHz8gQ8
# v-f3pzaCJMc
# cpkXKfqfHS0
# xdoJENrmLNM
# bBsMH_3fcrA
# idRo2HQCTKs
# 33IWV92pMws
# rcRwAaaF-_E
# d0ASIQ7VMTc
# sc6rjp_NVDg
# 4ue2AqXl5Fk
# iD-1mMr7y10
# fEQHqSnRlUg
# 1CKXawKbRF0
# APN3olj2ibo
# nBUwGYrVuB0
# P_kDXPUn7jU
# fdjiq4ID0-g
# SYP-BM4opnQ
# Lt9lw-DLQKw
# VB404TRlntc
# Yc15rpmiWS0
# wWZ7wRNAg7A
# uchjs64JND8
# dcdvfejRjVM
# w-P6AekhgnI
# t1fGDukQgYU
# hGMaKAzaTvU
# BDI-w40QU7Y
# IIZdbRnyPaQ
# Vl89obZ6v24
# 0WffllyCTBU
# wZ2QTbRdB2o
# u0yKLmEezlg
# XVQblN7pioo
# UiNR15P6lsc
# 8snwHvJGgYY
# Vm6pNG1JD-E
# UHom-Xi5pzA
# azMSr816yys
# gJZs7q54SXY
# trsEr45BTLs
# Dad7lgZNzas
# ArHHgtIdu4A
# 3M8YGF16jl8
# lyYGC8GAZmI
# rIs4SIN9-zE
# Irs8qS_NUY8
# C_4n04jTIvg
# zHOD_3NsL-Y
# jrploPfc5Tg
# fz5daHHYo2Y
# 8fBUGQqZ-XU
# 2Db7g8irGM0
# rf6K1ys8GB8
# OlZIVMAN4Xs
# c7ZIbg3uAEA
# fGejjfVvDS8
# 0-aJnKvnzzY
# GwcXL3nr4Do
# 8ZpjYVQs68g
# 093pbP9BTlA
# lGTO_cAO7jA
# CcM70PKcd-Y
# X5F6wNG-dIg
# NEBfy72FKiE
# J_bi029Fx5U
# l2Au3DFkOC4
# lhQHgBpvyYU
# fy1t-vtceW0
# zxneJ2tZYbc
# pQ_tExxaS6A
# vcrTdfm_KRI
# j8O8-LytqrA
# Z31SD2tz6TA
# kRhGQ_5rSDk
# CQzGrUDJDZg
# FLz1-rPqcqs
# yDxwtevkMYA
# JoVVN9Bubr8
# 2ny9u-qlxCs
# LvsO3y4cy50
# J3uTZSPSt44
# Z_P0TPE2kgg
# Y5geUXpIp3U
# H4zHK4By8hM
# tUGZHCyIM8g
# MhvRcRAhZzc
# 82Xn74NImjs
# g3UHcpMex7k
# sbRWkH5evZ8
# GcZkqpAA5QE
# XeS4PYyfXpY
# _GV3cNjAJpA
# mAwcpEcc38s
# N8ELFQl0L3g
# 46F-qD73tJE
# CX7ztDHdYbc
# SMRyasoZ3kk
# nCMOyOd2uAo
# BqiFKbo-NRg
# aE3ykYykR7E
# u_qdKsZw2EY
# z2yhoBWkR5s
# WR3DnVIB10M
# g-2gMeiKFsg
# WY9oZsuWqzE
# buQGz9FphT0
# LP1swyTWCcc
# nP0NpeU73FQ
# AwE05UsXIHI
# mMoR2atwOiU
# UpahDMF9Tek
# DoloyE_pGfY
# 3oyjA4GQx1g
# RPtEr5et4qc
# GotY7f0LVg0
# BeRsyOSomkk
# b7YD2dm9rWk
# MvExL0fMFdk
# KWpEQWQlU24
# B61EoBKTRv8
# 1hVaCS6DVEg
# 5ZjgVre5_WY
# v8JV_uO-hBU
# WuTeeiEHoYk
# vYgMWafQAL4
# z8YolcNGfdE
# jwOxNXREifo
# HzqVD4HzWk0
# e7Rm3wVb92Q
# M2N-U1tx3kw
# _Cie4GFu0f8
# Vx-XdwjNbl4
# 1cnUYychq6k
# JQ--1rrZRQE
# uQW_0v-9TIY
# ETw88C-SvXo
# Euw2EPkGVhA
# Cwr-4hCAM7k
# Sfj44L-tFTk
# crR_4jzUjCw
# lnhTvwNGVfk
# 4T_ERDsHkzc
# 50Vx8hkqcMY
# K-K24uIFYmY
# Wx9y2aN5wag
# nsWD2uq_q_Y
# _iWhAvqhFZ8
# ycqdsoeKyHo
# hRyXCZPnYhc
# UK3n3RN6tSQ
# 8i_IGwnC1q4
# 3ES7ulm8eAE
# 4XZBXq3MQjQ
# izGIlNVPrPc
# Dy_WhJ78SyA
# nEPknO1XN_k
# 9k5cQ4bcFQ8
# 8Yh6WfDH77w
# 0QxS_cbrQeE
# tNEjpV1dSyQ
# 3zpRwmPwJO8
# djGMI0Q2_ok
# Rd3Dnp9uLMc
# 8e2jeV-Wb6k
# zm8swEKvl_0
# mUv0wXgKoC0
# TiXGr8fmUe8
# rpGdHgDC-Js
# 90h2FZO-bIc
# OL9X_pJHw4g
# zPCqvTAKAUk
# Drazzv4m0n0
# zJabngpDVGs
# 3LRNH2d1FOg
# 5L88DK2tO8o
# C11HxVCipRA
# iIKqe26rgbo
# F7l5P0zszTs
# 2RZxJkZ_c80
# cfY3Z_asQ0o
# Be2OHvGu2ag
# IZSLCUL2bAI
# VEkUmC-qmpE
# b_OvRQzjKGQ
# fQp8qpDavhM
# GoRpzUj6lvc
# HPoExrxpTSo
# xGqgxN8Dfn4
# 2JC2PUgsv_Q
# Q8LZwK2CWIM
# QLB-h_sBVEQ
# DbnmI12T_Qg
# eulxVOO-nR8
# kbHwkuzeUPY
# mYBzJBtLoCM
# PyVIjI4mf78
# dsUhfAhx4I4
# xIDRdyrsYW0
# Wv-L5TTq0Vg
# pbIGkjUME9g
# lEKl2j3vQWI
# 5WkoogZT-GM
# A8xBR_hE5Os
# z2s-PgLAvVk
# DPNdwwPvpc4
# xmHoO-RaLxQ
# Vn9Q7yU6if8
# XHyX8d8khpY
# 1Ei5VA3vq2U
# sFE4Z8yYr5g
# RBmQ7Y0Kegs
# iEU7FK8ljM8
# M4FLyWEThTo
# Q8FVQahpeOA
# kqwct-TsqMA
# DR4tBRiTCvc
# UbNowFcJJIU
# 1D0WOic1Wm4
# FtRM5pfWxH8
# GVVgpacQrSI
# Dkg62MYTpsU
# zYdFO2vBu_U
# jSHvsDuslsc
# kOBdtSybOJY
# Zu1Dycwg66M
# oks9P2ORdIc
# qk4Et4Pz0yE
# sh9fNco7i_A
# omQ_wLd8dPg
# lWZHQ3HXoSI
# XMjZemTwE3E
# i88t25Q8wgQ
# 0z46ZJsDD8E
# cVU_-2UpYYc
# XC-BIboVmoY
# pd0dj2ryvu4
# XxuAyJeM-Bg
# Urt8yEu2ELA
# KcLT6UxXSJU
# 8xsQ_v2iK_w
# N6hDOMBl_60
# 5l4mlIFiaY0
# pjClbm90yAc
# EnYpCZRaTZs
# 0T8PflP4i2g
# tWQc4AC1BEg
# BcGsO-SpCWQ
# g9M_iYWDKfA
# CASDCt3PUJg
# SDla7erhAnA
# pEg3HIm01e4
# 8ZbxGNzBRCg
# AKAjEzI5n5U
# TPgTqTmYPoA
# xzHsgf3bnjc
# tYcWu4d8QWU
# 3Bf9tIPFlYQ
# AYXJHiEGbWo
# p3awf8ue5X0
# f4Pvjr0GEds
# gGkpIxEPK4k
# LYfw0YCxHZY
# 7SVEmoYB5-4
# JQn9WFWE2kw
# aChDSQNOS9Q
# XqlYdXG19Ws
# aT2FCTqn_Mk
# 4KcYLMiuWfM
# BPsNOeU-jWI
# -Gj-PHyrdbA
# 0mbv436NqEQ
# rH0O8OQtyTo
# v9Cks5rdpcA
# FWMD63nN1RY
# XjoheN_Pe3Q
# 2U3_fpTbfHw
# c7tBLItjQLc
# QrnbFPcAlRE
# ghyVOJvTqQw
# CH5HVZKDOjw
# OYf_mxfe5x4
# D6FaxKPoD4E
# hM1CMrbEF0Y
# bgvj5KH8O-g
# -P7bwMHmwUo
# nCKIDsmfx-o
# Xwl2eRl9edQ
# JpiaXnyvWZI
# tK8jGR3m5G0
# eFFtwf7x9Z8
# DxuBz_p6fRc
# iZoLUEr5K9s
# GLkoEdOPbSg
# 1nQsYetqsJQ
# 2mJwW1-kniQ
# 4VYGW1sgImE
# DBozlPMDlYQ
# 96HHDaINJ0c
# FZiT09VXTFM
# YNgxGQaVAa8
# x4_BiTCFunk
# nlM1NXM_3P0
# wiMH3tBK7Ek
# OrjpKhOU_hI
# j3Kn9L8QpYM
# hf5BY_vrTTo
# zTGxuCJenRM
# vzhJY4Zh7b0
# 1JTCGS6-VzY
# QAQRv1D9KyQ
# rf0qsFjb7fg
# 8EDoQlTOyEE
# tyTjVgmuQt4
# qhFi0QRbp8M
# fsbtwEppBc8
# 92GiQzCoGCc
# 3IqFK5vQPXc
# J0EfiOvOEgw
# kfUb60GKL8Q
# VvdssiRzUWc
# lS0x5ReHJpY
# uEv0iqnlpXE
# WOoX7Mo1DWE
# cpNAliO92dI
# JlGQ42zmt-M
# CtwbMInrRV8
# PyVL-0mXmfs
# 1KcNzXeLiik
# ossx9sW9S3k
# EtWd0VPkRXw
# 4rAe6rraRmE
# x7c6e1vEIrE
# h17TkOuBdNI
# tSk2k6DSwPY
# fhPFpoMwQc4
# x5I9MK_-O4U
# diXn5H-43Vw
# DNIzuUgGucw
# D0l7G65WaRI
# bADutdlO35Q
# C8ZnAenuyH8
# i_eyU1ebgas
# 8-Kd4dTqdkk
# 9dbxc9a6o8U
# u1tO1zdiRXc
# kTU2878_xv8
# DNaN30vkXE4
# 0hH7AKx4X3s
# wssOe_cU6Go
# Au2bbW7dzW8
# ACkm1q4TqN0
# W9luF3xcHfs
# hOTTfE_CaM4
# NZq4AadVWiw
# DQ3uPEzeT0g
# bK_kfh8vIbI
# DpXmX3eI9tc
# mY2D9TQEvxo
# WhHJUoCrGKs
# giYT6Q64TlI
# piCeN0_pjDs
# syIZW4LzbFY
# J58E8W3EoXI
# wSLuS6YOwrs
# Q6sZlIc2v2Q
# hbxR81fJoec
# h4uIy_YSwao
# V8yyWzhtkQ4
# A8gHGgD3H1M
# pqML9AHtDFg
# 6N35c-f7uws
# 05-LLQiEtjs
# JQ8xWuvBuq0
# Siol7hEg7zI
# vwUbG--8Shc
# ZW6Y0fE1nq8
# heinnAVAhTA
# lOYTzLozgKI
# fL2asXnTiL4

# %%
main_df[main_df["id"] == "fyvEDS-PQO8"]
# Out:
#                    id                 title  duration  view_count  \
# 16753897  fyvEDS-PQO8  404 (FILE NOT FOUND)       368        19.0
# 18029445  fyvEDS-PQO8  404 (FILE NOT FOUND)       368        19.0
#
#               categories  comment_count  like_count channel  \
# 16753897  People & Blogs            1.0         2.0    Nubz
# 18029445  People & Blogs            1.0         2.0    Nubz
#
#                         channel_id  channel_follower_count  ...     abr  \
# 16753897  UCVlYKhbTiO8TT6fRD-aY6vw                    53.0  ...  125.77
# 18029445  UCVlYKhbTiO8TT6fRD-aY6vw                    53.0  ...  125.77
#
#              vbr         vcodec      asr audio_channels chapters  \
# 16753897  125.77  vp09.00.50.08  48000.0            2.0     None
# 18029445  125.77  vp09.00.50.08  48000.0            2.0     None
#
#          manual_caption_languages  automatic_caption_orig_language  location  \
# 16753897                    en-GB                               en      None
# 18029445                    en-GB                               en      None
#
#           license
# 16753897     None
# 18029445     None
#
# [2 rows x 34 columns]

# %% [markdown]
# ### Getting information on remaining to download (after getting 440K hours/2.4M audio-transcript pairs)

# %%
unique_count_main_df = len(set(main_df["id"]))
unique_count_downloaded = len(set(id_downloaded))
print(unique_count_main_df, unique_count_downloaded)
print(unique_count_main_df - unique_count_downloaded)
# Out:
# 60098151 2448500
# 57649651

# %%
main_df_dedup = main_df.drop_duplicates(subset=["id"], keep="first")
len(main_df_dedup)
# Out:
# 60098151

# %%
all_ids = set(main_df_dedup['id'])
downloaded_ids = set(id_downloaded)

not_downloaded_ids = all_ids - downloaded_ids

not_downloaded_df = main_df_dedup[main_df_dedup['id'].isin(not_downloaded_ids)]

# %%
not_downloaded_df.reset_index(drop=True, inplace=True)

# %%
not_downloaded_df.head()
# Out:
#             id                           title  duration  view_count  \
# 0  LwJv3vSd8no             Free Art Wednesday!       372       378.0
# 1  XXjYyBCNJEY              FREE Art Wednesday       293       194.0
# 2  OREjUtUT2Sc  New Intro | I keep losing them        11        39.0
# 3  cNPxiPUdyvA      (Примьера дораммы 2021!!!)        20        29.0
# 4  2XitiLKk6rM              Анонимки в тик ток       102       578.0
#
#        categories  comment_count  like_count       channel  \
# 0  People & Blogs          175.0        70.0         Wajas
# 1  People & Blogs           69.0        48.0         Wajas
# 2  People & Blogs            3.0         9.0  Sade Royalty
# 3  People & Blogs            NaN         5.0         Overk
# 4  People & Blogs            3.0        17.0         Overk
#
#                  channel_id  channel_follower_count  ...      abr      vbr  \
# 0  UCrfdGNBnkDd0rOh1M9mdmaQ                  1680.0  ...  120.177  120.177
# 1  UCrfdGNBnkDd0rOh1M9mdmaQ                  1680.0  ...  129.700  129.700
# 2  UCE_3_c7b769PCiS1iqc1APw                   363.0  ...  158.206  158.206
# 3  UCOxiCFiOYLUgPCtdcDZiK5A                    12.0  ...  129.293  129.293
# 4  UCOxiCFiOYLUgPCtdcDZiK5A                    12.0  ...  121.210  121.210
#
#                          vcodec      asr audio_channels chapters  \
# 0                           vp9  48000.0            2.0     None
# 1                           vp9  48000.0            2.0     None
# 2                           vp9  48000.0            2.0     None
# 3                           vp9  48000.0            2.0     None
# 4  vp09.00.21.08.01.05.01.06.00  48000.0            2.0     None
#
#   manual_caption_languages  automatic_caption_orig_language  location  license
# 0                       en                               en      None     None
# 1                       en                               en      None     None
# 2                       en                               en      None     None
# 3                       sv                               sv      None     None
# 4                       sv                               ru      None     None
#
# [5 rows x 34 columns]

# %%
not_downloaded_df.head()
print(len(not_downloaded_df))
# Out:
# 57649651

# %%
not_downloaded_df.columns
# Out:
# Index(['id', 'title', 'duration', 'view_count', 'categories', 'comment_count',
#        'like_count', 'channel', 'channel_id', 'channel_follower_count',
#        'age_limit', 'upload_date', 'is_live', 'was_live', 'format',
#        'format_id', 'language', 'filesize', 'stretched_ratio', 'width',
#        'height', 'fps', 'dynamic_range', 'aspect_ratio', 'abr', 'vbr',
#        'vcodec', 'asr', 'audio_channels', 'chapters',
#        'manual_caption_languages', 'automatic_caption_orig_language',
#        'location', 'license'],
#       dtype='object')

# %% [markdown]
# #### English

# %%
clean_not_downloaded_df = clean_df(not_downloaded_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language

# %%
clean_not_downloaded_df.head()
# Out:
#             id                           title  duration  view_count  \
# 0  LwJv3vSd8no             Free Art Wednesday!       372       378.0
# 1  XXjYyBCNJEY              FREE Art Wednesday       293       194.0
# 2  OREjUtUT2Sc  New Intro | I keep losing them        11        39.0
# 3  cNPxiPUdyvA      (Примьера дораммы 2021!!!)        20        29.0
# 4  2XitiLKk6rM              Анонимки в тик ток       102       578.0
#
#        categories  comment_count  like_count       channel  \
# 0  People & Blogs          175.0        70.0         Wajas
# 1  People & Blogs           69.0        48.0         Wajas
# 2  People & Blogs            3.0         9.0  Sade Royalty
# 3  People & Blogs            NaN         5.0         Overk
# 4  People & Blogs            3.0        17.0         Overk
#
#                  channel_id  channel_follower_count  ...      abr      vbr  \
# 0  UCrfdGNBnkDd0rOh1M9mdmaQ                  1680.0  ...  120.177  120.177
# 1  UCrfdGNBnkDd0rOh1M9mdmaQ                  1680.0  ...  129.700  129.700
# 2  UCE_3_c7b769PCiS1iqc1APw                   363.0  ...  158.206  158.206
# 3  UCOxiCFiOYLUgPCtdcDZiK5A                    12.0  ...  129.293  129.293
# 4  UCOxiCFiOYLUgPCtdcDZiK5A                    12.0  ...  121.210  121.210
#
#                          vcodec      asr audio_channels chapters  \
# 0                           vp9  48000.0            2.0     None
# 1                           vp9  48000.0            2.0     None
# 2                           vp9  48000.0            2.0     None
# 3                           vp9  48000.0            2.0     None
# 4  vp09.00.21.08.01.05.01.06.00  48000.0            2.0     None
#
#   manual_caption_languages  automatic_caption_orig_language  location  license
# 0                       en                               en      None     None
# 1                       en                               en      None     None
# 2                       en                               en      None     None
# 3                       sv                               sv      None     None
# 4                       sv                               ru      None     None
#
# [5 rows x 34 columns]

# %%
view_lang_cols(clean_not_downloaded_df)
# Out:
#             id                           title manual_caption_languages  \
# 0  LwJv3vSd8no             Free Art Wednesday!                       en
# 1  XXjYyBCNJEY              FREE Art Wednesday                       en
# 2  OREjUtUT2Sc  New Intro | I keep losing them                       en
# 3  cNPxiPUdyvA      (Примьера дораммы 2021!!!)                       sv
# 4  2XitiLKk6rM              Анонимки в тик ток                       sv
#
#   automatic_caption_orig_language language
# 0                              en       en
# 1                              en
# 2                              en
# 3                              sv
# 4                              ru       ru

# %%
condition = (
        clean_not_downloaded_df["manual_caption_languages"]
        .str.split(",")
        .apply(lambda lst: set(lst) == {"en"})
    )
only_en_1 = clean_not_downloaded_df[condition]

# %%
only_en_1.shape[0]
# Out:
# 25507801

# %%
not_only_en_1_id = set(clean_not_downloaded_df["id"]) - set(only_en_1["id"])
len(not_only_en_1_id)
# Out:
# 32141850

# %%
not_only_en_1 = clean_not_downloaded_df[clean_not_downloaded_df["id"].isin(not_only_en_1_id)]

# %%
view_lang_cols(not_only_en_1)
# Out:
#             id                                  title  \
# 3  cNPxiPUdyvA             (Примьера дораммы 2021!!!)
# 4  2XitiLKk6rM                     Анонимки в тик ток
# 5  IPxXLQpOJRU                          Marisa Marisa
# 6  ug5TkquQEHo                          Marisa marisa
# 7  Ar-XwEnnFPY  Formation des Classe D | Serveur UPRP
#
#   manual_caption_languages automatic_caption_orig_language language
# 3                       sv                              sv
# 4                       sv                              ru       ru
# 5                       it                              it
# 6                       it                              it
# 7                       fr                              fr       fr

# %%
get_num_rows(not_only_en_1)
# Out:
# 32141850

# %%
view_lang_cols(not_only_en_1[not_only_en_1["language"] == "en"], 20)
# Out:
#               id                                              title  \
# 75   qVlXu1zanWE                               【游玩克拉普】 平常小方块怎么测试声音的
# 99   1f14oKd9jx8  Meet Don - Direct Express cardholder & PayPerk...
# 100  SK6ngqjyp8E  Meet Helen (Part 2) - Financial Capability wit...
# 101  Wssea1xQJBE  Meet Helen (Part 1) - Convenience, Safety & Se...
# 102  OjjMLrhBkSk  Meet Ray: Direct Express Cardholder & PayPerks...
# 103  zicChYIBtIw  Direct Express Cardholder & PayPerks User Prof...
# 104  6KsSZFDkwJ4  Meet Dawn - Direct Express Cardholder & PayPer...
# 181  AxmibPoLlvo                              [𝐏𝐋𝐀𝐘𝐋𝐈𝐒𝐓] 일렁이는 여름 햇살
# 280  wboahvmJHyU  Resident Evil Revelations 2 - Trailer Oficial ...
# 281  p_GO0YcfN4M  Resident Evil Revelations 2 - Trailer Oficial ...
# 283  GszPk3jAqck                  แกงฟักทองหอมใบเตยแบบ โบร๊าณ โบราณ
# 284  BadVeuJ6h1E                              Short history of Rome
# 327  3jsjeyAOmEs  Capt  Steve Neal (Ret.)  WRIC Naked Man Shot o...
# 328  59UHgUKNfTk  Capt  Steve Neal Ret  WRIC Graduation Safety S...
# 368  G3neEq6-ZWk       Talking To The Moon cover by (Arthur Miguel)
# 439  O1ebCIhPopw  Unboxing and Album Tour "IM NAYEON" NAYEON 1st...
# 532  w_MhP2dmxf8  explaining my three year toxic relationship. s...
# 547  4khB0ZyEhVM                             DFAT-CSIRO partnership
# 571  uWWBF5S-UHE                      送給被生活壓垮的你⋯ 《Burnt out》(audio)
# 665  stIDKDUA-Xs                         Panty Bleaching Gone Viral
#
#     manual_caption_languages automatic_caption_orig_language language
# 75                        zh                              en       en
# 99                     en,es                              en       en
# 100                    en,es                              en       en
# 101                    en,es                              en       en
# 102                    en,es                              en       en
# 103                    en,es                              en       en
# 104                    en,es                              en       en
# 181                       ko                              en       en
# 280                       pt                              en       en
# 281                       pt                              en       en
# 283                       th                              en       en
# 284                       sr                              en       en
# 327                      und                              en       en
# 328                      und                              en       en
# 368                      fil                              en       en
# 439                      fil                              en       en
# 532                       fr                              en       en
# 547                    en,vi                              en       en
# 571             live_chat,zh                              en       en
# 665             en,live_chat                              en       en

# %%
get_num_rows(not_only_en_1[not_only_en_1["language"] == "en"])
# Out:
# 4070589

# %%
view_lang_cols(not_only_en_1[not_only_en_1["manual_caption_languages"].str.contains("en")], 20)
# Out:
#               id                                              title  \
# 11   hWQZq0wHIwQ                           rimne - First Color / MV
# 19   4w-OpSyV5dw            Sangat Sedap | Semua Pasti Menyukainya!
# 21   JiHuFJ9RoHM  DEI UMA PASSADA NO CANADÁ ANTES DE IR PARA O B...
# 22   YhPHqdGcCQ4  MINHA COLEÇÃO INTEIRA DA SUPERESTRELA DA NBA, ...
# 23   zwPpeXqHsZs  JOGUEI O NBA 2K23 (PS4) CURRENT GEN PELA PRIME...
# 24   VdlUZgEL1Qs  JOGUEI BASQUETE COM OS GRINGOS EM UMA QUADRA A...
# 56   9wY84F2-aUQ  DOĞADA HAYAT 44.BÖLÜM |  LİFE İN NATURE EPİSOD...
# 90   so8TfVlMuVs  COMING SEPT 2021 - NEW MUSIC FROM "CUSTOM"! - ...
# 92   OFZyHn-GP48                                Control Z - bad guy
# 99   1f14oKd9jx8  Meet Don - Direct Express cardholder & PayPerk...
# 100  SK6ngqjyp8E  Meet Helen (Part 2) - Financial Capability wit...
# 101  Wssea1xQJBE  Meet Helen (Part 1) - Convenience, Safety & Se...
# 102  OjjMLrhBkSk  Meet Ray: Direct Express Cardholder & PayPerks...
# 103  zicChYIBtIw  Direct Express Cardholder & PayPerks User Prof...
# 104  6KsSZFDkwJ4  Meet Dawn - Direct Express Cardholder & PayPer...
# 106  SI7nWeZJsaE  अब रोबोट पुलिस करेगी अपराधियों का एनकाउंटर/Now...
# 107  -ruaKTKQuvM  Ayam Penyet Cheese & Kambing Bakar Madu - Menu...
# 108  AbEu5_Rn7P4  Kopi 434 - Jenama Kopi PADU Dari Muar! (ENG SUBS)
# 109  bYbhnr-aQ6o  "Pernah Jual Keropok Lekor Tepi Jalan, Payung ...
# 110  TTPbel0c3Qk  Roti John Western Cheese Tarik Paling Dahsyat ...
#
#     manual_caption_languages automatic_caption_orig_language language
# 11                     en,ja                         unknown
# 19           en,live_chat,ms                         unknown
# 21                     en,pt                              pt       pt
# 22                     en,pt                              pt       pt
# 23                     en,pt                         unknown
# 24                     en,pt                              pt       pt
# 56                  en,ko,ur                              tr       tr
# 90              en,live_chat                              en
# 92                  en,es,pt                         unknown
# 99                     en,es                              en       en
# 100                    en,es                              en       en
# 101                    en,es                              en       en
# 102                    en,es                              en       en
# 103                    en,es                              en       en
# 104                    en,es                              en       en
# 106                    en,hi                              hi       hi
# 107                    en,ms                         unknown
# 108                    en,ms                         unknown
# 109                    en,ms                         unknown
# 110                    en,ms                         unknown

# %%
only_en_2 = not_only_en_1[not_only_en_1["manual_caption_languages"].str.contains("en")]

# %%
only_en_2.shape[0]
# Out:
# 9991767

# %%
view_lang_cols(only_en_2[only_en_2["language"] == "en"], 20)
# Out:
#                id                                              title  \
# 99    1f14oKd9jx8  Meet Don - Direct Express cardholder & PayPerk...
# 100   SK6ngqjyp8E  Meet Helen (Part 2) - Financial Capability wit...
# 101   Wssea1xQJBE  Meet Helen (Part 1) - Convenience, Safety & Se...
# 102   OjjMLrhBkSk  Meet Ray: Direct Express Cardholder & PayPerks...
# 103   zicChYIBtIw  Direct Express Cardholder & PayPerks User Prof...
# 104   6KsSZFDkwJ4  Meet Dawn - Direct Express Cardholder & PayPer...
# 547   4khB0ZyEhVM                             DFAT-CSIRO partnership
# 665   stIDKDUA-Xs                         Panty Bleaching Gone Viral
# 696   1G1Fv0oGcpM             Adding subtitles using Chromebook only
# 750   LeXguFYox0o  ENTREVISTA | Neil Newbon, dublador de Nicholai...
# 767   VSa8tQ4umrA                                           Among us
# 854   PiOkO0yKL6s                      Katolik bukan menyembah Maria
# 903   _UsoeCHeBRM                             Who is the antichrist?
# 925   KO6P3mzJ8Q8  Sandwich Ikan Hanyir + Jus Jeruk Kobis Masam G...
# 1023  e9aHLwWbTXk  ENTREVISTA | Jolene Andersen, dubladora de Ada...
# 1083  MZIobSwlDNc  [cafe vlog] 취미부터 창업까지, 베이킹 클래스 오픈 브이로그 | Bakin...
# 1143  1LyApwguwcA  【Kitchen Construction 廚房工程全記錄】Clarence Hong Ko...
# 1176  nlD3u_MZ_oM  ENTREVISTA | Nicole Tompkins, dubladora de Jil...
# 1178  rlCTN-n4q7w  ENTREVISTA | Jeff Schine, dublador de Carlos O...
# 1180  ask0_XubD2k  VINHETA | Nicole Tompkins, dubladora de Jill V...
#
#                     manual_caption_languages automatic_caption_orig_language  \
# 99                                     en,es                              en
# 100                                    en,es                              en
# 101                                    en,es                              en
# 102                                    en,es                              en
# 103                                    en,es                              en
# 104                                    en,es                              en
# 547                                    en,vi                              en
# 665                             en,live_chat                              en
# 696                                    de,en                              en
# 750                                    en,pt                              en
# 767                                    ba,en                              en
# 854                                    en,ms                              en
# 903                             en,live_chat                              en
# 925                                    en,ms                              en
# 1023                                   en,pt                              en
# 1083  de,en,es,fr,id,it,ja,pt,ru,th,vi,zh,zh                              en
# 1143                                   en,zh                              en
# 1176                                   en,pt                              en
# 1178                                   en,pt                              en
# 1180                                   en,pt                              en
#
#      language
# 99         en
# 100        en
# 101        en
# 102        en
# 103        en
# 104        en
# 547        en
# 665        en
# 696        en
# 750        en
# 767        en
# 854        en
# 903        en
# 925        en
# 1023       en
# 1083       en
# 1143       en
# 1176       en
# 1178       en
# 1180       en

# %%
get_num_rows(only_en_2[only_en_2["language"] == "en"])
# Out:
# 1933919

# %%
(only_en_2[only_en_2["language"] == "en"]["automatic_caption_orig_language"] == "").sum() / len(only_en_2[only_en_2["language"] == "en"])
# Out:
# 0.0011768848643609168

# %%
view_lang_cols(only_en_2[only_en_2["automatic_caption_orig_language"] == "en"], 20)
# Out:
#                id                                              title  \
# 90    so8TfVlMuVs  COMING SEPT 2021 - NEW MUSIC FROM "CUSTOM"! - ...
# 99    1f14oKd9jx8  Meet Don - Direct Express cardholder & PayPerk...
# 100   SK6ngqjyp8E  Meet Helen (Part 2) - Financial Capability wit...
# 101   Wssea1xQJBE  Meet Helen (Part 1) - Convenience, Safety & Se...
# 102   OjjMLrhBkSk  Meet Ray: Direct Express Cardholder & PayPerks...
# 103   zicChYIBtIw  Direct Express Cardholder & PayPerks User Prof...
# 104   6KsSZFDkwJ4  Meet Dawn - Direct Express Cardholder & PayPer...
# 433   tFtImC8E0wY  My Heart And Seoul 😍 | 15 Days Around Seoul - ...
# 547   4khB0ZyEhVM                             DFAT-CSIRO partnership
# 665   stIDKDUA-Xs                         Panty Bleaching Gone Viral
# 696   1G1Fv0oGcpM             Adding subtitles using Chromebook only
# 750   LeXguFYox0o  ENTREVISTA | Neil Newbon, dublador de Nicholai...
# 767   VSa8tQ4umrA                                           Among us
# 854   PiOkO0yKL6s                      Katolik bukan menyembah Maria
# 865   -2auYFne_l0  Adventures of Zalke West : Tenerife Part II - ...
# 866   dM2FwfPBC2A  Adventures of Zalke West: Tenerife Part I - Teide
# 903   _UsoeCHeBRM                             Who is the antichrist?
# 925   KO6P3mzJ8Q8  Sandwich Ikan Hanyir + Jus Jeruk Kobis Masam G...
# 1023  e9aHLwWbTXk  ENTREVISTA | Jolene Andersen, dubladora de Ada...
# 1083  MZIobSwlDNc  [cafe vlog] 취미부터 창업까지, 베이킹 클래스 오픈 브이로그 | Bakin...
#
#                     manual_caption_languages automatic_caption_orig_language  \
# 90                              en,live_chat                              en
# 99                                     en,es                              en
# 100                                    en,es                              en
# 101                                    en,es                              en
# 102                                    en,es                              en
# 103                                    en,es                              en
# 104                                    en,es                              en
# 433                             en,live_chat                              en
# 547                                    en,vi                              en
# 665                             en,live_chat                              en
# 696                                    de,en                              en
# 750                                    en,pt                              en
# 767                                    ba,en                              en
# 854                                    en,ms                              en
# 865                             en,live_chat                              en
# 866                             en,live_chat                              en
# 903                             en,live_chat                              en
# 925                                    en,ms                              en
# 1023                                   en,pt                              en
# 1083  de,en,es,fr,id,it,ja,pt,ru,th,vi,zh,zh                              en
#
#      language
# 90
# 99         en
# 100        en
# 101        en
# 102        en
# 103        en
# 104        en
# 433
# 547        en
# 665        en
# 696        en
# 750        en
# 767        en
# 854        en
# 865
# 866
# 903        en
# 925        en
# 1023       en
# 1083       en

# %%
get_num_rows(only_en_2[only_en_2["automatic_caption_orig_language"] == "en"])
# Out:
# 1980299

# %%
view_lang_cols(only_en_2[(only_en_2["automatic_caption_orig_language"] == "en") & (only_en_2["language"] == "en")], 20)
# Out:
#                id                                              title  \
# 99    1f14oKd9jx8  Meet Don - Direct Express cardholder & PayPerk...
# 100   SK6ngqjyp8E  Meet Helen (Part 2) - Financial Capability wit...
# 101   Wssea1xQJBE  Meet Helen (Part 1) - Convenience, Safety & Se...
# 102   OjjMLrhBkSk  Meet Ray: Direct Express Cardholder & PayPerks...
# 103   zicChYIBtIw  Direct Express Cardholder & PayPerks User Prof...
# 104   6KsSZFDkwJ4  Meet Dawn - Direct Express Cardholder & PayPer...
# 547   4khB0ZyEhVM                             DFAT-CSIRO partnership
# 665   stIDKDUA-Xs                         Panty Bleaching Gone Viral
# 696   1G1Fv0oGcpM             Adding subtitles using Chromebook only
# 750   LeXguFYox0o  ENTREVISTA | Neil Newbon, dublador de Nicholai...
# 767   VSa8tQ4umrA                                           Among us
# 854   PiOkO0yKL6s                      Katolik bukan menyembah Maria
# 903   _UsoeCHeBRM                             Who is the antichrist?
# 925   KO6P3mzJ8Q8  Sandwich Ikan Hanyir + Jus Jeruk Kobis Masam G...
# 1023  e9aHLwWbTXk  ENTREVISTA | Jolene Andersen, dubladora de Ada...
# 1083  MZIobSwlDNc  [cafe vlog] 취미부터 창업까지, 베이킹 클래스 오픈 브이로그 | Bakin...
# 1143  1LyApwguwcA  【Kitchen Construction 廚房工程全記錄】Clarence Hong Ko...
# 1176  nlD3u_MZ_oM  ENTREVISTA | Nicole Tompkins, dubladora de Jil...
# 1178  rlCTN-n4q7w  ENTREVISTA | Jeff Schine, dublador de Carlos O...
# 1180  ask0_XubD2k  VINHETA | Nicole Tompkins, dubladora de Jill V...
#
#                     manual_caption_languages automatic_caption_orig_language  \
# 99                                     en,es                              en
# 100                                    en,es                              en
# 101                                    en,es                              en
# 102                                    en,es                              en
# 103                                    en,es                              en
# 104                                    en,es                              en
# 547                                    en,vi                              en
# 665                             en,live_chat                              en
# 696                                    de,en                              en
# 750                                    en,pt                              en
# 767                                    ba,en                              en
# 854                                    en,ms                              en
# 903                             en,live_chat                              en
# 925                                    en,ms                              en
# 1023                                   en,pt                              en
# 1083  de,en,es,fr,id,it,ja,pt,ru,th,vi,zh,zh                              en
# 1143                                   en,zh                              en
# 1176                                   en,pt                              en
# 1178                                   en,pt                              en
# 1180                                   en,pt                              en
#
#      language
# 99         en
# 100        en
# 101        en
# 102        en
# 103        en
# 104        en
# 547        en
# 665        en
# 696        en
# 750        en
# 767        en
# 854        en
# 903        en
# 925        en
# 1023       en
# 1083       en
# 1143       en
# 1176       en
# 1178       en
# 1180       en

# %%
get_num_rows(only_en_2[(only_en_2["automatic_caption_orig_language"] == "en") & (only_en_2["language"] == "en")])
# Out:
# 1930688

# %%
lang_en = only_en_2[only_en_2["language"] == "en"]
auto_lang_en = only_en_2[only_en_2["automatic_caption_orig_language"] == "en"]
lang_en_auto_lang_en = only_en_2[(only_en_2["automatic_caption_orig_language"] == "en") & (only_en_2["language"] == "en")]

# %%
lang_en.shape[0], auto_lang_en.shape[0], lang_en_auto_lang_en.shape[0]
# Out:
# (1933919, 1980299, 1930688)

# %%
temp = set(lang_en["id"]) - set(lang_en_auto_lang_en["id"])
temp_df_2 = lang_en[lang_en["id"].isin(temp)]
view_lang_cols(temp_df_2, 20)
# Out:
#                  id                                              title  \
# 30378   VHOvLOPVxX8                  noc18-me62-Lec 02B-Instrument -II
# 38783   M56GMKXRE7c  🥥❤️ Sadece 3 Malzemeyle Yapabileceğiniz En Güz...
# 59528   34iDTeCNTz4  Simulating color vision deficiencies in the Bl...
# 123890  Wn_1Egqrq9o  Crazy Speed Eating Challenge w/ Rosanna | Copy...
# 123891  RZsb2O2ndCk  Transforming 3 YouTubers into Contortionists |...
# 219529  Np8GMBsUiv8    L'Italien | Policier | Film complet en français
# 219532  J-t9WP_Gl_I  N'embrasse pas la mariée | Comédie, Action | F...
# 219533  CWKZetMHzO8    Ultime Combat (Action) Film complet en français
# 220580  V9JSRHVuLBE  Petite Princesse | Classique | Film complet en...
# 220584  dZPEVh0PWAU  Last Apocalypse | Action | Film complet en fra...
# 220767  Hg9SlI_akI8  Action Movie | Black Belt Angels (1994) | Shaw...
# 220770  ebmWoXYGyPg  La revanche d'un pistolero | Western, Jack Nic...
# 220771  z_Kw9uVyy-g  La Nuit de tous les Mystères | Thriller | Film...
# 220773  d15Fhz3LtSg  Le bistouri de la mafia blanche | Policier | F...
# 220774  5uTTj6DWjSc  Le Fier Rebelle (Western Américain) Film compl...
# 220775  hfBjJXrBdnM  Le Château de la Terreur | Thriller | Film com...
# 220777  owQit9hUNAo  L'homme par qui la vengeance arrive (1970) Wes...
# 220778  ICc2Fz5PDL8  Charade : Trois maris plutôt qu'une veuve | Ro...
# 222058  ra5JMrjy5a4  John Wayne | McLintock! (1963) Western, Comédi...
# 222060  HRewjfpMmOI  Jared Leto | Chapitre 27 (Thriller, Histoire v...
#
#                                  manual_caption_languages  \
# 30378                       bn,en,en,gu,hi,kn,ml,mr,ta,te
# 38783   ar,az,bg,bn,bs,cs,da,de,el,en,es,fa,fi,fil,fr,...
# 59528                                               en,nl
# 123890                                              en,es
# 123891                                              en,es
# 219529  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
# 219532  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
# 219533  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
# 220580  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
# 220584  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
# 220767  ar,de,en,es,fa,fr,hi,hu,id,ja,no,pt,ro,ru,sr,s...
# 220770  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
# 220771  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
# 220773  ar,de,el,en,es,fa,fil,fr,fr,hi,hu,id,it,iw,ja,...
# 220774  ar,bg,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,...
# 220775  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
# 220777  ar,de,el,en,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,...
# 220778  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
# 222058  ar,bg,da,de,el,en,es,fa,fi,fil,fr,hi,hr,hu,id,...
# 222060  ar,de,el,en,es,fa,fil,fr,hi,hu,id,it,iw,ja,ko,...
#
#        automatic_caption_orig_language language
# 30378                                        en
# 38783                                        en
# 59528                               nl       en
# 123890                                       en
# 123891                                       en
# 219529                              fr       en
# 219532                                       en
# 219533                                       en
# 220580                         unknown       en
# 220584                                       en
# 220767                                       en
# 220770                                       en
# 220771                                       en
# 220773                                       en
# 220774                                       en
# 220775                                       en
# 220777                                       en
# 220778                                       en
# 222058                              fr       en
# 222060                              fr       en

# %%
temp_1 = set(auto_lang_en["id"]) - set(lang_en_auto_lang_en["id"])
temp_df_3 = auto_lang_en[auto_lang_en["id"].isin(temp_1)]
view_lang_cols(temp_df_3, 20)
# Out:
#                id                                              title  \
# 90    so8TfVlMuVs  COMING SEPT 2021 - NEW MUSIC FROM "CUSTOM"! - ...
# 433   tFtImC8E0wY  My Heart And Seoul 😍 | 15 Days Around Seoul - ...
# 865   -2auYFne_l0  Adventures of Zalke West : Tenerife Part II - ...
# 866   dM2FwfPBC2A  Adventures of Zalke West: Tenerife Part I - Teide
# 1511  4cz74eJittA  20 Days in CA Exam | Must Cover these things! ...
# 8014  C3oJo-J3lTo  Setting Up Our Christmas Tree 2021 ft. Rayan &...
# 8015  cMOHF0BWKTw  400 to 1000 Rs Kurti Shopping | Meesho Haul | ...
# 8016  VDWdvB8JYVs  Fun Baking Cookies with Rayan 👩‍🍳😎🧒 | Cooking ...
# 8017  tNpSQure4iA  5000 Rupees For A Lunch 😵 | Most Expensive Res...
# 8018  HPY1tat23pI  Masala Chowk Street Food Review 😋♥️ | Jaipur S...
# 8019  Oytplrjbw_Q  Jaipur Street Shopping 🛒🛍| Bapu Bazar | Shoppi...
# 8020  1TjecnoE5os  Samyuktha's Wardrobe Tour 👗💃 | New Dress Colle...
# 8021  q-Xa3pJ32S8  My Trip to Jaipur 😍 🤳| Travel Diaries 🛩 | Samy...
# 8023  -4Q5qDL12fQ  My Kerala Garden Tour ☘️🏡🌱  | Small Space Home...
# 8024  u0oTXU5EojU  Rayan Birthday Celebration 😍🎉🥳| Rio & Jithen R...
# 8157  wPgGlEqMXQ8            Как кормить попугая зеленью? Как часто?
# 8534  ZcACqSivyn8  What's in My Makeup Bag ft. Samyuktha | Makeup...
# 8535  UkA4q85T4U4  Rowdy Baby Dance Workout with Samyuktha | Samy...
# 8536  SN0njFCH3b4          Samyuktha's Kitchen Tour | Samyuktha Shan
# 8537  Zn53stiG9Ds  What's Inside My Fridge?🍟🍕 ft. Samyuktha | Fri...
#
#      manual_caption_languages automatic_caption_orig_language language
# 90               en,live_chat                              en
# 433              en,live_chat                              en
# 865              en,live_chat                              en
# 866              en,live_chat                              en
# 1511             en,live_chat                              en
# 8014             en,live_chat                              en
# 8015             en,live_chat                              en
# 8016             en,live_chat                              en
# 8017             en,live_chat                              en
# 8018             en,live_chat                              en
# 8019             en,live_chat                              en
# 8020             en,live_chat                              en
# 8021             en,live_chat                              en
# 8023             en,live_chat                              en
# 8024             en,live_chat                              en
# 8157             en,live_chat                              en
# 8534             en,live_chat                              en
# 8535             en,live_chat                              en
# 8536             en,live_chat                              en
# 8537             en,live_chat                              en

# %%
any_lang_en_id = set(lang_en["id"].tolist() + auto_lang_en["id"].tolist() + lang_en_auto_lang_en["id"].tolist())
temp_2 = set(only_en_2["id"]) - any_lang_en_id
temp_df_4 = only_en_2[only_en_2["id"].isin(temp_2)]
view_lang_cols(temp_df_4, 20)
# Out:
#               id                                              title  \
# 11   hWQZq0wHIwQ                           rimne - First Color / MV
# 19   4w-OpSyV5dw            Sangat Sedap | Semua Pasti Menyukainya!
# 21   JiHuFJ9RoHM  DEI UMA PASSADA NO CANADÁ ANTES DE IR PARA O B...
# 22   YhPHqdGcCQ4  MINHA COLEÇÃO INTEIRA DA SUPERESTRELA DA NBA, ...
# 23   zwPpeXqHsZs  JOGUEI O NBA 2K23 (PS4) CURRENT GEN PELA PRIME...
# 24   VdlUZgEL1Qs  JOGUEI BASQUETE COM OS GRINGOS EM UMA QUADRA A...
# 56   9wY84F2-aUQ  DOĞADA HAYAT 44.BÖLÜM |  LİFE İN NATURE EPİSOD...
# 92   OFZyHn-GP48                                Control Z - bad guy
# 106  SI7nWeZJsaE  अब रोबोट पुलिस करेगी अपराधियों का एनकाउंटर/Now...
# 107  -ruaKTKQuvM  Ayam Penyet Cheese & Kambing Bakar Madu - Menu...
# 108  AbEu5_Rn7P4  Kopi 434 - Jenama Kopi PADU Dari Muar! (ENG SUBS)
# 109  bYbhnr-aQ6o  "Pernah Jual Keropok Lekor Tepi Jalan, Payung ...
# 110  TTPbel0c3Qk  Roti John Western Cheese Tarik Paling Dahsyat ...
# 111  A2lbnq1_ma8  Bertarung Untuk Pasang ANDA SEAT! Gaming Chair...
# 112  HmMeWO8lPuo  Melantak Thai Food Sampai Lebam Di Soi 55 Thai...
# 113  wDVOnlvcEM4  Aku Ketagih Makan Kerepek Belinjo! 👨🏼 | Belinj...
# 114  Uj51y43wPcM  Berhabis RM3++ Makan Di Beard Brothers BBQ | B...
# 115  UiWrPNGTp0Q  Tealive Buat Flavour 'Mercun' Pop Pop?! (ENG S...
# 116  tjNoXLmB92Y  Kasi Hirup Sampai Licin! Spicy Ramen TERPADU D...
# 145  _1Nt7LgUc4Q  KISAH MISTIS PENJUAL BUAH-BUAHAN YANG MELAKUKA...
#
#     manual_caption_languages automatic_caption_orig_language language
# 11                     en,ja                         unknown
# 19           en,live_chat,ms                         unknown
# 21                     en,pt                              pt       pt
# 22                     en,pt                              pt       pt
# 23                     en,pt                         unknown
# 24                     en,pt                              pt       pt
# 56                  en,ko,ur                              tr       tr
# 92                  en,es,pt                         unknown
# 106                    en,hi                              hi       hi
# 107                    en,ms                         unknown
# 108                    en,ms                         unknown
# 109                    en,ms                         unknown
# 110                    en,ms                         unknown
# 111                    en,ms                         unknown
# 112                    en,ms                         unknown
# 113                    en,ms                         unknown
# 114                    en,ms                         unknown
# 115                    en,ms                         unknown
# 116                    en,ms                         unknown
# 145        en,en,en,id,tk,tr                              id       id

# %%
en_ids = set(only_en_1["id"].tolist() + lang_en["id"].tolist() + lang_en_auto_lang_en["id"].tolist())
len(en_ids)
# Out:
# 27441720

# %%
approx_en_only = list(en_ids) + id_downloaded
len(approx_en_only)
# Out:
# 29890220

# %%
with open("data/metadata/approx_en_only.txt", "w") as f:
    for video_id in approx_en_only:
        f.write(video_id + "\n")

# %% [markdown]
# #### English (w/ established filters)

# %%
en_not_downloaded_df = not_downloaded_df[not_downloaded_df["id"].isin(en_ids)]
view_lang_cols(en_not_downloaded_df, 20)
# Out:
#              id                                              title  \
# 0   LwJv3vSd8no                                Free Art Wednesday!
# 1   XXjYyBCNJEY                                 FREE Art Wednesday
# 2   OREjUtUT2Sc                     New Intro | I keep losing them
# 8   nmRxk7k3kvU                           Meditation Music video-2
# 14  m18UlcXg3Xg  ' YOU LADYBUG SONG' |MIRACULOUS LADYBUG & CAT ...
# 20  y1yb_WnCfUA                       Video Editor is. Thastefuel?
# 30  sIKsodQRvlc                                MYO Hand Letter Art
# 31  v8uKybpMJdM          Nature Moment | Common Blue Violet Flower
# 32  IkiTwxRtQUk                                 MYO Whipped Coffee
# 33  VvPE3uB7O1A                    Nature Moment | The Holly Plant
# 35  Nj4wCms-Xko         NSFW Shego (Kim Possible) Speedrun #Shorts
# 36  8SnK7mWezWw  Jobs for Veterans: Janine Hardman RN, BSN, Arm...
# 37  D0TBEM3oUtk         Meet Medical Oncologist, Matthew Kulke, MD
# 38  t1EwgfdBn-0                       BMC Faces: Sarah Kimball, MD
# 39  qjXauRp1uaU               Jobs for Veterans: Joseph Blansfield
# 40  7TZ02EP-VaE  BMC Presents: Donate Life - Marta and Brenda's...
# 41  lVBVy0EY0I4  BMC Presents: Donate Life - Bob & Mike featuri...
# 42  ln8Tgp4NsOg  BMC Presents: Donate Life - Dan & Susan's Kidn...
# 43  1CDSz94YRGk                         Meet: Gregory Grillone, MD
# 44  Dvyxal7xrfI  Inflammatory Bowel Disease Care at Boston Medi...
#
#    manual_caption_languages automatic_caption_orig_language language
# 0                        en                              en       en
# 1                        en                              en     None
# 2                        en                              en     None
# 8                     en-US                           en-US     None
# 14                    en-GB                           en-GB     None
# 20                    en-GB                           en-GB     None
# 30                    en-US                           en-US     None
# 31                       en                              en       en
# 32                       en                              en       en
# 33                       en                              en       en
# 35                       en                              en       en
# 36                       en                              en       en
# 37                       en                              en       en
# 38                       en                              en       en
# 39                       en                              en       en
# 40                       en                              en       en
# 41                       en                              en       en
# 42                       en                              en       en
# 43                       en                              en       en
# 44                       en                              en       en

# %%
en_not_downloaded_df[en_not_downloaded_df["manual_caption_languages"].str.contains("en-")].head(20)
# Out:
#               id                                              title  duration  \
# 8    nmRxk7k3kvU                           Meditation Music video-2      1295
# 14   m18UlcXg3Xg  ' YOU LADYBUG SONG' |MIRACULOUS LADYBUG & CAT ...       157
# 20   y1yb_WnCfUA                       Video Editor is. Thastefuel?        12
# 30   sIKsodQRvlc                                MYO Hand Letter Art        80
# 52   0Yt4JoCW8oU                        G Gundam Screenshop Repaint      1233
# 54   orWh_OLaRg4  All Goals | Final Copa America | Argentina (1)...        77
# 93   y3o-baXQT0Q                             VLOG #1 - Introduction       123
# 131  zHGwE0ritgk       Let's Play Minecraft: Greatest freakout ever       122
# 133  1N2Q2-veW8Y  Changing the Roofing Industry by Building Trus...       128
# 134  7CRyjEyWjP4  Schneider Roofing & Remodeling - Show Me St. L...       164
# 135  GhnyvKtQm7w   Do I Really Need a New Roof? - Schneider Roofing       158
# 136  BGl0TRn-kdY           Schneider Roofing - St. Louis Cardinal's       107
# 161  _vcLAPLnv4o  1Granja Helio,  2 Aniversario Alvaro , 3 Brasilia      3608
# 162  dBUOZQZpODA                                  natal joao pessoa      1227
# 163  Kfdc3s1hl9k                                         Natal 1996      3245
# 164  5BTrs5Uvi0s                                              Vidéo      3611
# 166  TYmnAQT88qw                       Ano Novo 1989 e Aniversarios      3589
# 190  qwNlru5_Ej4  Undertale Minecraft RolePlay (UTRP) [UPDATE VI...       656
# 200  uEDPh2HOxDI  Friendly Compadre 18 (ENG CC) - My EX and my a...       530
# 207  u_TgMlq6rQA  Advancing Health Equity through Community COVI...       288
#
#      view_count             categories  comment_count  like_count  \
# 8          44.0                  Music            1.0         2.0
# 14       2433.0                  Music            NaN        57.0
# 20         25.0                  Music            1.0         1.0
# 30         24.0          Howto & Style            NaN         1.0
# 52         27.0          Howto & Style            NaN         1.0
# 54         17.0         People & Blogs            NaN         0.0
# 93        169.0         People & Blogs            7.0         7.0
# 131      2620.0                 Gaming            3.0        14.0
# 133         1.0          Howto & Style            NaN         0.0
# 134        13.0          Howto & Style            NaN         0.0
# 135         2.0          Howto & Style            NaN         0.0
# 136         1.0          Howto & Style            NaN         0.0
# 161        34.0         People & Blogs            NaN         5.0
# 162        24.0         People & Blogs            NaN         0.0
# 163        55.0         People & Blogs            NaN         0.0
# 164        85.0         People & Blogs            1.0         3.0
# 166       120.0         People & Blogs            NaN         3.0
# 190      2069.0                 Gaming           66.0        14.0
# 200        18.0          Howto & Style            NaN         2.0
# 207      1629.0  Nonprofits & Activism            NaN        10.0
#
#                             channel                channel_id  \
# 8                  Meditation music  UCaHJfbRk8gnOZGrJTm5ZI4Q
# 14     miraculous ladybug season 06  UCBgXfZj6cVvu8cz0AX66HZQ
# 20                   FrostyBallz Jr  UC-uKNbvsFlLqBaVI_ysSvig
# 30    Roanoke County Public Library  UCRDIW4cJil7ls67SLQs9a4Q
# 52                         TkayArtz  UCHH2EHqaELDc2Lq9Ct5tn5w
# 54                  North Direction  UCDWbla2PIao9c6DnQNENkDQ
# 93                          Rikzaaa  UCkWADUHEgSPEdLlpdsc6pAA
# 131              Riftenthecoolish93  UC_eV8_QSpMKm7ouQrs__qew
# 133  Schneider Roofing & Remodeling  UCA0DTNFRM-GrtGH_DpH9vYA
# 134  Schneider Roofing & Remodeling  UCA0DTNFRM-GrtGH_DpH9vYA
# 135  Schneider Roofing & Remodeling  UCA0DTNFRM-GrtGH_DpH9vYA
# 136  Schneider Roofing & Remodeling  UCA0DTNFRM-GrtGH_DpH9vYA
# 161                      aabPalitot  UCENZUDVWbiekZNefJjTh_bA
# 162                      aabPalitot  UCENZUDVWbiekZNefJjTh_bA
# 163                      aabPalitot  UCENZUDVWbiekZNefJjTh_bA
# 164                      aabPalitot  UCENZUDVWbiekZNefJjTh_bA
# 166                      aabPalitot  UCENZUDVWbiekZNefJjTh_bA
# 190             The Almighty Hotdog  UCGEH5eyg5RfuPD-dObKZNNQ
# 200                  Compadre Amigo  UCrNP-93yRcJMKo1BtAdAOYQ
# 207           Boston Medical Center  UCCsieriDUNU-2-nNmXngYAw
#
#      channel_follower_count  ...      abr      vbr  \
# 8                       3.0  ...  124.292  124.292
# 14                    524.0  ...  131.965  131.965
# 20                      3.0  ...  130.202  130.202
# 30                    217.0  ...  138.620  138.620
# 52                     34.0  ...  139.683  139.683
# 54                      NaN  ...  122.410  122.410
# 93                    306.0  ...  115.805  115.805
# 131                   776.0  ...  156.967  156.967
# 133                     4.0  ...  115.743  115.743
# 134                     4.0  ...  103.942  103.942
# 135                     4.0  ...  116.439  116.439
# 136                     4.0  ...  123.846  123.846
# 161                    16.0  ...  130.630  130.630
# 162                    16.0  ...  124.008  124.008
# 163                    16.0  ...  123.808  123.808
# 164                    16.0  ...  127.808  127.808
# 166                    16.0  ...  131.259  131.259
# 190                    40.0  ...  149.189  149.189
# 200                    87.0  ...  123.836  123.836
# 207                  7460.0  ...  138.457  138.457
#
#                            vcodec      asr audio_channels chapters  \
# 8                     avc1.640028  48000.0            2.0     None
# 14   vp09.00.31.08.01.05.01.06.00  48000.0            2.0     None
# 20                            vp9  44100.0            2.0     None
# 30                  vp09.00.50.08  48000.0            2.0     None
# 52                    avc1.640028  48000.0            2.0     None
# 54                  vp09.00.21.08  48000.0            2.0     None
# 93                    avc1.640028  48000.0            2.0     None
# 131                 vp09.00.30.08  48000.0            2.0     None
# 133                   avc1.640028  48000.0            2.0     None
# 134                   avc1.640028  48000.0            2.0     None
# 135                   avc1.640028  48000.0            2.0     None
# 136                   avc1.640028  48000.0            2.0     None
# 161                   avc1.4D401E  48000.0            2.0     None
# 162                           vp9  48000.0            2.0     None
# 163                   avc1.4D401E  48000.0            2.0     None
# 164                   avc1.4D401E  48000.0            2.0     None
# 166                   avc1.4D401E  48000.0            2.0     None
# 190                 vp09.00.31.08  48000.0            2.0     None
# 200                           vp9  48000.0            2.0     None
# 207                   avc1.640028  48000.0            2.0     None
#
#           manual_caption_languages  automatic_caption_orig_language  \
# 8                            en-US                            en-US
# 14                           en-GB                            en-GB
# 20                           en-GB                            en-GB
# 30                           en-US                            en-US
# 52                           en-US                               en
# 54   en-JkeT_87f4cc,en-uYU-mmqFLq8                               en
# 93                           en-US                               en
# 131                 en-18WT74-rBWA                               en
# 133                          en-US                               en
# 134           en-US,en-uYU-mmqFLq8                               en
# 135                          en-US                               en
# 136                          en-US                               en
# 161                 en-uYU-mmqFLq8                               en
# 162                 en-uYU-mmqFLq8                               en
# 163                 en-uYU-mmqFLq8                               en
# 164                 en-uYU-mmqFLq8                               es
# 166                 en-uYU-mmqFLq8                               en
# 190                          en-GB                            en-GB
# 200                          en-US                               es
# 207                 en-eEY6OEpapPo                               en
#
#       location  license
# 8         None     None
# 14   AUSTRALIA     None
# 20        None     None
# 30        None     None
# 52        None     None
# 54        None     None
# 93        None     None
# 131       None     None
# 133       None     None
# 134       None     None
# 135       None     None
# 136       None     None
# 161       None     None
# 162       None     None
# 163       None     None
# 164       None     None
# 166       None     None
# 190       None     None
# 200       None     None
# 207       None     None
#
# [20 rows x 34 columns]

# %%
en_not_downloaded_df["man_cap_langs_2"] = en_not_downloaded_df["manual_caption_languages"]
# Out:
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_73078/761563661.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en_not_downloaded_df["man_cap_langs_2"] = en_not_downloaded_df["manual_caption_languages"]

# %%
en_not_downloaded_df.columns
# Out:
# Index(['id', 'title', 'duration', 'view_count', 'categories', 'comment_count',
#        'like_count', 'channel', 'channel_id', 'channel_follower_count',
#        'age_limit', 'upload_date', 'is_live', 'was_live', 'format',
#        'format_id', 'language', 'filesize', 'stretched_ratio', 'width',
#        'height', 'fps', 'dynamic_range', 'aspect_ratio', 'abr', 'vbr',
#        'vcodec', 'asr', 'audio_channels', 'chapters',
#        'manual_caption_languages', 'automatic_caption_orig_language',
#        'location', 'license', 'man_cap_langs_2'],
#       dtype='object')

# %%
view_lang_cols(en_not_downloaded_df)
# Out:
#              id                                              title  \
# 0   LwJv3vSd8no                                Free Art Wednesday!
# 1   XXjYyBCNJEY                                 FREE Art Wednesday
# 2   OREjUtUT2Sc                     New Intro | I keep losing them
# 8   nmRxk7k3kvU                           Meditation Music video-2
# 14  m18UlcXg3Xg  ' YOU LADYBUG SONG' |MIRACULOUS LADYBUG & CAT ...
#
#    manual_caption_languages automatic_caption_orig_language language
# 0                        en                              en       en
# 1                        en                              en     None
# 2                        en                              en     None
# 8                     en-US                           en-US     None
# 14                    en-GB                           en-GB     None

# %%
condition = (
        en_not_downloaded_df["man_cap_langs_2"]
        .apply(standardize_dialects_2)
        .apply(lambda lst: set(lst) == {"en"})
)
temp_df_5 = en_not_downloaded_df[condition]

# %%
temp_df_5["manual_caption_languages"].unique()
# Out:
# array(['en', 'en-US', 'en-GB', ..., 'en-CA-UFjxr4OIYz8', 'en-FpQ6dhQAASY',
#        'en-LQRErUK_jpw'], dtype=object)

# %%
list(temp_df_5["manual_caption_languages"].unique())
# Out:
# ['en',
#  'en-US',
#  'en-GB',
#  'en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-18WT74-rBWA',
#  'en-US,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8',
#  'en-eEY6OEpapPo',
#  'en-IN',
#  'en-CA',
#  'en,en-GB',
#  'en-cvfXDfbeED0',
#  'en-US-anMIXjicSL4',
#  'en-s8TMdDjdYe8',
#  'en-IE',
#  'en,en-US',
#  'en-rX01gsAdUfU',
#  'en-nP7-2PuUl7o',
#  'en-zL7EZQmMa4Q',
#  'en,en-IN',
#  'en-imjcPpJerPk',
#  'en-zL_pKPa_d08',
#  'en-cFSbaKj2OKY',
#  'en-anMIXjicSL4',
#  'en-UMYBvvsXfqo',
#  'en-1oAFzPNiuC0',
#  'en-ehkg1hFWq8A',
#  'en-vleHeMwJqgw',
#  'en-0hllRZe4s5s',
#  'en-US-eEY6OEpapPo',
#  'en-K3JFmAG0FTI',
#  'en,en-zL7EZQmMa4Q',
#  'en-GB,en-US',
#  'en-PQgNkSoyyBk',
#  'en-TW7qhz_uLiI',
#  'en-Zixs6prhbeE,en-nPk3V-duwf8',
#  'en-US-YfeEIUII1AU',
#  'en-y01yHln2iAs',
#  'en-uYU-mmqFLq8,en-zL_pKPa_d08',
#  'en-y7ZDYfb4tI8',
#  'en-GusEpHUv8yI',
#  'en-1FAeErPlCAc',
#  'en,en-CA',
#  'en-fGGqjO4aYg8',
#  'en-q_HRRye8iTM',
#  'en-nPk3V-duwf8',
#  'en-A8Ln5B_8GBo',
#  'en,en-UDggLCECq8g',
#  'en-lqO-PPJy4Bc',
#  'en-qoXxhA4oLYo',
#  'en-m9hPnTBjEoU',
#  'en-wILyS7txfUA',
#  'en-IN,en-US',
#  'en-6Effb_CP71k',
#  'en,en-uYU-mmqFLq8',
#  'en-nHenYwqXk4s',
#  'en-d6gV6WVcwQQ',
#  'en-oEkF-RzuXbU',
#  'en-WPGPOmZxCFk',
#  'en-HmwMawKq9bY',
#  'en-ZW6bPmS_ILY',
#  'en-2WL_udbGxQs',
#  'en-Uym2X1t3MTA',
#  'en-puBa_fWWqOc',
#  'en,en-ehkg1hFWq8A',
#  'en-VuAxBFMsp20',
#  'en-vP3gpS-n2EU',
#  'en,en-Uym2X1t3MTA',
#  'en-NjKQ6KFPTeM',
#  'en-OkkdIt_1FtE',
#  'en-8k-bGVCfGYE',
#  'en-Ofml0VSlMyE',
#  'en-MPV48gM7bqQ',
#  'en-US,en-US-Az1uF2nEdyo',
#  'en-LUU0EuDKgKo',
#  'en-6UJrWS5jR_I',
#  'en-6UJrWS5jR_I,en-gG13fOM8Dfs',
#  'en-FmoQciUtYSc',
#  'en-gG13fOM8Dfs',
#  'en-6UJrWS5jR_I,en-LUU0EuDKgKo',
#  'en-tyWfmtkyBQo',
#  'en-SJ_OorK2o0k',
#  'en-LUU0EuDKgKo,en-gG13fOM8Dfs',
#  'en,en-LUU0EuDKgKo',
#  'en-bo0751DuF0A',
#  'en-6UJrWS5jR_I,en-GB',
#  'en,en-GB-6UJrWS5jR_I,en-LUU0EuDKgKo',
#  'en,en-0kNkGc9-BfI,en-GB-6UJrWS5jR_I,en-LUU0EuDKgKo',
#  'en,en-0kNkGc9-BfI,en-GB-6UJrWS5jR_I,en-LUU0EuDKgKo,en-vYdUoF8TkEk',
#  'en,en-GB-6UJrWS5jR_I,en-vYdUoF8TkEk',
#  'en-GB-6UJrWS5jR_I',
#  'en-GB,en-SJ_OorK2o0k',
#  'en,en-0kNkGc9-BfI,en-GB-6UJrWS5jR_I',
#  'en,en-6UJrWS5jR_I',
#  'en-zOnwy86eUkk',
#  'en,en-GB,en-LUU0EuDKgKo',
#  'en-GB-6UJrWS5jR_I,en-LUU0EuDKgKo',
#  'en-ZBvqvWAExS0',
#  'en,en-xMpCOKC5I4I',
#  'en-Sxg7wWGnGNg',
#  'en-76oVOw9oKuU,en-xMpCOKC5I4I',
#  'en-7MvIfktc4v4,en-yB5yjZ1ML2M',
#  'en-LUU0EuDKgKo,en-M-WisMIBVug',
#  'en-LIpNJOgiZG4,en-gG13fOM8Dfs',
#  'en-islCoqYLrbY',
#  'en-iGJpuh49ngc',
#  'en-cAKMgbCC-fs',
#  'en-Fn5MF40AHlI',
#  'en-2avXrs-sA5o',
#  'en-gHD45WmuTUk',
#  'en-iGRNtWUgfHc',
#  'en-ngggGVIunHc',
#  'en-if-_5MVq4Oo',
#  'en-xqMIxE5vx4g',
#  'en-WMWuJvsuvM0',
#  'en-Phs7HaRpmxc',
#  'en-vWpxECmUytM',
#  'en-gjf-1tSwjvQ',
#  'en-9H6bSekVbKY',
#  'en-GHQATvmmdhE',
#  'en-MvXeHcEkV6M',
#  'en-HfU1kBDaoeU',
#  'en-tn2FgxsJXPs',
#  'en-zsweiKMxjbg',
#  'en-DvHdX2kI9hs',
#  'en-S1Q9ONhyWlE',
#  'en-1Hzps0N_MPU',
#  'en-upRjq0FRvOM',
#  'en-3t0pjotC4o8',
#  'en-g_D0HJdf2ak',
#  'en-Hvkv0GLQGe0',
#  'en-61rj6qWJFLM',
#  'en-6biY9mi3trE',
#  'en-1yERvTPwLfs',
#  'en-gQs2rYpr-Bs',
#  'en-yMosIl2z1s0',
#  'en-llJczrNKcy4',
#  'en-T7MrD1YrYNQ',
#  'en-xf0PX6EkjBE',
#  'en-fcVymTUPpeI',
#  'en-EqpVbppp6GY',
#  'en-H_h6RMPrfCg',
#  'en-Ea2cOYhJJN8',
#  'en-meBFpKW-w_Y',
#  'en-BL_DZqyFfhQ',
#  'en-d4e-sftakyk',
#  'en-US,en-nP7-2PuUl7o',
#  'en-FhOyXW7vw1Q',
#  'en-gpLhevRF8rA',
#  'en-eojh1S_pMNM',
#  'en-jFK5kpDRP3M',
#  'en,en-21M8WI-ZtuA',
#  'en-O5gwMiep5w8',
#  'en-cmGzvRTCcoM',
#  'en-zWSztBjdBA0',
#  'en-qmp7RGYOjJQ',
#  'en-HrjNrJ83ADA',
#  'en-rro1-ZU-JXE',
#  'en-S5keeP5-mFg',
#  'en-v9B2qqWVzdQ',
#  'en-AU',
#  'en-GB-duqIB3Ivo2c',
#  'en-dE8xcS92EcM',
#  'en-REjPv0WzLGo',
#  'en,en-dZAhw2Veuag',
#  'en-TGqiiJw2dmI',
#  'en-y4fwKszN_rY',
#  'en-BCIa9Uq2gpQ,en-GB',
#  'en,en-GB-uMN-M9795Rw',
#  'en-gmhThQ938Kc',
#  'en-ZMpglypuySY',
#  'en-wUbgmG6Sv_I',
#  'en-qD-qwlB2ZC0',
#  'en-FetHzM0RQJU',
#  'en-dBnIPyQn-7E',
#  'en-VzZ7z7gID6c',
#  'en-DX1xJ45FbHc',
#  'en-Pn_zu28Dr6A',
#  'en-j3PyPqV-e1s',
#  'en-qlPKC2UN_YU',
#  'en,en-qlPKC2UN_YU',
#  'en-US,en-j3PyPqV-e1s',
#  'en-JkeT_87f4cc,en-j3PyPqV-e1s',
#  'en-US-BfshbuJ9u2Q',
#  'en-US-qhidoPi0w8c',
#  'en-US-7VqXalgof68',
#  'en-US-iLtzV24hzLM',
#  'en,en-j3PyPqV-e1s',
#  'en-0GZSgHK00aQ',
#  'en,en-CA,en-GB,en-IE,en-IN,en-US',
#  'en-US-Tz2g3Ok69lM',
#  'en-US-KeiurSZEkPo',
#  'en-US-T4OLh11_lkI',
#  'en-6ebHVfu6BsQ',
#  'en-LncXMvopwAc',
#  'en,en-GB,en-IN,en-US',
#  'en-GB,en-IE',
#  'en-LtWZwabQMh4',
#  'en-ovhHx95i6Ho',
#  'en-Jyun0WSqg2k',
#  'en,en-6J3Fe4Pss0Y',
#  'en-GHEw9DUond8',
#  'en-GB,en-uYU-mmqFLq8',
#  'en-bFjpeiP6wzQ',
#  'en-YbU81EbFwnU',
#  'en-Hod1tDuSZpQ',
#  'en-g3sZi71aORs',
#  'en-ejYvIAw3rm4',
#  'en-3EZ2SlE8DSw',
#  'en-jr_ntwmUyqk',
#  'en-CUBnaAm_WCg',
#  'en-1oAFzPNiuC0,en-uYU-mmqFLq8',
#  'en-N4kgRcPSw6A',
#  'en-uKpN1tTG93w',
#  'en-RPMGl4fB8OA',
#  'en-eHloqz0DtQ0',
#  'en-5iccchR9oVs',
#  'en-SAlmeBsx6eA',
#  'en-yY28IvSfG0o',
#  'en-xzT-nJHltPQ',
#  'en-CvmWTchUDqY',
#  'en-L7Y8rZWawzA',
#  'en-aL_5_v9zbBM',
#  'en-mI7aUCLzdjE',
#  'en-2qxE-mwDpSU',
#  'en-bSRtDOqDE9o',
#  'en-KyVObD-42KU',
#  'en-IujS0_XVVrw',
#  'en-GB-anMIXjicSL4',
#  'en-OxbJ1MTIVs4',
#  'en--gxqKfNj5XA',
#  'en-23PnzzdJvos',
#  'en--FB6cFtFezg',
#  'en-0ONhgy-lWvo',
#  'en-yR6JfUoAWYg',
#  'en-1mR-xBGZEZ4',
#  'en-64EvSf-i32o',
#  'en-8P0-Z2SKhy4',
#  'en-xWCTb4ASxWo',
#  'en-3oY-wYEVjgY',
#  'en-DI1FT9YnJxw',
#  'en-mqT_bUH1f74',
#  'en-nWZJSqx27Co',
#  'en-wrkgf4iBZSg',
#  'en-p-a8_cEWdOk',
#  'en-z32Y2Axx7Xs',
#  'en-bdFBGmYVkEA',
#  'en-1dfyypFS06k',
#  'en-3BbmkACe_Ck',
#  'en-hUGJy75jDp0',
#  'en-QLlkAr8DpK0',
#  'en-gcgg6QaEclI',
#  'en-fT_tyvG74RA',
#  'en,en-nP7-2PuUl7o',
#  'en-G1jV0keXEkQ',
#  'en,en-1oAFzPNiuC0',
#  'en-t8dcvQ4hAi0',
#  'en-jm5Qn7oS3ns',
#  'en-C98BKmi_tmk',
#  'en-7rk6kshSjAg',
#  'en-ZLqp32PlplQ',
#  'en-_Hof7-ZAGIA,en-uYU-mmqFLq8',
#  'en-iktMRMbGemc,en-uYU-mmqFLq8',
#  'en-3MbBqDa1_xg,en-uYU-mmqFLq8',
#  'en-B1i59iwuZlM,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-wbPQmIjmQP8',
#  'en-76Rj-GuXV8A,en-uYU-mmqFLq8',
#  'en-8K7HLuWh9lI,en-uYU-mmqFLq8',
#  'en-FltNKKLDWYo,en-uYU-mmqFLq8',
#  'en-MGaoCWZxdkw,en-uYU-mmqFLq8',
#  'en-TG_nCj5ASpU,en-uYU-mmqFLq8',
#  'en-Q6Y_6uU4N38,en-uYU-mmqFLq8',
#  'en-EfSslzmZKw0,en-uYU-mmqFLq8',
#  'en-ywMsn8eDCTc',
#  'en-JRakUmdHCC8',
#  'en-fBJ7WLCgqx8',
#  'en-GtDsi6WLVPc',
#  'en-VqxSfNneakA',
#  'en-Ofp0J1P2Fj8',
#  'en-dIsCpYIEZ-A',
#  'en-CY5OQ3YEjy0',
#  'en-DU6Y4mlPvmE',
#  'en-0raYX-fjB-Y',
#  'en-A2Vm0pEh5-Y',
#  'en-yd_sspvDACE',
#  'en-6DGfwZopUls',
#  'en-ab5nJ29o4es',
#  'en-BEo9_LMRxWY',
#  'en-oD20rO7Phvo',
#  'en-d9VYABo4dik',
#  'en-AKTRZJ-NMNI',
#  'en-xEM73oi3n3M',
#  'en-UgyXJBR6AFs,en-uYU-mmqFLq8',
#  'en-qAfPFHriwdk,en-uYU-mmqFLq8',
#  'en-QylZedUUFiA,en-uYU-mmqFLq8',
#  'en-O6wkUz5wElU,en-uYU-mmqFLq8',
#  'en-jIpDolMlEmA',
#  'en-QiHwL5tfpfI',
#  'en-dSf3a27VGm8',
#  'en-ssLC1dOyF34',
#  'en-JWp4A7VQiG0',
#  'en-9qd52hCbh0o',
#  'en-UQOvE_COaTM',
#  'en-8DarVTzXFEE',
#  'en-5X6CBLEIevk',
#  'en-u_ZFxZ4Iwxw',
#  'en-FF1NwU-wxK4,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-x80YNd3z25Y',
#  'en-cHMI6a8ww9E,en-uYU-mmqFLq8',
#  'en-FcsVn2rKMtI,en-uYU-mmqFLq8',
#  'en-0qs7cWpj4rA,en-uYU-mmqFLq8',
#  'en-e3NusTPrr30',
#  'en-ZvsrR0Q_eXs',
#  'en-UNfGon_hYfo',
#  'en-DhOS5gtZfZk',
#  'en-_CqfN_LT9aE',
#  'en-9v0ZI75fiZE',
#  'en-EJnfUyAiN2g,en-uYU-mmqFLq8',
#  'en-iT7qnIhNJWA,en-uYU-mmqFLq8',
#  'en-tTbOJDVqCbI',
#  'en-Rhz_4ijIPaQ',
#  'en-i3qf1mbYapA',
#  'en-11ZdSa6hooI',
#  'en-lurLXvJcXvI',
#  'en-tkYzxHx4p5Q',
#  'en-3GFUKXcb7WM',
#  'en-uVxC6Conj38,en-uYU-mmqFLq8',
#  'en-1UNkydfJV24,en-uYU-mmqFLq8',
#  'en-mWAmV_B9GV8,en-uYU-mmqFLq8',
#  'en-NpXwbx70etE,en-uYU-mmqFLq8',
#  'en-0XFuZABDzVk,en-uYU-mmqFLq8',
#  'en-V9jSuAjJEbI,en-uYU-mmqFLq8',
#  'en-qZlK2sLnnoo,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-ySYwVaaeHaY',
#  'en-iN6F7OcXyNY,en-uYU-mmqFLq8',
#  'en-PWabrcnD3Z8,en-uYU-mmqFLq8',
#  'en-8F2EDzgHxtg,en-uYU-mmqFLq8',
#  'en-cAkvJR0zB90,en-uYU-mmqFLq8',
#  'en-jhHEXAO2I0o,en-uYU-mmqFLq8',
#  'en-jx4UCXjwadg',
#  'en-efEyZfXswYU',
#  'en-0nRMqpa1Hr0',
#  'en-NFcLRpr5wbM',
#  'en-RFC1Y7VVULk',
#  'en-MPUBBCWfl68',
#  'en-xCMTqQGUYLg',
#  'en-7D5_z6-AsQ4',
#  'en-80RURFZ4zuI',
#  'en-i-yJDRLzc9k',
#  'en-dp6BXKpHKFo',
#  'en-dmhUiaHExf8',
#  'en-xG2L3wN5MZY',
#  'en-eLuuvKe3-1Q',
#  'en-s7haLhmWpG4',
#  'en-N26N9DLURLo,en-uYU-mmqFLq8',
#  'en-7LiXD61PwAc,en-uYU-mmqFLq8',
#  'en-Anbi2vIZBTk,en-uYU-mmqFLq8',
#  'en-tsgj_oGjMgw,en-uYU-mmqFLq8',
#  'en-TZAATuirJ_Q,en-uYU-mmqFLq8',
#  'en-BgBHMiEXI_o,en-uYU-mmqFLq8',
#  'en-H7ZOto6JJT8,en-uYU-mmqFLq8',
#  'en-l6QjZcGF8aw',
#  'en-zoEa883gshU',
#  'en-bV6djx43ixY',
#  'en-FZX3Xl_7zRI',
#  'en-Q9iUvTQL9FE',
#  'en-Z5N4aknX6OI',
#  'en-GpK8vawI_Io',
#  'en-DzJWn9OFqRc,en-uYU-mmqFLq8',
#  'en-MSHQHP5KFLc,en-uYU-mmqFLq8',
#  'en-sDADfminFcM,en-uYU-mmqFLq8',
#  'en-4YnTPw1gmr0,en-uYU-mmqFLq8',
#  'en-Mpg_1Va2K9k,en-uYU-mmqFLq8',
#  'en-VNj6tqF9Oo4,en-uYU-mmqFLq8',
#  'en-H_1Mk8KB8K4,en-uYU-mmqFLq8',
#  'en-120rn_vNGx8',
#  'en-uVRFU16Reas,en-uYU-mmqFLq8',
#  'en-cQ1llC5r_N4,en-uYU-mmqFLq8',
#  'en-TDNdoLvhUmM,en-uYU-mmqFLq8',
#  'en-3LFvsy878l0',
#  'en-_t72HAHLm4A,en-uYU-mmqFLq8',
#  'en-MEPSEoivOZM,en-uYU-mmqFLq8',
#  'en-dxJE3C5Pgys',
#  'en-UlnzoFdN954',
#  'en-hewyImnU_PU',
#  'en-w_XpXbpNjaI',
#  'en-d1xiFG08gjs',
#  'en-t7rWrKd8Ad4',
#  'en-h9Qm8Wn81Qc',
#  'en-YElYWYZYBsE',
#  'en-VZXvqQ1HUM0',
#  'en-IbwESjAIKIM',
#  'en-Od1s-yjzCk4',
#  'en-xSbralMSyL8',
#  'en-vdMGBCErqgs',
#  'en-6274TbjLkDI',
#  'en-YbU4xl3NPKY',
#  'en-ig-_8-DReig',
#  'en-M-EM8ZJR5TY',
#  'en-9K8SNO-JzzM',
#  'en-Bgj8gkOBno0,en-uYU-mmqFLq8',
#  'en-idzNd7o7AJc,en-uYU-mmqFLq8',
#  'en-Iab1tzXpOWE',
#  'en-Wzivx_W_sbs',
#  'en-lCdwCUkWeJc',
#  'en-Ycc3eL1B2yA',
#  'en-wbkKCiI2CMM',
#  'en-z5LQBEn4dek',
#  'en-pZZLShZpWcM',
#  'en-L3CV-TGVGgQ',
#  'en-ONET0Yaghao',
#  'en-XZJdMyFfkRg',
#  'en-3ikBRqOBHzg',
#  'en-lBFmVTJlG5U',
#  'en-cHH2Vv6QkUk',
#  'en-OobyRLDl1NE',
#  'en-s_gezPJHA58',
#  'en-0eQpfQgW5No',
#  'en-3fk7h0swSlQ',
#  'en-hJoysNUZZ7U',
#  'en-XYa62Rh3toU',
#  'en-zljFX1uHcD0',
#  'en-OcUZzOF9GkM',
#  'en-uYU-mmqFLq8,en-z7LZbhxneiw',
#  'en-A05o5yoyJLE,en-uYU-mmqFLq8',
#  'en-Yb3ad0LoV-g,en-uYU-mmqFLq8',
#  'en-nVStdFdGyZo,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-z6Cp3yGtK4o',
#  'en-stM_8fv3fe4',
#  'en-VcWfqzZUl2g',
#  'en-5OEB2XOeUUM',
#  'en-cWhQ94lMBLs,en-uYU-mmqFLq8',
#  'en-FXiSFqPbPqs,en-uYU-mmqFLq8',
#  'en-DhteUWac6pc,en-uYU-mmqFLq8',
#  'en-n-QYkRU47BE,en-uYU-mmqFLq8',
#  'en-Ap3T694wA6g,en-uYU-mmqFLq8',
#  'en-BM0WI_iALvk,en-uYU-mmqFLq8',
#  'en-RzgOMvnhUvI,en-uYU-mmqFLq8',
#  'en-BpqEfjDo2BA,en-uYU-mmqFLq8',
#  'en-kHNDB91_-QU',
#  'en-3U7Dqf--y-Q,en-uYU-mmqFLq8',
#  'en-jGvZftyZcEo,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-vGD_FQdQeLM',
#  'en-T9qhxQRJRmc',
#  'en-ulPx8tGYPGw',
#  'en-jnHY8P9_ks0',
#  'en-FFxRwzh0muQ',
#  'en-ArhI5MAV3NA',
#  'en-09Ux-9GNvKI,en-uYU-mmqFLq8',
#  'en-Rv828-gT8jc,en-uYU-mmqFLq8',
#  'en-e8JF94SJ4NQ',
#  'en-U0YbS-QWxd4',
#  'en-gsXMwymIud0',
#  'en-e_Xh7w9Epkw',
#  'en-2P9uztvhaeA',
#  'en-IeNvToZgHPg',
#  'en-0eZ0TCi15HI',
#  'en-qTlCOyMhOSw',
#  'en-kJfiWXfUCLU',
#  'en-tVVXmG2kB7g',
#  'en-uJHoRATdkm8',
#  'en-Qcc1GOdpamE',
#  'en-hUIoxyi-030',
#  'en-Wd5ne0NZlm4',
#  'en-SPZjhkhweMk,en-uYU-mmqFLq8',
#  'en-Axcy-8KW7e0,en-uYU-mmqFLq8',
#  'en-DtCDVLpE9O4,en-uYU-mmqFLq8',
#  'en-ofSVbU4YSJQ,en-uYU-mmqFLq8',
#  'en-NthDPQrGQAQ',
#  'en-XquW9nIuafg,en-uYU-mmqFLq8',
#  'en-uoLYTLJz9cA',
#  'en-iLuGeEx0xbk',
#  'en-3JhTMIiRCvg',
#  'en-ds50qUua7D0',
#  'en-FoTemYs0spk',
#  'en-z3-LawTILdw',
#  'en-q-Hi8ef2nGk',
#  'en-RJGMsfRKmMo',
#  'en-pUhGHX3gKk4',
#  'en-GB,en-ehkg1hFWq8A',
#  'en-i-Xj9hVqayE',
#  'en-zb626elTQfI',
#  'en-zrhEfMSreNI',
#  'en-mjBqq25IgRg',
#  'en-NyJtIHtZVhA',
#  'en-_UV89z7lq1I',
#  'en,en-DLxmEfVUC9A',
#  'en-GB-HREnMOppNQQ',
#  'en-QCotXvb3gqc',
#  'en-4_3WYQr9MRA',
#  'en-EWlhny-7MOA',
#  'en--ez3iVCnwCg',
#  'en-M6DkMKzioWg',
#  'en-GhBJkI-ZY6I',
#  'en-pUqyR1dH3z0',
#  'en-gqf8ywQ2sow',
#  'en-Jt9r_xG_fDg',
#  'en-xsdh2DrdsNs',
#  'en-yumAWoW7qWU',
#  'en-5eFA4iUleFw',
#  'en-J2TymM82MtI',
#  'en-clf6ljnzPtE',
#  'en-cGdqV1w3puY',
#  'en-b2Dj6g88f9c',
#  'en-2h3TFzHPqXs',
#  'en-fkRIyfeeA9w',
#  'en-Bs1qkbsohDQ',
#  'en-kK23sFf5UBg',
#  'en-K2FocqUpHRI',
#  'en-o5JzkzEIPbY',
#  'en-mP2Grm9Ss5w',
#  'en-tuKINWKc7CA',
#  'en-7-YRqxZY-jc',
#  'en-US,en-ehkg1hFWq8A',
#  'en-gY_yrt0x_8w',
#  'en-VKj_Zw7S2zI',
#  'en-QdaCGHhfh14',
#  'en-RYczKem2P_o',
#  'en-GDlQFzyoy3k',
#  'en-GQwauXgAcv0',
#  'en-fLe3xL7M3l8',
#  'en-uBTuqohGLvI',
#  'en-3QM-Ihr9bGQ',
#  'en-oUH2mtTh3i8',
#  'en-nnNTxpgfZCo',
#  'en-I8wvA-91FLs',
#  'en-jeRO6oyMib8',
#  'en-EMtBlLA2w_E',
#  'en-mkIqslO62RE',
#  'en-85vgYh-5Y4w',
#  'en-MUHkQi6Jj1s',
#  'en-rw12mh_SfIk',
#  'en-DzWYXXbsT4g',
#  'en-DBVgrKn_J2Q',
#  'en-p8nSjUMMvuc',
#  'en-mY6jaOMW3PY',
#  'en-TBD5uZH-UAE',
#  'en-iI3gF-Y9AAI',
#  'en-EipA9Y1I8h4',
#  'en-z7ILyPzY03I',
#  'en-KwtO0Ql93wA',
#  'en-7Px4sdc5n3E',
#  'en-i7LFIGUQP0g',
#  'en-P0tcqV_XoMw',
#  'en-ItWavQTbn9E',
#  'en-JBfyDMnnLCU',
#  'en-COr59TqeAPE',
#  'en--R-guCm8R6g',
#  'en-6p4UjyuXlSs',
#  'en-Lcy4KIe2XhE',
#  'en-NqLLpdiUBc8',
#  'en-PR2LyS0iiqY',
#  'en-KhWKOo0qF3w',
#  'en-5U1EGHNmTyY',
#  'en-ZzZt-22CG70',
#  'en-AzcRNGUccjw',
#  'en-7EXKh1JJ0ls',
#  'en-WMxZjK83e88',
#  'en-0E-uKd5Fs0g',
#  'en-Pam56VcfJwc',
#  'en-YYWuqi_RG-k',
#  'en-69I7iLY-3a4',
#  'en-zWeQYJZSa9I',
#  'en-_hYnLvTXczw',
#  'en-uEeDvB13UpI',
#  'en-gspU9OLearw',
#  'en-viWK5tKAY5o',
#  'en-pMl9FArDVss',
#  'en-AXwwrOrXLh8',
#  'en-vnl-vWORp4I',
#  'en-F2jLaidLhvw',
#  'en-6iulBvwACy4',
#  'en-NI3JxG4jWzo',
#  'en-UGVyG7Vq28g',
#  'en-RQ5ovr9l5BY',
#  'en,en-Z718QvEZyWc',
#  'en-5XR7eC0ZFeo',
#  'en-3RqRCbsr_xg',
#  'en,en-_MQS1NmgeQw',
#  'en-OrMU4aRBs8k',
#  'en-NKbu1RTbYuo',
#  'en-iQqhxWOvnbg',
#  'en-ITdJ2ruQ_Is',
#  'en-3UcICQ1-yA8',
#  'en-5FeuvWizfG8',
#  'en-Jljv6wib23c',
#  'en-r0AnDEQp_fg',
#  'en-oTp_B_xOvu4',
#  'en-VVRlss9RIU8',
#  'en-cXA6z0YDJuA',
#  'en-LPnVTah3NPQ',
#  'en-d3JHjS3jU64',
#  'en-YW1aiZ9-g60',
#  'en-US-YGQ902-g2TI',
#  'en-IUYXXmWEt8E',
#  'en-XxpTnCbIytc',
#  'en-D8dBMXirXhQ',
#  'en-Hz9YoeZmCxY',
#  'en-BAUxXoJBx7Q',
#  'en-eNrGvamCrqo',
#  'en-UbksbRvzyXo',
#  'en-1oAFzPNiuC0,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-FD6xoZsyAlw',
#  'en-gjixCfCnBvA',
#  'en-jRnxSnnJKsE',
#  'en-GB-8Mke0_njMzM',
#  'en,en-IE',
#  'en-t_rK2yKGuew',
#  'en-UwNGZaUp4Nk',
#  'en-_rgNrs8ZQd4',
#  'en-eq4NNW_4HrA',
#  'en-H4i0Z74JAMg',
#  'en-SL3JhRiwRdo',
#  'en-bdCIdPg1B-k',
#  'en--QfmURZHiTQ',
#  'en-DegjjUawlm8',
#  'en-hAJjRapOVVQ',
#  'en,en-slp2VzjvzuY',
#  'en-9gIChYjjc9I',
#  'en-CVDiK9g50bs',
#  'en-okvGocAgwdk',
#  'en-w0I42LU0b2k',
#  'en-5UsapxdRFf8',
#  'en-rE8lCltoHlw',
#  'en-C_fBn36sO_o',
#  'en-vr3ZgywzNpA',
#  'en-gAYYlDAlMV8',
#  'en,en-anMIXjicSL4',
#  'en-GB-xtDBcRnqi9Q',
#  'en-g0bN4mhb0hs',
#  'en-87T3pm9SGDM',
#  'en-vXfWBg8Pqq8',
#  'en-Od8H0Ugbovk',
#  'en-vmz9EZNj_jY',
#  'en-KiF8PLhXDeA',
#  'en-tjXMsETQXaE',
#  'en-z7V-MSjyksA',
#  'en-S3pdBb-CH08',
#  'en-EP2_IH4RNQY',
#  'en-CA,en-GB',
#  'en-Qmus90MA7kU',
#  'en-BtgOsMULSaU',
#  'en-2XqNNQ0SglU',
#  'en-h7RozCqfl1I',
#  'en-LG8d_i9VuVg',
#  'en-x4JPPU1fey8',
#  'en-GB,en-LG8d_i9VuVg',
#  'en-s7xBf6vQ5LM',
#  'en-n9AlwhLaAlE',
#  'en-WfEfoHUd5QE',
#  'en-0zfjSeGzKME',
#  'en-WIECNI8hvGc',
#  'en-MD7z0qR4F_g,en-mSoz6_ISHv8',
#  'en-cYotUUH_ne0',
#  'en-3pK74FgVxOs',
#  'en-jJhZPlUrNCo',
#  'en-W7D_rH2z_y8',
#  'en-ilDNOedWomQ',
#  'en-DBKy2q3Vaj4',
#  'en-JkeT_87f4cc,en-uYU-mmqFLq8,en-zL_pKPa_d08',
#  'en-A9bSQE2doEM',
#  'en-VZQDQwedvKw',
#  'en-XdJbaBj1uRs',
#  'en-rAB9mvXiy_k',
#  'en-pdfOssWbjO4',
#  'en-2PqpQm6lhas',
#  'en-Skcuu5dovbQ',
#  'en-BI_H8fHGEws',
#  'en-WR81p6BYZBg',
#  'en-5mF1M-yAtaA',
#  'en-2G0bp8YxGws',
#  'en-anM8ms4cips',
#  'en-eEL_dW8EI4k',
#  'en-Glkapzp1npw',
#  'en-W1a5XUwgNpE',
#  'en,en-US-8yztapuhZMQ',
#  'en-ZDIZLd0TxZ4',
#  'en-_wo7fz2u8EA',
#  'en,en-x_yxDECDNlQ',
#  'en,en-O7lMj7lDYkQ',
#  'en-rxsI4JzibH4',
#  'en-cKSc6s98mtQ',
#  'en-whyRX1JI64w',
#  'en-B-aJ56r1SFg',
#  'en-xiKGd7TT90g',
#  'en-l3Tlt9MJgXY',
#  'en-JsFt_iul1zU',
#  'en-La0keTR7_Pw',
#  'en-K83W_w3D6DM',
#  'en--wekYWsJexA',
#  'en-qUDwV093yHw',
#  'en-DUiGB2B0BrI',
#  'en-tjfWAt_T5jg',
#  'en-DuL8Rh9qgXY',
#  'en-r1sv6oAp6j0',
#  'en-mrPbNs1k-xM',
#  'en-BIYDkt-ixA4',
#  'en-KGDwxvm6OD0',
#  'en-VboTa6TI5jk',
#  'en-a0nESNfPRAE',
#  'en-Bq1w29tYyIw',
#  'en-Uz4xcAVwOGc',
#  'en-zjT3E6tEukw',
#  'en-tXnlHtoo830',
#  'en-bTEEku7m_dI',
#  'en-RFfUQIcK1tQ',
#  'en-LZg5jBUGuhg',
#  'en-hzkUZk8SLLc',
#  'en-koWG0Cdscjc',
#  'en-irkgdZGKe_0',
#  'en-XRrE9oflpbU',
#  'en-UJFdZw25Jdc',
#  'en-FgNQ6gnITdM',
#  'en-S9eLTse3JGw',
#  'en-QUQY448TsWc',
#  'en-3E88c8m_-SA',
#  'en-pK8Av3W7mj0',
#  'en-HoKbdB4Dzo4',
#  'en-W3H6IVN677s',
#  'en-9Xdcvl7IH6I',
#  'en-ePZrFTdGZoQ',
#  'en-i5kVHc3lf-U',
#  'en-q-Xiya00Df0',
#  'en-z0T8M3jsoU0',
#  'en-jf7xKtvxgLM',
#  'en--BbGSwzns0s',
#  'en-0agDWbfTB_I',
#  'en-wM-1q7pMLrI',
#  'en-ONFNSJSopns',
#  'en-lX9jl0kvZfs',
#  'en-ftylmGiorMU',
#  'en-pi34-gP0-qk',
#  'en-smFHrho8E_Q',
#  'en-Ixyetto8H3Q',
#  'en-aSY2uweTGnI',
#  'en-Dcru9dW5ODM',
#  'en-WGOd9r5UQuI',
#  'en-8kZLnIB6dFI',
#  'en-XUp_RpzxaUo',
#  'en-gwKGy7jbExw',
#  'en-T-iV2Vc9ehU',
#  'en-m6UlexV5PgI',
#  'en-V2YjA2e6Fyo',
#  'en-TsqtZXIWL0g',
#  'en-9Pux1EfLFnE',
#  'en-US--N8GEju60NE',
#  'en-VzJZ2D_l_ls',
#  'en-L-XHGaFuMC0',
#  'en-dzJ4Lf5JT0A',
#  'en-Zvyn-r40YsU',
#  'en-j4VkGyWwQv0',
#  'en-j0pxzQv08Ak',
#  'en-lzoA4I-_t5w',
#  'en-sMU_b-kxkdQ',
#  'en-ciZSKPjj5rA',
#  'en-2bxU0UIufCQ',
#  'en-fkqKbO096WE',
#  'en-2UQqoD9FHzk',
#  'en-V6i59PheuiQ',
#  'en-pl-_xl-0R3M',
#  'en,en-CYLbD2oks0A',
#  'en-GB-I3Gx6yWtFIU',
#  'en,en-KpaL35C_-HI',
#  'en-f36Xvv2vzjQ',
#  'en-onfSNiZjPxU',
#  'en-JqoeKhp1TL4',
#  'en-7YCFbWGMOFU',
#  'en-koc11vLGO-4',
#  'en-xsbwZ6Pq2c4',
#  'en-ENncpMFwm2U',
#  'en-gdn8-xps-JE',
#  'en-AXs3i2UoW1A',
#  'en-EM-BgM-Qqj8',
#  'en-w6WvNZBbuYE',
#  'en-pAHgNybY8WI',
#  'en-GTssHSoeDGo',
#  'en-Tl0ZgSThE5Q',
#  'en-kwA0cidvQrg',
#  'en-QnTdjL2_qUI',
#  'en-lTcNyPIB5U4',
#  'en-qAB5Fq03yBw',
#  'en-xV7KiDBj6Fg',
#  'en-tAQ4hImcKYA',
#  'en-uJDqTZqIpmE',
#  'en-rBr0ouVbIOY',
#  'en--UH-iNULyHo',
#  'en-qa9qbEes5cg',
#  'en,en-j7St9X4Tetw',
#  'en,en-6aBbT7oRxLM',
#  'en-vRZYVqSZfRI',
#  'en-n4HivAs74FI',
#  'en-bpsZiO6Z6z0',
#  'en-5m06k7pTjso,en-eEY6OEpapPo',
#  'en-Fd4hxnCufD8',
#  'en-pq_E5OO3DMc',
#  'en-PtLxtQKJUe8',
#  'en-m-XBGA6iMgQ',
#  'en,en-AU',
#  'en,en--Os4ayKvP8k',
#  'en-YzjTkubKa6s',
#  'en-D4Em8AAJKTg',
#  'en-RtQ3btr4J3w',
#  'en-bpcHtLLHgbY',
#  'en-pJiaWBX8SGg',
#  'en-XC-n5_xFQhU',
#  'en-IYi0QQw2yb8',
#  'en-GyZ2GcSBLMQ',
#  'en-U3rlr0shWvg',
#  'en-Dc642RRnt6w',
#  'en-TUoASCAVR04',
#  'en-vKqGZxjE-X4',
#  'en-lWQ7bK81pqg',
#  'en-vAf3QoYfjS4',
#  'en-hdzLK19xFbc',
#  'en-GB-lWQ7bK81pqg',
#  'en-hrRiEqQrYMk',
#  'en-VZaPj70E-cQ',
#  'en-ZbwDLHY73wk',
#  'en-VRQZutW6exs',
#  'en-Mc-l5KuhysI',
#  'en-0hllRZe4s5s,en-iGJpuh49ngc',
#  'en-yKueVqfHYdU',
#  'en-8zkrV7GAeQg',
#  'en-I4NqW1OuItw',
#  'en-PHizVQKyaT8',
#  'en-6GcSGw81TyM',
#  'en,en-GB,en-IE,en-IN',
#  'en-LZLVDZ90HJg',
#  'en-rdGFSo6YWYw',
#  'en-uaodlqUtGlk',
#  'en-j7CkrLLB2No',
#  'en-3pag1knAp8U',
#  'en-cEVAqP0f_G0',
#  'en-S3doMV87xA4',
#  'en-JxeEcfLEAZw',
#  'en-ZyY-uO77toM',
#  'en-I8U16adu9Ao',
#  'en-yUGZRbwkFHY',
#  'en-wVtCXo_byE0',
#  'en,en-8juMyiLfTHE',
#  'en-jzS_7j95uRA',
#  'en-GB-0ukLhsivnNw',
#  'en-xp8wTkmrYBk',
#  'en-zHAsX2OD_Ck',
#  'en-aVFqY5T1TS0',
#  'en-US,en-anMIXjicSL4',
#  'en,en-jwR4iCu2oeQ',
#  'en,en-GB-rSJfcHgCuhE',
#  'en-NSlS7dtTG5o',
#  'en-6ei4hcl37co',
#  'en-SP4rODexMfI',
#  'en-PYsvNJU8zrc',
#  'en-5EatZTF0P8E',
#  'en-yv1qnlVLzoQ',
#  'en-ERHTqSDmRBA',
#  'en-CA-ym5edNzE7Ow',
#  'en-XO6biEujy9M',
#  'en,en-UAf0XEz263s',
#  'en-LHfzsWHceM8',
#  'en-TRqv_jJCFUc',
#  'en-d9EZkvuWXSY',
#  'en-yxUYmUNzXbA',
#  'en-ugpt3ZTHNpg',
#  'en,en-fmYsiOyK3-g',
#  'en-9feNz6QFbwo',
#  'en,en-ta2EIo-0Agw',
#  'en-_0blXBczMBo',
#  'en-eqP-X6xk9NE',
#  'en-v8dpQGAc-d8',
#  'en-6hIILe6Z3Qs',
#  'en--ZoC_Py8hU4',
#  'en-Kz2KN9hZJG0',
#  'en-wjj9m-wANHQ',
#  'en-tFFT0E3L5KY',
#  'en-A19OKdotbTE',
#  'en,en-gbiht3Bo0G4,en-lKWUz2CgtmE',
#  'en-GB-eEY6OEpapPo',
#  'en-7bo4ePph0HE',
#  'en-e0ONNn-Kl-w',
#  'en-LjR8n7Lz-p4',
#  'en-k_wf--qsiAA',
#  'en-US-Iiw-2QMjdD8',
#  'en-EQQL0p207Jk',
#  'en-GnmjnzQ_IiQ',
#  'en,en-CA,en-IN,en-US',
#  'en,en-IN,en-US',
#  'en-Cz1sVjP1r1o',
#  'en-k-RbSZKoSCk',
#  'en-pnZHtGsjvhY',
#  'en-HlcGwNfXzkU',
#  'en-US-zOFsReYi2c4,en-nP7-2PuUl7o',
#  'en-eEY6OEpapPo,en-nP7-2PuUl7o',
#  'en-GB,en-nP7-2PuUl7o',
#  'en-E-ab62m56P0',
#  'en-DwjU7rTr-pQ',
#  'en-Aq89wfGisj4',
#  'en-mIBiXa3O-aM',
#  'en-GB-Rj6tISS247k',
#  'en-IE,en-IN',
#  'en-yU1tISHR1cU',
#  'en-vlqMvZ_EagY',
#  'en-XFdwTH7buVA',
#  'en-US-b3nrla8N478',
#  'en-_yASqOZhnrs',
#  'en-yPS3IiLDWzY',
#  'en--xcNaj9_GHs',
#  'en-5b2-yZHucJo',
#  'en-WVU3oZ6sBt8',
#  'en-US-nPk3V-duwf8',
#  'en-aOBkoefI5-4',
#  'en-GB,en-GB-eEHGWr0Dx3k',
#  'en-mA7n3IYAKQ8',
#  'en-bVoBjau-9u8',
#  'en-6AFV7OuUDIk',
#  'en-9LnJK7YkjGQ',
#  'en,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en,en-CA,en-GB,en-US',
#  'en-CA,en-GB,en-US',
#  'en-0yHdmxR001I',
#  'en-hPGx1GpLXXM',
#  'en-M-wMdNpa-sk',
#  'en-GjwumeVy7HE',
#  'en-GB-sMbCfrtAnXE',
#  'en-XKJ3-9EPpfo',
#  'en-wDaok4uyq2c',
#  'en-6PYU4BfXJRw',
#  'en-Mm-WBSbQgVg',
#  'en-kuJ60RHvJe8',
#  'en-QLSqRHAqJSA',
#  'en-1oAFzPNiuC0,en-uYU-mmqFLq8,en-zL_pKPa_d08',
#  'en-NmRnE_m57ik',
#  'en-UmuJL7B34v8',
#  'en-GB,en-IN',
#  'en-tPYWh49b7dY',
#  'en-16blpPmVDXw',
#  'en-JkeT_87f4cc,en-WhMMu4FR6EA,en-uYU-mmqFLq8',
#  'en-D5BAJqcz8o0',
#  'en,en-GB,en-US',
#  'en,en-mTWoFxlQXE4',
#  'en-Vz6lb-KycrM,en-frRR1ShdaF0',
#  'en-zwzribV5jpg',
#  'en-9upq1y_Il_w,en-uYU-mmqFLq8,en-zL_pKPa_d08',
#  'en-mqEgSABiK3A',
#  'en-w2A1RLSdsBo',
#  'en-4EAJVydkbtI',
#  'en-iw-hPWzcsKk',
#  'en-5Y4u1IzkH2A',
#  'en-M3FTz6BDvH4',
#  'en-sAXuvQpvP94',
#  'en-i6PQtgqa41g',
#  'en-_BZ0tSw-zX4',
#  'en-kVgEwsc-Yzw',
#  'en-etK2C2H8QxQ',
#  'en-gYFX_jzdutk',
#  'en-LowWcOfbRz0',
#  'en-xp7AIyTVSDM',
#  'en-PiSUR-H3p-A',
#  'en-7coGiDq3oJE',
#  'en-oeetDVbazqM',
#  'en-Pobwd6b-BQI',
#  'en-opvMIlCf6yU',
#  'en-ne1kkAzzDEo',
#  'en-l9ZAytQDX8s',
#  'en-AVI3SstIgVg',
#  'en-US-3pK74FgVxOs',
#  'en-EKy-uLtZUwM',
#  'en-AzINBuNud_A',
#  'en-QhNKIcv0o9w',
#  'en-uV_xnKPqpTA',
#  'en-Xq4d7oZ7WUs',
#  'en-40ni5xyRDYc',
#  'en-3JZJhEiiEO0',
#  'en-apj47bPOE6E',
#  'en-0n_kkREWipc',
#  'en-iroYDGvjVPs',
#  'en-qABeYVmG2T8',
#  'en-tWoY4OrN9Ro',
#  'en-75HoPQdITQk',
#  'en-E40TfOK3xzE',
#  'en-KF5XjG2vvvs',
#  'en-LEq064LOwdU',
#  'en-SRUAhgHqNeM',
#  'en-7uKXVR-sleM',
#  'en-MUKFLdkALs8',
#  'en-Easc7SnxoFA',
#  'en-sMO8DSWpiJw',
#  'en,en-YME_-BQi2ZM',
#  'en-ZRr7aanC-Bg',
#  'en,en-ukxnAB508a8',
#  'en-ce1CQ-vJEQM',
#  'en-DAVCo9jsrrQ',
#  'en-M8YHoxz5ms8',
#  'en-PDEGDhA4w_4',
#  'en-ycXGX7SvnPk',
#  'en-QFGQiasiaDw',
#  'en-VCBnncJ4KZ4',
#  'en-35qsMs3jRUM,en-Jyun0WSqg2k',
#  'en-1ECGQ8y9foM',
#  'en-hCy5EFxFrxQ',
#  'en-J9ntHtLQLhQ',
#  ...]

# %% [markdown]
# ### Getting metadata on audio-transcript pairs that have been downloaded (and trained on)

# %%
with open("logs/data/download/trainable_ids.txt", "r") as f:
    trainable_ids = [line.strip() for line in f]

# %%
trainable_df = main_df_dedup[main_df_dedup['id'].isin(trainable_ids)]

# %%
trainable_df.head()
# Out:
#              id                                              title  duration  \
# 1   3TwThCtZGVI                                    Etsy Commission       313
# 3   fG3DqJ_YqAs   PANGANDARAN SAAT INI | DRONE VIEW | DISAAT MALAM       781
# 33  sndzyEYbmTA                                MYO Pointillism Art       112
# 56  kWpOGMfmyFI  Write Code Save Lives:  Digital Innovation for...       831
# 57  4H2n-qfwvZ8  SUNY Downstate Medical Center / University at ...       310
#
#     view_count            categories  comment_count  like_count  \
# 1        133.0        People & Blogs           53.0        19.0
# 3       1024.0        People & Blogs           13.0        47.0
# 33        54.0         Howto & Style            NaN         0.0
# 56      2222.0  Science & Technology            NaN         2.0
# 57       725.0  Science & Technology            NaN         2.0
#
#                                 channel                channel_id  \
# 1                                 Wajas  UCrfdGNBnkDd0rOh1M9mdmaQ
# 3                          CIAMIS 46211  UCCwrY8WB54qY-jI7hXJsh3g
# 33        Roanoke County Public Library  UCRDIW4cJil7ls67SLQs9a4Q
# 56  Fogarty International Center at NIH  UCcSRJ6pWh8fvQVxwJMAEfWg
# 57  Fogarty International Center at NIH  UCcSRJ6pWh8fvQVxwJMAEfWg
#
#     channel_follower_count  ...      abr      vbr         vcodec      asr  \
# 1                   1680.0  ...  128.038  128.038    avc1.640028  48000.0
# 3                  19300.0  ...  137.007  137.007    avc1.640028  48000.0
# 33                   217.0  ...  123.075  123.075  vp09.00.50.08  48000.0
# 56                   171.0  ...  107.520  107.520  vp09.00.40.08  48000.0
# 57                   171.0  ...  135.472  135.472            vp9  48000.0
#
#    audio_channels                                           chapters  \
# 1             2.0  0.0,79.0,Intro\n79.0,109.0,Lesson Learned\n109...
# 3             2.0                                               None
# 33            2.0                                               None
# 56            2.0  0,135.0,<Untitled Chapter 1>\n135.0,419.0,Stan...
# 57            2.0                                               None
#
#    manual_caption_languages  automatic_caption_orig_language  location  \
# 1                        en                               en      None
# 3                        en                               en      None
# 33                       en                               en      None
# 56                       en                               en      None
# 57                       en                               en      None
#
#     license
# 1      None
# 3      None
# 33     None
# 56     None
# 57     None
#
# [5 rows x 34 columns]

# %%
trainable_df.reset_index(drop=True, inplace=True)

# %%
def write_df_to_parquet(df, output_dir, rows_per_file):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    num_rows = df.shape[0]
    num_files = (num_rows + rows_per_file - 1) // rows_per_file  # Calculate number of files
    
    for i in range(num_files):
        start_row = i * rows_per_file
        end_row = min(start_row + rows_per_file, num_rows)
        subset_df = df.iloc[start_row:end_row]
        
        # Write each subset to a separate parquet file
        file_name = os.path.join(output_dir, f"subset_{i}.parquet")
        subset_df.to_parquet(file_name, engine='pyarrow')  # 'pyarrow' is commonly used as the Parquet engine

        print(f"Written rows {start_row} to {end_row} into file: {file_name}")

# Define parameters
output_directory = 'data/440K_metadata'
rows_per_file = 600000  # Change this value based on your file size requirement

# Call the function to write DataFrame into multiple parquet files
write_df_to_parquet(trainable_df, output_directory, rows_per_file)
# Out:
# Written rows 0 to 600000 into file: data/440K_metadata/subset_0.parquet
# Written rows 600000 to 1200000 into file: data/440K_metadata/subset_1.parquet
# Written rows 1200000 to 1800000 into file: data/440K_metadata/subset_2.parquet
# Written rows 1800000 to 2300152 into file: data/440K_metadata/subset_3.parquet

# %% [markdown]
# ## Generating Statistics

# %%
captions_0_df = pd.read_parquet(metadata_files[0])
temp_df = clean_df(captions_0_df)
get_duration_ml_t(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# (449872.3247222222, 163173.4663888889)

# %%
captions_1_df = pd.read_parquet(metadata_files[1])
temp_df = clean_df(captions_1_df)
get_duration_ml_t(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# (468788.4372222223, 161794.45944444442)

# %%
captions_2_df = pd.read_parquet(metadata_files[2])
temp_df = clean_df(captions_2_df)
get_duration_ml_t(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# (463617.8672222222, 167049.53333333333)

# %%
captions_3_df = pd.read_parquet(metadata_files[3])
temp_df = clean_df(captions_3_df)
get_duration_ml_t(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# (471860.9663888889, 152873.61833333335)

# %%
captions_4_df = pd.read_parquet(metadata_files[4])
temp_df = clean_df(captions_4_df)
get_duration_ml_t(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# (461073.8111111111, 172368.21916666668)

# %%
captions_5_df = pd.read_parquet(metadata_files[5])
temp_df = clean_df(captions_5_df)
get_duration_ml_t(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# (450831.0725, 156993.89027777777)

# %%
captions_6_df = pd.read_parquet(metadata_files[6])
temp_df = clean_df(captions_6_df)
get_duration_ml_t(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# (453780.5527777778, 171731.0841666667)

# %%
captions_7_df = pd.read_parquet(metadata_files[7])
temp_df = clean_df(captions_7_df)
get_duration_ml_t(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# (451183.7258333333, 151748.9525)

# %%
captions_8_df = pd.read_parquet(metadata_files[8])
temp_df = clean_df(captions_8_df)
get_duration_ml_t(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# (445482.2472222222, 183320.50694444444)

# %%
captions_9_df = pd.read_parquet(metadata_files[9])
temp_df = clean_df(captions_9_df)
get_duration_ml_t(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# (448018.40305555554, 174166.63444444444)

# %%
captions_10_df = pd.read_parquet(metadata_files[10])
temp_df = clean_df(captions_10_df)
get_duration_ml_t(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# (588.0472222222222, 58.34777777777778)

# %%
449872.3247222222 + 468788.4372222223 + 463617.8672222222 + 471860.9663888889 + 461073.8111111111 + 450831.0725 + 453780.5527777778 + 451183.7258333333 + 445482.2472222222 + 448018.40305555554 + 588.0472222222222
# Out:
# 4565097.455277778

# %%
163173.4663888889 + 161794.45944444442 + 167049.53333333333 + 152873.61833333335 + 172368.21916666668 + 156993.89027777777 + 171731.0841666667 + 151748.9525 + 183320.50694444444 + 174166.63444444444 + 58.34777777777778
# Out:
# 1655278.712777778

# %%
4565097.455277778 + 1655278.712777778
# Out:
# 6220376.168055557

# %%
temp_df = clean_df(captions_0_df)
get_duration_en_only(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# 566697.6641666667

# %%
temp_df = clean_df(captions_1_df)
get_duration_en_only(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# 574250.731111111

# %%
temp_df = clean_df(captions_2_df)
get_duration_en_only(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# 551560.5

# %%
temp_df = clean_df(captions_3_df)
get_duration_en_only(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# 572103.6394444444

# %%
temp_df = clean_df(captions_4_df)
get_duration_en_only(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# 566707.5469444444

# %%
temp_df = clean_df(captions_5_df)
get_duration_en_only(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# 580833.2383333333

# %%
temp_df = clean_df(captions_6_df)
get_duration_en_only(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# 569279.4233333333

# %%
temp_df = clean_df(captions_7_df)
get_duration_en_only(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# 563446.2297222223

# %%
temp_df = clean_df(captions_8_df)
get_duration_en_only(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# 550060.0961111111

# %%
temp_df = clean_df(captions_9_df)
get_duration_en_only(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# 562896.7374999999

# %%
temp_df = clean_df(captions_10_df)
get_duration_en_only(temp_df)
# Out:
# all dialects have been changed to strictly family language in manual_caption_languages
# all dialects have been changed to strictly family language in automatic_caption_orig_language
# all dialects have been changed to strictly family language in language
# 420.2072222222222

# %% [markdown]
# ## Is number of hours proportional to number of audio-transcript pairs? As in, can you estimate the number of hours from number of audio-transcript pairs?

# %%
# calculating total duration from all trainable audio-transcript pairs
df_list = []
total_dur = 0
for parquet in glob.glob("data/440K_metadata/*.parquet"):
    df = pd.read_parquet(parquet)
    df_dur = sum(df["duration"]) / (60 * 60)
    total_dur += df_dur

# %%
total_dur
# Out:
# 411584.1433333333

# %%
# calculating total duration from all audio-transcript pairs subsampled randomly for downloading and training
with open("logs/data/download/sampled_en.txt", "r") as f:
    durs = [int(line.strip().split("\t")[-1]) for line in f]
sum(durs) / (60 * 60)
# Out:
# 438202.3872222222

# %%
# if 438202 hours correspond to 2448500 audio-transcript pairs, then how many hours correspond to 2300152 audio-transcript pairs?
est_total_dur = (2300152 * 438202.3872222222) / 2448500
print(total_dur, est_total_dur)
# it looks like they're quite close, so it seems that the duration of the subsampled audio-transcript pairs is quite 
# representative of the total duration of all audio-transcript pairs
# but let's check again...
# Out:
# 411584.1433333333 411652.8884516924

# %%
# getting the video IDs after best filter
with open("logs/data/download/filtered.txt", "r") as f:
    filtered = [line.strip() for line in f]
filtered
# Out:
# ['pkp_MM22ivE',
#  'q7QPE66HoNY',
#  'qHeOWpL7uCI',
#  'qJoGRiG_iOQ',
#  'qPUT1ovOqjc',
#  'qPWWtUwRYlY',
#  'qQbULMp2RFo',
#  'qS3njdnQ29g',
#  'qSMPGxovMi0',
#  'qSj6m7ZHUmE',
#  'qZfmbaSz_yg',
#  'qzaWJXGmDnE',
#  'rCahxo8uEIU',
#  'rD6Y9Rvef7w',
#  'rH09pwsMIYQ',
#  'rLu4-1d9Qe4',
#  'rR29J6-8b_4',
#  'r_JTowo-E1s',
#  'sBFsqZW01Ds',
#  'sHXDknsO1DA',
#  'sMYQCT7GPiI',
#  'sSzU11S1e0o',
#  'sUw117HHuQM',
#  'snod06rCcZc',
#  'tBslHCACu20',
#  'tFwd_m5U-pw',
#  'tG1Ai-oIYB8',
#  'tK7bKhFvcP4',
#  'tL3nd6ltJf4',
#  'tPt5Bc-FYY8',
#  'tc6zpF_jXFM',
#  'tdkBABj5TJg',
#  'tnSOdcWzozM',
#  'tunQASBB9FA',
#  'tuvrW998tko',
#  'tyHAVBBp0iw',
#  'u6NfqReEnuc',
#  'uQpbEjdCDLQ',
#  'ufgd1tgZk5A',
#  'v5FXsOqCJhw',
#  'v8-YdYtv4hE',
#  'vK9B_6PgGek',
#  'vLyrce6NdF0',
#  'vNogT4RDw3I',
#  'vO9Qos87aYg',
#  'vYtoQlQIxqU',
#  'vaTJzRB7DLg',
#  'vfFzwBd6HAs',
#  'vkDkfJEWRUY',
#  'vkFnM5Xad24',
#  'vlUveFSZxUU',
#  'vzFYhtQLBpA',
#  'w-QuumiO0Fw',
#  'w2nhb7Js7lw',
#  'w4NX46wjbdQ',
#  'w90sTQt6_dQ',
#  'wA_2NxFuWM0',
#  'wFQu7CFAtX4',
#  'wPLW6ZfCUlM',
#  'wQephUzleVg',
#  'wQqpC4A2xbA',
#  'wRjRiLOluk4',
#  'whFecU62SyE',
#  'x0FyAB-zwXU',
#  'x7QRjoetS9Y',
#  'xFUjdEEH3lk',
#  'xK0U4YUVC3A',
#  'xO3uOIH-3uk',
#  'xcu8bJHJZAE',
#  'xnU2is3SvZU',
#  'xqw50ZK4bQI',
#  'y01tvqBhSqo',
#  'y57TLT5gJ94',
#  'yAp8szh1ycE',
#  'yFQBJcV_dqg',
#  'yG5Iooz8f_g',
#  'ySh1m6It0-g',
#  'yXqv5BBxAL8',
#  'yeM4NnYIGwM',
#  'yh35w7Qojt4',
#  'yp_NoA16pzU',
#  'ys35X0p7pS0',
#  'yyR6QcS8kQQ',
#  'yzPxplTbvFI',
#  'z2pZZjq97kY',
#  'zILWSdNWjXU',
#  'zRWG0fZB1Oc',
#  'zRqXJbSUGT4',
#  'zWL5J5Zd0Rw',
#  'zcuos1Yxrzs',
#  'zlBm7uaUeKE',
#  'zqnLGKSSROk',
#  'zzQDhN2GNRk',
#  '-jb27NXdBaY',
#  '-lfjsdz9aqM',
#  '-mGQCnQ0i-I',
#  '-n9VvhlZKog',
#  '-qE39VGpPas',
#  '-teS9IgVTvY',
#  '-v2WifVnEIM',
#  '-ve-AI0x6eg',
#  '-vtfJdUk4Wk',
#  '-xvSxS1_gUM',
#  '-z8CnwnrqLQ',
#  '003iUexO69k',
#  '0BW6Z-7ZTOw',
#  '0H7oQCUl0cw',
#  '0PuF-tYIwrI',
#  '0Yt1N21pFxU',
#  '0dMT6sCixYM',
#  '0eeir-Bc0Vc',
#  '0g7VK0W4jPE',
#  '0m75-vsX7wM',
#  '0oeUPkok79k',
#  '0q1ZDlre0M8',
#  '0sKswNz0pjU',
#  '0wTu9aAoJB4',
#  '1ZomexiSol4',
#  '1_JF3Qla_RU',
#  '1eGrOilmIfk',
#  '1fx-l4ymjQ0',
#  '1g22UgARzJg',
#  '1kSQoQDOpvQ',
#  '1tZ24chBUFE',
#  '1u4e3bGxCv0',
#  '21f4BnXZ16A',
#  '25HmFwz__sQ',
#  '297rtdEvsAk',
#  '2BQ7ZnpZP64',
#  '2R-SqtAhkj8',
#  '2mWweuJwNAo',
#  '2oYWS4ArIyU',
#  '2r7mCbD5ehY',
#  '2y4XIGgr_f8',
#  '2yt2YHcBkLw',
#  '2zxH1JGSRSI',
#  '3Jq-xxOLouY',
#  '3NipCBgg-JM',
#  '3ZScOw3c8Xk',
#  '3o6Ddw2nlRM',
#  '3wQ4G0ylrNE',
#  '43IfY6ek3KA',
#  '43w6AKVLTTg',
#  '48Jz-RlK-_c',
#  '4Q52uF3uv7s',
#  '4f-I2mfdcos',
#  '4hJvNk6fIuc',
#  '4o8XXPqKh3M',
#  '4p6q4m2OLew',
#  '4x9-Y9RpqBY',
#  '51txezozwMA',
#  '5_PFwkRQEwc',
#  '5cFtNgHLJMw',
#  '5dntf8e0q1M',
#  '5fH3W17qLLM',
#  '5wxD91Lk2Hk',
#  '63uSl0J1oJM',
#  '68yXJy-mTow',
#  '6ESgzi8NBHo',
#  '6QFEcF4Kwdg',
#  '6Qzpq0mXbO0',
#  '6TgTR234OrU',
#  '6iUcBJ7MHf0',
#  '6j_1C_n8if0',
#  '7IyFCBSqbYU',
#  '7OudWESkyg4',
#  '7TQK9roXk2o',
#  '7aY2z8mzypc',
#  '7j13qt3l6hc',
#  '7olO0fkHdoA',
#  '8-3UKn1GQTs',
#  '8-C9Z5z3R6Q',
#  '8EaUW532acQ',
#  '8OAbX3PquOI',
#  '8QmtTd_rdu8',
#  '8RxZOAMBcQ4',
#  '8uNxJZ_9WjM',
#  '95s-PgQuFt0',
#  '96pAfazv9Tc',
#  '9BSH563kNSk',
#  '9l8mJZfPztQ',
#  '9t6LQCEhMZ4',
#  '9yh9F6JQ1c8',
#  'A9c_gDmaH28',
#  'AAQnMSVX9jY',
#  'AAi8C91qPUo',
#  'AD9UwsWHIKI',
#  'AEGheH8mx98',
#  'AOT6KqSBaeI',
#  'AcfPrU98xyU',
#  'Ah5KoA3qH-0',
#  'Ai_yHwsHSvs',
#  'AsjaGQfCfv4',
#  'Av9aOI--0ZI',
#  'BTCUUo3LL-A',
#  'BmGyhFOi47Y',
#  'Bmb6PfwtQXc',
#  'BrNaQf1ce68',
#  'BwOqxocx13g',
#  'C1y8VmluIaE',
#  'C5FKJw2LXC8',
#  'CCtg8HKEWnY',
#  'CEmQiAhKoUs',
#  'CG2bq9gCjDg',
#  'COJSCeQcZdk',
#  'CY5oa_ps0wg',
#  'CkBi6sKUxs8',
#  'CvaA83lKUl0',
#  'D-HpTVALxVg',
#  'D9D3NGSfJ6o',
#  'DNMw82qJ1Vk',
#  'D_9e_XqbqLM',
#  'EAMCl7iTmBs',
#  'EC_8LX5TzcA',
#  'EGmKaaf4YrM',
#  'ERA7OfCqT9Y',
#  'EbT7Tjz9O9A',
#  'EcJNP5BQHLo',
#  'EjYeB8WZFOs',
#  'Es52rHM_gyo',
#  'Ew0ltTiDmeM',
#  'F1Hz-yj2AI0',
#  'F3N7eFCbM5c',
#  'F8_tUJq9a6U',
#  'F9F_I75kZNA',
#  'F9qH2tuUFJ0',
#  'FBk82RFGCw8',
#  'FEScFlOBZfM',
#  'FFtSD53hNAk',
#  'FKMUeRffJOs',
#  'FWdABCwn4vo',
#  'FYYIh2kyB7g',
#  'FtoLTmoBp-w',
#  'GBmKRy3SqU4',
#  'GDZnDU-DCa0',
#  'GKCcKoLrMCs',
#  'GOT-k_J_1ko',
#  'GVGK6BkEFvg',
#  'GpqYL429spo',
#  'Gv-639c_A9k',
#  'GwmkHdPUl_k',
#  'H0BS4hngTFo',
#  'H1_6khTWE4s',
#  'H3jMPIzNSU4',
#  'H7U8dW1GQUs',
#  'H86jn0XmFwQ',
#  'HJFvvac4REQ',
#  'HLpck32Hc0k',
#  'HeOYf-a9PpI',
#  'HjherMqCsfE',
#  'HvzQ-6XZkzc',
#  'I150Uixseuk',
#  'I7EkB_wdsLc',
#  'I7MBbvqcKuI',
#  'INDWAMbdTaw',
#  'IYocl1c98F0',
#  'Ib0lObHUn44',
#  'Ih-nzxPTizc',
#  'IjtNyFxXevw',
#  'IvPMQVmHmmE',
#  'JKrHWo4nHPg',
#  'JLvZEdpi5_A',
#  'JMsWBEP-LlI',
#  'JUEOwCyL5Rg',
#  'JWTlhUEO3nE',
#  'JX3Qe_VDlO8',
#  'JanXdh4IHV0',
#  'JnQYKa30bwM',
#  'KBjXm9rnKjM',
#  'KKKtlrkgVPQ',
#  'KKsROi2VdfY',
#  'KPiU0A_YptY',
#  'KQkNXr0eJko',
#  'KTO4-4bb-H4',
#  'KcrkUfjJDH8',
#  'KgEBXD6X-gA',
#  'KulbfLCH_HA',
#  'KuyDxTO4Qe8',
#  'Kxs1hCUZiSA',
#  'L9QrqcY7zxc',
#  'LH4igfPri6E',
#  'LLwiq7btZlc',
#  'LSZWOT27za0',
#  'LYsGi3Ig7dg',
#  'LnuTgNU0Yrs',
#  'Loxlav1sGz4',
#  'LptZhiwL5rc',
#  'Lr7DUYtQb8I',
#  'LsOBdtG0qcM',
#  'MAHP9d6D9jk',
#  'MIw9FZj7GqY',
#  'MJdHS2H_skY',
#  'Mle-dCmOY9A',
#  'N6GD0aNgptU',
#  'NVeC4v7M0_g',
#  'NoalJ7Qwn6Y',
#  'O86ywBpY0lg',
#  'OXBkL7CUUKQ',
#  'OZFYFh-g-9I',
#  'OdNYY7bLV9A',
#  'OeWe53Yp51M',
#  'Op7RUDYFXuo',
#  'OwY0hRCCJps',
#  'Ow_vJamkPso',
#  'PQz2IiepUbE',
#  'PRuYvyB18RA',
#  'PT_7luuiqX0',
#  'PXKnH43btUk',
#  'Pm3UMA0C_bM',
#  'Q6wqq6vC3pA',
#  'QNhhhus9oc4',
#  'QQjRjUo5AIQ',
#  'QUOOlfJQGa4',
#  'QZNe9gCZIHs',
#  'QeUoEC8YkZM',
#  'QfR4GOgWjGU',
#  'QfnFwWXOJbA',
#  'R0GpSVQRCrI',
#  'R2ayrYXVG6U',
#  'R7BKUVA-7Tc',
#  'RRqaOgCDjdU',
#  'S6ApSPdX01U',
#  'S9cVgCveEWw',
#  'SQWUXCfMqAY',
#  'STy04iD6if0',
#  'SY-LDvgXit8',
#  'SYUQh56soCc',
#  'Sa4LJFBqdRA',
#  'SfEAx7P0uqA',
#  'ShjQ9hB_aFs',
#  'Sisf48hmdlg',
#  'Sk17ovChQ3o',
#  'T8zH7U_A8Zo',
#  'T9bLfP4lhJc',
#  'TGngItVILCs',
#  'TMBlLhMW6Y8',
#  'TO33_0NN3SM',
#  'TRBKFQMaT3c',
#  'TWxznlaDowk',
#  'TnAENFyBiCM',
#  'TptZ-myqNb8',
#  'TvTUSKCDW6U',
#  'U0sPpKf3_iI',
#  'UAt0TNv4sTI',
#  'UEwW-ua_Xvs',
#  'UbN1Rv0oPDs',
#  'Ucu6jZfDM3Q',
#  'UeSI5Frqx2A',
#  'UhbBqx7lSPk',
#  'V2t_HyuNdSI',
#  'VF9GW5no8rs',
#  'VMmos_8e7dg',
#  'VPanjgEj13o',
#  'Vjd7lpc2JH0',
#  'VlWe1wSlykI',
#  'VmB9EO0ntRk',
#  'VqY_61Ziu8Q',
#  'WH0mSXLm7A8',
#  'WMBlZfPFgD4',
#  'WNfTEl6sJ-4',
#  'WSJIa1riQno',
#  'WXHShqkVYnM',
#  'Wh98E1Iq6B0',
#  'WqcyECsw1F0',
#  'WxyL6lhx864',
#  'XBCnoYynxK0',
#  'XQe2Me4gTno',
#  'XWzTdtCkLdI',
#  'Xb-gf_X8DCs',
#  'XbQOQMas8pM',
#  'Xw2sEta5GWc',
#  'XzZw9ExEApA',
#  'Y2MwImFc5b4',
#  'Y6-iW-sMRWc',
#  'YGOLpmrYPkE',
#  'YMFXLZhsSPw',
#  'YSPaLBdp9kg',
#  'YV7CQlQqYrI',
#  'YdjJMpT_BsY',
#  'YknQmxzn_0g',
#  'YtGgBbE8g6s',
#  'ZDnwIoE2HAc',
#  'ZOIupAiPzks',
#  'ZPvCCs5ki4g',
#  'ZZ6YWlpOJCM',
#  'ZaYFPE2ZhAI',
#  'ZbZNQbRcDfc',
#  'Zbt_fE77lLY',
#  'ZgZOQz-kKoc',
#  'Zj5PfI4dQM0',
#  '_DixNgQArqc',
#  '_Fbicv7uFCU',
#  '_Mv7MSDEKwE',
#  '_RvKiNfeHSU',
#  '__dygiSdBfE',
#  '_bjt1hbX89E',
#  '_rN2X5Pwl7s',
#  'a8wtdHjOsQ4',
#  'aC2AsJPVUSA',
#  'aFjv2MQwzgk',
#  'aN8gwQpiAk4',
#  'ak3_NdAq4kk',
#  'anpwhaF0xp0',
#  'ap69Wky3Jx0',
#  'b07Ut3pR38M',
#  'b1jkys9uEGQ',
#  'b4WfGxyxzt4',
#  'bBfTLwSTCgU',
#  'bVQ6Z9DaSJ0',
#  'bVWsjrCkWOw',
#  'bd8bLRmvjTg',
#  'bjtLEjJROls',
#  'blqXyilXW_U',
#  'butKzQY6UB0',
#  'bvgwV7aWoGw',
#  'bxvybxYFq2o',
#  'c6ld4rtzjpU',
#  'cBsCckAdEkU',
#  'cCDClJz5Qx8',
#  'cb3sSe7jzlc',
#  'csU2jJ-L8Ok',
#  'cynJjYxxVw8',
#  'd0YxDq-MTgA',
#  'dHe9PQDDAis',
#  'dLPXXrx3Zo0',
#  'dPJ9cZen-lg',
#  'dS8cI64OT2I',
#  'dTvxE5zcY08',
#  'da_7SBMeEgU',
#  'dhxcNMhrdyw',
#  'dqAVgktMX0o',
#  'e7-NmYzMCTQ',
#  'eBbmUl8UA_M',
#  'eHgfMmheIcs',
#  'eWAR9eiyNq0',
#  'ehTNpOoO-GQ',
#  'eqhffVaBPDQ',
#  'eu0d6kOjoNg',
#  'ewlSPXgBPn4',
#  'f5FOwV-5vyY',
#  'f663XULOanQ',
#  'f7lJZsGad6Q',
#  'fFb_4vxpAHM',
#  'fG_ZixbeZsQ',
#  'fJ91FG6H9wQ',
#  'fLVyv7U0cX0',
#  'fbAmthm4Ymc',
#  'frJfPWipJYc',
#  'frZwL8rE31c',
#  'fzMTAdlkibM',
#  'g-LPtlhR6io',
#  'g3y5yVL-wvk',
#  'g7ra9w8NvHM',
#  'gFw-8PmrPwY',
#  'gLs8w7gMN9M',
#  'gf7Ad97vMh4',
#  'ggnh_aiBexo',
#  'ghWuiC6iKJw',
#  'gkGAfBx58EI',
#  'gxT8TfI5DaE',
#  'h5bMYNoHO_4',
#  'h6QAxyE9HEM',
#  'h9qn6L6DgXs',
#  'hB9VIp-A5pE',
#  'hC66tn2yCHk',
#  'hFmY9W31NwY',
#  'hQm7y9tPS9s',
#  'hUg85yU8yX4',
#  'hal95Y5oVqk',
#  'havfsJKMeZI',
#  'hce7YAkk7JI',
#  'hh_f-leBPCI',
#  'hyq3eK1vPlU',
#  'i8m9uMht_sE',
#  'iLFXtcYBPbc',
#  'iTTf7uHceUg',
#  'id1coLKPNbw',
#  'jB__4I-ZsBg',
#  'jRm6-PNy1E4',
#  'jTKE1UveMoI',
#  'jXCsT71a8yk',
#  'k3oydDd8ufc',
#  'keQrWZXskv8',
#  'khIu6n98GPM',
#  'ko8FDASl1D0',
#  'l2481Ik0UYk',
#  'l5t-ewvbulg',
#  'l7dHvqA-WB4',
#  'lCXp92fbhnw',
#  'lFTXSGMdRlQ',
#  'laAs3lefrKY',
#  'lkV2ykWhnhY',
#  'lmq3P8Uf0FA',
#  'm53wzg_22iA',
#  'm9CrQpJudDU',
#  'mhvHeh_BT60',
#  'mlEgCVtrpOM',
#  'mzMUIIgflQ4',
#  'nDuaToFAXcM',
#  'nEcWwCWQcPs',
#  'nIWIV7zeZy8',
#  'nRWyNY1xmto',
#  'nbAAtH8BVEI',
#  'nq4X-rt9rQc',
#  'oLbapEHtaqc',
#  'oNntNOM--Is',
#  'oPaUrb_2BRA',
#  'oTIc-94m3Ns',
#  'oiI2vje_q8Q',
#  'oorcCqRiL0I',
#  'ox69pmZWVtw',
#  'oxOAVMCAT6U',
#  'p62TigiVoN0',
#  'p7XdPEzsKqc',
#  'p98bHiaBVSc',
#  'pBn67-BwhHI',
#  'pE_uEd1HNSE',
#  'pF94_n76EBA',
#  'pIqmhg6qzF4',
#  'pJvgMXChVd8',
#  'prdpyc1yYdI',
#  'pz69txOMLGM',
#  'q4rdYmOC_q4',
#  'q9sjug6nQHU',
#  'qT-yGSvwDYU',
#  'qUtvufRLvlE',
#  'qZxwtg4jkos',
#  'qbfQxATwPi8',
#  'qjU6jC2h_mw',
#  'qr2sUrGH5WU',
#  'qtJPkQYtYck',
#  'r0g_qE9fHqE',
#  'r0uh4X6lsE4',
#  'r7WMbhW1CNs',
#  'rH4I7ikR3Rw',
#  'rLroop0PhQg',
#  'rUBoX7ou8hg',
#  'rwgOD53IBM8',
#  'rx1EaDUVCmU',
#  's02VNUzzsKk',
#  'sJasscw4nzo',
#  'sSugOSKi9PY',
#  'sasgvQAyb9A',
#  'sciJokigr5M',
#  'sh2FudiOY4U',
#  'si_t945sKwE',
#  'slADRMfcwc4',
#  'spQIHIenUOs',
#  'sq8vms7RCb4',
#  'sufGJFI7e0I',
#  't9KQhRGt3TA',
#  'tC9kqNg5WOg',
#  't_X4GF6LmYc',
#  'trimeXlto-c',
#  'u9rYtImtjwo',
#  'uGz5eNccvds',
#  'uJJqDBNoZmE',
#  'uLO2W6zSPz8',
#  'uPNOap_tsgQ',
#  'uSHsa8-VDj0',
#  'v7dSjZeZ7ro',
#  'vAKBvz-IBDY',
#  'vC6ZAqO_efQ',
#  'vDnX7q1Ps7A',
#  'vfFf-1Zsz2Y',
#  'vk7FnITElbg',
#  'vq0iAteGOkI',
#  'w5neOjAI_Cw',
#  'wN-TuAfWaDM',
#  'wNLNxmoe8mo',
#  'wUCf3eG7AUA',
#  'wa0cE-drf0c',
#  'wi1pamd5Des',
#  'wlKcr3m7nvw',
#  'woskLR1OKkk',
#  'wrt10WKnKWo',
#  'xJ9tK3PYlf8',
#  'xKSokhKQA6A',
#  'xRGAwGJEQ60',
#  'xZCyrS7IJiI',
#  'xbM8p_XJ4Qc',
#  'xwo9XGxvgzI',
#  'y3fABGnSeDE',
#  'y4NhZ4LuGGo',
#  'yA7Es1qS018',
#  'yJvV4qX5mxM',
#  'yKWlJq31BPY',
#  'yLqITdGUZWM',
#  'yVf-WsanlTI',
#  'yWgh2Q6b73I',
#  'yt6kh2YjFBA',
#  'z4oXy_pqO-c',
#  'zChrCJ24V7M',
#  'zGqNk_reinY',
#  'zak0y05TKuI',
#  'zwxyTVA725E',
#  '-6o03I9M1cM',
#  '-9rc2fN9khQ',
#  '-KMpDkwzYvQ',
#  '-oTz2Ick93g',
#  '-x9jOHOH1XE',
#  '-z6SeHBd_kQ',
#  '03mNO-4V4r4',
#  '04Q8v1xou6k',
#  '04Z_jBC2HtM',
#  '08_5x8LPvc8',
#  '0FiFOf_YJmc',
#  '0XvLmEbXpGM',
#  '0oVyoxGJLFQ',
#  '10EhW-lV8po',
#  '1ifckPRdDKs',
#  '1ijc66BlgNk',
#  '1kZNw16qAhM',
#  '1uZIXCFA-1U',
#  '2YARsjB0pZM',
#  '2gB0wtwjkos',
#  '34EhYVMGUPE',
#  '3A9kmcBpc_s',
#  'Qku0zj0hp1s',
#  'Qrea8CaA3Gs',
#  'RDitzOHYmoQ',
#  'ROxPb0nJXTo',
#  'RZrMnKi_QvA',
#  'R_SrRr_plFE',
#  'RalrhRN_xWI',
#  'RbGlgAghwrQ',
#  'Rgr5pBfR0vM',
#  'RkiM0kuPT1E',
#  'Rnxxz9LUo9I',
#  'SI4yRZo56I8',
#  'SLMCZcFsp14',
#  'SYVaSQ816CE',
#  'SmGK_rnCq08',
#  'SnCJ1yYiVZo',
#  'SqPO5UUxO_Y',
#  'SrpYXCy9_2E',
#  'T0Yw8i1NU_M',
#  'T64c0IMyrVg',
#  'T8QyydkqrpU',
#  'T9KT_BxTB3U',
#  'TCL4TIDoHnY',
#  'TFrEG7PEKcU',
#  'TFzux1FXbTo',
#  'TLMbrJbkQIA',
#  'TSV6M303PHk',
#  'TVM8ZnTHhG8',
#  'Tl2TyYkEgUs',
#  'TrgCBAgijTI',
#  'TxjcVSXEj6c',
#  'UH7YKdk9bdk',
#  'UooXGtYPQbM',
#  'Uup6Jyxh2cg',
#  'UzAY7IwHdkQ',
#  'V3l1j6XFdX0',
#  'V9rH-M89C8Q',
#  'VCDyTCacQKM',
#  'VEujyTiAbsg',
#  'VMod816eV6Y',
#  'W9OjCCS24kc',
#  'WBYC436li3E',
#  'WBgTOYAXBKk',
#  'WEf17gNpfPU',
#  'WNXHEc68PRM',
#  'WVOBWsV1qkM',
#  'W_RzdvV7_rw',
#  'Wk_S2fU4csk',
#  'WkswguWRJ5Q',
#  'WwaEZhneErk',
#  'WwbGGmlZlZE',
#  'WxNAarKvb0U',
#  'WyxhwVCp7mQ',
#  'X0F3IyUtpXc',
#  'X6_YgOKvKik',
#  'XEznfLuaZqo',
#  'XP_R6Br3hS8',
#  'XTLdsfup44o',
#  'XXqs6vpTjjE',
#  'XYKciAYaStU',
#  'XfBrpbjR6L0',
#  'Xy-QersPrEw',
#  'Y5SKRo0AsXw',
#  'Y9DqNLkNJXA',
#  'YK2MIb25C4A',
#  'YThEKAO1lzE',
#  'YZzbR01bBgI',
#  'YqTgJK2jlJA',
#  'Z2YG2E8UJ98',
#  'ZHai2Ra_Dd8',
#  'ZQoXoUFAVdU',
#  'ZcrhKP-Ouww',
#  '_01OjlsRtGY',
#  '_EntjxXYFH0',
#  '_HARjltPpW8',
#  '_P9T5w7iBFY',
#  '_QhHYLa5B5I',
#  '_VJxdrmGfEk',
#  '_jG48e0rm7o',
#  '_kLvBwZ2uF0',
#  '_oyBGIMCyp4',
#  '_szJZBeplaY',
#  '_xQs6xCPTfc',
#  '_yQflnGKcDE',
#  'a51dGmtUbcE',
#  'a7TICjrZTEs',
#  'a9TBSuq0d1o',
#  'aBzs4LyYwg4',
#  'aFtO9QJrMYc',
#  'aHFBSk2-dCw',
#  'aR_puRoVxOk',
#  'adNioxPXmNE',
#  'aobk1lIMJGs',
#  'arva-2Yw184',
#  'b4ek9u2AAbc',
#  'b6fJtXTSlfs',
#  'b7vSmXJeoWw',
#  'bCaNYr5YowI',
#  'bLe3zoizRF8',
#  'bMuso4mIY1I',
#  'bOupJQv3Aes',
#  'bXyn-ALGXTM',
#  'b_7plgApc0c',
#  'ba7h02tyQb0',
#  'barw3szkfyo',
#  'bcQFs2wIRnc',
#  'be2uCsyhTFk',
#  'bzIgkktZN8I',
#  'cBxCRJDVmr0',
#  'cHHaWlBtOGA',
#  'cJDTYXX4JXk',
#  'cXwiFI8vZxA',
#  'c_O7R9Z0Lfw',
#  'c_ZoyddNPms',
#  'cc3L_rz6Ev4',
#  'cghprIqPqMY',
#  'cilVosVd4A0',
#  'cnnirTP9ifo',
#  'cr4oBpKjoA0',
#  'cuqXPksravo',
#  'cv7UtyRWb8g',
#  'cyrUjzTiOnk',
#  'd3-eYoc7CZk',
#  'd5MLHyvrKao',
#  'dHmxcDUdi_E',
#  'dRhHqD-5dOM',
#  'dVe4QUGXPSo',
#  'dh93yQ8L7lY',
#  'e96lRP3MXqE',
#  'eEOEDyMitmo',
#  'eGVchNA9ysc',
#  'eXzNwl1b7fU',
#  'f9EzC6eFhrw',
#  'fKqx7ESeyAs',
#  'fVJ6JeYYTXY',
#  'fqebYYcpaHM',
#  'fssr-U9JU6o',
#  'fyf-x9fej1I',
#  'g0T8qFFSx9I',
#  'g9GifyBBlNw',
#  'gEsZPCKCch4',
#  'gNd2Ay9wR0U',
#  'gQPIePzcmfo',
#  'ge13put3Bys',
#  'hFP3GTcNYus',
#  'hGCaz9KfDK8',
#  'hKOvDhvOGYk',
#  'hM8-PbRI8Bw',
#  'hPiMR9G_3go',
#  'hZWJdA_C3H4',
#  'hbHxbhQe_I4',
#  'hbJCSG2BpD0',
#  'hqjcXT4Jz6s',
#  'i1WSzHN8hEk',
#  'iGydm4-vnsA',
#  'iIx7zOSTVJ4',
#  'ihkG0L9yFQc',
#  'ii4rMD3seAM',
#  'ikN0FupGEOs',
#  'imbT6t9Befo',
#  'j3FtaEjZWkk',
#  'jSNP8TucE7U',
#  'jWcUILajkQ8',
#  'jZVGfgCQDQg',
#  'jf5a-YnENOs',
#  'jgAU3ScyZQs',
#  'jhr_U9eVuyk',
#  'jolPLMUKT0o',
#  'jq5jstV4hto',
#  'jwVyFgUeRaA',
#  'kIJdmrJzNnY',
#  'kJdjIEgOMf0',
#  'kevAMBcHgcM',
#  'ktodOGLxX8I',
#  'l-Om6NqXDrs',
#  'l1ZNAMJNfEs',
#  'l3_9_DBASGA',
#  'lB1Vt_LBKTE',
#  'lQug_EJuUp0',
#  'lcz26xuZuss',
#  'lf_gVhiQyt0',
#  'lg7ravIdrPw',
#  'llMJEM-f2N8',
#  'lx8Eg7m5e6Y',
#  'm-TJvXwNm0o',
#  'm-bYcQIs37M',
#  'm8YpZQHd63A',
#  'mHtCyLz03H8',
#  'mLP-wr80XIU',
#  'mXpi7ESnTrg',
#  'mZQN-oztdlw',
#  'msoZqv_6bJg',
#  'n2_t1y-OCCU',
#  'n8d9yTAFiF8',
#  'nFGs_KraepI',
#  'nObNc8hX-9M',
#  'nROkzRzz7Rc',
#  'nVUnXG_mu2g',
#  'njs7Rw_iDwE',
#  'nly4U8e2BjE',
#  'noV2elVRFOI',
#  'nrA9C3vIzF4',
#  'nwKBTSLdUTI',
#  'oD0DhbAcGwM',
#  'oJhwbQBl830',
#  'oOjjcvjPBqs',
#  'oSR1SNf8ngQ',
#  'oWS7LZYzryQ',
#  'omhGqzyAnvw',
#  'owkujrYo9gE',
#  'p2UXVt6KRmY',
#  'p2pSYe_WAy8',
#  'p5xMjfhnd2o',
#  'pf2NNgpijfU',
#  'pr6S7Ja9Cl8',
#  'q0is1FaxMKU',
#  'qODUqTUcHeM',
#  'qRNQGo6A0ew',
#  'qRnnGRd1Wg8',
#  'qS3maJSmlms',
#  'qTfc5KInJcs',
#  'qZW06SuAQzo',
#  'qbfIJCLEs74',
#  'qfuckceEdug',
#  'qjCg69YNj80',
#  'qwtbp4SfpTE',
#  'qzQeV3KTOKA',
#  'rRRX2xcqVDQ',
#  'rVwulEfuv1Q',
#  'r_Mo-jOB_IY',
#  'rpuE9P-2-v8',
#  'rqZc_iLUgbg',
#  'rtoAURzgJ54',
#  'rvS55MqBlkE',
#  'sFbgC2m65F8',
#  'sFc9s3wHP8E',
#  'sYkOAw_sa_8',
#  'sZjV7klZDCI',
#  'sc6dE2d4jSA',
#  'sciarA7TwTg',
#  'si7BmWLZLYY',
#  'sk6zO6qoRlo',
#  'sp5hj-3QCFI',
#  'sshQHeEvaaM',
#  'sxAKmWv4roA',
#  'sy0k_uRHHjs',
#  't5GsKOQoL8w',
#  'tLIOaupl3Jo',
#  'tLMoNG586cc',
#  'tTSAmPotnHw',
#  'td1Gn_YHoBM',
#  'toAoXGf5PIg',
#  'tp-oOgvd250',
#  'u45Ahsd9dac',
#  'uLTymGyfr70',
#  'uYbCF1aF_TQ',
#  'uhXMmagSu0g',
#  'v9kdhI0Xego',
#  'vI1ujbSm8BI',
#  'vJG1wgFSfDk',
#  'vKXfnXqKfwQ',
#  'vUWdts6PVYM',
#  'vZLscXbM1Q8',
#  'vhV-4omJLCc',
#  'w16M8oLeHXE',
#  'w1SruPlST9U',
#  'wFyxHDcGr-Q',
#  'wLxDC5SuUeY',
#  'wNZeZgkCcb4',
#  'wPEXvMZgNCw',
#  'wXtBIZBLv7o',
#  'wo7Ztar7hBY',
#  'x1RYdIYvjhw',
#  'x79Q7ZR4a1Y',
#  'xDNlDZNFwZ4',
#  'xFwWwJ5tdiI',
#  'xGnt2bQA8Ww',
#  'xKG-F1cgb0o',
#  'xLWU6AoB7w0',
#  'xXcI1liNGQU',
#  'xYUxdUBKBHs',
#  'xZJg-lcv2oA',
#  'xnmmHwAid9k',
#  'xuPMhAzWpOk',
#  'xvP_eOgmoZk',
#  'y4cr6j3Xo2M',
#  'yBMY3FEMlEY',
#  'yBVdY186Udw',
#  'yrH0-VyYWY4',
#  'yrOeGf5UvLo',
#  'z-L2ZtCG9E8',
#  'z77QsfqFY_A',
#  'zEcbRAm8YM0',
#  'zKJpQvi4niM',
#  'zWYHAwFDAbU',
#  'zWpaVT5ygr4',
#  'zdfsseoqUHM',
#  'zfUr1X6jFeo',
#  'zj74VFZf50s',
#  'znjNGpUDLKk',
#  'zwfeB2fkQ8U',
#  '--TtsBzgp9o',
#  '-10vNqQ7b7Y',
#  '-Gh1TWYpdtI',
#  '-TRtfHeECts',
#  '-UOKkahZ6po',
#  '-_po6HndQ3g',
#  '-coQXIHY-fM',
#  '-iXsn4XsGYg',
#  '-yvJjr9awoI',
#  '02BjZLtVC9Y',
#  '0AkqZ24mK1s',
#  '0Nv6hlETPYc',
#  '0g6AIbFCZqw',
#  '0mpic1ylXk4',
#  '0p634JqAZBo',
#  '0vFr56pBuVU',
#  '14P2BrLfwv4',
#  '1Nr9Fjxsu2A',
#  '1Q36tdVdNQo',
#  '1XPdmkNLCfg',
#  '1bmkISuc-u8',
#  '1f3_joLF214',
#  '1gKG_qQKZF0',
#  '1zWCwqnV2hc',
#  '21o9GWYLhgY',
#  '2A_dX7WIDp8',
#  '2SfxZYAlvNs',
#  '2YzjmH168oM',
#  '2cOPGWuqquQ',
#  '2jwR76RvTNk',
#  '3AHXqjJE_88',
#  '3BmS89SJhwg',
#  '3C0JNMA5Bv8',
#  '3GZ98aYioJI',
#  '3LhpoHF6lZo',
#  '3QRJsE1Az-s',
#  '3bOlSQyJnZo',
#  '3g1g0fOOtkk',
#  '3hY1cOdaljY',
#  '3hYiQnn73Co',
#  '3ku-99dZRj4',
#  '3lf0tzqHXMY',
#  '3lvEXGSqNgs',
#  '3uuBSG1e3p4',
#  '3wKu2UaepuY',
#  '3yfCc_hnRWM',
#  '402Mkbt0D9c',
#  '4H9Pbz3ffDs',
#  '4KttDH0nvaA',
#  '4Y87oiA4I3k',
#  '4ZkO-sG0FsY',
#  '4m8xRYFfsJI',
#  '58G_Rh9P-7U',
#  '5ES9gO66UJ4',
#  '5KIPuJQWyZY',
#  '5U2eJfjeRC4',
#  '5c45aH9ZFzs',
#  '5fpYmxi79Uw',
#  '5iLp3Wsub7Y',
#  '5vFNHkvfBbM',
#  '6-qbAHR_VRM',
#  '62U2GS2RAPI',
#  '6BsAaz-Gk7A',
#  '6D4AvFKOOhk',
#  '6QNMAzj6i74',
#  '6Wn4ZcSEnrA',
#  '6b1qn1lonos',
#  '6tfX6IhKfy4',
#  '7F2iKw7Khik',
#  '7RcB6T96jLE',
#  '7V2zNsHc5Q0',
#  '7Wmx5DkX4eI',
#  '7kkviJNfoKc',
#  '7t9mDqmMAlI',
#  '81dOiyaNqFg',
#  '8QDP5bbPvtc',
#  '8USTVO8877c',
#  '8WRrg-m3_8I',
#  '8da-YadzWbA',
#  '8f5Rnu2usog',
#  '8mido52XddY',
#  ...]

# %%
temp_df_1 = main_df_dedup[main_df_dedup['id'].isin(filtered)]
temp_df_1.shape[0]
# Out:
# 1175427

# %%
# duration of all audio-transcript pairs after best filter
sum(temp_df_1['duration']) / (60 * 60)
# Out:
# 122121.75833333333

# %%
# if 411584 hours correspond to 2300152 audio-transcript pairs, then how many hours correspond to 1175427 audioo-transcript pairs?
est_dur = (1175427 * 411584.1433333333) / 2300152
act_dur = sum(temp_df_1['duration']) / (60 * 60)
print(act_dur, est_dur)
# they're quite different, so the duration of the subsampled audio-transcript pairs is not representative of the 
# total duration of all audio-transcript pairs
# Out:
# 122121.75833333333 210328.3238872344

# %% [markdown]
# ## How to systematically calculate how much to subsample from raw data pool and download
# - Calculate reduction in data by **hours** after filtering (percentage and hours)
# - If this reduction leads to number of hours **<440K hours**, then
#     - Using percentage of reduction in data hours, calculate how much might be needed to enable reduction and yield minimum number of data hours to fulfill 440K hours (reduction in data hours)
#     - Also account for how much might be removed when trying to download (downloadable) and segmented (trainable)
# - Randomly subsample from the raw data pool iteratively until total duration of sample meets requirement

# %%
# calculating data hours retained after filtering
hours_kept = sum(temp_df_1['duration']) / (60 * 60)
# calculating the reduction in data hours
hours_reduced = total_dur - sum(temp_df_1['duration']) / (60 * 60)
print(f"{hours_kept=}, {hours_reduced=}")
perc_kept = (hours_kept / 411584.1433333333) * 100
# calculating the reduction in data hours by percentage
perc_reduced = (100 - perc_kept)
print(f"{perc_kept=}, {perc_reduced=}")
# Out:
# hours_kept=122121.75833333333, hours_reduced=289462.385
# perc_kept=29.671152378294973, perc_reduced=70.32884762170502

# %%
approx_hours_needed = (440000 - hours_kept)
approx_hours_subsample = (100 * approx_hours_needed) / perc_kept
print(f"{approx_hours_needed=}, {approx_hours_subsample=}")
# Out:
# approx_hours_needed=317878.2416666667, approx_hours_subsample=1071337.7007197093

# %% [markdown]
# ## Randomly subsampling English data for downloading (2nd time) to get sufficient data to filter down to 440K hours

# %%
with open("data/metadata/approx_en_only.txt", "r") as f:
    all_en_ids = [line.strip() for line in f]

with open("logs/data/download/440K/440K_download_ids.txt", "r") as f:
    downloaded_ids = [line.strip().split("\t")[0] for line in f]

en_ids = set(all_en_ids) - set(downloaded_ids)
print(len(en_ids))

en_not_downloaded_df = main_df_dedup[main_df_dedup['id'].isin(en_ids)]
# Out:
# 27441720

# %%
import pandas as pd
import numpy as np

# Parameters
num_samples = 1000000  # Number of values to subsample
subsampled_ids = []
hours_to_subsample = 1080000
en_ids_list = list(en_ids)
duration = 0
rng = np.random.default_rng(42)
while True:
    # Randomly subsample a specified amount of values from 'category' column
    subsampled_values = rng.choice(en_ids_list, num_samples, replace=False)
    subsampled_ids.extend(subsampled_values)
    
    duration += en_not_downloaded_df[en_not_downloaded_df['id'].isin(subsampled_values)]["duration"].sum() / (60 * 60)
    print(f"{duration=}")
    print(f"{len(subsampled_values)=}")
    
    if duration >= hours_to_subsample:
        break
    else:
        en_ids_list = list(set(en_ids_list) - set(subsampled_values))
# Out:
# duration=187233.3025
# len(subsampled_values)=1000000
# duration=375183.75638888887
# len(subsampled_values)=1000000
# duration=564000.3927777777
# len(subsampled_values)=1000000
# duration=752849.7641666667
# len(subsampled_values)=1000000
# duration=941115.3980555555
# len(subsampled_values)=1000000
# duration=1129832.358611111
# len(subsampled_values)=1000000

# %%
len(set(subsampled_ids))
# Out:
# 6000000

# %%
en_not_downloaded_df["duration"].sum() / (60 * 60)
# Out:
# 5174723.14

# %%
main_df_dedup[main_df_dedup['id'].isin(downloaded_ids)]["duration"].sum() / (60 * 60)
# Out:
# 438202.3872222222

# %%
subsampled_ids[:10]
# Out:
# ['U6msOTWWOFo',
#  'bRow2kcrPmQ',
#  'LCFilmhRBwU',
#  'Touc8zNtky8',
#  'Ow8SVjlrwjE',
#  'f7AoNul76v0',
#  'a8GYAcbg_1w',
#  'N0vBTUkADl4',
#  'HDqnzGBAt4A',
#  'OUljrTDyBD0']

# %%
with open("logs/data/download/1M_en/subsampled_ids.txt", "w") as f:
    for video_id in subsampled_ids:
        f.write(video_id + "\n")

# %%
subsampled_df = main_df_dedup[main_df_dedup["id"].isin(subsampled_ids)]

# %%
subsampled_df["man_cap_langs_2"] = subsampled_df["manual_caption_languages"]
# Out:
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_99339/1970342885.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subsampled_df["man_cap_langs_2"] = subsampled_df["manual_caption_languages"]

# %%
condition = (
        subsampled_df["man_cap_langs_2"]
        .apply(standardize_dialects_2)
        .apply(lambda lst: set(lst) == {"en"})
)
temp_df_5 = subsampled_df[condition]
list(temp_df_5["manual_caption_languages"].unique())
# Out:
# ['en',
#  'en-US,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8',
#  'en-eEY6OEpapPo',
#  'en-IN',
#  'en-GB',
#  'en-US',
#  'en-cvfXDfbeED0',
#  'en-CA',
#  'en-zL7EZQmMa4Q',
#  'en-IE',
#  'en-zL_pKPa_d08',
#  'en-cFSbaKj2OKY',
#  'en-1oAFzPNiuC0',
#  'en-ehkg1hFWq8A',
#  'en,en-zL7EZQmMa4Q',
#  'en-0hllRZe4s5s',
#  'en-rX01gsAdUfU',
#  'en-anMIXjicSL4',
#  'en-US-YfeEIUII1AU',
#  'en,en-GB',
#  'en-y01yHln2iAs',
#  'en-uYU-mmqFLq8,en-zL_pKPa_d08',
#  'en-nP7-2PuUl7o',
#  'en-y7ZDYfb4tI8',
#  'en,en-US',
#  'en-GusEpHUv8yI',
#  'en-UMYBvvsXfqo',
#  'en,en-CA',
#  'en-A8Ln5B_8GBo',
#  'en,en-UDggLCECq8g',
#  'en-wILyS7txfUA',
#  'en,en-uYU-mmqFLq8',
#  'en-d6gV6WVcwQQ',
#  'en-ZW6bPmS_ILY',
#  'en-Uym2X1t3MTA',
#  'en-puBa_fWWqOc',
#  'en-vP3gpS-n2EU',
#  'en-OkkdIt_1FtE',
#  'en-US,en-US-Az1uF2nEdyo',
#  'en-LUU0EuDKgKo',
#  'en-6UJrWS5jR_I',
#  'en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-FmoQciUtYSc',
#  'en-gG13fOM8Dfs',
#  'en-LUU0EuDKgKo,en-gG13fOM8Dfs',
#  'en-SJ_OorK2o0k',
#  'en-bo0751DuF0A',
#  'en-6UJrWS5jR_I,en-gG13fOM8Dfs',
#  'en-tyWfmtkyBQo',
#  'en-6UJrWS5jR_I,en-LUU0EuDKgKo',
#  'en,en-GB-6UJrWS5jR_I,en-LUU0EuDKgKo',
#  'en-GB-6UJrWS5jR_I',
#  'en,en-LUU0EuDKgKo',
#  'en,en-6UJrWS5jR_I',
#  'en,en-0kNkGc9-BfI,en-GB-6UJrWS5jR_I',
#  'en,en-xMpCOKC5I4I',
#  'en-islCoqYLrbY',
#  'en-gHD45WmuTUk',
#  'en-ngggGVIunHc',
#  'en-if-_5MVq4Oo',
#  'en-MvXeHcEkV6M',
#  'en-zsweiKMxjbg',
#  'en-1Hzps0N_MPU',
#  'en-upRjq0FRvOM',
#  'en-Hvkv0GLQGe0',
#  'en-xf0PX6EkjBE',
#  'en-FhOyXW7vw1Q',
#  'en-gpLhevRF8rA',
#  'en-US,en-nP7-2PuUl7o',
#  'en,en-21M8WI-ZtuA',
#  'en,en-IN',
#  'en-AU',
#  'en,en-ehkg1hFWq8A',
#  'en-y4fwKszN_rY',
#  'en-IN,en-US',
#  'en-DX1xJ45FbHc',
#  'en-Pn_zu28Dr6A',
#  'en-j3PyPqV-e1s',
#  'en-qlPKC2UN_YU',
#  'en,en-qlPKC2UN_YU',
#  'en-US-iLtzV24hzLM',
#  'en-US-Tz2g3Ok69lM',
#  'en-US-KeiurSZEkPo',
#  'en,en-GB,en-IN,en-US',
#  'en-GHEw9DUond8',
#  'en-Hod1tDuSZpQ',
#  'en-g3sZi71aORs',
#  'en-3EZ2SlE8DSw',
#  'en-jr_ntwmUyqk',
#  'en-uKpN1tTG93w',
#  'en-2qxE-mwDpSU',
#  'en-GB,en-US',
#  'en-64EvSf-i32o',
#  'en-3oY-wYEVjgY',
#  'en-bdFBGmYVkEA',
#  'en-1dfyypFS06k',
#  'en,en-nP7-2PuUl7o',
#  'en,en-1oAFzPNiuC0',
#  'en-jm5Qn7oS3ns',
#  'en-7rk6kshSjAg',
#  'en-_Hof7-ZAGIA,en-uYU-mmqFLq8',
#  'en-8K7HLuWh9lI,en-uYU-mmqFLq8',
#  'en-FltNKKLDWYo,en-uYU-mmqFLq8',
#  'en-Q6Y_6uU4N38,en-uYU-mmqFLq8',
#  'en-ywMsn8eDCTc',
#  'en-dIsCpYIEZ-A',
#  'en-A2Vm0pEh5-Y',
#  'en-ab5nJ29o4es',
#  'en-QylZedUUFiA,en-uYU-mmqFLq8',
#  'en-jIpDolMlEmA',
#  'en-8DarVTzXFEE',
#  'en-u_ZFxZ4Iwxw',
#  'en-FF1NwU-wxK4,en-uYU-mmqFLq8',
#  'en-0qs7cWpj4rA,en-uYU-mmqFLq8',
#  'en-DhOS5gtZfZk',
#  'en-EJnfUyAiN2g,en-uYU-mmqFLq8',
#  'en-Rhz_4ijIPaQ',
#  'en-tkYzxHx4p5Q',
#  'en-1UNkydfJV24,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-ySYwVaaeHaY',
#  'en-8F2EDzgHxtg,en-uYU-mmqFLq8',
#  'en-eLuuvKe3-1Q',
#  'en-sDADfminFcM,en-uYU-mmqFLq8',
#  'en-4YnTPw1gmr0,en-uYU-mmqFLq8',
#  'en-120rn_vNGx8',
#  'en-uVRFU16Reas,en-uYU-mmqFLq8',
#  'en-_t72HAHLm4A,en-uYU-mmqFLq8',
#  'en-MEPSEoivOZM,en-uYU-mmqFLq8',
#  'en-dxJE3C5Pgys',
#  'en-ig-_8-DReig',
#  'en-Iab1tzXpOWE',
#  'en-Wzivx_W_sbs',
#  'en-L3CV-TGVGgQ',
#  'en-3ikBRqOBHzg',
#  'en-OobyRLDl1NE',
#  'en-3fk7h0swSlQ',
#  'en-XYa62Rh3toU',
#  'en-A05o5yoyJLE,en-uYU-mmqFLq8',
#  'en-RzgOMvnhUvI,en-uYU-mmqFLq8',
#  'en-jGvZftyZcEo,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-vGD_FQdQeLM',
#  'en-09Ux-9GNvKI,en-uYU-mmqFLq8',
#  'en-qTlCOyMhOSw',
#  'en-uJHoRATdkm8',
#  'en-Axcy-8KW7e0,en-uYU-mmqFLq8',
#  'en-XquW9nIuafg,en-uYU-mmqFLq8',
#  'en-3JhTMIiRCvg',
#  'en-z3-LawTILdw',
#  'en-pUhGHX3gKk4',
#  'en-mjBqq25IgRg',
#  'en-_UV89z7lq1I',
#  'en,en-DLxmEfVUC9A',
#  'en-Jt9r_xG_fDg',
#  'en-clf6ljnzPtE',
#  'en-b2Dj6g88f9c',
#  'en-fkRIyfeeA9w',
#  'en-o5JzkzEIPbY',
#  'en-7-YRqxZY-jc',
#  'en-GDlQFzyoy3k',
#  'en-I8wvA-91FLs',
#  'en-DBVgrKn_J2Q',
#  'en-P0tcqV_XoMw',
#  'en-COr59TqeAPE',
#  'en-KhWKOo0qF3w',
#  'en-ZzZt-22CG70',
#  'en-AzcRNGUccjw',
#  'en-0E-uKd5Fs0g',
#  'en-gspU9OLearw',
#  'en-UGVyG7Vq28g',
#  'en-3RqRCbsr_xg',
#  'en,en-_MQS1NmgeQw',
#  'en-iQqhxWOvnbg',
#  'en-Jljv6wib23c',
#  'en-VVRlss9RIU8',
#  'en-XxpTnCbIytc',
#  'en-D8dBMXirXhQ',
#  'en-BAUxXoJBx7Q',
#  'en,en-IE',
#  'en-H4i0Z74JAMg',
#  'en-hAJjRapOVVQ',
#  'en-CVDiK9g50bs',
#  'en-okvGocAgwdk',
#  'en-rE8lCltoHlw',
#  'en-vr3ZgywzNpA',
#  'en,en-anMIXjicSL4',
#  'en-iGJpuh49ngc',
#  'en-87T3pm9SGDM',
#  'en-EP2_IH4RNQY',
#  'en-h7RozCqfl1I',
#  'en-x4JPPU1fey8',
#  'en-cYotUUH_ne0',
#  'en-jJhZPlUrNCo',
#  'en-A9bSQE2doEM',
#  'en-XdJbaBj1uRs',
#  'en-rAB9mvXiy_k',
#  'en-Skcuu5dovbQ',
#  'en-BI_H8fHGEws',
#  'en-5mF1M-yAtaA',
#  'en-W1a5XUwgNpE',
#  'en-_wo7fz2u8EA',
#  'en,en-O7lMj7lDYkQ',
#  'en-rxsI4JzibH4',
#  'en-BIYDkt-ixA4',
#  'en-Bq1w29tYyIw',
#  'en-RFfUQIcK1tQ',
#  'en-hzkUZk8SLLc',
#  'en-koWG0Cdscjc',
#  'en-UJFdZw25Jdc',
#  'en-pK8Av3W7mj0',
#  'en-HoKbdB4Dzo4',
#  'en-W3H6IVN677s',
#  'en-ePZrFTdGZoQ',
#  'en-0agDWbfTB_I',
#  'en-wM-1q7pMLrI',
#  'en-ONFNSJSopns',
#  'en-WGOd9r5UQuI',
#  'en-XUp_RpzxaUo',
#  'en-T-iV2Vc9ehU',
#  'en-gwKGy7jbExw',
#  'en-m6UlexV5PgI',
#  'en-9Pux1EfLFnE',
#  'en-j0pxzQv08Ak',
#  'en-lzoA4I-_t5w',
#  'en-f36Xvv2vzjQ',
#  'en,en-KpaL35C_-HI',
#  'en-GTssHSoeDGo',
#  'en-qAB5Fq03yBw',
#  'en-uJDqTZqIpmE',
#  'en-qa9qbEes5cg',
#  'en-pq_E5OO3DMc',
#  'en-m-XBGA6iMgQ',
#  'en,en-AU',
#  'en-US,en-ehkg1hFWq8A',
#  'en-0zfjSeGzKME',
#  'en-D4Em8AAJKTg',
#  'en-TUoASCAVR04',
#  'en-lWQ7bK81pqg',
#  'en-vAf3QoYfjS4',
#  'en-VZaPj70E-cQ',
#  'en-I4NqW1OuItw',
#  'en-6GcSGw81TyM',
#  'en-j7CkrLLB2No',
#  'en-LZLVDZ90HJg',
#  'en-I8U16adu9Ao',
#  'en,en-8juMyiLfTHE',
#  'en-jzS_7j95uRA',
#  'en-NSlS7dtTG5o',
#  'en-CA-ym5edNzE7Ow',
#  'en,en-j3PyPqV-e1s',
#  'en-wjj9m-wANHQ',
#  'en-GB-eEY6OEpapPo',
#  'en-GnmjnzQ_IiQ',
#  'en,en-IN,en-US',
#  'en-pnZHtGsjvhY',
#  'en-eEY6OEpapPo,en-nP7-2PuUl7o',
#  'en-US-zOFsReYi2c4,en-nP7-2PuUl7o',
#  'en-DwjU7rTr-pQ',
#  'en-mIBiXa3O-aM',
#  'en-XFdwTH7buVA',
#  'en-_yASqOZhnrs',
#  'en-yPS3IiLDWzY',
#  'en-WVU3oZ6sBt8',
#  'en-US-nPk3V-duwf8',
#  'en-6AFV7OuUDIk',
#  'en,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en,en-CA,en-GB,en-US',
#  'en-0yHdmxR001I',
#  'en-nPk3V-duwf8',
#  'en-1oAFzPNiuC0,en-uYU-mmqFLq8,en-zL_pKPa_d08',
#  'en-NmRnE_m57ik',
#  'en-D5BAJqcz8o0',
#  'en-Vz6lb-KycrM,en-frRR1ShdaF0',
#  'en-zwzribV5jpg',
#  'en-4EAJVydkbtI',
#  'en-kVgEwsc-Yzw',
#  'en-etK2C2H8QxQ',
#  'en-xp7AIyTVSDM',
#  'en-PiSUR-H3p-A',
#  'en-AzINBuNud_A',
#  'en-3JZJhEiiEO0',
#  'en-75HoPQdITQk',
#  'en-Easc7SnxoFA',
#  'en-sMO8DSWpiJw',
#  'en,en-YME_-BQi2ZM',
#  'en-ZRr7aanC-Bg',
#  'en-PDEGDhA4w_4',
#  'en-35qsMs3jRUM,en-Jyun0WSqg2k',
#  'en-S3doMV87xA4',
#  'en,en-CvPV5UEGfp8',
#  'en-1DS0n4-nWWY',
#  'en,en-CY9rzUYh03M',
#  'en-Yd7nKbXdYxU',
#  'en-HJ2zV3OVZYo',
#  'en-L0QjHYAemIU',
#  'en-rqfUwQRgJMM',
#  'en-oCyDp9vZYpU',
#  'en-_BCirTlwFAI',
#  'en-nOhH3P70g7c',
#  'en-Q8VSUiGLCHE',
#  'en-gzYyVURHVJY',
#  'en-cwta4DdYlqs,en-uYU-mmqFLq8',
#  'en-1y8vE1lB4mc,en-uYU-mmqFLq8',
#  'en-m4eBBXR2NWI,en-uYU-mmqFLq8',
#  'en-ISAkFRZufcQ,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-djFNrEpTT9E,en-uYU-mmqFLq8',
#  'en-JfRb7_yIlwE,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-mcQ9TUdsemU,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-eJ_oKHlbQEw,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-o4bcFJtS9qQ,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-hn9t9RVLJlU,en-uYU-mmqFLq8',
#  'en-FmcA0Ck4050',
#  'en-UurlFyOxtk0',
#  'en-JkeT_87f4cc,en-N0OCHJwFMH0,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-eFhmwgo0i34,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-nUL-EcCn21I,en-uYU-mmqFLq8',
#  'en-tT8GuReHDsU',
#  'en-fUFEIUBWbCg',
#  'en-JkeT_87f4cc,en-W-JJ06y4PfY,en-uYU-mmqFLq8',
#  'en-J0epTwdbUSg',
#  'en--7JlpR3yemc',
#  'en-DnW9kAMlmHE',
#  'en-zTT00x_NlkE',
#  'en-JkeT_87f4cc,en-YVC8crOXZFU,en-uYU-mmqFLq8',
#  'en-02k8hDK1bLs,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-ErjV-5z0wKU,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-e8DgYwwn-fQ',
#  'en-JkeT_87f4cc,en-c7Tt8RLlOBM,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-n6ThXxX3M7s,en-uYU-mmqFLq8',
#  'en-CU0sooMoRUM,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-P9z0FfFJDsE',
#  'en-JkeT_87f4cc,en-kSEm-6II2_w,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-NaDbnOoA0A4,en-uYU-mmqFLq8',
#  'en-HXvi7no3jzM,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-P3X9kweWMD0,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-XAP2AaHFTrw,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-uYU-mmqFLq8,en-z5LJrmsRFCk',
#  'en-JkeT_87f4cc,en-NC5DvQNKvcA,en-uYU-mmqFLq8',
#  'en-fTefqTUvyW0',
#  'en-0ZWcPsniXKg,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-mSyRcxqykOo,en-uYU-mmqFLq8',
#  'en-ExqhZw6zUCU,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-ekZTxVlPuOU',
#  'en-1VuLuNef9z8',
#  'en-zmD1Wp-2I-I',
#  'en-wl3NC8L9erY',
#  'en-YxoyVgBjYnk',
#  'en-tRvCG3BTkFE',
#  'en-JeSFqZ48phI',
#  'en-Q_sqxUSrxGE',
#  'en-Bej7DZrLiM4',
#  'en-jlUhcD8PG_0',
#  'en-n4IfoToK65Q',
#  'en-JkeT_87f4cc,en-uYU-mmqFLq8,en-vg7QzroLV6w',
#  'en-4KmLBrav5Jo,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-foFjCBrdEuM,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-ZgS1_d9W6fo,en-uYU-mmqFLq8',
#  'en-zeFibAith8A',
#  'en-0oQUxOUd-Zo',
#  'en-2aInOgBVNqo',
#  'en-X2ggMwi0efo',
#  'en-JSZLZf4jJYc',
#  'en-fmWN8gPbw7c',
#  'en-CJSY2_7aYiw',
#  'en-kXB4N1t6iLA',
#  'en-tlprxW9GvG8',
#  'en-s8Z7YU7hHEk',
#  'en-r4UpPO3mGog',
#  'en-Bn5RPss0NpE',
#  'en-Yls0RH9_LJc,en-uYU-mmqFLq8',
#  'en-Gvr4wtX5ecY,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-x6r8LMNaImI',
#  'en-T8hJ1QDZMRc,en-uYU-mmqFLq8',
#  'en-bdj9Fom8Qp4,en-uYU-mmqFLq8',
#  'en-i0RTeT6SVc4,en-uYU-mmqFLq8',
#  'en-qVePah7_Ffs,en-uYU-mmqFLq8',
#  'en-gbsUrnkF54A,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-woXxrZ_GsHQ',
#  'en-3TJuWpxVJPg,en-uYU-mmqFLq8',
#  'en-n1B3TxFD5xM,en-uYU-mmqFLq8',
#  'en-5E7JmI6zoWM,en-uYU-mmqFLq8',
#  'en-xNvSJaHxCxo',
#  'en-VMy1-uJaoIU',
#  'en-JkeT_87f4cc,en-pwHbEGcaoQ0,en-uYU-mmqFLq8',
#  'en-0fDBhth8enk,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-T5ut_xj-WJc',
#  'en-5HRkwkBJ7Sc,en-uYU-mmqFLq8',
#  'en-BYLgFlfkVNI,en-uYU-mmqFLq8',
#  'en-T1iB35RRLEA',
#  'en-_NxoXC-T1ys',
#  'en-PboFWDgOvh4',
#  'en-cCvIfBSPzvA,en-uYU-mmqFLq8',
#  'en-kwdHWP30m3o,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-zJPRVvxZT6I',
#  'en-7cil13m_SlM,en-uYU-mmqFLq8',
#  'en-7tNo1_YVM4U,en-uYU-mmqFLq8',
#  'en-DxuJ9jsl2ko,en-uYU-mmqFLq8',
#  'en-14MuiWftFiU,en-uYU-mmqFLq8',
#  'en-8lKq5RpGyx4,en-uYU-mmqFLq8',
#  'en-Uw2pbZ-YYus,en-uYU-mmqFLq8',
#  'en-IVvarIVQ-Nc,en-uYU-mmqFLq8',
#  'en-pgY9p5vO4Pc,en-uYU-mmqFLq8',
#  'en-HizxonZuoKY,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-vhvGdkPgJQ8',
#  'en-G9-9t0Po7lI,en-uYU-mmqFLq8',
#  'en-y-0mtYhrfaI',
#  'en-H4l5Up4ql6Q',
#  'en-M6TwBG6I5mI',
#  'en-kEvIx4UT4bk',
#  'en-JInPfvzz934',
#  'en-m-y7uIW8KjU',
#  'en-JIiFvkJEvcQ',
#  'en-sDKD_tMckdI,en-uYU-mmqFLq8',
#  'en-KJ9qq5SWeTM,en-uYU-mmqFLq8',
#  'en-tTqswtZrL6Q,en-uYU-mmqFLq8',
#  'en-qWXmWgm72gw',
#  'en-ljvZHVZxzj0',
#  'en-e_z5WUDOKiE',
#  'en-fs9F6Kbxm9s',
#  'en-p0xRR3NGPJE',
#  'en-eLA-4ND6Wpk',
#  'en-GsYySCJOMhI',
#  'en-vuODDtA2vyo',
#  'en-1UPANnXNCfY',
#  'en-D-uZ5qCI3TY',
#  'en-pSahjIwbUoc',
#  'en-AdO9SGL59_Y,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-UaWuWP08dPI',
#  'en-JkeT_87f4cc,en-ajfXxReBKWI,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-TXnpeTVKEpk,en-uYU-mmqFLq8',
#  'en-FQTvEavKcuA',
#  'en-JkeT_87f4cc,en-qtkH62ya5Rs,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-X4r2kcBohZQ,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-Vq01KFj7urE,en-uYU-mmqFLq8',
#  'en-5OJtUkBZAlw,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-BqlmWsYeWAw,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-4pKoOp1IIF0',
#  'en-nIqoX4YeHIg',
#  'en-5VNWHYHZnwA',
#  'en-nxk12l00fsE',
#  'en-gYIX7a7YNUU',
#  'en-6D1bywJpb_Y',
#  'en-4H3-xTbRjpw',
#  'en-GZgargbgRks',
#  'en-ytxD-WhcR34',
#  'en-YGqKPVGh8F8',
#  'en-yi3ljXAj3Xw',
#  'en-0uiE5fn52Eg',
#  'en-t233v9LL63E',
#  'en-b4XKE4XXqxs',
#  'en-KIQBN-lm0so',
#  'en-zScbOjDuT0Y',
#  'en-4OIDhSvBd5k',
#  'en-c_drPkCOs1c,en-uYU-mmqFLq8',
#  'en-bV7eFyc8w24,en-uYU-mmqFLq8',
#  'en-H5RIrCEgj_o,en-uYU-mmqFLq8',
#  'en-zGHonflUZYY',
#  'en-fot-BDCk-Qk',
#  'en-vEvMgsXNaw4',
#  'en-4WW53ZlFtP4',
#  'en-g9Vwf4gsK44',
#  'en-crRb_w6Hh2c',
#  'en-YDp4Z95LH7I',
#  'en-TUnF1kF3IMc',
#  'en-LxHs-caYTVg',
#  'en-naTIeOHjejU',
#  'en-SLd-NPr9wE0',
#  'en-D3KGVNnWVXc',
#  'en-7B2swBEnVFE',
#  'en-bnD6qQonUNY',
#  'en-jOWYpFQ6sAg',
#  'en-2eiXw9j-5lg',
#  'en-XFbnTgS_vfU,en-uYU-mmqFLq8',
#  'en-1PVL-b_a4Vs,en-uYU-mmqFLq8',
#  'en-iq63Wz4_gOU,en-uYU-mmqFLq8',
#  'en-WDmkHCAxKOg,en-uYU-mmqFLq8',
#  'en-ScZSMNgGl5Y,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-zLl1HiKP0mI',
#  'en-uYU-mmqFLq8,en-xpZjouUkLyM',
#  'en-tf7wnwX28I0',
#  'en-UcDZa8ve5NE',
#  'en-Ry-74ARGXK0',
#  'en-I91RmOm2a0Y,en-uYU-mmqFLq8',
#  'en-RDjum6X7Js4,en-uYU-mmqFLq8',
#  'en-9JnqA94WljU,en-uYU-mmqFLq8',
#  'en-f-PO6mf35Eg,en-uYU-mmqFLq8',
#  'en-gPEJ_snqSPs,en-uYU-mmqFLq8',
#  'en-BotdjIhuHhg,en-uYU-mmqFLq8',
#  'en-AJQ7GFy6g9c,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-w5grtzI2ntg',
#  'en-EdfVOehrkEI,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-xPBSDyTsGK8',
#  'en-ccFduJD1354,en-uYU-mmqFLq8',
#  'en-CVyQaktgnMo,en-uYU-mmqFLq8',
#  'en-w3dm51QQJIs',
#  'en-kYbLJSKvLWs',
#  'en-nFArZydpGFM',
#  'en-dryo5ILzpqY',
#  'en-6J9rMmCwbaU',
#  'en-ICybCdfLEA4',
#  'en-Cci7YHTJgQ0',
#  'en-XnZ_36N9-0g',
#  'en-xusEHENwKrw',
#  'en-prksAQH3MoM',
#  'en-JkeT_87f4cc,en-rGEk6qJhOi0,en-uYU-mmqFLq8',
#  'en-Gc9h2QWxG90,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-ZXRKI5-vZL4',
#  'en-rGBOvrMH8fQ',
#  'en-Ej3eVF-qSoM',
#  'en-dMjynRURiEs',
#  'en-UxC2z0Li8cE',
#  'en-fPQX9PLZUSA',
#  'en-wfqSCOB_jzA',
#  'en-XEWJRdKSmH8',
#  'en-5OQh4W6NqzE',
#  'en-cDa2ojPLyvY',
#  'en-pSDJx5e92dw',
#  'en-ZassluTMBTU',
#  'en-X6nKGjEbuRM',
#  'en-JkeT_87f4cc,en-MX0a2-JxWaI,en-uYU-mmqFLq8',
#  'en-GWMI1HIbRFk,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-k4n2tVjTDvg,en-uYU-mmqFLq8',
#  'en-7Irsti1qID4,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-OJh7yZky8Ug',
#  'en-n1ZjHT2l2jY',
#  'en-olRY1R-YW-I',
#  'en-2TDlnpKDEO4',
#  'en-psoZQhcFKAk',
#  'en-0gv015-svsM',
#  'en-WXL0ccb8V04',
#  'en-pjBi2SePb5U',
#  'en-_RPwzfT4YMk',
#  'en-C0OOThambJc',
#  'en-q7CjhNW0y7E',
#  'en-10zA7PpoJGg',
#  'en--JmW57K_i4o',
#  'en-4QsiFKGMS5k',
#  'en-NC1Gtr5Su6o',
#  'en-JkeT_87f4cc,en-maDjyA1rrK0,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-rGaghtUoNTg,en-uYU-mmqFLq8',
#  'en-zmGhVn-IQqA',
#  'en-JkeT_87f4cc,en-VQfgLeCe5bo,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-pM0PIBgNML4,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-mdV7OQzWdHc,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-iuT34ySfbDY,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-QOrTQNTQ44I,en-uYU-mmqFLq8',
#  'en-I6tzANQA_Pk',
#  'en-I2KVxIPw3cc',
#  'en-S-ldS_S7GEs',
#  'en-g3btklqT-OI',
#  'en-0epg4PlMzRc',
#  'en-bqvhiWH81mw',
#  'en--QfLQ34LY28',
#  'en-iiZGjsA8ySI',
#  'en-x9AskfYA98U',
#  'en-uYU-mmqFLq8,en-w8-LtMEp8rc',
#  'en-AnhrQgoQxVg,en-uYU-mmqFLq8',
#  'en-IrSVDH_Wp64,en-uYU-mmqFLq8',
#  'en-roR3FWSFiLw,en-uYU-mmqFLq8',
#  'en-JDP294bgcp8,en-uYU-mmqFLq8',
#  'en-ofHovnauvHs',
#  'en-3dHVUvdxxNQ',
#  'en-BAxwwg8ffmw',
#  'en-X1ICYiw8L48,en-uYU-mmqFLq8',
#  'en-CGuSG1PcipQ,en-uYU-mmqFLq8',
#  'en-tkJZ3sca3NE,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-x8dUT1BkxrU',
#  'en-E6UnoO0z-Gk,en-uYU-mmqFLq8',
#  'en-8qWQttoDR1E,en-uYU-mmqFLq8',
#  'en-74Z05iwxMoI',
#  'en-gIxUvlNBKHg',
#  'en-bRq7FQkTsqk',
#  'en-nClrvlaaFcE',
#  'en-c_Igw_9pWMo',
#  'en-WQCApD8XA2M',
#  'en-k8p3rTshsxM',
#  'en-wPT7PtA4orE',
#  'en-lb3yLOz5F0w',
#  'en-0zd1ix70Qu8',
#  'en-9ft_H6X_10o,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-K2h6C-3mtmw',
#  'en-e90HjXEkPoU',
#  'en-Ym5xkioGRIY',
#  'en-S0O8W5931Rs',
#  'en-CLJVT-vLVnA',
#  'en-mdlwndgXmY8',
#  'en-EnVIOzO1kls,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-WdCFIZNo8dc,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-SLzdVF1Rf8M,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-_QahDB_Oc5A,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-XZ-5gesSgp0,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-YPMnttzVCbo,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-a7IwutyIykk,en-uYU-mmqFLq8',
#  'en-fReXXaNUmRA',
#  'en-UIv2CFCfEJE',
#  'en-lIrRp92A7hw',
#  'en-gniP4QVAtMs',
#  'en-yCgVNT5mJBM',
#  'en-x5mqI1hW8tI',
#  'en--AL8AW6Yh-A',
#  'en-OosBGechHxE',
#  'en-8TlpKm6YTLY,en-uYU-mmqFLq8',
#  'en-N5jgVa_vb_k,en-uYU-mmqFLq8',
#  'en-5S-QF2npXp4,en-uYU-mmqFLq8',
#  'en-G3EsVxkn9iw,en-uYU-mmqFLq8',
#  'en-krotAjpRpm0,en-uYU-mmqFLq8',
#  'en-0owyPSWY_3s,en-uYU-mmqFLq8',
#  'en-CdUQCzZS6VM,en-uYU-mmqFLq8',
#  'en-1Sz9FH2BgTA,en-uYU-mmqFLq8',
#  'en-QtP3iagBeBk',
#  'en-oGjJKGuYomc',
#  'en-7yr_zJ5FTsQ',
#  'en-Oo3W7fFR5ZU',
#  'en-b-YLvP3gz40,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-wmBgW7WJJqs',
#  'en-5OaGJXXU5Gc,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-xQ4cffmRjLY',
#  'en-CWflQ89d98Q,en-uYU-mmqFLq8',
#  'en-iIk_3W4MZkA,en-uYU-mmqFLq8',
#  'en-zwIM2erTpoM',
#  'en-JQ-p9Dv7fBM,en-uYU-mmqFLq8',
#  'en-dCc0XwfrYPU,en-uYU-mmqFLq8',
#  'en-H4thDkJd36M,en-uYU-mmqFLq8',
#  'en-jWcktD5Srt4,en-uYU-mmqFLq8',
#  'en-EQUPmQAggtM,en-uYU-mmqFLq8',
#  'en-X5-J5xYlNmU,en-uYU-mmqFLq8',
#  'en-HuXpKe2MFIs',
#  'en-d4CwY3ed4Y4',
#  'en-z6PwDfg6bwc',
#  'en-aKZynpoARuU',
#  'en-2CxYGY5hbiE',
#  'en-AuJubyKrOH8',
#  'en-Y3T_igQDqTI',
#  'en-JkeT_87f4cc,en-nBcmj59IqSY,en-uYU-mmqFLq8',
#  'en-n8sAdu28ybM',
#  'en-0JUtYfVEdw8',
#  'en-lW29xAamoZQ',
#  'en-tkEH-gRgB-o',
#  'en-w216B3DQ8vo',
#  'en-dFVnw0TnuPg',
#  'en-oZy1HsfbnMw',
#  'en-d70UqKeji-Y',
#  'en-ir9SLtDkgG8',
#  'en-11YQP5DMHGY',
#  'en-y1KGoJTvIVA',
#  'en-b_8d02gFY3I',
#  'en-Ny_nupfWwE8',
#  'en-DElVKN_ZNog',
#  'en-g4n-G0DbYwk',
#  'en-w1SEvLKom1E',
#  'en-TFAzk3f0CAY,en-uYU-mmqFLq8',
#  'en-AP8wS34rcGw,en-uYU-mmqFLq8',
#  'en-a6DEpMQkIZY,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-ywOqoPJrqCA',
#  'en-oGR5Q77f-90,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-UnCwJSeM2x0,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-dVo-isoYWj0,en-uYU-mmqFLq8',
#  'en-Dvup2HD_BiY,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-K2AOomj9izE,en-uYU-mmqFLq8',
#  'en-s_8eEpw-aRU',
#  'en-5HRtNNX13-4',
#  'en-XRiuvJZ-5I0',
#  'en-UlETQw9sfcc',
#  'en-yRMuJ-Ed7F4',
#  'en-Yg3i5WjCWtg',
#  'en-krftIsVB4IE',
#  'en-ashKsppnIjY',
#  'en-8_ucOBEf-3A',
#  'en-R9DXlA9fQzM',
#  'en-OyQtcokG530',
#  'en-h98chQO-o2I,en-uYU-mmqFLq8',
#  'en-1xzLNmsvweQ,en-uYU-mmqFLq8',
#  'en-C6qyWl1C1yw,en-uYU-mmqFLq8',
#  'en-4kJuDNV3bFc,en-uYU-mmqFLq8',
#  'en-iHZf-9hI3eo,en-uYU-mmqFLq8',
#  'en-6mOM3w7qmCI,en-uYU-mmqFLq8',
#  'en-Y6UetiH0EzA,en-uYU-mmqFLq8',
#  'en-Gn1I65EBvYw,en-uYU-mmqFLq8',
#  'en-CrbNtWffYBA',
#  'en-pNOi26zJDjE',
#  'en-q60gObQBlJI',
#  'en-xchGlETCzM4',
#  'en-deZIN5CxETo',
#  'en-65POMjTedQ0',
#  'en-mHQTZQUubQ4',
#  'en-GfeFNDMKVU0',
#  'en-xSSFeFiI58o',
#  'en-4eAQFA5amDA,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-ct4ooROz1pc,en-uYU-mmqFLq8',
#  'en-q26n6lBYlPY,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-zCTd-nUx9MQ',
#  'en-wUJ_Hp8ni50',
#  'en-JkeT_87f4cc,en-VZwfUAAznLY,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-d1dWcVLEK2c,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-cIzgL4UnXfw,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-pU1CcyPgKHU,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-UhfvuMe6K2c,en-uYU-mmqFLq8',
#  'en-8SC5Q4gjCn8,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-lVwkIxKU0R0',
#  'en-njIi8lf-JCg',
#  'en-0E_B9LC3wEM',
#  'en-Gl17_lSuxbk',
#  'en-B3o8FsgFm6c',
#  'en-dwLJMSaP0kM,en-uYU-mmqFLq8',
#  'en-Ei-rOIuWfkI,en-uYU-mmqFLq8',
#  'en-W6hVKXfBLzg,en-uYU-mmqFLq8',
#  'en-GOUrX6Vy3DE,en-uYU-mmqFLq8',
#  'en-WbUJARc8P7o,en-uYU-mmqFLq8',
#  'en-PtOyLx66PH8,en-uYU-mmqFLq8',
#  'en-EKOUvsO0AdU,en-uYU-mmqFLq8',
#  'en-6K30DPIgBZQ,en-uYU-mmqFLq8',
#  'en-5LDHFLvR1tw,en-uYU-mmqFLq8',
#  'en-qEujBe_1sJc',
#  'en-P-ROsX50cuE',
#  'en-ynegHrfIWQg',
#  'en-7BMXm6PdvXA',
#  'en-kp8xg-ysstQ',
#  'en-odMtgTDF9nU',
#  'en-7q_mbESg8gA',
#  'en-SllA-HwwZqY',
#  'en-ASRC4Vm9C54',
#  'en-uYU-mmqFLq8,en-vf0t7pNxMGE',
#  'en-_Cqzh6_KYxU,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-xHQHjtqvGwI',
#  'en-6ZLF4OjSVVw,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-qKSa-aEfxxE,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-Opuz3GBAYMI,en-uYU-mmqFLq8',
#  'en-78Fd2hcZ0D4',
#  'en-6m7daS9NiyU,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-JjOLBMwUo8A',
#  'en-q1S7eCk4lIg',
#  'en-KpcC69nXMPg',
#  'en-QXstC-FMEd8',
#  'en-JkeT_87f4cc,en-VBF6ShT-M88,en-uYU-mmqFLq8',
#  'en-btKQbsBK1Do',
#  'en-31NoBCsI3vA',
#  'en-r_RZsbcuM8Q',
#  'en-ffi305B9zVU',
#  'en-cSbdw2K00cA',
#  'en-1KGG2Yw5_-4',
#  'en-NFhKpP35vVs',
#  'en-tZ7L_tWBpeM',
#  'en-j6QtxNY-Oqc',
#  'en-QxCJW_at7fQ',
#  'en-0-K8BOQDzRc',
#  'en-FgT3EgXAsmg',
#  'en-jbGB20C0wZs',
#  'en-cVKvtq9C0Pw',
#  'en-G6GZ20xSiXw',
#  'en-huABhLbujHI',
#  'en-fkD4R8r6m8k',
#  'en-qF0_7udISdE',
#  'en-R7OSmgBLKWg',
#  'en-JkeT_87f4cc,en-bPFDwqXK0VE,en-uYU-mmqFLq8',
#  'en-5-D5fU_S4y4',
#  'en-JkeT_87f4cc,en-Z_4kRTkHyuc,en-uYU-mmqFLq8',
#  'en-9CUFjn0zdsY,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-LuAHFcrmqPY,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-Xvko2hUx20U,en-uYU-mmqFLq8',
#  'en-ZUiZLmP5Ems',
#  'en-vZkMhC8Uxsg',
#  'en-kuAffN77oL0',
#  'en-zSOCHBlYEOw',
#  'en-OYNdW6woH1I',
#  'en-a4gzRAPYLjE',
#  'en-m3lvltognyA',
#  'en-znHZpPt69Wk',
#  'en-8XI_NO4KMys',
#  'en-14TW_lHyaJU,en-uYU-mmqFLq8',
#  'en-ipIXJV-uRXE,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-ygZ0AE1qpyc',
#  'en-esoBemXiuH4,en-uYU-mmqFLq8',
#  'en-Ewv633eR7f8,en-uYU-mmqFLq8',
#  'en-AU_GFml-QLg',
#  'en-HtdefZXcTts',
#  'en-awxGrKfVIKo',
#  'en-GnewxOD2wC8',
#  'en-iUDIzyjyezA',
#  'en-Y6CoXnqRd_8',
#  'en-s_g66IbOWSI',
#  'en-CvDaH9rnnXg',
#  'en-VRr2fX9USuo',
#  'en-ORhSsMohBCI',
#  'en-al3S7eYvuX0,en-uYU-mmqFLq8',
#  'en-UXalfNSxiYk',
#  'en-IdgRBjoysWM',
#  'en-2QiLntqXUZc',
#  'en-qGoWmGE_Zfo',
#  'en-0WexDgDq4pY',
#  'en-F7NEJDURL-c',
#  'en-_D38-v6NUJE',
#  'en-gPu27YhNwgE',
#  'en-OoixAiqzldg',
#  'en-QfFk9QuSQbo',
#  'en-EMYnv2V0f7U',
#  'en-Vd8xEIk0XQE',
#  'en-tOeWc7djD-g',
#  'en-lgN5YZ50OEQ,en-uYU-mmqFLq8',
#  'en-871GXDPAvQw,en-uYU-mmqFLq8',
#  'en-WdZYw-_2Wz0,en-uYU-mmqFLq8',
#  'en-asEPRwvF2E8,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-QGmKxq_4s4g,en-uYU-mmqFLq8',
#  'en-Ds8t6o0OEJs,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-a0u4ybf58Q4,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-km4lBwU7G7A,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-MHY7YNggODo,en-uYU-mmqFLq8',
#  'en-THuuzC89zSU',
#  'en-9AAySEpzwro,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-kgnzFo4YBpc,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-TogJyAzUdOg,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-nSONvs-4JI0,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-gLQs5SXKgrI,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-fgHBlQPKQmo,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-fFxIKQ_32Zw,en-uYU-mmqFLq8',
#  'en-B1B72iG1NeQ,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-2ewXahVkSkg',
#  'en-MN_Muj5TnxA',
#  'en-ox7bg5WscZA',
#  'en-4eKN512GRDs',
#  'en-SxvwEcD__vI',
#  'en-JlW8312n0nE',
#  'en-6xI6ONwntIY',
#  'en-lZxYLs384uU',
#  'en-mTjDfwfbu9w',
#  'en-Y2GEd0F15cU',
#  'en-1eMY_En4hC4',
#  'en-cnDsrK4TXv0',
#  'en-bcZ4c61k6WY',
#  'en-rHhg1CeNbWA',
#  'en-Qvh92WB32qc',
#  'en-gO9uRUAxOlI',
#  'en-UEIt5FXxqz0',
#  'en-fpJx6i3zGQE',
#  'en-JBIOTb1x_R0',
#  'en-3XK5p2Gbet0',
#  'en-jvjpfaioBDI',
#  'en-_7pnjMiHxeQ,en-uYU-mmqFLq8',
#  'en-6iacdxq1Bm4,en-uYU-mmqFLq8',
#  'en-KCvXWqAagIA,en-uYU-mmqFLq8',
#  'en-Q61FN41uNNM',
#  'en-FcPNsJqv3ts,en-uYU-mmqFLq8',
#  'en-6y54BLMnqv4,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-yT6D6nNJBdA',
#  'en-d55EOnAfqKw,en-uYU-mmqFLq8',
#  'en-QRRAZx8NQ98,en-uYU-mmqFLq8',
#  'en-jP1Yyo78TBY,en-uYU-mmqFLq8',
#  'en-q0R0SXJu6CQ,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-yLLZDHmRmDA',
#  'en-mvhnNT-L-oM,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-dSLRtDswUdo,en-uYU-mmqFLq8',
#  'en-v82dnekQ3JI',
#  'en-JkeT_87f4cc,en-JoJGzx3KnHU,en-uYU-mmqFLq8',
#  'en-Yd_XIbK6zKg',
#  'en-ggnm99vwN5Y,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-yc96fikP_wc',
#  'en-efbyeKx35wI,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-vsw0FfDTNh0',
#  'en-Rsh-QDuiEQ8,en-uYU-mmqFLq8',
#  'en--6cOBGsu4No,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-EGzIb9D0f8g,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-XrukWjKjKG0,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-VK8kXM4Dnos,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-O6-ADG9_duc,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-x8z73oZeh5M',
#  'en-Ma45Mr-a4ZA,en-uYU-mmqFLq8',
#  'en-sEhyTVjII7Y,en-uYU-mmqFLq8',
#  'en-Z8BIdFLHBYc,en-uYU-mmqFLq8',
#  'en-Zg7jvMXZVME,en-uYU-mmqFLq8',
#  'en-n5T1npoLUK0,en-uYU-mmqFLq8',
#  'en-XaVioCYoOys,en-uYU-mmqFLq8',
#  'en-R0wO5fgB-sc',
#  'en-3dGpESMgRy4',
#  'en-aKVOYKbFEVk',
#  'en-7kIubaw5Awo,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-we3tvIDvwlM',
#  'en-H7Y3UpkES8w,en-uYU-mmqFLq8',
#  'en-Z6b8ILPZzJY,en-uYU-mmqFLq8',
#  'en-7CV0xi9Gswk,en-uYU-mmqFLq8',
#  'en-XHa3RTcGILI,en-uYU-mmqFLq8',
#  'en-QfUx_idnlBc,en-uYU-mmqFLq8',
#  'en-Jexk7DKYGh4,en-uYU-mmqFLq8',
#  'en-fzhva_C4LoQ',
#  'en-xXdhnXiKgUo',
#  'en-oaMh964zH-s',
#  'en-VGx5vrzARw0',
#  'en-51dauywMMC4',
#  'en-XkiL6UU4dxc',
#  'en-THWPN3QFKqQ',
#  'en-JkeT_87f4cc,en-hvSO8yRrQsI,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-UnkNrD0vljY,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-nBYWQsMGmfY,en-uYU-mmqFLq8',
#  'en-4pl5HyJVwwg,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-D8U1_4c5oq8,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-2nTOFH8AlDI,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-jlvfyYfTbP4,en-uYU-mmqFLq8',
#  'en-FuVWtSwX9yI,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-FKSF48bAdtM',
#  'en-R_gBg8vFEaU',
#  'en-UM5OS_8I6jM',
#  'en-XMCK8ayAd98',
#  'en-fd04KURkb4s',
#  'en-bLmUXtv2h9o',
#  'en-zrGpzHzAnMA',
#  'en-uxB-beFXk1U',
#  'en-DgWgab13AGY',
#  'en-ihfZSGPsBgo',
#  'en-Bsed3Me5H_A,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-uiHtv3DzaWQ',
#  'en-bLFOqxj2VDg,en-uYU-mmqFLq8',
#  'en-uYU-mmqFLq8,en-vdi2ygfF0-0',
#  'en-M8jaTEgMtco,en-uYU-mmqFLq8',
#  'en-l1-3myXK8pI',
#  'en-0nOSh3nfESk',
#  'en-goqtWqMBqnI',
#  'en-tcEB4JRz4u4',
#  'en-nyGhyS8Dbgs',
#  'en-Koxq8jtMaxY',
#  'en-jq4sAHQzTVE',
#  'en-G12DvsTVXOI',
#  'en-9oNY_0PobhI',
#  'en-zSBHqwHxLqI',
#  'en-yuLOuRR1xYM',
#  'en-EAee3pTT5Mg,en-uYU-mmqFLq8',
#  'en-sZL-eFa4hW0,en-uYU-mmqFLq8',
#  'en-WhhanxL1J50,en-uYU-mmqFLq8',
#  'en-U0EhZq58yUY,en-uYU-mmqFLq8',
#  'en-ArVkPI1tQH0',
#  'en-Mc6kkZFGwiM',
#  'en-jNW9Rpty2_M',
#  'en-DqXt9cGKacA,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-gfM9b0ajCag',
#  'en-JkeT_87f4cc,en-_mllDw7mfM0,en-uYU-mmqFLq8',
#  'en-crbSbEm2Zh0',
#  'en-ukcqwuwPrjs',
#  'en-MsdlYfy0_5w',
#  'en-JkeT_87f4cc,en-NRhlWT0uoK8,en-uYU-mmqFLq8',
#  'en-Jm6z1-XIrtE',
#  'en-EgBgq04Q1VU',
#  'en-CXJVeGeH8eo',
#  'en--dW93YR-Xh8',
#  'en-fNJ_Ba5KQJ0',
#  'en-vtKNelBzR4Q',
#  'en-nwh5WZRsSM0',
#  'en-SJfFFQSMiUE',
#  'en-2p6karTV6cI',
#  'en-Tnj5WPE-E9c',
#  'en-L0DYT37BSOI,en-uYU-mmqFLq8',
#  'en-8qfsim5mLlc,en-uYU-mmqFLq8',
#  'en-lrXEe8Kl0kE,en-uYU-mmqFLq8',
#  'en-BaqEB3mv7Xs',
#  'en-JDiHPixHC9s',
#  'en-kpo9dQg4q44',
#  'en-pVwYJU2_2dI',
#  'en-81SENe6YbvY',
#  'en-JFnb8tir4CE',
#  'en-NgKRBpZEJI4',
#  'en-DgbpUkdof4M',
#  'en-MzYFwAaMsIA',
#  'en-DP8N8FwTf5k',
#  'en-JeC_3PAVxgQ',
#  'en-dqkPHQwRZv8',
#  'en-jAq3cKoI9E0',
#  'en-pgKV5WvLm2U',
#  'en-bYpR3Ged5V0',
#  'en-iFJjMTlLDUM',
#  'en-LkPb5h8uTMk',
#  'en-YstXRZnkLyw',
#  'en-iI52QLc1IS4',
#  'en-NyXeWzD4fmY',
#  'en-SiJ7Tp8vCi0,en-uYU-mmqFLq8',
#  'en-GzGzUiKowBs,en-uYU-mmqFLq8',
#  'en-SroCL71VqkE,en-uYU-mmqFLq8',
#  'en-Ui9UUYV3HtQ,en-uYU-mmqFLq8',
#  'en-0HTzsnoQJKw,en-uYU-mmqFLq8',
#  'en-fKDuXLf_2xM,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-Q2rU_sNvrfU,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-NG10GM1uXtw,en-uYU-mmqFLq8',
#  'en-F5eVNYNX914,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-JkeT_87f4cc,en-tTDFcUeMFnA,en-uYU-mmqFLq8',
#  'en-8O859dq5IoQ,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-uOJpHqZe51A,en-uYU-mmqFLq8',
#  'en-03aylNGeqbs,en-uYU-mmqFLq8',
#  'en-05vY0K3opIc,en-uYU-mmqFLq8',
#  'en-i5UjXDsiEH8,en-uYU-mmqFLq8',
#  'en-exmEfZIJMsE,en-uYU-mmqFLq8',
#  'en-w4ntW6qw5Ms',
#  'en-Ocv7ltEw7iE',
#  'en-xmUaTNu_3A4',
#  'en-YraE3QGwIYA',
#  'en-GKz92jiMNAg,en-JkeT_87f4cc,en-uYU-mmqFLq8',
#  'en-H8fe5d_dqaY',
#  'en-Z3fmHRxdhWM',
#  'en-JkeT_87f4cc,en-UJrI4fPjCQs,en-uYU-mmqFLq8',
#  'en-ywSc101HTtc',
#  'en-PJjRfpjVVVs',
#  'en-df0nTerLqgw',
#  'en-Dek2XxjleM4',
#  'en-pEpgTy_U0z0',
#  'en-qyDY800EyKs',
#  'en-o3otWWyrcOc',
#  ...]

# %%
subsampled_df["filtered_langs"] = subsampled_df["man_cap_langs_2"].apply(lambda langs: [lang for lang in langs.split(",") if lang.startswith("en")])
# Out:
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_99339/1294208229.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subsampled_df["filtered_langs"] = subsampled_df["man_cap_langs_2"].apply(lambda langs: [lang for lang in langs.split(",") if lang.startswith("en")])

# %%
view_lang_cols_2(subsampled_df, 50)
# Out:
#               id                                              title  \
# 40   D0TBEM3oUtk         Meet Medical Oncologist, Matthew Kulke, MD
# 50   ybPciSw7vyE                       Meet: J. Pieter Noordzij, MD
# 93   3Mr8lg5kvIU  🌶🔥 SPICY FRIED CHICKEN RAMEN: The Best In Osak...
# 115  SK6ngqjyp8E  Meet Helen (Part 2) - Financial Capability wit...
# 118  zicChYIBtIw  Direct Express Cardholder & PayPerks User Prof...
# 149  7CRyjEyWjP4  Schneider Roofing & Remodeling - Show Me St. L...
# 169  OJEVmtRoDW0  SOPIR TRUK PALING HOROR SERING KETEMU HANTU DI...
# 184  TYmnAQT88qw                       Ano Novo 1989 e Aniversarios
# 220  LQ1kAABebes  Amazing Korean Strawberries 🍓😮  | 15 Days Arou...
# 223  oU2XC49MLEk  Arriving in Seoul ❤️ | 15 Days Around Seoul - ...
# 228  Sne_BZcBROM   Multiple Sclerosis Care at Boston Medical Center
# 233  Fd82dkhX2pY  Vaccine Story: Rev. Willie Bodrick, II - Senio...
# 291  lu83Gig4O70  HSNC UNIVERSITY ADMISSION PROCESS FOR KC & HR ...
# 293  D8IfVhGWkvQ  DELHI UNIVERSITY & IPU BEST MASS MEDIA COLLEGE...
# 295  21Sk4c8UpVY  تطبيق seed4.me لتشغيل الواتس اب و الفايبر رغم ...
# 296  3FqBMwNq_5o  حل مشكلة التعليق و فشل تنزيل و خطأ في تحليل ال...
# 297  Ac-L2nopy5s     طريقة عمل حساب جديد على ال فيس بوك من الموبايل
# 308  jsw52zj_7nc   Another shitty one jdsfsdj (captions again bruv)
# 339  MvKvPhb4UsU                    Feliz Cumpleaños | LaPildora CO
# 346  HsyxE7irZSc  TBjack313 - rockstar (official music video) @T...
# 347  m0LZVcjQCsE              @TBjack313 - skrilla (official video)
# 349  _EQ2-wNJq0c            @TBjack313 - real ones (official video)
# 390  cSpA0Lywc14                   Treatment for Burns of all Types
# 396  wx42wgGKNsg  Blk 40 Tanglin Halt- EM and Fujitec Accompanie...
# 401  lpXAhP0TpmA  Free fire all mod best killing moment.My fries...
# 420  BtDfJt8JmmE  Back To School Q and A | ❌PLICIT Mom/ Daughter...
# 422  DLJeaDYSkRI  Boric Acid Suppositories Reviews for BV and Ye...
# 424  MT2IF-FMQsI           Italy Towel Korean Beauty Secret Exposed
# 425  HPQ9M_z8EdU  Salux Cloth The Dry Skin Cure You've Never Hea...
# 427  p8GrSkQ7GiQ       Yoni Steam Herbs & Supplies For DIY Steaming
# 449  Fm6X3eVidQs  How To Position Trade, Trading Risks & Managin...
# 450  T7CizQR1szs  Top Trading Indicators To Use For Position Tra...
# 452  pgDac6A6D8Y  How The Forex Market Moves & How To Measure Yo...
# 460  aGZzW7KeBAs                 Drake x Future Type Beat - "Mouse"
# 462  ACWsYeYWx60  Gotham Knights Gameplay | Story | Abilities | ...
# 472  beLxHhnQ8Vg  Malaysian Food In Korea & HALAL Korean Fried C...
# 475  UBvhOj0HztE  Rapid Rec | The Field Guide to the North Ameri...
# 484  cy1Vjz9dTRU                            Belgrade Blueberry Beer
# 496  n-C0cMBNJwU                                      cfgs chagdeba
# 502  XLUskGNGHDI  Medical City Plano and Medical City Frisco Eme...
# 510  0DjoQ3PdCEw  New Procedure Offers Hope to Treat Advanced Ab...
# 516  UokeBHBX6YU                  Hospital Stay After Joint Surgery
# 523  qxvtYeh2EUs  Therapy Dog Brings Joy to Patients and Staff a...
# 528  Ix3m3DSa-C8                Signs & Symptoms of West Nile Virus
# 530  EO70wJR_9Q8    Hyperbaric Oxygen Therapy at Medical City Plano
# 539  mNnWujUykTc           Emergency Services at Medical City Plano
# 540  nBnhhZNFH-w  Advanced Orthopedics, Trauma and Rehab at Medi...
# 543  Q5gmIyby48M  High Cholesterol: Dangers, Targets and Prevent...
# 544  qV_OyYyGxR4  Burn patient receives collaborative care from ...
# 595  uiukSrmsha0  Nếu người ấy say gọi điện cho bạn, họ sẽ nói g...
#
#     manual_caption_languages automatic_caption_orig_language language  \
# 40                        en                              en       en
# 50                        en                              en       en
# 93                        en                              en     None
# 115                    en,es                              en       en
# 118                    en,es                              en       en
# 149     en-US,en-uYU-mmqFLq8                              en       en
# 169                       en                              id       id
# 184           en-uYU-mmqFLq8                              en     None
# 220                       en                              en     None
# 223                       en                              en     None
# 228                       en                              en       en
# 233           en-eEY6OEpapPo                              en       en
# 291                    en-IN                              en       en
# 293                    en-IN                           en-IN     None
# 295                       en                              en       en
# 296                       en                              ru       ru
# 297                       en                              en     None
# 308                    en-GB                           en-GB     None
# 339                    en-US                              es       es
# 346                       en                              en       en
# 347                       en                              en       en
# 349                       en                              en       en
# 390                       en                              en       en
# 396                    en-GB                           en-GB     None
# 401                       en                              en       en
# 420                       en                              en       en
# 422                       en                              en       en
# 424                       en                              en       en
# 425                       en                              en       en
# 427                       en                              en       en
# 449                    en-US                              en       en
# 450                    en-US                              en       en
# 452                    en-US                              en       en
# 460                    en-US                           en-US     None
# 462                       en                              en       en
# 472                       en                              en       en
# 475                       en                              en       en
# 484                       en                              en     None
# 496                       en                              en     None
# 502                       en                              en       en
# 510                       en                              en     None
# 516                       en                              en       en
# 523                       en                              en     None
# 528                       en                              es       es
# 530                       en                              en       en
# 539                       en                              en       en
# 540                       en                              en       en
# 543                       en                              en       en
# 544                       en                              en       en
# 595                    en-US                              vi       vi
#
#               filtered_langs
# 40                      [en]
# 50                      [en]
# 93                      [en]
# 115                     [en]
# 118                     [en]
# 149  [en-US, en-uYU-mmqFLq8]
# 169                     [en]
# 184         [en-uYU-mmqFLq8]
# 220                     [en]
# 223                     [en]
# 228                     [en]
# 233         [en-eEY6OEpapPo]
# 291                  [en-IN]
# 293                  [en-IN]
# 295                     [en]
# 296                     [en]
# 297                     [en]
# 308                  [en-GB]
# 339                  [en-US]
# 346                     [en]
# 347                     [en]
# 349                     [en]
# 390                     [en]
# 396                  [en-GB]
# 401                     [en]
# 420                     [en]
# 422                     [en]
# 424                     [en]
# 425                     [en]
# 427                     [en]
# 449                  [en-US]
# 450                  [en-US]
# 452                  [en-US]
# 460                  [en-US]
# 462                     [en]
# 472                     [en]
# 475                     [en]
# 484                     [en]
# 496                     [en]
# 502                     [en]
# 510                     [en]
# 516                     [en]
# 523                     [en]
# 528                     [en]
# 530                     [en]
# 539                     [en]
# 540                     [en]
# 543                     [en]
# 544                     [en]
# 595                  [en-US]

# %%
subsampled_df.reset_index(drop=True, inplace=True)
subsampled_df.iloc[0]
# Out:
# id                                                                       D0TBEM3oUtk
# title                                     Meet Medical Oncologist, Matthew Kulke, MD
# duration                                                                          60
# view_count                                                                    1179.0
# categories                                                            People & Blogs
# comment_count                                                                    NaN
# like_count                                                                       5.0
# channel                                                        Boston Medical Center
# channel_id                                                  UCCsieriDUNU-2-nNmXngYAw
# channel_follower_count                                                        7460.0
# age_limit                                                                          0
# upload_date                                                                 20180618
# is_live                                                                        False
# was_live                                                                       False
# format                             137 - 1920x1080 (1080p)+251 - audio only (medium)
# format_id                                                                    137+251
# language                                                                          en
# filesize                                                                  13421137.0
# stretched_ratio                                                                  NaN
# width                                                                         1920.0
# height                                                                        1080.0
# fps                                                                             30.0
# dynamic_range                                                                    SDR
# aspect_ratio                                                                    1.78
# abr                                                                          122.111
# vbr                                                                          122.111
# vcodec                                                                   avc1.640028
# asr                                                                          48000.0
# audio_channels                                                                   2.0
# chapters                           0.0,18.0,Introduction\n18.0,34.0,What sparked ...
# manual_caption_languages                                                          en
# automatic_caption_orig_language                                                   en
# location                                                                        None
# license                                                                         None
# man_cap_langs_2                                                                   en
# filtered_langs                                                                  [en]
# Name: 0, dtype: object

# %%
subsampled_df.iloc[0].filtered_langs
# Out:
# ['en']

# %%
rng = np.random.default_rng(42)
subsampled_df["download_lang"] = subsampled_df["filtered_langs"].apply(lambda langs: rng.choice(langs) if len(langs) > 0 else langs[0])
# Out:
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_99339/1915292234.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subsampled_df["download_lang"] = subsampled_df["filtered_langs"].apply(lambda langs: rng.choice(langs) if len(langs) > 0 else langs[0])

# %%
view_lang_cols_4(subsampled_df, 50)
# Out:
#              id                                              title  \
# 0   D0TBEM3oUtk         Meet Medical Oncologist, Matthew Kulke, MD
# 1   ybPciSw7vyE                       Meet: J. Pieter Noordzij, MD
# 2   3Mr8lg5kvIU  🌶🔥 SPICY FRIED CHICKEN RAMEN: The Best In Osak...
# 3   SK6ngqjyp8E  Meet Helen (Part 2) - Financial Capability wit...
# 4   zicChYIBtIw  Direct Express Cardholder & PayPerks User Prof...
# 5   7CRyjEyWjP4  Schneider Roofing & Remodeling - Show Me St. L...
# 6   OJEVmtRoDW0  SOPIR TRUK PALING HOROR SERING KETEMU HANTU DI...
# 7   TYmnAQT88qw                       Ano Novo 1989 e Aniversarios
# 8   LQ1kAABebes  Amazing Korean Strawberries 🍓😮  | 15 Days Arou...
# 9   oU2XC49MLEk  Arriving in Seoul ❤️ | 15 Days Around Seoul - ...
# 10  Sne_BZcBROM   Multiple Sclerosis Care at Boston Medical Center
# 11  Fd82dkhX2pY  Vaccine Story: Rev. Willie Bodrick, II - Senio...
# 12  lu83Gig4O70  HSNC UNIVERSITY ADMISSION PROCESS FOR KC & HR ...
# 13  D8IfVhGWkvQ  DELHI UNIVERSITY & IPU BEST MASS MEDIA COLLEGE...
# 14  21Sk4c8UpVY  تطبيق seed4.me لتشغيل الواتس اب و الفايبر رغم ...
# 15  3FqBMwNq_5o  حل مشكلة التعليق و فشل تنزيل و خطأ في تحليل ال...
# 16  Ac-L2nopy5s     طريقة عمل حساب جديد على ال فيس بوك من الموبايل
# 17  jsw52zj_7nc   Another shitty one jdsfsdj (captions again bruv)
# 18  MvKvPhb4UsU                    Feliz Cumpleaños | LaPildora CO
# 19  HsyxE7irZSc  TBjack313 - rockstar (official music video) @T...
# 20  m0LZVcjQCsE              @TBjack313 - skrilla (official video)
# 21  _EQ2-wNJq0c            @TBjack313 - real ones (official video)
# 22  cSpA0Lywc14                   Treatment for Burns of all Types
# 23  wx42wgGKNsg  Blk 40 Tanglin Halt- EM and Fujitec Accompanie...
# 24  lpXAhP0TpmA  Free fire all mod best killing moment.My fries...
# 25  BtDfJt8JmmE  Back To School Q and A | ❌PLICIT Mom/ Daughter...
# 26  DLJeaDYSkRI  Boric Acid Suppositories Reviews for BV and Ye...
# 27  MT2IF-FMQsI           Italy Towel Korean Beauty Secret Exposed
# 28  HPQ9M_z8EdU  Salux Cloth The Dry Skin Cure You've Never Hea...
# 29  p8GrSkQ7GiQ       Yoni Steam Herbs & Supplies For DIY Steaming
# 30  Fm6X3eVidQs  How To Position Trade, Trading Risks & Managin...
# 31  T7CizQR1szs  Top Trading Indicators To Use For Position Tra...
# 32  pgDac6A6D8Y  How The Forex Market Moves & How To Measure Yo...
# 33  aGZzW7KeBAs                 Drake x Future Type Beat - "Mouse"
# 34  ACWsYeYWx60  Gotham Knights Gameplay | Story | Abilities | ...
# 35  beLxHhnQ8Vg  Malaysian Food In Korea & HALAL Korean Fried C...
# 36  UBvhOj0HztE  Rapid Rec | The Field Guide to the North Ameri...
# 37  cy1Vjz9dTRU                            Belgrade Blueberry Beer
# 38  n-C0cMBNJwU                                      cfgs chagdeba
# 39  XLUskGNGHDI  Medical City Plano and Medical City Frisco Eme...
# 40  0DjoQ3PdCEw  New Procedure Offers Hope to Treat Advanced Ab...
# 41  UokeBHBX6YU                  Hospital Stay After Joint Surgery
# 42  qxvtYeh2EUs  Therapy Dog Brings Joy to Patients and Staff a...
# 43  Ix3m3DSa-C8                Signs & Symptoms of West Nile Virus
# 44  EO70wJR_9Q8    Hyperbaric Oxygen Therapy at Medical City Plano
# 45  mNnWujUykTc           Emergency Services at Medical City Plano
# 46  nBnhhZNFH-w  Advanced Orthopedics, Trauma and Rehab at Medi...
# 47  Q5gmIyby48M  High Cholesterol: Dangers, Targets and Prevent...
# 48  qV_OyYyGxR4  Burn patient receives collaborative care from ...
# 49  uiukSrmsha0  Nếu người ấy say gọi điện cho bạn, họ sẽ nói g...
#
#    manual_caption_languages automatic_caption_orig_language language  \
# 0                        en                              en       en
# 1                        en                              en       en
# 2                        en                              en     None
# 3                     en,es                              en       en
# 4                     en,es                              en       en
# 5      en-US,en-uYU-mmqFLq8                              en       en
# 6                        en                              id       id
# 7            en-uYU-mmqFLq8                              en     None
# 8                        en                              en     None
# 9                        en                              en     None
# 10                       en                              en       en
# 11           en-eEY6OEpapPo                              en       en
# 12                    en-IN                              en       en
# 13                    en-IN                           en-IN     None
# 14                       en                              en       en
# 15                       en                              ru       ru
# 16                       en                              en     None
# 17                    en-GB                           en-GB     None
# 18                    en-US                              es       es
# 19                       en                              en       en
# 20                       en                              en       en
# 21                       en                              en       en
# 22                       en                              en       en
# 23                    en-GB                           en-GB     None
# 24                       en                              en       en
# 25                       en                              en       en
# 26                       en                              en       en
# 27                       en                              en       en
# 28                       en                              en       en
# 29                       en                              en       en
# 30                    en-US                              en       en
# 31                    en-US                              en       en
# 32                    en-US                              en       en
# 33                    en-US                           en-US     None
# 34                       en                              en       en
# 35                       en                              en       en
# 36                       en                              en       en
# 37                       en                              en     None
# 38                       en                              en     None
# 39                       en                              en       en
# 40                       en                              en     None
# 41                       en                              en       en
# 42                       en                              en     None
# 43                       en                              es       es
# 44                       en                              en       en
# 45                       en                              en       en
# 46                       en                              en       en
# 47                       en                              en       en
# 48                       en                              en       en
# 49                    en-US                              vi       vi
#
#          man_cap_langs_2           filtered_langs   download_lang
# 0                     en                     [en]              en
# 1                     en                     [en]              en
# 2                     en                     [en]              en
# 3                  en,es                     [en]              en
# 4                  en,es                     [en]              en
# 5   en-US,en-uYU-mmqFLq8  [en-US, en-uYU-mmqFLq8]           en-US
# 6                     en                     [en]              en
# 7         en-uYU-mmqFLq8         [en-uYU-mmqFLq8]  en-uYU-mmqFLq8
# 8                     en                     [en]              en
# 9                     en                     [en]              en
# 10                    en                     [en]              en
# 11        en-eEY6OEpapPo         [en-eEY6OEpapPo]  en-eEY6OEpapPo
# 12                 en-IN                  [en-IN]           en-IN
# 13                 en-IN                  [en-IN]           en-IN
# 14                    en                     [en]              en
# 15                    en                     [en]              en
# 16                    en                     [en]              en
# 17                 en-GB                  [en-GB]           en-GB
# 18                 en-US                  [en-US]           en-US
# 19                    en                     [en]              en
# 20                    en                     [en]              en
# 21                    en                     [en]              en
# 22                    en                     [en]              en
# 23                 en-GB                  [en-GB]           en-GB
# 24                    en                     [en]              en
# 25                    en                     [en]              en
# 26                    en                     [en]              en
# 27                    en                     [en]              en
# 28                    en                     [en]              en
# 29                    en                     [en]              en
# 30                 en-US                  [en-US]           en-US
# 31                 en-US                  [en-US]           en-US
# 32                 en-US                  [en-US]           en-US
# 33                 en-US                  [en-US]           en-US
# 34                    en                     [en]              en
# 35                    en                     [en]              en
# 36                    en                     [en]              en
# 37                    en                     [en]              en
# 38                    en                     [en]              en
# 39                    en                     [en]              en
# 40                    en                     [en]              en
# 41                    en                     [en]              en
# 42                    en                     [en]              en
# 43                    en                     [en]              en
# 44                    en                     [en]              en
# 45                    en                     [en]              en
# 46                    en                     [en]              en
# 47                    en                     [en]              en
# 48                    en                     [en]              en
# 49                 en-US                  [en-US]           en-US

# %%
subsampled_df[["id", "manual_caption_languages", "download_lang"]].to_json("logs/data/download/1M_en/subsampled_ids.json", orient="records", lines=True)

# %%
import json

with open("logs/data/download/1M_en/subsampled_ids.json", "r") as f:
    subsampled_dicts = [json.loads(line) for line in f]

# %%
rng = np.random.default_rng(42)
rng.shuffle(subsampled_dicts)

# %%
subsampled_dicts[:10]
# Out:
# [{'id': 'hahSCT7UYfE',
#   'manual_caption_languages': 'en-uYU-mmqFLq8',
#   'download_lang': 'en-uYU-mmqFLq8'},
#  {'id': 'YOxTr-KmtoU',
#   'manual_caption_languages': 'en',
#   'download_lang': 'en'},
#  {'id': 'hetgPN1Pmmo',
#   'manual_caption_languages': 'en-US',
#   'download_lang': 'en-US'},
#  {'id': 'qettCHgdKAU',
#   'manual_caption_languages': 'en-WJwqjBL5cw8,en-uYU-mmqFLq8',
#   'download_lang': 'en-WJwqjBL5cw8'},
#  {'id': '2-D6zNVqVvY',
#   'manual_caption_languages': 'en-uYU-mmqFLq8',
#   'download_lang': 'en-uYU-mmqFLq8'},
#  {'id': 'W9kG-knT7do',
#   'manual_caption_languages': 'en-1weAQujjfYU',
#   'download_lang': 'en-1weAQujjfYU'},
#  {'id': '7novyN7ZF6w',
#   'manual_caption_languages': 'en-q-YP8NOPts0,en-uYU-mmqFLq8',
#   'download_lang': 'en-q-YP8NOPts0'},
#  {'id': 'JenZpOb_now',
#   'manual_caption_languages': 'en-US',
#   'download_lang': 'en-US'},
#  {'id': 'MEbBC1i3ucI',
#   'manual_caption_languages': 'en-GB',
#   'download_lang': 'en-GB'},
#  {'id': 'qMbGM_F1A3s',
#   'manual_caption_languages': 'en-uYU-mmqFLq8,live_chat',
#   'download_lang': 'en-uYU-mmqFLq8'}]

# %%
subsampled_tuples = [(d["id"], d["download_lang"]) for d in subsampled_dicts]

# %%
subsampled_tuples[:10]
# Out:
# [('hahSCT7UYfE', 'en-uYU-mmqFLq8'),
#  ('YOxTr-KmtoU', 'en'),
#  ('hetgPN1Pmmo', 'en-US'),
#  ('qettCHgdKAU', 'en-WJwqjBL5cw8'),
#  ('2-D6zNVqVvY', 'en-uYU-mmqFLq8'),
#  ('W9kG-knT7do', 'en-1weAQujjfYU'),
#  ('7novyN7ZF6w', 'en-q-YP8NOPts0'),
#  ('JenZpOb_now', 'en-US'),
#  ('MEbBC1i3ucI', 'en-GB'),
#  ('qMbGM_F1A3s', 'en-uYU-mmqFLq8')]

# %%
with open("logs/data/download/1M_en/shuffled_subsampled_ids.json", "w") as f:
    for d in subsampled_dicts:
        f.write(json.dumps(d) + "\n")

# %%
subsampled_batches = [{f"batch_{i // 1000}": subsampled_dicts[i:i + 1000]} for i in range(0, 6000000, 1000)]

# %%
subsampled_batches_tuples = [{"videoIds": subsampled_tuples[i:i + 1000], "batchIdx": i // 1000} for i in range(0, 6000000, 1000)]

# %%
subsampled_batches_tuples[-1]
# Out:
# {'videoIds': [('1kSG0gDVvmY', 'en'),
#   ('_hALGphRLEE', 'en-ehkg1hFWq8A'),
#   ('U3xac534mEE', 'en'),
#   ('1cqzp47V4Jc', 'en-yGn0zlAHf04'),
#   ('UoMIxsepHvY', 'en-US'),
#   ('aZOlUO0f6fw', 'en'),
#   ('x5bEeaKBkeg', 'en'),
#   ('fHWrf-XkRdk', 'en-US'),
#   ('c64JrGjYL9c', 'en-RTbB2cpHawQ'),
#   ('BL1K7wrA73k', 'en'),
#   ('j-9p8INVN5Y', 'en-nP7-2PuUl7o'),
#   ('e3YAZSi-uHA', 'en-GB'),
#   ('bQrDaIYSOV8', 'en-uYU-mmqFLq8'),
#   ('2a-thABZcpM', 'en'),
#   ('TfeFv-wBeOc', 'en'),
#   ('wyQ1YpLFK5U', 'en-GB'),
#   ('4OrZ5OhCxjE', 'en'),
#   ('qBbHZMT9Y5U', 'en-uYU-mmqFLq8'),
#   ('_XTsTPKaZ8o', 'en'),
#   ('ZnDJbAPNVz0', 'en'),
#   ('q78z0Axl1MI', 'en'),
#   ('hpYUGIL8Ew8', 'en'),
#   ('wr4E81B8vnQ', 'en'),
#   ('AHpX25o2iH8', 'en'),
#   ('jJKLVi5K0VI', 'en'),
#   ('bK1icqYTbSQ', 'en'),
#   ('Mo-lwPeouN4', 'en'),
#   ('glbQlYjwBIE', 'en-US'),
#   ('fWOE5FEeMC4', 'en-IN'),
#   ('qDkg8pgiwrY', 'en-GB'),
#   ('AfvHGHP01BE', 'en'),
#   ('QkPN9P5lYZk', 'en'),
#   ('Vvvrs3fiB7w', 'en'),
#   ('rqcPMoNgb4E', 'en-US'),
#   ('iX3X6YXooLQ', 'en'),
#   ('HMMPRnK2H3Q', 'en'),
#   ('wmFRBP0BdrU', 'en'),
#   ('QUHqO_9YwWU', 'en-US'),
#   ('wq9UnsnEHHQ', 'en'),
#   ('EVrscvj6kEc', 'en-US'),
#   ('zXUnWYRseVQ', 'en'),
#   ('S1q1LK-BKVA', 'en-CA'),
#   ('W55Z3aEGeEc', 'en'),
#   ('cfg74054dT4', 'en'),
#   ('Z95zvKYqZ3E', 'en'),
#   ('gNm7sh_h2xI', 'en'),
#   ('FtkFQv-1IAo', 'en-uYU-mmqFLq8'),
#   ('cRoYG_J48b4', 'en'),
#   ('o0WdDABNB0Y', 'en-uYU-mmqFLq8'),
#   ('AtSg8Oh8wCQ', 'en'),
#   ('k7s__dCDpyA', 'en-ehkg1hFWq8A'),
#   ('4vCZ53AEgA0', 'en-US'),
#   ('ysoXgtNW5MA', 'en'),
#   ('_gvPXVfjiwI', 'en'),
#   ('gT7iwkDIseA', 'en-nP7-2PuUl7o'),
#   ('jdAo-PDOgKE', 'en-CbwH8mx86EM'),
#   ('461OPH2WyaM', 'en-uYU-mmqFLq8'),
#   ('xdpQWyeTcsM', 'en'),
#   ('6rq1i4yCGeQ', 'en-uYU-mmqFLq8'),
#   ('nKZBM3_fJ0Y', 'en'),
#   ('F1rnQrNsnlI', 'en'),
#   ('WZUbAiWk7Dg', 'en-US'),
#   ('alV9w5t7pao', 'en'),
#   ('Hy-zymdxVDA', 'en-uYU-mmqFLq8'),
#   ('fq3uawclOLs', 'en'),
#   ('m5-HQvSS4p4', 'en'),
#   ('rDuxOsXxw0o', 'en'),
#   ('kcDoCGmBY1Y', 'en'),
#   ('tChSqOUYVyA', 'en'),
#   ('DJ79cU7CPU8', 'en-GB'),
#   ('vyS4pwMNMQQ', 'en-Bb9eRC69SK0'),
#   ('j-6KrCMHjS4', 'en-US'),
#   ('3ekA1fVx1Bk', 'en'),
#   ('OnnljuaDX-M', 'en-0hllRZe4s5s'),
#   ('I-e37-LL8Cg', 'en'),
#   ('S0efTKgq3Pk', 'en'),
#   ('y1RrSbk-B4g', 'en'),
#   ('fc1BQUjpeHY', 'en'),
#   ('XRHkw-xCVq0', 'en-US'),
#   ('97LcBtdZiKg', 'en'),
#   ('2V6Qtc__1a8', 'en'),
#   ('bbkxvn23lMU', 'en-CA'),
#   ('iUmdDQatWE4', 'en'),
#   ('HLIwfRKv9Dw', 'en-IN'),
#   ('OprIa6d3C2c', 'en'),
#   ('sgaiUsInmKU', 'en-US'),
#   ('3B7Pqho8SU0', 'en'),
#   ('DxDvz88CjRA', 'en-GB'),
#   ('PM6KjxvDd5k', 'en-RTbB2cpHawQ'),
#   ('QbKKnReGwgM', 'en-nP7-2PuUl7o'),
#   ('6urYuOWK48E', 'en'),
#   ('yythxWhoOdw', 'en-nP7-2PuUl7o'),
#   ('2CXPg-ydyJY', 'en-GB'),
#   ('2S45n-s52W8', 'en-US'),
#   ('xGWVPgQCY5s', 'en-GB'),
#   ('_8h1x3GZBOY', 'en'),
#   ('00PPkXO6oDM', 'en'),
#   ('9m1NWznUIm8', 'en'),
#   ('dSl6nzC4JjM', 'en'),
#   ('DJBw5NKMqOg', 'en'),
#   ('5T0Qa_z2tkA', 'en'),
#   ('IViJGww6kx8', 'en-US'),
#   ('Z6DNPkW47Og', 'en'),
#   ('uEOVoo8D7Cw', 'en-GB'),
#   ('bg6RwctbUok', 'en'),
#   ('7NDJn45NoG0', 'en-uYU-mmqFLq8'),
#   ('_dG6-vppWS8', 'en'),
#   ('CEkmU_jpDCE', 'en'),
#   ('_ZL6-UGrfQA', 'en'),
#   ('FjH7-qKBap4', 'en-uYU-mmqFLq8'),
#   ('Xr7cqcIHDdQ', 'en-US'),
#   ('5DuPkC6uZC4', 'en-US'),
#   ('RTJkTXEFh1I', 'en-ehkg1hFWq8A'),
#   ('_aau585JNbc', 'en'),
#   ('OOB-5p-jdhk', 'en'),
#   ('wk_5d86udvw', 'en'),
#   ('yDNFbz9dkFk', 'en'),
#   ('I-rtcmttGqQ', 'en-uYU-mmqFLq8'),
#   ('VBLbqZicwOY', 'en'),
#   ('bIbyVeBd-k8', 'en-US'),
#   ('YsGiCwzXH_o', 'en'),
#   ('mZxwwSrDNo8', 'en'),
#   ('1bhqUZooG_8', 'en-i7LFIGUQP0g'),
#   ('92bgbCeEuxU', 'en-CA'),
#   ('H_C50OZkrVs', 'en'),
#   ('dWtuhT-KYkA', 'en'),
#   ('FIpm2xbNcHc', 'en'),
#   ('lEGTh6BIpA8', 'en'),
#   ('xcoevQ-1jvI', 'en-IN'),
#   ('0ybVmas7gWs', 'en'),
#   ('21f80dZ43no', 'en-US'),
#   ('vmZAA0OyRcI', 'en-nP7-2PuUl7o'),
#   ('QG0hE0R_ng4', 'en-IN'),
#   ('iPH5dA6n2vI', 'en-rX01gsAdUfU'),
#   ('v5jf7KHOzbE', 'en-uYU-mmqFLq8'),
#   ('ZqwOicMNC1E', 'en'),
#   ('KUdz2_hmNwg', 'en'),
#   ('KvbkeqYM2zw', 'en'),
#   ('uYeYubA7syk', 'en'),
#   ('9Snu2NuL6eM', 'en-uYU-mmqFLq8'),
#   ('LM2PWViznS8', 'en-ZDdPN5tsLY4'),
#   ('DCMAgE_P7uM', 'en'),
#   ('-_M_LIzSnF8', 'en'),
#   ('Hf5MDyKk8V4', 'en-uYU-mmqFLq8'),
#   ('1HnpNMu56-E', 'en'),
#   ('UDmiECaIBXk', 'en'),
#   ('iaHMvTU-HuM', 'en-JkeT_87f4cc'),
#   ('03w9gTWf9W8', 'en'),
#   ('EwkUHn4If-s', 'en-i7LFIGUQP0g'),
#   ('2K-5Xu3FCww', 'en-nP7-2PuUl7o'),
#   ('c0nyd9KzZBw', 'en-GB'),
#   ('4uoCV0QS808', 'en'),
#   ('z2b98mPfHFc', 'en-uYU-mmqFLq8'),
#   ('6FxfwKOlBqU', 'en-uYU-mmqFLq8'),
#   ('JGNbbaxXxmw', 'en-US'),
#   ('Nxi0OUpx0wk', 'en'),
#   ('R-36E87cghc', 'en'),
#   ('qUmRRhd0cuI', 'en-IN'),
#   ('_T4ye5mc1Jg', 'en-nP7-2PuUl7o'),
#   ('CDaEdww7tsE', 'en'),
#   ('Syv-8vl08O8', 'en-uYU-mmqFLq8'),
#   ('xhmrLvYGhFk', 'en-VjEpQ-RlAYk'),
#   ('IkHOcjaGoa0', 'en-US'),
#   ('XTd2UWjs09w', 'en-uYU-mmqFLq8'),
#   ('3l8quEM35z0', 'en'),
#   ('UH_RUD7rrRk', 'en-RTbB2cpHawQ'),
#   ('uoLfRoQeMh8', 'en-US'),
#   ('fOTOBfH9eno', 'en'),
#   ('EQzKSfmg33E', 'en-US'),
#   ('E1pRvAleTQ8', 'en'),
#   ('hpvqw3q2dLU', 'en'),
#   ('1FKW96cQLmE', 'en-US'),
#   ('MlhyNPQ2560', 'en'),
#   ('i2NxjWvnavg', 'en'),
#   ('1fZLlGPwfCY', 'en'),
#   ('T9A9xDAcuH4', 'en'),
#   ('E_kIB8Ci0NI', 'en-nP7-2PuUl7o'),
#   ('ll_yD8O7MfA', 'en'),
#   ('WC1QbVIw5II', 'en'),
#   ('IHQ-Y8vFs3I', 'en'),
#   ('aL2lla4gUQg', 'en'),
#   ('XhYx1wl7Zb0', 'en'),
#   ('hTL4Eh3pCEM', 'en'),
#   ('8HZtbp45AZo', 'en-hnCuwW0TCiQ'),
#   ('9fyR9SWmpPY', 'en'),
#   ('TdcdXE2ChcY', 'en'),
#   ('o_2LrUvcOPk', 'en'),
#   ('gHvBoFBJhMM', 'en'),
#   ('OFRZH_MPsoo', 'en'),
#   ('ZAy9t8QCkgk', 'en'),
#   ('fxXn-I_QWZs', 'en-nP7-2PuUl7o'),
#   ('hY91zVrD3Ag', 'en'),
#   ('l1y_w4RrYXI', 'en'),
#   ('g9TDJmLpgKQ', 'en'),
#   ('wRtR750Bsd8', 'en'),
#   ('eAYpKgJhx1U', 'en'),
#   ('tg189gkGTzM', 'en'),
#   ('zdmuEdoKoGU', 'en'),
#   ('OmnBpSBnilU', 'en'),
#   ('btKtZBiuTtQ', 'en'),
#   ('GRaZ5WYS-M8', 'en'),
#   ('Q5ut_MCnoIY', 'en'),
#   ('EQF6QXOIFKk', 'en-E3euOu7LhIg'),
#   ('324sYkBijF4', 'en-US'),
#   ('hFp0oq8dugA', 'en'),
#   ('iLMa5LIk7ms', 'en'),
#   ('BrKXPZFED7U', 'en'),
#   ('OmiRPHi8o24', 'en'),
#   ('df4WT6mDnx0', 'en'),
#   ('U0AyYF2sWok', 'en'),
#   ('Covo-3EVNMw', 'en'),
#   ('it8QQM5eaog', 'en'),
#   ('PSbRsaOuUNI', 'en-v0mWmvJhcr0'),
#   ('O3nwY0xY7mU', 'en'),
#   ('oIoUqRmJ70Y', 'en-US'),
#   ('XRmIx0ZUhtU', 'en'),
#   ('fGFqwS0UZbY', 'en'),
#   ('ObxrrP8tBsc', 'en'),
#   ('YlQPlUNt5s8', 'en-uYU-mmqFLq8'),
#   ('ow8lrUmgizQ', 'en'),
#   ('Rlx-SL1RlaE', 'en-mrXZSxv27wo'),
#   ('Gb3leRY0yEQ', 'en'),
#   ('RZemQMtr3bI', 'en'),
#   ('wq8Zi-hNaRA', 'en'),
#   ('j7xWXKv9ckQ', 'en'),
#   ('5RaTLDaypC4', 'en'),
#   ('UF9kOf8Rpec', 'en-uYU-mmqFLq8'),
#   ('AR7UpX2_AIc', 'en'),
#   ('qihTylHtbpo', 'en-nP7-2PuUl7o'),
#   ('y35VTA0NuRk', 'en-U-2MYTshV4Q'),
#   ('L1fKKeKy2yU', 'en'),
#   ('HGnnsMafNuw', 'en'),
#   ('3WzEVwaxeII', 'en'),
#   ('7kqAvL36RkA', 'en'),
#   ('tVy3ccEbTJ0', 'en'),
#   ('oLYZOYNHTks', 'en-IN'),
#   ('2pQnMk6yMv0', 'en'),
#   ('GEGciPeegkw', 'en-US'),
#   ('QJhe9CQh_2o', 'en'),
#   ('TFGJXUtY55c', 'en'),
#   ('ZyQujyRX6xY', 'en'),
#   ('H4UKr_CswXU', 'en-nP7-2PuUl7o'),
#   ('rQ1NMRKJzj0', 'en-uYU-mmqFLq8'),
#   ('cw7fU7PRSK8', 'en-nP7-2PuUl7o'),
#   ('VBORwUuU5GY', 'en'),
#   ('6oy569epm8Y', 'en-9fXO75lTcLY'),
#   ('cBdTzOnDoXw', 'en'),
#   ('YhKYZsEXv7U', 'en'),
#   ('XVgebDFi3Co', 'en'),
#   ('Kv8A9h2ZGNM', 'en'),
#   ('3CjnPoYGOxA', 'en'),
#   ('T5G1hHtx0V4', 'en-uYU-mmqFLq8'),
#   ('vGEutk5PJyw', 'en-CA'),
#   ('2e8mL806Dvw', 'en-j3PyPqV-e1s'),
#   ('s_8u2xU2Xjk', 'en'),
#   ('Oj654LGCbpY', 'en-uYU-mmqFLq8'),
#   ('eiLYXDhL22o', 'en-US'),
#   ('-4QTM2fo7CI', 'en'),
#   ('qT4EqsVrqDo', 'en'),
#   ('8JMCdjvdc2Q', 'en-uYU-mmqFLq8'),
#   ('-Cxek6YbPoU', 'en'),
#   ('Pw8VjJ0vIcA', 'en'),
#   ('dGOTOkS07Ig', 'en-RTbB2cpHawQ'),
#   ('YUmF6n6tnz0', 'en'),
#   ('CZnJoQmKfCs', 'en-US'),
#   ('zacKQFkypGE', 'en-uYU-mmqFLq8'),
#   ('A9gY0GyNhTc', 'en'),
#   ('neAFEvNsiqw', 'en'),
#   ('OzqDVTYhnoA', 'en-nP7-2PuUl7o'),
#   ('ZoKCCj2ChK4', 'en-uYU-mmqFLq8'),
#   ('ckZchGUHcjg', 'en'),
#   ('QNe5FL76Llc', 'en-US'),
#   ('VGW9ifpU6PI', 'en-US'),
#   ('gm-Rz_oL8HI', 'en-US'),
#   ('CZVPVlg_gpw', 'en-uYU-mmqFLq8'),
#   ('VT04K4V85hk', 'en'),
#   ('sm6iwlcSdRU', 'en-nP7-2PuUl7o'),
#   ('yUMMca7iSOY', 'en'),
#   ('HMrHskqElVo', 'en'),
#   ('OEl1boDODH4', 'en-CA'),
#   ('QLfHEjT71WE', 'en-eEY6OEpapPo'),
#   ('-4ebjd-BJ94', 'en-US'),
#   ('Nq0Ya4zHoLg', 'en'),
#   ('opv5ARMe2Uk', 'en-ehkg1hFWq8A'),
#   ('Mhpda4fWO0U', 'en'),
#   ('9BGhx2OqG4E', 'en'),
#   ('nRbG1a2bduo', 'en-thYHmXxJoEw'),
#   ('U-aulndn3UU', 'en'),
#   ('BGrl7d73Z9s', 'en-IN'),
#   ('Cu3XtguylR8', 'en-uYU-mmqFLq8'),
#   ('Ockbgqap7hg', 'en-RTbB2cpHawQ'),
#   ('H6P1FM6bbUI', 'en-uYU-mmqFLq8'),
#   ('ZIp63Q8FBOw', 'en'),
#   ('wW1bnE5G0aA', 'en-RTbB2cpHawQ'),
#   ('nMZEzWOFkIM', 'en-wUMCMe1Ek2Q'),
#   ('36Jxrs5cvpI', 'en-US'),
#   ('wa3ncLwOwHc', 'en-uYU-mmqFLq8'),
#   ('Qv5cHCrnHKA', 'en'),
#   ('H6OD4_l9DVQ', 'en-m8DiAxbKPiw'),
#   ('tXhLpSvk6LE', 'en'),
#   ('S23Koz9jf20', 'en'),
#   ('tiA9NDgEa3k', 'en-nP7-2PuUl7o'),
#   ('Lu5ZLKAUr_E', 'en'),
#   ('F0IjFYlIgH8', 'en-JkeT_87f4cc'),
#   ('ZM_J_uC5QmM', 'en'),
#   ('TMOaN3qEy7w', 'en-US'),
#   ('cDbC9CWDvQA', 'en-US'),
#   ('39RIsSgVJ7Y', 'en'),
#   ('FHZ1I4nkQ9w', 'en'),
#   ('auwypxCUKB8', 'en-GB'),
#   ('cyZgc8SNR4A', 'en'),
#   ('7XLRnwuywa0', 'en'),
#   ('Ph4c472LQrI', 'en-uYU-mmqFLq8'),
#   ('8tHef2EMgg4', 'en'),
#   ('JwyCuYQlSe4', 'en'),
#   ('rgDu094Jsfo', 'en-IN'),
#   ('0WXc2KH2KKs', 'en'),
#   ('3b4tU2Jlb1k', 'en'),
#   ('hZmAFzxtohw', 'en-US'),
#   ('ZAUCII79VcE', 'en'),
#   ('WgnuxGh2hBk', 'en'),
#   ('mPf9cpNBq5g', 'en-GB'),
#   ('rfihYBhym04', 'en'),
#   ('Cmnq9c3EJPo', 'en-JkeT_87f4cc'),
#   ('7NmklaTWO_8', 'en-CA'),
#   ('4NbalXY3Xt4', 'en'),
#   ('v5Rb5OkPNEM', 'en'),
#   ('cRNHycLA4pg', 'en'),
#   ('0rNTMQdbJ04', 'en-HK2uFMokY8w'),
#   ('R2b_S7XdW2c', 'en'),
#   ('_dJmz4L2K-0', 'en-uYU-mmqFLq8'),
#   ('rUBmTZYNegI', 'en'),
#   ('mlXq6F15vHs', 'en'),
#   ('ZieIKoVkkBQ', 'en-uYU-mmqFLq8'),
#   ('io_9qpHnFlM', 'en'),
#   ('zRu0sNOZUdk', 'en-uYU-mmqFLq8'),
#   ('851pCwAZWsY', 'en'),
#   ('r467mrCbriw', 'en-US'),
#   ('X1aAOUNY8eo', 'en-nP7-2PuUl7o'),
#   ('KGfWZgx6QVc', 'en'),
#   ('y3YlFygCBis', 'en'),
#   ('fOqhZBvifPk', 'en'),
#   ('lHeoT0CIONs', 'en-uYU-mmqFLq8'),
#   ('tjSxFAGP9Ss', 'en'),
#   ('wDTfHha9B8A', 'en-GB'),
#   ('djnvZrTm3Qk', 'en'),
#   ('ES4wmAITJ-c', 'en-GB'),
#   ('XfaNH7tM0Mk', 'en-GB'),
#   ('LMLtGDKZtJ0', 'en-US'),
#   ('qOJQZJClThk', 'en-US'),
#   ('8_kbG3efOPc', 'en'),
#   ('gJPpsag37AU', 'en'),
#   ('5SyCE3PC7bM', 'en'),
#   ('JWalL_RlCHA', 'en'),
#   ('xCCy-OsGbjY', 'en-anMIXjicSL4'),
#   ('3mOLqcnttIY', 'en'),
#   ('61pnWY6UhW4', 'en'),
#   ('GpdgCbcGe-Q', 'en'),
#   ('GVnAAw0l5tw', 'en'),
#   ('HiB3kMZl9tQ', 'en'),
#   ('aAvqnTu_TF0', 'en-uYU-mmqFLq8'),
#   ('F7kklBtsuE4', 'en-US'),
#   ('-HrILrhnSoU', 'en'),
#   ('-SvdTR3stQw', 'en-uYU-mmqFLq8'),
#   ('is_N8JDUuEs', 'en'),
#   ('BAGak27LddQ', 'en-GB'),
#   ('j8dAgBCDrxc', 'en'),
#   ('hr9HqvqvP5A', 'en-CA'),
#   ('brLfDuKDzYg', 'en'),
#   ('GrYTdtEakKU', 'en-US'),
#   ('Jti1SqmGI6U', 'en'),
#   ('SQnkNN0ejL0', 'en'),
#   ('m28cAr2BuTg', 'en-US'),
#   ('VQpKvmP6ISY', 'en-US'),
#   ('WE_1g9I7NAM', 'en'),
#   ('O3PLo960QvE', 'en'),
#   ('baOpmGd0PVU', 'en'),
#   ('wjvk0w7lSaI', 'en-US'),
#   ('Rm5AtenVwks', 'en'),
#   ('yz5Ygy3BEWU', 'en-US'),
#   ('GfU8yuEet0w', 'en-US'),
#   ('If5asuPxDKM', 'en'),
#   ('4v4BIEbJaMk', 'en-vVBWihXbEy0'),
#   ('7qhiLn7GLA0', 'en'),
#   ('lbkWq1qWcZ8', 'en'),
#   ('WXSmnBG3Pds', 'en'),
#   ('WvFHoMFozP8', 'en-lcmonCS91KQ'),
#   ('zQUSdSxPwuU', 'en-nP7-2PuUl7o'),
#   ('QqLZ5eSfFbI', 'en-GB'),
#   ('6-0n4FOprIw', 'en-uYU-mmqFLq8'),
#   ('LmMCRHSvVZ4', 'en'),
#   ('P1O_U9yqhYI', 'en'),
#   ('dwVBrJ2CXLA', 'en-U7npZ5qOolg'),
#   ('4X2_wIGDE7M', 'en'),
#   ('aVKDRbk-S8k', 'en-uYU-mmqFLq8'),
#   ('c5eVwfFKJtI', 'en'),
#   ('c6WubjrDNJQ', 'en-uYU-mmqFLq8'),
#   ('llUqkdwQNYM', 'en-uYU-mmqFLq8'),
#   ('Log6RnrusfY', 'en'),
#   ('dx4wUPIhRws', 'en-US'),
#   ('NSeKCBTFC18', 'en'),
#   ('pSMPVeaHxeU', 'en'),
#   ('6U6eNQf6n34', 'en-uYU-mmqFLq8'),
#   ('Ozw1XWA883o', 'en-nP7-2PuUl7o'),
#   ('72jiWo7S1ZY', 'en-nP7-2PuUl7o'),
#   ('NTrdeWxxMgQ', 'en'),
#   ('OBI54xujkN0', 'en'),
#   ('nF9a7X_iBPI', 'en-zL7EZQmMa4Q'),
#   ('7y_3b_zCMNE', 'en'),
#   ('7k2o4DeP8Pk', 'en'),
#   ('OmEbxUD4spw', 'en-yzlRvDSUTn8'),
#   ('ZzpPw-NFzdE', 'en-vlW2OHFw3ww'),
#   ('-7UIRof_2iw', 'en'),
#   ('cMSWlMuAsdU', 'en'),
#   ('Y8lTdDpeC7Y', 'en'),
#   ('CtSJDjmayI0', 'en-US'),
#   ('zUpTzwznzFY', 'en'),
#   ('L55J2W1zqMY', 'en-US'),
#   ('-ZhIgoID90w', 'en'),
#   ('cyg8OmgZOnE', 'en-uYU-mmqFLq8'),
#   ('bebIH4XHqHc', 'en-US'),
#   ('GdWxck6zgFs', 'en-US'),
#   ('-fjgb3zb9qc', 'en-uYU-mmqFLq8'),
#   ('EGFyatxX4pk', 'en-US'),
#   ('IX-7U-Vv5o4', 'en'),
#   ('JDyy9ypw8gY', 'en-nP7-2PuUl7o'),
#   ('vLGa1-C-msY', 'en-qoXxhA4oLYo'),
#   ('A4TdW1dQvCg', 'en-uYU-mmqFLq8'),
#   ('JYRQgTRdEtg', 'en-IN'),
#   ('UOOWLihU6O0', 'en-E7jCWwwNYJg'),
#   ('ldX3YQ31REM', 'en-US'),
#   ('xBb0QaMaAFE', 'en-US'),
#   ('gbdTkDEAmco', 'en'),
#   ('R1faazKXU5g', 'en'),
#   ('NGpvaX3pShw', 'en'),
#   ('I2vfrqfsiEw', 'en'),
#   ('XX0SP58EZwA', 'en'),
#   ('69JbCFLJHAU', 'en'),
#   ('WnWO10v5EY4', 'en'),
#   ('dRkilHkpX5g', 'en'),
#   ('rhBNXYSOsco', 'en'),
#   ('iLl1H2sVlkU', 'en-CA'),
#   ('PtSSejgDJtQ', 'en'),
#   ('A_kD6RXTLhs', 'en'),
#   ('YqoOmSTvW2g', 'en-US'),
#   ('akxE7O5tWSs', 'en-GB'),
#   ('UPOyNntybk8', 'en'),
#   ('tpAoCf5sGhQ', 'en-iQ4tIeK26yM'),
#   ('ih6IQztGJug', 'en'),
#   ('yPfoy2xpHdg', 'en-JkeT_87f4cc'),
#   ('bdLQfxlWL68', 'en-uYU-mmqFLq8'),
#   ('pn9T_rQnRSA', 'en-uYU-mmqFLq8'),
#   ('MrM1kD5dUSI', 'en'),
#   ('NU7LT2gpglU', 'en-rNeeJrcpviU'),
#   ('ASJsM-v_MSY', 'en-US'),
#   ('-COUAj4Lbuk', 'en'),
#   ('1S8NuFDf78c', 'en-US'),
#   ('gfp8_okjX3I', 'en-nP7-2PuUl7o'),
#   ('mX3XaM9aQB8', 'en-US'),
#   ('w4hFfWfkZpw', 'en-US'),
#   ('fvR3aa91MU4', 'en-US'),
#   ('ATFD-16fmZs', 'en'),
#   ('bYGzBHBq6YI', 'en-GB'),
#   ('xnoclScTt5Y', 'en'),
#   ('qMcSkj9UZj0', 'en-US'),
#   ('uCyB9fqOaCI', 'en-EfBjBWaqzDk'),
#   ('Iqon2M615vo', 'en'),
#   ('FPZya_P73hU', 'en-nP7-2PuUl7o'),
#   ('4zibjtD7Ew4', 'en'),
#   ('wzO71p9yxec', 'en'),
#   ('fo3Z0eEfz8E', 'en'),
#   ('S6mjZq4AbNs', 'en'),
#   ('i8x7yOrabtY', 'en-eEY6OEpapPo'),
#   ('UhrF6NUbJ2U', 'en-GB'),
#   ('0NjwhAv2bV0', 'en'),
#   ('jX16Hx9oUxs', 'en-rX01gsAdUfU'),
#   ('qKJV8mRlYvo', 'en'),
#   ('86eGXGUmRls', 'en'),
#   ('fx4dyQtL5Sg', 'en-GB'),
#   ('q30_s1kiQws', 'en-nP7-2PuUl7o'),
#   ('4nH_wgrFW-I', 'en-RTbB2cpHawQ'),
#   ('sSodkc5VsKU', 'en'),
#   ('be48zuMDmvM', 'en'),
#   ('8l369Ov2MBY', 'en'),
#   ('gPNtaewZBeA', 'en'),
#   ('THzQ7147v2Y', 'en'),
#   ('svnCnR92UPE', 'en'),
#   ('U9Om2F-TtOA', 'en'),
#   ('knwzGwZTMqc', 'en'),
#   ('_EEh1_JF8eI', 'en'),
#   ('TE7BoPiIYec', 'en'),
#   ('hcfljSQ1mFA', 'en'),
#   ('3YPMCgWpVz8', 'en'),
#   ('aT2-GFX_3BA', 'en-nP7-2PuUl7o'),
#   ('kGSn5NXy8ps', 'en'),
#   ('e_aMaCsckx0', 'en'),
#   ('5_Yk3bGAVA4', 'en'),
#   ('5c3OCyrpKFc', 'en-uYU-mmqFLq8'),
#   ('6cG9kUBYr0c', 'en-imabS5-lp4g'),
#   ('_PIUQpKbeh4', 'en'),
#   ('8GaQWrGglxI', 'en'),
#   ('QqaETbfsNWM', 'en'),
#   ('4OuG0n3oKF0', 'en'),
#   ('O3pgBkepSVY', 'en-1oAFzPNiuC0'),
#   ('iwWxvBwH-c0', 'en'),
#   ('pDkCpLBPeA4', 'en'),
#   ('aTc7eb9ilvM', 'en-RTbB2cpHawQ'),
#   ('VqemIRl0WuI', 'en-GB'),
#   ('jTE_KUrASFE', 'en-US'),
#   ('N1odvL8TxNU', 'en-uYU-mmqFLq8'),
#   ('K6tBOuTakwY', 'en-nP7-2PuUl7o'),
#   ('o1ZqAYza0DU', 'en'),
#   ('wXIZriBqZWM', 'en'),
#   ('xp0L4qCLiRQ', 'en-At-FBsaMiko'),
#   ('eilmzFiU1Ok', 'en'),
#   ('hfLuYA7U8_Q', 'en-US'),
#   ('Cx9QrRUg7_s', 'en'),
#   ('OcTMQsoqlKQ', 'en'),
#   ('ns2hUDiOPLE', 'en-v3Ix30JOZGE'),
#   ('KhuON5gvWuE', 'en-US'),
#   ('fi8Z7QvjflY', 'en'),
#   ('AF4QGePz0kg', 'en'),
#   ('haOoBrVUGtc', 'en-US'),
#   ('y1thbed0-mA', 'en'),
#   ('iloQeVDSxT4', 'en-uYU-mmqFLq8'),
#   ('fthhTGWk6J4', 'en-US'),
#   ('hzlzd5I7v3A', 'en'),
#   ('ur-s2xaTIUE', 'en-GB'),
#   ('OzBHdQVtVkw', 'en-rX01gsAdUfU'),
#   ('cDF9Qit0EdM', 'en'),
#   ('GdEg_hJoVLU', 'en-uYU-mmqFLq8'),
#   ('psGf7JWxk68', 'en'),
#   ('JRRM5CEVaAM', 'en'),
#   ('DC_IWj9RoSM', 'en'),
#   ('77SSmoXZJ7I', 'en-DLxmEfVUC9A'),
#   ('3v2C_jRLxIU', 'en'),
#   ('COJ6lmGmuXE', 'en'),
#   ('vjIZHtmXHHA', 'en'),
#   ('VRYD5cbZxZ8', 'en-US'),
#   ('DbQH3UH2sOU', 'en'),
#   ('fIn913c4JGQ', 'en'),
#   ('8xge2NpA0yo', 'en'),
#   ('s-N5tsTYqcY', 'en'),
#   ('itW6b3oKX2c', 'en-IN'),
#   ('riHwgGiIvxQ', 'en-RTbB2cpHawQ'),
#   ('35gV4NWQ1jQ', 'en'),
#   ('oefgRKcfFzQ', 'en-uYU-mmqFLq8'),
#   ('rsce8cCDbP4', 'en'),
#   ('UiKxJtNK98E', 'en'),
#   ('NRSfS-iUFpk', 'en-uYU-mmqFLq8'),
#   ('_c19iOUNNwA', 'en-nP7-2PuUl7o'),
#   ('t8b6XsE0GsA', 'en-US'),
#   ('oWC7PVWtMMw', 'en-US'),
#   ('X0jxUIyEdfM', 'en'),
#   ('J-AYeEyivMQ', 'en'),
#   ('D2L3aFQinjI', 'en-IN'),
#   ('u2cFysoNwIg', 'en-CA'),
#   ('65aLgC9J0fE', 'en-anMIXjicSL4'),
#   ('njjpBUMB8T4', 'en-US'),
#   ('tGKQtLWUOpM', 'en'),
#   ('54qMQf9KnIU', 'en-US'),
#   ('RkxcjslqMmM', 'en-US'),
#   ('hCtMAH5IcT8', 'en'),
#   ('_2NN3I-vsOs', 'en'),
#   ('OjVnm5FOPwQ', 'en'),
#   ('-2p7k4eMhN0', 'en-uYU-mmqFLq8'),
#   ('FfwH1Ax5hsE', 'en-RTbB2cpHawQ'),
#   ('RYL50RvNXqs', 'en-GB'),
#   ('-cZhmrBNxK0', 'en'),
#   ('MtN32H4sCXQ', 'en'),
#   ('X8ejIt6XOOg', 'en'),
#   ('wXkE91znynU', 'en'),
#   ('eWMz4n5EfyU', 'en-CA'),
#   ('L9IdjICBYGQ', 'en'),
#   ('BV_21nwR9kw', 'en'),
#   ('UliHQSkcEvU', 'en'),
#   ('ElAqfYjKI2Q', 'en-US'),
#   ('VQ5EfLsjaqA', 'en-US'),
#   ('fE29-C-tDM8', 'en-IN'),
#   ('xEjAhyAjgNw', 'en-US'),
#   ('Bq3bbp35-Ow', 'en-US-aGDv2vuZMSk'),
#   ('VOrjRbRRxso', 'en'),
#   ('gKeih1JqQhA', 'en-nP7-2PuUl7o'),
#   ('NJ0v8XCdXco', 'en-uYU-mmqFLq8'),
#   ('Jl-xNXHMntA', 'en'),
#   ('4LNNeyXjtc8', 'en'),
#   ('YzIYybZZb3c', 'en'),
#   ('hkwxnraIEOI', 'en'),
#   ('iIGWkNubaVQ', 'en-US'),
#   ('oskT_br3pzo', 'en'),
#   ('yAdLmKA-kVM', 'en'),
#   ('rbHtexS4ntY', 'en-uYU-mmqFLq8'),
#   ('3llTEQ7UENM', 'en'),
#   ('1KxFIZ3MOLQ', 'en'),
#   ('tR5Eae_cyWk', 'en-US'),
#   ('ctGH7gUFrUk', 'en-uYU-mmqFLq8'),
#   ('xx58OIrnApI', 'en-GB'),
#   ('niaoAF5orDg', 'en-nP7-2PuUl7o'),
#   ('igi6IoahLJw', 'en'),
#   ('TsXe5VPN5Qs', 'en'),
#   ('BsH6mPQWVCs', 'en'),
#   ('Sc5-4CfbZrU', 'en'),
#   ('jAK1ncCY10U', 'en-qlPKC2UN_YU'),
#   ('36OoP_OVFZg', 'en-US'),
#   ('hBBtaWmvNW8', 'en-uYU-mmqFLq8'),
#   ('nLkXJVBaChE', 'en'),
#   ('icIEktgAGb0', 'en-uYU-mmqFLq8'),
#   ('KvuBz0aBACQ', 'en'),
#   ('FP7KiDjxekI', 'en-US'),
#   ('s08ihpD_OKU', 'en-CA'),
#   ('HVd3NZnCZE8', 'en'),
#   ('hPz-G4lDTZY', 'en'),
#   ('xOeNHDlImug', 'en-US'),
#   ('B8OhdO1kmHo', 'en-n2W4vBs_ndc'),
#   ('GS_2mzXG8dU', 'en'),
#   ('DYkr4J1vqQM', 'en-zL_pKPa_d08'),
#   ('2UfYvtccB6M', 'en-nP7-2PuUl7o'),
#   ('kwl_mjt3stY', 'en-US'),
#   ('nXUcpSnmwCE', 'en-nP7-2PuUl7o'),
#   ('vPAdR4fHQFM', 'en'),
#   ('ct-Qu5sALF8', 'en-uYU-mmqFLq8'),
#   ('FErWYjbiUGc', 'en'),
#   ('1vtL2qh8n24', 'en'),
#   ('IbZD79nJ8Y8', 'en'),
#   ('vUwkC9JYhf4', 'en-US'),
#   ('sTls9kup0u8', 'en-US'),
#   ('iYpa-HbujvU', 'en-nP7-2PuUl7o'),
#   ('5UPoolXcIIM', 'en'),
#   ('zeuEFrDD4-o', 'en'),
#   ('QsKAhPdjrBg', 'en'),
#   ('mIekESmTi3w', 'en-US'),
#   ('rCZLizvc4Ls', 'en-mlFj4X0195A'),
#   ('HsEjjJoehI4', 'en'),
#   ('4VmLlxEh68g', 'en-GB'),
#   ('wiuPNGjcQKg', 'en-GB'),
#   ('-mfmKteL6Qk', 'en-uYU-mmqFLq8'),
#   ('ljVQgxuyZxo', 'en-eEY6OEpapPo'),
#   ('HZKvfOFzvN8', 'en'),
#   ('g5n8OqS1Fow', 'en'),
#   ('vcN_uzkisqM', 'en-US'),
#   ('f6yRfT7mOKs', 'en'),
#   ('lMSmg9ofMDQ', 'en-US'),
#   ('cedV4A1fe-4', 'en'),
#   ('FfyBlfR8E1s', 'en'),
#   ('V6ZbL9SYhvI', 'en'),
#   ('KNKbNAK2Bwc', 'en-IN'),
#   ('XDHRQ8LRvpw', 'en-uYU-mmqFLq8'),
#   ('7lOVpYtcg2Y', 'en'),
#   ('3cvPTvCH_GA', 'en'),
#   ('_46UbDy2AbA', 'en'),
#   ('U1XpleqU_wY', 'en-US'),
#   ('ZITZMBCjdgw', 'en-nP7-2PuUl7o'),
#   ('PjQIbQkUI-Q', 'en-uYU-mmqFLq8'),
#   ('zMCNfdWiiLE', 'en'),
#   ('coaYjLm1xB0', 'en'),
#   ('nsqsdrFLCOU', 'en-uYU-mmqFLq8'),
#   ('GR80g4tqnSA', 'en'),
#   ('a88OcqY_RL4', 'en'),
#   ('YJkX5NWyXho', 'en-_yASqOZhnrs'),
#   ('AzjPl1_YpoU', 'en'),
#   ('yQsiZRdJuO8', 'en-m9lSYxxRqCI'),
#   ('lnz4Ah6_fL4', 'en'),
#   ('HHT7CshAfko', 'en'),
#   ('uM0TrflS40A', 'en'),
#   ('4xsV6iGca3M', 'en'),
#   ('FFG-2K6Gb2M', 'en'),
#   ('YO-FK6Y3aTI', 'en-US'),
#   ('a1LknQ7SFE4', 'en'),
#   ('iDFDKVndvK4', 'en-G5mFvsN0Jf0'),
#   ('oJjIltJQJpg', 'en'),
#   ('qRUq8fMH_1Q', 'en'),
#   ('VdydjGnvWZw', 'en-bj2DEeG9jsk'),
#   ('buhPQqbM9qk', 'en-US'),
#   ('bIIrhkrjqYQ', 'en'),
#   ('Rtye238_2H8', 'en'),
#   ('1fm83xeFZys', 'en-uYU-mmqFLq8'),
#   ('VkDLBAnte10', 'en-US'),
#   ('yJy0VeCajyo', 'en'),
#   ('KbjbK5vzPJI', 'en'),
#   ('YQoPW5OmseU', 'en-US'),
#   ('29y_mHD3ATU', 'en'),
#   ('LTTG0YFCErk', 'en-US'),
#   ('19RgSH6KzKg', 'en-Rh_FN2UmpLc'),
#   ('knOC3uFTT7o', 'en'),
#   ('AXM-mafNgYg', 'en-US'),
#   ('3pPRihbBNY0', 'en-GB'),
#   ('lyHhoicneuA', 'en-US'),
#   ('DOtzPTze-OU', 'en-uYU-mmqFLq8'),
#   ('H3hjLYuC4eo', 'en'),
#   ('iXsEKtKAeqY', 'en'),
#   ('RTL01yg5K5c', 'en-uYU-mmqFLq8'),
#   ('fD0IBaYfFIQ', 'en-uYU-mmqFLq8'),
#   ('M4ZDuWGbbO8', 'en'),
#   ('C1veobd_0ng', 'en'),
#   ('2IuA8HGacJw', 'en'),
#   ('SbhKWIEoQkw', 'en'),
#   ('s7uQKhjHyi4', 'en-US'),
#   ('g2ZdGjcFxuk', 'en-IN'),
#   ('L5y1RlNjHAc', 'en-6UJrWS5jR_I'),
#   ('wN4dFAuwP8E', 'en-uYU-mmqFLq8'),
#   ('xzgy8fWKP2I', 'en'),
#   ('L6nRspkGmXg', 'en-RTbB2cpHawQ'),
#   ('uXCROvzrnSQ', 'en-zL7EZQmMa4Q'),
#   ('jk-TobNpGDU', 'en'),
#   ('584y8fOZN5M', 'en'),
#   ('h6se2xzc3NI', 'en'),
#   ('jGTmiV3_dWw', 'en-uYU-mmqFLq8'),
#   ('_-HNsLOfxc0', 'en'),
#   ('EnkPJV16Jf8', 'en-ehkg1hFWq8A'),
#   ('NH0TDt-Iw4k', 'en'),
#   ('H7PaLzBKnY4', 'en'),
#   ('MosX4FK2LEI', 'en-US'),
#   ('Nb33KxOYPs0', 'en-US'),
#   ('vNgduwLjg1g', 'en'),
#   ('pjD0YQwSfDE', 'en-US'),
#   ('0FHeFKYE5dM', 'en-IN'),
#   ('0AUmROVg92A', 'en'),
#   ('YCO-D3-lU1k', 'en'),
#   ('k5Z5K2G04bw', 'en'),
#   ('JARI3XMqoUE', 'en-nP7-2PuUl7o'),
#   ('tjjDEB9IK1c', 'en'),
#   ('vgriLjxaVlg', 'en'),
#   ('v28sMjpsNf0', 'en'),
#   ('8rl9rVWkUmo', 'en'),
#   ('j2YiOCAkLIY', 'en'),
#   ('kKwXdeUVNOw', 'en'),
#   ('STPOFMA4Z6s', 'en'),
#   ('Ynk76OZMvjI', 'en-X1uKRDIPOcI'),
#   ('h_tQQ4znppw', 'en'),
#   ('e8q8vPUzddo', 'en'),
#   ('9Sxa-qkt13Q', 'en-GB'),
#   ('IIL1ElQkKI8', 'en-US'),
#   ('el-GURYzikw', 'en'),
#   ('jxZhfhE9BjE', 'en-uYU-mmqFLq8'),
#   ('M-cEDwuiO7I', 'en-US'),
#   ('IJWEJdPrvg8', 'en'),
#   ('JWqt7Qq7Gtw', 'en-h-j2qawAz7o'),
#   ('JzdGkhAwb_g', 'en-uYU-mmqFLq8'),
#   ('K-oKrTVpbSs', 'en'),
#   ('W44WBP1FhV4', 'en-ehkg1hFWq8A'),
#   ('8f9S8TMJpC4', 'en-nP7-2PuUl7o'),
#   ('PbaPUjuTcB8', 'en'),
#   ('poNslhJ5Xzw', 'en'),
#   ('qXeFUGPRZzk', 'en-GB'),
#   ('Lt9ectxSNiA', 'en-US'),
#   ('XMmEttIb-8s', 'en-US'),
#   ('KOeFqkZXbnI', 'en-nP7-2PuUl7o'),
#   ('bW-0K-jmTX0', 'en-ehkg1hFWq8A'),
#   ('4rFafaRKV60', 'en-CA'),
#   ('iFTdEmumVmY', 'en-nP7-2PuUl7o'),
#   ('PjQzDA6J1E0', 'en'),
#   ('kOyfPKssXGI', 'en'),
#   ('8jjvmgKftwU', 'en'),
#   ('iU2Ou2tTUGM', 'en'),
#   ('AsHaN7ZGtQ0', 'en'),
#   ('hQptgnIMlhE', 'en-RTbB2cpHawQ'),
#   ('xE7GY_Y0Qco', 'en'),
#   ('8UEvyLNIREk', 'en'),
#   ('qmM9Yxtf1Ck', 'en'),
#   ('x1dn1ZMNBH4', 'en'),
#   ('G53hqu-jTok', 'en'),
#   ('G6PCO7QlpLM', 'en-US'),
#   ('9NlCqD2k_sk', 'en'),
#   ('Kk12YWMazz0', 'en'),
#   ('xoJPaHri2Pw', 'en'),
#   ('prn7a-OPbWc', 'en'),
#   ('nKJbNhkQNAE', 'en-q24JKni9mwo'),
#   ('Y3btR66lDWs', 'en'),
#   ('KmbzxStLIyo', 'en'),
#   ('nnMIsMMpDgc', 'en'),
#   ('aAA-3bHzVwg', 'en'),
#   ('vSZoYIakKOk', 'en'),
#   ('IVMZy-Ah8gs', 'en'),
#   ('NdPm51Tutdk', 'en'),
#   ('F7Eg8dJfiew', 'en-uYU-mmqFLq8'),
#   ('5LZwMEnmJpg', 'en-RTbB2cpHawQ'),
#   ('umJzz-9MJzw', 'en-US'),
#   ('RFf4s8-4dpY', 'en'),
#   ('D-JBHP_aa0g', 'en-US'),
#   ('V89FKEOGuhw', 'en'),
#   ('asnE5oEqwLA', 'en'),
#   ('1r9FkMqsNLQ', 'en-GB'),
#   ('kur2nwILo0o', 'en-uYU-mmqFLq8'),
#   ('0Nd2zSccx34', 'en'),
#   ('yo98uE-0GHA', 'en-US'),
#   ('59ofFsFn0EU', 'en-uYU-mmqFLq8'),
#   ('BCZUIEHDbtM', 'en'),
#   ('_hAl8Xr1Qko', 'en-US'),
#   ('oivUugyMVOE', 'en'),
#   ('NzfbSgVhMn0', 'en'),
#   ('bL4W4-a3Q2U', 'en'),
#   ('3XYSzHJtT_0', 'en-US'),
#   ('WnTNbac_-dI', 'en'),
#   ('sdJ03INO7EQ', 'en'),
#   ('HGNBQCKu-bA', 'en'),
#   ('XFmZnvBO8Gc', 'en'),
#   ('K9p83B-sPcE', 'en-US'),
#   ('Wf9X3CF56ro', 'en'),
#   ('yS58y2lhuG8', 'en'),
#   ('ikDPw8fpG7E', 'en-uYU-mmqFLq8'),
#   ('fQ2Ci7SDroY', 'en-GB'),
#   ('9alXUr9lI9s', 'en'),
#   ('J57jAcFK5lI', 'en'),
#   ('tjdXpSUDRlw', 'en'),
#   ('HnEzWP70n3Q', 'en-GB'),
#   ('T5F-ZVlnLks', 'en'),
#   ('bLdmOJfAykY', 'en'),
#   ('8Il07c9KuDg', 'en-CA'),
#   ('RMblrDA-Xu4', 'en'),
#   ('qzKO-XfHSk0', 'en'),
#   ('dQMPC9AI1T8', 'en'),
#   ('ri-6K897bs0', 'en'),
#   ('6ogEAAMJtQU', 'en-GB'),
#   ('K-AQ4s2IYu4', 'en-nP7-2PuUl7o'),
#   ('0K42G1p8jlk', 'en-US'),
#   ('u77LD19fRo0', 'en-GB'),
#   ('xq7dGUpyteY', 'en'),
#   ('6sqfNt-4314', 'en-RTbB2cpHawQ'),
#   ('P2PtuRAaDac', 'en-uYU-mmqFLq8'),
#   ('xsBBlZjuxwg', 'en'),
#   ('MzDh9eKowlg', 'en-IN'),
#   ('xjAZYjpIC80', 'en-S4qVaLt9uDE'),
#   ('OxxnXERotvE', 'en-GB'),
#   ('2WvrxMCtc7U', 'en-US'),
#   ('plBZucIhZGA', 'en'),
#   ('-yC3dID-zJk', 'en'),
#   ('oIUMii1iwdE', 'en'),
#   ('gFQuI008YWM', 'en'),
#   ('77QY5mw1eKU', 'en-eEY6OEpapPo'),
#   ('xqrALt0sqQw', 'en-GB'),
#   ('9Lve1kbFEGU', 'en'),
#   ('9Zw7DUgpaMc', 'en'),
#   ('76LEYnTPYmo', 'en'),
#   ('ZVe16Ef-hdw', 'en'),
#   ('P0KVdMnlnIs', 'en-uYU-mmqFLq8'),
#   ('wcUsBe0dWNs', 'en'),
#   ('rkvGVyGgiec', 'en'),
#   ('5wF-H7vjRd0', 'en'),
#   ('4arDGHL3lvY', 'en-nP7-2PuUl7o'),
#   ('-YjVWnx0h5A', 'en-lHVrtPqdvzs'),
#   ('Kiqds9iJ9Ac', 'en-GB'),
#   ('hspkDmj0-Ho', 'en'),
#   ('Q-_i56zGQ08', 'en'),
#   ('yNq8B0LvPbI', 'en-f-S7PRHt8Xk'),
#   ('6uK1U7TA3eI', 'en'),
#   ('atlXFXHzISI', 'en-JkeT_87f4cc'),
#   ('U1Xnha0ZjwI', 'en-US'),
#   ('itHo9ootuPs', 'en'),
#   ('IchbQkuiL9k', 'en'),
#   ('V_fKYrrsVT4', 'en'),
#   ('iF3O4_rkEFw', 'en'),
#   ('21i454Onp7c', 'en-IN'),
#   ('L8yXDSuVWcY', 'en'),
#   ('NR8rzBmmxkw', 'en'),
#   ('nh03jCCcXTk', 'en'),
#   ('3riFwUNxRDs', 'en'),
#   ('FW5W7RH_c1Y', 'en-vlW2OHFw3ww'),
#   ('_DaLWSlu1ho', 'en-uYU-mmqFLq8'),
#   ('ky5GF82g50M', 'en'),
#   ('8CJh39I2jYk', 'en-uYU-mmqFLq8'),
#   ('nvfnU1Eqfec', 'en'),
#   ('r5As_vuyg8w', 'en'),
#   ('19UYJRrlRyE', 'en'),
#   ('BfG5zQEeWuQ', 'en-GB'),
#   ('TO0plygoEZg', 'en'),
#   ('yimTKH612SQ', 'en-ehkg1hFWq8A'),
#   ('HzmcjKvCy5E', 'en'),
#   ('dUKJXrkrL4E', 'en'),
#   ('KQB_oz4NULI', 'en'),
#   ('o_l_3DNmnFQ', 'en-US'),
#   ('5UsrG8Iw1Aw', 'en'),
#   ('PcfFjaQgRgI', 'en-US'),
#   ('Zko-ZGT7a2E', 'en-eEY6OEpapPo'),
#   ('0f0r2GnRLZs', 'en'),
#   ('z20GI2-fVRs', 'en-US'),
#   ('fuO4LILAJH8', 'en'),
#   ('hBYptkSgxEg', 'en'),
#   ('vUsSR4-sgMg', 'en'),
#   ('BKA9z2ZNrLA', 'en-uYU-mmqFLq8'),
#   ('rYqR-JpyBYo', 'en'),
#   ('WeHuogd4Hbk', 'en-US'),
#   ('kFbYg4XMbkI', 'en'),
#   ('oGpQXY9sxsE', 'en'),
#   ('xvW5gNXIdcE', 'en-uYU-mmqFLq8'),
#   ('-67sbeu0BJ0', 'en-1oAFzPNiuC0'),
#   ('z0Xa4-J3Lho', 'en'),
#   ('HW0MNcxoltg', 'en'),
#   ('ZGVHb5-x6b8', 'en'),
#   ('Z5JndhrGKgo', 'en-GB'),
#   ('wf60YIXYb60', 'en'),
#   ('dQhI26qxy-Q', 'en-US'),
#   ('32gLO1r-Aeo', 'en'),
#   ('wBl05WQlBlg', 'en'),
#   ('F7YnXIP6iaQ', 'en'),
#   ('DKb1SIK3BQs', 'en-JkeT_87f4cc'),
#   ('U6FNqs-LdEM', 'en'),
#   ('GLZk4lPOlUs', 'en'),
#   ('aYFQFblpGuw', 'en-US'),
#   ('uZAfX0il1Ks', 'en'),
#   ('BFk5SRgrF70', 'en-0hllRZe4s5s'),
#   ('upiy1kCwTYI', 'en'),
#   ('nUNK03BaYM8', 'en-GB'),
#   ('rnlEpEtMLhk', 'en-nP7-2PuUl7o'),
#   ('IjDKUYxEaTE', 'en-US'),
#   ('-OFpHzi7XOk', 'en'),
#   ('xBUng3BPwxI', 'en'),
#   ('n1hHb4e8QLU', 'en'),
#   ('vf1137n7EFg', 'en'),
#   ('ii715uWl4SI', 'en'),
#   ('dIevyJX1Vf0', 'en'),
#   ('3nyoXpr4K38', 'en'),
#   ('Nh7Gn5X3mEc', 'en'),
#   ('OJNp6hj_oGE', 'en'),
#   ('z2rjS41NufE', 'en'),
#   ('sRxwMOPksyk', 'en'),
#   ('5ehKnm67JUc', 'en'),
#   ('3SA-ePO4gcY', 'en-US'),
#   ('f8GTwT9lsNM', 'en-vlW2OHFw3ww'),
#   ('_7v6_ko4CkQ', 'en'),
#   ('i6vhOtEAZSU', 'en'),
#   ('RXEP1R_ZNrs', 'en'),
#   ('utL9sKfORFk', 'en'),
#   ('cpGX-pxTIB0', 'en'),
#   ('5wmEmtwW8fQ', 'en-IN'),
#   ('zu9g_XpjyY0', 'en'),
#   ('7H4XqpL658M', 'en'),
#   ('io63vW11vh4', 'en-US'),
#   ('X3op9TQL2XY', 'en-GB'),
#   ('dYsJOxsHYO8', 'en'),
#   ('u4EGJrwbDO0', 'en-US'),
#   ('8KBx70wRLWE', 'en'),
#   ('A0_1DYnqk0M', 'en'),
#   ('X8j7mo2t3lE', 'en'),
#   ('kstJC5A5l_s', 'en'),
#   ('SpvX9e16FH4', 'en'),
#   ('d1TaNsRVI10', 'en-US'),
#   ('rferA9wOvDE', 'en'),
#   ('A-qeB6OMswg', 'en'),
#   ('n0zqxlQ3KPM', 'en-GB'),
#   ('cTJ-eUKyNaY', 'en-lpAACan9byU'),
#   ('DvnLvv9NkIo', 'en'),
#   ('2HkBpSmh7fY', 'en-US'),
#   ('QFS2FUQy9Y8', 'en'),
#   ('R-CRs73e9zg', 'en'),
#   ('SP9JVZpB49M', 'en'),
#   ('_3AgyHpAGUA', 'en'),
#   ('ExCsSqwfXA8', 'en-lm4VUwi6eHo'),
#   ('9Sqra6spyrs', 'en'),
#   ('vkhsP-KaaKs', 'en'),
#   ('zu3aV7v2Fs0', 'en-RTbB2cpHawQ'),
#   ('srm-SqAF8Jk', 'en'),
#   ('gidFilN4_cw', 'en-uYU-mmqFLq8'),
#   ('SN08kQ38OGY', 'en'),
#   ('G_NnUCZIH0I', 'en-uYU-mmqFLq8'),
#   ('PWs8MBPh6Go', 'en'),
#   ('nhdnrSAnOw4', 'en-CA'),
#   ('TMlPCgj1oLg', 'en'),
#   ('ApMxRgDUiHc', 'en'),
#   ('G184u-0j2j0', 'en-uYU-mmqFLq8'),
#   ('Cc_a0znuJLA', 'en'),
#   ('RvxhCsHf69k', 'en-GB'),
#   ('SqUnY2u-m4k', 'en'),
#   ('OSyt7cWv0Xw', 'en-GB'),
#   ('SIOQJUKZz6o', 'en-ehkg1hFWq8A'),
#   ('RHBtpt5UeaY', 'en-GB'),
#   ('ofcjJZUbmHg', 'en'),
#   ('iyYAh73MN6k', 'en'),
#   ('8biBeEiJDlQ', 'en'),
#   ('_hDPUoUi6_s', 'en-nP7-2PuUl7o'),
#   ('Thy-b6EDiDU', 'en'),
#   ('kKHHw9VCoxM', 'en'),
#   ('Y1yrfADwgqk', 'en-GB'),
#   ('4GJ_0oriZjQ', 'en-US'),
#   ('c-sNuc9PIxQ', 'en'),
#   ('b2q3byuI_fI', 'en-hXb-X2kXPe0'),
#   ('omqVKkzaLaE', 'en'),
#   ('7xAjZUFBDnc', 'en-US'),
#   ('wiVR5gGiAOU', 'en'),
#   ('KGkSmXTUoNE', 'en-GB'),
#   ('jIdiVgH4joA', 'en'),
#   ('rptvO7ucgro', 'en-US'),
#   ('0D22dqooHSw', 'en-US'),
#   ('UggNwxfI1K4', 'en-uYU-mmqFLq8'),
#   ('_ucKZgRK0-g', 'en'),
#   ('gwhQR1ymO64', 'en-US'),
#   ('hh-ZhlarrFA', 'en-US-SvvTkdNMQDo'),
#   ('wam-elDJsNM', 'en-tllcrjiZuUM'),
#   ('_JW8Ss-x0xs', 'en'),
#   ('jdvfFrY2x38', 'en-nP7-2PuUl7o'),
#   ('t0ejQOywDho', 'en'),
#   ('9thGL3ua9HE', 'en'),
#   ('tkkvDuNnIs0', 'en'),
#   ('mmjcI9gcf6E', 'en-US'),
#   ('08VXkLCYQIs', 'en'),
#   ('3s9rMpW0qSw', 'en'),
#   ('i-YVjCQPkdM', 'en-xiEgTJu_uNg'),
#   ('915EBgT70BQ', 'en-GB'),
#   ('ASGXJlAtM9U', 'en'),
#   ('w2GJmPExeMY', 'en-US'),
#   ('Ozn8TWqWh7k', 'en-IN')],
#  'batchIdx': 5999}

# %%
len(subsampled_batches)
# Out:
# 6000

# %%
subsampled_batches[-1]
# Out:
# {'batch_5999': [{'id': '1kSG0gDVvmY',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '_hALGphRLEE',
#    'manual_caption_languages': 'de-ehkg1hFWq8A,en-ehkg1hFWq8A,es-ehkg1hFWq8A,ru-ehkg1hFWq8A',
#    'download_lang': 'en-ehkg1hFWq8A'},
#   {'id': 'U3xac534mEE',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '1cqzp47V4Jc',
#    'manual_caption_languages': 'en-yGn0zlAHf04',
#    'download_lang': 'en-yGn0zlAHf04'},
#   {'id': 'UoMIxsepHvY',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'aZOlUO0f6fw',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'x5bEeaKBkeg',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'fHWrf-XkRdk',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'c64JrGjYL9c',
#    'manual_caption_languages': 'en-RTbB2cpHawQ',
#    'download_lang': 'en-RTbB2cpHawQ'},
#   {'id': 'BL1K7wrA73k',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'j-9p8INVN5Y',
#    'manual_caption_languages': 'en-nP7-2PuUl7o',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'e3YAZSi-uHA',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'bQrDaIYSOV8',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': '2a-thABZcpM',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'TfeFv-wBeOc',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'wyQ1YpLFK5U',
#    'manual_caption_languages': 'ar,cs,de-DE,el,en-GB,es-ES,fil,fr-FR,hu,id,it,ja,ko,nl-NL,pl,pt-PT,ru,sk,th,tr,uk,vi,zh-Hans,zh-Hant',
#    'download_lang': 'en-GB'},
#   {'id': '4OrZ5OhCxjE',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'qBbHZMT9Y5U',
#    'manual_caption_languages': 'en-JkeT_87f4cc,en-uYU-mmqFLq8,en-vlW2OHFw3ww',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': '_XTsTPKaZ8o',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'ZnDJbAPNVz0',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'q78z0Axl1MI',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'hpYUGIL8Ew8',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'wr4E81B8vnQ',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'AHpX25o2iH8',
#    'manual_caption_languages': 'ar,be,bn,cs,da,de,el,en,es,fa,fi,fil,fr,ga,hi,hu,id,is,it,iw,ja,ko,lb,ms,nl,no,pl,pt,ro,ru,sl,so,sv,sw,th,tr,uk,vi,zh-Hans,zh-Hant',
#    'download_lang': 'en'},
#   {'id': 'jJKLVi5K0VI',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'bK1icqYTbSQ',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'Mo-lwPeouN4',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'glbQlYjwBIE',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'fWOE5FEeMC4',
#    'manual_caption_languages': 'en-IN',
#    'download_lang': 'en-IN'},
#   {'id': 'qDkg8pgiwrY',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'AfvHGHP01BE',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'QkPN9P5lYZk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'Vvvrs3fiB7w',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'rqcPMoNgb4E',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'iX3X6YXooLQ',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'HMMPRnK2H3Q',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'wmFRBP0BdrU',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'QUHqO_9YwWU',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'wq9UnsnEHHQ',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'EVrscvj6kEc',
#    'manual_caption_languages': 'ar,be,de-AT,de-DE,en,en-CA,en-GB,en-IE,en-US,fr-BE,ja,ka,kk,kn,nl-BE,nl-NL,ru,tr,uk',
#    'download_lang': 'en-US'},
#   {'id': 'zXUnWYRseVQ',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'S1q1LK-BKVA',
#    'manual_caption_languages': 'en-CA',
#    'download_lang': 'en-CA'},
#   {'id': 'W55Z3aEGeEc',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'cfg74054dT4',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'Z95zvKYqZ3E',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'gNm7sh_h2xI',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'FtkFQv-1IAo',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'cRoYG_J48b4',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'o0WdDABNB0Y',
#    'manual_caption_languages': 'en-JkeT_87f4cc,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'AtSg8Oh8wCQ',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'k7s__dCDpyA',
#    'manual_caption_languages': 'en-ehkg1hFWq8A',
#    'download_lang': 'en-ehkg1hFWq8A'},
#   {'id': '4vCZ53AEgA0',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'ysoXgtNW5MA',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '_gvPXVfjiwI',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'gT7iwkDIseA',
#    'manual_caption_languages': 'en-JkeT_87f4cc,en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'jdAo-PDOgKE',
#    'manual_caption_languages': 'en-CbwH8mx86EM',
#    'download_lang': 'en-CbwH8mx86EM'},
#   {'id': '461OPH2WyaM',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'xdpQWyeTcsM',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '6rq1i4yCGeQ',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'nKZBM3_fJ0Y',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'F1rnQrNsnlI',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'WZUbAiWk7Dg',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'alV9w5t7pao',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'Hy-zymdxVDA',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'fq3uawclOLs',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'm5-HQvSS4p4',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'rDuxOsXxw0o',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'kcDoCGmBY1Y',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'tChSqOUYVyA',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'DJ79cU7CPU8',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'vyS4pwMNMQQ',
#    'manual_caption_languages': 'en-Bb9eRC69SK0',
#    'download_lang': 'en-Bb9eRC69SK0'},
#   {'id': 'j-6KrCMHjS4',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': '3ekA1fVx1Bk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'OnnljuaDX-M',
#    'manual_caption_languages': 'en-0hllRZe4s5s',
#    'download_lang': 'en-0hllRZe4s5s'},
#   {'id': 'I-e37-LL8Cg',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'S0efTKgq3Pk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'y1RrSbk-B4g',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'fc1BQUjpeHY',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'XRHkw-xCVq0',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': '97LcBtdZiKg',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '2V6Qtc__1a8',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'bbkxvn23lMU',
#    'manual_caption_languages': 'en-CA',
#    'download_lang': 'en-CA'},
#   {'id': 'iUmdDQatWE4',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'HLIwfRKv9Dw',
#    'manual_caption_languages': 'en-IN,live_chat',
#    'download_lang': 'en-IN'},
#   {'id': 'OprIa6d3C2c',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'sgaiUsInmKU',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': '3B7Pqho8SU0',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'DxDvz88CjRA',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'PM6KjxvDd5k',
#    'manual_caption_languages': 'en-RTbB2cpHawQ,en-uYU-mmqFLq8',
#    'download_lang': 'en-RTbB2cpHawQ'},
#   {'id': 'QbKKnReGwgM',
#    'manual_caption_languages': 'en-nP7-2PuUl7o',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': '6urYuOWK48E',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'yythxWhoOdw',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': '2CXPg-ydyJY',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': '2S45n-s52W8',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'xGWVPgQCY5s',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': '_8h1x3GZBOY',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '00PPkXO6oDM',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '9m1NWznUIm8',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'dSl6nzC4JjM',
#    'manual_caption_languages': 'en,live_chat',
#    'download_lang': 'en'},
#   {'id': 'DJBw5NKMqOg',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '5T0Qa_z2tkA',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'IViJGww6kx8',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'Z6DNPkW47Og',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'uEOVoo8D7Cw',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'bg6RwctbUok',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '7NDJn45NoG0',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': '_dG6-vppWS8',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'CEkmU_jpDCE',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '_ZL6-UGrfQA',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'FjH7-qKBap4',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'Xr7cqcIHDdQ',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': '5DuPkC6uZC4',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'RTJkTXEFh1I',
#    'manual_caption_languages': 'en-ehkg1hFWq8A',
#    'download_lang': 'en-ehkg1hFWq8A'},
#   {'id': '_aau585JNbc',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'OOB-5p-jdhk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'wk_5d86udvw',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'yDNFbz9dkFk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'I-rtcmttGqQ',
#    'manual_caption_languages': 'en-JkeT_87f4cc,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'VBLbqZicwOY',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'bIbyVeBd-k8',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'YsGiCwzXH_o',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'mZxwwSrDNo8',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '1bhqUZooG_8',
#    'manual_caption_languages': 'en-i7LFIGUQP0g',
#    'download_lang': 'en-i7LFIGUQP0g'},
#   {'id': '92bgbCeEuxU',
#    'manual_caption_languages': 'en-CA',
#    'download_lang': 'en-CA'},
#   {'id': 'H_C50OZkrVs',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'dWtuhT-KYkA',
#    'manual_caption_languages': 'ar,de,en,es,fr,id',
#    'download_lang': 'en'},
#   {'id': 'FIpm2xbNcHc',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'lEGTh6BIpA8',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'xcoevQ-1jvI',
#    'manual_caption_languages': 'en-IN',
#    'download_lang': 'en-IN'},
#   {'id': '0ybVmas7gWs',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '21f80dZ43no',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'vmZAA0OyRcI',
#    'manual_caption_languages': 'en-nP7-2PuUl7o',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'QG0hE0R_ng4',
#    'manual_caption_languages': 'en-IN',
#    'download_lang': 'en-IN'},
#   {'id': 'iPH5dA6n2vI',
#    'manual_caption_languages': 'en-rX01gsAdUfU',
#    'download_lang': 'en-rX01gsAdUfU'},
#   {'id': 'v5jf7KHOzbE',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'ZqwOicMNC1E',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'KUdz2_hmNwg',
#    'manual_caption_languages': 'af,bg,de,en,es,fr,it,ne,no,ru',
#    'download_lang': 'en'},
#   {'id': 'KvbkeqYM2zw',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'uYeYubA7syk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '9Snu2NuL6eM',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'LM2PWViznS8',
#    'manual_caption_languages': 'en-ZDdPN5tsLY4',
#    'download_lang': 'en-ZDdPN5tsLY4'},
#   {'id': 'DCMAgE_P7uM',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '-_M_LIzSnF8',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'Hf5MDyKk8V4',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': '1HnpNMu56-E',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'UDmiECaIBXk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'iaHMvTU-HuM',
#    'manual_caption_languages': 'en-JkeT_87f4cc,en-uYU-mmqFLq8',
#    'download_lang': 'en-JkeT_87f4cc'},
#   {'id': '03w9gTWf9W8',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'EwkUHn4If-s',
#    'manual_caption_languages': 'en-i7LFIGUQP0g',
#    'download_lang': 'en-i7LFIGUQP0g'},
#   {'id': '2K-5Xu3FCww',
#    'manual_caption_languages': 'en-nP7-2PuUl7o',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'c0nyd9KzZBw',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': '4uoCV0QS808',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'z2b98mPfHFc',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': '6FxfwKOlBqU',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'JGNbbaxXxmw',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'Nxi0OUpx0wk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'R-36E87cghc',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'qUmRRhd0cuI',
#    'manual_caption_languages': 'en-IN',
#    'download_lang': 'en-IN'},
#   {'id': '_T4ye5mc1Jg',
#    'manual_caption_languages': 'en-nP7-2PuUl7o',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'CDaEdww7tsE',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'Syv-8vl08O8',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'xhmrLvYGhFk',
#    'manual_caption_languages': 'en-VjEpQ-RlAYk',
#    'download_lang': 'en-VjEpQ-RlAYk'},
#   {'id': 'IkHOcjaGoa0',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'XTd2UWjs09w',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': '3l8quEM35z0',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'UH_RUD7rrRk',
#    'manual_caption_languages': 'en-RTbB2cpHawQ',
#    'download_lang': 'en-RTbB2cpHawQ'},
#   {'id': 'uoLfRoQeMh8',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'fOTOBfH9eno',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'EQzKSfmg33E',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'E1pRvAleTQ8',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'hpvqw3q2dLU',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '1FKW96cQLmE',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'MlhyNPQ2560',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'i2NxjWvnavg',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '1fZLlGPwfCY',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'T9A9xDAcuH4',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'E_kIB8Ci0NI',
#    'manual_caption_languages': 'de-XwLwiJMB_Xs,en-nP7-2PuUl7o,es-EkcP5AbUQBc,pl-KIQEIE49RSI,pt-_J_fCE4pDyY,ru-iUhLFLNqjVM',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'll_yD8O7MfA',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'WC1QbVIw5II',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'IHQ-Y8vFs3I',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'aL2lla4gUQg',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'XhYx1wl7Zb0',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'hTL4Eh3pCEM',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '8HZtbp45AZo',
#    'manual_caption_languages': 'en-hnCuwW0TCiQ',
#    'download_lang': 'en-hnCuwW0TCiQ'},
#   {'id': '9fyR9SWmpPY',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'TdcdXE2ChcY',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'o_2LrUvcOPk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'gHvBoFBJhMM',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'OFRZH_MPsoo',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'ZAy9t8QCkgk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'fxXn-I_QWZs',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'hY91zVrD3Ag',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'l1y_w4RrYXI',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'g9TDJmLpgKQ',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'wRtR750Bsd8',
#    'manual_caption_languages': 'en,es,ja,ko',
#    'download_lang': 'en'},
#   {'id': 'eAYpKgJhx1U',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'tg189gkGTzM',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'zdmuEdoKoGU',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'OmnBpSBnilU',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'btKtZBiuTtQ',
#    'manual_caption_languages': 'ar,de,en,es,fil,fr,hi,id,it,pa,pt,tr',
#    'download_lang': 'en'},
#   {'id': 'GRaZ5WYS-M8',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'Q5ut_MCnoIY',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'EQF6QXOIFKk',
#    'manual_caption_languages': 'en-E3euOu7LhIg',
#    'download_lang': 'en-E3euOu7LhIg'},
#   {'id': '324sYkBijF4',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'hFp0oq8dugA',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'iLMa5LIk7ms',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'BrKXPZFED7U',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'OmiRPHi8o24',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'df4WT6mDnx0',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'U0AyYF2sWok',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'Covo-3EVNMw',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'it8QQM5eaog',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'PSbRsaOuUNI',
#    'manual_caption_languages': 'en-v0mWmvJhcr0',
#    'download_lang': 'en-v0mWmvJhcr0'},
#   {'id': 'O3nwY0xY7mU',
#    'manual_caption_languages': 'en,ja,ko,live_chat',
#    'download_lang': 'en'},
#   {'id': 'oIoUqRmJ70Y',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'XRmIx0ZUhtU',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'fGFqwS0UZbY',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'ObxrrP8tBsc',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'YlQPlUNt5s8',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'ow8lrUmgizQ',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'Rlx-SL1RlaE',
#    'manual_caption_languages': 'en-mrXZSxv27wo',
#    'download_lang': 'en-mrXZSxv27wo'},
#   {'id': 'Gb3leRY0yEQ',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'RZemQMtr3bI',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'wq8Zi-hNaRA',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'j7xWXKv9ckQ',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '5RaTLDaypC4',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'UF9kOf8Rpec',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'AR7UpX2_AIc',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'qihTylHtbpo',
#    'manual_caption_languages': 'en-nP7-2PuUl7o',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'y35VTA0NuRk',
#    'manual_caption_languages': 'en-U-2MYTshV4Q',
#    'download_lang': 'en-U-2MYTshV4Q'},
#   {'id': 'L1fKKeKy2yU',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'HGnnsMafNuw',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '3WzEVwaxeII',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '7kqAvL36RkA',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'tVy3ccEbTJ0',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'oLYZOYNHTks',
#    'manual_caption_languages': 'en,en-IN,es,hi,la,live_chat,ta',
#    'download_lang': 'en-IN'},
#   {'id': '2pQnMk6yMv0',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'GEGciPeegkw',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'QJhe9CQh_2o',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'TFGJXUtY55c',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'ZyQujyRX6xY',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'H4UKr_CswXU',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'rQ1NMRKJzj0',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'cw7fU7PRSK8',
#    'manual_caption_languages': 'en-nP7-2PuUl7o',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'VBORwUuU5GY',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '6oy569epm8Y',
#    'manual_caption_languages': 'en-9fXO75lTcLY',
#    'download_lang': 'en-9fXO75lTcLY'},
#   {'id': 'cBdTzOnDoXw',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'YhKYZsEXv7U',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'XVgebDFi3Co',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'Kv8A9h2ZGNM',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '3CjnPoYGOxA',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'T5G1hHtx0V4',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'vGEutk5PJyw',
#    'manual_caption_languages': 'en-CA',
#    'download_lang': 'en-CA'},
#   {'id': '2e8mL806Dvw',
#    'manual_caption_languages': 'en-j3PyPqV-e1s',
#    'download_lang': 'en-j3PyPqV-e1s'},
#   {'id': 's_8u2xU2Xjk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'Oj654LGCbpY',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'eiLYXDhL22o',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': '-4QTM2fo7CI',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'qT4EqsVrqDo',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '8JMCdjvdc2Q',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': '-Cxek6YbPoU',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'Pw8VjJ0vIcA',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'dGOTOkS07Ig',
#    'manual_caption_languages': 'en-RTbB2cpHawQ',
#    'download_lang': 'en-RTbB2cpHawQ'},
#   {'id': 'YUmF6n6tnz0',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'CZnJoQmKfCs',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'zacKQFkypGE',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'A9gY0GyNhTc',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'neAFEvNsiqw',
#    'manual_caption_languages': 'az,bg,cs,en,ja,pt-BR,tr,zh-Hans-CN,zh-Hant-TW',
#    'download_lang': 'en'},
#   {'id': 'OzqDVTYhnoA',
#    'manual_caption_languages': 'en-nP7-2PuUl7o',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'ZoKCCj2ChK4',
#    'manual_caption_languages': 'en-JkeT_87f4cc,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'ckZchGUHcjg',
#    'manual_caption_languages': 'ar,de,en,es,fil,fr,hi,id,nl,pt,tr',
#    'download_lang': 'en'},
#   {'id': 'QNe5FL76Llc',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'VGW9ifpU6PI',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'gm-Rz_oL8HI',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'CZVPVlg_gpw',
#    'manual_caption_languages': 'en-JkeT_87f4cc,en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'VT04K4V85hk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'sm6iwlcSdRU',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'yUMMca7iSOY',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'HMrHskqElVo',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'OEl1boDODH4',
#    'manual_caption_languages': 'en-CA,fr-CA',
#    'download_lang': 'en-CA'},
#   {'id': 'QLfHEjT71WE',
#    'manual_caption_languages': 'en-eEY6OEpapPo',
#    'download_lang': 'en-eEY6OEpapPo'},
#   {'id': '-4ebjd-BJ94',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'Nq0Ya4zHoLg',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'opv5ARMe2Uk',
#    'manual_caption_languages': 'en-ehkg1hFWq8A',
#    'download_lang': 'en-ehkg1hFWq8A'},
#   {'id': 'Mhpda4fWO0U',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '9BGhx2OqG4E',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'nRbG1a2bduo',
#    'manual_caption_languages': 'en-thYHmXxJoEw',
#    'download_lang': 'en-thYHmXxJoEw'},
#   {'id': 'U-aulndn3UU',
#    'manual_caption_languages': 'en,pt-BR',
#    'download_lang': 'en'},
#   {'id': 'BGrl7d73Z9s',
#    'manual_caption_languages': 'en-IN',
#    'download_lang': 'en-IN'},
#   {'id': 'Cu3XtguylR8',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'Ockbgqap7hg',
#    'manual_caption_languages': 'en-RTbB2cpHawQ',
#    'download_lang': 'en-RTbB2cpHawQ'},
#   {'id': 'H6P1FM6bbUI',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'ZIp63Q8FBOw',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'wW1bnE5G0aA',
#    'manual_caption_languages': 'en-RTbB2cpHawQ,en-uYU-mmqFLq8',
#    'download_lang': 'en-RTbB2cpHawQ'},
#   {'id': 'nMZEzWOFkIM',
#    'manual_caption_languages': 'en-wUMCMe1Ek2Q',
#    'download_lang': 'en-wUMCMe1Ek2Q'},
#   {'id': '36Jxrs5cvpI',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'wa3ncLwOwHc',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'Qv5cHCrnHKA',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'H6OD4_l9DVQ',
#    'manual_caption_languages': 'en-m8DiAxbKPiw',
#    'download_lang': 'en-m8DiAxbKPiw'},
#   {'id': 'tXhLpSvk6LE',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'S23Koz9jf20',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'tiA9NDgEa3k',
#    'manual_caption_languages': 'en-nP7-2PuUl7o',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'Lu5ZLKAUr_E',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'F0IjFYlIgH8',
#    'manual_caption_languages': 'en-JkeT_87f4cc,en-uYU-mmqFLq8',
#    'download_lang': 'en-JkeT_87f4cc'},
#   {'id': 'ZM_J_uC5QmM',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'TMOaN3qEy7w',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'cDbC9CWDvQA',
#    'manual_caption_languages': 'en-US,es-419,live_chat',
#    'download_lang': 'en-US'},
#   {'id': '39RIsSgVJ7Y',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'FHZ1I4nkQ9w',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'auwypxCUKB8',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'cyZgc8SNR4A',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '7XLRnwuywa0',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'Ph4c472LQrI',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': '8tHef2EMgg4',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'JwyCuYQlSe4',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'rgDu094Jsfo',
#    'manual_caption_languages': 'en-IN',
#    'download_lang': 'en-IN'},
#   {'id': '0WXc2KH2KKs',
#    'manual_caption_languages': 'en,es',
#    'download_lang': 'en'},
#   {'id': '3b4tU2Jlb1k',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'hZmAFzxtohw',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'ZAUCII79VcE',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'WgnuxGh2hBk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'mPf9cpNBq5g',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'rfihYBhym04',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'Cmnq9c3EJPo',
#    'manual_caption_languages': 'en-JkeT_87f4cc,en-uYU-mmqFLq8',
#    'download_lang': 'en-JkeT_87f4cc'},
#   {'id': '7NmklaTWO_8',
#    'manual_caption_languages': 'en-CA',
#    'download_lang': 'en-CA'},
#   {'id': '4NbalXY3Xt4',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'v5Rb5OkPNEM',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'cRNHycLA4pg',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '0rNTMQdbJ04',
#    'manual_caption_languages': 'en-HK2uFMokY8w',
#    'download_lang': 'en-HK2uFMokY8w'},
#   {'id': 'R2b_S7XdW2c',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '_dJmz4L2K-0',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'rUBmTZYNegI',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'mlXq6F15vHs',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'ZieIKoVkkBQ',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'io_9qpHnFlM',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'zRu0sNOZUdk',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': '851pCwAZWsY',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'r467mrCbriw',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'X1aAOUNY8eo',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'KGfWZgx6QVc',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'y3YlFygCBis',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'fOqhZBvifPk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'lHeoT0CIONs',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'tjSxFAGP9Ss',
#    'manual_caption_languages': 'en,es',
#    'download_lang': 'en'},
#   {'id': 'wDTfHha9B8A',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'djnvZrTm3Qk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'ES4wmAITJ-c',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'XfaNH7tM0Mk',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'LMLtGDKZtJ0',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'qOJQZJClThk',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': '8_kbG3efOPc',
#    'manual_caption_languages': 'en,pl',
#    'download_lang': 'en'},
#   {'id': 'gJPpsag37AU',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '5SyCE3PC7bM',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'JWalL_RlCHA',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'xCCy-OsGbjY',
#    'manual_caption_languages': 'en-anMIXjicSL4',
#    'download_lang': 'en-anMIXjicSL4'},
#   {'id': '3mOLqcnttIY',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '61pnWY6UhW4',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'GpdgCbcGe-Q',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'GVnAAw0l5tw',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'HiB3kMZl9tQ',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'aAvqnTu_TF0',
#    'manual_caption_languages': 'en-JkeT_87f4cc,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'F7kklBtsuE4',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': '-HrILrhnSoU',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '-SvdTR3stQw',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'is_N8JDUuEs',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'BAGak27LddQ',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'j8dAgBCDrxc',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'hr9HqvqvP5A',
#    'manual_caption_languages': 'en-CA',
#    'download_lang': 'en-CA'},
#   {'id': 'brLfDuKDzYg',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'GrYTdtEakKU',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'Jti1SqmGI6U',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'SQnkNN0ejL0',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'm28cAr2BuTg',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'VQpKvmP6ISY',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'WE_1g9I7NAM',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'O3PLo960QvE',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'baOpmGd0PVU',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'wjvk0w7lSaI',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'Rm5AtenVwks',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'yz5Ygy3BEWU',
#    'manual_caption_languages': 'en,en-US',
#    'download_lang': 'en-US'},
#   {'id': 'GfU8yuEet0w',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'If5asuPxDKM',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '4v4BIEbJaMk',
#    'manual_caption_languages': 'en-vVBWihXbEy0',
#    'download_lang': 'en-vVBWihXbEy0'},
#   {'id': '7qhiLn7GLA0',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'lbkWq1qWcZ8',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'WXSmnBG3Pds',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'WvFHoMFozP8',
#    'manual_caption_languages': 'en-lcmonCS91KQ',
#    'download_lang': 'en-lcmonCS91KQ'},
#   {'id': 'zQUSdSxPwuU',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'QqLZ5eSfFbI',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': '6-0n4FOprIw',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'LmMCRHSvVZ4',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'P1O_U9yqhYI',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'dwVBrJ2CXLA',
#    'manual_caption_languages': 'en-U7npZ5qOolg',
#    'download_lang': 'en-U7npZ5qOolg'},
#   {'id': '4X2_wIGDE7M',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'aVKDRbk-S8k',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'c5eVwfFKJtI',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'c6WubjrDNJQ',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'llUqkdwQNYM',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'Log6RnrusfY',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'dx4wUPIhRws',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'NSeKCBTFC18',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'pSMPVeaHxeU',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '6U6eNQf6n34',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'Ozw1XWA883o',
#    'manual_caption_languages': 'en-nP7-2PuUl7o',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': '72jiWo7S1ZY',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'NTrdeWxxMgQ',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'OBI54xujkN0',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'nF9a7X_iBPI',
#    'manual_caption_languages': 'en-zL7EZQmMa4Q',
#    'download_lang': 'en-zL7EZQmMa4Q'},
#   {'id': '7y_3b_zCMNE',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '7k2o4DeP8Pk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'OmEbxUD4spw',
#    'manual_caption_languages': 'en-yzlRvDSUTn8',
#    'download_lang': 'en-yzlRvDSUTn8'},
#   {'id': 'ZzpPw-NFzdE',
#    'manual_caption_languages': 'en-JkeT_87f4cc,en-uYU-mmqFLq8,en-vlW2OHFw3ww',
#    'download_lang': 'en-vlW2OHFw3ww'},
#   {'id': '-7UIRof_2iw',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'cMSWlMuAsdU',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'Y8lTdDpeC7Y',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'CtSJDjmayI0',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'zUpTzwznzFY',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'L55J2W1zqMY',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': '-ZhIgoID90w',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'cyg8OmgZOnE',
#    'manual_caption_languages': 'en-uYU-mmqFLq8,en-zL_pKPa_d08',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'bebIH4XHqHc',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'GdWxck6zgFs',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': '-fjgb3zb9qc',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'EGFyatxX4pk',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'IX-7U-Vv5o4',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'JDyy9ypw8gY',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'vLGa1-C-msY',
#    'manual_caption_languages': 'en-qoXxhA4oLYo',
#    'download_lang': 'en-qoXxhA4oLYo'},
#   {'id': 'A4TdW1dQvCg',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'JYRQgTRdEtg',
#    'manual_caption_languages': 'en-IN',
#    'download_lang': 'en-IN'},
#   {'id': 'UOOWLihU6O0',
#    'manual_caption_languages': 'en-E7jCWwwNYJg,en-uYU-mmqFLq8',
#    'download_lang': 'en-E7jCWwwNYJg'},
#   {'id': 'ldX3YQ31REM',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'xBb0QaMaAFE',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'gbdTkDEAmco',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'R1faazKXU5g',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'NGpvaX3pShw',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'I2vfrqfsiEw',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'XX0SP58EZwA',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '69JbCFLJHAU',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'WnWO10v5EY4',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'dRkilHkpX5g',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'rhBNXYSOsco',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'iLl1H2sVlkU',
#    'manual_caption_languages': 'en-CA',
#    'download_lang': 'en-CA'},
#   {'id': 'PtSSejgDJtQ',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'A_kD6RXTLhs',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'YqoOmSTvW2g',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'akxE7O5tWSs',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'UPOyNntybk8',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'tpAoCf5sGhQ',
#    'manual_caption_languages': 'en-iQ4tIeK26yM',
#    'download_lang': 'en-iQ4tIeK26yM'},
#   {'id': 'ih6IQztGJug',
#    'manual_caption_languages': 'en,live_chat',
#    'download_lang': 'en'},
#   {'id': 'yPfoy2xpHdg',
#    'manual_caption_languages': 'en-JkeT_87f4cc,en-uYU-mmqFLq8',
#    'download_lang': 'en-JkeT_87f4cc'},
#   {'id': 'bdLQfxlWL68',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'pn9T_rQnRSA',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'MrM1kD5dUSI',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'NU7LT2gpglU',
#    'manual_caption_languages': 'en-rNeeJrcpviU',
#    'download_lang': 'en-rNeeJrcpviU'},
#   {'id': 'ASJsM-v_MSY',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': '-COUAj4Lbuk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '1S8NuFDf78c',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'gfp8_okjX3I',
#    'manual_caption_languages': 'en-nP7-2PuUl7o',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'mX3XaM9aQB8',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'w4hFfWfkZpw',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'fvR3aa91MU4',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'ATFD-16fmZs',
#    'manual_caption_languages': 'en,live_chat',
#    'download_lang': 'en'},
#   {'id': 'bYGzBHBq6YI',
#    'manual_caption_languages': 'ar,be,bn,cs,de,de-AT,de-CH,de-DE,el,en,en-CA,en-GB,en-IE,en-IN,en-US,es,es-419,es-ES,es-MX,es-US,et,fi,fil,fr,fr-BE,fr-CA,fr-CH,fr-FR,ga,hi,hr,hu,id,is,it,iw,ja,ko,lt,ne,nl,nl-BE,nl-NL,no,pl,pt,pt-BR,pt-PT,ru,si,sr,sv,tr,uk,vi,yi',
#    'download_lang': 'en-GB'},
#   {'id': 'xnoclScTt5Y',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'qMcSkj9UZj0',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'uCyB9fqOaCI',
#    'manual_caption_languages': 'en-EfBjBWaqzDk',
#    'download_lang': 'en-EfBjBWaqzDk'},
#   {'id': 'Iqon2M615vo',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'FPZya_P73hU',
#    'manual_caption_languages': 'en-nP7-2PuUl7o',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': '4zibjtD7Ew4',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'wzO71p9yxec',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'fo3Z0eEfz8E',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'S6mjZq4AbNs',
#    'manual_caption_languages': 'ar,en',
#    'download_lang': 'en'},
#   {'id': 'i8x7yOrabtY',
#    'manual_caption_languages': 'en-eEY6OEpapPo',
#    'download_lang': 'en-eEY6OEpapPo'},
#   {'id': 'UhrF6NUbJ2U',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': '0NjwhAv2bV0',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'jX16Hx9oUxs',
#    'manual_caption_languages': 'en-rX01gsAdUfU',
#    'download_lang': 'en-rX01gsAdUfU'},
#   {'id': 'qKJV8mRlYvo',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '86eGXGUmRls',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'fx4dyQtL5Sg',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'q30_s1kiQws',
#    'manual_caption_languages': 'en-nP7-2PuUl7o',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': '4nH_wgrFW-I',
#    'manual_caption_languages': 'en-RTbB2cpHawQ',
#    'download_lang': 'en-RTbB2cpHawQ'},
#   {'id': 'sSodkc5VsKU',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'be48zuMDmvM',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '8l369Ov2MBY',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'gPNtaewZBeA',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'THzQ7147v2Y',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'svnCnR92UPE',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'U9Om2F-TtOA',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'knwzGwZTMqc',
# ...
#    'download_lang': 'en'},
#   {'id': '5wF-H7vjRd0',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '4arDGHL3lvY',
#    'manual_caption_languages': 'en-nP7-2PuUl7o',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': '-YjVWnx0h5A',
#    'manual_caption_languages': 'en-lHVrtPqdvzs',
#    'download_lang': 'en-lHVrtPqdvzs'},
#   {'id': 'Kiqds9iJ9Ac',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'hspkDmj0-Ho',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'Q-_i56zGQ08',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'yNq8B0LvPbI',
#    'manual_caption_languages': 'en-f-S7PRHt8Xk',
#    'download_lang': 'en-f-S7PRHt8Xk'},
#   {'id': '6uK1U7TA3eI',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'atlXFXHzISI',
#    'manual_caption_languages': 'en-JkeT_87f4cc,en-uYU-mmqFLq8',
#    'download_lang': 'en-JkeT_87f4cc'},
#   {'id': 'U1Xnha0ZjwI',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'itHo9ootuPs',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'IchbQkuiL9k',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'V_fKYrrsVT4',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'iF3O4_rkEFw',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '21i454Onp7c',
#    'manual_caption_languages': 'en-IN',
#    'download_lang': 'en-IN'},
#   {'id': 'L8yXDSuVWcY',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'NR8rzBmmxkw',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'nh03jCCcXTk',
#    'manual_caption_languages': 'en,live_chat',
#    'download_lang': 'en'},
#   {'id': '3riFwUNxRDs',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'FW5W7RH_c1Y',
#    'manual_caption_languages': 'en-JkeT_87f4cc,en-uYU-mmqFLq8,en-vlW2OHFw3ww',
#    'download_lang': 'en-vlW2OHFw3ww'},
#   {'id': '_DaLWSlu1ho',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'ky5GF82g50M',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '8CJh39I2jYk',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'nvfnU1Eqfec',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'r5As_vuyg8w',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '19UYJRrlRyE',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'BfG5zQEeWuQ',
#    'manual_caption_languages': 'en-GB,it',
#    'download_lang': 'en-GB'},
#   {'id': 'TO0plygoEZg',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'yimTKH612SQ',
#    'manual_caption_languages': 'en-ehkg1hFWq8A',
#    'download_lang': 'en-ehkg1hFWq8A'},
#   {'id': 'HzmcjKvCy5E',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'dUKJXrkrL4E',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'KQB_oz4NULI',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'o_l_3DNmnFQ',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': '5UsrG8Iw1Aw',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'PcfFjaQgRgI',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'Zko-ZGT7a2E',
#    'manual_caption_languages': 'en-eEY6OEpapPo',
#    'download_lang': 'en-eEY6OEpapPo'},
#   {'id': '0f0r2GnRLZs',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'z20GI2-fVRs',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'fuO4LILAJH8',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'hBYptkSgxEg',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'vUsSR4-sgMg',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'BKA9z2ZNrLA',
#    'manual_caption_languages': 'en-nP7-2PuUl7o,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'rYqR-JpyBYo',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'WeHuogd4Hbk',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'kFbYg4XMbkI',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'oGpQXY9sxsE',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'xvW5gNXIdcE',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': '-67sbeu0BJ0',
#    'manual_caption_languages': 'en-1oAFzPNiuC0',
#    'download_lang': 'en-1oAFzPNiuC0'},
#   {'id': 'z0Xa4-J3Lho',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'HW0MNcxoltg',
#    'manual_caption_languages': 'en,es,live_chat,pt',
#    'download_lang': 'en'},
#   {'id': 'ZGVHb5-x6b8',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'Z5JndhrGKgo',
#    'manual_caption_languages': 'ar,de,en,en-GB,es,es-419,fr,id,it,ja,ko,pl,pt-BR,ru,th,tr,vi,zh-Hans,zh-Hant',
#    'download_lang': 'en-GB'},
#   {'id': 'wf60YIXYb60',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'dQhI26qxy-Q',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': '32gLO1r-Aeo',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'wBl05WQlBlg',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'F7YnXIP6iaQ',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'DKb1SIK3BQs',
#    'manual_caption_languages': 'en-JkeT_87f4cc,en-uYU-mmqFLq8,en-vlW2OHFw3ww',
#    'download_lang': 'en-JkeT_87f4cc'},
#   {'id': 'U6FNqs-LdEM',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'GLZk4lPOlUs',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'aYFQFblpGuw',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'uZAfX0il1Ks',
#    'manual_caption_languages': 'en,es,pt,pt-BR,tr,zh-TW',
#    'download_lang': 'en'},
#   {'id': 'BFk5SRgrF70',
#    'manual_caption_languages': 'en-0hllRZe4s5s',
#    'download_lang': 'en-0hllRZe4s5s'},
#   {'id': 'upiy1kCwTYI',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'nUNK03BaYM8',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'rnlEpEtMLhk',
#    'manual_caption_languages': 'en-nP7-2PuUl7o',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'IjDKUYxEaTE',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': '-OFpHzi7XOk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'xBUng3BPwxI',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'n1hHb4e8QLU',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'vf1137n7EFg',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'ii715uWl4SI',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'dIevyJX1Vf0',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '3nyoXpr4K38',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'Nh7Gn5X3mEc',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'OJNp6hj_oGE',
#    'manual_caption_languages': 'en,fil,hi,hi-Latn,id,ko,ms,pt,pt-BR',
#    'download_lang': 'en'},
#   {'id': 'z2rjS41NufE',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'sRxwMOPksyk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '5ehKnm67JUc',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '3SA-ePO4gcY',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'f8GTwT9lsNM',
#    'manual_caption_languages': 'en-JkeT_87f4cc,en-uYU-mmqFLq8,en-vlW2OHFw3ww',
#    'download_lang': 'en-vlW2OHFw3ww'},
#   {'id': '_7v6_ko4CkQ',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'i6vhOtEAZSU',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'RXEP1R_ZNrs',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'utL9sKfORFk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'cpGX-pxTIB0',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '5wmEmtwW8fQ',
#    'manual_caption_languages': 'en-IN,live_chat',
#    'download_lang': 'en-IN'},
#   {'id': 'zu9g_XpjyY0',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '7H4XqpL658M',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'io63vW11vh4',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'X3op9TQL2XY',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'dYsJOxsHYO8',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'u4EGJrwbDO0',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': '8KBx70wRLWE',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'A0_1DYnqk0M',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'X8j7mo2t3lE',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'kstJC5A5l_s',
#    'manual_caption_languages': 'en,es,fr,ru',
#    'download_lang': 'en'},
#   {'id': 'SpvX9e16FH4',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'd1TaNsRVI10',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'rferA9wOvDE',
#    'manual_caption_languages': 'en,es',
#    'download_lang': 'en'},
#   {'id': 'A-qeB6OMswg',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'n0zqxlQ3KPM',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'cTJ-eUKyNaY',
#    'manual_caption_languages': 'en-lpAACan9byU',
#    'download_lang': 'en-lpAACan9byU'},
#   {'id': 'DvnLvv9NkIo',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '2HkBpSmh7fY',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'QFS2FUQy9Y8',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'R-CRs73e9zg',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'SP9JVZpB49M',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '_3AgyHpAGUA',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'ExCsSqwfXA8',
#    'manual_caption_languages': 'en-lm4VUwi6eHo',
#    'download_lang': 'en-lm4VUwi6eHo'},
#   {'id': '9Sqra6spyrs',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'vkhsP-KaaKs',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'zu3aV7v2Fs0',
#    'manual_caption_languages': 'en-RTbB2cpHawQ,en-uYU-mmqFLq8',
#    'download_lang': 'en-RTbB2cpHawQ'},
#   {'id': 'srm-SqAF8Jk',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'gidFilN4_cw',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'SN08kQ38OGY',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'G_NnUCZIH0I',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'PWs8MBPh6Go',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'nhdnrSAnOw4',
#    'manual_caption_languages': 'en-CA,fr-CA',
#    'download_lang': 'en-CA'},
#   {'id': 'TMlPCgj1oLg',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'ApMxRgDUiHc',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'G184u-0j2j0',
#    'manual_caption_languages': 'en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': 'Cc_a0znuJLA',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'RvxhCsHf69k',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'SqUnY2u-m4k',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'OSyt7cWv0Xw',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'SIOQJUKZz6o',
#    'manual_caption_languages': 'en-ehkg1hFWq8A,live_chat',
#    'download_lang': 'en-ehkg1hFWq8A'},
#   {'id': 'RHBtpt5UeaY',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'ofcjJZUbmHg',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'iyYAh73MN6k',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '8biBeEiJDlQ',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '_hDPUoUi6_s',
#    'manual_caption_languages': 'en-nP7-2PuUl7o',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 'Thy-b6EDiDU',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'kKHHw9VCoxM',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'Y1yrfADwgqk',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': '4GJ_0oriZjQ',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'c-sNuc9PIxQ',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'b2q3byuI_fI',
#    'manual_caption_languages': 'en-hXb-X2kXPe0,en-uYU-mmqFLq8',
#    'download_lang': 'en-hXb-X2kXPe0'},
#   {'id': 'omqVKkzaLaE',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '7xAjZUFBDnc',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'wiVR5gGiAOU',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'KGkSmXTUoNE',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'jIdiVgH4joA',
#    'manual_caption_languages': 'de,en,es-US,fr,hi,ja,ta,zh',
#    'download_lang': 'en'},
#   {'id': 'rptvO7ucgro',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': '0D22dqooHSw',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': 'UggNwxfI1K4',
#    'manual_caption_languages': 'en-JkeT_87f4cc,en-uYU-mmqFLq8',
#    'download_lang': 'en-uYU-mmqFLq8'},
#   {'id': '_ucKZgRK0-g',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'gwhQR1ymO64',
#    'manual_caption_languages': 'en-US,es,fr,it,live_chat,pt',
#    'download_lang': 'en-US'},
#   {'id': 'hh-ZhlarrFA',
#    'manual_caption_languages': 'en-US-SvvTkdNMQDo',
#    'download_lang': 'en-US-SvvTkdNMQDo'},
#   {'id': 'wam-elDJsNM',
#    'manual_caption_languages': 'en-tllcrjiZuUM',
#    'download_lang': 'en-tllcrjiZuUM'},
#   {'id': '_JW8Ss-x0xs',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'jdvfFrY2x38',
#    'manual_caption_languages': 'en-nP7-2PuUl7o',
#    'download_lang': 'en-nP7-2PuUl7o'},
#   {'id': 't0ejQOywDho',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '9thGL3ua9HE',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'tkkvDuNnIs0',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'mmjcI9gcf6E',
#    'manual_caption_languages': 'en-US',
#    'download_lang': 'en-US'},
#   {'id': '08VXkLCYQIs',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': '3s9rMpW0qSw',
#    'manual_caption_languages': 'ar,az,be,bg,bn,bs,ca,cs,da,de,el,en,es,et,fi,fr,ga,gl,hy,is,it,ja,ka,ko,lb,nl,no,pl,pt,ru,sk,sl,sr,sv,tr,uk,zh-Hans',
#    'download_lang': 'en'},
#   {'id': 'i-YVjCQPkdM',
#    'manual_caption_languages': 'en-xiEgTJu_uNg',
#    'download_lang': 'en-xiEgTJu_uNg'},
#   {'id': '915EBgT70BQ',
#    'manual_caption_languages': 'en-GB',
#    'download_lang': 'en-GB'},
#   {'id': 'ASGXJlAtM9U',
#    'manual_caption_languages': 'en',
#    'download_lang': 'en'},
#   {'id': 'w2GJmPExeMY',
#    'manual_caption_languages': 'ar,cs,de,en,en-US,es,fa,fil,fr,hi,hr,id,it,ja,kk,ko,live_chat,pl,pt-BR,ru,tr,zh',
#    'download_lang': 'en-US'},
#   {'id': 'Ozn8TWqWh7k',
#    'manual_caption_languages': 'en-IN',
#    'download_lang': 'en-IN'}]}

# %%
len(subsampled_batches[1]["batch_1"])
# Out:
# 1000

# %%
with open("logs/data/download/1M_en/shuffled_subsampled_batches.jsonl", "w") as f:
    for i, batch in enumerate(subsampled_batches):
        f.write(json.dumps(batch) + "\n")

# %%
with open("logs/data/download/1M_en/shuffled_subsampled_batches.jsonl", "w") as f:
    for i, batch in enumerate(subsampled_batches_tuples):
        f.write(json.dumps(batch) + "\n")

# %%
import json

# code to split up batches into smaller batches from existing JSONL file
new_batches = []
with open("logs/data/download/1M_en/shuffled_subsampled_batches.jsonl", "r") as f:
    for line in f:
        d = json.loads(line.strip())
        batch_idx = int(d["batchIdx"])
        for i in range(0, len(d["videoIds"]), 250):
            new_batches.append({"videoIds": d["videoIds"][i:i + 250], "batchIdx": (batch_idx * 4) + (i // 250)})
            
with open("logs/data/download/1M_en/shuffled_subsampled_quart_batches.jsonl", "w") as f:
    for d in new_batches:
        f.write(json.dumps(d) + "\n")

# %% [markdown]
# ## Dealing w/ missing pairs (2nd download)

# %%
with open("logs/data/download/missing_pairs_ids.txt", "r") as f:
    missing_pairs = [(line.strip().split(" ")[0], int(line.strip().split(" ")[1])) for line in f]
missing_pairs
# Out:
# [('EA8N7g8I_ns', 7922),
#  ('wkx9hWqa_ok', 7922),
#  ('kmVgCGWoXIA', 7922),
#  ('s7DAFyO56mE', 7922),
#  ('jU0c6fS3d6U', 7922),
#  ('Q5DJgt-XF_k', 7922),
#  ('P8MNjOVOxvE', 7922),
#  ('NYxyfhoTooE', 7922),
#  ('7tNoD9m9qAo', 7922),
#  ('yaUjx_JLkyo', 5167),
#  ('pitvacBn-Eg', 5167),
#  ('d1wtQlaQEuQ', 5167),
#  ('KWtkFHDjiiQ', 5167),
#  ('51JN86DU-3o', 5167),
#  ('3gKx5ng9mgg', 5167),
#  ('ajxTT1TKhYI', 5167),
#  ('5d8sOQZ8npM', 5167),
#  ('aZINEc6YVxI', 5167),
#  ('tdvRwbRsLa0', 5167),
#  ('kcq73_jFMn0', 5628),
#  ('Kpba6f53hds', 5628),
#  ('E_70QGzZFfU', 5628),
#  ('lDTL8tfv6ts', 5628),
#  ('4WIudT6-lco', 5628),
#  ('s_6CkYke0BE', 5628),
#  ('OuBjMcI7ANU', 5628),
#  ('XpDNYy78fiU', 5628),
#  ('Dv4B6QrqVUA', 5628),
#  ('Qk1ZlDKTyys', 3880),
#  ('Ryij01EbQkI', 3880),
#  ('N-wDlQkgpKA', 3880),
#  ('-ZwpuQEFJjo', 3880),
#  ('2NF9eJtwHOs', 3880),
#  ('sWEunvKrFUI', 3880),
#  ('V0nms7EK4BI', 3880),
#  ('y1U89RB5PvU', 7741),
#  ('5MvK7wOnDTw', 7741),
#  ('9XZF9gJakaU', 7741),
#  ('YO1TFY2CY0U', 7741),
#  ('U0BQxLAxVqE', 7741),
#  ('IKGd7bKTFe4', 7741),
#  ('DJDF7BNS9js', 7741),
#  ('2_dAybKwP80', 7741),
#  ('Ip9HgJIqqws', 7741),
#  ('msNijolazjU', 7741),
#  ('BnbbHFCI9gc', 3605),
#  ('8snvic2AfOU', 3605),
#  ('ghz3sCzNXjw', 3605),
#  ('4Oz_jWXeFLY', 3605),
#  ('nF5U2a3wp0s', 3605),
#  ('DU61hE-j0Bg', 3605),
#  ('OtmvvRRahN0', 3605),
#  ('gvtSKeS4U9k', 3605),
#  ('iPVhhs7XqNw', 3605),
#  ('_gLRoSqQ-uc', 3605),
#  ('MOP0scB8_mQ', 3605),
#  ('L6KXJaH0Q6Y', 6822),
#  ('ktYtGMm7QMg', 6822),
#  ('3H1zZNswdf4', 6822),
#  ('8nnqYXX7VDU', 6822),
#  ('oB4aXnc34MI', 8366),
#  ('J3tO5bOUR2s', 8366),
#  ('mDafoSoy4Vo', 8366),
#  ('uiF5Pf7cTMw', 8366),
#  ('2L2sjH3bigw', 8366),
#  ('SNYqlWxcPhs', 8366),
#  ('BXZRb2DLUTw', 8366),
#  ('JFNX0Om9W-E', 8366),
#  ('Evaloxxqs7o', 8366),
#  ('i7TIUOqlocA', 8366),
#  ('Kb8Uwn56MeM', 4607),
#  ('4D0b6Rlcj8w', 4607),
#  ('9I9APnlmbFY', 4607),
#  ('M_7iyjTARh0', 4607),
#  ('X18wYx5oj6g', 4607),
#  ('KL0VXb2zAOQ', 4607),
#  ('uto98LAM8QA', 4607),
#  ('pUfaD5CN0Q0', 4607),
#  ('D6JRj3PyX0E', 4607),
#  ('77SHN-GPB6I', 7876),
#  ('vkL-b4K1PtU', 7876),
#  ('PS2J8Flq8hQ', 7876),
#  ('2pMwgEK7r8A', 7876),
#  ('GjC8JFSBtoU', 7876),
#  ('WdEsgMwnifg', 7876),
#  ('Cil_PVvPDDA', 7876),
#  ('QeeAJ2oouwg', 7876),
#  ('iG_JIMMv0Oo', 2769),
#  ('oDCBclbDzyo', 2769),
#  ('EoZ0p7Zytt8', 2769),
#  ('JcAqJYNS8Fc', 2769),
#  ('r9E1R5ogTps', 2769),
#  ('mM53H_IEikA', 2769),
#  ('HLP9Z1tgeDA', 2769),
#  ('nhSfZkkSjF8', 2769),
#  ('mJXr1FiuBR4', 2769),
#  ('X7Ss0Dv3bkM', 7321),
#  ('wgsY47qPOoA', 7321),
#  ('GOSowy9fO60', 7321),
#  ('NTTBpPWazuY', 7321),
#  ('BeJT3HQGG2U', 7321),
#  ('ESPU4dezo6E', 7321),
#  ('fgfDQyVptFc', 7321),
#  ('BCpf9SvkPDQ', 7321),
#  ('LT0e6evqJ48', 7321),
#  ('rdGLV6PvJYY', 7321),
#  ('oI2UiWDCSNU', 4428),
#  ('VHZ4jPNRTT8', 4428),
#  ('4Qi7XxVJs8Q', 4428),
#  ('5NaWAWQ49OA', 4428),
#  ('42DK5zQKubc', 4428),
#  ('BrWeZYxzBxY', 4428),
#  ('w-vTs4GGXnQ', 4428),
#  ('sEk-eQusdIE', 4428),
#  ('joVnxBGWwSY', 4428),
#  ('OKvlzlSNIJY', 4090),
#  ('1Al69zWm3fU', 4090),
#  ('-L30OP9ira4', 4090),
#  ('m4Sc8HZB1k4', 4090),
#  ('WCOjM7Gs3Io', 4090),
#  ('IQC3zkV5Nqc', 4090),
#  ('BKfQ7itcfvM', 4090),
#  ('mo1S--r8PFk', 4090),
#  ('GJ_bv8aSiHU', 4090),
#  ('uAzsqHZUPh0', 5530),
#  ('0dCWOv55qZQ', 5530),
#  ('OUkC4hWKUs4', 5530),
#  ('Adzs_HWx--M', 5530),
#  ('ctlmqgPXcvY', 5530),
#  ('T_fNWyGqGBk', 5530),
#  ('iJ9L-Ywn3Dw', 5530),
#  ('_2waeKI1M2w', 5530),
#  ('vr3sBRYawoA', 7787),
#  ('gvNnwhxpCUI', 7787),
#  ('dFXThx3rxQ0', 7787),
#  ('7VAr-6QCon4', 7787),
#  ('ZoNdDPtZcmw', 7787),
#  ('FiRj2W2zSTo', 7787),
#  ('StrBXi8njHk', 7787),
#  ('XJYCcCz209Y', 7787),
#  ('1Qenukve05E', 8197),
#  ('ikirpPAJAYY', 8197),
#  ('qyfOE_78nT0', 8197),
#  ('v8s2Af5Bq8A', 8197),
#  ('fTiw__wFbDc', 8197),
#  ('sNzpb4ZTHxM', 8197),
#  ('7ghyjqhKFhY', 8197),
#  ('ghfCqEj9IdI', 8197),
#  ('IHCyFwvj9yY', 8197),
#  ('zpbWKopsvTg', 8197),
#  ('_OlMFW4QDx8', 8197),
#  ('yt83alq8yGc', 8197),
#  ('Q3usTryGt80', 8197),
#  ('p8n32CaQMjk', 8197),
#  ('3ffj5SxoQc8', 8197),
#  ('YNwPSXYeiZs', 2802),
#  ('opeuBmtFyaE', 2802),
#  ('r_aJg825DF0', 2802),
#  ('pJlEvrhfTN4', 2802),
#  ('WtS0Ymoz01E', 2802),
#  ('bqwB1KA3i74', 2802),
#  ('X-qsT9Ke4jU', 2802),
#  ('wPwWtFMkxLo', 2802),
#  ('oRf7nqGs_jI', 2802),
#  ('CuKq7yyWRXE', 2802),
#  ('4-Lpd-4_fXY', 3833),
#  ('9fCw41H0qHE', 3833),
#  ('Xl-7_kDpc0g', 3833),
#  ('XStViSWj_Kc', 3833),
#  ('JPeuwMxLlXc', 3833),
#  ('ZYDwxOwLdyc', 3833),
#  ('R2YWW_MQnIU', 3833),
#  ('oXy6GjX05VI', 3833),
#  ('y4dF4_J1fn0', 3833),
#  ('h2B8yGs2Nh0', 3833),
#  ('GHiBAmXTAr4', 3833),
#  ('utogRYqaRqA', 3833),
#  ('Nnm1ZbokaaY', 3833),
#  ('v3kuNz9fw9M', 3833),
#  ('HEe0w2TKANw', 3833),
#  ('1_wXSdLhdUY', 6606),
#  ('ZBL8AbK7YGY', 6606),
#  ('1OKwBKMF2Rw', 6606),
#  ('m47rd2ur2cQ', 6606),
#  ('oKwrm9S1fjE', 6606),
#  ('S_gWwW_7SPc', 5467),
#  ('a62w2Hv_byw', 5467),
#  ('F5aZ7DbmF3M', 5467),
#  ('W0gJEqq54dg', 5467),
#  ('ljLI5gFsqvI', 5467),
#  ('QQka41IfmKs', 2777),
#  ('AHoSydVPw08', 2777),
#  ('vaWaVoGDlWI', 2777),
#  ('SRVJhRP2aho', 2777),
#  ('K91K2g5ryjs', 2777),
#  ('p80KSrf6SGE', 2777),
#  ('YfRcOoEdBqk', 2699),
#  ('MMCUl7A4lFg', 2699),
#  ('n9qhKtvBUXI', 2699),
#  ('is5Atf54qsI', 2699),
#  ('HMrBlPi8jWs', 2699),
#  ('mbxeLxOHcCU', 5534),
#  ('rIBbG1XkuRg', 5534),
#  ('3C3ELo1vcs4', 5534),
#  ('4FJdaxTvFXs', 5534),
#  ('hJReAtyK_vw', 5534),
#  ('cAx5OWg-u88', 5534),
#  ('3wmPv09bQQk', 5534),
#  ('McrgupIaQ5g', 5534),
#  ('YqtjKjeTL3U', 5534),
#  ('TCzHy8KIWoM', 5534),
#  ('tMUtGeCOj70', 5534),
#  ('GZVGRs5YFcQ', 5534),
#  ('mgx0ADFHDOM', 3759),
#  ('YAGhD03XUgk', 3759),
#  ('PJsAF9xUgjg', 3759),
#  ('qz_Y3AjtbEM', 3759),
#  ('8yLXaEWTCvo', 3759),
#  ('yzW5-XIX0Vg', 3759),
#  ('9kjATUm59VE', 3759),
#  ('fzp5RDJ_gXc', 3759),
#  ('GVCFwrBar2w', 3427),
#  ('siXbx5sil6Y', 3427),
#  ('f6GGqQLWZQ4', 3427),
#  ('RQxvk6M_mjA', 3427),
#  ('TUQrBlXWy-g', 3427),
#  ('UTSpRGZBBhI', 3427),
#  ('w0HiooqQZYA', 3427),
#  ('ILfWJT9V8g8', 3427),
#  ('yVw64IWUJPg', 3427),
#  ('RR80M5jOtoQ', 3427),
#  ('QQd0q6i1Wbc', 3427),
#  ('OWVKgg7C-74', 7006),
#  ('leTj13KF1Og', 7006),
#  ('mV66oZV3l9g', 7006),
#  ('_4GluwAe9Xg', 7006),
#  ('H7lZfjsSBSE', 7006),
#  ('w7aGpIeXhmo', 7006),
#  ('IctjEZeyUt8', 7006),
#  ('r94qCHwnzL4', 7006),
#  ('ZNrFq_YNzvw', 7006),
#  ('oiMfF3xMuJ8', 6750),
#  ('1pAxO4PSS4g', 6750),
#  ('vTMPVO9veOc', 6750),
#  ('cHykn95k3ko', 6750),
#  ('fJXyHpoWunE', 6979),
#  ('h-QM8vssqqg', 6979),
#  ('8TI-kydfFwg', 6979),
#  ('iIQebqJzCO8', 6979),
#  ('9KoUJVWA5nE', 6979),
#  ('KGk5tQT4SGA', 6979),
#  ('ktvoakQYZ00', 6979),
#  ('Y26tyAi05IY', 6979),
#  ('HSRVEGsBuTQ', 6979),
#  ('lY-qW1Dwwno', 5623),
#  ('CnvBEyTSYzk', 5623),
#  ('dCYkkiOuUKM', 5623),
#  ('E6l-M-t-_Gk', 5623),
#  ('cBz2J_z_I2c', 5623),
#  ('-72ZKQkp7Bo', 5623),
#  ('RL99TF7eE70', 5623),
#  ('ZOVdNZAlnSY', 5623),
#  ('e9UKKyCx6Cw', 5623),
#  ('fp_gsJxvJUY', 5623),
#  ('yURvGY-QPrg', 5623),
#  ('abvFwIkku9U', 5623),
#  ('Sw5J5TIoneA', 5623),
#  ('OqkTwNmDfvE', 4479),
#  ('h0PyRTXzYIM', 4479),
#  ('LfdJS_8M8bY', 4479),
#  ('6uZJWOWK3zU', 4479),
#  ('3MKJeX00vcQ', 4479),
#  ('t4KSFwtP1gg', 4479),
#  ('4PWNsVmUxa8', 4479),
#  ('v-keaUtiglg', 4479),
#  ('9dVH8NCN5l4', 4479),
#  ('5k2DWJiWfQE', 4479),
#  ('fR6LrdKl-EA', 4479),
#  ('kgVlgNeFGdQ', 6164),
#  ('nnDHaMw09yo', 6164),
#  ('w7GBMqEyl8I', 6164),
#  ('tn96p8K-8Rk', 6164),
#  ('VnqdaogGhbE', 6164),
#  ('iLFvLMBwxCM', 6164),
#  ('flURdaG1eFc', 6164),
#  ('v3FWu15wypA', 3459),
#  ('6qBIWHcXgDM', 3459),
#  ('OcETW5VE7fA', 3459),
#  ('fmR0oVXTVrQ', 3459),
#  ('vpcFT9LJYDw', 3459),
#  ('BLUfrqvgCKA', 3459),
#  ('sfNTo3X_gDA', 3459),
#  ('FZZy14-W6Bc', 3459),
#  ('jSjPfJ2Onvg', 3459),
#  ('flQ92W9_pRE', 3459),
#  ('LzgpyzTpjIE', 3459),
#  ('IL7PEjk1pys', 3489),
#  ('BeeyzJ2Uynw', 3489),
#  ('4f6wKQ5jcAA', 3489),
#  ('K-GcrL1DRjI', 3489),
#  ('8vjACwImv6M', 3489),
#  ('oj6J1t7BNzM', 3489),
#  ('T5GZAyfX8SM', 3489),
#  ('W22ydwTZP4I', 3489),
#  ('Er8MeYKTd7w', 3489),
#  ('b8_BD_fvS_4', 3489),
#  ('h2I37vgL1bo', 3489),
#  ('2nU7810vR_g', 3489),
#  ('Hr4JD2OoQQI', 3489),
#  ('CJbRsbCTrVI', 3489),
#  ('CymBsL8wL4g', 3489),
#  ('lgczeThzen4', 4129),
#  ('seLt1roJjmU', 4129),
#  ('7fWa2-xFZoM', 4129),
#  ('GTu_7p9FWgo', 4129),
#  ('EzZUQH9faKE', 4129),
#  ('WBqwCXsoQcE', 4129),
#  ('lPA8e38L55s', 4129),
#  ('Mn4LWVL0TGw', 4129),
#  ('vRp1sdCkV_s', 4129),
#  ('cOMP8YtkCXc', 4129),
#  ('t33Ba0EIZNk', 4129),
#  ('hUBdwcUpNS0', 4129),
#  ('pCoZpLOtV9k', 4129),
#  ('FGmOOrTKRPM', 4129),
#  ('TUFuSD20lAk', 4129),
#  ('2I52j8aG3gk', 2455),
#  ('gPxuS7rGDUM', 2455),
#  ('DkiWBnW3yn4', 2455),
#  ('OFLiABRCqtY', 2455),
#  ('Dia_Kt8yJNg', 2455),
#  ('1R5awCwplVc', 2455),
#  ('ONwDZFGbw8o', 2455),
#  ('9T7v_Sy3XLo', 2455),
#  ('znhUjZkBuyw', 2455),
#  ('SVktfMkJdQU', 2455),
#  ('AZ7zKySUArw', 2455),
#  ('bQ4GQOnbNqw', 2455),
#  ('tugg3iXeLmM', 5664),
#  ('ZPbk1wnK3Ow', 5664),
#  ('x-LLAuAGjnM', 5664),
#  ('lMHd95K1ZYE', 5664),
#  ('C1C1Gs95PRQ', 5664),
#  ('Ts-1s9oYh-M', 5664),
#  ('bIBTDJNJDIs', 5664),
#  ('yT9iYPh_7DU', 5664),
#  ('wQhTpppcAF4', 5664),
#  ('1K_ieMi6k_I', 5664),
#  ('vgIJhavljN4', 5664),
#  ('lDAgretW_8I', 7262),
#  ('quMrUofinUQ', 7262),
#  ('7zYGHM08DHE', 7262),
#  ('J0IaMhxSf_k', 7262),
#  ('G1aAqV6OedM', 7262),
#  ('W3kxK_na_jA', 7262),
#  ('FeYoZyY0XNQ', 7262),
#  ('-OZbBLvgu5s', 7262),
#  ('qG00CVUZLNY', 7262),
#  ('hwis6ojBwL8', 7262),
#  ('J_03HiOq7Yo', 3709),
#  ('HQIUlYdRZzI', 3709),
#  ('04E9YlPQBvc', 3709),
#  ('oLT2JGc9HJY', 3709),
#  ('rWPGAshZY0k', 3709),
#  ('EWV6_zNYMF0', 3709),
#  ('3jMaKlNBjug', 3709),
#  ('EwzFahsEAqs', 3709),
#  ('3DIa1sTU1Sg', 3709),
#  ('6z2XdVMMPZw', 3709),
#  ('FuwiQPYojDM', 3709),
#  ('JT5BbQqEUcg', 3709),
#  ('UtV5xI7O5sI', 3709),
#  ('SCdAakK-1wY', 3534),
#  ('i1qnN2pg0no', 3534),
#  ('plfaLQa55q0', 3534),
#  ('Bs9jq_c__tQ', 3534),
#  ('My92w22FH1o', 3534),
#  ('B-LoQBNHERI', 3534),
#  ('hG2TXj7fRi8', 3534),
#  ('mr16lFnfIrU', 3534),
#  ('uXmUXjzik-A', 3534),
#  ('S5tTsqfsYvA', 3534),
#  ('A_mWsmHka_M', 3534),
#  ('5-MxDBTdJAQ', 3534),
#  ('ZOtbzTva-fM', 3534),
#  ('tRnElznhzxg', 7752),
#  ('mY5I4G3tyPI', 7752),
#  ('T3Avk-sblVU', 7752),
#  ('kfFUAFcp_5o', 7752),
#  ('3WkaLNR5jks', 7752),
#  ('6KNs-29Q1XQ', 7752),
#  ('lwF5R_G9x0A', 7752),
#  ('MdZL7x81N7w', 7752),
#  ('7Tmo7O86awE', 8106),
#  ('E-eWJX_i3dY', 8106),
#  ('RhusG6MCyjA', 8106),
#  ('XbEm0yEQRwY', 8106),
#  ('HZv7V5NNd7Q', 8106),
#  ('ix8YsZV-R-8', 8106),
#  ('SklNUZlugtU', 8106),
#  ('-zPbNlE7SPY', 4940),
#  ('j5jBVQdQQIs', 4940),
#  ('_lF5FWxHRdc', 4940),
#  ('8eSHlxf5JKE', 4940),
#  ('w5KlANTSJ-w', 4940),
#  ('IBUOvVqSQEk', 4940),
#  ('dbk8ZbAg0DA', 4940),
#  ('oK13RfG1_YI', 4940),
#  ('Zv4Aag_vmrE', 4940),
#  ('-vfAmZT04dw', 4940),
#  ('ILfa9VHIC5k', 4940),
#  ('Qc2sgAM7d-w', 4940),
#  ('ksHkGb8zDak', 6950),
#  ('hheC8Cwvxuk', 6950),
#  ('JwnrnU-D9Sg', 6950),
#  ('0_K0CQZ4Wno', 6950),
#  ('JbWW8HCCNZY', 6950),
#  ('6zb3K_Vr5aY', 6950),
#  ('LCOJfg1FNhw', 6950),
#  ('GAPHCoW5r7U', 6950),
#  ('NHf4fphjlQI', 6950),
#  ('Aez9Ji3llJM', 5683),
#  ('Nd-8XKBcS8Q', 5683),
#  ('xvF9FzxHcW0', 5683),
#  ('W8gjyjDIYEQ', 5683),
#  ('4Nxoq1-hb84', 5523),
#  ('DOr69Jm_ZnI', 5523),
#  ('kJ6ert2hI2k', 5523),
#  ('NoRi6YM6jIU', 5523),
#  ('Kz5cixhqIaA', 5523),
#  ('1jstPB3GDk0', 5523),
#  ('7NgQYnuynvY', 5523),
#  ('5WvD68d4Ogs', 5523),
#  ('XydUurLvaf0', 5523),
#  ('qfzIDFaMKZc', 5397),
#  ('MFd4ualheEQ', 5397),
#  ('zAU8YOoZY9A', 5397),
#  ('ZfosUxm98Zc', 5397),
#  ('ZpCK44e-Luw', 5397),
#  ('FlIdW1CbCy8', 5397),
#  ('gVVcj47eEAs', 5397),
#  ('8lgpql5s1M8', 3569),
#  ('nB40QHTJqPo', 3569),
#  ('84hqZR5odfg', 3569),
#  ('OjM7uHBawpw', 3569),
#  ('twnzs7_z8Qo', 3569),
#  ('nG0wmHo6p68', 3569),
#  ('PA0MyYh6ys0', 3569),
#  ('sCI9QcUs60s', 3569),
#  ('xIejlaIs4lE', 3569),
#  ('6ES0p3p-OhY', 6056),
#  ('fpnSoAaxWPw', 6056),
#  ('VUDLyPslHZQ', 6056),
#  ('LYR033SUAV0', 6056),
#  ('-U6lW861syA', 6056),
#  ('6SllD-0klcU', 6056),
#  ('beMckqz9INU', 6056),
#  ('Bo6YFqY0Kn4', 6056),
#  ('GVa6VCEQF9k', 6056),
#  ('veB5DrP8UO0', 6056),
#  ('Bx2-wFV9abY', 6056),
#  ('50on6TQI9Ys', 6056),
#  ('DGQXCRLpze0', 6056),
#  ('DOxPXb9Z92E', 6056),
#  ('o7wJCdifwmg', 3986),
#  ('VEHJXt064rI', 3986),
#  ('UqTNdbqHMZc', 3986),
#  ('loVtIS1Prcw', 3986),
#  ('p9e_vCbKrxY', 3986),
#  ('TFaZC1iP_AI', 4486),
#  ('6GPA5JVqTn8', 4486),
#  ('CVyJH7xhOS4', 4486),
#  ('ej77J_P4a_8', 4486),
#  ('lDRTVN_rki8', 4486),
#  ('ySr5AAIPwio', 4486),
#  ('J3XzFaJ9lk4', 4486),
#  ('MXHfCXJmTWU', 4486),
#  ('GZBFWML8u38', 4486),
#  ('FRbk-Mgd1R0', 4486),
#  ('HMfb0ERAQmo', 5394),
#  ('xqwKyjjGQMs', 5394),
#  ('SvqJMrepc5s', 5394),
#  ('SqLF-88hvAw', 5394),
#  ('z7Cf9Pz4oXY', 5394),
#  ('DIuz03Gdh9U', 5394),
#  ('UhR1CCY74cw', 5394),
#  ('HJ0uo0jsLqo', 8270),
#  ('bZSLKfhDj90', 8270),
#  ('Xdbijnhrf-s', 8270),
#  ('u0lCweJpoC8', 8270),
#  ('60Fvp6Mep4A', 8270),
#  ('9UG1CJgx21w', 8270),
#  ('VivkgX7ebV4', 8270),
#  ('TTXIp8t2E6g', 8270),
#  ('QpIOjsxfsWk', 8270),
#  ('AE_SAMMylqs', 8270),
#  ('Ox9Rt4g70EQ', 8270),
#  ('ramCcVjr6fs', 8270),
#  ('ehJ1EOS0xvU', 8270),
#  ('K62hKhm0ekc', 8270),
#  ('kQNrD_l5HMI', 8270),
#  ('McRmVoHPzGk', 4533),
#  ('jo7RxoJUvl8', 4533),
#  ('oMoBDisQ-ow', 4533),
#  ('uTrJw3IlObs', 4533),
#  ('j0WE1GIun0Q', 4533),
#  ('YN9qQWuFu0M', 4533),
#  ('_mzES9uca0k', 4533),
#  ('zE6AakOxqUo', 4533),
#  ('C7x3oudTwKo', 4533),
#  ('8lTUk2JHwDA', 3037),
#  ('9Qz1FSzQ2mQ', 3037),
#  ('9SXRwqRjzCU', 3037),
#  ('uKJ1Gb4zHF8', 3037),
#  ('_vfCrup_wqY', 3037),
#  ('oibz6CVXNac', 3037),
#  ('3L6RK_4r8To', 3037),
#  ('WXz1zUsgFY4', 3037),
#  ('NfCYP9T_i-I', 3037),
#  ('1R0qbsvruAw', 3037),
#  ('yiDINFEwtzs', 3037),
#  ('VBlh2irPeOM', 3037),
#  ('RfDqHDuj3fk', 6764),
#  ('ieSCa50CnKE', 6764),
#  ('_7hQIICIRRA', 6764),
#  ('JPBEiYSxJao', 6764),
#  ('qTOn2Ht_kPc', 6764),
#  ('MLLwqtY4MQU', 6764),
#  ('gixE2eaaXRU', 3641),
#  ('JXhlSnm3HYM', 3641),
#  ('Dz3NOArQSVw', 3641),
#  ('Frs-FyLcL7I', 3641),
#  ('CKRrEhXAJkc', 3641),
#  ('6xlUpY1G1aI', 3641),
#  ('o-K-s8Q8ap0', 3641),
#  ('KyXrzbg8HpM', 3641),
#  ('_Uv6C2s7lMM', 3641),
#  ('ibrNU1TukBQ', 3641),
#  ('fM3OEMQRBas', 3641),
#  ('LoS6RH9fKmk', 3641),
#  ('JmHddBObVoE', 3641),
#  ('IITnvmnfi_Y', 3641),
#  ('L8G8_-APrj8', 3641),
#  ('0lsghVMXACI', 3641),
#  ('u3VI7EiRUxE', 5144),
#  ('oaPoEzgIW7k', 5144),
#  ('ad9aa-HWQQk', 5144),
#  ('3zP8QO8ptj0', 5144),
#  ('0HgoiLfmADM', 5144),
#  ('TuerJLdKfCc', 5144),
#  ('l6BMNVzXB3Q', 5144),
#  ('gpow-RsbA34', 5144),
#  ('1R9qNAbRarw', 5144),
#  ('bJRYggXp16Y', 5144),
#  ('d76VsaB9YSI', 5144),
#  ('6sBpHIeH78w', 6227),
#  ('m8UVdIpRUYY', 6227),
#  ('IbuOIRNT2rk', 6227),
#  ('uL4FP0y7ItI', 6227),
#  ('brStDb52jmY', 6227),
#  ('gusqKZ4pPcY', 6227),
#  ('bIJ8xLqFPIA', 6227),
#  ('ynGP5c06WB4', 6227),
#  ('eSL1po1rk8s', 6227),
#  ('pml5SMKpSjM', 6227),
#  ('C11qF_edSCc', 6227),
#  ('vVT7PFy4S4c', 6227),
#  ('siPsCEFOi38', 6227),
#  ('8iSTWI-mumM', 6227),
#  ('JrvxKmmbOvQ', 6227),
#  ('CPACbIuPxEk', 7769),
#  ('Xm5bZhYPVNI', 7769),
#  ('7ONY8rA0l14', 7769),
#  ('gBBjAhhRaTQ', 7769),
#  ('0P7wRVZJRTA', 7769),
#  ('vTnSkcDcino', 7769),
#  ('I8_1S509evA', 7769),
#  ('U1nj7TR66m8', 7769),
#  ('z0fV_Zybsss', 7769),
#  ('wYtCymNFs68', 8137),
#  ('O7bdn8yf51M', 8137),
#  ('K1UtkjRiwyw', 8137),
#  ('q8lt656mqAc', 8137),
#  ('EkxpatFA9qk', 8137),
#  ('jrrqAYslfAI', 8137),
#  ('hrqdlRm-jP0', 8137),
#  ('vLIEG55Vgqo', 8137),
#  ('mfCZUYqB2lM', 8137),
#  ('A1eVyZ1US10', 7419),
#  ('w44BXLATt5w', 7419),
#  ('fa4Yl7Pn5Fg', 7419),
#  ('SbDUY6c0ICE', 7419),
#  ('eb_cDiZPfFk', 7419),
#  ('wUE1rlSvB58', 7419),
#  ('hUHrEFiktKI', 7419),
#  ('FKgLw0khHac', 7419),
#  ('KYXhOP0kex4', 7419),
#  ('Ef4XYnJWl_E', 7419),
#  ('jOu4Uvdgfik', 7419),
#  ('U0J5Zr-FLs8', 7419),
#  ('InVirEjbL34', 8005),
#  ('40opT2Efhs0', 8005),
#  ('nfX9mldsXtQ', 8005),
#  ('hcrFRTOE9dA', 8005),
#  ('8DG_oMutB04', 8005),
#  ('ccn_6C6YZfQ', 8005),
#  ('inbJXLQtZS4', 8005),
#  ('rNDEvVKNTQY', 8005),
#  ('9E_qZfNL_ss', 8005),
#  ('iZr8r_excJU', 4871),
#  ('a58IVR51WoY', 4871),
#  ('XCUJ7lg5-qY', 4871),
#  ('peh-aeHKegU', 4871),
#  ('VRwRqtIcXXw', 4871),
#  ('ZM-g45I0RoA', 4871),
#  ('6lkoWncRsHM', 4871),
#  ('DL00TDq9A-s', 4871),
#  ('vUgSyaejII8', 4871),
#  ('vVqt8CtVb-Y', 4707),
#  ('eIWVLh5l64M', 4707),
#  ('lXTa0LxP1Ds', 4707),
#  ('wPCJpli_RX4', 4707),
#  ('ceNllISphtI', 4707),
#  ('wDL_BMX_JNk', 4707),
#  ('X4ViZGZkP3A', 4707),
#  ('ukPzbbPYbYc', 4707),
#  ('ecWa8XI6jlw', 4707),
#  ('-key6YKwtu8', 4707),
#  ('vd7YOpIMVDc', 8397),
#  ('CWh9MuVe5ZM', 8397),
#  ('qc297bxb3jI', 8397),
#  ('Qv-btZqe7Og', 8397),
#  ('SSzUaGNyIKQ', 8397),
#  ('U5tC3zy4ewI', 8397),
#  ('FfkLmCsGTSU', 8397),
#  ('jYPbVSn8sxU', 8397),
#  ('YpyuIZ53Pgg', 7869),
#  ('PnmH-2UeCBI', 7869),
#  ('X9mnrfyYwv8', 7869),
#  ('ZK68ywHtEU4', 7869),
#  ('YKjGKynOptM', 7869),
#  ('RStSJooHURY', 7869),
#  ('gWJtD4aQKPg', 7869),
#  ('-MU5OFK2Mjc', 7869),
#  ('O1ym15x0tZ4', 7869),
#  ('ugk86jvZKz0', 7869),
#  ('gHJ_HyAZzxE', 4336),
#  ('h4mrlFJYoL8', 4336),
#  ('zS5jZpXjrno', 4336),
#  ('wyzFloJ2PcU', 4336),
#  ('Uu31-wZCaQY', 4336),
#  ('GvkN7h0GK0k', 4336),
#  ('yH41H8TF0KE', 4336),
#  ('CXpVeZXdGLI', 4336),
#  ('VHI-LsbrgQo', 4336),
#  ('I8O21yKEYd4', 4336),
#  ('kqcpFaBSONA', 4336),
#  ('y3y8ZEhWZpA', 4835),
#  ('UyRRrcjInhY', 4835),
#  ('zpX3uR-LY4M', 4835),
#  ('eTwHmpd8EgA', 4835),
#  ('mdymQo-YuZY', 4835),
#  ('76sbGwY6Kgs', 4835),
#  ('83KatH8HoHM', 4835),
#  ('7n2Z2OpgFts', 4835),
#  ('hctYCvKNolI', 4835),
#  ('LCBaDdMC8F8', 4835),
#  ('LvPPaAkAmGg', 4835),
#  ('SGLedVsIh20', 4835),
#  ('y_5gqV_TQ04', 4835),
#  ('uS1ppjrvnOk', 4835),
#  ('ooLMDFkKHAQ', 4835),
#  ('R2qpfqTNs1E', 4835),
#  ('ywJsX3ArQaw', 4835),
#  ('Rl3tuN2ZvnM', 4835),
#  ('LPAZu9p9ps8', 4233),
#  ('Yaw6Sa-87L8', 4233),
#  ('oKriC0gbFLM', 4233),
#  ('VmAfFM5aLUk', 4233),
#  ('eG-xAIX5Of0', 4233),
#  ('oPGx-B7IcpM', 4233),
#  ('H7bMHu_Mc8g', 4233),
#  ('neAzyz_lNgA', 4233),
#  ('McwiQqrtmGI', 4233),
#  ('ppzXloUAFS4', 4233),
#  ('iNq99h0_a-4', 4233),
#  ('xY3-P7r23Ys', 4233),
#  ('4fZ7fjaCoyk', 7154),
#  ('NMPSScNfR94', 7154),
#  ('bWFqYDo_imM', 7154),
#  ('Ph_b5vA4M6w', 7154),
#  ('q8M5oA-TiZU', 7154),
#  ('BNxRN5qtrL0', 7154),
#  ('IWwdT_q7Q6Y', 7154),
#  ('EjVTccHX3RY', 7154),
#  ('nP88dd8kYoA', 7154),
#  ('qSKU9irMP1w', 7154),
#  ('8uIdik1fkQI', 5719),
#  ('sZ7zCjhbw4U', 5719),
#  ('TpQKxULHc1k', 5719),
#  ('1_2Nr9AKvpU', 5719),
#  ('fuX5UmPBgbg', 2536),
#  ('HWyyUWebEbw', 2536),
#  ('oCR1B1bSuoQ', 2536),
#  ('joKwdfPtbks', 2536),
#  ('SiQE20vspOw', 2536),
#  ('Q1G7oHjZuy0', 2536),
#  ('VaoFuuOrxJ0', 2536),
#  ('v_pHW1ILFB8', 2536),
#  ('hFkJCIN_8xQ', 2536),
#  ('8B-LtH5zW5k', 5605),
#  ('wuhshhsqw68', 5605),
#  ('qtSgviHegAg', 5605),
#  ('uarTRgpn2ms', 5605),
#  ('FzWFwNa8qDU', 5605),
#  ('Ostw31lGgcU', 5605),
#  ('366Ve4xCXHw', 5605),
#  ('Q7eH3-oi2Z4', 5605),
#  ('RFE41BGCmy8', 5605),
#  ('k_2-5Ej4C9U', 5605),
#  ('ncIdn3CKlgY', 5605),
#  ('WBbilmgKW7w', 5605),
#  ('1nCYPitHAfM', 5605),
#  ('ugKQ1TFAL1c', 5605),
#  ('ysPHeSbGOwE', 5605),
#  ('_IzxdwvpeOk', 5605),
#  ('iq_Cx-KYFN0', 6994),
#  ('FqtWh12XKn4', 6994),
#  ('Lz2A3CPUAws', 6994),
#  ('3CsPTSS0YJY', 6994),
#  ('Tl0M3wvGpzA', 6994),
#  ('sFqNsIn-j9o', 6994),
#  ('hkOmvkuhwA8', 6994),
#  ('vbyyRv40_Us', 6994),
#  ('3Db5yGw3YiU', 6994),
#  ('pIPy475Krgw', 8211),
#  ('Oy9KfBHRRAo', 8211),
#  ('L6WXIboxb6g', 8211),
#  ('5be50C0PiTw', 8211),
#  ('BgCmzhqkhfw', 8211),
#  ('q1meZBapNpo', 8211),
#  ('STKvGM73aok', 8211),
#  ('NwqCpEK6iLY', 8211),
#  ('teG3eIN1Xo8', 5978),
#  ('_xzVMY2V7wY', 5978),
#  ('dWkzSgSxzro', 5978),
#  ('i4tCdR8f97s', 5978),
#  ('js7_38yyzow', 5978),
#  ('EfZ2ZgdGJX0', 5978),
#  ('U12Wgdw2cQk', 5978),
#  ('StsVR-IBLW8', 5978),
#  ('8ZuMAOgygfM', 5978),
#  ('EZLCapJsGEk', 5978),
#  ('ewAHyph17kk', 5978),
#  ('saINtyjzKyI', 5946),
#  ('OcUR9P9p57Y', 5946),
#  ('iUazrhm4yxM', 5946),
#  ('KEHdZzc6wsI', 5946),
#  ('zuYioEhS8mc', 5946),
#  ('7KxmzgqWauA', 5946),
#  ('pzUV3BtOyRo', 5946),
#  ('T3tGmK5zQuY', 5946),
#  ('MGFJA_2rVuI', 5946),
#  ('hXfqXhpPNsY', 5946),
#  ('rDDj4qs7BHA', 5946),
#  ('2GcgNOkzGmc', 5946),
#  ('ZZtk6wspRs4', 5946),
#  ('jGBi8LZKtRw', 5946),
#  ('zb0sV4xKH7g', 4847),
#  ('T0scpb9LR5I', 4847),
#  ('zLNyuzkS5oA', 4847),
#  ('eB6Tx2B3NlA', 4847),
#  ('di8_jBHrSRk', 4847),
#  ('shbJWdBfUYQ', 4847),
#  ('L94c6c8C8oU', 5599),
#  ('HIjO5TlWCvw', 5599),
#  ('J3xXLTxjIj4', 5599),
#  ('4BmzORaN6XU', 5599),
#  ('wpIuF2VXu68', 5599),
#  ('-FTazwYvV64', 5599),
#  ('DITHMx0vbB8', 5599),
#  ('t9a_HbWtH4g', 5599),
#  ('nzoKwwmozX0', 5599),
#  ('5tROkLbol3s', 5599),
#  ('oUt8cgYTMRo', 4697),
#  ('6JTIuFU6uY8', 4697),
#  ('7zO53mSGl_E', 4697),
#  ('UDf7ugya79o', 4697),
#  ('XKsXohKMVjc', 4697),
#  ('emPYcRZyAV4', 7061),
#  ('oU23SN3sj-Y', 7061),
#  ('6vkCnjVbgv8', 7061),
#  ('2mOje5omDqo', 7061),
#  ('Wzn4dTeSpKE', 7061),
#  ('IG50t4EPgXE', 7061),
#  ('tjbIUe0nb20', 4359),
#  ('KeBaHOiKR_s', 4359),
#  ('qAIwjG1xsBw', 4359),
#  ('nxg0cq5P7xw', 4359),
#  ('vtJIsS5eGRQ', 4044),
#  ('DjDVTyWRcZk', 4044),
#  ('fw2mAyW43uk', 4044),
#  ('Qu3hC2rOCG0', 4044),
#  ('33ARHiIO9JE', 4044),
#  ('zQgB9sIeraY', 4044),
#  ('wsVgDG69GHw', 4044),
#  ('-PNsGaJDJQI', 4044),
#  ('36cieH0YwFY', 4044),
#  ('3SbAnh1mGjc', 4044),
#  ('ebXaUy9I1TI', 5275),
#  ('7hIWDoV0VW4', 5275),
#  ('RY3f41lfkuo', 5275),
#  ('bIeRniAPBEo', 5275),
#  ('QmlqzcCiHvA', 5275),
#  ('gfK9pQ6ompI', 5275),
#  ('gkorUqLLOqA', 5275),
#  ('-7AWkQDDp-8', 8416),
#  ('MPPeMZxR2nM', 8416),
#  ('BQNSOL4Dj3M', 8416),
#  ('t56dcYV1mqY', 8416),
#  ('YUvwm9vnlpw', 8416),
#  ('jf_Xihk5W20', 8416),
#  ('tY8SKKDCeis', 8416),
#  ('rbsLN4AkvyA', 8416),
#  ('eQvQy1EWpKk', 8416),
#  ('p79ufoUQdQY', 8416),
#  ('DCW8HCj-G_0', 8416),
#  ('hiwgt7_UtCs', 8416),
#  ('lvOKGfl2cbw', 4957),
#  ('Mq3Buf0i_YY', 4957),
#  ('SIlg7HAcCv0', 4957),
#  ('giR7RN3UcD0', 4957),
#  ('8aeX6dzg5jU', 4957),
#  ('eF93xbJScxg', 4957),
#  ('L1PfgEkWQD0', 4957),
#  ('RSjiFETdslM', 7649),
#  ('U3mn0BtU7x0', 7649),
#  ('STNDGBEckOk', 7649),
#  ('Q9VLtSN8nSA', 7649),
#  ('Rf90Jbbcr3M', 7649),
#  ('bm5_8viqi28', 7649),
#  ('0GOAyQESVsk', 7649),
#  ('UJ13YcN5OFQ', 6542),
#  ('M8gzfTBFPz0', 6542),
#  ('u5DpVtoN5qo', 6542),
#  ('WaBRiZ12iTk', 6542),
#  ('nJWPBC07b9o', 6542),
#  ('jwwGY88ikFw', 6542),
#  ('7Pg7MzV4hsU', 6542),
#  ('xMfKyEjBa4w', 6542),
#  ('x3Cq607VILg', 6542),
#  ('NUo6AlfuVV0', 4011),
#  ('wiSixQ7VVII', 4011),
#  ('HyEDc3PfZKA', 4011),
#  ('FicSnweaNSY', 4011),
#  ('dA54MoaaLEE', 4011),
#  ('1zJdZYWlN0c', 4011),
#  ('k3qg55Iq13k', 4011),
#  ('3Snvi6wwz8E', 4011),
#  ('BzhbfmHspFE', 4011),
#  ('pmBWI18qjGI', 4011),
#  ('pIjpnQdYOOg', 4011),
#  ('mC-0cm1g5_g', 6921),
#  ('RFFCLA5rf2Q', 6921),
#  ('OXuTvG9peQg', 6921),
#  ('je_sC6FJ8iU', 6921),
#  ('8sO2guxmJNs', 6921),
#  ('aI8H5tvY0ho', 6921),
#  ('ohbHEiDTrZA', 6921),
#  ('fD4wqwa48Z4', 6921),
#  ('JCl16p8xo9w', 6921),
#  ('yjohrPtAoso', 6921),
#  ('0W0g1n2U-KM', 6921),
#  ('XirYhAsn14Q', 3453),
#  ('UeH-rJ837h4', 3453),
#  ('xSuO9Aa2_64', 3453),
#  ('YZbJ11UtaXc', 3453),
#  ('tialXNmboqk', 3453),
#  ('qcIW-eMHIL8', 3453),
#  ('EWl7WUOlt34', 3453),
#  ('CtwkwZ1lcGY', 3453),
#  ('IYZ-c6G6PIY', 3453),
#  ('9tF5ItqDmn8', 3453),
#  ('5qJNZ0vFVhQ', 4882),
#  ('GFcyEpys61k', 4882),
#  ('zGlPgE66VxM', 4882),
#  ('06cYWnqihl0', 4882),
#  ('ItKCxviHBSA', 4882),
#  ('P6T0xP1j5sA', 4882),
#  ('LID3NzcmTnE', 4882),
#  ('l1wR5cRx7mM', 4882),
#  ('4fOqs2CMpMk', 4882),
#  ('eG71XDuHoG0', 4342),
#  ('KRokDDel6yI', 4342),
#  ('NTlehboZttA', 4342),
#  ('Wq68pQWfO4I', 4342),
#  ('fhlWSALC7yk', 4342),
#  ('ArMeEnAOPHI', 4342),
#  ('Mp_bRgmph8A', 4342),
#  ('x8PbYCzXmLk', 4342),
#  ('YAzNuDzkcj0', 4342),
#  ('Az7r3o_9ol0', 4342),
#  ('p85reKKuA2w', 4342),
#  ('0ZUldbKNh6g', 4293),
#  ('XVwomB4EToY', 4293),
#  ('atfMzYSp_U0', 4293),
#  ('ZKulYs3lNGk', 4293),
#  ('F01Uc9ZvgcY', 4293),
#  ('DnykCyEtLyQ', 4293),
#  ('Du8a5KyRHdI', 4293),
#  ('kKtEVSFg9ZU', 4293),
#  ('cZkaA3_SvZ0', 4293),
#  ('wb9lIIxcJ38', 4293),
#  ('x-SRsUieT9M', 4293),
#  ('qnZvsYxLA4E', 4293),
#  ('2DR_0_QNib4', 4293),
#  ('gVIFh0Hly2k', 4489),
#  ('cDoubtvdf0w', 4489),
#  ('2dP8KpVtCHU', 4489),
#  ('8w-hsRcSRHY', 4489),
#  ('Uvrv9vmQObU', 4489),
#  ('-N5YKjArRWg', 4489),
#  ('oxDuZfqgkiI', 4190),
#  ('5TwLTJ_zGBI', 4190),
#  ('xdwmaUZKmas', 4190),
#  ('S22xeq8xxFQ', 4190),
#  ('i9--QMVpqCw', 4190),
#  ('gU3fhVr6rmM', 4190),
#  ('0Fjh-KX4wq4', 4190),
#  ('6SX5f0mVMxQ', 4190),
#  ('9a9O8UCegSE', 6275),
#  ('mDoOl7d-sMU', 6275),
#  ('ryuTz4diZTw', 6275),
#  ('pTXqOPu9gSk', 6275),
#  ('Xg2v4iIqThI', 6275),
#  ('i5vu379JZPU', 6275),
#  ('kzNixhWmRlw', 6275),
#  ('2b96xl5YU1k', 6275),
#  ('_-8vsnmbw3o', 6275),
#  ('7azc8LeBvnE', 6275),
#  ('Sz4gF49VOq0', 4056),
#  ('XjxtOwuzHi4', 4056),
#  ('-8Ai8Ghzbow', 4056),
#  ('adclsaUfI1s', 4056),
#  ('h8FBH7Iyxks', 4056),
#  ('6N3T2xVpvFY', 4056),
#  ('r4KJNv7Xboo', 4056),
#  ('0lFhR6lmlUg', 4056),
#  ('O0lIZ_menV0', 4056),
#  ('Uq9BjlR7XXc', 4056),
#  ('cEwwFHMsUYk', 4056),
#  ('6WpQAE5F4g0', 4056),
#  ('CNSMspI5wTo', 4056),
#  ('k62DqRsTmfw', 4056),
#  ('MTCTvcxmh6k', 2612),
#  ('CF5ROgsY0kc', 2612),
#  ('YDF4mVnNTsY', 2612),
#  ('moH0egGmaBs', 2612),
#  ('XfWQN3q27ss', 2612),
#  ('tLmn0RNuUoo', 2612),
#  ('PtnB_TW9jA0', 2612),
#  ('RBl0miVa0H4', 2612),
#  ('XpR8coS_Bos', 2612),
#  ('JLgGatzD18A', 2612),
#  ('sRl-jGwqllo', 2612),
#  ('HriuD7MsUak', 2612),
#  ('-DUxg3CLDX0', 2612),
#  ('raZ9QEPTOJM', 3753),
#  ('Kp_rURU6RGY', 3753),
#  ('NT9z6MWiGdM', 3753),
#  ('N-RFJHOTWTs', 3753),
#  ('UD7wsI99-HE', 3753),
#  ('zdYiKRpSXmc', 3753),
#  ('zF50g7W7fkc', 3753),
#  ('XFUypN3qtHQ', 3753),
#  ('VmP2v3hIVDs', 5980),
#  ('SeXLurfU67I', 5980),
#  ('I96VLZWVtBc', 5980),
#  ('zawmBw0AA9w', 5980),
#  ('bojfyE56Ndo', 5085),
#  ('TVyLfrUqyNI', 5085),
#  ('uOzPekC4JVI', 5085),
#  ('-RmnrhLmscU', 5085),
#  ('t7cCQ71AMWM', 5085),
#  ('ThwB8wuEq-0', 5085),
#  ('yDAkmdKM5yw', 5085),
#  ('eKc8-YWIVqg', 5085),
#  ('zwZWFuZA6sY', 5085),
#  ('dMz1o7GWOZM', 5085),
#  ('WJaIRQJ49Jo', 5085),
#  ('yeDkdPc0mYQ', 5085),
#  ('LTBXluGaRpo', 5085),
#  ('U1TgQEpiuRU', 2630),
#  ('a1FsvbopGg8', 2630),
#  ('-MuU6pFmrN0', 2630),
#  ('EZiUTX-fn6U', 2630),
#  ('LQocHJGla-M', 2630),
#  ('fCtmCI-yAeM', 2630),
#  ('gPsoJaGXHsI', 2630),
#  ('0j_NIBRSLFI', 2630),
#  ...]

# %%
from collections import defaultdict

def group_by_second_element(data):
    grouped_data = defaultdict(list)
    
    # Iterate through each tuple
    for first, second in data:
        grouped_data[second].append(first)
    
    return dict(grouped_data)

# Using the function
batch_idx_ids = group_by_second_element(missing_pairs)
batch_idx_ids
# Out:
# {7922: ['EA8N7g8I_ns',
#   'wkx9hWqa_ok',
#   'kmVgCGWoXIA',
#   's7DAFyO56mE',
#   'jU0c6fS3d6U',
#   'Q5DJgt-XF_k',
#   'P8MNjOVOxvE',
#   'NYxyfhoTooE',
#   '7tNoD9m9qAo'],
#  5167: ['yaUjx_JLkyo',
#   'pitvacBn-Eg',
#   'd1wtQlaQEuQ',
#   'KWtkFHDjiiQ',
#   '51JN86DU-3o',
#   '3gKx5ng9mgg',
#   'ajxTT1TKhYI',
#   '5d8sOQZ8npM',
#   'aZINEc6YVxI',
#   'tdvRwbRsLa0'],
#  5628: ['kcq73_jFMn0',
#   'Kpba6f53hds',
#   'E_70QGzZFfU',
#   'lDTL8tfv6ts',
#   '4WIudT6-lco',
#   's_6CkYke0BE',
#   'OuBjMcI7ANU',
#   'XpDNYy78fiU',
#   'Dv4B6QrqVUA'],
#  3880: ['Qk1ZlDKTyys',
#   'Ryij01EbQkI',
#   'N-wDlQkgpKA',
#   '-ZwpuQEFJjo',
#   '2NF9eJtwHOs',
#   'sWEunvKrFUI',
#   'V0nms7EK4BI'],
#  7741: ['y1U89RB5PvU',
#   '5MvK7wOnDTw',
#   '9XZF9gJakaU',
#   'YO1TFY2CY0U',
#   'U0BQxLAxVqE',
#   'IKGd7bKTFe4',
#   'DJDF7BNS9js',
#   '2_dAybKwP80',
#   'Ip9HgJIqqws',
#   'msNijolazjU'],
#  3605: ['BnbbHFCI9gc',
#   '8snvic2AfOU',
#   'ghz3sCzNXjw',
#   '4Oz_jWXeFLY',
#   'nF5U2a3wp0s',
#   'DU61hE-j0Bg',
#   'OtmvvRRahN0',
#   'gvtSKeS4U9k',
#   'iPVhhs7XqNw',
#   '_gLRoSqQ-uc',
#   'MOP0scB8_mQ'],
#  6822: ['L6KXJaH0Q6Y', 'ktYtGMm7QMg', '3H1zZNswdf4', '8nnqYXX7VDU'],
#  8366: ['oB4aXnc34MI',
#   'J3tO5bOUR2s',
#   'mDafoSoy4Vo',
#   'uiF5Pf7cTMw',
#   '2L2sjH3bigw',
#   'SNYqlWxcPhs',
#   'BXZRb2DLUTw',
#   'JFNX0Om9W-E',
#   'Evaloxxqs7o',
#   'i7TIUOqlocA'],
#  4607: ['Kb8Uwn56MeM',
#   '4D0b6Rlcj8w',
#   '9I9APnlmbFY',
#   'M_7iyjTARh0',
#   'X18wYx5oj6g',
#   'KL0VXb2zAOQ',
#   'uto98LAM8QA',
#   'pUfaD5CN0Q0',
#   'D6JRj3PyX0E'],
#  7876: ['77SHN-GPB6I',
#   'vkL-b4K1PtU',
#   'PS2J8Flq8hQ',
#   '2pMwgEK7r8A',
#   'GjC8JFSBtoU',
#   'WdEsgMwnifg',
#   'Cil_PVvPDDA',
#   'QeeAJ2oouwg'],
#  2769: ['iG_JIMMv0Oo',
#   'oDCBclbDzyo',
#   'EoZ0p7Zytt8',
#   'JcAqJYNS8Fc',
#   'r9E1R5ogTps',
#   'mM53H_IEikA',
#   'HLP9Z1tgeDA',
#   'nhSfZkkSjF8',
#   'mJXr1FiuBR4'],
#  7321: ['X7Ss0Dv3bkM',
#   'wgsY47qPOoA',
#   'GOSowy9fO60',
#   'NTTBpPWazuY',
#   'BeJT3HQGG2U',
#   'ESPU4dezo6E',
#   'fgfDQyVptFc',
#   'BCpf9SvkPDQ',
#   'LT0e6evqJ48',
#   'rdGLV6PvJYY'],
#  4428: ['oI2UiWDCSNU',
#   'VHZ4jPNRTT8',
#   '4Qi7XxVJs8Q',
#   '5NaWAWQ49OA',
#   '42DK5zQKubc',
#   'BrWeZYxzBxY',
#   'w-vTs4GGXnQ',
#   'sEk-eQusdIE',
#   'joVnxBGWwSY'],
#  4090: ['OKvlzlSNIJY',
#   '1Al69zWm3fU',
#   '-L30OP9ira4',
#   'm4Sc8HZB1k4',
#   'WCOjM7Gs3Io',
#   'IQC3zkV5Nqc',
#   'BKfQ7itcfvM',
#   'mo1S--r8PFk',
#   'GJ_bv8aSiHU'],
#  5530: ['uAzsqHZUPh0',
#   '0dCWOv55qZQ',
#   'OUkC4hWKUs4',
#   'Adzs_HWx--M',
#   'ctlmqgPXcvY',
#   'T_fNWyGqGBk',
#   'iJ9L-Ywn3Dw',
#   '_2waeKI1M2w'],
#  7787: ['vr3sBRYawoA',
#   'gvNnwhxpCUI',
#   'dFXThx3rxQ0',
#   '7VAr-6QCon4',
#   'ZoNdDPtZcmw',
#   'FiRj2W2zSTo',
#   'StrBXi8njHk',
#   'XJYCcCz209Y'],
#  8197: ['1Qenukve05E',
#   'ikirpPAJAYY',
#   'qyfOE_78nT0',
#   'v8s2Af5Bq8A',
#   'fTiw__wFbDc',
#   'sNzpb4ZTHxM',
#   '7ghyjqhKFhY',
#   'ghfCqEj9IdI',
#   'IHCyFwvj9yY',
#   'zpbWKopsvTg',
#   '_OlMFW4QDx8',
#   'yt83alq8yGc',
#   'Q3usTryGt80',
#   'p8n32CaQMjk',
#   '3ffj5SxoQc8'],
#  2802: ['YNwPSXYeiZs',
#   'opeuBmtFyaE',
#   'r_aJg825DF0',
#   'pJlEvrhfTN4',
#   'WtS0Ymoz01E',
#   'bqwB1KA3i74',
#   'X-qsT9Ke4jU',
#   'wPwWtFMkxLo',
#   'oRf7nqGs_jI',
#   'CuKq7yyWRXE'],
#  3833: ['4-Lpd-4_fXY',
#   '9fCw41H0qHE',
#   'Xl-7_kDpc0g',
#   'XStViSWj_Kc',
#   'JPeuwMxLlXc',
#   'ZYDwxOwLdyc',
#   'R2YWW_MQnIU',
#   'oXy6GjX05VI',
#   'y4dF4_J1fn0',
#   'h2B8yGs2Nh0',
#   'GHiBAmXTAr4',
#   'utogRYqaRqA',
#   'Nnm1ZbokaaY',
#   'v3kuNz9fw9M',
#   'HEe0w2TKANw'],
#  6606: ['1_wXSdLhdUY',
#   'ZBL8AbK7YGY',
#   '1OKwBKMF2Rw',
#   'm47rd2ur2cQ',
#   'oKwrm9S1fjE'],
#  5467: ['S_gWwW_7SPc',
#   'a62w2Hv_byw',
#   'F5aZ7DbmF3M',
#   'W0gJEqq54dg',
#   'ljLI5gFsqvI'],
#  2777: ['QQka41IfmKs',
#   'AHoSydVPw08',
#   'vaWaVoGDlWI',
#   'SRVJhRP2aho',
#   'K91K2g5ryjs',
#   'p80KSrf6SGE'],
#  2699: ['YfRcOoEdBqk',
#   'MMCUl7A4lFg',
#   'n9qhKtvBUXI',
#   'is5Atf54qsI',
#   'HMrBlPi8jWs'],
#  5534: ['mbxeLxOHcCU',
#   'rIBbG1XkuRg',
#   '3C3ELo1vcs4',
#   '4FJdaxTvFXs',
#   'hJReAtyK_vw',
#   'cAx5OWg-u88',
#   '3wmPv09bQQk',
#   'McrgupIaQ5g',
#   'YqtjKjeTL3U',
#   'TCzHy8KIWoM',
#   'tMUtGeCOj70',
#   'GZVGRs5YFcQ'],
#  3759: ['mgx0ADFHDOM',
#   'YAGhD03XUgk',
#   'PJsAF9xUgjg',
#   'qz_Y3AjtbEM',
#   '8yLXaEWTCvo',
#   'yzW5-XIX0Vg',
#   '9kjATUm59VE',
#   'fzp5RDJ_gXc'],
#  3427: ['GVCFwrBar2w',
#   'siXbx5sil6Y',
#   'f6GGqQLWZQ4',
#   'RQxvk6M_mjA',
#   'TUQrBlXWy-g',
#   'UTSpRGZBBhI',
#   'w0HiooqQZYA',
#   'ILfWJT9V8g8',
#   'yVw64IWUJPg',
#   'RR80M5jOtoQ',
#   'QQd0q6i1Wbc'],
#  7006: ['OWVKgg7C-74',
#   'leTj13KF1Og',
#   'mV66oZV3l9g',
#   '_4GluwAe9Xg',
#   'H7lZfjsSBSE',
#   'w7aGpIeXhmo',
#   'IctjEZeyUt8',
#   'r94qCHwnzL4',
#   'ZNrFq_YNzvw'],
#  6750: ['oiMfF3xMuJ8', '1pAxO4PSS4g', 'vTMPVO9veOc', 'cHykn95k3ko'],
#  6979: ['fJXyHpoWunE',
#   'h-QM8vssqqg',
#   '8TI-kydfFwg',
#   'iIQebqJzCO8',
#   '9KoUJVWA5nE',
#   'KGk5tQT4SGA',
#   'ktvoakQYZ00',
#   'Y26tyAi05IY',
#   'HSRVEGsBuTQ'],
#  5623: ['lY-qW1Dwwno',
#   'CnvBEyTSYzk',
#   'dCYkkiOuUKM',
#   'E6l-M-t-_Gk',
#   'cBz2J_z_I2c',
#   '-72ZKQkp7Bo',
#   'RL99TF7eE70',
#   'ZOVdNZAlnSY',
#   'e9UKKyCx6Cw',
#   'fp_gsJxvJUY',
#   'yURvGY-QPrg',
#   'abvFwIkku9U',
#   'Sw5J5TIoneA'],
#  4479: ['OqkTwNmDfvE',
#   'h0PyRTXzYIM',
#   'LfdJS_8M8bY',
#   '6uZJWOWK3zU',
#   '3MKJeX00vcQ',
#   't4KSFwtP1gg',
#   '4PWNsVmUxa8',
#   'v-keaUtiglg',
#   '9dVH8NCN5l4',
#   '5k2DWJiWfQE',
#   'fR6LrdKl-EA'],
#  6164: ['kgVlgNeFGdQ',
#   'nnDHaMw09yo',
#   'w7GBMqEyl8I',
#   'tn96p8K-8Rk',
#   'VnqdaogGhbE',
#   'iLFvLMBwxCM',
#   'flURdaG1eFc'],
#  3459: ['v3FWu15wypA',
#   '6qBIWHcXgDM',
#   'OcETW5VE7fA',
#   'fmR0oVXTVrQ',
#   'vpcFT9LJYDw',
#   'BLUfrqvgCKA',
#   'sfNTo3X_gDA',
#   'FZZy14-W6Bc',
#   'jSjPfJ2Onvg',
#   'flQ92W9_pRE',
#   'LzgpyzTpjIE'],
#  3489: ['IL7PEjk1pys',
#   'BeeyzJ2Uynw',
#   '4f6wKQ5jcAA',
#   'K-GcrL1DRjI',
#   '8vjACwImv6M',
#   'oj6J1t7BNzM',
#   'T5GZAyfX8SM',
#   'W22ydwTZP4I',
#   'Er8MeYKTd7w',
#   'b8_BD_fvS_4',
#   'h2I37vgL1bo',
#   '2nU7810vR_g',
#   'Hr4JD2OoQQI',
#   'CJbRsbCTrVI',
#   'CymBsL8wL4g'],
#  4129: ['lgczeThzen4',
#   'seLt1roJjmU',
#   '7fWa2-xFZoM',
#   'GTu_7p9FWgo',
#   'EzZUQH9faKE',
#   'WBqwCXsoQcE',
#   'lPA8e38L55s',
#   'Mn4LWVL0TGw',
#   'vRp1sdCkV_s',
#   'cOMP8YtkCXc',
#   't33Ba0EIZNk',
#   'hUBdwcUpNS0',
#   'pCoZpLOtV9k',
#   'FGmOOrTKRPM',
#   'TUFuSD20lAk'],
#  2455: ['2I52j8aG3gk',
#   'gPxuS7rGDUM',
#   'DkiWBnW3yn4',
#   'OFLiABRCqtY',
#   'Dia_Kt8yJNg',
#   '1R5awCwplVc',
#   'ONwDZFGbw8o',
#   '9T7v_Sy3XLo',
#   'znhUjZkBuyw',
#   'SVktfMkJdQU',
#   'AZ7zKySUArw',
#   'bQ4GQOnbNqw'],
#  5664: ['tugg3iXeLmM',
#   'ZPbk1wnK3Ow',
#   'x-LLAuAGjnM',
#   'lMHd95K1ZYE',
#   'C1C1Gs95PRQ',
#   'Ts-1s9oYh-M',
#   'bIBTDJNJDIs',
#   'yT9iYPh_7DU',
#   'wQhTpppcAF4',
#   '1K_ieMi6k_I',
#   'vgIJhavljN4'],
#  7262: ['lDAgretW_8I',
#   'quMrUofinUQ',
#   '7zYGHM08DHE',
#   'J0IaMhxSf_k',
#   'G1aAqV6OedM',
#   'W3kxK_na_jA',
#   'FeYoZyY0XNQ',
#   '-OZbBLvgu5s',
#   'qG00CVUZLNY',
#   'hwis6ojBwL8'],
#  3709: ['J_03HiOq7Yo',
#   'HQIUlYdRZzI',
#   '04E9YlPQBvc',
#   'oLT2JGc9HJY',
#   'rWPGAshZY0k',
#   'EWV6_zNYMF0',
#   '3jMaKlNBjug',
#   'EwzFahsEAqs',
#   '3DIa1sTU1Sg',
#   '6z2XdVMMPZw',
#   'FuwiQPYojDM',
#   'JT5BbQqEUcg',
#   'UtV5xI7O5sI'],
#  3534: ['SCdAakK-1wY',
#   'i1qnN2pg0no',
#   'plfaLQa55q0',
#   'Bs9jq_c__tQ',
#   'My92w22FH1o',
#   'B-LoQBNHERI',
#   'hG2TXj7fRi8',
#   'mr16lFnfIrU',
#   'uXmUXjzik-A',
#   'S5tTsqfsYvA',
#   'A_mWsmHka_M',
#   '5-MxDBTdJAQ',
#   'ZOtbzTva-fM'],
#  7752: ['tRnElznhzxg',
#   'mY5I4G3tyPI',
#   'T3Avk-sblVU',
#   'kfFUAFcp_5o',
#   '3WkaLNR5jks',
#   '6KNs-29Q1XQ',
#   'lwF5R_G9x0A',
#   'MdZL7x81N7w'],
#  8106: ['7Tmo7O86awE',
#   'E-eWJX_i3dY',
#   'RhusG6MCyjA',
#   'XbEm0yEQRwY',
#   'HZv7V5NNd7Q',
#   'ix8YsZV-R-8',
#   'SklNUZlugtU'],
#  4940: ['-zPbNlE7SPY',
#   'j5jBVQdQQIs',
#   '_lF5FWxHRdc',
#   '8eSHlxf5JKE',
#   'w5KlANTSJ-w',
#   'IBUOvVqSQEk',
#   'dbk8ZbAg0DA',
#   'oK13RfG1_YI',
#   'Zv4Aag_vmrE',
#   '-vfAmZT04dw',
#   'ILfa9VHIC5k',
#   'Qc2sgAM7d-w'],
#  6950: ['ksHkGb8zDak',
#   'hheC8Cwvxuk',
#   'JwnrnU-D9Sg',
#   '0_K0CQZ4Wno',
#   'JbWW8HCCNZY',
#   '6zb3K_Vr5aY',
#   'LCOJfg1FNhw',
#   'GAPHCoW5r7U',
#   'NHf4fphjlQI'],
#  5683: ['Aez9Ji3llJM', 'Nd-8XKBcS8Q', 'xvF9FzxHcW0', 'W8gjyjDIYEQ'],
#  5523: ['4Nxoq1-hb84',
#   'DOr69Jm_ZnI',
#   'kJ6ert2hI2k',
#   'NoRi6YM6jIU',
#   'Kz5cixhqIaA',
#   '1jstPB3GDk0',
#   '7NgQYnuynvY',
#   '5WvD68d4Ogs',
#   'XydUurLvaf0'],
#  5397: ['qfzIDFaMKZc',
#   'MFd4ualheEQ',
#   'zAU8YOoZY9A',
#   'ZfosUxm98Zc',
#   'ZpCK44e-Luw',
#   'FlIdW1CbCy8',
#   'gVVcj47eEAs'],
#  3569: ['8lgpql5s1M8',
#   'nB40QHTJqPo',
#   '84hqZR5odfg',
#   'OjM7uHBawpw',
#   'twnzs7_z8Qo',
#   'nG0wmHo6p68',
#   'PA0MyYh6ys0',
#   'sCI9QcUs60s',
#   'xIejlaIs4lE'],
#  6056: ['6ES0p3p-OhY',
#   'fpnSoAaxWPw',
#   'VUDLyPslHZQ',
#   'LYR033SUAV0',
#   '-U6lW861syA',
#   '6SllD-0klcU',
#   'beMckqz9INU',
#   'Bo6YFqY0Kn4',
#   'GVa6VCEQF9k',
#   'veB5DrP8UO0',
#   'Bx2-wFV9abY',
#   '50on6TQI9Ys',
#   'DGQXCRLpze0',
#   'DOxPXb9Z92E'],
#  3986: ['o7wJCdifwmg',
#   'VEHJXt064rI',
#   'UqTNdbqHMZc',
#   'loVtIS1Prcw',
#   'p9e_vCbKrxY'],
#  4486: ['TFaZC1iP_AI',
#   '6GPA5JVqTn8',
#   'CVyJH7xhOS4',
#   'ej77J_P4a_8',
#   'lDRTVN_rki8',
#   'ySr5AAIPwio',
#   'J3XzFaJ9lk4',
#   'MXHfCXJmTWU',
#   'GZBFWML8u38',
#   'FRbk-Mgd1R0'],
#  5394: ['HMfb0ERAQmo',
#   'xqwKyjjGQMs',
#   'SvqJMrepc5s',
#   'SqLF-88hvAw',
#   'z7Cf9Pz4oXY',
#   'DIuz03Gdh9U',
#   'UhR1CCY74cw'],
#  8270: ['HJ0uo0jsLqo',
#   'bZSLKfhDj90',
#   'Xdbijnhrf-s',
#   'u0lCweJpoC8',
#   '60Fvp6Mep4A',
#   '9UG1CJgx21w',
#   'VivkgX7ebV4',
#   'TTXIp8t2E6g',
#   'QpIOjsxfsWk',
#   'AE_SAMMylqs',
#   'Ox9Rt4g70EQ',
#   'ramCcVjr6fs',
#   'ehJ1EOS0xvU',
#   'K62hKhm0ekc',
#   'kQNrD_l5HMI'],
#  4533: ['McRmVoHPzGk',
#   'jo7RxoJUvl8',
#   'oMoBDisQ-ow',
#   'uTrJw3IlObs',
#   'j0WE1GIun0Q',
#   'YN9qQWuFu0M',
#   '_mzES9uca0k',
#   'zE6AakOxqUo',
#   'C7x3oudTwKo'],
#  3037: ['8lTUk2JHwDA',
#   '9Qz1FSzQ2mQ',
#   '9SXRwqRjzCU',
#   'uKJ1Gb4zHF8',
#   '_vfCrup_wqY',
#   'oibz6CVXNac',
#   '3L6RK_4r8To',
#   'WXz1zUsgFY4',
#   'NfCYP9T_i-I',
#   '1R0qbsvruAw',
#   'yiDINFEwtzs',
#   'VBlh2irPeOM'],
#  6764: ['RfDqHDuj3fk',
#   'ieSCa50CnKE',
#   '_7hQIICIRRA',
#   'JPBEiYSxJao',
#   'qTOn2Ht_kPc',
#   'MLLwqtY4MQU'],
#  3641: ['gixE2eaaXRU',
#   'JXhlSnm3HYM',
#   'Dz3NOArQSVw',
#   'Frs-FyLcL7I',
#   'CKRrEhXAJkc',
#   '6xlUpY1G1aI',
#   'o-K-s8Q8ap0',
#   'KyXrzbg8HpM',
#   '_Uv6C2s7lMM',
#   'ibrNU1TukBQ',
#   'fM3OEMQRBas',
#   'LoS6RH9fKmk',
#   'JmHddBObVoE',
#   'IITnvmnfi_Y',
#   'L8G8_-APrj8',
#   '0lsghVMXACI'],
#  5144: ['u3VI7EiRUxE',
#   'oaPoEzgIW7k',
#   'ad9aa-HWQQk',
#   '3zP8QO8ptj0',
#   '0HgoiLfmADM',
#   'TuerJLdKfCc',
#   'l6BMNVzXB3Q',
#   'gpow-RsbA34',
#   '1R9qNAbRarw',
#   'bJRYggXp16Y',
#   'd76VsaB9YSI'],
#  6227: ['6sBpHIeH78w',
#   'm8UVdIpRUYY',
#   'IbuOIRNT2rk',
#   'uL4FP0y7ItI',
#   'brStDb52jmY',
#   'gusqKZ4pPcY',
#   'bIJ8xLqFPIA',
#   'ynGP5c06WB4',
#   'eSL1po1rk8s',
#   'pml5SMKpSjM',
#   'C11qF_edSCc',
#   'vVT7PFy4S4c',
#   'siPsCEFOi38',
#   '8iSTWI-mumM',
#   'JrvxKmmbOvQ'],
#  7769: ['CPACbIuPxEk',
#   'Xm5bZhYPVNI',
#   '7ONY8rA0l14',
#   'gBBjAhhRaTQ',
#   '0P7wRVZJRTA',
#   'vTnSkcDcino',
#   'I8_1S509evA',
#   'U1nj7TR66m8',
#   'z0fV_Zybsss'],
#  8137: ['wYtCymNFs68',
#   'O7bdn8yf51M',
#   'K1UtkjRiwyw',
#   'q8lt656mqAc',
#   'EkxpatFA9qk',
#   'jrrqAYslfAI',
#   'hrqdlRm-jP0',
#   'vLIEG55Vgqo',
#   'mfCZUYqB2lM'],
#  7419: ['A1eVyZ1US10',
#   'w44BXLATt5w',
#   'fa4Yl7Pn5Fg',
#   'SbDUY6c0ICE',
#   'eb_cDiZPfFk',
#   'wUE1rlSvB58',
#   'hUHrEFiktKI',
#   'FKgLw0khHac',
#   'KYXhOP0kex4',
#   'Ef4XYnJWl_E',
#   'jOu4Uvdgfik',
#   'U0J5Zr-FLs8'],
#  8005: ['InVirEjbL34',
#   '40opT2Efhs0',
#   'nfX9mldsXtQ',
#   'hcrFRTOE9dA',
#   '8DG_oMutB04',
#   'ccn_6C6YZfQ',
#   'inbJXLQtZS4',
#   'rNDEvVKNTQY',
#   '9E_qZfNL_ss'],
#  4871: ['iZr8r_excJU',
#   'a58IVR51WoY',
#   'XCUJ7lg5-qY',
#   'peh-aeHKegU',
#   'VRwRqtIcXXw',
#   'ZM-g45I0RoA',
#   '6lkoWncRsHM',
#   'DL00TDq9A-s',
#   'vUgSyaejII8'],
#  4707: ['vVqt8CtVb-Y',
#   'eIWVLh5l64M',
#   'lXTa0LxP1Ds',
#   'wPCJpli_RX4',
#   'ceNllISphtI',
#   'wDL_BMX_JNk',
#   'X4ViZGZkP3A',
#   'ukPzbbPYbYc',
#   'ecWa8XI6jlw',
#   '-key6YKwtu8'],
#  8397: ['vd7YOpIMVDc',
#   'CWh9MuVe5ZM',
#   'qc297bxb3jI',
#   'Qv-btZqe7Og',
#   'SSzUaGNyIKQ',
#   'U5tC3zy4ewI',
#   'FfkLmCsGTSU',
#   'jYPbVSn8sxU'],
#  7869: ['YpyuIZ53Pgg',
#   'PnmH-2UeCBI',
#   'X9mnrfyYwv8',
#   'ZK68ywHtEU4',
#   'YKjGKynOptM',
#   'RStSJooHURY',
#   'gWJtD4aQKPg',
#   '-MU5OFK2Mjc',
#   'O1ym15x0tZ4',
#   'ugk86jvZKz0'],
#  4336: ['gHJ_HyAZzxE',
#   'h4mrlFJYoL8',
#   'zS5jZpXjrno',
#   'wyzFloJ2PcU',
#   'Uu31-wZCaQY',
#   'GvkN7h0GK0k',
#   'yH41H8TF0KE',
#   'CXpVeZXdGLI',
#   'VHI-LsbrgQo',
#   'I8O21yKEYd4',
#   'kqcpFaBSONA'],
#  4835: ['y3y8ZEhWZpA',
#   'UyRRrcjInhY',
#   'zpX3uR-LY4M',
#   'eTwHmpd8EgA',
#   'mdymQo-YuZY',
#   '76sbGwY6Kgs',
#   '83KatH8HoHM',
#   '7n2Z2OpgFts',
#   'hctYCvKNolI',
#   'LCBaDdMC8F8',
#   'LvPPaAkAmGg',
#   'SGLedVsIh20',
#   'y_5gqV_TQ04',
#   'uS1ppjrvnOk',
#   'ooLMDFkKHAQ',
#   'R2qpfqTNs1E',
#   'ywJsX3ArQaw',
#   'Rl3tuN2ZvnM'],
#  4233: ['LPAZu9p9ps8',
#   'Yaw6Sa-87L8',
#   'oKriC0gbFLM',
#   'VmAfFM5aLUk',
#   'eG-xAIX5Of0',
#   'oPGx-B7IcpM',
#   'H7bMHu_Mc8g',
#   'neAzyz_lNgA',
#   'McwiQqrtmGI',
#   'ppzXloUAFS4',
#   'iNq99h0_a-4',
#   'xY3-P7r23Ys'],
#  7154: ['4fZ7fjaCoyk',
#   'NMPSScNfR94',
#   'bWFqYDo_imM',
#   'Ph_b5vA4M6w',
#   'q8M5oA-TiZU',
#   'BNxRN5qtrL0',
#   'IWwdT_q7Q6Y',
#   'EjVTccHX3RY',
#   'nP88dd8kYoA',
#   'qSKU9irMP1w'],
#  5719: ['8uIdik1fkQI', 'sZ7zCjhbw4U', 'TpQKxULHc1k', '1_2Nr9AKvpU'],
#  2536: ['fuX5UmPBgbg',
#   'HWyyUWebEbw',
#   'oCR1B1bSuoQ',
#   'joKwdfPtbks',
#   'SiQE20vspOw',
#   'Q1G7oHjZuy0',
#   'VaoFuuOrxJ0',
#   'v_pHW1ILFB8',
#   'hFkJCIN_8xQ'],
#  5605: ['8B-LtH5zW5k',
#   'wuhshhsqw68',
#   'qtSgviHegAg',
#   'uarTRgpn2ms',
#   'FzWFwNa8qDU',
#   'Ostw31lGgcU',
#   '366Ve4xCXHw',
#   'Q7eH3-oi2Z4',
#   'RFE41BGCmy8',
#   'k_2-5Ej4C9U',
#   'ncIdn3CKlgY',
#   'WBbilmgKW7w',
#   '1nCYPitHAfM',
#   'ugKQ1TFAL1c',
#   'ysPHeSbGOwE',
#   '_IzxdwvpeOk'],
#  6994: ['iq_Cx-KYFN0',
#   'FqtWh12XKn4',
#   'Lz2A3CPUAws',
#   '3CsPTSS0YJY',
#   'Tl0M3wvGpzA',
#   'sFqNsIn-j9o',
#   'hkOmvkuhwA8',
#   'vbyyRv40_Us',
#   '3Db5yGw3YiU'],
#  8211: ['pIPy475Krgw',
#   'Oy9KfBHRRAo',
#   'L6WXIboxb6g',
#   '5be50C0PiTw',
#   'BgCmzhqkhfw',
#   'q1meZBapNpo',
#   'STKvGM73aok',
#   'NwqCpEK6iLY'],
#  5978: ['teG3eIN1Xo8',
#   '_xzVMY2V7wY',
#   'dWkzSgSxzro',
#   'i4tCdR8f97s',
#   'js7_38yyzow',
#   'EfZ2ZgdGJX0',
#   'U12Wgdw2cQk',
#   'StsVR-IBLW8',
#   '8ZuMAOgygfM',
#   'EZLCapJsGEk',
#   'ewAHyph17kk'],
#  5946: ['saINtyjzKyI',
#   'OcUR9P9p57Y',
#   'iUazrhm4yxM',
#   'KEHdZzc6wsI',
#   'zuYioEhS8mc',
#   '7KxmzgqWauA',
#   'pzUV3BtOyRo',
#   'T3tGmK5zQuY',
#   'MGFJA_2rVuI',
#   'hXfqXhpPNsY',
#   'rDDj4qs7BHA',
#   '2GcgNOkzGmc',
#   'ZZtk6wspRs4',
#   'jGBi8LZKtRw'],
#  4847: ['zb0sV4xKH7g',
#   'T0scpb9LR5I',
#   'zLNyuzkS5oA',
#   'eB6Tx2B3NlA',
#   'di8_jBHrSRk',
#   'shbJWdBfUYQ'],
#  5599: ['L94c6c8C8oU',
#   'HIjO5TlWCvw',
#   'J3xXLTxjIj4',
#   '4BmzORaN6XU',
#   'wpIuF2VXu68',
#   '-FTazwYvV64',
#   'DITHMx0vbB8',
#   't9a_HbWtH4g',
#   'nzoKwwmozX0',
#   '5tROkLbol3s'],
#  4697: ['oUt8cgYTMRo',
#   '6JTIuFU6uY8',
#   '7zO53mSGl_E',
#   'UDf7ugya79o',
#   'XKsXohKMVjc'],
#  7061: ['emPYcRZyAV4',
#   'oU23SN3sj-Y',
#   '6vkCnjVbgv8',
#   '2mOje5omDqo',
#   'Wzn4dTeSpKE',
#   'IG50t4EPgXE'],
#  4359: ['tjbIUe0nb20', 'KeBaHOiKR_s', 'qAIwjG1xsBw', 'nxg0cq5P7xw'],
#  4044: ['vtJIsS5eGRQ',
#   'DjDVTyWRcZk',
#   'fw2mAyW43uk',
#   'Qu3hC2rOCG0',
#   '33ARHiIO9JE',
#   'zQgB9sIeraY',
#   'wsVgDG69GHw',
#   '-PNsGaJDJQI',
#   '36cieH0YwFY',
#   '3SbAnh1mGjc'],
#  5275: ['ebXaUy9I1TI',
#   '7hIWDoV0VW4',
#   'RY3f41lfkuo',
#   'bIeRniAPBEo',
#   'QmlqzcCiHvA',
#   'gfK9pQ6ompI',
#   'gkorUqLLOqA'],
#  8416: ['-7AWkQDDp-8',
#   'MPPeMZxR2nM',
#   'BQNSOL4Dj3M',
#   't56dcYV1mqY',
#   'YUvwm9vnlpw',
#   'jf_Xihk5W20',
#   'tY8SKKDCeis',
#   'rbsLN4AkvyA',
#   'eQvQy1EWpKk',
#   'p79ufoUQdQY',
#   'DCW8HCj-G_0',
#   'hiwgt7_UtCs'],
#  4957: ['lvOKGfl2cbw',
#   'Mq3Buf0i_YY',
#   'SIlg7HAcCv0',
#   'giR7RN3UcD0',
#   '8aeX6dzg5jU',
#   'eF93xbJScxg',
#   'L1PfgEkWQD0'],
#  7649: ['RSjiFETdslM',
#   'U3mn0BtU7x0',
#   'STNDGBEckOk',
#   'Q9VLtSN8nSA',
#   'Rf90Jbbcr3M',
#   'bm5_8viqi28',
#   '0GOAyQESVsk'],
#  6542: ['UJ13YcN5OFQ',
#   'M8gzfTBFPz0',
#   'u5DpVtoN5qo',
#   'WaBRiZ12iTk',
#   'nJWPBC07b9o',
#   'jwwGY88ikFw',
#   '7Pg7MzV4hsU',
#   'xMfKyEjBa4w',
#   'x3Cq607VILg'],
#  4011: ['NUo6AlfuVV0',
#   'wiSixQ7VVII',
#   'HyEDc3PfZKA',
#   'FicSnweaNSY',
#   'dA54MoaaLEE',
#   '1zJdZYWlN0c',
#   'k3qg55Iq13k',
#   '3Snvi6wwz8E',
#   'BzhbfmHspFE',
#   'pmBWI18qjGI',
#   'pIjpnQdYOOg'],
#  6921: ['mC-0cm1g5_g',
#   'RFFCLA5rf2Q',
#   'OXuTvG9peQg',
#   'je_sC6FJ8iU',
#   '8sO2guxmJNs',
#   'aI8H5tvY0ho',
#   'ohbHEiDTrZA',
#   'fD4wqwa48Z4',
#   'JCl16p8xo9w',
#   'yjohrPtAoso',
#   '0W0g1n2U-KM'],
#  3453: ['XirYhAsn14Q',
#   'UeH-rJ837h4',
#   'xSuO9Aa2_64',
#   'YZbJ11UtaXc',
#   'tialXNmboqk',
#   'qcIW-eMHIL8',
#   'EWl7WUOlt34',
#   'CtwkwZ1lcGY',
#   'IYZ-c6G6PIY',
#   '9tF5ItqDmn8'],
#  4882: ['5qJNZ0vFVhQ',
#   'GFcyEpys61k',
#   'zGlPgE66VxM',
#   '06cYWnqihl0',
#   'ItKCxviHBSA',
#   'P6T0xP1j5sA',
#   'LID3NzcmTnE',
#   'l1wR5cRx7mM',
#   '4fOqs2CMpMk'],
#  4342: ['eG71XDuHoG0',
#   'KRokDDel6yI',
#   'NTlehboZttA',
#   'Wq68pQWfO4I',
#   'fhlWSALC7yk',
#   'ArMeEnAOPHI',
#   'Mp_bRgmph8A',
#   'x8PbYCzXmLk',
#   'YAzNuDzkcj0',
#   'Az7r3o_9ol0',
#   'p85reKKuA2w'],
#  4293: ['0ZUldbKNh6g',
#   'XVwomB4EToY',
#   'atfMzYSp_U0',
#   'ZKulYs3lNGk',
#   'F01Uc9ZvgcY',
#   'DnykCyEtLyQ',
#   'Du8a5KyRHdI',
#   'kKtEVSFg9ZU',
#   'cZkaA3_SvZ0',
#   'wb9lIIxcJ38',
#   'x-SRsUieT9M',
#   'qnZvsYxLA4E',
#   '2DR_0_QNib4'],
#  4489: ['gVIFh0Hly2k',
#   'cDoubtvdf0w',
#   '2dP8KpVtCHU',
#   '8w-hsRcSRHY',
#   'Uvrv9vmQObU',
#   '-N5YKjArRWg'],
#  4190: ['oxDuZfqgkiI',
#   '5TwLTJ_zGBI',
#   'xdwmaUZKmas',
#   'S22xeq8xxFQ',
#   'i9--QMVpqCw',
#   'gU3fhVr6rmM',
#   '0Fjh-KX4wq4',
#   '6SX5f0mVMxQ'],
#  6275: ['9a9O8UCegSE',
#   'mDoOl7d-sMU',
#   'ryuTz4diZTw',
#   'pTXqOPu9gSk',
#   'Xg2v4iIqThI',
#   'i5vu379JZPU',
#   'kzNixhWmRlw',
#   '2b96xl5YU1k',
#   '_-8vsnmbw3o',
#   '7azc8LeBvnE'],
#  4056: ['Sz4gF49VOq0',
#   'XjxtOwuzHi4',
#   '-8Ai8Ghzbow',
#   'adclsaUfI1s',
#   'h8FBH7Iyxks',
#   '6N3T2xVpvFY',
#   'r4KJNv7Xboo',
#   '0lFhR6lmlUg',
#   'O0lIZ_menV0',
#   'Uq9BjlR7XXc',
#   'cEwwFHMsUYk',
#   '6WpQAE5F4g0',
#   'CNSMspI5wTo',
#   'k62DqRsTmfw'],
#  2612: ['MTCTvcxmh6k',
#   'CF5ROgsY0kc',
#   'YDF4mVnNTsY',
#   'moH0egGmaBs',
#   'XfWQN3q27ss',
#   'tLmn0RNuUoo',
#   'PtnB_TW9jA0',
#   'RBl0miVa0H4',
#   'XpR8coS_Bos',
#   'JLgGatzD18A',
#   'sRl-jGwqllo',
#   'HriuD7MsUak',
#   '-DUxg3CLDX0'],
#  3753: ['raZ9QEPTOJM',
#   'Kp_rURU6RGY',
#   'NT9z6MWiGdM',
#   'N-RFJHOTWTs',
#   'UD7wsI99-HE',
#   'zdYiKRpSXmc',
#   'zF50g7W7fkc',
#   'XFUypN3qtHQ'],
#  5980: ['VmP2v3hIVDs', 'SeXLurfU67I', 'I96VLZWVtBc', 'zawmBw0AA9w'],
#  5085: ['bojfyE56Ndo',
#   'TVyLfrUqyNI',
#   'uOzPekC4JVI',
#   '-RmnrhLmscU',
#   't7cCQ71AMWM',
#   'ThwB8wuEq-0',
#   'yDAkmdKM5yw',
#   'eKc8-YWIVqg',
#   'zwZWFuZA6sY',
#   'dMz1o7GWOZM',
#   'WJaIRQJ49Jo',
#   'yeDkdPc0mYQ',
#   'LTBXluGaRpo'],
#  2630: ['U1TgQEpiuRU',
#   'a1FsvbopGg8',
#   '-MuU6pFmrN0',
#   'EZiUTX-fn6U',
#   'LQocHJGla-M',
#   'fCtmCI-yAeM',
#   'gPsoJaGXHsI',
#   '0j_NIBRSLFI',
#   'G2ZMHLQG8RQ',
#   '7uOvhAITlMo'],
#  4795: ['GRTDtGAuE74',
#   'GXQ7RvqXfkQ',
#   'soS-j77oQT4',
#   'mp6Hhs1_kk4',
#   'qJ34wXlkmv0',
#   'ul54qU_32oY',
#   'E5kJf-JBw4k',
#   '7zzwjWV3uM0',
#   'eHpGRR3S4nE',
#   'FTSLUG-Fu50',
#   'JjWlBGgFzeE',
#   'L-EtHtqCDnA',
#   '5A4xBp2rizQ',
#   'eBTETzFgmmg',
#   'CznCv64-HJw'],
#  4353: ['nN_WO9QUN3s',
#   '1VVKI3vHmCE',
#   'DkXJqEa5S3I',
#   'qd-DDzIh7Xs',
#   'JmHwG8gvkpw',
#   'kvggWX4DTjk',
#   '0arNl7skqg4',
#   'LSAUNvh4ADc',
#   'OAyE3a9Ek8M',
#   'HJIRQjuvxzE',
#   'SdxpclofF-E',
#   'WFXonrsMkwc',
#   '1nC3KmSF85Q',
#   '0RXBMUGQLa0',
#   'E4P6G76clhU',
#   'LAcErtGU-VU',
#   'dt7wsMqnBE0'],
#  7678: ['jVI4gvsPCTs',
#   'pE9k6OVDuc8',
#   'XTO7YJisj1c',
#   'cXkTAIeaH8c',
#   'G0X653zY3R8',
#   '8FYPN9HkevQ',
#   'yjUA7Ej8r0E',
#   'DRBcUvKOmSs',
#   'UVfAuO1UgQI',
#   'KHZRVDGQWNw'],
#  2898: ['kOTcoeXsU6o',
#   'Vfp1zB4U4Rk',
#   'YfGHNdVeyB4',
#   'aGbC68cC2jA',
#   '8BC4DOlJkT8',
#   'bhsjYvv60YI',
#   'TjUv8V2jH-4',
#   'ziV9Gfd1C2I'],
#  7590: ['qhoUHXyZLYI',
#   '4b29ElIi3QM',
#   '0W-NioIROHQ',
#   'HkBXi0XHwa8',
#   'zaJqqusjOmg',
#   'LYstLMalQHI',
#   '5HnUAreV4a8',
#   'ADWY-hQw7jg',
#   'tgGIUY1qVDU'],
#  5139: ['eOIErOyp4Ro',
#   'wLZ6N3875Q0',
#   'Gpf9sMDGvPQ',
#   'st769WtUqlA',
#   'TpzksMbzJyU',
#   'w8dRF2RQWZQ'],
#  5191: ['n206vtoSN9Q',
#   'afLNRwhZoGU',
#   'h2TDy__MMjs',
#   'V2Jm5v32JBI',
#   'fJwYGAWBSOE',
#   'tJRzc2C0Cl8',
#   'XFXaw-wJAas',
#   'kTVi5OvGJcA',
#   'YR3nBfaRQU0',
#   '1YmEheMBTic',
#   'SEoK3cWjPq0',
#   'nfbHEOhC0C4',
#   'ZHGzUX_moS4',
#   'o5BDoi06j4M'],
#  4928: ['Jt44Aa7XD8A',
#   'UaH7nvn7BA0',
#   'zvx5C5X_Ee4',
#   '_v7pY9irOT0',
#   '1nyyvM6pxrM',
#   'hTlxDQep5Z8',
#   'Tm-GzkORjkM'],
#  4887: ['1BNXYZXw4hY',
#   '9m4PcrWIxN0',
#   '4twQyrlPpTE',
#   'aF9CI3seXtY',
#   'D2ci7o2kRAE',
#   'WMJHziJkAcE',
#   '9sDqOrMosKQ',
#   'ojq53hPHihw'],
#  7338: ['xLfheoP4fnA',
#   'sYww42_Tef4',
#   '-oXA9xVJNt0',
#   'rOWb4VdR0ms',
#   'kcI2H4aafx8',
#   'dzT97gzXQTE',
#   '-_sPd7zpWu8',
#   'PJJpOAqqoYs',
#   'pTk2mRMI_MA'],
#  5538: ['eel3M4hHPMY',
#   'SPF0KmS_0Cs',
#   'ww8lzvSZj34',
#   '2FeB5LZcf1U',
#   'vC9gclpqcwo',
#   'BZQ8a7ys6ro',
#   '9k6z9auuSXw',
#   'uMiza385Vzc',
#   'Iixcc5kGTkY',
#   'AnT5e2v6F3g'],
#  5089: ['nJgAK-kUO1A',
#   'ekak7nCa-_0',
#   'cb3wtAA2wgY',
#   'PfVP60f5vck',
#   '55Yo9Dwjnxo',
#   '1c2FsI9pCSc',
#   'ijqo43gHMko',
#   'JGOw4doTEnA'],
#  7263: ['oxgUU5HMp5A', 'FUXmA7PecTA', 'isAFI0wpMHI', 'ETUrokLt_so'],
#  5297: ['MYrS2VUQjmc',
#   'sdLJB-sH7hU',
#   '-0IQkLdCtSs',
#   'e47GLZKzqzM',
#   'FelCtBepNMI',
#   'BOVW7L95dB0'],
#  6186: ['zTQVYP11qK4', 'PVPZGO7Sioo', 'X5XlzGLRulY', 'RS7uKveZsP4'],
#  7682: ['Ip0kRqbrZ74',
#   'cl7VvLSM3Os',
#   'Igcen_J25Fc',
#   '2259xI1zTbc',
#   'lzYfp4ZPO0k',
#   'qlHtv0Pd7QQ',
#   'Xw8-IQ220Tk'],
#  6827: ['IEic4SOcFMo',
#   '8796Ybk4NUA',
#   'rL2xqAo_CPg',
#   'mgbz8K1cMZI',
#   'BMByxj2aXsA',
#   'mXwklQdt9Aw',
#   'o6bPNuCOVNs',
#   'jgXSJonQ-fQ',
#   'd2Gqf9bUFN4',
#   'UgrKkcovDEY',
#   'mok_z3DxsEE'],
#  5508: ['68l7wyHw97Y',
#   'S_pQFEbWF7I',
#   '5fB9ugKqnN4',
#   'jxvBVf5e_IQ',
#   'UqQb3Nf_Cis',
#   'aVTWRrXmgl0'],
#  5789: ['1ylVze6Wbos',
#   'gvxi9xhmg4w',
#   'tXxWPCTRLiE',
#   'Pb5TvnjrV7c',
#   '6Ium8-r0Fu8',
#   'LGHyuRzrJ6Y',
#   'aGW7RN_hZB0',
#   'XzB7M9L1ZIw'],
#  7212: ['rhRt4MsiCbU',
#   'K2WjexyzKHE',
#   'DO1a7hMUWfI',
#   'jJ85Wf5FFe4',
#   'PxgONVdVnGM',
#   'zBi-MOQ_OoE',
#   'FZsxNFpXGMU',
#   'KmirhpWA84c',
#   'zgTbnus5q4Y',
#   'lpQX37SCHb8'],
#  5458: ['PmEZy6J_LjI',
#   '-pyrVvjSqMg',
#   'QIhbijrZhBc',
#   'yN9xGIbS8D8',
#   'HGn29fK906I',
#   'y2w37akqKsU'],
#  4992: ['_o0KGWxLnig',
#   'mbMa-tNVM1Q',
#   'S2tH07AMZsY',
#   '-6_-Z8j2b0w',
#   'ALWH0Vwaa6s',
#   'OVdt4TMKRyI',
#   'OZjvQejrBfw',
#   'vOmebcleTIQ',
#   '_M6u4iOraZ8',
#   'eUpJj3q0ST0',
#   'HQ8_bcyekBk'],
#  8062: ['13khOzl4roc',
#   '-h66IdvqFHY',
#   'EmIY1hPtSgE',
#   'z4otK2kZ8a4',
#   'zc592JvDjuA',
#   'cbsZRtE4vhg',
#   'WibHZtXgRS4',
#   '1Q4OhqVotBk',
#   'XOk2T0ZZnfU',
#   'K0FOGJsRBoc',
#   '0Ok7gFFnMeY',
#   'yPDdiQA8SFw',
#   'NMmPWEHvfVs'],
#  3473: ['KMkek8CHe5U',
#   '17QsFtxg_gU',
#   '_yR_G7nKPg4',
#   'cVLNG3i-l8o',
#   'vjejsnzSs8g',
#   'mnd80X6RS0Y',
#   'cC841IyJXxw',
#   'moutq42k3Ek',
#   '2Erl8nBH1k0',
#   'l22uLDCClLY',
#   '3999UYJ9_aI',
#   'y9WpEw-eALU',
#   'ZCX53Zz2QC0',
#   'YxYsZi26fek'],
#  3665: ['bHQwrN-_EK4',
#   'YDmtZBz4AnQ',
#   'rg1Y5UE4C1k',
#   'V5FDo_83mHM',
#   'wnQok1wJmv0',
#   'O16eaCJFg6I',
#   'l7_xKZFjsFc',
#   'Ny4c0NR81Eo'],
#  7613: ['w7T7tuWo0ns',
#   '6U4Dx1WLAic',
#   'V6mBHVxYw20',
#   '1sAItbKqr8o',
#   'CnAbreRrq70',
#   'OJCnsuj33sE',
#   'peJ_B9i8ziw',
#   'L1U7Xx1S1sc',
#   'eilYPOeWeRA',
#   'T-_AarNOhX0',
#   'C-JDuZSxvDs'],
#  7127: ['gaMNTMnHYD0',
#   'mtD99QClqrI',
#   'yiVPg2Y9koI',
#   'b0F9mjiWzuk',
#   '0BOuGKceDJk',
#   'yMX3LEHVWCI'],
#  3633: ['NxGba1Sj2T8',
#   'QJKGZb9GYLw',
#   'p8wJwMPkxYA',
#   'kF6xBGoYVL8',
#   '61hTHeba4J4',
#   'Drvq314FrXY',
#   'm9ABwcSQFZA',
#   'hxwhffU-tvU',
#   'yveC98ju_zA',
#   'I47xKdRt0J8',
#   '2QeTyo8e2L0',
#   '0KvBaTI1ISQ',
#   'yOvvMwU4zo0',
#   'Le-6q31zICc',
#   'B8wiP7vEobY',
#   'z8ls8c3VxCI',
#   'nXvLiQ870Vs'],
#  4926: ['XBJ0qc2aHd4',
#   't7fpvduXZI0',
#   'evhimEoP4Ao',
#   'R6qho_rREZo',
#   'nAYkmpD25lQ',
#   'KdwX-kOE6KQ',
#   'rsGmi5_-0aw',
#   'gxm9ami-v0U',
#   'v2A9UNOVIYg',
#   'k02t9jVtJk0',
#   'gh3xM96AaR0',
#   'PLDYU3sl494'],
#  6688: ['9_ob0OMjInQ',
#   'gKUEb9D4810',
#   '3B-CkV2BgMw',
#   'MFLYLePD3h4',
#   'JacqlHS8JHE'],
#  4041: ['70twCfbx3-k',
#   'G4Pos9EKbsA',
#   'LVXRp1t3oTg',
#   'BwJCRje0HGY',
#   '_PKvjD_xhgA',
#   'lVL-ZBEymYo',
#   'sJd1eD5t-xk',
#   'ssX1jsEl-gU',
#   'OxHuxZVQS-4',
#   'qY5PIhk3FmE',
#   '_Ass2bbR0kQ',
#   'LP4Rh1RhmPE',
#   'NYYMDv18H7k'],
#  7599: ['TerZFwF8a-M',
#   '6GmJOoFD5Xc',
#   'wDOizGWU1yY',
#   'rwK7I1hALhw',
#   'cfhGMznrLtk',
#   'pexTf1AoYyY',
#   'dN34gntY84I',
#   '_efb0KP18yA',
#   'cnZ0evkwQAI',
#   'WQ1D1K1ywh8',
#   'VsW04tpUXLs'],
#  7668: ['tXOJGfw9VGg',
#   'EUaj9S8msFo',
#   'NfPf73a1iOI',
#   'PgTrl__pK-E',
#   'quGQ3925vBU',
#   'gPydJVWvVvI',
#   'ZVHq9AzhMyI',
#   'JpJc-LOq6Jw'],
#  8420: ['XGJbpZVdSdo',
#   'FtgUQowgeaU',
#   'KzySwLGHyBY',
#   'DFQv7RKRo3A',
#   '2_KSZNm9syg',
#   '1ErBA2v-gVU',
#   '8Gol_RbmwnQ',
#   'CdafSWel1KY',
#   '26147ElRUJ4'],
#  4991: ['4WaVVGRJjpY',
#   'd-6PR0C1SFg',
#   'VK5Y9w1vmRw',
#   '4gGla8JfQnI',
#   'DxwdSxWR2nY',
#   'BDdz6ttcFps',
#   '1XsnLt2X4k4',
#   'ESVRQnDoksA',
#   'GKlaZUFvYos',
#   'YjxiLHpRbj0',
#   'mFEAFLvFcxQ',
#   '6Y7Jd4LqqCc'],
#  3600: ['z6JU1B1b8Ik',
#   '1LFtvo1mDAI',
#   '8gf2DvMuots',
#   'v0J1n_BD5uQ',
#   '4ddvq9rQsck',
#   'CaudurpFLAg',
#   'unBDAeK3kHI'],
#  8380: ['EfYCy3fdMk8',
#   'AldjKoPOEzg',
#   '_RDNxLVcnBU',
#   'wTfE_vAdd-U',
#   'G0MCSoDB3bM',
#   'KucU0fsceY4',
#   '_1TmDDm9n-E',
#   'FSkhXVIgvjg',
#   '8tmqoJ6Ij1k'],
#  7480: ['ryfbZAjIg1o',
#   'npfp6JeBhWU',
#   'bEdfWt34iSo',
#   'RDHtrxdZLjw',
#   'xrdirml8R1Y',
#   'dgBuXEjLwcM',
#   'QB5d5X5L0ao',
#   '2Ca6K18XK9k',
#   'g3NvjfCufGw',
#   'Je39Ri5gMGQ',
#   'gBG6PQuqgsU',
#   '7Izl65CIHBg',
#   '50YviZCLffo',
#   'I46EN67q94g',
#   'Q85ciQl4n4E',
#   'g5_eN-oJk_o',
#   'vVsF9eJGn4M'],
#  4430: ['D-HC-KlZ0Q8',
#   '3u4FmlPzaZk',
#   'zuR2mz9bj7A',
#   '62QCLW61e48',
#   'pDJHj0S9038',
#   'sUGwqsyTVcQ',
#   '_yXcAxPyaMI',
#   'bN32ZJAACUg',
#   'aZy1fFNXfMU'],
#  4276: ['rHrlfELNad8',
#   's8OUAX14uSE',
#   'QZUECL6fPiQ',
#   'mFIPOABvXJo',
#   'X5Y56p3IGXA',
#   'JMiXQeHsp_A',
#   'lJ3pVJ24BZc',
#   'rvuh77qBfqE',
#   '3AaL1y-8N2M',
#   'kfAxR950yac'],
#  5428: ['vk5Wu8SN2LA',
#   'oY0DFJlhVHQ',
#   '6vWo3gLNAlc',
#   'Eh6CkXXgPQ0',
#   'JhMdknf37u4',
#   'mb0aQzyevDk',
#   'wH9cuq27LT4',
#   '31Mn1-usGHE',
#   'wX4qahQ71bw',
#   'BiyDjBF3hE4',
#   'M56V2VNAnIQ',
#   'SxiedgMbhxU',
#   '5LusTQyrjJ4',
#   '4OkBKHEdWF0',
#   'fVeHG-4A5Iw',
#   'RpgSO1hvCoI',
#   '2qHUxrm3Vbg'],
#  5834: ['7vW-yE5YIkw',
#   'u2awJ56zE-o',
#   'w8BTX89XGD4',
#   'v3FQOQ2AuIQ',
#   '8LYoR2Mpa_0',
#   'v-u9ykuPezQ',
#   'DGKjUX6LwzQ',
#   '-7yf1tOVgk0',
#   'V8X68km7szA',
#   'UHSjvM3Mr-M'],
#  2821: ['4_WE4bSUm2E',
#   'lXFwIEAOfxA',
#   '_OKyg9QgZLQ',
#   '_Ytxp-TAkMU',
#   'VwTjdz1bAco',
#   'dITwx4H8kcc',
#   'LO0ctsjDtJM',
#   'OMTZkulJ3fk',
#   'vL01OqZTrTk',
#   'vtq9cS83ZBI',
#   'P8Nf45BZTrY',
#   'bWnUjCnq1-M',
#   'Ha7mGHvaS3U',
#   'q4lVfMTKfsE',
#   'c1EyN8bsrbk',
#   'HNZsMsEEht4'],
#  6753: ['2ov34WqbjhY',
#   'hHzbi4CZhUg',
#   'kB52yDvCCQE',
#   '3F8ZVLFoXTY',
#   'C3R4zBPJvII',
#   'sgjUwxS4bxA',
#   '_uMUpceERSM',
#   'Z-ervTdQ65M',
#   '4yrVlcNj2G0',
#   'cbEA64C6wbY',
#   'Fe0HRXsDDNM',
#   'wJZg9ZtgUNU',
#   '8busrqKX7dA',
#   'NgS_nG4URF4'],
#  5773: ['Etw6YcRNdYg',
#   'oUn4m9dDFqs',
#   'MLuJYaqWIxQ',
#   'nPXtr9L7_bs',
#   '-UVaFkMeStg',
#   'sAYydkYCKNw',
#   'TerM8Ks74ig',
#   'TEHlZRAAHVw',
#   'blwmrZ5M1gg',
#   'oVXZRtKtBms',
#   'FtJI2NLkj8E',
#   '3nTD3D3PCXk',
#   'WV53Mf5Zm7Y',
#   'uUbsb7nrxNE'],
#  3779: ['cnKAroHx3Co',
#   '9sLULL0mbig',
#   'M2c8bAQHT0g',
#   'gyKV6s2Tx3I',
#   'jvJPqcx-9NA',
#   'RiPTjdd8B_s',
#   'FCIyXkPdwkk',
#   'xm4WFPvVUMk',
#   'TFQk5oPUe8U',
#   'Jnuw97yqmHo',
#   'fW4PPMg_WaM'],
#  4454: ['Fy6UkTsCsLg',
#   '79zrbmNnM98',
#   '0wzEQFR2B_s',
#   'iRGvvXL15CM',
#   'Kcjrinli4Gg',
#   'XKdSYpIRa4M',
#   'CqBtO4PNMmA',
#   'OcTzvxw5I14',
#   'lF-RFm6N3yA',
#   'ljeZRn33qDw'],
#  3063: ['TIGTt1YehX4',
#   '3apkhu5UL1I',
#   'OCaIiXSp18A',
#   'IvjZ1n8Gtaw',
#   'zdcXgOnuhAk',
#   'i7S4wXt2Rck',
#   'UPPZXFalh1E',
#   'yaXR8ZMhzwA',
#   'l448IBNpuZI',
#   'objF6sXnRCM',
#   '5LDbQLiaBFw'],
#  3872: ['ehVUb-RXAd0',
#   'Chp8OVjRVr4',
#   'z_tFVS3CbsY',
#   'RpOVlvO0MFs',
#   '_dR9r3vXpRo',
#   'AhFu81WiNDs',
#   'J85991pPYoc',
#   '4g-Qxt8jbGs',
#   'Dco4NWKhTO0',
#   'AHAx10Azj2g',
#   'LWznoK6osFY'],
#  4330: ['G83JJhid8GI',
#   'QxDbo2XWHZM',
#   'JSw6uVKVfpY',
#   'q8dPBKb8jqI',
#   'F9ptZ1Xkvdc',
#   'p-oNZKNv0UY',
#   'euajGoaxSz0',
#   'HyLZOfZjEgY',
#   'TbCCH3ZY9RI',
#   'f3zQKbH8nG4',
#   'V1kf311iB1g',
#   'LQbkTwbyJYA',
#   'vpnlTUXfElk'],
#  6676: ['2fiBOu4jtxE',
#   'RVrVdMpfGvU',
#   'HKLYP8AYJwA',
#   'LNhGSQiv-4Y',
#   'PRZlUg07qSs',
#   'dk4anVtP7g8'],
#  6297: ['wY3Rm3pDhRw',
#   'BTThho9V8zo',
#   'Fkvsi1E27Po',
#   'a3a6D70C5gk',
#   'htCaMTyxQ8g',
#   'aTvj03AWCiU',
#   'mTfaUa64Y14',
#   'fEKIIrh4nDA',
#   'R5aCK_GklSQ'],
#  4827: ['WBjqVWjMJaI',
#   'FEic-oOPqLw',
#   'dbJExVW3GQQ',
#   'QPLCevl8Nec',
#   'aHdSWPyBkZ4',
#   'MaXP3qeorME',
#   'FT4KNRueL8U',
#   'yPXjougb22I'],
#  6108: ['vRgxrBr0CSY',
#   'wbsB11aD2tA',
#   'FA0oyo5bAjU',
#   '-G0oxRcfQic',
#   'Cs-Nwabq-sw',
#   'r7fJsP3DCtY',
#   'ybEXSdG0kdw',
#   'Cb0bik4ZUVI',
#   'sT-iUjiZWj4'],
#  4791: ['Y5Ilicq-mPQ',
#   'FsQF50CKi0Y',
#   '6qTfUtf0Cto',
#   '-9mXmNcvbBg',
#   'smWMMHDucL0',
#   'gdg_eCxl_Xg',
#   'NTo7FzfpMWU',
#   'bSsUeUXQGis',
#   '6Lplvph9ZCI',
#   'b8DqxQ9TAb0',
#   'eZGaqFRL4-g'],
#  7469: ['nlDNADtE42Y',
#   'arwB3Y5N3yU',
#   'n17dG8A04CA',
#   'wzoM6Vwe_Y4',
#   'yVdStxak7Xo',
#   'tjXFjI9jedA',
#   'WaAAwJIQQko'],
#  6906: ['NflslbNLntc',
#   'x8yzRO0QAg4',
#   'z4Z2fmbI9gY',
#   'AURIhx9U6aE',
#   'rCrBMhsMeZk',
#   '1VjE8SOIXD8',
#   '6rvHIwT1KyM',
#   'ylDbTIumYBI',
#   'hpReB6BhqWc',
#   'gWd1yEh5AFM',
#   'VcQ8K5Jxmvw',
#   'iE7eMWecB9o'],
#  7841: ['R0KT2-skwqQ',
#   '1oeBmr3pXlM',
#   '52fcped3Y64',
#   '-NVJjkeY0CQ',
#   'FVZeLxPO6cU',
#   '7f8v6EIBtoI',
#   'k-L-Vtzc3XI'],
#  4344: ['eHGiXSLkrNg',
#   '3AYlnqErVKg',
#   '2OPYwXzqz5o',
#   'mbfV0MQRbLI',
#   'Q_u1sTmn5EA',
#   '4vgPJDIwGXs',
#   'vzi64nlNeJY',
#   'b9Sz33H1jwo',
#   'KEOvmuMHvE0',
#   '-nz9mhv3FQ0',
#   'KuI--Uk7yXo',
#   'TuWI4nVAZFA'],
#  7547: ['G8DN9pvMydE',
#   'qywS0Nvv3BU',
#   'zLuGrAhZ8lI',
#   'wnorSDDlQo0',
#   '5-JkB4gx0RM',
#   'NRvXCZCaHYk',
#   'g3-_7je0CWc',
#   '0abz2byL_NU',
#   '7-lP3L6lJUY',
#   'usTnJr-v-RI',
#   'VJximEVbCnE'],
#  2658: ['2OyiPEw-F9k',
#   'B1cMD-ZzuaE',
#   '4K7YS2R9NI4',
#   'E7NVmRENXdM',
#   'BMpTPJDT76U',
#   '0x7MMBapu28',
#   'qD7_H_-Rq-g',
#   'KbGpf4XmEk4',
#   'diCQyr3XP9U',
#   'VEMprZX46FE'],
#  2975: ['WlhVOIkkmcA',
#   'xxJ2SXVgJpE',
#   'oNACISsMgHs',
#   'gqzPIu4BlpM',
#   'hXEW4RWE-kM',
#   'pzjfRBDl7Fk',
#   '318O0B5BEhk',
#   'erBML8cIy3Q',
#   'Oo55RMSznms',
#   'PUyngMwVqcE',
#   'u0YrnDUwF50'],
#  2708: ['GqhUHaTQTms',
#   'N-rSk0GOGBs',
#   'Cb68gKmo1Vw',
#   '4rdzyglP7eY',
#   'P1qNamxy4Q0',
#   'Q3oxYgd0DLM',
#   'ugDv6AjMZP8'],
#  6964: ['A02IoQuGYlw',
#   '98Kb26RVCzg',
#   'd39Vf9qAiPg',
#   'r8LX-dXs_bo',
#   'GNrV9-vE1so',
#   '5qcJWQYo8TQ',
#   '1FL2u12cAzQ',
#   '37s6obQZYLs'],
#  2865: ['0c7xPsZ9fqg',
#   'SI74eIYchto',
#   'yeiSw_8RtFs',
#   'C4NuvoRWk2Q',
#   'oMcksb8XFHE',
#   '0-5Ghy9erWg',
#   'eGZvG0TH7Jk',
#   'SWEaKdVvuIM',
#   'iebi0A2cGJg',
#   'PaThPriobiM'],
#  7879: ['eCwdO3zd1L4',
#   'tfF-gTg4snc',
#   '--FJS5da1ic',
#   'a2zvxkJkHAc',
#   'UZMnzXXg0zA',
#   'WmkYA0JNm8Y',
#   'A1qJ6toQHkA',
#   '9PGyaaxxvJg',
#   'MoClQtd4gbQ',
#   'slZV9eXsMfI'],
#  5488: ['bG-jfyOI85Y',
#   'e90BVIJ4LS8',
#   '2ylFQPXhl6U',
#   'cUQxScOwHEk',
#   '-0Yhlqgtqt0',
#   'wak7PA00cV0',
#   'f4p7RqglnH0',
#   'gB3sfwJx2a4',
#   'kXD2ffZ_5fQ',
#   '382wb4bKqVQ',
#   'lzZ7F-FvJic'],
#  4516: ['6uT7swfhz2Q', 'XlrVd9NGtMA', '52aU241gZzE', 'T_hsVPRiKY0'],
#  5216: ['Oo9hCqxXk1w',
#   '1htMdZSE8mY',
#   'Y1aMxkCSNpI',
#   'hW19a6CfZf8',
#   'p2i57txk2es',
#   'FXhM8hREkms',
#   'mIB1oveFJKM'],
#  7475: ['-MatCpLOawc',
#   'adguxFqG8Gg',
#   'UluRnTjxXd0',
#   'yZE0zMjl9z0',
#   'SLSaZ9p7mF8',
#   'Ce82qE4wv3I'],
#  3629: ['VOmSPQb67-c',
#   'Jp9J4d-tWFY',
#   'vvnolUDToUA',
#   'PGS2v5nc1es',
#   'CTwnQt-PS7c'],
#  5791: ['OJZWYV4LPJE',
#   'XCc65xx5sRA',
#   'h93pSHSFOzc',
#   '4VdiS4yRqQY',
#   'LHRzTpsc43E',
#   'qStsN6RO-fM',
#   'rgX1JRGJYpg',
#   'Ou969pxJrJo',
#   '7oQLVx_udHQ',
#   'y852Z314ISY',
#   'ID7-ftQ9YCs',
#   'teHOptYkqMw',
#   '8Nhy8QdL6-Y',
#   'Qj_A6lYD5xY'],
#  3789: ['CdkFpyQFf1Y',
#   '1rtwQdnq5Gg',
#   'Dc8kUgN6Vic',
#   '-_unpqsHAWQ',
#   'V0O0MEnqjwU',
#   'F7YDuPLDA8k',
#   'lAvRVwq9v6M',
#   'OSsamzBxTiY',
#   'PrmOugvWPqk',
#   'svd6RR-Z9A4',
#   'uKYCuj419qU',
#   'kF960hfCqoc'],
#  3071: ['yqJJuC4Z7x8',
#   '2XeHHflt3Vk',
#   'H7Quhnm-Z8A',
#   'PtDrfU0WwX0',
#   'DMVPxXQLgqo',
#   'hBpaNzi68WA',
#   '3GNq09bq51Y',
#   '__lWehKZZpE',
#   '3CEBCqrcArc',
#   'hld66x8jFD8'],
#  5285: ['1KU7kW0odd4',
#   'XdPzGBth1Lw',
#   'YxnI3nQehsw',
#   'ROfdad44e_o',
#   'JJVtDDx9l4E',
#   'r7Q0YEBPfrY'],
#  7781: ['6cGMmw7qMq0',
#   'xVhsS3aTrO0',
#   '6a-9UFfebqE',
#   'MWKAms0yTcs',
#   'TLVrBCyx7jk',
#   'vJ-N1LQISkU',
#   '_M6K9re14L0',
#   'XYwT-Br13ws',
#   'OxrfdrEO1m4'],
#  8082: ['4rl1XuvzlAI',
#   '33ZvNqG-c8s',
#   'VZW2MikUDB0',
#   'IoGSvc3Co_c',
#   'qm7M90oZWKc',
#   '_6v84m__pqg',
#   'EsZo8BCBHKs',
#   'jY60xIt0Zoo',
#   'sVXNQzU9l6s',
#   'eBPX7QUoamM',
#   '__ERnDB4-8w',
#   'HYrZ3BSzwPA',
#   'uvY2Kk23tSE'],
#  5951: ['_wI8dVrRrkA',
#   'O5RW8JiZU6o',
#   '_x5MQJB3CVo',
#   'E7hkkUtekJE',
#   'pSuV2t12kho',
#   'Tb23W8lVECI',
#   'OkRzuYu1Lz8'],
#  6986: ['aRiUBnFy3X4',
#   'IOzQ0qtjOKw',
#   'VcZUN7IwdGs',
#   'W9pf-dAhTOg',
#   'K7B6ScZcg7Y',
#   'b6kCQtsdKoM',
#   'Pfe9KVn6SYI',
#   'TSK_ljD2_qw',
#   'wDjf4xLfMuQ',
#   '676bnHNzKbo'],
#  3402: ['JaDbUIPaaTA',
#   '3w4Nnldmxh8',
#   'Y0JQgEOhtcc',
#   'C47TFhdchSQ',
#   'yzI0Hb1yb3c',
#   'H5xfPcWjWqs',
#   'Ldtdemqc2iQ',
#   'B9CtW7mthqs',
#   '2mEQgZfRvLY',
#   'QPsuhw-mfgk'],
#  7153: ['xE4p4abHA3Y',
#   'RQeTF-UaW-U',
#   'ztfrHPnau6Q',
#   'GAvqCJQ_Ll8',
#   'ZgthVD622bs',
#   'gOBqOgNbOi4',
#   'J8om9xy_x6g',
#   'OsL4qdHrMoY'],
#  6853: ['J2pgpbL_ers',
#   'eVTzBJsYOmI',
#   '6BOtES7SPng',
#   'SNZTXHTirUs',
#   '9KF5CFttbXY',
#   'ceWJ2Wj8lho',
#   'YTX-l7t082s',
#   'aGnUVXYtR6I',
#   'sm3l-15gypo',
#   'jEySfGnvouA',
#   'pLYgq8wEgxA',
#   '6Icc2rP_LSM',
#   'KaX7UgpAN78',
#   'svcxrlMmFJI',
#   '4R3u0KS1nuY',
#   'qRajKN-kRlA',
#   'DZbUWVsy-ao',
#   'XoszaRDsQgg',
#   'TAA1ykpfXxM'],
#  3971: ['lf7dAteKDcQ',
#   'Yk2tvenC01I',
#   '6KhT2Pi6wWc',
#   '3LuFN59vk-I',
#   'yMzZ3VCmF78'],
#  6258: ['SZGLBuw-bKc',
#   'NXuY2RcLZp8',
#   '3s0xV6rEgYo',
#   'V3utBJ692kY',
#   '0TVHz9WoY3s',
#   '5mOqpf0g1fo',
#   'qP-ZXs7hJzM',
#   'pOpcjmIH0Ps'],
#  3546: ['PprqSWj1MSQ',
#   'hdBc7_ZxqOo',
#   'AmmYELCH4cc',
#   'qCNnnK-UK2I',
#   'khz3CC6WiPE',
#   'tWzn0NX-k6Q',
#   'd08I8TEHGn0',
#   'GZaHl1sGHRI',
#   'uB_trWSFJGc'],
#  3114: ['6Lw_k-vx40Y',
#   'r3NmIaz58cw',
#   'qJHiHt3XAOw',
#   'CQsY9T6v3Kg',
#   '9kZnA9_fQNA',
#   'DpPrMsRoK1U',
#   'bxQpVYMLN28',
#   'wok6s8VB9ww',
#   'dT1CjvwQ3sY',
#   'v-BnaOnOcMw',
#   'g2JCZFcC65E',
#   '0JD2o5peAFg',
#   '5IeW03IROsw'],
#  3343: ['KWClCh42skk',
#   'RGXeEherc-k',
#   'XWRcF3lV7ZE',
#   '0YOULbqoS1c',
#   '4oAe1C7j9cg',
#   'DEGK2QmM07w',
#   'dK2yZ-v0vPc'],
#  7906: ['AcQRGXres1g',
#   'E7aaSyrolzs',
#   'PwC0sDWDA98',
#   'nCOr2Pe6Q0E',
#   'KyRPLscVqiM',
#   'HDRnq2VXVxg',
#   'T9Ich0Ag_Gg',
#   'WBYhYHrXJK0',
#   'JzaniemO0_s',
#   'SurIEgQ3Ve0'],
#  6514: ['I-O3Io9lg_Q',
#   'uMTXwMFBYUE',
#   'yo2craw7NII',
#   '-_uuPk2chGA',
#   'NBvZ45YLqhg',
#   'yQCSNY5zUnE'],
#  7745: ['Ir1qQ8T-qcI',
#   'ulyZUskvzME',
#   'ztCUsxw_NqA',
#   '3d8x5ms-cf8',
#   '5Hw6Y5N0ECk',
#   'CjIdYANBNFo',
#   'VrH1bVc82UI',
#   '5CCeG1vB0as',
#   '7G04LB5EjiA',
#   'Uoc2PBd2Tfw',
#   'cWkmfr2HFHo'],
#  4493: ['7-ZMSdsLHuw',
#   'fbA8Z5WILk4',
#   'SPnkN-bT_zg',
#   '8FgPbUqwXB4',
#   'lLcs410OHPo',
#   'SWlQM0z3P0U',
#   '58bMKWojouk',
#   'zX5EinvDxM0',
#   'EHIGs4flIWg',
#   'sVCY55I2aLM',
#   'leHirBqXBLw'],
#  4700: ['QJvgwX5HVBc',
#   'SRUBgKK1JaY',
#   'LH6NqJUnjHQ',
#   'iiwv9YFShzE',
#   'b2IR-SYmJco',
#   '_OnH-TWv8ho',
#   'd3laj4NphgU',
#   'bG9ZzXH2GOM'],
#  5912: ['-FAm5pW5gUU',
#   'fx7GUuY_Z4E',
#   'cBkWFMpiXg4',
#   'QwkiHS7Xqec',
#   '4yOmxZ79PZ0',
#   'CvwV9DkmaG4',
#   '0SRb1pxlLKY',
#   'uHRLnUvhX38',
#   'DkgaS_M3y6k',
#   'ecYaTslDYxQ',
#   'BrKuB5lf6wg'],
#  2800: ['1i9QK51L1FM',
#   'r-ns2eyPkYY',
#   'Bla_hlVj1GU',
#   'h33H8N3tKX4',
#   'lio6n1T0hUs',
#   'QHZ0ZVML0xc',
#   'qgoQEEozHHU',
#   'jKmd-d4eFKY',
#   'GAcM9xamY3Y',
#   'F-ng_oUMjJs',
#   'Uxbzlkcp5X8',
#   'mZCmm6hEpSQ',
#   'RdnHgjvHhF0',
#   'ZliGyAfGZgg',
#   'BBs_MAXakU0'],
#  3934: ['yw-iIpvBMtA',
#   'GC-221kaF1Q',
#   '9J0zs33kGBM',
#   'aoyRH5KWKZc',
#   'k-Oa3gMlj8M',
#   'wwgaFbvp-eA',
#   'paquGtHTSDk',
#   'hmegNq2h_eo',
#   'CcC0e9Ztfyg',
#   'lw5jNrbm8N4',
#   'DHq7TLr7BRE',
#   'OaW2f0QFuMk'],
#  2752: ['hgtLjAFiHH0', 'T42MbZf2sMQ', 'Cl5hT3X1Zwc', 'xnSjCY8KNeo'],
#  4655: ['TxVm7_U5ZWs',
#   'STXP9uQThwA',
#   'rkMyRUD2szI',
#   'eEykeA8Xzpw',
#   'voaUJetpan8',
#   '2WViJPkFtiw'],
#  7243: ['2HOxbcmqPOY',
#   '2oW6DRvSgYk',
#   'gSw771-4Uuk',
#   'c6fwRdvCJOE',
#   'F0G2XGwTH4Y',
#   'DeMOZZ7zyfI',
#   'DGEhBUj7N2I',
#   'vqhlpsjVTdo'],
#  6114: ['iv_5YIRsl88',
#   '3LXz6eDAxAg',
#   '9Rranu5dc7c',
#   '-PNH0qzC2jg',
#   'xUTjersXSkY',
#   'hEPHeq6a1PU',
#   '-Z9j8fGGefA',
#   'EleVCCmXYgE'],
#  3768: ['m84ZiK_PzMg',
#   'ziZSBuh1XLM',
#   'BrAXTV6TaRg',
#   'TXHwgtFVdQY',
#   'WheF-CD1dHY',
#   'bE3qElRbN6M',
#   'gC99Jf_BJ1w',
#   '8ZMX8mQc_jM',
#   'tgqIj_CdgYQ',
#   'Dd3hkLLWus8',
#   '9gYWqXIpWdE',
#   'znfZGBYDzgI',
#   'jFDfqZXjN7E',
#   'bSoLj_wKIN4',
#   '6g44nwt_-Cc'],
#  3544: ['MDHn0I5w354',
#   'cj43eTRONQQ',
#   'TRKG60GCjNU',
#   'Oo5xt9wE4N8',
#   'lfnvMRsS2os',
#   'BNMfDvZFaYA',
#   'uxT_FKLwSW8',
#   'VF0AJK0aw6A'],
#  2660: ['FhSp3w-BgPA',
#   'UEEkUY39tAQ',
#   'JhjAk47S-qY',
#   'YLn-_uU4wX4',
#   'j2634MqoHjM',
#   'ZQA4vWXQ8vs',
#   '1tr40c_-Lgs',
#   'DL6ER9VEpN0'],
#  6631: ['OwUa8uG0p2w',
#   '8weYz_9uYko',
#   'M7VBBXLj18Q',
#   'Z6nNSX1vFfw',
#   'ui_LkpHH-og',
#   '1kQzk95aiWI',
#   'G9hXIDZOh3Q',
#   'jywy9vi3wrk',
#   'lh33MiN_hsQ'],
#  4639: ['03eAVnd5qi0',
#   '4bOPBUgbsvU',
#   'a1ETHqlkumk',
#   'AbNlLWo1h8U',
#   'E291233d_sE',
#   'he27b0Wh2Vg',
#   'ZdP8WH24HXM',
#   'NMHfqORJCYc',
#   'FcYa7G6LzHg',
#   'AdGHYhbvIK0',
#   'gV1XmIlzxEo',
#   'AJqIMWagqHg'],
#  5844: ['58-ihyD8l-8',
#   'sUC6VLOa-Ho',
#   'OqY7tcpLILo',
#   'pDHXI2FB5dE',
#   'mEx9etEjQXs',
#   '5pwRfBGarOM',
#   'ag5tkrRs3GI',
#   'hK0s1jrRr2A',
#   'NaVrEzvBH9Y',
#   'twKecIOwTy8',
#   'C-F7YSf8CfI'],
#  7541: ['sBwYE6B9XdE',
#   'HLVjx2vSqSs',
#   'V-L_GJpBcOY',
#   '9f8lVIc8jhs',
#   'H4wLn9VoPaI',
#   '9s-hSzpC88s',
#   'ayQ-b2uIZ8k',
#   'GEz5jJO_IY4',
#   'P9DVQQQSA6I'],
#  6971: ['1feBqn-MMls',
#   'tJAxB_jnXbo',
#   'm4i-8izgJz4',
#   'SeW1bvhojJk',
#   '0ISV_kChtwU',
#   'XU34kZnnrpI',
#   'VtD6vuwb8cw',
#   'cKjAT6QcAOc',
#   'ma4AmxwcFH0',
#   'qIrXQSqQjak',
#   'ofgM_U5tyB4'],
#  5096: ['K0o3V6GAMO8',
#   'hk1uBcW7Gj8',
#   'rEDMFXVHqyw',
#   '1_M0g_2MpmY',
#   'qiPIAP7Kntc',
#   '8f6dpsFqG6c',
#   'he51Sqw-5G0',
#   'u31Zx8fXfac',
#   'Q_g9NMz0zCc',
#   '5-pHpEcFt4g',
#   '34px6589ARE',
#   'UQd3JG3IFeI',
#   'Tm-WBDXA1mw',
#   'IBo7RJn-Xh4'],
#  7901: ['hlXQOCRzs-k',
#   'uJqOk-4qmOA',
#   'dUkVvEwe1Uc',
#   'IbwgB2-9ZMk',
#   'GjnvYg18uUA',
#   'KRWa0U7HBJ0',
#   'wYTztdhdGhU',
#   'Aw0a9wxkj4o',
#   'Rw4XO-kc6N8',
#   'UT7vSUnxF2U',
#   'VuHv1sVS0uY',
#   '_yTrLjoQHH4'],
#  6101: ['BRfHK7vknPU',
#   'qCp-1kREF7M',
#   'L4ddZmvXq2E',
#   'bIA2fXGDIoo',
#   'Xxw2B4r7bdE'],
#  3287: ['Rlb4WApQKw0',
#   'reqBk4eOS6k',
#   '_ARvkunNxvA',
#   'CMavXMT-yQE',
#   'yZPnxf2Ilp4',
#   'lwYvgBs5rKE',
#   'S_DjqkPvE6U',
#   'gMqy3JCpI14',
#   'svjfDTfgXPQ',
#   'jjT6qwB196s',
#   'uUyEdVhm8Cg',
#   'SjHdO-7Bk18',
#   'uDaFDPvf044',
#   'UhHv0AJ5jfA'],
#  7431: ['xs0c3k1vJ3c',
#   'TQUcSrBKxpA',
#   'd7BK1cFiw1o',
#   'Qqkioku_6O8',
#   'jwLb-wxri-o',
#   'XN1auh5eWFQ'],
#  3476: ['qhSOFpdSsNM', 'nGDSDCgTcQo', 'zO6cAycXAXU'],
#  3245: ['h5sI957TlLg',
#   'DKglgug_ZUo',
#   '-ov063K01Lc',
#   '6kOxI6U3VUs',
#   'KK9lEYz13pg',
#   '6PRLcTQeP7o',
#   'XLPmTyKZ9qw',
#   '3HumUjOwKPA',
#   'c6nZjy4DnO8',
#   '3IzGQDzT5nI',
#   'yBYcy4Mzhl8',
#   'HPXm3ySohvw',
#   'ZS2waZDdtGQ',
#   '6i__QCL524A',
#   'BRYiZuz1dmk',
#   'lzbagAJaD2o'],
#  5273: ['mEKfN_HAkF4',
#   'gcGTLz8wZuI',
#   '3pUaF-uUhLM',
#   'ygZiGRsGsQs',
#   'x3rSyDLFIxg',
#   'ppNy0nwZPCs',
#   'HuRht3BBvy0',
#   'qDHIe8pJCEc',
#   'nPmvkPeW4pQ',
#   'CEQvaHX4xsw',
#   'pWzV_n9Hy7U',
#   'pj2uUu2jGiI',
#   'aS_1FrzQ0Ls',
#   'csRmVCzqqgE'],
#  3592: ['4Pl4PqdULYo',
#   'qwGQx28WdoA',
#   '9PN6ApB61Jw',
#   'Ac-b-QEwOnw',
#   '4hwgKIWRgo4',
#   'J5I1cUQK_tQ',
#   '9shpEL5a7mQ'],
#  5940: ['bHheFP2e5u4',
#   'eJQdFjPg-Z0',
#   'JWX0S3KhCzM',
#   '5G8qf8jncbM',
#   'sjRdj8AzEys',
#   'MsQfGGLRBi0',
#   'eW3Ov08R2F8',
#   'BI_Jy_PZQB8',
#   '6VfpyxT0Zws',
#   '_97cgPq6zxE',
#   'warmkzMzQ9Y',
#   '7j8Ja-ffVuc',
#   'tp2sZ4fNY5I'],
#  6989: ['iegjfQmxanw',
#   'rPjeUyFXCco',
#   'PHy5lx6EmXw',
#   'cB9yBoVq574',
#   'ayK2-qLVu9c',
#   'jptPbVZ4_iU',
#   'VhTfZWOXP5k',
#   'xwc5F-mG9fA',
#   'fUWHFQ5JeGE',
#   '4eBLFUuxzYA',
#   'DWNaSX0mLJ0',
#   'cFbccVlA-00',
#   'zMHTWa_bUek'],
#  4540: ['hWkmhAu2lfk',
#   '7RQNS8FJF2U',
#   'BAQ4u0wPIkw',
#   '85MUDaT0dfM',
#   '6pge6w5GNEQ',
#   'qItglF4dmNk',
#   '7QJTOK5aD5g',
#   'gfagFkBnQFQ',
#   'LY-NwEg5gig'],
#  5990: ['12sqwvM20Z0',
#   'nBKR71Kxk84',
#   '2loGaDzIHxE',
#   'aPLM7z0L4vU',
#   'avy7gBo2OHs',
#   '98dVCZG_bP8',
#   'bYanZqJ9zg0',
#   'b6-IggitFEo',
#   'ees02s2OttY',
#   'FurQUZDo0iU'],
#  6727: ['-SsoXjvokBo',
#   'S574RO74nM8',
#   'LV6vU3MmBHQ',
#   'pQXiIQSQXfA',
#   'Na-Q_zTp9hY',
#   'HXyeJ0QXdHA',
#   '6smFDaA6Gx8',
#   '1G65Gb05ueA',
#   'Tan4sfPFamc',
#   'xz1h34fLWtQ',
#   'Xv5k2qaLfcA',
#   'Qjtqd9EjvaA'],
#  6269: ['b5wUAcWC5Gw',
#   '2maPT9um29E',
#   'OW3aNZc020E',
#   'T6Qljux1z-U',
#   'UZNbYQf2ncw',
#   'DS8ZLqSyug4',
#   'Zo40dC64VQg',
#   'y9aaTz4BBVA',
#   '_wZahI2_ay0',
#   'oSMzMK_ISis',
#   '_9WOMw2GLQQ',
#   'hmcgIgZzycM',
#   'OfD4tYUHs_c',
#   'VbVczYEJUAc'],
#  6765: ['WDKDR7edfm0',
#   'h-Ko1qZcoKI',
#   '4P1MP5_P8KQ',
#   'hoiTd2oIEBQ',
#   'kP3TNNCWE7A',
#   'ppcjdQ8AhA4',
#   'OcNNwBAiwqY',
#   'WX8umzs0h1w',
#   'lee-pXfZ7Nk',
#   'xJyhYiXbYDo',
#   'ctPI3N95GcM',
#   'wMTSHI6T90o',
#   '-LOTXKS8Nqw',
#   'I8IU0zxHze0',
#   't_UWIrFFaxo',
#   'Zs-MFfbGKE4',
#   'kdfewPDzL0k'],
#  7158: ['U3v8UUR3B_I',
#   'dvHI50bxRCI',
#   'syZ7lAeB9kY',
#   'HPWnAat5c28',
#   'vdgTfEutPbU',
#   'Leqoz5MJHc4',
#   'tKgPySXnTnM',
#   'DaIft8T7G18',
#   'qC2JtGET2Ak',
#   '6p9KwxGYK4E',
#   'e9tRHXgUnNw',
#   'ND50RWTOwpo',
#   'h9HpDQN6Cqc',
#   'vxv_9ogVJWs',
#   'jzWSpe4rphE',
#   'UVC44io9LeQ',
#   'QZ5dMMqsWGg',
#   'lwTZkvs5gCQ',
#   'qrD9ScGpMYQ'],
#  2785: ['f9SAi-OMWcs',
#   'sIzFN0QZX9E',
#   'sZSI7sxDUkU',
#   'HoAusMJpZWc',
#   's07hpERHKdw',
#   'XoXZzvywQrU',
#   'K481wPxidiU',
#   'xREk9rAswh4',
#   'IvFOZvb0qEw',
#   'MiDZRYQkRNI',
#   'achHmqKZyOo',
#   'EZ2Wgfiz2D0',
#   'cMq-VwKPhzs',
#   'pGk4G3BjfgA'],
#  8230: ['coS1_VIu2d4',
#   'YgS2p07G6NQ',
#   'cQuQBt_9a9E',
#   'WNsAHUivZyc',
#   'YNohJSlQ6q0',
#   'ci28H1njf58',
#   'r74vy2Aqgvw',
#   'KYO95hip76g',
#   'lPlZcqKqYy0'],
#  8118: ['B4n8OG_qU3U',
#   'HLiVz8tF18U',
#   '80Bp3Q597vk',
#   'kb89XzGyqeo',
#   'P3xS-eIzuhk',
#   'kj5fwlyXWtg',
#   'cq8MGY8wurI',
#   'iWBSevW7P0k'],
#  3722: ['DUyM_7cogdc',
#   'AmCtyh2PhP8',
#   'Cgys_tE7BJc',
#   'dWJzQR8y9Sg',
#   'zorjME7QcL4',
#   'OsN_4Forahg',
#   'O2Ph_cA3Jyg',
#   'tnRiovEu5iM'],
#  6059: ['OTx7aPNwPh0',
#   'NWvAKxQeUlY',
#   'AxnDoQOmlLM',
#   '3CPgbB4DbiQ',
#   'dMZjWT7MAJw',
#   'mpprUSR-L7Y',
#   'U08RA6_bQXc',
#   'YFQMwQZHZLY',
#   'P46pjiTejrE',
#   'FkFbkGZOjsI'],
#  4300: ['iMnJPYawm90',
#   'i2bZe5tecR4',
#   'cbpUyoxGG7g',
#   '_NGzIL20bAI',
#   'HVfoSFLABY4',
#   'fMdeo_UO8xM',
#   '_DvgvQxyfZY',
#   'YWFjzkGBNUI',
#   'ilkJrocGuhQ'],
#  5100: ['9CdhRn9-5o0',
#   'LczzB9iTRR0',
#   'iaOcZKvUNn0',
#   'QKfkMomuWlA',
#   '-obtrT02jMc',
#   '4l1NqcJbP88',
#   'MZmqFCynaPA',
#   'hQ4vTV0Y2GY',
#   'StFKEKfqu7A',
#   'BekCnaLx-70'],
#  6176: ['QWHX6Ow1iYA',
#   'KaEU65tIhwk',
#   'i1Nfup0iksU',
#   'VCTfKhvmRUY',
#   'LiG2y8FrHbE',
#   'kjKevb3XZZE',
#   'q8YJOwgikVE',
#   'fWVwoE_UBO8'],
#  2657: ['9gawvGcUlwg',
#   'uLdBrr6E0eI',
#   'uJfpdm94AJ8',
#   '4UHDhSVa028',
#   'Hm_4-x49z6w',
#   'uZfsxVptjhc',
#   'pA6p7h_44Kg',
#   'Zhi5j0DWAG8',
#   'EYIqiPfcaRU',
#   '70CetYf5Xrw',
#   'FsM8qJ-qiis'],
#  3012: ['Ib0_vLxIGQY',
#   'vf6z_6oKriE',
#   'i6F2EYRg3Bc',
#   'DCzntMNnyeY',
#   '_QRm475V7-c',
#   'xHWDvHOVD18',
#   'PkVfYoADhzw',
#   'J33bvuSnoa0',
#   'bhU7yJ0-1VU',
#   'ksDq5QLHlAQ',
#   'wd0tVq_VUGg',
#   'N5G9kYm88Gg',
#   'nFkeazG_xXc',
#   'kuP0TRWP3iE'],
#  6589: ['Y4tqlVarh2Y',
#   'dEwYlX9iSNs',
#   'j3DKZCFFoks',
#   '6pCOOySVmFQ',
#   'scQJzpTvr4U',
#   'yd8xVI8-Y3k',
#   'fWWKH7SbIps',
#   'VMBeCvyVGmY',
#   '3eM1n2Kt4K8',
#   'pGMXw57ouDQ'],
#  6383: ['-qhujAtyVDw',
#   'OeS1_h1doQg',
#   'ocKSFh8xs5k',
#   'uMwckdRc3CU',
#   'CO7NEvJU_CI',
#   'vLpPPR5_Ld8',
#   '01UsMV8wZ9I',
#   'o3FtVAZZ3qA',
#   'md44z9Xlrdo',
#   'PEfAvXQfMrU'],
#  4117: ['1arLGRmUNag',
#   'M7zUcqIvzE4',
#   'oyMOB4O7v9I',
#   'h_270bJtmBQ',
#   'j1jXNxXnMcM',
#   '1wSYuuV3EWs',
#   'K6No_Pgd8Lk',
#   '-EEig6Prig8',
#   'I4TsRknOA98',
#   'ZVELf0srNq8',
#   'mF41dsgtucc',
#   'AEl0ypPR2bM'],
#  7894: ['hUiitZ_kzoc',
#   '_l6mqq6V-K4',
#   '3VdDJg-L3CQ',
#   'lpGuGdWdd_k',
#   'DVBNBn8oBDw',
#   'Qbp7rXJ4-tE',
#   's8o73Hu03FQ',
#   'DU6wzQceyLs',
#   '2ItYaAbUiFA',
#   'Jblx63Pq3HA',
#   'aTR4irvRM34'],
#  6352: ['494p0Tfm5mg',
#   '_R5-2CEXDIg',
#   'lms4iDekHd0',
#   'E56VF1EqAJo',
#   '8KNCzC3BlJw',
#   'fwDBP3z6iIc',
#   'M_Vf5CtGy2c',
#   'MUrDBE3Xfl4',
#   'ca8_bwW7kvQ'],
#  5210: ['e2TczCv3DSA',
#   'F7Gxb1pJysE',
#   'uG7Pl0DspcQ',
#   'e8yT2KIJcxU',
#   'gvzdKWy0z8E',
#   'sL2ld3rUE38',
#   'xY-_uRHWOFw',
#   'OdHbNTp5gD0',
#   'QwXr5hfNa-o'],
#  2809: ['MZ4WjRhwqYE',
#   '4oeHvrl24m4',
#   'PZZKgSdfpMM',
#   'lrxpVFBNaTw',
#   '7Qs8_qO41iI',
#   '8lYHaK6aDEc',
#   'ACwhEaNtQNQ',
#   'eYr7-JXVfe8',
#   'hpo9Cm0XVJ8'],
#  6129: ['PnhAIjrxfIo',
#   '4DCoH_MDQQc',
#   'PLkDxqeImwk',
#   '1EoyGBFPRh4',
#   'v3DHBlGg4go',
#   'xMSk9KBr7d4',
#   '9xw36IbVcf8',
#   'tJVslkz1E1o',
#   'kABnwoY-w2A',
#   'n1z0Jc9tVIg',
#   'Xiox0MYJA6c'],
#  6805: ['3uajrMz1ZQU',
#   'm5klH--4RJk',
#   '4NJpbQbjQF8',
#   'GrtL21huwTw',
#   'CCrytCH4Gq4',
#   'rm0kGyfHvjA',
#   'l4Bjd8ynOCg',
#   'dXlTANO-VOM',
#   '1WTlePHe8o4',
#   'r7NcvOQeWrY'],
#  4064: ['4CnWDRZLQgk',
#   '6ja8rLaFjBA',
#   'p84tTbNxb60',
#   '2Qd8TJaahSI',
#   'xPmwpmknJnc',
#   'ztQ2MvrqSRg'],
#  5443: ['OPMPc9rqjbw',
#   'JZLumJprzZ4',
#   'b0JROfSVmbk',
#   '4a8drlqNtdg',
#   'lRFP1Z0PInY',
#   'GKe2p8dicPk',
#   'YRXFtve50ZQ',
#   'XuluTXFzRpM',
#   'kfoQJdKXIS8',
#   'VNG3Wx_Pm_0'],
#  6424: ['MxbiN5R5-gA',
#   'wod6zbBhXfs',
#   '1JscPajT2Ho',
#   'TTLBPCNA4MA',
#   'bG8XufgQq3Y'],
#  2599: ['FauuUHuvTSM',
#   'IsWFkkWEoek',
#   'T_OEukNtUSg',
#   'c9oyhUyBBlk',
#   'XaV5Y6RZtDQ',
#   'BolC2w1XbCI',
#   'x6DEqUrLUVY',
#   'Fj-y-ttDTB4',
#   'FeaomPua3QM',
#   'ypnpRK26ceI',
#   'mTyg2t6exv4',
#   'noo4jIfK9MQ'],
#  3654: ['xlPKzHac93c',
#   'SNg-C7c3x0I',
#   'ZIOhCHRlMYc',
#   'nt_0In-mc9k',
#   'NE6D8P8baEs',
#   'CIsqqO9xcJ4',
#   'HM21-frTGxY',
#   'ROfUPKSijtE',
#   '1kWxgZOX_Hk',
#   'VYiABh09imQ',
#   'pYZOnDXV25Q'],
#  6253: ['nzO6fxBrOyA',
#   'XcBqOwswO94',
#   'uzPdcZLrDiE',
#   'fC6YMWHgoEk',
#   'yxsZjdMAPjE'],
#  7635: ['lxH-fUR5rSg',
#   'g5X_We9gJd4',
#   'f6lKq1W_WoU',
#   'Y0-GQnmpdjY',
#   '28_uW7LA0I8',
#   'MMmPk2w6h7g',
#   'ZxuTVlPrfeM',
#   'KpuTb-Rr_io'],
#  6858: ['gHjIMGv58I8',
#   'xlkglQNftsM',
#   'bHCdLCg0qFI',
#   'mi-QTqnmUSw',
#   '8VwBgvIMUSg',
#   'aUSsVM7XPnI',
#   'MrlWOXrm4hY',
#   '6IkoTXavZuQ',
#   'qQ1gpskJ5Mo',
#   'DhrQ-CsD6Uk',
#   'TcPlZDuKhr0',
#   'CQQnhOsauIo',
#   'A3JToF7Q-hE',
#   '-FIGWQcmDM8'],
#  7087: ['rgN8LG-zCBQ',
#   'aErVvK-yfqU',
#   'VrpPfTEOdnQ',
#   'PO4VojWNG4c',
#   'h1z-1TyM3Vw',
#   '7VCmrhb2k34',
#   'p-vGqFvjKN0',
#   'M2t8sRb0hyk',
#   '19keBnh28Nk',
#   'KUq09jGTPiE'],
#  6098: ['z9EjEka6AQ4',
#   'PqkGuS6-g3I',
#   'Md2bSckySQg',
#   'e46TSbvVpqQ',
#   'rh5etEG5ZOQ',
#   'fhigyz12FWA',
#   'yrApshKPpuU',
#   'OhHFT8zgSPc',
#   'C9wRPgfKuVE',
#   'dPRONPBzoZE',
#   'VYrdg34YL6g'],
#  4763: ['cEFW0ATd1JY',
#   'l8utcq7niAU',
#   'RmvgAJVRr_4',
#   '9xOpnO090qY',
#   'c5Ndc8pnDsQ',
#   'Z76Ueg-fZsc',
#   'TdXNSP0BxCc',
#   '_SB_fwUZ-RM',
#   'ivQkqnPQGCg',
#   'FBVmOqboZmg',
#   'GWjHs35YaBY',
#   '_p-9vsU8hu8'],
#  3866: ['-6mfBNPRapQ',
#   'u2QmUk4cI8U',
#   'UsUauk0UGAU',
#   '4_zu-QJCEnk',
#   'MrDh0Ss81RA',
#   'J_XAe4KrmBk',
#   'QRiRFtCUd58',
#   '2ukAVjme8NI',
#   'GXf-wNysm7I',
#   'xSRlqZgELBo',
#   'plYNz1rxgNk',
#   '0vYZ8bj2fdU'],
#  5304: ['0yZxjIj5vFA', 'ldCbPSz_FbE', 'lk4CHvX0nmE', 'WS0FXApGxJY'],
#  3403: ['TICn3QBfNQA',
#   'BZYbcTt27-Q',
#   'I48flTM8Mho',
#   'IiCSK7mgjK8',
#   'LTxv1KOJQeA',
#   'jqNqL0_jEEQ',
#   'XdYMMCBoRuQ'],
#  2941: ['yrPm1f4lKGU',
#   '_ihhqxXJXBw',
#   'F854lL2P_5s',
#   'VlxCWmJZ90E',
#   '6mMpcTSvo9Y',
#   'sl1sgdaqxUQ',
#   'z2GFNc-X6mA',
#   '7WlIjHRb-e0'],
#  6103: ['sw_MPjZ56S0',
#   'JPFxxeSoBdA',
#   'U__NWxhxpBU',
#   'H5s-FTbY2nw',
#   'X7ncZHa4HXc',
#   'GSL9SsibCyI',
#   'PfmrqE9E9xg',
#   'TgC2iJ7oqo0',
#   'ux3C1xEIVeU',
#   'PIyx2-qsxeQ',
#   '2zw8Mid5YRQ',
#   'H5o9E8kIuj8',
#   'aWk3IhN2Ets'],
#  7477: ['cf8cZJrzoPg',
#   'QmFvbnkB_O0',
#   '6iy9OSv4LdU',
#   'bqBdYqpGm1c',
#   'ZfgiqrLXh2Y',
#   'H1U6LlkTIf8',
#   'sNhKqaBLykw',
#   'W--Ilu2gXbQ',
#   '-suIWqYHvIQ'],
#  2946: ['IBJ_XcyhcAU',
#   'hkdmjRaQ0Uk',
#   'RvX80NandV0',
#   'h3UsdEn1Lq4',
#   'CUSjz0VuQi8',
#   'XJIjLQYpBr0'],
#  3183: ['96qAzL6MOSA',
#   'Ght5GNx3XN8',
#   'zv4HtBaKKXs',
#   'cL3ELruSDcM',
#   '9XwkdjWZRqI',
#   'CtNbjRSAC3E',
#   'Pt97nD3PuYY'],
#  5051: ['Bq7GNcRk1n0',
#   'kvdY7XTSVG0',
#   'Grrx9Y5NNRM',
#   'pLYxtSTSfRk',
#   'lr8CRVDXxhM',
#   'lt-Wj02NrFQ',
#   '4B4tiFnj9zg',
#   'h63c-jASShg',
#   'kj--SUAqV2M',
#   'I9eKrjdPjKo'],
#  3642: ['ymar2ASRJqo',
#   'T3Sexm7MqYs',
#   'w-H_XTobg3s',
#   'x3KPBXICrfI',
#   'JyV9AWPpZUU',
#   'nsgYRBKZFOY',
#   'lLoQWWiL59s',
#   'DXBaJ7ttFNU',
#   'gJyaMyBJXGY'],
#  4068: ['75rTxmsn6bM', 'blgvnsiaCkk', 'mZSrM-K-Dyc', 'tHk0veYWP8M'],
#  7831: ['hSpMKDujsIg', 'F64avsEa8CQ', 'Df-KZ7h8Q2E', 'ZjrwrxIO0MY'],
#  3810: ['u6ZddTZq7Ws',
#   'Jcntj1DFBgE',
#   'YxLAU0lmwAU',
#   'S4IC-i7d9js',
#   'GFra7nXZuHA',
#   '1CsGBKxLvN8'],
#  2787: ['CaZ5LhUbFng',
#   'gi1O4M4UpmQ',
#   'ptzDW7hwK4M',
#   'TNYH6QiffBg',
#   'ip52MV2nJMg',
#   'cpSSEzH-Q8U',
#   'zEbq2w18N2I'],
#  4802: ['tZl5EPxof2A',
#   '4wsVkPkLb7E',
#   'F_OtCj6P40Q',
#   'ReXyoe-sNQo',
#   'Qu0gtJmn4mM',
#   'q9LKDmjXRB0',
#   'JuNnOpW8NAM',
#   'rJJiU2UAVnM'],
#  3256: ['huOITc2QVP0',
#   'Ee4BfKAwVrM',
#   'aG9UP5mGf54',
#   'zaXpu1ycXzI',
#   '2R9K88ohHxA',
#   'bQmAxiY68AA',
#   'O5JwxFuEcuA',
#   '9hjL1WadyiI',
#   'S9pt6O1FgGk',
#   'IyLwHAESLyM',
#   'F1bCAp5abcM',
#   '2FDzXJG1-N0',
#   'B-KEgf-mY3s',
#   'pMxamOxhle8',
#   's-3ak1dAU_0'],
#  4084: ['dqWqKhh0C6g',
#   'orQlw4yqUr8',
#   'gI0YXkB6pNc',
#   'IKfS_JDI04w',
#   'yDbgIxqP4iI',
#   'UzWDgNtGFws',
#   'XTKWaoThpQI',
#   '32F0P0KDvtA',
#   'ZMzWB-8CutE',
#   'F5IoaOWIb2A',
#   'akElz5Xem_g',
#   'ROzja6nvHiw',
#   'n8PzR46bmNw',
#   'QVU8jUIAKTk'],
#  6322: ['KrLj6nc516A',
#   'Eq5hXskp408',
#   'jT7ID8MInBo',
#   '761AFcmMRzU',
#   'P66uhYUQbI0',
#   'BNhGY7ixVI8',
#   'zcRrgKLEpdE',
#   'nn38KMNGpvI',
#   'svSAnEepNes',
#   'iknnO2iOXm4',
#   'YXWCE-LVnMs'],
#  4205: ['3HGOPXisbGI',
#   'd7qAogQKVk4',
#   'Li2UPg6l_vQ',
#   'f0HGsgQCRYA',
#   'gVrKmma9W-Y',
#   'uq8JGzZ9ql4',
#   'DN0GYoxt_5s',
#   'tOMaRkMMWXM',
#   'Sd42fNviqHY',
#   'aHaN1b0OHr0',
#   'g5_nCFV7hXA',
#   'Ds8bw99C6AE'],
#  7002: ['eSapZLIN0PI',
#   'yHsCfF0vkh0',
#   'IjE3HTQzkQI',
#   'rjsXnwU7yeY',
#   'DcVDb3JfsdM',
# ...
#   'mxwZHc66fuo',
#   'GdKGuWshYH8',
#   'LC2kHh5N-7g',
#   '9l7Yt7R5TQw'],
#  4001: ['FpIiII6vmtg',
#   'SD2x-qJQ3w8',
#   'twbAfWn8oJc',
#   '3_G3cmiL8Xo',
#   'szDqrBibKZU'],
#  5127: ['12zB4SDm740',
#   '_rovWSPJad0',
#   'fZYZeHUc3Mo',
#   'AqN9ijsyL6s',
#   '7EeXgUb48h4',
#   'cUcCc83eKvk',
#   'BBRr1xK4W1c',
#   '4zhRgNmpFT0',
#   '7qh5vJqUa6A',
#   'EvDaGm0MJXQ',
#   'YpcC-P4Z4s8',
#   '0H1USDSUH9M',
#   'XQvq4Ml5x9A',
#   '0m-Kdrbk2hs',
#   'pMBMvRdRB3o'],
#  7963: ['chQ5ozQf6p0',
#   '4_dWQ34YNU4',
#   'DNxcyDlRns4',
#   'dyoeJOYQiws',
#   'yLcxzl1nADM',
#   'zehRo0aKBF0',
#   'isMCuw2kbVs',
#   'aB8hs9rwuEc',
#   'tTl7CTHm6Xw',
#   'aK_9qWuGEk4',
#   'KnD7o2NiiLM',
#   'ZxxWqmJqnWA',
#   'K9ReuCvBf9M',
#   'upNX4VYq_F0',
#   'ah3evsQZxN0',
#   'C2HgesvlzFg'],
#  7855: ['MDurWpj_1rY',
#   'hi-MjlvDL4I',
#   'SaBP1UvfHMo',
#   '21JSImF2ZRw',
#   'Je0vCsQ8KYs',
#   'SYq3S2aLIjE',
#   '3SO3rYdjHaE',
#   'nYESqSQc8X0',
#   'BGMJQleTO2I',
#   'RuRwvf6UW0U'],
#  5838: ['MDIVxf8ffQ4',
#   '292JDuxTeK0',
#   'M39YPfzbLHw',
#   '1zHsUeFx45M',
#   'ivUODL-PmwQ'],
#  2893: ['nc-xyxO1veA',
#   '6e7bLRUvntY',
#   'xgre9HFF6O0',
#   '5UFVcCjPLLU',
#   'blpa9kyifuE',
#   'dMDvySvE4ns',
#   'Aux9FmLWbZw',
#   'Yoz0J1lK25I',
#   'WjXNSqMS2wc',
#   'S09tX8nZGE0'],
#  7628: ['BD4HxAkh_8c',
#   'QfF1kY9dP7g',
#   'HRtktmN_HG8',
#   'Y7qB5O77vpY',
#   'Y1N4p0XRJIU',
#   'pDJnF5kFSwA',
#   'ChW3UoMLNDQ',
#   'M0n4qppBEE8',
#   'ZTkXqxM_8aA'],
#  7458: ['Z8yNrbyDIk8',
#   'Gye376R3PCQ',
#   'WiA4Fq8j-Eo',
#   'JGc2FDiRBnI',
#   '_hn1vw_QVRo',
#   'DMLJmW4JJeQ',
#   '9C0dEnFD5Mg'],
#  2910: ['7ALrWo2UkB0',
#   'dlBgKcZcyQc',
#   'W0ntIhn3la8',
#   'KIRIIdapMjs',
#   '1pEA3ZyXeyk',
#   'DbM_hCvtV1Q',
#   'hh4CmrzkQfc',
#   '6P_a4WDTUZk',
#   'XLf_wFfWmuY',
#   'XKbHoUsmdV4',
#   'QqJQUf9Cz8I'],
#  7766: ['6TCyj7spir8',
#   'IyZcQIUlXCU',
#   'UjtVajlrad8',
#   'BHWGwhmiQIw',
#   'Ot9hLrh--Oo',
#   'Q0hcI4toLLU',
#   'vUJpJT3gco4',
#   'b8VudLf4Am4',
#   'G1sjri4lCNo'],
#  8174: ['eEyWz1je63Q',
#   'q4gFUPrqk5o',
#   'kj_svYWfP2A',
#   'O44fZySo97E',
#   'x-2JdNkIkks',
#   'FQfxNyd9mRM',
#   'MS9MgymLtxQ',
#   'rphuGtFWPYo',
#   'qZirWG5s7gc',
#   'DXk7CaZs6Rw'],
#  7116: ['avRJ7ADgcmg',
#   '6VBk-1O_MG4',
#   'vtRIH3fnFrQ',
#   'LvZHIRKZqkw',
#   'zS6sNBPrDnk',
#   'Zeai0Mo3ijI',
#   'Pp2kIC5e11c',
#   'CRsjg6Da3ko',
#   '5bHToY-t5Tw'],
#  5037: ['BZ6JKTmX1lc',
#   '2IWR1krzhnQ',
#   'yVnJuec_ydY',
#   '8jLLVpqn2XI',
#   'i-ZJjdUbvSk',
#   'tgSJGGGd4no',
#   'tAAtl4awahw',
#   'Uh0Ekosbpvo',
#   'J62p6Vkuqek',
#   'yM6g87ES3HM',
#   'HJbjVvKguRI',
#   'DbotukzmsRY'],
#  2597: ['gMNYGB-b5x0',
#   'Sa1IXZhbhSM',
#   '5HUZ3Xk6zkU',
#   'XE7tQg-D3AQ',
#   '9zdyTBtqfJs',
#   'LzRfyp9MZZA'],
#  6596: ['4qSCaDi5Dvc',
#   'hcAqXIPTWFM',
#   'vuPTtzzSh64',
#   'x17JsVb4UnE',
#   'uuktQmM3GLA',
#   'I23vHiZuwbc',
#   '80yG4hUv05A',
#   'oXK1LoDsN0g'],
#  7492: ['NrXEpFmNWgo',
#   'tRsQevqGyI0',
#   'b5NJyf3Lu8U',
#   'a6PHHaHHN6Q',
#   'UCFAkD4EkYI',
#   'lFQgg1SSRoU'],
#  8049: ['9E3gtjrjfaY', 'IwxYw_DvRAA', 'aakdHd73d5A', 'Mip0W2K3su0'],
#  7587: ['DKhEv0eoD_w',
#   'bqvoPMzvHG8',
#   'qbheymn3szo',
#   'LIEu_SY1TCQ',
#   'i4X5uUYHsXg',
#   'VVtSQrU4TIw',
#   'r-2s2thDA54',
#   'yKgnv619qz4',
#   '-fmKCXW6mg4',
#   'kv4y49xnm2U'],
#  3683: ['UzIebKnuKbA',
#   'EMkCTmSmVoM',
#   '71ruibOfRKg',
#   'KGRDbhfwJ0M',
#   'dlVt1AZf6i8',
#   'O-pT_Elidj8',
#   'kipD3BdoQGY',
#   'Z2skxA51w40',
#   'Psmc1D2ddQo',
#   'LnS836TIknE',
#   'szZjEy4aCKg',
#   'OqygMm66E5w',
#   'h4MclJICzwg',
#   'PnuDm1wvVMQ',
#   'WkjkoNjuyMc',
#   'g_0Ojyhdti0',
#   'LvZ27srtT2w',
#   'qwMEjHLaP9E'],
#  4255: ['LFxu99MoOkI',
#   '7my10KlbHmI',
#   'HPnyezGPC_k',
#   'MfefeHrX0M0',
#   'VNiMQCoDiE8'],
#  5939: ['HyWmd6fOxfs',
#   'mbEgR34i1cQ',
#   's1wSChWE0Co',
#   'm-cDn8lEJ_U',
#   'SQTBb04qeP8',
#   '2mwBHr3v7I8',
#   'y4aC5wVe98E',
#   '49DQKP7zuZU',
#   'fbAlwSEChvM',
#   '8E7dr3cC0ug',
#   'zdsiP0PpSUc',
#   'dem01Fmy_d0',
#   'lW3HzsUSe7Q',
#   'DHvLGJ192Yc',
#   '4BqSF6ECF-I'],
#  8256: ['ZqfUGE-N5Ug',
#   '5psF6GBI38Y',
#   'rfwr8gMqXlk',
#   '3mjpHb9utEU',
#   'pBKSYUOm9y4',
#   'I9Pp6RAAGd4',
#   'AOxayirkPuU'],
#  4920: ['gMKR56Rlzek',
#   'r_W2nK994NQ',
#   'NvmpamjSTKo',
#   'lAT3z-kzj0M',
#   'VyM6oWeO_CA',
#   '7HP8rYDtCno',
#   'olWsYAnvmiM',
#   '0AdzWGl7SFQ',
#   'ECiiMfg0eeQ',
#   'u6PmxypqZ9I'],
#  5450: ['5JwmxVPfEgY',
#   'hccZ32c0nCw',
#   'weSTLTcUaCU',
#   'Gt6wq-DcFLo',
#   'NN6jkbkArGY',
#   'm97g8CsD1fc',
#   'ndThuqVumAk',
#   'sM9A8G-ZR5w'],
#  5708: ['ij28Me6pAD0',
#   'tjR7vGpMpwM',
#   '0tA8enZ7nds',
#   'KyMgA_hSJhI',
#   '7jAYwwAxI7U',
#   'ZudIYPcp9_M',
#   'UqECqn0QXss'],
#  7396: ['QwfNHTws_Y4',
#   'LqCCUvinpV4',
#   'd-mXopCZ428',
#   'LleNLl6sb6Q',
#   'uZob8kZRGac',
#   'f8Z3JfOvpgE',
#   'RcnrhIt-YPI',
#   'F4gllczZkPA',
#   'N-MwpvwKYl0',
#   'RM2TZEmQE08',
#   'XX8T0tNBRWA',
#   'lhEFwtVBjug',
#   '8iHkUzqr1Gc',
#   '5muX2kwFW-w',
#   'QCRlWvW9a54'],
#  3265: ['r7wI9GmgnzU',
#   'o9kjbq9lvEE',
#   'WvrfWDjZhQE',
#   'jZVZF46o_pc',
#   'e1Ud88svdVo',
#   'Xof4_A1mGos',
#   '53PeU1OdEpU',
#   'VDMAshmyRZc',
#   '3LYKl8C5nkI',
#   'd0DuZ_sq0as'],
#  4761: ['UTTY5hbWjMw',
#   'tjAZwoIY-MA',
#   'V86HKHI65nw',
#   'QuFeNhOX1I8',
#   'rmejj89F12M',
#   'r6Y2N0ISJqc',
#   'c0yd3uBFuP8',
#   'txuhhswEZKA',
#   'QL5QGMDlvCs',
#   'kk7gSSROR6w'],
#  7077: ['-FuvBITVbBo',
#   'lm2BlmIyHUI',
#   'zeInoCrXcM4',
#   'zXQZK-C2ijA',
#   '7Uv5jK_dRG8',
#   'VPNwxHhwbjg',
#   'gSyljo5l1UA',
#   'hKboviRLh70',
#   'BOcDeAEMXJc',
#   'uV3cVfKxtzA',
#   '3j-qyY-8TM4'],
#  3862: ['xKZpasHxwKw',
#   'al-fqE8cuq8',
#   '9QwPyFzC1kU',
#   'y-XWqpazxyg',
#   'y8qyiNCtMts',
#   'LTsocMXerHE',
#   'LWsZu2O7ZrE',
#   'P9JUn9eD2v8',
#   'A9PVZ79O4jQ',
#   'tjPcr-xq7Qk',
#   '4bfMPG9y6m4',
#   'ctFirZJcqIQ',
#   'ufWH_u2oQlQ',
#   '1z2AcMqINYo',
#   'rPgv7mOqHlA'],
#  4132: ['KiwJi1QBXQo',
#   'RQhPxymJfGI',
#   'bBX4p6NS4Xo',
#   'w1WCTWHKSbw',
#   'FWimezJuk0U',
#   'pI_LHHuSMyE',
#   'VwbZb-dcPI8',
#   'ZZpbDPJGFc4',
#   'fVs5BFEEVwg',
#   'jRNQjn-d1H4',
#   'fG__1gGNuvw'],
#  5934: ['ay4JPg9XjhY',
#   'rfMV8HALVdk',
#   'DrQAL5jWX9Q',
#   '7A9cgkjp8jA',
#   'uromXr5LY1A',
#   'QBR7nS2RmNY',
#   'lcSRGP-r6RM',
#   '3omtdukI_Ts',
#   'aUkGe2ultNc',
#   'jzyC-WWQJBU',
#   'drqkX0sNqXI',
#   'DJIBlSo7yOA'],
#  4450: ['FsBo4Uvfd3s',
#   'fvuGXojEh9A',
#   'GC8bEYaH8_g',
#   'KDN8yYQxA5o',
#   '6D9T2ZY8h5c',
#   'UCrJvyf0noA',
#   'VV52C2jzNWQ',
#   'OA5BtulS3VE',
#   'FVLtc0ryUS4'],
#  4549: ['_Hskis_0Evk',
#   '2D9kt4xlxnM',
#   'tIvAJ0-ZIjY',
#   'xDKDyl_IV0E',
#   'HspE-Al7_Y0',
#   'JUVAWmulY9o',
#   'UaMPZjbBRR4',
#   'x0UdJRO9-z8',
#   'SrYu85tiG-A',
#   'cTGS4ybOxuw',
#   'WD5osfSZhWc'],
#  3884: ['f3e1Xf_9NbI',
#   'f9dHH7ZP4T4',
#   's7PwF_IKkQo',
#   'k79dYbd_BM8',
#   'ZJpmD5hLeQo',
#   'hFVxkdHh9To',
#   'ZrB4XTS36mo',
#   '56ti5GLvznw',
#   'Ujvpr7HO3V4',
#   'felSQ8xjLJ8',
#   '_Qjf1k8z5tY',
#   'LQQNHR8S-xg',
#   'JNQeYC_bOtA',
#   '3VLK8dLcq9Q',
#   'ijQGGoh-BKQ'],
#  2576: ['P3iFDXKqYwk',
#   'WOAOcKIX3Tc',
#   'fVKUtkDc5qQ',
#   'lZO4ThvVlPQ',
#   'UqafbTmqLz8',
#   '8rHgUvTFPP8',
#   '5twLujqmtjE',
#   'rk3CR4EQ-h8',
#   'N1rgWOFKTGg',
#   'D5xJ5YcrjWU',
#   '7StWLQVW5xA'],
#  3679: ['2FTtUlAxKtQ',
#   '01_FQgjPS1Y',
#   'CSmhz7BEm-0',
#   'Jxrx1f-RHE4',
#   'GwPzdrLrbHw',
#   'SX8soVZo9AQ',
#   'MW6qR5b3L3E',
#   'ajB1j7xyQiQ',
#   'MRbbfY1_cjI'],
#  3828: ['-7k690aS7VI',
#   '0VtdyrwPkcY',
#   'o-gGcGLKd5s',
#   '8hf_TMFDpgQ',
#   'TkuopTXCHus',
#   'KSOOsbCYqJQ',
#   'G94_BcstNH0',
#   'DPiGe3jKupE'],
#  4127: ['LQ2E4iaekBM',
#   'c0PpRFzVHIc',
#   '55Pc0tq09sM',
#   '2Z34JYbWM48',
#   'dQYHtQ8Sg90',
#   'vfkIxhjel5c',
#   'hvA4xjF-2Vc',
#   'T3javgU2_E8'],
#  5326: ['lyVNneQWA00',
#   'KqU9x0tbbP4',
#   'UlPcXKrRgEQ',
#   'nd39bGWB-nY',
#   'xLoDH339x0Q',
#   'LgBJuDMl1SU',
#   '3-h6UODDWwU',
#   'huroR8LxWZ8',
#   '3QWvi8EC_DI'],
#  2509: ['BtijVBOXl_U',
#   'gTAN7zLWMRU',
#   'aAW1UxC_reo',
#   'aR_C7P5dFVg',
#   'mX7qNGoZTCg',
#   '07Qg26RQXxs',
#   '8BMhTFfgbdQ',
#   'Vpsw8MsCykg',
#   'FPaHff0rZp8',
#   'D8TFg0Y44Lg',
#   'NVteJ88V-E4',
#   'nV3mrVat45A'],
#  7976: ['S5fK2yx9Fuk', '4r2KmOJ1tLc', 'WWEeYmdmgLk', 'qTTvpTZKysU'],
#  7067: ['U9MznpaMQaM',
#   '8_oD_jDXhxU',
#   'PISQy8stdnE',
#   'UdYJtodnDsI',
#   'ayBLOCq3dMU',
#   'I_e1NTVHhPo'],
#  4189: ['cV7BAY7RGqY',
#   '7CYsV7s0ccs',
#   'bjD6BQ5egu0',
#   'NG922frdh0U',
#   'vBRPrK8Uu8M',
#   '7sX-5PYLq8k',
#   'mIQQskKEtts',
#   'depdwsjBbSk',
#   'f2X6Yj7kp6I',
#   'MxyiJiBkTwc',
#   'cFR6hzLW5Fk',
#   '1uQXnNHWRlQ'],
#  4690: ['9mIEuwhYsAs',
#   'sj147_8MuyA',
#   'giMiItpyEUA',
#   'WOZWlxOfF5k',
#   '-8b2PCPGX6s',
#   'wMqsK5YJn0M',
#   '2Mq5Yt2g8zc'],
#  5257: ['gRtEQTQUvRY',
#   'y1t59NAkaZ0',
#   'qzUzFDFtZlc',
#   'OixrZ5epfO4',
#   'XbHmNuJDiNU',
#   'ATjN55l6DCs'],
#  7875: ['_qksNTDX6ug',
#   'eKvE1ghQ1iw',
#   'mEs1cjU6v_8',
#   'DiqIyhj6hpU',
#   'W58c7pB2-F8',
#   'CSAuBEJdM6Y',
#   'M6e_snXdqMg',
#   'OVOlvOtWPy0'],
#  7632: ['E0xB5eupDMc',
#   '9KEvR8cwwvI',
#   'dTkIxJf2jtg',
#   'FKHEPrP7y7Y',
#   '6DBxEchMgMU',
#   'rZNlTUHrbc0',
#   'ZsFLgFMteQU',
#   'D8qpvE-bpOM',
#   '5b-OBphYXjo',
#   'vX6Iq75atFI'],
#  8357: ['yaxFJQwsEBs',
#   'qHpsvyxUtZE',
#   'rTYhm776FW8',
#   'JcYdihSBXxo',
#   'b7LJv3UsDF0',
#   'gIwZ2RLPb7g',
#   '3NiF2YM9Pn4',
#   '7pLumaJFnXg'],
#  7790: ['LRHr7nRXpKU',
#   'MTpZI0LjCig',
#   'v4yUqC_tPXI',
#   't9Q7LKN8WzE',
#   'kNPRNrIldGI',
#   '46Zz0L0ij1g',
#   'f80WwpNuaxg',
#   'ni2yruOeH9g',
#   'mSDl9Q1sbPE',
#   '_lsbJRmNcic',
#   'dkV1-WGD9h8',
#   'esd2sSkcoUs',
#   'M3V7gxYElDs',
#   'l8tEl04nd8Y'],
#  5054: ['_JJPPLWF0UM',
#   'JLBeqh8hlGo',
#   'Nw6yJrIXmcI',
#   'Lw4d3M2R7E0',
#   'NMmYowXd1go',
#   'YdNUl1a3no8',
#   '5msDmNkVOIc',
#   '44AhsIGqT3k',
#   'eZNHcRzFTfM'],
#  3623: ['EPjQq3u36cM',
#   'FY-j9FQ8_B0',
#   'jNkVDC20n_o',
#   'PU2rRId1PeE',
#   '5pWnB-i939E',
#   'RH50IgriyxQ',
#   'uFq0Ykzmy9c',
#   'a6Q8-BmU-hs',
#   'ALjMQMGK0Hk',
#   'c2bPBjKGYG4'],
#  2705: ['I9iFI8GbuLk',
#   'pKbgvMtZtDY',
#   'rTRNUrYIyuc',
#   '42Dc-vzV01s',
#   'rsY0zvauiBg',
#   'kmMaElHwwDM',
#   'gMS5VnSipPg',
#   'pQNrN8pS9PU',
#   '5X57t8Iz_bo',
#   'eo9BXoNpFi8',
#   'GsiPHDYxXJk',
#   'DkyKN_81yv0'],
#  5820: ['rS7IkpIJEWg',
#   'veEQzmvv31U',
#   'zUQ_qiNnqBM',
#   'OdnUWn8aMvg',
#   'yapHjTEgIMg',
#   '2FgPyBQQtlQ',
#   '7g6jQ5fqu_E',
#   'FObvsEnT2CE'],
#  2475: ['D5FwQl2T458',
#   'yj85qRI2D2o',
#   '8l9cF6pW7n0',
#   'bBfO8NafKOI',
#   'YiK-StK-w-o',
#   'myNqEqeK7l0',
#   'zUa8VHNXoJc',
#   '9y-sN3GRbDE',
#   'EEtW7luJFO0',
#   'GpHQAqWUQZI'],
#  5514: ['iAgyqc3_xQ8', 'WW4H0JyKRi8', 'e6Md72yXNtc'],
#  5502: ['PjQFGqu0RBY',
#   'punvYr4eeMY',
#   'LVrIBs-_Hao',
#   'CFlvovDh0SE',
#   '53sHwb7dYbM',
#   'ZCGX9zrEbOI',
#   'EnhdoXEuqis',
#   'Sct2SZP8XaM',
#   'jOMypreF2Nk'],
#  4932: ['mLpgOehsjh8',
#   'mezH2dWCdJg',
#   'DbnHuaXEiM0',
#   'wCVYLbF7_bo',
#   'zxHxgB07Yn8',
#   't3Ihh6MF9CA',
#   'F8YViZju0Pc',
#   'ZKipzc8VEhE',
#   'dW_tfPhYSoI',
#   'IhM4x0BogcQ'],
#  6013: ['hnJtyCM5X4E',
#   '95bDpySUYis',
#   'jEentILOx_M',
#   'KLPjiRrbiiw',
#   'eO5NqC1zg6Y',
#   'K2iilzfP01I',
#   'EsnYgmU-WfY',
#   'TrsBqXADq34'],
#  5045: ['U1KpmQ0lHus',
#   'YfVxuZCD8cI',
#   '1Jl7vcz7_7Y',
#   'R5XvSO3DBLU',
#   'HC0nVTR1b_4',
#   'SPDKEZBsydg',
#   'i-Fa0h_CXic',
#   'D5lb0LnGQrE',
#   'bwGPmbcwccs',
#   '-z9bKqkDv9E'],
#  6544: ['USi-OuDNyL4',
#   'F9p6mXCgOKc',
#   'aylIrjTA5eA',
#   'audhSaNLaH8',
#   '0jYEQdUK_ck',
#   'QcUr4vdlZt0',
#   'I25jWQewsNc',
#   'znms_0HbnlQ',
#   'dpFfxBgcaRs',
#   '-chdk3MAnVs',
#   'TH4qTn5JekA'],
#  6412: ['hbeXPfW2Qqg',
#   '549C5ZfvN14',
#   '54BVBcWGcw4',
#   'dbTxwctn0xg',
#   'expDlxxRhDg',
#   'MiXIPVSA5Oc',
#   'HY5Q3hgki-g',
#   '0L8loOYuhxc',
#   'zmQKBJlmtfM',
#   'ujD50Grulro'],
#  7755: ['ka7-w9UMu0o',
#   'SsEUsI5aFLw',
#   'mhZ0CbBr0BI',
#   'NRErugKLGRs',
#   'R1ZDMpLeRco',
#   'oxFIiDYGJ2I',
#   'PCOVvbvQenA',
#   'DFNbcfUWGIc',
#   '1XqDzSEnrak',
#   'SLmYdgX8T3g',
#   'J-pdU9V2_zU',
#   'Xb4MsEB7lzs',
#   'ZWRsB7zNm5w',
#   'Sj86I4sZVuQ',
#   'JFwfB6Eg-E0'],
#  7729: ['Nws_b4dRsqE',
#   '3Q79F6owrjY',
#   'oVlMgWR-FaA',
#   'deOYe_h3jn8',
#   'w59MiEkB0H4',
#   'L6j5gxo2SnA',
#   'JoVMO_bE980',
#   'udxyJLaui1M',
#   'QJcbe8P5900',
#   'cOjp0VsG1KE'],
#  7659: ['ELacrCCA-UY',
#   'oQSpWjQ9Tns',
#   'Pcc9NsuKhUc',
#   'MAnDvpYYfQA',
#   'R9jrg6s-9ic',
#   'NTa5CVxlhg8',
#   'BRrm4sld6Ag',
#   'IBxirbVZ9tM',
#   'HBgPk2et-Hg'],
#  5278: ['1DTjTZnrJ9I',
#   'P-bPJjvpkv4',
#   'B7VmOgQmn0c',
#   '9m44I5gOo0Q',
#   'wSghzV990O0',
#   'gnXPdtYhlB8',
#   'wdo5lKFImWk',
#   'O_6kQ_WmL7k',
#   'DggjZn3CSgk',
#   'F65vmIHWRew',
#   'Hs79HqrdsNA'],
#  7638: ['mOsdb8Eh7Eo',
#   'lRp0Jan1GuA',
#   'F66AakziT2M',
#   't6mhbkfrjuo',
#   'c5joJaI5XII',
#   'v98PIqfHbo4',
#   'ikfLLUfp4fc',
#   'qVcPTC-m7hA',
#   'lEJBMzmIHxY',
#   'DW6aeTybASk',
#   'IhpuRpJfLEk',
#   'FNqgUbqmQEY',
#   'FXXXU9ATtHw'],
#  2547: ['3PphEmDOZNQ',
#   '3hAS5R5L2MI',
#   'KiUw5EsIFaM',
#   'wrSMjGqRzpE',
#   'i0e8ZZpgsGU',
#   '9IrsWFf3-yM',
#   'c8xrKJlgAck',
#   'XmSSzZKDtRw',
#   'gLlY0IdDDBc',
#   '5-ZxxlbaW3g',
#   'KJ5BDadDmjM',
#   'wpMNGI0mlrM'],
#  3712: ['Y6ATVhgRQeA',
#   'e9fbEKp-xFA',
#   'L6oviyErBi8',
#   'uCKqUhhXvnE',
#   'dRQpYM1EjOQ',
#   'fPZeUgUhKoY',
#   'eroVdAeIt-A',
#   'TWNxqQBe6pA',
#   'eQwZj3gPDdw',
#   'gVmLE6TOr0g',
#   '-yhnmH7hgLI',
#   'oC1LwJsgCIU',
#   'VHUkLkeJFnI'],
#  3506: ['_63wXvrz7-0',
#   'yuqvtyUDp5g',
#   'Nl9POXdx4ss',
#   'EX8DVz17jpU',
#   'U_WyqEv-s1I',
#   'wmixenC6UKk',
#   'hORxU8RnbdA',
#   'gPDBoLcTn5U',
#   'IrhqH7pQu50',
#   'sEHCnF3lli0',
#   'YXCiKz5ypXc',
#   'q5EGtTRyvO8'],
#  4303: ['jH3_JduVGuk',
#   'AkMFgfp-boM',
#   '1ESCDXISgaI',
#   '_PYO3r29tuk',
#   'HPf4ZeYOl5w',
#   'i6Iw-z7Ktm8',
#   'GOeYX34wqxU',
#   'JdbHku6I274',
#   '0VJBPFerGoM',
#   '1bayiDxtYgo',
#   'YH-Gq0pA_bM'],
#  4016: ['oMldpeQu7sE',
#   'dXqNKIIoOcw',
#   'BZYVOur6xeY',
#   'QZTysLURrEE',
#   'u1Iq0pmok4Q',
#   'RsoxBBWOW9M',
#   'S85ay3FRUak'],
#  5722: ['JESv4p7PKuw',
#   'tGdL9Mk-CEQ',
#   '6AR82U4RDKA',
#   'm1d2z5VAq2k',
#   'GxI03v_TTbk',
#   '55qNF98DzHQ',
#   '9b9De48ZOSM',
#   '5OSk8EtmNso',
#   '5xpKFwyRdEM',
#   'QEOudlqoR9s'],
#  7347: ['9Vvl2EaSdSw',
#   '4zBqWdyyFMk',
#   '8u3rowXNp1c',
#   '70WwcCdoCd8',
#   '2GYUUusVpXI'],
#  7852: ['lSZ0ozIhi4w',
#   'hhSgryi3RW8',
#   'NSfZgaJ8FXc',
#   'isl9oun4Hj8',
#   'lMLD2cWuGUs',
#   'S-mDgqO8ing',
#   'WF6rWdVfD28'],
#  2562: ['7I-QGHB24F0',
#   'VxGR6L94SPw',
#   'P1yvjQp9NsM',
#   'KpAf8Kox1QU',
#   'Rl4VwnaGYbc',
#   'OsujksSF-zo',
#   '003cKU_Xrkk',
#   'fJjDlZiu20c',
#   'mUBNUpFFU1Q'],
#  3816: ['d5DYsMXXx5g',
#   'zw-WvHkfaX0',
#   'XsFn4VT-SMA',
#   'syE7tolAuJo',
#   '_JySICKIQ0Y',
#   'bPeGWuO6ETg',
#   '9QuBHatXXxU',
#   'sSpGwZkn3FI',
#   'PpSauVnLFNQ',
#   'XOW8XSgcZsU',
#   'zj8olSC59rU',
#   '0xpDIXaawJc',
#   'Px7EePVsKWQ'],
#  6084: ['prIob49hT5M',
#   'Ep74f2sdF7E',
#   'qU_jLfb0C_c',
#   'xJpIMeAt7XM',
#   'cvqtgoYGykw',
#   'WnBAiZheRyY',
#   'fAT91cJ2Kbo',
#   '_WUTp-o13vA',
#   'mgknE7r6OXw',
#   '5hCotGYkKjs',
#   'n36KGQxpEmg',
#   '7uGWg6F3jzg'],
#  3821: ['cS7p3O7flHQ',
#   'OEcmT_if9uU',
#   '_V4vwaJUKBA',
#   'tB3F7IcxCIU',
#   'kYj2bBM17pM',
#   'ZA4OEUpcSN8',
#   'aQjiXs9Chmw',
#   '-KRzxsRjrPg'],
#  7168: ['M3e7X1cplgw',
#   'KVKUdWxykbI',
#   'DZf6Uchkyz0',
#   'bMvGR2cmL8Q',
#   'WyzxKDMcRPk',
#   'z6aaL5hqFr4',
#   'vVnMFDMfxkU',
#   'MMF0cEb7c4A',
#   '75AVPTPyAbM',
#   'OkvRI8Tr89g'],
#  6270: ['eKg1_NffPlA',
#   'qIxjUXsmsng',
#   'vlD3qNqaptQ',
#   '86vlwFfJeZU',
#   'usscwbC-DhE',
#   'uf96_u7ncUg',
#   'hORX9E0nBPE',
#   'iV8EbpUEGz0',
#   'K10SGMxvyFo'],
#  6330: ['83U6_olrG9Y',
#   'lahJdKLnGYA',
#   'ETX5_ZAGo4k',
#   'Sj8hT3rThFA',
#   'DmhglUQdx7k',
#   'qfrgXHFUAz0',
#   'niw1H9KHDKo',
#   '3rtgdjBLxXo',
#   '86ADMBY1eRM',
#   '_GFllHz-Pys',
#   'fYRz9SNbjU0'],
#  5803: ['xszv-b6cxf0',
#   'EoOf3LgoYgs',
#   'A76lJ_oFJTE',
#   'NEklye-jVCE',
#   '04Gr4endaqk',
#   '6GmwGTv6p3w',
#   'x6oKl3tBOLk',
#   '-Vz7m0z7h5w',
#   'VauyE6DThtM',
#   'mCIS8rEWUBM'],
#  6168: ['oTGgNtrlwdM',
#   'Nw8NMONwFyU',
#   'dUThA-2aJl8',
#   'M9vSYAnEYQY',
#   '0M9NAD_b25g',
#   'RR06MGgsdZo',
#   'zlITVFBYox8'],
#  2988: ['WFZf4Ih-rz8',
#   'onfbd4oQfDU',
#   '7leZDEC698A',
#   '9G1aa-8wpyc',
#   'uXtZVPwLuDs',
#   '6LE-oZoQjRk',
#   'NRI6WxWBWMY',
#   'SBs4lwAf0GM',
#   'R39wZK7hwVs',
#   '82z-TY9raKs',
#   'u0rU5wUNBD4',
#   '5EW0-7XsbNM',
#   'NNeMB25deHo',
#   'ux7CX9W7_CQ'],
#  6900: ['gmV3x-PSljg',
#   '-8vBcBVqKCo',
#   'uMsVVy0aY48',
#   '6CVZYAKX6zw',
#   'gcNsil7MHCE',
#   '4uWUyFNLl_s',
#   'a9Zp0bfwJOs',
#   'hpe_K8I8ITU',
#   'qqGfsHDZPmw'],
#  6598: ['N4j5rmgh4OI',
#   'JXuQIL6uq9w',
#   'kgImRMFFFd0',
#   'hISeePLEv9g',
#   'K770sITZkSw',
#   'MT7sJ60RoQw',
#   'ZWGIYK77zak',
#   'Avu81Af01so',
#   'aUPV_uSa4i8',
#   'mlS-41p6F68',
#   'hb1gH-y91ug',
#   'tp1aPbmTgG0',
#   '4ivkan7QHXg',
#   'JgSa1XWBEnY',
#   'DiiHQasGi7I',
#   'SSXAQ78da4Y',
#   'Vx79wNaIDOg'],
#  7970: ['cgS0Lqo5sTE',
#   'cy5o52LB-p0',
#   'pOsVK8-xhSU',
#   'UyhgGIZl7as',
#   '7iq2IrQfKaw',
#   'OltKjVj0VNg',
#   'pHjR5DWhm6Y',
#   'ZHxycmStF5Y',
#   'MSBM0_QJ4rg',
#   '69xX-UMdRv4'],
#  5039: ['jQSgtp58T_g',
#   '37bPJDgBVO8',
#   'lnoAbzzUkcA',
#   'TN-mNZ_g_zc',
#   'Yj7Mu6kBYRo',
#   '19toix4VW_o',
#   'xXQyxr9cmuk',
#   '3WunFoekISc',
#   'SzZXKd7TaJQ',
#   '2qVF-9zqgCc',
#   'p7UsHL2vc1U',
#   'zxB4tZKpG2s'],
#  4200: ['6xV0mYhvYd4',
#   '3_-inkaW-CQ',
#   'BK0U3lnntsY',
#   'yhFmLtQQKqw',
#   'lFrlQb3qCMc',
#   'nQt1Ds4MNCs'],
#  3375: ['ooUecVoyQPg',
#   'wVtOdBIxIes',
#   '8leHRlF_VwU',
#   'jG6GVg_RHmE',
#   'HAVoZHK-oRM',
#   'OnwFuLYmd-0',
#   'jOJFg7OLvOA',
#   'oOtEWjXE8T4',
#   'h8LZbAGDrNY',
#   'K549s-PrA2s',
#   'kg7f3zEHuyA',
#   'vkNoWcqPWxI',
#   '0XsKsoiQAg8',
#   'ezoIiDYKcPo',
#   'BGItcm0xqM8'],
#  ...}

# %%
with open("logs/data/download/missing_pairs_ids.txt", "r") as f:
    missing_pairs_ids = [line.strip().split(" ")[0] for line in f]
missing_pairs_ids
# Out:
# ['EA8N7g8I_ns',
#  'wkx9hWqa_ok',
#  'kmVgCGWoXIA',
#  's7DAFyO56mE',
#  'jU0c6fS3d6U',
#  'Q5DJgt-XF_k',
#  'P8MNjOVOxvE',
#  'NYxyfhoTooE',
#  '7tNoD9m9qAo',
#  'yaUjx_JLkyo',
#  'pitvacBn-Eg',
#  'd1wtQlaQEuQ',
#  'KWtkFHDjiiQ',
#  '51JN86DU-3o',
#  '3gKx5ng9mgg',
#  'ajxTT1TKhYI',
#  '5d8sOQZ8npM',
#  'aZINEc6YVxI',
#  'tdvRwbRsLa0',
#  'kcq73_jFMn0',
#  'Kpba6f53hds',
#  'E_70QGzZFfU',
#  'lDTL8tfv6ts',
#  '4WIudT6-lco',
#  's_6CkYke0BE',
#  'OuBjMcI7ANU',
#  'XpDNYy78fiU',
#  'Dv4B6QrqVUA',
#  'Qk1ZlDKTyys',
#  'Ryij01EbQkI',
#  'N-wDlQkgpKA',
#  '-ZwpuQEFJjo',
#  '2NF9eJtwHOs',
#  'sWEunvKrFUI',
#  'V0nms7EK4BI',
#  'y1U89RB5PvU',
#  '5MvK7wOnDTw',
#  '9XZF9gJakaU',
#  'YO1TFY2CY0U',
#  'U0BQxLAxVqE',
#  'IKGd7bKTFe4',
#  'DJDF7BNS9js',
#  '2_dAybKwP80',
#  'Ip9HgJIqqws',
#  'msNijolazjU',
#  'BnbbHFCI9gc',
#  '8snvic2AfOU',
#  'ghz3sCzNXjw',
#  '4Oz_jWXeFLY',
#  'nF5U2a3wp0s',
#  'DU61hE-j0Bg',
#  'OtmvvRRahN0',
#  'gvtSKeS4U9k',
#  'iPVhhs7XqNw',
#  '_gLRoSqQ-uc',
#  'MOP0scB8_mQ',
#  'L6KXJaH0Q6Y',
#  'ktYtGMm7QMg',
#  '3H1zZNswdf4',
#  '8nnqYXX7VDU',
#  'oB4aXnc34MI',
#  'J3tO5bOUR2s',
#  'mDafoSoy4Vo',
#  'uiF5Pf7cTMw',
#  '2L2sjH3bigw',
#  'SNYqlWxcPhs',
#  'BXZRb2DLUTw',
#  'JFNX0Om9W-E',
#  'Evaloxxqs7o',
#  'i7TIUOqlocA',
#  'Kb8Uwn56MeM',
#  '4D0b6Rlcj8w',
#  '9I9APnlmbFY',
#  'M_7iyjTARh0',
#  'X18wYx5oj6g',
#  'KL0VXb2zAOQ',
#  'uto98LAM8QA',
#  'pUfaD5CN0Q0',
#  'D6JRj3PyX0E',
#  '77SHN-GPB6I',
#  'vkL-b4K1PtU',
#  'PS2J8Flq8hQ',
#  '2pMwgEK7r8A',
#  'GjC8JFSBtoU',
#  'WdEsgMwnifg',
#  'Cil_PVvPDDA',
#  'QeeAJ2oouwg',
#  'iG_JIMMv0Oo',
#  'oDCBclbDzyo',
#  'EoZ0p7Zytt8',
#  'JcAqJYNS8Fc',
#  'r9E1R5ogTps',
#  'mM53H_IEikA',
#  'HLP9Z1tgeDA',
#  'nhSfZkkSjF8',
#  'mJXr1FiuBR4',
#  'X7Ss0Dv3bkM',
#  'wgsY47qPOoA',
#  'GOSowy9fO60',
#  'NTTBpPWazuY',
#  'BeJT3HQGG2U',
#  'ESPU4dezo6E',
#  'fgfDQyVptFc',
#  'BCpf9SvkPDQ',
#  'LT0e6evqJ48',
#  'rdGLV6PvJYY',
#  'oI2UiWDCSNU',
#  'VHZ4jPNRTT8',
#  '4Qi7XxVJs8Q',
#  '5NaWAWQ49OA',
#  '42DK5zQKubc',
#  'BrWeZYxzBxY',
#  'w-vTs4GGXnQ',
#  'sEk-eQusdIE',
#  'joVnxBGWwSY',
#  'OKvlzlSNIJY',
#  '1Al69zWm3fU',
#  '-L30OP9ira4',
#  'm4Sc8HZB1k4',
#  'WCOjM7Gs3Io',
#  'IQC3zkV5Nqc',
#  'BKfQ7itcfvM',
#  'mo1S--r8PFk',
#  'GJ_bv8aSiHU',
#  'uAzsqHZUPh0',
#  '0dCWOv55qZQ',
#  'OUkC4hWKUs4',
#  'Adzs_HWx--M',
#  'ctlmqgPXcvY',
#  'T_fNWyGqGBk',
#  'iJ9L-Ywn3Dw',
#  '_2waeKI1M2w',
#  'vr3sBRYawoA',
#  'gvNnwhxpCUI',
#  'dFXThx3rxQ0',
#  '7VAr-6QCon4',
#  'ZoNdDPtZcmw',
#  'FiRj2W2zSTo',
#  'StrBXi8njHk',
#  'XJYCcCz209Y',
#  '1Qenukve05E',
#  'ikirpPAJAYY',
#  'qyfOE_78nT0',
#  'v8s2Af5Bq8A',
#  'fTiw__wFbDc',
#  'sNzpb4ZTHxM',
#  '7ghyjqhKFhY',
#  'ghfCqEj9IdI',
#  'IHCyFwvj9yY',
#  'zpbWKopsvTg',
#  '_OlMFW4QDx8',
#  'yt83alq8yGc',
#  'Q3usTryGt80',
#  'p8n32CaQMjk',
#  '3ffj5SxoQc8',
#  'YNwPSXYeiZs',
#  'opeuBmtFyaE',
#  'r_aJg825DF0',
#  'pJlEvrhfTN4',
#  'WtS0Ymoz01E',
#  'bqwB1KA3i74',
#  'X-qsT9Ke4jU',
#  'wPwWtFMkxLo',
#  'oRf7nqGs_jI',
#  'CuKq7yyWRXE',
#  '4-Lpd-4_fXY',
#  '9fCw41H0qHE',
#  'Xl-7_kDpc0g',
#  'XStViSWj_Kc',
#  'JPeuwMxLlXc',
#  'ZYDwxOwLdyc',
#  'R2YWW_MQnIU',
#  'oXy6GjX05VI',
#  'y4dF4_J1fn0',
#  'h2B8yGs2Nh0',
#  'GHiBAmXTAr4',
#  'utogRYqaRqA',
#  'Nnm1ZbokaaY',
#  'v3kuNz9fw9M',
#  'HEe0w2TKANw',
#  '1_wXSdLhdUY',
#  'ZBL8AbK7YGY',
#  '1OKwBKMF2Rw',
#  'm47rd2ur2cQ',
#  'oKwrm9S1fjE',
#  'S_gWwW_7SPc',
#  'a62w2Hv_byw',
#  'F5aZ7DbmF3M',
#  'W0gJEqq54dg',
#  'ljLI5gFsqvI',
#  'QQka41IfmKs',
#  'AHoSydVPw08',
#  'vaWaVoGDlWI',
#  'SRVJhRP2aho',
#  'K91K2g5ryjs',
#  'p80KSrf6SGE',
#  'YfRcOoEdBqk',
#  'MMCUl7A4lFg',
#  'n9qhKtvBUXI',
#  'is5Atf54qsI',
#  'HMrBlPi8jWs',
#  'mbxeLxOHcCU',
#  'rIBbG1XkuRg',
#  '3C3ELo1vcs4',
#  '4FJdaxTvFXs',
#  'hJReAtyK_vw',
#  'cAx5OWg-u88',
#  '3wmPv09bQQk',
#  'McrgupIaQ5g',
#  'YqtjKjeTL3U',
#  'TCzHy8KIWoM',
#  'tMUtGeCOj70',
#  'GZVGRs5YFcQ',
#  'mgx0ADFHDOM',
#  'YAGhD03XUgk',
#  'PJsAF9xUgjg',
#  'qz_Y3AjtbEM',
#  '8yLXaEWTCvo',
#  'yzW5-XIX0Vg',
#  '9kjATUm59VE',
#  'fzp5RDJ_gXc',
#  'GVCFwrBar2w',
#  'siXbx5sil6Y',
#  'f6GGqQLWZQ4',
#  'RQxvk6M_mjA',
#  'TUQrBlXWy-g',
#  'UTSpRGZBBhI',
#  'w0HiooqQZYA',
#  'ILfWJT9V8g8',
#  'yVw64IWUJPg',
#  'RR80M5jOtoQ',
#  'QQd0q6i1Wbc',
#  'OWVKgg7C-74',
#  'leTj13KF1Og',
#  'mV66oZV3l9g',
#  '_4GluwAe9Xg',
#  'H7lZfjsSBSE',
#  'w7aGpIeXhmo',
#  'IctjEZeyUt8',
#  'r94qCHwnzL4',
#  'ZNrFq_YNzvw',
#  'oiMfF3xMuJ8',
#  '1pAxO4PSS4g',
#  'vTMPVO9veOc',
#  'cHykn95k3ko',
#  'fJXyHpoWunE',
#  'h-QM8vssqqg',
#  '8TI-kydfFwg',
#  'iIQebqJzCO8',
#  '9KoUJVWA5nE',
#  'KGk5tQT4SGA',
#  'ktvoakQYZ00',
#  'Y26tyAi05IY',
#  'HSRVEGsBuTQ',
#  'lY-qW1Dwwno',
#  'CnvBEyTSYzk',
#  'dCYkkiOuUKM',
#  'E6l-M-t-_Gk',
#  'cBz2J_z_I2c',
#  '-72ZKQkp7Bo',
#  'RL99TF7eE70',
#  'ZOVdNZAlnSY',
#  'e9UKKyCx6Cw',
#  'fp_gsJxvJUY',
#  'yURvGY-QPrg',
#  'abvFwIkku9U',
#  'Sw5J5TIoneA',
#  'OqkTwNmDfvE',
#  'h0PyRTXzYIM',
#  'LfdJS_8M8bY',
#  '6uZJWOWK3zU',
#  '3MKJeX00vcQ',
#  't4KSFwtP1gg',
#  '4PWNsVmUxa8',
#  'v-keaUtiglg',
#  '9dVH8NCN5l4',
#  '5k2DWJiWfQE',
#  'fR6LrdKl-EA',
#  'kgVlgNeFGdQ',
#  'nnDHaMw09yo',
#  'w7GBMqEyl8I',
#  'tn96p8K-8Rk',
#  'VnqdaogGhbE',
#  'iLFvLMBwxCM',
#  'flURdaG1eFc',
#  'v3FWu15wypA',
#  '6qBIWHcXgDM',
#  'OcETW5VE7fA',
#  'fmR0oVXTVrQ',
#  'vpcFT9LJYDw',
#  'BLUfrqvgCKA',
#  'sfNTo3X_gDA',
#  'FZZy14-W6Bc',
#  'jSjPfJ2Onvg',
#  'flQ92W9_pRE',
#  'LzgpyzTpjIE',
#  'IL7PEjk1pys',
#  'BeeyzJ2Uynw',
#  '4f6wKQ5jcAA',
#  'K-GcrL1DRjI',
#  '8vjACwImv6M',
#  'oj6J1t7BNzM',
#  'T5GZAyfX8SM',
#  'W22ydwTZP4I',
#  'Er8MeYKTd7w',
#  'b8_BD_fvS_4',
#  'h2I37vgL1bo',
#  '2nU7810vR_g',
#  'Hr4JD2OoQQI',
#  'CJbRsbCTrVI',
#  'CymBsL8wL4g',
#  'lgczeThzen4',
#  'seLt1roJjmU',
#  '7fWa2-xFZoM',
#  'GTu_7p9FWgo',
#  'EzZUQH9faKE',
#  'WBqwCXsoQcE',
#  'lPA8e38L55s',
#  'Mn4LWVL0TGw',
#  'vRp1sdCkV_s',
#  'cOMP8YtkCXc',
#  't33Ba0EIZNk',
#  'hUBdwcUpNS0',
#  'pCoZpLOtV9k',
#  'FGmOOrTKRPM',
#  'TUFuSD20lAk',
#  '2I52j8aG3gk',
#  'gPxuS7rGDUM',
#  'DkiWBnW3yn4',
#  'OFLiABRCqtY',
#  'Dia_Kt8yJNg',
#  '1R5awCwplVc',
#  'ONwDZFGbw8o',
#  '9T7v_Sy3XLo',
#  'znhUjZkBuyw',
#  'SVktfMkJdQU',
#  'AZ7zKySUArw',
#  'bQ4GQOnbNqw',
#  'tugg3iXeLmM',
#  'ZPbk1wnK3Ow',
#  'x-LLAuAGjnM',
#  'lMHd95K1ZYE',
#  'C1C1Gs95PRQ',
#  'Ts-1s9oYh-M',
#  'bIBTDJNJDIs',
#  'yT9iYPh_7DU',
#  'wQhTpppcAF4',
#  '1K_ieMi6k_I',
#  'vgIJhavljN4',
#  'lDAgretW_8I',
#  'quMrUofinUQ',
#  '7zYGHM08DHE',
#  'J0IaMhxSf_k',
#  'G1aAqV6OedM',
#  'W3kxK_na_jA',
#  'FeYoZyY0XNQ',
#  '-OZbBLvgu5s',
#  'qG00CVUZLNY',
#  'hwis6ojBwL8',
#  'J_03HiOq7Yo',
#  'HQIUlYdRZzI',
#  '04E9YlPQBvc',
#  'oLT2JGc9HJY',
#  'rWPGAshZY0k',
#  'EWV6_zNYMF0',
#  '3jMaKlNBjug',
#  'EwzFahsEAqs',
#  '3DIa1sTU1Sg',
#  '6z2XdVMMPZw',
#  'FuwiQPYojDM',
#  'JT5BbQqEUcg',
#  'UtV5xI7O5sI',
#  'SCdAakK-1wY',
#  'i1qnN2pg0no',
#  'plfaLQa55q0',
#  'Bs9jq_c__tQ',
#  'My92w22FH1o',
#  'B-LoQBNHERI',
#  'hG2TXj7fRi8',
#  'mr16lFnfIrU',
#  'uXmUXjzik-A',
#  'S5tTsqfsYvA',
#  'A_mWsmHka_M',
#  '5-MxDBTdJAQ',
#  'ZOtbzTva-fM',
#  'tRnElznhzxg',
#  'mY5I4G3tyPI',
#  'T3Avk-sblVU',
#  'kfFUAFcp_5o',
#  '3WkaLNR5jks',
#  '6KNs-29Q1XQ',
#  'lwF5R_G9x0A',
#  'MdZL7x81N7w',
#  '7Tmo7O86awE',
#  'E-eWJX_i3dY',
#  'RhusG6MCyjA',
#  'XbEm0yEQRwY',
#  'HZv7V5NNd7Q',
#  'ix8YsZV-R-8',
#  'SklNUZlugtU',
#  '-zPbNlE7SPY',
#  'j5jBVQdQQIs',
#  '_lF5FWxHRdc',
#  '8eSHlxf5JKE',
#  'w5KlANTSJ-w',
#  'IBUOvVqSQEk',
#  'dbk8ZbAg0DA',
#  'oK13RfG1_YI',
#  'Zv4Aag_vmrE',
#  '-vfAmZT04dw',
#  'ILfa9VHIC5k',
#  'Qc2sgAM7d-w',
#  'ksHkGb8zDak',
#  'hheC8Cwvxuk',
#  'JwnrnU-D9Sg',
#  '0_K0CQZ4Wno',
#  'JbWW8HCCNZY',
#  '6zb3K_Vr5aY',
#  'LCOJfg1FNhw',
#  'GAPHCoW5r7U',
#  'NHf4fphjlQI',
#  'Aez9Ji3llJM',
#  'Nd-8XKBcS8Q',
#  'xvF9FzxHcW0',
#  'W8gjyjDIYEQ',
#  '4Nxoq1-hb84',
#  'DOr69Jm_ZnI',
#  'kJ6ert2hI2k',
#  'NoRi6YM6jIU',
#  'Kz5cixhqIaA',
#  '1jstPB3GDk0',
#  '7NgQYnuynvY',
#  '5WvD68d4Ogs',
#  'XydUurLvaf0',
#  'qfzIDFaMKZc',
#  'MFd4ualheEQ',
#  'zAU8YOoZY9A',
#  'ZfosUxm98Zc',
#  'ZpCK44e-Luw',
#  'FlIdW1CbCy8',
#  'gVVcj47eEAs',
#  '8lgpql5s1M8',
#  'nB40QHTJqPo',
#  '84hqZR5odfg',
#  'OjM7uHBawpw',
#  'twnzs7_z8Qo',
#  'nG0wmHo6p68',
#  'PA0MyYh6ys0',
#  'sCI9QcUs60s',
#  'xIejlaIs4lE',
#  '6ES0p3p-OhY',
#  'fpnSoAaxWPw',
#  'VUDLyPslHZQ',
#  'LYR033SUAV0',
#  '-U6lW861syA',
#  '6SllD-0klcU',
#  'beMckqz9INU',
#  'Bo6YFqY0Kn4',
#  'GVa6VCEQF9k',
#  'veB5DrP8UO0',
#  'Bx2-wFV9abY',
#  '50on6TQI9Ys',
#  'DGQXCRLpze0',
#  'DOxPXb9Z92E',
#  'o7wJCdifwmg',
#  'VEHJXt064rI',
#  'UqTNdbqHMZc',
#  'loVtIS1Prcw',
#  'p9e_vCbKrxY',
#  'TFaZC1iP_AI',
#  '6GPA5JVqTn8',
#  'CVyJH7xhOS4',
#  'ej77J_P4a_8',
#  'lDRTVN_rki8',
#  'ySr5AAIPwio',
#  'J3XzFaJ9lk4',
#  'MXHfCXJmTWU',
#  'GZBFWML8u38',
#  'FRbk-Mgd1R0',
#  'HMfb0ERAQmo',
#  'xqwKyjjGQMs',
#  'SvqJMrepc5s',
#  'SqLF-88hvAw',
#  'z7Cf9Pz4oXY',
#  'DIuz03Gdh9U',
#  'UhR1CCY74cw',
#  'HJ0uo0jsLqo',
#  'bZSLKfhDj90',
#  'Xdbijnhrf-s',
#  'u0lCweJpoC8',
#  '60Fvp6Mep4A',
#  '9UG1CJgx21w',
#  'VivkgX7ebV4',
#  'TTXIp8t2E6g',
#  'QpIOjsxfsWk',
#  'AE_SAMMylqs',
#  'Ox9Rt4g70EQ',
#  'ramCcVjr6fs',
#  'ehJ1EOS0xvU',
#  'K62hKhm0ekc',
#  'kQNrD_l5HMI',
#  'McRmVoHPzGk',
#  'jo7RxoJUvl8',
#  'oMoBDisQ-ow',
#  'uTrJw3IlObs',
#  'j0WE1GIun0Q',
#  'YN9qQWuFu0M',
#  '_mzES9uca0k',
#  'zE6AakOxqUo',
#  'C7x3oudTwKo',
#  '8lTUk2JHwDA',
#  '9Qz1FSzQ2mQ',
#  '9SXRwqRjzCU',
#  'uKJ1Gb4zHF8',
#  '_vfCrup_wqY',
#  'oibz6CVXNac',
#  '3L6RK_4r8To',
#  'WXz1zUsgFY4',
#  'NfCYP9T_i-I',
#  '1R0qbsvruAw',
#  'yiDINFEwtzs',
#  'VBlh2irPeOM',
#  'RfDqHDuj3fk',
#  'ieSCa50CnKE',
#  '_7hQIICIRRA',
#  'JPBEiYSxJao',
#  'qTOn2Ht_kPc',
#  'MLLwqtY4MQU',
#  'gixE2eaaXRU',
#  'JXhlSnm3HYM',
#  'Dz3NOArQSVw',
#  'Frs-FyLcL7I',
#  'CKRrEhXAJkc',
#  '6xlUpY1G1aI',
#  'o-K-s8Q8ap0',
#  'KyXrzbg8HpM',
#  '_Uv6C2s7lMM',
#  'ibrNU1TukBQ',
#  'fM3OEMQRBas',
#  'LoS6RH9fKmk',
#  'JmHddBObVoE',
#  'IITnvmnfi_Y',
#  'L8G8_-APrj8',
#  '0lsghVMXACI',
#  'u3VI7EiRUxE',
#  'oaPoEzgIW7k',
#  'ad9aa-HWQQk',
#  '3zP8QO8ptj0',
#  '0HgoiLfmADM',
#  'TuerJLdKfCc',
#  'l6BMNVzXB3Q',
#  'gpow-RsbA34',
#  '1R9qNAbRarw',
#  'bJRYggXp16Y',
#  'd76VsaB9YSI',
#  '6sBpHIeH78w',
#  'm8UVdIpRUYY',
#  'IbuOIRNT2rk',
#  'uL4FP0y7ItI',
#  'brStDb52jmY',
#  'gusqKZ4pPcY',
#  'bIJ8xLqFPIA',
#  'ynGP5c06WB4',
#  'eSL1po1rk8s',
#  'pml5SMKpSjM',
#  'C11qF_edSCc',
#  'vVT7PFy4S4c',
#  'siPsCEFOi38',
#  '8iSTWI-mumM',
#  'JrvxKmmbOvQ',
#  'CPACbIuPxEk',
#  'Xm5bZhYPVNI',
#  '7ONY8rA0l14',
#  'gBBjAhhRaTQ',
#  '0P7wRVZJRTA',
#  'vTnSkcDcino',
#  'I8_1S509evA',
#  'U1nj7TR66m8',
#  'z0fV_Zybsss',
#  'wYtCymNFs68',
#  'O7bdn8yf51M',
#  'K1UtkjRiwyw',
#  'q8lt656mqAc',
#  'EkxpatFA9qk',
#  'jrrqAYslfAI',
#  'hrqdlRm-jP0',
#  'vLIEG55Vgqo',
#  'mfCZUYqB2lM',
#  'A1eVyZ1US10',
#  'w44BXLATt5w',
#  'fa4Yl7Pn5Fg',
#  'SbDUY6c0ICE',
#  'eb_cDiZPfFk',
#  'wUE1rlSvB58',
#  'hUHrEFiktKI',
#  'FKgLw0khHac',
#  'KYXhOP0kex4',
#  'Ef4XYnJWl_E',
#  'jOu4Uvdgfik',
#  'U0J5Zr-FLs8',
#  'InVirEjbL34',
#  '40opT2Efhs0',
#  'nfX9mldsXtQ',
#  'hcrFRTOE9dA',
#  '8DG_oMutB04',
#  'ccn_6C6YZfQ',
#  'inbJXLQtZS4',
#  'rNDEvVKNTQY',
#  '9E_qZfNL_ss',
#  'iZr8r_excJU',
#  'a58IVR51WoY',
#  'XCUJ7lg5-qY',
#  'peh-aeHKegU',
#  'VRwRqtIcXXw',
#  'ZM-g45I0RoA',
#  '6lkoWncRsHM',
#  'DL00TDq9A-s',
#  'vUgSyaejII8',
#  'vVqt8CtVb-Y',
#  'eIWVLh5l64M',
#  'lXTa0LxP1Ds',
#  'wPCJpli_RX4',
#  'ceNllISphtI',
#  'wDL_BMX_JNk',
#  'X4ViZGZkP3A',
#  'ukPzbbPYbYc',
#  'ecWa8XI6jlw',
#  '-key6YKwtu8',
#  'vd7YOpIMVDc',
#  'CWh9MuVe5ZM',
#  'qc297bxb3jI',
#  'Qv-btZqe7Og',
#  'SSzUaGNyIKQ',
#  'U5tC3zy4ewI',
#  'FfkLmCsGTSU',
#  'jYPbVSn8sxU',
#  'YpyuIZ53Pgg',
#  'PnmH-2UeCBI',
#  'X9mnrfyYwv8',
#  'ZK68ywHtEU4',
#  'YKjGKynOptM',
#  'RStSJooHURY',
#  'gWJtD4aQKPg',
#  '-MU5OFK2Mjc',
#  'O1ym15x0tZ4',
#  'ugk86jvZKz0',
#  'gHJ_HyAZzxE',
#  'h4mrlFJYoL8',
#  'zS5jZpXjrno',
#  'wyzFloJ2PcU',
#  'Uu31-wZCaQY',
#  'GvkN7h0GK0k',
#  'yH41H8TF0KE',
#  'CXpVeZXdGLI',
#  'VHI-LsbrgQo',
#  'I8O21yKEYd4',
#  'kqcpFaBSONA',
#  'y3y8ZEhWZpA',
#  'UyRRrcjInhY',
#  'zpX3uR-LY4M',
#  'eTwHmpd8EgA',
#  'mdymQo-YuZY',
#  '76sbGwY6Kgs',
#  '83KatH8HoHM',
#  '7n2Z2OpgFts',
#  'hctYCvKNolI',
#  'LCBaDdMC8F8',
#  'LvPPaAkAmGg',
#  'SGLedVsIh20',
#  'y_5gqV_TQ04',
#  'uS1ppjrvnOk',
#  'ooLMDFkKHAQ',
#  'R2qpfqTNs1E',
#  'ywJsX3ArQaw',
#  'Rl3tuN2ZvnM',
#  'LPAZu9p9ps8',
#  'Yaw6Sa-87L8',
#  'oKriC0gbFLM',
#  'VmAfFM5aLUk',
#  'eG-xAIX5Of0',
#  'oPGx-B7IcpM',
#  'H7bMHu_Mc8g',
#  'neAzyz_lNgA',
#  'McwiQqrtmGI',
#  'ppzXloUAFS4',
#  'iNq99h0_a-4',
#  'xY3-P7r23Ys',
#  '4fZ7fjaCoyk',
#  'NMPSScNfR94',
#  'bWFqYDo_imM',
#  'Ph_b5vA4M6w',
#  'q8M5oA-TiZU',
#  'BNxRN5qtrL0',
#  'IWwdT_q7Q6Y',
#  'EjVTccHX3RY',
#  'nP88dd8kYoA',
#  'qSKU9irMP1w',
#  '8uIdik1fkQI',
#  'sZ7zCjhbw4U',
#  'TpQKxULHc1k',
#  '1_2Nr9AKvpU',
#  'fuX5UmPBgbg',
#  'HWyyUWebEbw',
#  'oCR1B1bSuoQ',
#  'joKwdfPtbks',
#  'SiQE20vspOw',
#  'Q1G7oHjZuy0',
#  'VaoFuuOrxJ0',
#  'v_pHW1ILFB8',
#  'hFkJCIN_8xQ',
#  '8B-LtH5zW5k',
#  'wuhshhsqw68',
#  'qtSgviHegAg',
#  'uarTRgpn2ms',
#  'FzWFwNa8qDU',
#  'Ostw31lGgcU',
#  '366Ve4xCXHw',
#  'Q7eH3-oi2Z4',
#  'RFE41BGCmy8',
#  'k_2-5Ej4C9U',
#  'ncIdn3CKlgY',
#  'WBbilmgKW7w',
#  '1nCYPitHAfM',
#  'ugKQ1TFAL1c',
#  'ysPHeSbGOwE',
#  '_IzxdwvpeOk',
#  'iq_Cx-KYFN0',
#  'FqtWh12XKn4',
#  'Lz2A3CPUAws',
#  '3CsPTSS0YJY',
#  'Tl0M3wvGpzA',
#  'sFqNsIn-j9o',
#  'hkOmvkuhwA8',
#  'vbyyRv40_Us',
#  '3Db5yGw3YiU',
#  'pIPy475Krgw',
#  'Oy9KfBHRRAo',
#  'L6WXIboxb6g',
#  '5be50C0PiTw',
#  'BgCmzhqkhfw',
#  'q1meZBapNpo',
#  'STKvGM73aok',
#  'NwqCpEK6iLY',
#  'teG3eIN1Xo8',
#  '_xzVMY2V7wY',
#  'dWkzSgSxzro',
#  'i4tCdR8f97s',
#  'js7_38yyzow',
#  'EfZ2ZgdGJX0',
#  'U12Wgdw2cQk',
#  'StsVR-IBLW8',
#  '8ZuMAOgygfM',
#  'EZLCapJsGEk',
#  'ewAHyph17kk',
#  'saINtyjzKyI',
#  'OcUR9P9p57Y',
#  'iUazrhm4yxM',
#  'KEHdZzc6wsI',
#  'zuYioEhS8mc',
#  '7KxmzgqWauA',
#  'pzUV3BtOyRo',
#  'T3tGmK5zQuY',
#  'MGFJA_2rVuI',
#  'hXfqXhpPNsY',
#  'rDDj4qs7BHA',
#  '2GcgNOkzGmc',
#  'ZZtk6wspRs4',
#  'jGBi8LZKtRw',
#  'zb0sV4xKH7g',
#  'T0scpb9LR5I',
#  'zLNyuzkS5oA',
#  'eB6Tx2B3NlA',
#  'di8_jBHrSRk',
#  'shbJWdBfUYQ',
#  'L94c6c8C8oU',
#  'HIjO5TlWCvw',
#  'J3xXLTxjIj4',
#  '4BmzORaN6XU',
#  'wpIuF2VXu68',
#  '-FTazwYvV64',
#  'DITHMx0vbB8',
#  't9a_HbWtH4g',
#  'nzoKwwmozX0',
#  '5tROkLbol3s',
#  'oUt8cgYTMRo',
#  '6JTIuFU6uY8',
#  '7zO53mSGl_E',
#  'UDf7ugya79o',
#  'XKsXohKMVjc',
#  'emPYcRZyAV4',
#  'oU23SN3sj-Y',
#  '6vkCnjVbgv8',
#  '2mOje5omDqo',
#  'Wzn4dTeSpKE',
#  'IG50t4EPgXE',
#  'tjbIUe0nb20',
#  'KeBaHOiKR_s',
#  'qAIwjG1xsBw',
#  'nxg0cq5P7xw',
#  'vtJIsS5eGRQ',
#  'DjDVTyWRcZk',
#  'fw2mAyW43uk',
#  'Qu3hC2rOCG0',
#  '33ARHiIO9JE',
#  'zQgB9sIeraY',
#  'wsVgDG69GHw',
#  '-PNsGaJDJQI',
#  '36cieH0YwFY',
#  '3SbAnh1mGjc',
#  'ebXaUy9I1TI',
#  '7hIWDoV0VW4',
#  'RY3f41lfkuo',
#  'bIeRniAPBEo',
#  'QmlqzcCiHvA',
#  'gfK9pQ6ompI',
#  'gkorUqLLOqA',
#  '-7AWkQDDp-8',
#  'MPPeMZxR2nM',
#  'BQNSOL4Dj3M',
#  't56dcYV1mqY',
#  'YUvwm9vnlpw',
#  'jf_Xihk5W20',
#  'tY8SKKDCeis',
#  'rbsLN4AkvyA',
#  'eQvQy1EWpKk',
#  'p79ufoUQdQY',
#  'DCW8HCj-G_0',
#  'hiwgt7_UtCs',
#  'lvOKGfl2cbw',
#  'Mq3Buf0i_YY',
#  'SIlg7HAcCv0',
#  'giR7RN3UcD0',
#  '8aeX6dzg5jU',
#  'eF93xbJScxg',
#  'L1PfgEkWQD0',
#  'RSjiFETdslM',
#  'U3mn0BtU7x0',
#  'STNDGBEckOk',
#  'Q9VLtSN8nSA',
#  'Rf90Jbbcr3M',
#  'bm5_8viqi28',
#  '0GOAyQESVsk',
#  'UJ13YcN5OFQ',
#  'M8gzfTBFPz0',
#  'u5DpVtoN5qo',
#  'WaBRiZ12iTk',
#  'nJWPBC07b9o',
#  'jwwGY88ikFw',
#  '7Pg7MzV4hsU',
#  'xMfKyEjBa4w',
#  'x3Cq607VILg',
#  'NUo6AlfuVV0',
#  'wiSixQ7VVII',
#  'HyEDc3PfZKA',
#  'FicSnweaNSY',
#  'dA54MoaaLEE',
#  '1zJdZYWlN0c',
#  'k3qg55Iq13k',
#  '3Snvi6wwz8E',
#  'BzhbfmHspFE',
#  'pmBWI18qjGI',
#  'pIjpnQdYOOg',
#  'mC-0cm1g5_g',
#  'RFFCLA5rf2Q',
#  'OXuTvG9peQg',
#  'je_sC6FJ8iU',
#  '8sO2guxmJNs',
#  'aI8H5tvY0ho',
#  'ohbHEiDTrZA',
#  'fD4wqwa48Z4',
#  'JCl16p8xo9w',
#  'yjohrPtAoso',
#  '0W0g1n2U-KM',
#  'XirYhAsn14Q',
#  'UeH-rJ837h4',
#  'xSuO9Aa2_64',
#  'YZbJ11UtaXc',
#  'tialXNmboqk',
#  'qcIW-eMHIL8',
#  'EWl7WUOlt34',
#  'CtwkwZ1lcGY',
#  'IYZ-c6G6PIY',
#  '9tF5ItqDmn8',
#  '5qJNZ0vFVhQ',
#  'GFcyEpys61k',
#  'zGlPgE66VxM',
#  '06cYWnqihl0',
#  'ItKCxviHBSA',
#  'P6T0xP1j5sA',
#  'LID3NzcmTnE',
#  'l1wR5cRx7mM',
#  '4fOqs2CMpMk',
#  'eG71XDuHoG0',
#  'KRokDDel6yI',
#  'NTlehboZttA',
#  'Wq68pQWfO4I',
#  'fhlWSALC7yk',
#  'ArMeEnAOPHI',
#  'Mp_bRgmph8A',
#  'x8PbYCzXmLk',
#  'YAzNuDzkcj0',
#  'Az7r3o_9ol0',
#  'p85reKKuA2w',
#  '0ZUldbKNh6g',
#  'XVwomB4EToY',
#  'atfMzYSp_U0',
#  'ZKulYs3lNGk',
#  'F01Uc9ZvgcY',
#  'DnykCyEtLyQ',
#  'Du8a5KyRHdI',
#  'kKtEVSFg9ZU',
#  'cZkaA3_SvZ0',
#  'wb9lIIxcJ38',
#  'x-SRsUieT9M',
#  'qnZvsYxLA4E',
#  '2DR_0_QNib4',
#  'gVIFh0Hly2k',
#  'cDoubtvdf0w',
#  '2dP8KpVtCHU',
#  '8w-hsRcSRHY',
#  'Uvrv9vmQObU',
#  '-N5YKjArRWg',
#  'oxDuZfqgkiI',
#  '5TwLTJ_zGBI',
#  'xdwmaUZKmas',
#  'S22xeq8xxFQ',
#  'i9--QMVpqCw',
#  'gU3fhVr6rmM',
#  '0Fjh-KX4wq4',
#  '6SX5f0mVMxQ',
#  '9a9O8UCegSE',
#  'mDoOl7d-sMU',
#  'ryuTz4diZTw',
#  'pTXqOPu9gSk',
#  'Xg2v4iIqThI',
#  'i5vu379JZPU',
#  'kzNixhWmRlw',
#  '2b96xl5YU1k',
#  '_-8vsnmbw3o',
#  '7azc8LeBvnE',
#  'Sz4gF49VOq0',
#  'XjxtOwuzHi4',
#  '-8Ai8Ghzbow',
#  'adclsaUfI1s',
#  'h8FBH7Iyxks',
#  '6N3T2xVpvFY',
#  'r4KJNv7Xboo',
#  '0lFhR6lmlUg',
#  'O0lIZ_menV0',
#  'Uq9BjlR7XXc',
#  'cEwwFHMsUYk',
#  '6WpQAE5F4g0',
#  'CNSMspI5wTo',
#  'k62DqRsTmfw',
#  'MTCTvcxmh6k',
#  'CF5ROgsY0kc',
#  'YDF4mVnNTsY',
#  'moH0egGmaBs',
#  'XfWQN3q27ss',
#  'tLmn0RNuUoo',
#  'PtnB_TW9jA0',
#  'RBl0miVa0H4',
#  'XpR8coS_Bos',
#  'JLgGatzD18A',
#  'sRl-jGwqllo',
#  'HriuD7MsUak',
#  '-DUxg3CLDX0',
#  'raZ9QEPTOJM',
#  'Kp_rURU6RGY',
#  'NT9z6MWiGdM',
#  'N-RFJHOTWTs',
#  'UD7wsI99-HE',
#  'zdYiKRpSXmc',
#  'zF50g7W7fkc',
#  'XFUypN3qtHQ',
#  'VmP2v3hIVDs',
#  'SeXLurfU67I',
#  'I96VLZWVtBc',
#  'zawmBw0AA9w',
#  'bojfyE56Ndo',
#  'TVyLfrUqyNI',
#  'uOzPekC4JVI',
#  '-RmnrhLmscU',
#  't7cCQ71AMWM',
#  'ThwB8wuEq-0',
#  'yDAkmdKM5yw',
#  'eKc8-YWIVqg',
#  'zwZWFuZA6sY',
#  'dMz1o7GWOZM',
#  'WJaIRQJ49Jo',
#  'yeDkdPc0mYQ',
#  'LTBXluGaRpo',
#  'U1TgQEpiuRU',
#  'a1FsvbopGg8',
#  '-MuU6pFmrN0',
#  'EZiUTX-fn6U',
#  'LQocHJGla-M',
#  'fCtmCI-yAeM',
#  'gPsoJaGXHsI',
#  '0j_NIBRSLFI',
#  ...]

# %%
missing_pairs_df = main_df_dedup[main_df_dedup['id'].isin(missing_pairs_ids)]

# %%
missing_pairs_df["man_cap_langs_2"] = missing_pairs_df["manual_caption_languages"]
# Out:
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_48829/4134933299.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   missing_pairs_df["man_cap_langs_2"] = missing_pairs_df["manual_caption_languages"]

# %%
missing_pairs_df["filtered_langs"] = missing_pairs_df["man_cap_langs_2"].apply(lambda langs: [lang for lang in langs.split(",") if lang.startswith("en")])
# Out:
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_48829/3317244041.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   missing_pairs_df["filtered_langs"] = missing_pairs_df["man_cap_langs_2"].apply(lambda langs: [lang for lang in langs.split(",") if lang.startswith("en")])

# %%
view_lang_cols_2(missing_pairs_df, 30)
# Out:
#                 id                                              title  \
# 1710   vK-dM5aW1IE  WALA KANG MGA MAGULANG  explain  | spoken by A...
# 1744   edssqlT3woM        Follow Your God Nudges | Women of Influence
# 1896   PhOdfxigdTg  GRADUATION IN FILM STUDIES IN INDIA | IF YOU W...
# 2220   i_a908UrEaE                  Up Close & Personal: THE AMERICAS
# 2859   dUThA-2aJl8  Bedtime Yoga | 15 Min Yoga Stretch - Nighttime...
# 3604   1169YX_TV40              TREASURE - ASAHI CAM EP 1 REACTION !!
# 5176   x8XN_kZ64Ug       Meet Miss Universe Malta 2017 Tiffany Pisani
# 5185   aT2dnECDQgM  Behind the Scenes of "Around the World in 80 T...
# 5755   uQuf8Y_0FF4  Savitar, the God of Speed • Are you a man or a...
# 6358   LbcjEYdwo1U  Signs From The Universe That You Are On The Ri...
# 7548   SuiMXAYS6cM   I hate you (an experience I will never forget..)
# 8469   obV0RaqcKxg  Million Dollars, But... Slow Mo Millionaires |...
# 9271   _aGR7ybVjxI  Mastering Path Creation: Pen, Curvature, and P...
# 9273   LszeoIaXOR0  Discover the Magic of Adobe Illustrator  Unlea...
# 9573   SUixs2hphWo              reading graphs with function notation
# 9675   t2mGPJiQasA  Rooster Teeth Animated Adventures - RTX-travag...
# 9937   0fWEmzNUHX8  Bullying and Violent Behavior: School Talk wit...
# 10333  Ewg5icrZixs                        RT Life - Love Your Country
# 12172  4DdieMBGUGI                        Enrichment-Werkzeuge im Web
# 12863  wEfS7d059HA          在离开家的时候都会永远记住。 但也许我最大胆的是家乡河流的形象。 output 3
# 13919  rw_ubJwxlEY       50p coin hunt collection #23 #coincollecting
# 13922  rsYIuH142Iw        coin hunt collecting 2£ #22 #coincollecting
# 13924  KwaSYsxO7yw        coin hunt collecting 2£ #21 #coincollecting
# 13933  S4empWoYKdE                    Coin Collection 2£ full bag #17
# 14635  4dGzvhfOdGQ                   We're With You - Medical Banking
# 16086  nbHyY6DP0PM         One Last Time (Ariana Grande)  cover by RJ
# 18143  mWptVBzF6TM  Ferit and Seyran | Best Funny Moments (humor) ...
# 18447  gAybLChp7Sk                        Agape Church Of God 7th Day
# 18895  K37Apa9qy1g                 CHIA SẼ SANG NGAFY-06 CONG DỒNG SE
# 19714  E1ckT71powA                           蒙面鸟哥｜ 一狗斗三鸭，终究还是有牙齿的更胜一筹
#
#       manual_caption_languages automatic_caption_orig_language language  \
# 1710                        en                              en     None
# 1744            en-uYU-mmqFLq8                              en       en
# 1896                     en-IN                              en       en
# 2220                        en                              en       en
# 2859                        en                              en       en
# 3604                        en                              id       id
# 5176                        en                              en       en
# 5185                        en                              en       en
# 5755                     en,fr                              en       en
# 6358                        en                              en       en
# 7548                        en                              en       en
# 8469                  en,pt-PT                              en       en
# 9271                     en-US                              en       en
# 9273                     en-US                              en       en
# 9573                        en                              en       en
# 9675                  en,ko,pt                              en       en
# 9937                        en                              en     None
# 10333                       en                              en       en
# 12172           en-UMYBvvsXfqo                              en       en
# 12863           en-uYU-mmqFLq8                              en       en
# 13919                       en                              en       en
# 13922                       en                              en       en
# 13924                       en                              en       en
# 13933                       en                              en     None
# 14635                       en                              en       en
# 16086                       en                              en       en
# 18143                       en                            None     None
# 18447           en-uYU-mmqFLq8                              en       en
# 18895           en-zL7EZQmMa4Q                              vi       vi
# 19714                       en                            None     None
#
#       man_cap_langs_2    filtered_langs
# 1710               en              [en]
# 1744   en-uYU-mmqFLq8  [en-uYU-mmqFLq8]
# 1896            en-IN           [en-IN]
# 2220               en              [en]
# 2859               en              [en]
# 3604               en              [en]
# 5176               en              [en]
# 5185               en              [en]
# 5755            en,fr              [en]
# 6358               en              [en]
# 7548               en              [en]
# 8469         en,pt-PT              [en]
# 9271            en-US           [en-US]
# 9273            en-US           [en-US]
# 9573               en              [en]
# 9675         en,ko,pt              [en]
# 9937               en              [en]
# 10333              en              [en]
# 12172  en-UMYBvvsXfqo  [en-UMYBvvsXfqo]
# 12863  en-uYU-mmqFLq8  [en-uYU-mmqFLq8]
# 13919              en              [en]
# 13922              en              [en]
# 13924              en              [en]
# 13933              en              [en]
# 14635              en              [en]
# 16086              en              [en]
# 18143              en              [en]
# 18447  en-uYU-mmqFLq8  [en-uYU-mmqFLq8]
# 18895  en-zL7EZQmMa4Q  [en-zL7EZQmMa4Q]
# 19714              en              [en]

# %%
missing_pairs_df.reset_index(drop=True, inplace=True)

# %%
rng = np.random.default_rng(42)
missing_pairs_df["download_lang"] = missing_pairs_df["filtered_langs"].apply(lambda langs: rng.choice(langs) if len(langs) > 0 else langs[0])
# Out:
# /var/folders/nb/w5db6h5j2px1zqxljsbzfxh80000gp/T/ipykernel_48829/2841883287.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   missing_pairs_df["download_lang"] = missing_pairs_df["filtered_langs"].apply(lambda langs: rng.choice(langs) if len(langs) > 0 else langs[0])

# %%
view_lang_cols_4(missing_pairs_df, 50)
# Out:
#              id                                              title  \
# 0   vK-dM5aW1IE  WALA KANG MGA MAGULANG  explain  | spoken by A...
# 1   edssqlT3woM        Follow Your God Nudges | Women of Influence
# 2   PhOdfxigdTg  GRADUATION IN FILM STUDIES IN INDIA | IF YOU W...
# 3   i_a908UrEaE                  Up Close & Personal: THE AMERICAS
# 4   dUThA-2aJl8  Bedtime Yoga | 15 Min Yoga Stretch - Nighttime...
# 5   1169YX_TV40              TREASURE - ASAHI CAM EP 1 REACTION !!
# 6   x8XN_kZ64Ug       Meet Miss Universe Malta 2017 Tiffany Pisani
# 7   aT2dnECDQgM  Behind the Scenes of "Around the World in 80 T...
# 8   uQuf8Y_0FF4  Savitar, the God of Speed • Are you a man or a...
# 9   LbcjEYdwo1U  Signs From The Universe That You Are On The Ri...
# 10  SuiMXAYS6cM   I hate you (an experience I will never forget..)
# 11  obV0RaqcKxg  Million Dollars, But... Slow Mo Millionaires |...
# 12  _aGR7ybVjxI  Mastering Path Creation: Pen, Curvature, and P...
# 13  LszeoIaXOR0  Discover the Magic of Adobe Illustrator  Unlea...
# 14  SUixs2hphWo              reading graphs with function notation
# 15  t2mGPJiQasA  Rooster Teeth Animated Adventures - RTX-travag...
# 16  0fWEmzNUHX8  Bullying and Violent Behavior: School Talk wit...
# 17  Ewg5icrZixs                        RT Life - Love Your Country
# 18  4DdieMBGUGI                        Enrichment-Werkzeuge im Web
# 19  wEfS7d059HA          在离开家的时候都会永远记住。 但也许我最大胆的是家乡河流的形象。 output 3
# 20  rw_ubJwxlEY       50p coin hunt collection #23 #coincollecting
# 21  rsYIuH142Iw        coin hunt collecting 2£ #22 #coincollecting
# 22  KwaSYsxO7yw        coin hunt collecting 2£ #21 #coincollecting
# 23  S4empWoYKdE                    Coin Collection 2£ full bag #17
# 24  4dGzvhfOdGQ                   We're With You - Medical Banking
# 25  nbHyY6DP0PM         One Last Time (Ariana Grande)  cover by RJ
# 26  mWptVBzF6TM  Ferit and Seyran | Best Funny Moments (humor) ...
# 27  gAybLChp7Sk                        Agape Church Of God 7th Day
# 28  K37Apa9qy1g                 CHIA SẼ SANG NGAFY-06 CONG DỒNG SE
# 29  E1ckT71powA                           蒙面鸟哥｜ 一狗斗三鸭，终究还是有牙齿的更胜一筹
# 30  5Z4uD7Ngtm4  ✅ See how can you change the background of a p...
# 31  NeE9QarqMbc                        SEMICONDUCTORS: BAND THEORY
# 32  A6rsYnK5oxE  Sunday December 19, Sunday Evening Worship Ser...
# 33  LPaYZgQl07g         HEZOMAGARI - Interactive Movie - DATA1 - 6
# 34  6yCu9wqsI6c                              noc18-me69 Lecture 08
# 35  EICa-6RuzV0                              noc18-me69 Lecture 07
# 36  hU3eBcS_snQ                                         Lecture 04
# 37  j9HWWyaveCg  noc18-mm20 Lecture 09-Activity and Thermodynam...
# 38  VNXdu3WHHSc                               noc20-me28-lec44_OLD
# 39  WCWfwiDcnqA                              noc18-me69 Lecture 25
# 40  5tbYmLFDvaI                              noc18-me69 Lecture 30
# 41  3rg8ocY_PHc    Fenris MMD animation | It Has Begun + Motion DL
# 42  GLv7qHa1dC0                              noc18-me69 Lecture 02
# 43  dNY715mW9DU                              noc18-me69 Lecture 04
# 44  i6wTvwjpd4s                              noc18-me69 Lecture 05
# 45  Vil0VFYjKrY  noc19-hs14 Lecture 16 - Understanding Word Mea...
# 46  uhsc33vlZFc  noc18-me58  Lec 58-Role of D16 and D26 Terms O...
# 47  I4o9UK2GEik      noc19-ae03  lec20-High Resolution Schemes-III
# 48  rLn9bNPF7ac                                         Lecture 38
# 49  1Gb19ufSDkc  Important Update - I751 Conditional Green Card...
#
#          manual_caption_languages automatic_caption_orig_language language  \
# 0                              en                              en     None
# 1                  en-uYU-mmqFLq8                              en       en
# 2                           en-IN                              en       en
# 3                              en                              en       en
# 4                              en                              en       en
# 5                              en                              id       id
# 6                              en                              en       en
# 7                              en                              en       en
# 8                           en,fr                              en       en
# 9                              en                              en       en
# 10                             en                              en       en
# 11                       en,pt-PT                              en       en
# 12                          en-US                              en       en
# 13                          en-US                              en       en
# 14                             en                              en       en
# 15                       en,ko,pt                              en       en
# 16                             en                              en     None
# 17                             en                              en       en
# 18                 en-UMYBvvsXfqo                              en       en
# 19                 en-uYU-mmqFLq8                              en       en
# 20                             en                              en       en
# 21                             en                              en       en
# 22                             en                              en       en
# 23                             en                              en     None
# 24                             en                              en       en
# 25                             en                              en       en
# 26                             en                            None     None
# 27                 en-uYU-mmqFLq8                              en       en
# 28                 en-zL7EZQmMa4Q                              vi       vi
# 29                             en                            None     None
# 30                             en                            None     None
# 31                             en                              en       en
# 32                 en-uYU-mmqFLq8                              en       en
# 33                             en                              es       es
# 34                 en-LUU0EuDKgKo                              en       en
# 35                 en-LUU0EuDKgKo                              en       en
# 36                 en-gG13fOM8Dfs                              en       en
# 37  en-LUU0EuDKgKo,en-gG13fOM8Dfs                              en       en
# 38                 en-LUU0EuDKgKo                              en       en
# 39                 en-LUU0EuDKgKo                              en       en
# 40                 en-LUU0EuDKgKo                              en       en
# 41                             en                            None     None
# 42                 en-LUU0EuDKgKo                              en       en
# 43                 en-LUU0EuDKgKo                              en       en
# 44                 en-LUU0EuDKgKo                              en       en
# 45                 en-6UJrWS5jR_I                              en       en
# 46                 en-LUU0EuDKgKo                            None     None
# 47                 en-LUU0EuDKgKo                            None     None
# 48                 en-6UJrWS5jR_I                              en       en
# 49                             en                              en       en
#
#                   man_cap_langs_2                    filtered_langs  \
# 0                              en                              [en]
# 1                  en-uYU-mmqFLq8                  [en-uYU-mmqFLq8]
# 2                           en-IN                           [en-IN]
# 3                              en                              [en]
# 4                              en                              [en]
# 5                              en                              [en]
# 6                              en                              [en]
# 7                              en                              [en]
# 8                           en,fr                              [en]
# 9                              en                              [en]
# 10                             en                              [en]
# 11                       en,pt-PT                              [en]
# 12                          en-US                           [en-US]
# 13                          en-US                           [en-US]
# 14                             en                              [en]
# 15                       en,ko,pt                              [en]
# 16                             en                              [en]
# 17                             en                              [en]
# 18                 en-UMYBvvsXfqo                  [en-UMYBvvsXfqo]
# 19                 en-uYU-mmqFLq8                  [en-uYU-mmqFLq8]
# 20                             en                              [en]
# 21                             en                              [en]
# 22                             en                              [en]
# 23                             en                              [en]
# 24                             en                              [en]
# 25                             en                              [en]
# 26                             en                              [en]
# 27                 en-uYU-mmqFLq8                  [en-uYU-mmqFLq8]
# 28                 en-zL7EZQmMa4Q                  [en-zL7EZQmMa4Q]
# 29                             en                              [en]
# 30                             en                              [en]
# 31                             en                              [en]
# 32                 en-uYU-mmqFLq8                  [en-uYU-mmqFLq8]
# 33                             en                              [en]
# 34                 en-LUU0EuDKgKo                  [en-LUU0EuDKgKo]
# 35                 en-LUU0EuDKgKo                  [en-LUU0EuDKgKo]
# 36                 en-gG13fOM8Dfs                  [en-gG13fOM8Dfs]
# 37  en-LUU0EuDKgKo,en-gG13fOM8Dfs  [en-LUU0EuDKgKo, en-gG13fOM8Dfs]
# 38                 en-LUU0EuDKgKo                  [en-LUU0EuDKgKo]
# 39                 en-LUU0EuDKgKo                  [en-LUU0EuDKgKo]
# 40                 en-LUU0EuDKgKo                  [en-LUU0EuDKgKo]
# 41                             en                              [en]
# 42                 en-LUU0EuDKgKo                  [en-LUU0EuDKgKo]
# 43                 en-LUU0EuDKgKo                  [en-LUU0EuDKgKo]
# 44                 en-LUU0EuDKgKo                  [en-LUU0EuDKgKo]
# 45                 en-6UJrWS5jR_I                  [en-6UJrWS5jR_I]
# 46                 en-LUU0EuDKgKo                  [en-LUU0EuDKgKo]
# 47                 en-LUU0EuDKgKo                  [en-LUU0EuDKgKo]
# 48                 en-6UJrWS5jR_I                  [en-6UJrWS5jR_I]
# 49                             en                              [en]
#
#      download_lang
# 0               en
# 1   en-uYU-mmqFLq8
# 2            en-IN
# 3               en
# 4               en
# 5               en
# 6               en
# 7               en
# 8               en
# 9               en
# 10              en
# 11              en
# 12           en-US
# 13           en-US
# 14              en
# 15              en
# 16              en
# 17              en
# 18  en-UMYBvvsXfqo
# 19  en-uYU-mmqFLq8
# 20              en
# 21              en
# 22              en
# 23              en
# 24              en
# 25              en
# 26              en
# 27  en-uYU-mmqFLq8
# 28  en-zL7EZQmMa4Q
# 29              en
# 30              en
# 31              en
# 32  en-uYU-mmqFLq8
# 33              en
# 34  en-LUU0EuDKgKo
# 35  en-LUU0EuDKgKo
# 36  en-gG13fOM8Dfs
# 37  en-LUU0EuDKgKo
# 38  en-LUU0EuDKgKo
# 39  en-LUU0EuDKgKo
# 40  en-LUU0EuDKgKo
# 41              en
# 42  en-LUU0EuDKgKo
# 43  en-LUU0EuDKgKo
# 44  en-LUU0EuDKgKo
# 45  en-6UJrWS5jR_I
# 46  en-LUU0EuDKgKo
# 47  en-LUU0EuDKgKo
# 48  en-6UJrWS5jR_I
# 49              en

# %%
import json
batch_dict_list = []
for idx, video_ids in batch_idx_ids.items():
    batch_df = missing_pairs_df[missing_pairs_df['id'].isin(video_ids)]
    id_lang_dicts = batch_df[["id", "download_lang"]].to_dict("records")
    id_lang = [(d["id"], d["download_lang"]) for d in id_lang_dicts]
    batch_dict = {"videoIds": id_lang, "batchIdx": idx}
    batch_dict_list.append(batch_dict)
    
with open("logs/data/download/1M_en/missing_pairs.jsonl", "w") as f:
    for d in batch_dict_list:
        f.write(json.dumps(d) + "\n")

# %% [markdown]
# ## Downloading text data from pool (estimated to be English)

# %%
with open("data/metadata/approx_en_only.txt", "r") as f:
    all_en_ids = [line.strip() for line in f]
